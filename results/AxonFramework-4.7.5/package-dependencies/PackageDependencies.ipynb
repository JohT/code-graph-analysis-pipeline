# %% [markdown]
# # Package Dependencies for Java with Neo4j
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [py2neo](https://py2neo.org/2021.1/)

# %%
import os
import matplotlib.pyplot as plot
from py2neo import Graph

# %%
#Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
#before starting jupyter notebook to provide the password for the user "neo4j". 
#It is not recommended to hardcode the password into jupyter notebook for security reasons.
graph = Graph("bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))

# %%
def getCypherQueryFromFile(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def queryCypherToDataFrame(cypherFileName):
    return graph.run(getCypherQueryFromFile(cypherFileName)).to_data_frame()

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Artifacts
#
# ### Table 1
#
# - List all the artifacts this notebook is based on

# %%
queryCypherToDataFrame("../cypher/List_all_existing_artifacts.cypher")
# Out:
#                    artifactName  packages  types
# 0      axon-disruptor-4.7.5.jar         1     22
# 1  axon-eventsourcing-4.7.5.jar         9    130
# 2           axon-test-4.7.5.jar         8     85
# 3      axon-messaging-4.7.5.jar        61    729
# 4      axon-modelling-4.7.5.jar        10    149
# 5  axon-configuration-4.7.5.jar         1     39

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to a lot of trouble when one of these packages needs to be changed.
#
# ### Table 2
# - List packages with cyclic dependencies

# %%
queryCypherToDataFrame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_as_List.cypher")
# Out:
#                                           packageName  \
# 0                     org.axonframework.queryhandling
# 1                     org.axonframework.eventhandling
# 2                     org.axonframework.eventhandling
# 3                     org.axonframework.eventhandling
# 4                     org.axonframework.queryhandling
# 5                     org.axonframework.eventsourcing
# 6                          org.axonframework.deadline
# 7              org.axonframework.messaging.unitofwork
# 8         org.axonframework.commandhandling.callbacks
# 9                   org.axonframework.commandhandling
# 10                    org.axonframework.eventhandling
# 11              org.axonframework.eventhandling.async
# 12             org.axonframework.eventhandling.replay
# 13    org.axonframework.serialization.upcasting.event
# 14    org.axonframework.eventsourcing.eventstore.jdbc
# 15       org.axonframework.queryhandling.registration
# 16                    org.axonframework.eventhandling
# 17             org.axonframework.messaging.annotation
# 18                   org.axonframework.modelling.saga
# 19     org.axonframework.modelling.command.inspection
# 20                        org.axonframework.messaging
# 21  org.axonframework.commandhandling.distributed....
#
#                                  dependentPackageName  \
# 0           org.axonframework.messaging.responsetypes
# 1                           org.axonframework.tracing
# 2                         org.axonframework.messaging
# 3              org.axonframework.messaging.annotation
# 4                           org.axonframework.tracing
# 5          org.axonframework.eventsourcing.eventstore
# 6                           org.axonframework.tracing
# 7                         org.axonframework.messaging
# 8                   org.axonframework.commandhandling
# 9                           org.axonframework.tracing
# 10                    org.axonframework.serialization
# 11                    org.axonframework.eventhandling
# 12                    org.axonframework.eventhandling
# 13                    org.axonframework.eventhandling
# 14  org.axonframework.eventsourcing.eventstore.jdb...
# 15                    org.axonframework.queryhandling
# 16         org.axonframework.eventhandling.tokenstore
# 17           org.axonframework.messaging.interceptors
# 18         org.axonframework.modelling.saga.metamodel
# 19                org.axonframework.modelling.command
# 20                    org.axonframework.serialization
# 21      org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.882353             16               1
# 1                   0.857143             13               1
# 2                   0.842105             35               3
# 3                   0.840000             23               2
# 4                   0.800000              9               1
# 5                   0.777778             16               2
# 6                   0.750000              7               1
# 7                   0.750000             14               2
# 8                   0.733333             13               2
# 9                   0.666667              5               1
# 10                  0.647059             14               3
# 11                  0.538462             10               3
# 12                  0.454545              8               3
# 13                  0.333333              6               3
# 14                  0.317073             27              14
# 15                  0.250000              5               3
# 16                  0.230769              8               5
# 17                  0.200000              3               2
# 18                  0.142857              4               3
# 19                  0.130435             13              10
# 20                  0.111111             10               8
# 21                  0.076923              7               6
#
#                                   forwardDependencies  \
# 0   [QueryMessage->ResponseType, GenericStreamingQ...
# 1   [AbstractEventBus$Builder->SpanFactory, Abstra...
# 2   [EventMessage->Message, AbstractEventProcessor...
# 3   [AllowReplay->HasHandlerAttributes, ResetHandl...
# 4   [SimpleQueryBus->SpanFactory, SimpleQueryBus->...
# 5   [EventSourcingRepository->EventStore, EventSou...
# 6   [SimpleDeadlineManager$Builder->NoOpSpanFactor...
# 7   [CurrentUnitOfWork->MetaData, MessageProcessin...
# 8   [LoggingCallback->CommandResultMessage, Loggin...
# 9   [SimpleCommandBus$Builder->SpanFactory, Simple...
# 10  [AbstractSequencedDomainEventEntry->Serializer...
# 11  [AsynchronousEventProcessingStrategy->EventPro...
# 12  [ReplayAwareMessageHandlerWrapper$ReplayBlocki...
# 13  [InitialEventRepresentation->TrackingToken, In...
# 14  [JdbcEventStorageEngine->LastSequenceNumberFor...
# 15  [FailingDuplicateQueryHandlerResolver->QuerySu...
# 16  [TrackingEventProcessor$WorkerLauncher->Unable...
# 17  [ResultParameterResolverFactory->ResultHandler...
# 18  [AnnotatedSagaManager$Builder->AnnotationSagaM...
# 19  [CreationPolicyMember->AggregateCreationPolicy...
# 20  [ResultMessage->Serializer, ResultMessage->Ser...
# 21  [AndCommandMessageFilter->CommandMessageFilter...
#
#                                  backwardDependencies
# 0   [ConvertingResponseMessage->QueryResponseMessage]
# 1                  [NestingSpanFactory->EventMessage]
# 2   [Headers->EventMessage, StreamableMessageSourc...
# 3   [SourceIdParameterResolverFactory$SourceIdPara...
# 4                           [SpanUtils->QueryMessage]
# 5   [DomainEventStream->EventStreamUtils, Abstract...
# 6                        [SpanUtils->DeadlineMessage]
# 7   [MessageHandlerInterceptor->UnitOfWork, Defaul...
# 8   [SimpleCommandBus$Builder->LoggingCallback, Si...
# 9                         [SpanUtils->CommandMessage]
# 10  [AbstractXStreamSerializer->GenericEventMessag...
# 11  [SimpleEventHandlerInvoker$Builder->Sequential...
# 12  [ResetHandler->ResetContext, AnnotationEventHa...
# 13  [EventUtils->InitialEventRepresentation, Event...
# 14  [JdbcEventStorageEngineStatements->EventSchema...
# 15  [SimpleQueryBus->DuplicateQueryHandlerResolver...
# 16  [TokenStore->Segment, TokenStore->TrackingToke...
# 17  [ResultHandler->HasHandlerAttributes, MessageH...
# 18  [AnnotationSagaMetaModelFactory$InspectedSagaM...
# 19  [ForwardingMode->EntityModel, ForwardMatchingI...
# 20  [SerializedMessage->AbstractMessage, Serialize...
# 21  [CommandMessageFilter->AndCommandMessageFilter...

# %% [markdown]
# ### Table 3
# - List packages with cyclic dependencies with every dependency in a separate row sorted by the easiest and most valuable to resolve

# %%
queryCypherToDataFrame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_as_unwinded_List.cypher").head(60)
# Out:
#                         packageName  \
# 0   org.axonframework.queryhandling
# 1   org.axonframework.queryhandling
# 2   org.axonframework.queryhandling
# 3   org.axonframework.queryhandling
# 4   org.axonframework.queryhandling
# 5   org.axonframework.queryhandling
# 6   org.axonframework.queryhandling
# 7   org.axonframework.queryhandling
# 8   org.axonframework.queryhandling
# 9   org.axonframework.queryhandling
# 10  org.axonframework.queryhandling
# 11  org.axonframework.queryhandling
# 12  org.axonframework.queryhandling
# 13  org.axonframework.queryhandling
# 14  org.axonframework.queryhandling
# 15  org.axonframework.queryhandling
# 16  org.axonframework.queryhandling
# 17  org.axonframework.eventhandling
# 18  org.axonframework.eventhandling
# 19  org.axonframework.eventhandling
# 20  org.axonframework.eventhandling
# 21  org.axonframework.eventhandling
# 22  org.axonframework.eventhandling
# 23  org.axonframework.eventhandling
# 24  org.axonframework.eventhandling
# 25  org.axonframework.eventhandling
# 26  org.axonframework.eventhandling
# 27  org.axonframework.eventhandling
# 28  org.axonframework.eventhandling
# 29  org.axonframework.eventhandling
# 30  org.axonframework.eventhandling
# 31  org.axonframework.eventhandling
# 32  org.axonframework.eventhandling
# 33  org.axonframework.eventhandling
# 34  org.axonframework.eventhandling
# 35  org.axonframework.eventhandling
# 36  org.axonframework.eventhandling
# 37  org.axonframework.eventhandling
# 38  org.axonframework.eventhandling
# 39  org.axonframework.eventhandling
# 40  org.axonframework.eventhandling
# 41  org.axonframework.eventhandling
# 42  org.axonframework.eventhandling
# 43  org.axonframework.eventhandling
# 44  org.axonframework.eventhandling
# 45  org.axonframework.eventhandling
# 46  org.axonframework.eventhandling
# 47  org.axonframework.eventhandling
# 48  org.axonframework.eventhandling
# 49  org.axonframework.eventhandling
# 50  org.axonframework.eventhandling
# 51  org.axonframework.eventhandling
# 52  org.axonframework.eventhandling
# 53  org.axonframework.eventhandling
# 54  org.axonframework.eventhandling
# 55  org.axonframework.eventhandling
# 56  org.axonframework.eventhandling
# 57  org.axonframework.eventhandling
# 58  org.axonframework.eventhandling
# 59  org.axonframework.eventhandling
#
#                          dependentPackageName  \
# 0   org.axonframework.messaging.responsetypes
# 1   org.axonframework.messaging.responsetypes
# 2   org.axonframework.messaging.responsetypes
# 3   org.axonframework.messaging.responsetypes
# 4   org.axonframework.messaging.responsetypes
# 5   org.axonframework.messaging.responsetypes
# 6   org.axonframework.messaging.responsetypes
# 7   org.axonframework.messaging.responsetypes
# 8   org.axonframework.messaging.responsetypes
# 9   org.axonframework.messaging.responsetypes
# 10  org.axonframework.messaging.responsetypes
# 11  org.axonframework.messaging.responsetypes
# 12  org.axonframework.messaging.responsetypes
# 13  org.axonframework.messaging.responsetypes
# 14  org.axonframework.messaging.responsetypes
# 15  org.axonframework.messaging.responsetypes
# 16  org.axonframework.messaging.responsetypes
# 17                  org.axonframework.tracing
# 18                  org.axonframework.tracing
# 19                  org.axonframework.tracing
# 20                  org.axonframework.tracing
# 21                  org.axonframework.tracing
# 22                  org.axonframework.tracing
# 23                  org.axonframework.tracing
# 24                  org.axonframework.tracing
# 25                  org.axonframework.tracing
# 26                  org.axonframework.tracing
# 27                  org.axonframework.tracing
# 28                  org.axonframework.tracing
# 29                  org.axonframework.tracing
# 30                  org.axonframework.tracing
# 31                org.axonframework.messaging
# 32                org.axonframework.messaging
# 33                org.axonframework.messaging
# 34                org.axonframework.messaging
# 35                org.axonframework.messaging
# 36                org.axonframework.messaging
# 37                org.axonframework.messaging
# 38                org.axonframework.messaging
# 39                org.axonframework.messaging
# 40                org.axonframework.messaging
# 41                org.axonframework.messaging
# 42                org.axonframework.messaging
# 43                org.axonframework.messaging
# 44                org.axonframework.messaging
# 45                org.axonframework.messaging
# 46                org.axonframework.messaging
# 47                org.axonframework.messaging
# 48                org.axonframework.messaging
# 49                org.axonframework.messaging
# 50                org.axonframework.messaging
# 51                org.axonframework.messaging
# 52                org.axonframework.messaging
# 53                org.axonframework.messaging
# 54                org.axonframework.messaging
# 55                org.axonframework.messaging
# 56                org.axonframework.messaging
# 57                org.axonframework.messaging
# 58                org.axonframework.messaging
# 59                org.axonframework.messaging
#
#                                            dependency  \
# 0     QueryResponseMessage<-ConvertingResponseMessage
# 1                          QueryMessage->ResponseType
# 2          GenericStreamingQueryMessage->ResponseType
# 3   GenericStreamingQueryMessage->PublisherRespons...
# 4                        SimpleQueryBus->ResponseType
# 5                     QuerySubscription->ResponseType
# 6                 StreamingQueryMessage->ResponseType
# 7                   DefaultQueryGateway->ResponseType
# 8                          QueryGateway->ResponseType
# 9                         QueryGateway->ResponseTypes
# 10                  GenericQueryMessage->ResponseType
# 11    SimpleQueryUpdateEmitter->PublisherResponseType
# 12  SimpleQueryUpdateEmitter->MultipleInstancesRes...
# 13     SimpleQueryUpdateEmitter->OptionalResponseType
# 14             SimpleQueryUpdateEmitter->ResponseType
# 15             SubscriptionQueryMessage->ResponseType
# 16      GenericSubscriptionQueryMessage->ResponseType
# 17                   EventMessage<-NestingSpanFactory
# 18              AbstractEventBus$Builder->SpanFactory
# 19          AbstractEventBus$Builder->NoOpSpanFactory
# 20                       AbstractEventProcessor->Span
# 21                AbstractEventProcessor->SpanFactory
# 22        TrackingEventProcessor$Builder->SpanFactory
# 23                       TrackingEventProcessor->Span
# 24                TrackingEventProcessor->SpanFactory
# 25                      AbstractEventBus->SpanFactory
# 26                             AbstractEventBus->Span
# 27                SimpleEventBus$Builder->SpanFactory
# 28    AbstractEventProcessor$Builder->NoOpSpanFactory
# 29        AbstractEventProcessor$Builder->SpanFactory
# 30     SubscribingEventProcessor$Builder->SpanFactory
# 31                              EventMessage<-Headers
# 32             TrackingToken<-StreamableMessageSource
# 33                        DomainEventMessage<-Headers
# 34                              EventMessage->Message
# 35              AbstractEventProcessor->ResultMessage
# 36    AbstractEventProcessor->DefaultInterceptorChain
# 37  AbstractEventProcessor->MessageHandlerInterceptor
# 38  TrackingEventProcessor$Builder->StreamableMess...
# 39                    TrackingEventProcessor->Message
# 40    TrackingEventProcessor->StreamableMessageSource
# 41           TrackingEventProcessor->InterceptorChain
# 42       AbstractEventBus->MessageDispatchInterceptor
# 43                      GenericEventMessage->MetaData
# 44                GenericEventMessage->GenericMessage
# 45              GenericEventMessage->MessageDecorator
# 46                       GenericEventMessage->Message
# 47  MultiStreamableMessageSource->StreamableMessag...
# 48                EventBus->SubscribableMessageSource
# 49        EventBus->MessageDispatchInterceptorSupport
# 50   StreamingEventProcessor->StreamableMessageSource
# 51          GenericTrackedDomainEventMessage->Message
# 52  TrackingEventProcessorConfiguration->Streamabl...
# 53  SequenceNumberParameterResolverFactory$Sequenc...
# 54  MultiStreamableMessageSource$Builder->Streamab...
# 55                               ReplayToken->Message
# 56                       EventMessageHandler->Message
# 57                EventMessageHandler->MessageHandler
# 58             AnnotationEventHandlerAdapter->Message
# 59          EventProcessor->MessageHandlerInterceptor
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.882353             16               1
# 1                   0.882353             16               1
# 2                   0.882353             16               1
# 3                   0.882353             16               1
# 4                   0.882353             16               1
# 5                   0.882353             16               1
# 6                   0.882353             16               1
# 7                   0.882353             16               1
# 8                   0.882353             16               1
# 9                   0.882353             16               1
# 10                  0.882353             16               1
# 11                  0.882353             16               1
# 12                  0.882353             16               1
# 13                  0.882353             16               1
# 14                  0.882353             16               1
# 15                  0.882353             16               1
# 16                  0.882353             16               1
# 17                  0.857143             13               1
# 18                  0.857143             13               1
# 19                  0.857143             13               1
# 20                  0.857143             13               1
# 21                  0.857143             13               1
# 22                  0.857143             13               1
# 23                  0.857143             13               1
# 24                  0.857143             13               1
# 25                  0.857143             13               1
# 26                  0.857143             13               1
# 27                  0.857143             13               1
# 28                  0.857143             13               1
# 29                  0.857143             13               1
# 30                  0.857143             13               1
# 31                  0.842105             35               3
# 32                  0.842105             35               3
# 33                  0.842105             35               3
# 34                  0.842105             35               3
# 35                  0.842105             35               3
# 36                  0.842105             35               3
# 37                  0.842105             35               3
# 38                  0.842105             35               3
# 39                  0.842105             35               3
# 40                  0.842105             35               3
# 41                  0.842105             35               3
# 42                  0.842105             35               3
# 43                  0.842105             35               3
# 44                  0.842105             35               3
# 45                  0.842105             35               3
# 46                  0.842105             35               3
# 47                  0.842105             35               3
# 48                  0.842105             35               3
# 49                  0.842105             35               3
# 50                  0.842105             35               3
# 51                  0.842105             35               3
# 52                  0.842105             35               3
# 53                  0.842105             35               3
# 54                  0.842105             35               3
# 55                  0.842105             35               3
# 56                  0.842105             35               3
# 57                  0.842105             35               3
# 58                  0.842105             35               3
# 59                  0.842105             35               3

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.
#
# ### Table 3
# - List top 20 most used combinations of methods of larger Types that might benefit from *Interface Segregation*

# %%
queryCypherToDataFrame("../cypher/Candidates_for_Interface_Segregation.cypher").head(20)
# Out:
#                                     dependentType.fqn  declaredMethods  \
# 0    org.axonframework.commandhandling.CommandMessage                9
# 1   org.axonframework.eventhandling.DomainEventMes...               10
# 2        org.axonframework.eventhandling.EventMessage                9
# 3        org.axonframework.eventhandling.EventMessage                9
# 4   org.axonframework.eventhandling.TrackedEventMe...               10
# 5   org.axonframework.eventhandling.DomainEventMes...               10
# 6           org.axonframework.messaging.ResultMessage                9
# 7   org.axonframework.commandhandling.GenericComma...               15
# 8   org.axonframework.commandhandling.GenericComma...               14
# 9   org.axonframework.eventhandling.TrackedEventMe...               12
# 10  org.axonframework.deadline.GenericDeadlineMessage               11
# 11         org.axonframework.deadline.DeadlineMessage               10
# 12  org.axonframework.eventhandling.DomainEventMes...               10
# 13  org.axonframework.eventhandling.GenericEventMe...               10
# 14  org.axonframework.common.transaction.NoTransac...                4
# 15  org.axonframework.modelling.command.inspection...               13
# 16  org.axonframework.eventhandling.DomainEventMes...               11
# 17  org.axonframework.eventhandling.DomainEventMes...               10
# 18  org.axonframework.eventhandling.DomainEventMes...               10
# 19  org.axonframework.eventhandling.GapAwareTracki...               10
#
#                                     calledMethodNames  calledMethods  \
# 0                                    [getCommandName]              1
# 1                                 [getSequenceNumber]              1
# 2                       [getTimestamp, getIdentifier]              2
# 3                                     [getIdentifier]              1
# 4                                     [trackingToken]              1
# 5   [getType, getSequenceNumber, getAggregateIdent...              3
# 6                    [exceptionResult, isExceptional]              2
# 7                            [asCommandResultMessage]              1
# 8                            [asCommandResultMessage]              1
# 9                                     [trackingToken]              1
# 10                                [asDeadlineMessage]              1
# 11                                  [getDeadlineName]              1
# 12                           [getAggregateIdentifier]              1
# 13                                   [asEventMessage]              1
# 14                                         [instance]              1
# 15                                             [type]              1
# 16  [getType, getSequenceNumber, getAggregateIdent...              3
# 17                                          [getType]              1
# 18        [getSequenceNumber, getAggregateIdentifier]              2
# 19  [withGapsTruncatedAt, getGaps, newInstance, ge...              5
#
#     callerTypes
# 0            17
# 1             8
# 2             8
# 3             8
# 4             7
# 5             5
# 6             5
# 7             4
# 8             4
# 9             4
# 10            4
# 11            4
# 12            4
# 13            4
# 14            4
# 15            3
# 16            3
# 17            3
# 18            3
# 19            3

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Types that are used by multiple packages
#
# #### Table 4
# - List the top 20 packages that are used by the highest count of different packages

# %%
queryCypherToDataFrame("../cypher/Package_Usage/List_types_that_are_used_by_many_different_packages.cypher").head(20)
# Out:
#                                     dependentType.fqn  \
# 0               org.axonframework.common.BuilderUtils
# 1                 org.axonframework.messaging.Message
# 2   org.axonframework.common.AxonConfigurationExce...
# 3        org.axonframework.eventhandling.EventMessage
# 4                org.axonframework.messaging.MetaData
# 5   org.axonframework.messaging.unitofwork.UnitOfWork
# 6          org.axonframework.serialization.Serializer
# 7                     org.axonframework.common.Assert
# 8   org.axonframework.common.transaction.Transacti...
# 9    org.axonframework.serialization.SerializedObject
# 10     org.axonframework.serialization.SerializedType
# 11  org.axonframework.messaging.unitofwork.Current...
# 12  org.axonframework.messaging.annotation.Paramet...
# 13  org.axonframework.common.AxonNonTransientExcep...
# 14  org.axonframework.eventhandling.DomainEventMes...
# 15      org.axonframework.eventhandling.TrackingToken
# 16  org.axonframework.eventhandling.GenericEventMe...
# 17               org.axonframework.common.ObjectUtils
# 18  org.axonframework.messaging.MessageDispatchInt...
# 19  org.axonframework.messaging.MessageHandlerInte...
#
#             dependentType.name  \
# 0                 BuilderUtils
# 1                      Message
# 2   AxonConfigurationException
# 3                 EventMessage
# 4                     MetaData
# 5                   UnitOfWork
# 6                   Serializer
# 7                       Assert
# 8           TransactionManager
# 9             SerializedObject
# 10              SerializedType
# 11           CurrentUnitOfWork
# 12    ParameterResolverFactory
# 13   AxonNonTransientException
# 14          DomainEventMessage
# 15               TrackingToken
# 16         GenericEventMessage
# 17                 ObjectUtils
# 18  MessageDispatchInterceptor
# 19   MessageHandlerInterceptor
#
#                                   dependentTypeLabels  numberOfUsingPackages
# 0                 [Type, File, Java, ByteCode, Class]                     41
# 1   [Type, File, Java, ByteCode, GenericDeclaratio...                     36
# 2                 [Type, File, Java, ByteCode, Class]                     35
# 3   [Type, File, Java, ByteCode, GenericDeclaratio...                     30
# 4                 [Type, File, Java, ByteCode, Class]                     30
# 5   [Type, File, Java, ByteCode, GenericDeclaratio...                     29
# 6             [Type, File, Java, ByteCode, Interface]                     26
# 7                 [Type, File, Java, ByteCode, Class]                     25
# 8             [Type, File, Java, ByteCode, Interface]                     23
# 9   [Type, File, Java, ByteCode, GenericDeclaratio...                     22
# 10            [Type, File, Java, ByteCode, Interface]                     21
# 11                [Type, File, Java, ByteCode, Class]                     20
# 12            [Type, File, Java, ByteCode, Interface]                     18
# 13                [Type, File, Java, ByteCode, Class]                     18
# 14  [Type, File, Java, ByteCode, GenericDeclaratio...                     17
# 15            [Type, File, Java, ByteCode, Interface]                     17
# 16  [Type, File, Java, ByteCode, Class, GenericDec...                     16
# 17                [Type, File, Java, ByteCode, Class]                     15
# 18  [Type, File, Java, ByteCode, GenericDeclaratio...                     15
# 19  [Type, File, Java, ByteCode, GenericDeclaratio...                     15

# %% [markdown]
# ### Packages that are used by multiple artifacts
#
# #### Table 5
# - List the top 20 artifacts that only use a few (compared to all existing) packages of another artifact

# %%
queryCypherToDataFrame("../cypher/Package_Usage/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher").head(20)
# Out:
#                 artifactName     dependentArtifactName  dependentPackages  \
# 0       axon-disruptor-4.7.5      axon-messaging-4.7.5                  9
# 1            axon-test-4.7.5      axon-messaging-4.7.5                 10
# 2       axon-disruptor-4.7.5      axon-modelling-4.7.5                  2
# 3   axon-eventsourcing-4.7.5      axon-modelling-4.7.5                  2
# 4       axon-disruptor-4.7.5  axon-eventsourcing-4.7.5                  2
# 5            axon-test-4.7.5  axon-eventsourcing-4.7.5                  2
# 6       axon-modelling-4.7.5      axon-messaging-4.7.5                 18
# 7   axon-eventsourcing-4.7.5      axon-messaging-4.7.5                 20
# 8   axon-configuration-4.7.5  axon-eventsourcing-4.7.5                  4
# 9            axon-test-4.7.5      axon-modelling-4.7.5                  5
# 10  axon-configuration-4.7.5      axon-messaging-4.7.5                 34
# 11      axon-modelling-4.7.5      axon-modelling-4.7.5                  6
# 12  axon-configuration-4.7.5      axon-modelling-4.7.5                  6
# 13           axon-test-4.7.5           axon-test-4.7.5                  5
# 14      axon-messaging-4.7.5      axon-messaging-4.7.5                 40
# 15  axon-eventsourcing-4.7.5  axon-eventsourcing-4.7.5                  7
# 16  axon-configuration-4.7.5      axon-disruptor-4.7.5                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          61                0.147541
# 1                          61                0.163934
# 2                          10                0.200000
# 3                          10                0.200000
# 4                           9                0.222222
# 5                           9                0.222222
# 6                          61                0.295082
# 7                          61                0.327869
# 8                           9                0.444444
# 9                          10                0.500000
# 10                         61                0.557377
# 11                         10                0.600000
# 12                         10                0.600000
# 13                          8                0.625000
# 14                         61                0.655738
# 15                          9                0.777778
# 16                          1                1.000000
#
#                    dependentFullQualifiedPackageNames  \
# 0   [org.axonframework.common.caching, org.axonfra...
# 1   [org.axonframework.messaging, org.axonframewor...
# 2   [org.axonframework.modelling.command, org.axon...
# 3   [org.axonframework.modelling.command, org.axon...
# 4   [org.axonframework.eventsourcing, org.axonfram...
# 5   [org.axonframework.eventsourcing.eventstore, o...
# 6   [org.axonframework.common.property, org.axonfr...
# 7   [org.axonframework.common, org.axonframework.e...
# 8   [org.axonframework.eventsourcing, org.axonfram...
# 9   [org.axonframework.modelling.command.inspectio...
# 10  [org.axonframework.eventhandling.async, org.ax...
# 11  [org.axonframework.modelling.saga.metamodel, o...
# 12  [org.axonframework.modelling.saga.repository, ...
# 13  [org.axonframework.test, org.axonframework.tes...
# 14  [org.axonframework.serialization, org.axonfram...
# 15  [org.axonframework.eventsourcing.eventstore.jd...
# 16      [org.axonframework.disruptor.commandhandling]
#
#                                 dependentPackageNames
# 0   [caching, unitofwork, transaction, messaging, ...
# 1   [messaging, eventhandling, common, commandhand...
# 2                               [command, inspection]
# 3                               [command, inspection]
# 4                         [eventsourcing, eventstore]
# 5                         [eventstore, eventsourcing]
# 6   [property, eventhandling, messaging, annotatio...
# 7   [common, eventhandling, serialization, event, ...
# 8      [eventsourcing, snapshotting, eventstore, jpa]
# 9   [inspection, command, inmemory, repository, saga]
# 10  [async, deadletter, pooled, tracing, annotatio...
# 11  [metamodel, saga, command, inspection, reposit...
# 12  [repository, inmemory, jpa, inspection, comman...
# 13  [test, matchers, deadline, eventscheduler, utils]
# 14  [serialization, messaging, common, upcasting, ...
# 15  [jdbc, statements, eventstore, snapshotting, e...
# 16                                  [commandhandling]

# %% [markdown]
# ### Packages that are used by multiple artifacts
#
# #### Table 6
# - List the top 20 packages that only use a few (compared to all existing) types of another package

# %%
queryCypherToDataFrame("../cypher/Package_Usage/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher").head(20)
# Out:
#                 artifactName dependentArtifactName  \
# 0   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 1            axon-test-4.7.5  axon-messaging-4.7.5
# 2       axon-modelling-4.7.5  axon-messaging-4.7.5
# 3   axon-eventsourcing-4.7.5  axon-modelling-4.7.5
# 4   axon-eventsourcing-4.7.5  axon-modelling-4.7.5
# 5   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 6            axon-test-4.7.5  axon-messaging-4.7.5
# 7       axon-modelling-4.7.5  axon-messaging-4.7.5
# 8       axon-modelling-4.7.5  axon-messaging-4.7.5
# 9   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 10  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 11           axon-test-4.7.5  axon-messaging-4.7.5
# 12           axon-test-4.7.5  axon-messaging-4.7.5
# 13  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 14  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 15  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 16  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 17           axon-test-4.7.5  axon-modelling-4.7.5
# 18  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 19           axon-test-4.7.5  axon-messaging-4.7.5
#
#                                           packageName  \
# 0        org.axonframework.eventsourcing.snapshotting
# 1                     org.axonframework.test.matchers
# 2          org.axonframework.modelling.saga.metamodel
# 3   org.axonframework.eventsourcing.conflictresolu...
# 4     org.axonframework.eventsourcing.eventstore.jdbc
# 5   org.axonframework.eventsourcing.conflictresolu...
# 6               org.axonframework.test.eventscheduler
# 7                 org.axonframework.modelling.command
# 8       org.axonframework.modelling.command.legacyjpa
# 9   org.axonframework.eventsourcing.conflictresolu...
# 10         org.axonframework.eventsourcing.eventstore
# 11                             org.axonframework.test
# 12                    org.axonframework.test.matchers
# 13    org.axonframework.eventsourcing.eventstore.jdbc
# 14     org.axonframework.eventsourcing.eventstore.jpa
# 15  org.axonframework.eventsourcing.eventstore.leg...
# 16  org.axonframework.eventsourcing.eventstore.jdb...
# 17                       org.axonframework.test.utils
# 18  org.axonframework.eventsourcing.conflictresolu...
# 19                    org.axonframework.test.matchers
#
#                    dependentPackage.fqn  dependentTypes  \
# 0       org.axonframework.eventhandling               1
# 1       org.axonframework.eventhandling               1
# 2       org.axonframework.eventhandling               1
# 3   org.axonframework.modelling.command               1
# 4   org.axonframework.modelling.command               1
# 5       org.axonframework.eventhandling               2
# 6       org.axonframework.eventhandling               2
# 7       org.axonframework.eventhandling               2
# 8       org.axonframework.eventhandling               2
# 9           org.axonframework.messaging               1
# 10          org.axonframework.messaging               1
# 11          org.axonframework.messaging               1
# 12          org.axonframework.messaging               1
# 13      org.axonframework.serialization               1
# 14      org.axonframework.serialization               1
# 15      org.axonframework.serialization               1
# 16      org.axonframework.eventhandling               3
# 17     org.axonframework.modelling.saga               1
# 18    org.axonframework.commandhandling               1
# 19    org.axonframework.commandhandling               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                      93             0.010753
# 1                      93             0.010753
# 2                      93             0.010753
# 3                      51             0.019608
# 4                      51             0.019608
# 5                      93             0.021505
# 6                      93             0.021505
# 7                      93             0.021505
# 8                      93             0.021505
# 9                      35             0.028571
# 10                     35             0.028571
# 11                     35             0.028571
# 12                     35             0.028571
# 13                     34             0.029412
# 14                     34             0.029412
# 15                     34             0.029412
# 16                     93             0.032258
# 17                     30             0.033333
# 18                     29             0.034483
# 19                     29             0.034483
#
#                                    dependentTypeNames
# 0   [org.axonframework.eventhandling.DomainEventData]
# 1      [org.axonframework.eventhandling.EventMessage]
# 2      [org.axonframework.eventhandling.EventMessage]
# 3   [org.axonframework.modelling.command.Conflicti...
# 4   [org.axonframework.modelling.command.Concurren...
# 5   [org.axonframework.eventhandling.DomainEventMe...
# 6   [org.axonframework.eventhandling.GenericEventM...
# 7   [org.axonframework.eventhandling.DomainEventSe...
# 8   [org.axonframework.eventhandling.EventBus, org...
# 9               [org.axonframework.messaging.Message]
# 10  [org.axonframework.messaging.StreamableMessage...
# 11              [org.axonframework.messaging.Message]
# 12              [org.axonframework.messaging.Message]
# 13       [org.axonframework.serialization.Serializer]
# 14       [org.axonframework.serialization.Serializer]
# 15       [org.axonframework.serialization.Serializer]
# 16  [org.axonframework.eventhandling.DomainEventMe...
# 17  [org.axonframework.modelling.saga.SimpleResour...
# 18  [org.axonframework.commandhandling.CommandMess...
# 19  [org.axonframework.commandhandling.CommandMess...
