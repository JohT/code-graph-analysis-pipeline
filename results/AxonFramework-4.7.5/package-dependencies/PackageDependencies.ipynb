# %% [markdown]
# # Package Dependencies for Java with Neo4j
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [py2neo](https://py2neo.org/2021.1/)

# %%
import os
import matplotlib.pyplot as plot
from py2neo import Graph

# %%
#Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
#before starting jupyter notebook to provide the password for the user "neo4j". 
#It is not recommended to hardcode the password into jupyter notebook for security reasons.
graph = Graph("bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))

# %%
def getCypherQueryFromFile(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def queryCypherToDataFrame(cypherFileName):
    return graph.run(getCypherQueryFromFile(cypherFileName)).to_data_frame()

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Artifacts
#
# ### Table 1
#
# - List all the artifacts this notebook is based on

# %%
queryCypherToDataFrame("../cypher/List_all_existing_artifacts.cypher")
# Out:
#                    artifactName  packages  types
# 0           axon-test-4.7.5.jar         8     85
# 1      axon-disruptor-4.7.5.jar         1     22
# 2  axon-eventsourcing-4.7.5.jar         9    130
# 3      axon-messaging-4.7.5.jar        61    729
# 4      axon-modelling-4.7.5.jar        10    149
# 5  axon-configuration-4.7.5.jar         1     39

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to a lot of trouble when one of these packages needs to be changed.
#
# ### Table 2
# - List packages with cyclic dependencies

# %%
queryCypherToDataFrame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_as_List.cypher")
# Out:
#                                           packageName  \
# 0                     org.axonframework.eventhandling
# 1                     org.axonframework.eventhandling
# 2                     org.axonframework.eventhandling
# 3                     org.axonframework.queryhandling
# 4                     org.axonframework.eventsourcing
# 5                          org.axonframework.deadline
# 6         org.axonframework.commandhandling.callbacks
# 7              org.axonframework.messaging.unitofwork
# 8                     org.axonframework.eventhandling
# 9               org.axonframework.eventhandling.async
# 10                  org.axonframework.commandhandling
# 11             org.axonframework.eventhandling.replay
# 12                    org.axonframework.eventhandling
# 13    org.axonframework.serialization.upcasting.event
# 14    org.axonframework.eventsourcing.eventstore.jdbc
# 15       org.axonframework.queryhandling.registration
# 16             org.axonframework.messaging.annotation
# 17                        org.axonframework.messaging
# 18                   org.axonframework.modelling.saga
# 19  org.axonframework.commandhandling.distributed....
# 20     org.axonframework.modelling.command.inspection
#
#                                  dependentPackageName  \
# 0                           org.axonframework.tracing
# 1              org.axonframework.messaging.annotation
# 2                         org.axonframework.messaging
# 3                           org.axonframework.tracing
# 4          org.axonframework.eventsourcing.eventstore
# 5                           org.axonframework.tracing
# 6                   org.axonframework.commandhandling
# 7                         org.axonframework.messaging
# 8                     org.axonframework.serialization
# 9                     org.axonframework.eventhandling
# 10                          org.axonframework.tracing
# 11                    org.axonframework.eventhandling
# 12         org.axonframework.eventhandling.tokenstore
# 13                    org.axonframework.eventhandling
# 14  org.axonframework.eventsourcing.eventstore.jdb...
# 15                    org.axonframework.queryhandling
# 16           org.axonframework.messaging.interceptors
# 17                    org.axonframework.serialization
# 18         org.axonframework.modelling.saga.metamodel
# 19      org.axonframework.commandhandling.distributed
# 20                org.axonframework.modelling.command
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.857143             13               1
# 1                   0.840000             23               2
# 2                   0.837838             34               3
# 3                   0.800000              9               1
# 4                   0.764706             15               2
# 5                   0.750000              7               1
# 6                   0.733333             13               2
# 7                   0.647059             14               3
# 8                   0.600000             12               3
# 9                   0.538462             10               3
# 10                  0.500000              3               1
# 11                  0.454545              8               3
# 12                  0.333333              8               4
# 13                  0.333333              6               3
# 14                  0.317073             27              14
# 15                  0.250000              5               3
# 16                  0.200000              3               2
# 17                  0.157895             11               8
# 18                  0.142857              4               3
# 19                  0.076923              7               6
# 20                  0.040000             13              12
#
#                                   forwardDependencies  \
# 0   [SubscribingEventProcessor$Builder->SpanFactor...
# 1   [TrackingTokenParameterResolverFactory->Parame...
# 2   [MultiStreamableMessageSource->StreamableMessa...
# 3   [SimpleQueryBus->SpanScope, SimpleQueryBus->Sp...
# 4   [EventStreamUtils->DomainEventStream, EventSou...
# 5   [SimpleDeadlineManager$Builder->SpanFactory, S...
# 6   [LoggingCallback->CommandCallback, LoggingCall...
# 7   [AbstractUnitOfWork->Message, AbstractUnitOfWo...
# 8   [TrackedDomainEventData->SerializedObject, Eve...
# 9   [PropertySequencingPolicy$Builder->EventMessag...
# 10  [AsynchronousCommandBus$Builder->SpanFactory, ...
# 11  [ReplayAwareMessageHandlerWrapper->AllowReplay...
# 12  [TrackingEventProcessor$SplitSegmentInstructio...
# 13  [IntermediateEventRepresentation->TrackingToke...
# 14  [JdbcEventStorageEngine$Builder->ReadEventData...
# 15  [FailingDuplicateQueryHandlerResolver->QuerySu...
# 16  [MessageHandlerInterceptorDefinition->ResultHa...
# 17  [Message->Serializer, Message->SerializedObjec...
# 18  [AnnotatedSagaManager$Builder->SagaModel, Anno...
# 19  [DenyAll->CommandMessageFilter, AndCommandMess...
# 20  [ChildForwardingCommandMessageHandlingMember->...
#
#                                  backwardDependencies
# 0                  [NestingSpanFactory->EventMessage]
# 1   [SourceIdParameterResolverFactory$SourceIdPara...
# 2   [StreamableMessageSource->TrackingToken, Heade...
# 3                           [SpanUtils->QueryMessage]
# 4   [DomainEventStream->EventStreamUtils, Abstract...
# 5                        [SpanUtils->DeadlineMessage]
# 6   [SimpleCommandBus$Builder->LoggingCallback, Si...
# 7   [GenericMessage->CurrentUnitOfWork, MessageHan...
# 8   [GapAwareTrackingTokenConverter->GapAwareTrack...
# 9   [SimpleEventHandlerInvoker->SequencingPolicy, ...
# 10                        [SpanUtils->CommandMessage]
# 11  [ResetHandler->ResetContext, AnnotationEventHa...
# 12  [TokenStore->TrackingToken, ConfigToken->Track...
# 13  [EventUtils->IntermediateEventRepresentation, ...
# 14  [CreateTokenAtStatementBuilder->EventSchema, R...
# 15  [SimpleQueryBus$Builder->DuplicateQueryHandler...
# 16  [ResultHandler->HasHandlerAttributes, MessageH...
# 17  [SerializedMessage->AbstractMessage, Serialize...
# 18  [AnnotationSagaMetaModelFactory$InspectedSagaM...
# 19  [DistributedCommandBus->DenyAll, CommandMessag...
# 20  [ForwardMatchingInstances->EntityModel, Forwar...

# %% [markdown]
# ### Table 3
# - List packages with cyclic dependencies with every dependency in a separate row sorted by the easiest and most valuable to resolve

# %%
queryCypherToDataFrame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_as_unwinded_List.cypher").head(60)
# Out:
#                         packageName                    dependentPackageName  \
# 0   org.axonframework.eventhandling               org.axonframework.tracing
# 1   org.axonframework.eventhandling               org.axonframework.tracing
# 2   org.axonframework.eventhandling               org.axonframework.tracing
# 3   org.axonframework.eventhandling               org.axonframework.tracing
# 4   org.axonframework.eventhandling               org.axonframework.tracing
# 5   org.axonframework.eventhandling               org.axonframework.tracing
# 6   org.axonframework.eventhandling               org.axonframework.tracing
# 7   org.axonframework.eventhandling               org.axonframework.tracing
# 8   org.axonframework.eventhandling               org.axonframework.tracing
# 9   org.axonframework.eventhandling               org.axonframework.tracing
# 10  org.axonframework.eventhandling               org.axonframework.tracing
# 11  org.axonframework.eventhandling               org.axonframework.tracing
# 12  org.axonframework.eventhandling               org.axonframework.tracing
# 13  org.axonframework.eventhandling               org.axonframework.tracing
# 14  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 15  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 16  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 17  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 18  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 19  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 20  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 21  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 22  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 23  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 24  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 25  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 26  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 27  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 28  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 29  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 30  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 31  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 32  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 33  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 34  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 35  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 36  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 37  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 38  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 39  org.axonframework.eventhandling             org.axonframework.messaging
# 40  org.axonframework.eventhandling             org.axonframework.messaging
# 41  org.axonframework.eventhandling             org.axonframework.messaging
# 42  org.axonframework.eventhandling             org.axonframework.messaging
# 43  org.axonframework.eventhandling             org.axonframework.messaging
# 44  org.axonframework.eventhandling             org.axonframework.messaging
# 45  org.axonframework.eventhandling             org.axonframework.messaging
# 46  org.axonframework.eventhandling             org.axonframework.messaging
# 47  org.axonframework.eventhandling             org.axonframework.messaging
# 48  org.axonframework.eventhandling             org.axonframework.messaging
# 49  org.axonframework.eventhandling             org.axonframework.messaging
# 50  org.axonframework.eventhandling             org.axonframework.messaging
# 51  org.axonframework.eventhandling             org.axonframework.messaging
# 52  org.axonframework.eventhandling             org.axonframework.messaging
# 53  org.axonframework.eventhandling             org.axonframework.messaging
# 54  org.axonframework.eventhandling             org.axonframework.messaging
# 55  org.axonframework.eventhandling             org.axonframework.messaging
# 56  org.axonframework.eventhandling             org.axonframework.messaging
# 57  org.axonframework.eventhandling             org.axonframework.messaging
# 58  org.axonframework.eventhandling             org.axonframework.messaging
# 59  org.axonframework.eventhandling             org.axonframework.messaging
#
#                                            dependency  \
# 0                    EventMessage<-NestingSpanFactory
# 1      SubscribingEventProcessor$Builder->SpanFactory
# 2                 TrackingEventProcessor->SpanFactory
# 3                        TrackingEventProcessor->Span
# 4                        AbstractEventProcessor->Span
# 5                 AbstractEventProcessor->SpanFactory
# 6         TrackingEventProcessor$Builder->SpanFactory
# 7           AbstractEventBus$Builder->NoOpSpanFactory
# 8               AbstractEventBus$Builder->SpanFactory
# 9                 SimpleEventBus$Builder->SpanFactory
# 10        AbstractEventProcessor$Builder->SpanFactory
# 11    AbstractEventProcessor$Builder->NoOpSpanFactory
# 12                      AbstractEventBus->SpanFactory
# 13                             AbstractEventBus->Span
# 14  DomainEventMessage<-SourceIdParameterResolverF...
# 15  DomainEventMessage<-AggregateTypeParameterReso...
# 16  TrackingTokenParameterResolverFactory->Paramet...
# 17  TrackingTokenParameterResolverFactory->Paramet...
# 18                       EventHandler->MessageHandler
# 19  SimpleEventHandlerInvoker$Builder->HandlerDefi...
# 20  SimpleEventHandlerInvoker$Builder->ParameterRe...
# 21  TimestampParameterResolverFactory$TimestampPar...
# 22  TrackingTokenParameterResolverFactory$Tracking...
# 23                  AllowReplay->HasHandlerAttributes
# 24  TimestampParameterResolverFactory->ParameterRe...
# 25  TimestampParameterResolverFactory->AbstractAnn...
# 26  ConcludesBatchParameterResolverFactory->Abstra...
# 27  ConcludesBatchParameterResolverFactory->Parame...
# 28  SequenceNumberParameterResolverFactory$Sequenc...
# 29  AnnotationEventHandlerAdapter->MessageHandling...
# 30   AnnotationEventHandlerAdapter->HandlerDefinition
# 31  AnnotationEventHandlerAdapter->ClasspathParame...
# 32  AnnotationEventHandlerAdapter->AnnotatedHandle...
# 33  AnnotationEventHandlerAdapter->ParameterResolv...
# 34  AnnotationEventHandlerAdapter->ClasspathHandle...
# 35  AnnotationEventHandlerAdapter->MessageHandlerI...
# 36                       ResetHandler->MessageHandler
# 37  SequenceNumberParameterResolverFactory->Abstra...
# 38  SequenceNumberParameterResolverFactory->Parame...
# 39             TrackingToken<-StreamableMessageSource
# 40                              EventMessage<-Headers
# 41                        DomainEventMessage<-Headers
# 42  MultiStreamableMessageSource->StreamableMessag...
# 43  TimestampParameterResolverFactory$TimestampPar...
# 44                GenericDomainEventMessage->MetaData
# 45          GenericDomainEventMessage->GenericMessage
# 46                 GenericDomainEventMessage->Message
# 47  MultiStreamableMessageSource$IdentifiedStreama...
# 48  SubscribingEventProcessor$Builder->Subscribabl...
# 49                       EventMessageHandler->Message
# 50                EventMessageHandler->MessageHandler
# 51  TrackingTokenParameterResolverFactory$Tracking...
# 52                    TrackingEventProcessor->Message
# 53    TrackingEventProcessor->StreamableMessageSource
# 54           TrackingEventProcessor->InterceptorChain
# 55              AbstractEventProcessor->ResultMessage
# 56  AbstractEventProcessor->MessageHandlerInterceptor
# 57    AbstractEventProcessor->DefaultInterceptorChain
# 58                GenericTrackedEventMessage->Message
# 59  TrackingEventProcessor$Builder->StreamableMess...
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.857143             13               1
# 1                   0.857143             13               1
# 2                   0.857143             13               1
# 3                   0.857143             13               1
# 4                   0.857143             13               1
# 5                   0.857143             13               1
# 6                   0.857143             13               1
# 7                   0.857143             13               1
# 8                   0.857143             13               1
# 9                   0.857143             13               1
# 10                  0.857143             13               1
# 11                  0.857143             13               1
# 12                  0.857143             13               1
# 13                  0.857143             13               1
# 14                  0.840000             23               2
# 15                  0.840000             23               2
# 16                  0.840000             23               2
# 17                  0.840000             23               2
# 18                  0.840000             23               2
# 19                  0.840000             23               2
# 20                  0.840000             23               2
# 21                  0.840000             23               2
# 22                  0.840000             23               2
# 23                  0.840000             23               2
# 24                  0.840000             23               2
# 25                  0.840000             23               2
# 26                  0.840000             23               2
# 27                  0.840000             23               2
# 28                  0.840000             23               2
# 29                  0.840000             23               2
# 30                  0.840000             23               2
# 31                  0.840000             23               2
# 32                  0.840000             23               2
# 33                  0.840000             23               2
# 34                  0.840000             23               2
# 35                  0.840000             23               2
# 36                  0.840000             23               2
# 37                  0.840000             23               2
# 38                  0.840000             23               2
# 39                  0.837838             34               3
# 40                  0.837838             34               3
# 41                  0.837838             34               3
# 42                  0.837838             34               3
# 43                  0.837838             34               3
# 44                  0.837838             34               3
# 45                  0.837838             34               3
# 46                  0.837838             34               3
# 47                  0.837838             34               3
# 48                  0.837838             34               3
# 49                  0.837838             34               3
# 50                  0.837838             34               3
# 51                  0.837838             34               3
# 52                  0.837838             34               3
# 53                  0.837838             34               3
# 54                  0.837838             34               3
# 55                  0.837838             34               3
# 56                  0.837838             34               3
# 57                  0.837838             34               3
# 58                  0.837838             34               3
# 59                  0.837838             34               3

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.
#
# ### Table 3
# - List top 20 most used combinations of methods of larger Types that might benefit from *Interface Segregation*

# %%
queryCypherToDataFrame("../cypher/Candidates_for_Interface_Segregation.cypher").head(20)
# Out:
#                                     dependentType.fqn  declaredMethods  \
# 0    org.axonframework.commandhandling.CommandMessage                9
# 1   org.axonframework.eventhandling.DomainEventMes...               10
# 2        org.axonframework.eventhandling.EventMessage                9
# 3        org.axonframework.eventhandling.EventMessage                9
# 4   org.axonframework.eventhandling.TrackedEventMe...               10
# 5   org.axonframework.eventhandling.DomainEventMes...               10
# 6   org.axonframework.commandhandling.GenericComma...               15
# 7   org.axonframework.commandhandling.GenericComma...               14
# 8   org.axonframework.eventhandling.TrackedEventMe...               12
# 9   org.axonframework.deadline.GenericDeadlineMessage               11
# 10         org.axonframework.deadline.DeadlineMessage               10
# 11  org.axonframework.eventhandling.DomainEventMes...               10
# 12  org.axonframework.eventhandling.DomainEventMes...               10
# 13  org.axonframework.eventhandling.GenericEventMe...               10
# 14          org.axonframework.messaging.ResultMessage                9
# 15  org.axonframework.common.transaction.NoTransac...                4
# 16  org.axonframework.modelling.command.inspection...               13
# 17  org.axonframework.eventhandling.DomainEventMes...               11
# 18  org.axonframework.eventhandling.DomainEventMes...               10
# 19  org.axonframework.eventhandling.GapAwareTracki...               10
#
#                                     calledMethodNames  calledMethods  \
# 0                                    [getCommandName]              1
# 1                                 [getSequenceNumber]              1
# 2                       [getTimestamp, getIdentifier]              2
# 3                                     [getIdentifier]              1
# 4                                     [trackingToken]              1
# 5   [getType, getSequenceNumber, getAggregateIdent...              3
# 6                            [asCommandResultMessage]              1
# 7                            [asCommandResultMessage]              1
# 8                                     [trackingToken]              1
# 9                                 [asDeadlineMessage]              1
# 10                                  [getDeadlineName]              1
# 11                                          [getType]              1
# 12                           [getAggregateIdentifier]              1
# 13                                   [asEventMessage]              1
# 14                   [isExceptional, exceptionResult]              2
# 15                                         [instance]              1
# 16                                             [type]              1
# 17  [getType, getSequenceNumber, getAggregateIdent...              3
# 18        [getSequenceNumber, getAggregateIdentifier]              2
# 19  [advanceTo, getGaps, withGapsTruncatedAt, getI...              5
#
#     callerTypes
# 0            17
# 1             8
# 2             8
# 3             8
# 4             7
# 5             5
# 6             4
# 7             4
# 8             4
# 9             4
# 10            4
# 11            4
# 12            4
# 13            4
# 14            4
# 15            4
# 16            3
# 17            3
# 18            3
# 19            3

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Types that are used by multiple packages
#
# #### Table 4
# - List the top 20 packages that are used by the highest count of different packages

# %%
queryCypherToDataFrame("../cypher/Package_Usage/List_types_that_are_used_by_many_different_packages.cypher").head(20)
# Out:
#                                     dependentType.fqn  \
# 0               org.axonframework.common.BuilderUtils
# 1                 org.axonframework.messaging.Message
# 2   org.axonframework.common.AxonConfigurationExce...
# 3        org.axonframework.eventhandling.EventMessage
# 4   org.axonframework.messaging.unitofwork.UnitOfWork
# 5                org.axonframework.messaging.MetaData
# 6                     org.axonframework.common.Assert
# 7          org.axonframework.serialization.Serializer
# 8   org.axonframework.common.transaction.Transacti...
# 9   org.axonframework.messaging.unitofwork.Current...
# 10     org.axonframework.serialization.SerializedType
# 11   org.axonframework.serialization.SerializedObject
# 12  org.axonframework.common.AxonNonTransientExcep...
# 13  org.axonframework.messaging.annotation.Paramet...
# 14      org.axonframework.eventhandling.TrackingToken
# 15  org.axonframework.eventhandling.DomainEventMes...
# 16  org.axonframework.eventhandling.GenericEventMe...
# 17              org.axonframework.common.Registration
# 18               org.axonframework.common.ObjectUtils
# 19   org.axonframework.commandhandling.CommandMessage
#
#             dependentType.name  \
# 0                 BuilderUtils
# 1                      Message
# 2   AxonConfigurationException
# 3                 EventMessage
# 4                   UnitOfWork
# 5                     MetaData
# 6                       Assert
# 7                   Serializer
# 8           TransactionManager
# 9            CurrentUnitOfWork
# 10              SerializedType
# 11            SerializedObject
# 12   AxonNonTransientException
# 13    ParameterResolverFactory
# 14               TrackingToken
# 15          DomainEventMessage
# 16         GenericEventMessage
# 17                Registration
# 18                 ObjectUtils
# 19              CommandMessage
#
#                                   dependentTypeLabels  numberOfUsingPackages
# 0                 [Type, File, Java, ByteCode, Class]                     41
# 1   [Type, File, Java, ByteCode, GenericDeclaratio...                     35
# 2                 [Type, File, Java, ByteCode, Class]                     35
# 3   [Type, File, Java, ByteCode, GenericDeclaratio...                     30
# 4   [Type, File, Java, ByteCode, GenericDeclaratio...                     29
# 5                 [Type, File, Java, ByteCode, Class]                     29
# 6                 [Type, File, Java, ByteCode, Class]                     25
# 7             [Type, File, Java, ByteCode, Interface]                     25
# 8             [Type, File, Java, ByteCode, Interface]                     23
# 9                 [Type, File, Java, ByteCode, Class]                     21
# 10            [Type, File, Java, ByteCode, Interface]                     20
# 11  [Type, File, Java, ByteCode, GenericDeclaratio...                     20
# 12                [Type, File, Java, ByteCode, Class]                     18
# 13            [Type, File, Java, ByteCode, Interface]                     18
# 14            [Type, File, Java, ByteCode, Interface]                     17
# 15  [Type, File, Java, ByteCode, GenericDeclaratio...                     17
# 16  [Type, File, Java, ByteCode, Class, GenericDec...                     16
# 17            [Type, File, Java, ByteCode, Interface]                     16
# 18                [Type, File, Java, ByteCode, Class]                     15
# 19  [Type, File, Java, ByteCode, GenericDeclaratio...                     14

# %% [markdown]
# ### Packages that are used by multiple artifacts
#
# #### Table 5
# - List the top 20 artifacts that only use a few (compared to all existing) packages of another artifact

# %%
queryCypherToDataFrame("../cypher/Package_Usage/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher").head(20)
# Out:
#                 artifactName     dependentArtifactName  dependentPackages  \
# 0       axon-disruptor-4.7.5      axon-messaging-4.7.5                  9
# 1            axon-test-4.7.5      axon-messaging-4.7.5                 10
# 2       axon-disruptor-4.7.5      axon-modelling-4.7.5                  2
# 3   axon-eventsourcing-4.7.5      axon-modelling-4.7.5                  2
# 4            axon-test-4.7.5  axon-eventsourcing-4.7.5                  2
# 5       axon-disruptor-4.7.5  axon-eventsourcing-4.7.5                  2
# 6       axon-modelling-4.7.5      axon-messaging-4.7.5                 18
# 7   axon-eventsourcing-4.7.5      axon-messaging-4.7.5                 20
# 8            axon-test-4.7.5      axon-modelling-4.7.5                  4
# 9   axon-configuration-4.7.5  axon-eventsourcing-4.7.5                  4
# 10  axon-configuration-4.7.5      axon-messaging-4.7.5                 34
# 11      axon-modelling-4.7.5      axon-modelling-4.7.5                  6
# 12  axon-configuration-4.7.5      axon-modelling-4.7.5                  6
# 13           axon-test-4.7.5           axon-test-4.7.5                  5
# 14      axon-messaging-4.7.5      axon-messaging-4.7.5                 40
# 15  axon-eventsourcing-4.7.5  axon-eventsourcing-4.7.5                  7
# 16  axon-configuration-4.7.5      axon-disruptor-4.7.5                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          61                0.147541
# 1                          61                0.163934
# 2                          10                0.200000
# 3                          10                0.200000
# 4                           9                0.222222
# 5                           9                0.222222
# 6                          61                0.295082
# 7                          61                0.327869
# 8                          10                0.400000
# 9                           9                0.444444
# 10                         61                0.557377
# 11                         10                0.600000
# 12                         10                0.600000
# 13                          8                0.625000
# 14                         61                0.655738
# 15                          9                0.777778
# 16                          1                1.000000
#
#                    dependentFullQualifiedPackageNames  \
# 0   [org.axonframework.commandhandling.callbacks, ...
# 1   [org.axonframework.common, org.axonframework.e...
# 2   [org.axonframework.modelling.command, org.axon...
# 3   [org.axonframework.modelling.command, org.axon...
# 4   [org.axonframework.eventsourcing.eventstore, o...
# 5   [org.axonframework.eventsourcing.eventstore, o...
# 6   [org.axonframework.common.annotation, org.axon...
# 7   [org.axonframework.commandhandling, org.axonfr...
# 8   [org.axonframework.modelling.saga, org.axonfra...
# 9   [org.axonframework.eventsourcing.eventstore, o...
# 10  [org.axonframework.common.jpa, org.axonframewo...
# 11  [org.axonframework.modelling.saga.metamodel, o...
# 12  [org.axonframework.modelling.command.inspectio...
# 13  [org.axonframework.test, org.axonframework.tes...
# 14  [org.axonframework.util, org.axonframework.com...
# 15  [org.axonframework.eventsourcing.eventstore, o...
# 16      [org.axonframework.disruptor.commandhandling]
#
#                                 dependentPackageNames
# 0   [callbacks, transaction, unitofwork, monitorin...
# 1   [common, scheduling, eventhandling, annotation...
# 2                               [command, inspection]
# 3                               [command, inspection]
# 4                         [eventstore, eventsourcing]
# 5                         [eventstore, eventsourcing]
# 6   [annotation, tracing, messaging, eventhandling...
# 7   [commandhandling, messaging, annotation, unito...
# 8               [saga, inmemory, inspection, command]
# 9      [eventstore, eventsourcing, snapshotting, jpa]
# 10  [jpa, common, inmemory, queryhandling, messagi...
# 11  [metamodel, inspection, command, repository, j...
# 12  [inspection, repository, inmemory, jpa, comman...
# 13  [test, matchers, eventscheduler, utils, deadline]
# 14  [util, common, messaging, eventhandling, unito...
# 15  [eventstore, jpa, snapshotting, conflictresolu...
# 16                                  [commandhandling]

# %% [markdown]
# ### Packages that are used by multiple artifacts
#
# #### Table 6
# - List the top 20 packages that only use a few (compared to all existing) types of another package

# %%
queryCypherToDataFrame("../cypher/Package_Usage/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher").head(20)
# Out:
#                 artifactName dependentArtifactName  \
# 0            axon-test-4.7.5  axon-messaging-4.7.5
# 1   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 2       axon-modelling-4.7.5  axon-messaging-4.7.5
# 3   axon-eventsourcing-4.7.5  axon-modelling-4.7.5
# 4   axon-eventsourcing-4.7.5  axon-modelling-4.7.5
# 5            axon-test-4.7.5  axon-messaging-4.7.5
# 6   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 7       axon-modelling-4.7.5  axon-messaging-4.7.5
# 8       axon-modelling-4.7.5  axon-messaging-4.7.5
# 9            axon-test-4.7.5  axon-messaging-4.7.5
# 10           axon-test-4.7.5  axon-messaging-4.7.5
# 11  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 12  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 13  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 14  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 15  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 16  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 17           axon-test-4.7.5  axon-modelling-4.7.5
# 18           axon-test-4.7.5  axon-messaging-4.7.5
# 19  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
#
#                                           packageName  \
# 0                     org.axonframework.test.matchers
# 1        org.axonframework.eventsourcing.snapshotting
# 2          org.axonframework.modelling.saga.metamodel
# 3   org.axonframework.eventsourcing.conflictresolu...
# 4     org.axonframework.eventsourcing.eventstore.jdbc
# 5               org.axonframework.test.eventscheduler
# 6   org.axonframework.eventsourcing.conflictresolu...
# 7                 org.axonframework.modelling.command
# 8       org.axonframework.modelling.command.legacyjpa
# 9                              org.axonframework.test
# 10                    org.axonframework.test.matchers
# 11  org.axonframework.eventsourcing.conflictresolu...
# 12         org.axonframework.eventsourcing.eventstore
# 13    org.axonframework.eventsourcing.eventstore.jdbc
# 14     org.axonframework.eventsourcing.eventstore.jpa
# 15  org.axonframework.eventsourcing.eventstore.leg...
# 16  org.axonframework.eventsourcing.eventstore.jdb...
# 17                       org.axonframework.test.utils
# 18                    org.axonframework.test.matchers
# 19  org.axonframework.eventsourcing.conflictresolu...
#
#                    dependentPackage.fqn  dependentTypes  \
# 0       org.axonframework.eventhandling               1
# 1       org.axonframework.eventhandling               1
# 2       org.axonframework.eventhandling               1
# 3   org.axonframework.modelling.command               1
# 4   org.axonframework.modelling.command               1
# 5       org.axonframework.eventhandling               2
# 6       org.axonframework.eventhandling               2
# 7       org.axonframework.eventhandling               2
# 8       org.axonframework.eventhandling               2
# 9           org.axonframework.messaging               1
# 10          org.axonframework.messaging               1
# 11          org.axonframework.messaging               1
# 12          org.axonframework.messaging               1
# 13      org.axonframework.serialization               1
# 14      org.axonframework.serialization               1
# 15      org.axonframework.serialization               1
# 16      org.axonframework.eventhandling               3
# 17     org.axonframework.modelling.saga               1
# 18    org.axonframework.commandhandling               1
# 19    org.axonframework.commandhandling               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                      93             0.010753
# 1                      93             0.010753
# 2                      93             0.010753
# 3                      51             0.019608
# 4                      51             0.019608
# 5                      93             0.021505
# 6                      93             0.021505
# 7                      93             0.021505
# 8                      93             0.021505
# 9                      35             0.028571
# 10                     35             0.028571
# 11                     35             0.028571
# 12                     35             0.028571
# 13                     34             0.029412
# 14                     34             0.029412
# 15                     34             0.029412
# 16                     93             0.032258
# 17                     30             0.033333
# 18                     29             0.034483
# 19                     29             0.034483
#
#                                    dependentTypeNames
# 0      [org.axonframework.eventhandling.EventMessage]
# 1   [org.axonframework.eventhandling.DomainEventData]
# 2      [org.axonframework.eventhandling.EventMessage]
# 3   [org.axonframework.modelling.command.Conflicti...
# 4   [org.axonframework.modelling.command.Concurren...
# 5   [org.axonframework.eventhandling.EventMessage,...
# 6   [org.axonframework.eventhandling.DomainEventMe...
# 7   [org.axonframework.eventhandling.EventBus, org...
# 8   [org.axonframework.eventhandling.EventBus, org...
# 9               [org.axonframework.messaging.Message]
# 10              [org.axonframework.messaging.Message]
# 11              [org.axonframework.messaging.Message]
# 12  [org.axonframework.messaging.StreamableMessage...
# 13       [org.axonframework.serialization.Serializer]
# 14       [org.axonframework.serialization.Serializer]
# 15       [org.axonframework.serialization.Serializer]
# 16  [org.axonframework.eventhandling.GenericDomain...
# 17  [org.axonframework.modelling.saga.SimpleResour...
# 18  [org.axonframework.commandhandling.CommandMess...
# 19  [org.axonframework.commandhandling.CommandMess...
