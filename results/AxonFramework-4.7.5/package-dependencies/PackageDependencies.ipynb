# %% [markdown]
# # Package Dependencies for Java with Neo4j
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [py2neo](https://py2neo.org/2021.1/)

# %%
import os
import matplotlib.pyplot as plot
from py2neo import Graph

# %%
#Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
#before starting jupyter notebook to provide the password for the user "neo4j". 
#It is not recommended to hardcode the password into jupyter notebook for security reasons.
graph = Graph("bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))

# %%
def getCypherQueryFromFile(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def queryCypherToDataFrame(cypherFileName):
    return graph.run(getCypherQueryFromFile(cypherFileName)).to_data_frame()

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Artifacts
#
# ### Table 1
#
# - List all the artifacts this notebook is based on

# %%
queryCypherToDataFrame("../cypher/List_all_existing_artifacts.cypher")
# Out:
#                    artifactName  packages  types
# 0      axon-disruptor-4.7.5.jar         1     22
# 1  axon-eventsourcing-4.7.5.jar         9    130
# 2           axon-test-4.7.5.jar         8     85
# 3      axon-messaging-4.7.5.jar        61    729
# 4      axon-modelling-4.7.5.jar        10    149
# 5  axon-configuration-4.7.5.jar         1     39

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to a lot of trouble when one of these packages needs to be changed.
#
# ### Table 2
# - List packages with cyclic dependencies

# %%
queryCypherToDataFrame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_as_List.cypher")
# Out:
#                                           packageName  \
# 0                     org.axonframework.eventhandling
# 1                     org.axonframework.eventhandling
# 2                     org.axonframework.eventhandling
# 3                     org.axonframework.eventsourcing
# 4                          org.axonframework.deadline
# 5         org.axonframework.commandhandling.callbacks
# 6                     org.axonframework.queryhandling
# 7                   org.axonframework.commandhandling
# 8              org.axonframework.messaging.unitofwork
# 9               org.axonframework.eventhandling.async
# 10             org.axonframework.eventhandling.replay
# 11       org.axonframework.queryhandling.registration
# 12                    org.axonframework.eventhandling
# 13                    org.axonframework.eventhandling
# 14    org.axonframework.serialization.upcasting.event
# 15    org.axonframework.eventsourcing.eventstore.jdbc
# 16     org.axonframework.modelling.command.inspection
# 17             org.axonframework.messaging.annotation
# 18                        org.axonframework.messaging
# 19                   org.axonframework.modelling.saga
# 20  org.axonframework.commandhandling.distributed....
#
#                                  dependentPackageName  \
# 0              org.axonframework.messaging.annotation
# 1                         org.axonframework.messaging
# 2                           org.axonframework.tracing
# 3          org.axonframework.eventsourcing.eventstore
# 4                           org.axonframework.tracing
# 5                   org.axonframework.commandhandling
# 6                           org.axonframework.tracing
# 7                           org.axonframework.tracing
# 8                         org.axonframework.messaging
# 9                     org.axonframework.eventhandling
# 10                    org.axonframework.eventhandling
# 11                    org.axonframework.queryhandling
# 12                    org.axonframework.serialization
# 13         org.axonframework.eventhandling.tokenstore
# 14                    org.axonframework.eventhandling
# 15  org.axonframework.eventsourcing.eventstore.jdb...
# 16                org.axonframework.modelling.command
# 17           org.axonframework.messaging.interceptors
# 18                    org.axonframework.serialization
# 19         org.axonframework.modelling.saga.metamodel
# 20      org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.840000             23               2
# 1                   0.837838             34               3
# 2                   0.800000              9               1
# 3                   0.777778             16               2
# 4                   0.750000              7               1
# 5                   0.733333             13               2
# 6                   0.714286              6               1
# 7                   0.666667              5               1
# 8                   0.647059             14               3
# 9                   0.538462             10               3
# 10                  0.454545              8               3
# 11                  0.428571              5               2
# 12                  0.400000              7               3
# 13                  0.333333              8               4
# 14                  0.333333              6               3
# 15                  0.317073             27              14
# 16                  0.250000             20              12
# 17                  0.200000              3               2
# 18                  0.157895             11               8
# 19                  0.142857              4               3
# 20                  0.076923              7               6
#
#                                   forwardDependencies  \
# 0   [TrackingTokenParameterResolverFactory$Trackin...
# 1   [TrackingTokenParameterResolverFactory$Trackin...
# 2   [SimpleEventBus$Builder->SpanFactory, Tracking...
# 3   [EventSourcingRepository->EventStore, EventSou...
# 4   [SimpleDeadlineManager->SpanFactory, SimpleDea...
# 5   [NoOpCallback->CommandMessage, NoOpCallback->C...
# 6   [SimpleQueryUpdateEmitter$Builder->NoOpSpanFac...
# 7   [AsynchronousCommandBus$Builder->SpanFactory, ...
# 8   [UnitOfWork->Message, UnitOfWork->ResultMessag...
# 9   [SequentialPerAggregatePolicy->DomainEventMess...
# 10  [ReplayParameterResolverFactory$ReplayParamete...
# 11  [DuplicateQueryHandlerResolver->QuerySubscript...
# 12  [GenericEventMessage->CachingSupplier, EventDa...
# 13  [TrackingEventProcessor$MergeSegmentInstructio...
# 14  [UpcastedEventRepresentation->TrackingToken, I...
# 15  [JdbcEventStorageEngine->LastSequenceNumberFor...
# 16  [AbstractChildEntityDefinition->AggregateMembe...
# 17  [MessageHandlerInterceptorDefinition->ResultHa...
# 18  [GenericMessage->SerializedObjectHolder, Gener...
# 19  [AnnotatedSagaManager$Builder->AnnotationSagaM...
# 20  [NegateCommandMessageFilter->CommandMessageFil...
#
#                                  backwardDependencies
# 0   [SourceIdParameterResolverFactory$SourceIdPara...
# 1   [Headers->DomainEventMessage, Headers->EventMe...
# 2                  [NestingSpanFactory->EventMessage]
# 3   [DomainEventStream->EventStreamUtils, Abstract...
# 4                        [SpanUtils->DeadlineMessage]
# 5   [SimpleCommandBus$Builder->NoOpCallback, Simpl...
# 6                           [SpanUtils->QueryMessage]
# 7                         [SpanUtils->CommandMessage]
# 8   [MessageHandlerInterceptor->UnitOfWork, Defaul...
# 9   [SimpleEventHandlerInvoker$Builder->Sequential...
# 10  [ResetHandler->ResetContext, AnnotationEventHa...
# 11  [SimpleQueryBus$Builder->DuplicateQueryHandler...
# 12  [AbstractXStreamSerializer->GenericEventMessag...
# 13  [ConfigToken->TrackingToken, TokenStore->Track...
# 14  [EventUtils->InitialEventRepresentation, Event...
# 15  [JdbcEventStorageEngineStatements->EventSchema...
# 16  [AbstractRepository$Builder->AnnotatedAggregat...
# 17  [ResultHandler->HasHandlerAttributes, MessageH...
# 18  [SerializedMessage->GenericMessage, Serialized...
# 19  [SagaModel->AssociationValue, AnnotationSagaMe...
# 20  [CommandMessageFilter->NegateCommandMessageFil...

# %% [markdown]
# ### Table 3
# - List packages with cyclic dependencies with every dependency in a separate row sorted by the easiest and most valuable to resolve

# %%
queryCypherToDataFrame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_as_unwinded_List.cypher").head(60)
# Out:
#                         packageName                    dependentPackageName  \
# 0   org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 1   org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 2   org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 3   org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 4   org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 5   org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 6   org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 7   org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 8   org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 9   org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 10  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 11  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 12  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 13  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 14  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 15  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 16  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 17  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 18  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 19  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 20  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 21  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 22  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 23  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 24  org.axonframework.eventhandling  org.axonframework.messaging.annotation
# 25  org.axonframework.eventhandling             org.axonframework.messaging
# 26  org.axonframework.eventhandling             org.axonframework.messaging
# 27  org.axonframework.eventhandling             org.axonframework.messaging
# 28  org.axonframework.eventhandling             org.axonframework.messaging
# 29  org.axonframework.eventhandling             org.axonframework.messaging
# 30  org.axonframework.eventhandling             org.axonframework.messaging
# 31  org.axonframework.eventhandling             org.axonframework.messaging
# 32  org.axonframework.eventhandling             org.axonframework.messaging
# 33  org.axonframework.eventhandling             org.axonframework.messaging
# 34  org.axonframework.eventhandling             org.axonframework.messaging
# 35  org.axonframework.eventhandling             org.axonframework.messaging
# 36  org.axonframework.eventhandling             org.axonframework.messaging
# 37  org.axonframework.eventhandling             org.axonframework.messaging
# 38  org.axonframework.eventhandling             org.axonframework.messaging
# 39  org.axonframework.eventhandling             org.axonframework.messaging
# 40  org.axonframework.eventhandling             org.axonframework.messaging
# 41  org.axonframework.eventhandling             org.axonframework.messaging
# 42  org.axonframework.eventhandling             org.axonframework.messaging
# 43  org.axonframework.eventhandling             org.axonframework.messaging
# 44  org.axonframework.eventhandling             org.axonframework.messaging
# 45  org.axonframework.eventhandling             org.axonframework.messaging
# 46  org.axonframework.eventhandling             org.axonframework.messaging
# 47  org.axonframework.eventhandling             org.axonframework.messaging
# 48  org.axonframework.eventhandling             org.axonframework.messaging
# 49  org.axonframework.eventhandling             org.axonframework.messaging
# 50  org.axonframework.eventhandling             org.axonframework.messaging
# 51  org.axonframework.eventhandling             org.axonframework.messaging
# 52  org.axonframework.eventhandling             org.axonframework.messaging
# 53  org.axonframework.eventhandling             org.axonframework.messaging
# 54  org.axonframework.eventhandling             org.axonframework.messaging
# 55  org.axonframework.eventhandling             org.axonframework.messaging
# 56  org.axonframework.eventhandling             org.axonframework.messaging
# 57  org.axonframework.eventhandling             org.axonframework.messaging
# 58  org.axonframework.eventhandling             org.axonframework.messaging
# 59  org.axonframework.eventhandling             org.axonframework.messaging
#
#                                            dependency  \
# 0   DomainEventMessage<-SourceIdParameterResolverF...
# 1   DomainEventMessage<-AggregateTypeParameterReso...
# 2   TrackingTokenParameterResolverFactory$Tracking...
# 3                        ResetHandler->MessageHandler
# 4    AnnotationEventHandlerAdapter->HandlerDefinition
# 5   AnnotationEventHandlerAdapter->MessageHandlerI...
# 6   AnnotationEventHandlerAdapter->MessageHandling...
# 7   AnnotationEventHandlerAdapter->AnnotatedHandle...
# 8   AnnotationEventHandlerAdapter->ClasspathParame...
# 9   AnnotationEventHandlerAdapter->ClasspathHandle...
# 10  AnnotationEventHandlerAdapter->ParameterResolv...
# 11  SimpleEventHandlerInvoker$Builder->HandlerDefi...
# 12  SimpleEventHandlerInvoker$Builder->ParameterRe...
# 13  ConcludesBatchParameterResolverFactory->Abstra...
# 14  ConcludesBatchParameterResolverFactory->Parame...
# 15  TimestampParameterResolverFactory->ParameterRe...
# 16  TimestampParameterResolverFactory->AbstractAnn...
# 17                       EventHandler->MessageHandler
# 18  SequenceNumberParameterResolverFactory->Parame...
# 19  SequenceNumberParameterResolverFactory->Abstra...
# 20  TimestampParameterResolverFactory$TimestampPar...
# 21                  AllowReplay->HasHandlerAttributes
# 22  SequenceNumberParameterResolverFactory$Sequenc...
# 23  TrackingTokenParameterResolverFactory->Paramet...
# 24  TrackingTokenParameterResolverFactory->Paramet...
# 25                        DomainEventMessage<-Headers
# 26                              EventMessage<-Headers
# 27             TrackingToken<-StreamableMessageSource
# 28  TrackingTokenParameterResolverFactory$Tracking...
# 29             AnnotationEventHandlerAdapter->Message
# 30   StreamingEventProcessor->StreamableMessageSource
# 31                        DomainEventMessage->Message
# 32                GenericTrackedEventMessage->Message
# 33    ConcludesBatchParameterResolverFactory->Message
# 34              GenericEventMessage->MessageDecorator
# 35                GenericEventMessage->GenericMessage
# 36                      GenericEventMessage->MetaData
# 37                       GenericEventMessage->Message
# 38                              EventMessage->Message
# 39  MultiStreamableMessageSource->StreamableMessag...
# 40          GenericTrackedDomainEventMessage->Message
# 41  MultiStreamableMessageSource$Builder->Streamab...
# 42                       EventMessageHandler->Message
# 43                EventMessageHandler->MessageHandler
# 44  TrackingEventProcessor$Builder->StreamableMess...
# 45  TimestampParameterResolverFactory$TimestampPar...
# 46                EventBus->SubscribableMessageSource
# 47        EventBus->MessageDispatchInterceptorSupport
# 48  SequenceNumberParameterResolverFactory$Sequenc...
# 49           TrackingEventProcessor->InterceptorChain
# 50                    TrackingEventProcessor->Message
# 51    TrackingEventProcessor->StreamableMessageSource
# 52  AbstractEventProcessor->MessageHandlerInterceptor
# 53    AbstractEventProcessor->DefaultInterceptorChain
# 54              AbstractEventProcessor->ResultMessage
# 55  SubscribingEventProcessor$Builder->Subscribabl...
# 56  MultiStreamableMessageSource$IdentifiedStreama...
# 57  SubscribingEventProcessor->SubscribableMessage...
# 58  TrackingEventProcessorConfiguration->Streamabl...
# 59                               ReplayToken->Message
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.840000             23               2
# 1                   0.840000             23               2
# 2                   0.840000             23               2
# 3                   0.840000             23               2
# 4                   0.840000             23               2
# 5                   0.840000             23               2
# 6                   0.840000             23               2
# 7                   0.840000             23               2
# 8                   0.840000             23               2
# 9                   0.840000             23               2
# 10                  0.840000             23               2
# 11                  0.840000             23               2
# 12                  0.840000             23               2
# 13                  0.840000             23               2
# 14                  0.840000             23               2
# 15                  0.840000             23               2
# 16                  0.840000             23               2
# 17                  0.840000             23               2
# 18                  0.840000             23               2
# 19                  0.840000             23               2
# 20                  0.840000             23               2
# 21                  0.840000             23               2
# 22                  0.840000             23               2
# 23                  0.840000             23               2
# 24                  0.840000             23               2
# 25                  0.837838             34               3
# 26                  0.837838             34               3
# 27                  0.837838             34               3
# 28                  0.837838             34               3
# 29                  0.837838             34               3
# 30                  0.837838             34               3
# 31                  0.837838             34               3
# 32                  0.837838             34               3
# 33                  0.837838             34               3
# 34                  0.837838             34               3
# 35                  0.837838             34               3
# 36                  0.837838             34               3
# 37                  0.837838             34               3
# 38                  0.837838             34               3
# 39                  0.837838             34               3
# 40                  0.837838             34               3
# 41                  0.837838             34               3
# 42                  0.837838             34               3
# 43                  0.837838             34               3
# 44                  0.837838             34               3
# 45                  0.837838             34               3
# 46                  0.837838             34               3
# 47                  0.837838             34               3
# 48                  0.837838             34               3
# 49                  0.837838             34               3
# 50                  0.837838             34               3
# 51                  0.837838             34               3
# 52                  0.837838             34               3
# 53                  0.837838             34               3
# 54                  0.837838             34               3
# 55                  0.837838             34               3
# 56                  0.837838             34               3
# 57                  0.837838             34               3
# 58                  0.837838             34               3
# 59                  0.837838             34               3

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.
#
# ### Table 3
# - List top 20 most used combinations of methods of larger Types that might benefit from *Interface Segregation*

# %%
queryCypherToDataFrame("../cypher/Candidates_for_Interface_Segregation.cypher").head(20)
# Out:
#                                     dependentType.fqn  declaredMethods  \
# 0    org.axonframework.commandhandling.CommandMessage                9
# 1   org.axonframework.eventhandling.DomainEventMes...               10
# 2        org.axonframework.eventhandling.EventMessage                9
# 3        org.axonframework.eventhandling.EventMessage                9
# 4   org.axonframework.eventhandling.TrackedEventMe...               10
# 5           org.axonframework.messaging.ResultMessage                9
# 6   org.axonframework.eventhandling.DomainEventMes...               10
# 7   org.axonframework.commandhandling.GenericComma...               15
# 8   org.axonframework.commandhandling.GenericComma...               14
# 9   org.axonframework.eventhandling.TrackedEventMe...               12
# 10  org.axonframework.deadline.GenericDeadlineMessage               11
# 11         org.axonframework.deadline.DeadlineMessage               10
# 12  org.axonframework.eventhandling.DomainEventMes...               10
# 13  org.axonframework.eventhandling.GenericEventMe...               10
# 14  org.axonframework.common.transaction.NoTransac...                4
# 15  org.axonframework.modelling.command.inspection...               13
# 16  org.axonframework.eventhandling.DomainEventMes...               11
# 17  org.axonframework.eventhandling.DomainEventMes...               10
# 18  org.axonframework.eventhandling.DomainEventMes...               10
# 19  org.axonframework.eventhandling.GapAwareTracki...               10
#
#                                     calledMethodNames  calledMethods  \
# 0                                    [getCommandName]              1
# 1                                 [getSequenceNumber]              1
# 2                       [getTimestamp, getIdentifier]              2
# 3                                     [getIdentifier]              1
# 4                                     [trackingToken]              1
# 5                    [exceptionResult, isExceptional]              2
# 6   [getSequenceNumber, getAggregateIdentifier, ge...              3
# 7                            [asCommandResultMessage]              1
# 8                            [asCommandResultMessage]              1
# 9                                     [trackingToken]              1
# 10                                [asDeadlineMessage]              1
# 11                                  [getDeadlineName]              1
# 12                           [getAggregateIdentifier]              1
# 13                                   [asEventMessage]              1
# 14                                         [instance]              1
# 15                                             [type]              1
# 16  [getSequenceNumber, getAggregateIdentifier, ge...              3
# 17        [getSequenceNumber, getAggregateIdentifier]              2
# 18                                          [getType]              1
# 19  [advanceTo, newInstance, withGapsTruncatedAt, ...              5
#
#     callerTypes
# 0            18
# 1             9
# 2             8
# 3             8
# 4             7
# 5             6
# 6             5
# 7             4
# 8             4
# 9             4
# 10            4
# 11            4
# 12            4
# 13            4
# 14            4
# 15            3
# 16            3
# 17            3
# 18            3
# 19            3

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Types that are used by multiple packages
#
# #### Table 4
# - List the top 20 packages that are used by the highest count of different packages

# %%
queryCypherToDataFrame("../cypher/Package_Usage/List_types_that_are_used_by_many_different_packages.cypher").head(20)
# Out:
#                                     dependentType.fqn  \
# 0               org.axonframework.common.BuilderUtils
# 1                 org.axonframework.messaging.Message
# 2   org.axonframework.common.AxonConfigurationExce...
# 3        org.axonframework.eventhandling.EventMessage
# 4   org.axonframework.messaging.unitofwork.UnitOfWork
# 5                org.axonframework.messaging.MetaData
# 6                     org.axonframework.common.Assert
# 7          org.axonframework.serialization.Serializer
# 8   org.axonframework.common.transaction.Transacti...
# 9   org.axonframework.messaging.unitofwork.Current...
# 10   org.axonframework.serialization.SerializedObject
# 11     org.axonframework.serialization.SerializedType
# 12  org.axonframework.messaging.annotation.Paramet...
# 13  org.axonframework.common.AxonNonTransientExcep...
# 14  org.axonframework.eventhandling.DomainEventMes...
# 15      org.axonframework.eventhandling.TrackingToken
# 16              org.axonframework.common.Registration
# 17  org.axonframework.eventhandling.GenericEventMe...
# 18  org.axonframework.messaging.MessageHandlerInte...
# 19   org.axonframework.commandhandling.CommandMessage
#
#             dependentType.name  \
# 0                 BuilderUtils
# 1                      Message
# 2   AxonConfigurationException
# 3                 EventMessage
# 4                   UnitOfWork
# 5                     MetaData
# 6                       Assert
# 7                   Serializer
# 8           TransactionManager
# 9            CurrentUnitOfWork
# 10            SerializedObject
# 11              SerializedType
# 12    ParameterResolverFactory
# 13   AxonNonTransientException
# 14          DomainEventMessage
# 15               TrackingToken
# 16                Registration
# 17         GenericEventMessage
# 18   MessageHandlerInterceptor
# 19              CommandMessage
#
#                                   dependentTypeLabels  numberOfUsingPackages
# 0                 [Type, File, Java, ByteCode, Class]                     41
# 1   [Type, File, Java, ByteCode, GenericDeclaratio...                     35
# 2                 [Type, File, Java, ByteCode, Class]                     35
# 3   [Type, File, Java, ByteCode, GenericDeclaratio...                     30
# 4   [Type, File, Java, ByteCode, GenericDeclaratio...                     29
# 5                 [Type, File, Java, ByteCode, Class]                     29
# 6                 [Type, File, Java, ByteCode, Class]                     25
# 7             [Type, File, Java, ByteCode, Interface]                     25
# 8             [Type, File, Java, ByteCode, Interface]                     23
# 9                 [Type, File, Java, ByteCode, Class]                     21
# 10  [Type, File, Java, ByteCode, GenericDeclaratio...                     21
# 11            [Type, File, Java, ByteCode, Interface]                     20
# 12            [Type, File, Java, ByteCode, Interface]                     18
# 13                [Type, File, Java, ByteCode, Class]                     18
# 14  [Type, File, Java, ByteCode, GenericDeclaratio...                     17
# 15            [Type, File, Java, ByteCode, Interface]                     17
# 16            [Type, File, Java, ByteCode, Interface]                     16
# 17  [Type, File, Java, ByteCode, Class, GenericDec...                     16
# 18  [Type, File, Java, ByteCode, GenericDeclaratio...                     14
# 19  [Type, File, Java, ByteCode, GenericDeclaratio...                     14

# %% [markdown]
# ### Packages that are used by multiple artifacts
#
# #### Table 5
# - List the top 20 artifacts that only use a few (compared to all existing) packages of another artifact

# %%
queryCypherToDataFrame("../cypher/Package_Usage/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher").head(20)
# Out:
#                 artifactName     dependentArtifactName  dependentPackages  \
# 0       axon-disruptor-4.7.5      axon-messaging-4.7.5                  9
# 1            axon-test-4.7.5      axon-messaging-4.7.5                 10
# 2       axon-disruptor-4.7.5      axon-modelling-4.7.5                  2
# 3   axon-eventsourcing-4.7.5      axon-modelling-4.7.5                  2
# 4       axon-disruptor-4.7.5  axon-eventsourcing-4.7.5                  2
# 5            axon-test-4.7.5  axon-eventsourcing-4.7.5                  2
# 6       axon-modelling-4.7.5      axon-messaging-4.7.5                 18
# 7   axon-eventsourcing-4.7.5      axon-messaging-4.7.5                 20
# 8   axon-configuration-4.7.5  axon-eventsourcing-4.7.5                  4
# 9            axon-test-4.7.5      axon-modelling-4.7.5                  5
# 10  axon-configuration-4.7.5      axon-messaging-4.7.5                 34
# 11      axon-modelling-4.7.5      axon-modelling-4.7.5                  6
# 12  axon-configuration-4.7.5      axon-modelling-4.7.5                  6
# 13           axon-test-4.7.5           axon-test-4.7.5                  5
# 14      axon-messaging-4.7.5      axon-messaging-4.7.5                 40
# 15  axon-eventsourcing-4.7.5  axon-eventsourcing-4.7.5                  7
# 16  axon-configuration-4.7.5      axon-disruptor-4.7.5                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          61                0.147541
# 1                          61                0.163934
# 2                          10                0.200000
# 3                          10                0.200000
# 4                           9                0.222222
# 5                           9                0.222222
# 6                          61                0.295082
# 7                          61                0.327869
# 8                           9                0.444444
# 9                          10                0.500000
# 10                         61                0.557377
# 11                         10                0.600000
# 12                         10                0.600000
# 13                          8                0.625000
# 14                         61                0.655738
# 15                          9                0.777778
# 16                          1                1.000000
#
#                    dependentFullQualifiedPackageNames  \
# 0   [org.axonframework.messaging.annotation, org.a...
# 1   [org.axonframework.eventhandling, org.axonfram...
# 2   [org.axonframework.modelling.command.inspectio...
# 3   [org.axonframework.modelling.command, org.axon...
# 4   [org.axonframework.eventsourcing, org.axonfram...
# 5   [org.axonframework.eventsourcing.eventstore, o...
# 6   [org.axonframework.messaging.annotation, org.a...
# 7   [org.axonframework.eventhandling, org.axonfram...
# 8   [org.axonframework.eventsourcing.snapshotting,...
# 9   [org.axonframework.modelling.command, org.axon...
# 10  [org.axonframework.serialization.xml, org.axon...
# 11  [org.axonframework.modelling.command, org.axon...
# 12  [org.axonframework.modelling.saga.repository.j...
# 13  [org.axonframework.test, org.axonframework.tes...
# 14  [org.axonframework.common, org.axonframework.c...
# 15  [org.axonframework.eventsourcing.eventstore.jd...
# 16      [org.axonframework.disruptor.commandhandling]
#
#                                 dependentPackageNames
# 0   [annotation, monitoring, callbacks, messaging,...
# 1   [eventhandling, messaging, common, commandhand...
# 2                               [inspection, command]
# 3                               [command, inspection]
# 4                         [eventsourcing, eventstore]
# 5                         [eventstore, eventsourcing]
# 6   [annotation, property, eventhandling, unitofwo...
# 7   [eventhandling, serialization, common, jdbc, t...
# 8      [snapshotting, eventsourcing, eventstore, jpa]
# 9   [command, inspection, inmemory, repository, saga]
# 10  [xml, serialization, util, gateway, annotation...
# 11  [command, repository, saga, inspection, jpa, m...
# 12  [jpa, repository, inmemory, saga, inspection, ...
# 13  [test, matchers, deadline, utils, eventscheduler]
# 14  [common, transaction, tracing, messaging, io, ...
# 15  [jdbc, eventstore, statements, snapshotting, e...
# 16                                  [commandhandling]

# %% [markdown]
# ### Packages that are used by multiple artifacts
#
# #### Table 6
# - List the top 20 packages that only use a few (compared to all existing) types of another package

# %%
queryCypherToDataFrame("../cypher/Package_Usage/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher").head(20)
# Out:
#                 artifactName dependentArtifactName  \
# 0   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 1            axon-test-4.7.5  axon-messaging-4.7.5
# 2       axon-modelling-4.7.5  axon-messaging-4.7.5
# 3   axon-eventsourcing-4.7.5  axon-modelling-4.7.5
# 4   axon-eventsourcing-4.7.5  axon-modelling-4.7.5
# 5   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 6            axon-test-4.7.5  axon-messaging-4.7.5
# 7       axon-modelling-4.7.5  axon-messaging-4.7.5
# 8       axon-modelling-4.7.5  axon-messaging-4.7.5
# 9   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 10  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 11           axon-test-4.7.5  axon-messaging-4.7.5
# 12           axon-test-4.7.5  axon-messaging-4.7.5
# 13  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 14  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 15  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 16  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 17           axon-test-4.7.5  axon-modelling-4.7.5
# 18  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 19           axon-test-4.7.5  axon-messaging-4.7.5
#
#                                           packageName  \
# 0        org.axonframework.eventsourcing.snapshotting
# 1                     org.axonframework.test.matchers
# 2          org.axonframework.modelling.saga.metamodel
# 3   org.axonframework.eventsourcing.conflictresolu...
# 4     org.axonframework.eventsourcing.eventstore.jdbc
# 5   org.axonframework.eventsourcing.conflictresolu...
# 6               org.axonframework.test.eventscheduler
# 7                 org.axonframework.modelling.command
# 8       org.axonframework.modelling.command.legacyjpa
# 9   org.axonframework.eventsourcing.conflictresolu...
# 10         org.axonframework.eventsourcing.eventstore
# 11                             org.axonframework.test
# 12                    org.axonframework.test.matchers
# 13    org.axonframework.eventsourcing.eventstore.jdbc
# 14     org.axonframework.eventsourcing.eventstore.jpa
# 15  org.axonframework.eventsourcing.eventstore.leg...
# 16  org.axonframework.eventsourcing.eventstore.jdb...
# 17                       org.axonframework.test.utils
# 18  org.axonframework.eventsourcing.conflictresolu...
# 19                    org.axonframework.test.matchers
#
#                    dependentPackage.fqn  dependentTypes  \
# 0       org.axonframework.eventhandling               1
# 1       org.axonframework.eventhandling               1
# 2       org.axonframework.eventhandling               1
# 3   org.axonframework.modelling.command               1
# 4   org.axonframework.modelling.command               1
# 5       org.axonframework.eventhandling               2
# 6       org.axonframework.eventhandling               2
# 7       org.axonframework.eventhandling               2
# 8       org.axonframework.eventhandling               2
# 9           org.axonframework.messaging               1
# 10          org.axonframework.messaging               1
# 11          org.axonframework.messaging               1
# 12          org.axonframework.messaging               1
# 13      org.axonframework.serialization               1
# 14      org.axonframework.serialization               1
# 15      org.axonframework.serialization               1
# 16      org.axonframework.eventhandling               3
# 17     org.axonframework.modelling.saga               1
# 18    org.axonframework.commandhandling               1
# 19    org.axonframework.commandhandling               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                      93             0.010753
# 1                      93             0.010753
# 2                      93             0.010753
# 3                      51             0.019608
# 4                      51             0.019608
# 5                      93             0.021505
# 6                      93             0.021505
# 7                      93             0.021505
# 8                      93             0.021505
# 9                      35             0.028571
# 10                     35             0.028571
# 11                     35             0.028571
# 12                     35             0.028571
# 13                     34             0.029412
# 14                     34             0.029412
# 15                     34             0.029412
# 16                     93             0.032258
# 17                     30             0.033333
# 18                     29             0.034483
# 19                     29             0.034483
#
#                                    dependentTypeNames
# 0   [org.axonframework.eventhandling.DomainEventData]
# 1      [org.axonframework.eventhandling.EventMessage]
# 2      [org.axonframework.eventhandling.EventMessage]
# 3   [org.axonframework.modelling.command.Conflicti...
# 4   [org.axonframework.modelling.command.Concurren...
# 5   [org.axonframework.eventhandling.DomainEventMe...
# 6   [org.axonframework.eventhandling.EventMessage,...
# 7   [org.axonframework.eventhandling.EventBus, org...
# 8   [org.axonframework.eventhandling.EventBus, org...
# 9               [org.axonframework.messaging.Message]
# 10  [org.axonframework.messaging.StreamableMessage...
# 11              [org.axonframework.messaging.Message]
# 12              [org.axonframework.messaging.Message]
# 13       [org.axonframework.serialization.Serializer]
# 14       [org.axonframework.serialization.Serializer]
# 15       [org.axonframework.serialization.Serializer]
# 16  [org.axonframework.eventhandling.DomainEventMe...
# 17  [org.axonframework.modelling.saga.SimpleResour...
# 18  [org.axonframework.commandhandling.CommandMess...
# 19  [org.axonframework.commandhandling.CommandMess...
