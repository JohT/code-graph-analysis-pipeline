# %% [markdown]
# # Package Dependencies for Java with Neo4j
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [py2neo](https://py2neo.org/2021.1/)

# %%
import os
import matplotlib.pyplot as plot
from py2neo import Graph

# %%
#Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
#before starting jupyter notebook to provide the password for the user "neo4j". 
#It is not recommended to hardcode the password into jupyter notebook for security reasons.
graph = Graph("bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))

# %%
def getCypherQueryFromFile(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def queryCypherToDataFrame(cypherFileName):
    return graph.run(getCypherQueryFromFile(cypherFileName)).to_data_frame()

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Artifacts
#
# ### Table 1
#
# - List all the artifacts this notebook is based on

# %%
queryCypherToDataFrame("../cypher/List_all_existing_artifacts.cypher")
# Out:
#                    artifactName  packages  types
# 0           axon-test-4.7.5.jar         8     85
# 1      axon-disruptor-4.7.5.jar         1     22
# 2  axon-eventsourcing-4.7.5.jar         9    130
# 3      axon-messaging-4.7.5.jar        61    729
# 4      axon-modelling-4.7.5.jar        10    149
# 5  axon-configuration-4.7.5.jar         1     39

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to a lot of trouble when one of these packages needs to be changed.
#
# ### Table 2
# - List packages with cyclic dependencies

# %%
queryCypherToDataFrame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_as_List.cypher")
# Out:
#                                           packageName  \
# 0                     org.axonframework.eventsourcing
# 1                     org.axonframework.queryhandling
# 2                     org.axonframework.eventhandling
# 3                     org.axonframework.eventhandling
# 4                     org.axonframework.eventhandling
# 5                     org.axonframework.queryhandling
# 6                          org.axonframework.deadline
# 7         org.axonframework.commandhandling.callbacks
# 8                   org.axonframework.commandhandling
# 9              org.axonframework.messaging.unitofwork
# 10              org.axonframework.eventhandling.async
# 11             org.axonframework.eventhandling.replay
# 12                    org.axonframework.eventhandling
# 13    org.axonframework.serialization.upcasting.event
# 14    org.axonframework.eventsourcing.eventstore.jdbc
# 15     org.axonframework.modelling.command.inspection
# 16       org.axonframework.queryhandling.registration
# 17                        org.axonframework.messaging
# 18                    org.axonframework.eventhandling
# 19             org.axonframework.messaging.annotation
# 20                   org.axonframework.modelling.saga
# 21  org.axonframework.commandhandling.distributed....
#
#                                  dependentPackageName  \
# 0          org.axonframework.eventsourcing.eventstore
# 1           org.axonframework.messaging.responsetypes
# 2                         org.axonframework.messaging
# 3              org.axonframework.messaging.annotation
# 4                           org.axonframework.tracing
# 5                           org.axonframework.tracing
# 6                           org.axonframework.tracing
# 7                   org.axonframework.commandhandling
# 8                           org.axonframework.tracing
# 9                         org.axonframework.messaging
# 10                    org.axonframework.eventhandling
# 11                    org.axonframework.eventhandling
# 12                    org.axonframework.serialization
# 13                    org.axonframework.eventhandling
# 14  org.axonframework.eventsourcing.eventstore.jdb...
# 15                org.axonframework.modelling.command
# 16                    org.axonframework.queryhandling
# 17                    org.axonframework.serialization
# 18         org.axonframework.eventhandling.tokenstore
# 19           org.axonframework.messaging.interceptors
# 20         org.axonframework.modelling.saga.metamodel
# 21      org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.882353             16               1
# 1                   0.882353             16               1
# 2                   0.850000             37               3
# 3                   0.840000             23               2
# 4                   0.800000              9               1
# 5                   0.800000              9               1
# 6                   0.750000              7               1
# 7                   0.733333             13               2
# 8                   0.666667              5               1
# 9                   0.647059             14               3
# 10                  0.538462             10               3
# 11                  0.454545              8               3
# 12                  0.400000              7               3
# 13                  0.333333              6               3
# 14                  0.317073             27              14
# 15                  0.250000             20              12
# 16                  0.250000              5               3
# 17                  0.238095             13               8
# 18                  0.230769              8               5
# 19                  0.200000              3               2
# 20                  0.142857              4               3
# 21                  0.076923              7               6
#
#                                   forwardDependencies  \
# 0   [AbstractSnapshotter$Builder->EventStore, Even...
# 1   [SimpleQueryUpdateEmitter->MultipleInstancesRe...
# 2   [AbstractEventProcessor->MessageHandlerInterce...
# 3   [SequenceNumberParameterResolverFactory$Sequen...
# 4   [AbstractEventProcessor->Span, AbstractEventPr...
# 5   [SimpleQueryUpdateEmitter->Span, SimpleQueryUp...
# 6   [SimpleDeadlineManager->Span, SimpleDeadlineMa...
# 7   [FailureLoggingCallback->CommandCallback, Fail...
# 8   [SimpleCommandBus$Builder->NoOpSpanFactory, Si...
# 9   [ExecutionResult->ResultMessage, DefaultUnitOf...
# 10  [EventProcessorTask$ProcessingTask->EventMessa...
# 11  [ReplayParameterResolverFactory$ReplayParamete...
# 12  [EventData->SerializedObject, AbstractSequence...
# 13  [InitialEventRepresentation->TrackingToken, In...
# 14  [JdbcEventStorageEngine->ReadEventDataWithoutG...
# 15  [CreationPolicyMember->AggregateCreationPolicy...
# 16  [LoggingDuplicateQueryHandlerResolver->QuerySu...
# 17  [Message->Serializer, Message->SerializedObjec...
# 18  [TrackingEventProcessor$MergeSegmentInstructio...
# 19  [MessageHandlerInterceptorDefinition->ResultHa...
# 20  [AnnotatedSagaManager$Builder->AnnotationSagaM...
# 21  [OrCommandMessageFilter->CommandMessageFilter,...
#
#                                  backwardDependencies
# 0      [AbstractEventStorageEngine->EventStreamUtils]
# 1   [ConvertingResponseMessage->QueryResponseMessage]
# 2   [Headers->EventMessage, StreamableMessageSourc...
# 3   [AggregateTypeParameterResolverFactory$Aggrega...
# 4                  [NestingSpanFactory->EventMessage]
# 5                           [SpanUtils->QueryMessage]
# 6                        [SpanUtils->DeadlineMessage]
# 7   [SimpleCommandBus$Builder->NoOpCallback, Simpl...
# 8                         [SpanUtils->CommandMessage]
# 9   [GenericMessage->CurrentUnitOfWork, DefaultInt...
# 10  [SimpleEventHandlerInvoker$Builder->Sequencing...
# 11  [AnnotationEventHandlerAdapter->ResetContext, ...
# 12  [GapAwareTrackingTokenConverter->GapAwareTrack...
# 13  [EventUtils->InitialEventRepresentation, Event...
# 14  [CreateTailTokenStatementBuilder->EventSchema,...
# 15  [AggregateAnnotationCommandHandler->CreationPo...
# 16  [SimpleQueryBus->DuplicateQueryHandlerResolver...
# 17  [SerializedMessage->Message, SerializedObjectH...
# 18  [TokenStore->TrackingToken, GenericTokenEntry-...
# 19  [ResultHandler->HasHandlerAttributes, MessageH...
# 20  [AnnotationSagaMetaModelFactory$InspectedSagaM...
# 21  [CommandMessageFilter->OrCommandMessageFilter,...

# %% [markdown]
# ### Table 3
# - List packages with cyclic dependencies with every dependency in a separate row sorted by the easiest and most valuable to resolve

# %%
queryCypherToDataFrame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_as_unwinded_List.cypher").head(60)
# Out:
#                         packageName  \
# 0   org.axonframework.eventsourcing
# 1   org.axonframework.eventsourcing
# 2   org.axonframework.eventsourcing
# 3   org.axonframework.eventsourcing
# 4   org.axonframework.eventsourcing
# 5   org.axonframework.eventsourcing
# 6   org.axonframework.eventsourcing
# 7   org.axonframework.eventsourcing
# 8   org.axonframework.eventsourcing
# 9   org.axonframework.eventsourcing
# 10  org.axonframework.eventsourcing
# 11  org.axonframework.eventsourcing
# 12  org.axonframework.eventsourcing
# 13  org.axonframework.eventsourcing
# 14  org.axonframework.eventsourcing
# 15  org.axonframework.eventsourcing
# 16  org.axonframework.eventsourcing
# 17  org.axonframework.queryhandling
# 18  org.axonframework.queryhandling
# 19  org.axonframework.queryhandling
# 20  org.axonframework.queryhandling
# 21  org.axonframework.queryhandling
# 22  org.axonframework.queryhandling
# 23  org.axonframework.queryhandling
# 24  org.axonframework.queryhandling
# 25  org.axonframework.queryhandling
# 26  org.axonframework.queryhandling
# 27  org.axonframework.queryhandling
# 28  org.axonframework.queryhandling
# 29  org.axonframework.queryhandling
# 30  org.axonframework.queryhandling
# 31  org.axonframework.queryhandling
# 32  org.axonframework.queryhandling
# 33  org.axonframework.queryhandling
# 34  org.axonframework.eventhandling
# 35  org.axonframework.eventhandling
# 36  org.axonframework.eventhandling
# 37  org.axonframework.eventhandling
# 38  org.axonframework.eventhandling
# 39  org.axonframework.eventhandling
# 40  org.axonframework.eventhandling
# 41  org.axonframework.eventhandling
# 42  org.axonframework.eventhandling
# 43  org.axonframework.eventhandling
# 44  org.axonframework.eventhandling
# 45  org.axonframework.eventhandling
# 46  org.axonframework.eventhandling
# 47  org.axonframework.eventhandling
# 48  org.axonframework.eventhandling
# 49  org.axonframework.eventhandling
# 50  org.axonframework.eventhandling
# 51  org.axonframework.eventhandling
# 52  org.axonframework.eventhandling
# 53  org.axonframework.eventhandling
# 54  org.axonframework.eventhandling
# 55  org.axonframework.eventhandling
# 56  org.axonframework.eventhandling
# 57  org.axonframework.eventhandling
# 58  org.axonframework.eventhandling
# 59  org.axonframework.eventhandling
#
#                           dependentPackageName  \
# 0   org.axonframework.eventsourcing.eventstore
# 1   org.axonframework.eventsourcing.eventstore
# 2   org.axonframework.eventsourcing.eventstore
# 3   org.axonframework.eventsourcing.eventstore
# 4   org.axonframework.eventsourcing.eventstore
# 5   org.axonframework.eventsourcing.eventstore
# 6   org.axonframework.eventsourcing.eventstore
# 7   org.axonframework.eventsourcing.eventstore
# 8   org.axonframework.eventsourcing.eventstore
# 9   org.axonframework.eventsourcing.eventstore
# 10  org.axonframework.eventsourcing.eventstore
# 11  org.axonframework.eventsourcing.eventstore
# 12  org.axonframework.eventsourcing.eventstore
# 13  org.axonframework.eventsourcing.eventstore
# 14  org.axonframework.eventsourcing.eventstore
# 15  org.axonframework.eventsourcing.eventstore
# 16  org.axonframework.eventsourcing.eventstore
# 17   org.axonframework.messaging.responsetypes
# 18   org.axonframework.messaging.responsetypes
# 19   org.axonframework.messaging.responsetypes
# 20   org.axonframework.messaging.responsetypes
# 21   org.axonframework.messaging.responsetypes
# 22   org.axonframework.messaging.responsetypes
# 23   org.axonframework.messaging.responsetypes
# 24   org.axonframework.messaging.responsetypes
# 25   org.axonframework.messaging.responsetypes
# 26   org.axonframework.messaging.responsetypes
# 27   org.axonframework.messaging.responsetypes
# 28   org.axonframework.messaging.responsetypes
# 29   org.axonframework.messaging.responsetypes
# 30   org.axonframework.messaging.responsetypes
# 31   org.axonframework.messaging.responsetypes
# 32   org.axonframework.messaging.responsetypes
# 33   org.axonframework.messaging.responsetypes
# 34                 org.axonframework.messaging
# 35                 org.axonframework.messaging
# 36                 org.axonframework.messaging
# 37                 org.axonframework.messaging
# 38                 org.axonframework.messaging
# 39                 org.axonframework.messaging
# 40                 org.axonframework.messaging
# 41                 org.axonframework.messaging
# 42                 org.axonframework.messaging
# 43                 org.axonframework.messaging
# 44                 org.axonframework.messaging
# 45                 org.axonframework.messaging
# 46                 org.axonframework.messaging
# 47                 org.axonframework.messaging
# 48                 org.axonframework.messaging
# 49                 org.axonframework.messaging
# 50                 org.axonframework.messaging
# 51                 org.axonframework.messaging
# 52                 org.axonframework.messaging
# 53                 org.axonframework.messaging
# 54                 org.axonframework.messaging
# 55                 org.axonframework.messaging
# 56                 org.axonframework.messaging
# 57                 org.axonframework.messaging
# 58                 org.axonframework.messaging
# 59                 org.axonframework.messaging
#
#                                            dependency  \
# 0        EventStreamUtils<-AbstractEventStorageEngine
# 1             AbstractSnapshotter$Builder->EventStore
# 2          EventSourcingRepository->DomainEventStream
# 3                 EventSourcingRepository->EventStore
# 4                     AggregateCacheEntry->EventStore
# 5             AggregateSnapshotter->DomainEventStream
# 6            AggregateSnapshotter$Builder->EventStore
# 7   AbstractSnapshotter$CreateSnapshotTask->EventS...
# 8   AbstractSnapshotter$CreateSnapshotTask->Domain...
# 9            EventSourcedAggregate->DomainEventStream
# 10         CachingEventSourcingRepository->EventStore
# 11                    AbstractSnapshotter->EventStore
# 12             AbstractSnapshotter->DomainEventStream
# 13        EventSourcingRepository$Builder->EventStore
# 14                EventStreamUtils->DomainEventStream
# 15    FilteringEventStorageEngine->EventStorageEngine
# 16     FilteringEventStorageEngine->DomainEventStream
# 17    QueryResponseMessage<-ConvertingResponseMessage
# 18  SimpleQueryUpdateEmitter->MultipleInstancesRes...
# 19    SimpleQueryUpdateEmitter->PublisherResponseType
# 20             SimpleQueryUpdateEmitter->ResponseType
# 21     SimpleQueryUpdateEmitter->OptionalResponseType
# 22                StreamingQueryMessage->ResponseType
# 23                         QueryMessage->ResponseType
# 24      GenericSubscriptionQueryMessage->ResponseType
# 25                    QuerySubscription->ResponseType
# 26                  DefaultQueryGateway->ResponseType
# 27             SubscriptionQueryMessage->ResponseType
# 28                       SimpleQueryBus->ResponseType
# 29  GenericStreamingQueryMessage->PublisherRespons...
# 30         GenericStreamingQueryMessage->ResponseType
# 31                         QueryGateway->ResponseType
# 32                        QueryGateway->ResponseTypes
# 33                  GenericQueryMessage->ResponseType
# 34                              EventMessage<-Headers
# 35             TrackingToken<-StreamableMessageSource
# 36                        DomainEventMessage<-Headers
# 37  AbstractEventProcessor->MessageHandlerInterceptor
# 38              AbstractEventProcessor->ResultMessage
# 39    AbstractEventProcessor->DefaultInterceptorChain
# 40  SequenceNumberParameterResolverFactory$Sequenc...
# 41  SubscribingEventProcessor$Builder->Subscribabl...
# 42  SubscribingEventProcessor->SubscribableMessage...
# 43   StreamingEventProcessor->StreamableMessageSource
# 44                EventMessageHandler->MessageHandler
# 45                       EventMessageHandler->Message
# 46             AnnotationEventHandlerAdapter->Message
# 47                              EventMessage->Message
# 48  TrackingEventProcessor$Builder->StreamableMess...
# 49  MultiStreamableMessageSource$IdentifiedStreama...
# 50  TrackingEventProcessorConfiguration->Streamabl...
# 51  TrackingTokenParameterResolverFactory$Tracking...
# 52                EventBus->SubscribableMessageSource
# 53        EventBus->MessageDispatchInterceptorSupport
# 54          EventProcessor->MessageHandlerInterceptor
# 55   EventProcessor->MessageHandlerInterceptorSupport
# 56  TimestampParameterResolverFactory$TimestampPar...
# 57                               ReplayToken->Message
# 58          GenericDomainEventMessage->GenericMessage
# 59                 GenericDomainEventMessage->Message
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.882353             16               1
# 1                   0.882353             16               1
# 2                   0.882353             16               1
# 3                   0.882353             16               1
# 4                   0.882353             16               1
# 5                   0.882353             16               1
# 6                   0.882353             16               1
# 7                   0.882353             16               1
# 8                   0.882353             16               1
# 9                   0.882353             16               1
# 10                  0.882353             16               1
# 11                  0.882353             16               1
# 12                  0.882353             16               1
# 13                  0.882353             16               1
# 14                  0.882353             16               1
# 15                  0.882353             16               1
# 16                  0.882353             16               1
# 17                  0.882353             16               1
# 18                  0.882353             16               1
# 19                  0.882353             16               1
# 20                  0.882353             16               1
# 21                  0.882353             16               1
# 22                  0.882353             16               1
# 23                  0.882353             16               1
# 24                  0.882353             16               1
# 25                  0.882353             16               1
# 26                  0.882353             16               1
# 27                  0.882353             16               1
# 28                  0.882353             16               1
# 29                  0.882353             16               1
# 30                  0.882353             16               1
# 31                  0.882353             16               1
# 32                  0.882353             16               1
# 33                  0.882353             16               1
# 34                  0.850000             37               3
# 35                  0.850000             37               3
# 36                  0.850000             37               3
# 37                  0.850000             37               3
# 38                  0.850000             37               3
# 39                  0.850000             37               3
# 40                  0.850000             37               3
# 41                  0.850000             37               3
# 42                  0.850000             37               3
# 43                  0.850000             37               3
# 44                  0.850000             37               3
# 45                  0.850000             37               3
# 46                  0.850000             37               3
# 47                  0.850000             37               3
# 48                  0.850000             37               3
# 49                  0.850000             37               3
# 50                  0.850000             37               3
# 51                  0.850000             37               3
# 52                  0.850000             37               3
# 53                  0.850000             37               3
# 54                  0.850000             37               3
# 55                  0.850000             37               3
# 56                  0.850000             37               3
# 57                  0.850000             37               3
# 58                  0.850000             37               3
# 59                  0.850000             37               3

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.
#
# ### Table 3
# - List top 20 most used combinations of methods of larger Types that might benefit from *Interface Segregation*

# %%
queryCypherToDataFrame("../cypher/Candidates_for_Interface_Segregation.cypher").head(20)
# Out:
#                                     dependentType.fqn  declaredMethods  \
# 0    org.axonframework.commandhandling.CommandMessage                9
# 1           org.axonframework.messaging.ResultMessage                9
# 2   org.axonframework.eventhandling.DomainEventMes...               10
# 3        org.axonframework.eventhandling.EventMessage                9
# 4        org.axonframework.eventhandling.EventMessage                9
# 5   org.axonframework.eventhandling.TrackedEventMe...               10
# 6   org.axonframework.eventhandling.DomainEventMes...               10
# 7   org.axonframework.commandhandling.GenericComma...               15
# 8   org.axonframework.commandhandling.GenericComma...               14
# 9   org.axonframework.messaging.annotation.Wrapped...               14
# 10  org.axonframework.modelling.command.inspection...               13
# 11  org.axonframework.eventhandling.TrackedEventMe...               12
# 12  org.axonframework.deadline.GenericDeadlineMessage               11
# 13         org.axonframework.deadline.DeadlineMessage               10
# 14  org.axonframework.eventhandling.DomainEventMes...               10
# 15  org.axonframework.eventhandling.DomainEventMes...               10
# 16  org.axonframework.eventhandling.GenericEventMe...               10
# 17  org.axonframework.common.transaction.NoTransac...                4
# 18        org.axonframework.eventhandling.ReplayToken               13
# 19  org.axonframework.eventhandling.DomainEventMes...               11
#
#                                     calledMethodNames  calledMethods  \
# 0                                    [getCommandName]              1
# 1                    [isExceptional, exceptionResult]              2
# 2                                 [getSequenceNumber]              1
# 3                       [getTimestamp, getIdentifier]              2
# 4                                     [getIdentifier]              1
# 5                                     [trackingToken]              1
# 6   [getType, getAggregateIdentifier, getSequenceN...              3
# 7                            [asCommandResultMessage]              1
# 8                            [asCommandResultMessage]              1
# 9                                            [handle]              1
# 10                                             [type]              1
# 11                                    [trackingToken]              1
# 12                                [asDeadlineMessage]              1
# 13                                  [getDeadlineName]              1
# 14                                          [getType]              1
# 15                           [getAggregateIdentifier]              1
# 16                                   [asEventMessage]              1
# 17                                         [instance]              1
# 18                                         [isReplay]              1
# 19  [getType, getAggregateIdentifier, getSequenceN...              3
#
#     callerTypes
# 0            18
# 1            10
# 2             9
# 3             8
# 4             8
# 5             7
# 6             6
# 7             4
# 8             4
# 9             4
# 10            4
# 11            4
# 12            4
# 13            4
# 14            4
# 15            4
# 16            4
# 17            4
# 18            3
# 19            3

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Types that are used by multiple packages
#
# #### Table 4
# - List the top 20 packages that are used by the highest count of different packages

# %%
queryCypherToDataFrame("../cypher/Package_Usage/List_types_that_are_used_by_many_different_packages.cypher").head(20)
# Out:
#                                     dependentType.fqn  \
# 0               org.axonframework.common.BuilderUtils
# 1                 org.axonframework.messaging.Message
# 2   org.axonframework.common.AxonConfigurationExce...
# 3        org.axonframework.eventhandling.EventMessage
# 4                org.axonframework.messaging.MetaData
# 5   org.axonframework.messaging.unitofwork.UnitOfWork
# 6                     org.axonframework.common.Assert
# 7          org.axonframework.serialization.Serializer
# 8   org.axonframework.common.transaction.Transacti...
# 9   org.axonframework.messaging.unitofwork.Current...
# 10   org.axonframework.serialization.SerializedObject
# 11     org.axonframework.serialization.SerializedType
# 12  org.axonframework.common.AxonNonTransientExcep...
# 13  org.axonframework.messaging.annotation.Paramet...
# 14  org.axonframework.eventhandling.DomainEventMes...
# 15      org.axonframework.eventhandling.TrackingToken
# 16  org.axonframework.eventhandling.GenericEventMe...
# 17              org.axonframework.common.Registration
# 18   org.axonframework.commandhandling.CommandMessage
# 19  org.axonframework.messaging.MessageHandlerInte...
#
#             dependentType.name  \
# 0                 BuilderUtils
# 1                      Message
# 2   AxonConfigurationException
# 3                 EventMessage
# 4                     MetaData
# 5                   UnitOfWork
# 6                       Assert
# 7                   Serializer
# 8           TransactionManager
# 9            CurrentUnitOfWork
# 10            SerializedObject
# 11              SerializedType
# 12   AxonNonTransientException
# 13    ParameterResolverFactory
# 14          DomainEventMessage
# 15               TrackingToken
# 16         GenericEventMessage
# 17                Registration
# 18              CommandMessage
# 19   MessageHandlerInterceptor
#
#                                   dependentTypeLabels  numberOfUsingPackages
# 0                 [Type, File, Java, ByteCode, Class]                     41
# 1   [Type, File, Java, ByteCode, GenericDeclaratio...                     36
# 2                 [Type, File, Java, ByteCode, Class]                     35
# 3   [Type, File, Java, ByteCode, GenericDeclaratio...                     30
# 4                 [Type, File, Java, ByteCode, Class]                     30
# 5   [Type, File, Java, ByteCode, GenericDeclaratio...                     28
# 6                 [Type, File, Java, ByteCode, Class]                     26
# 7             [Type, File, Java, ByteCode, Interface]                     26
# 8             [Type, File, Java, ByteCode, Interface]                     23
# 9                 [Type, File, Java, ByteCode, Class]                     21
# 10  [Type, File, Java, ByteCode, GenericDeclaratio...                     21
# 11            [Type, File, Java, ByteCode, Interface]                     19
# 12                [Type, File, Java, ByteCode, Class]                     18
# 13            [Type, File, Java, ByteCode, Interface]                     17
# 14  [Type, File, Java, ByteCode, GenericDeclaratio...                     17
# 15            [Type, File, Java, ByteCode, Interface]                     17
# 16  [Type, File, Java, ByteCode, Class, GenericDec...                     16
# 17            [Type, File, Java, ByteCode, Interface]                     16
# 18  [Type, File, Java, ByteCode, GenericDeclaratio...                     14
# 19  [Type, File, Java, ByteCode, GenericDeclaratio...                     14

# %% [markdown]
# ### Packages that are used by multiple artifacts
#
# #### Table 5
# - List the top 20 artifacts that only use a few (compared to all existing) packages of another artifact

# %%
queryCypherToDataFrame("../cypher/Package_Usage/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher").head(20)
# Out:
#                 artifactName     dependentArtifactName  dependentPackages  \
# 0       axon-disruptor-4.7.5      axon-messaging-4.7.5                  9
# 1            axon-test-4.7.5      axon-messaging-4.7.5                 10
# 2       axon-disruptor-4.7.5      axon-modelling-4.7.5                  2
# 3   axon-eventsourcing-4.7.5      axon-modelling-4.7.5                  2
# 4            axon-test-4.7.5  axon-eventsourcing-4.7.5                  2
# 5       axon-disruptor-4.7.5  axon-eventsourcing-4.7.5                  2
# 6       axon-modelling-4.7.5      axon-messaging-4.7.5                 18
# 7   axon-eventsourcing-4.7.5      axon-messaging-4.7.5                 19
# 8   axon-configuration-4.7.5  axon-eventsourcing-4.7.5                  4
# 9            axon-test-4.7.5      axon-modelling-4.7.5                  5
# 10  axon-configuration-4.7.5      axon-messaging-4.7.5                 34
# 11      axon-modelling-4.7.5      axon-modelling-4.7.5                  6
# 12  axon-configuration-4.7.5      axon-modelling-4.7.5                  6
# 13           axon-test-4.7.5           axon-test-4.7.5                  5
# 14      axon-messaging-4.7.5      axon-messaging-4.7.5                 40
# 15  axon-eventsourcing-4.7.5  axon-eventsourcing-4.7.5                  7
# 16  axon-configuration-4.7.5      axon-disruptor-4.7.5                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          61                0.147541
# 1                          61                0.163934
# 2                          10                0.200000
# 3                          10                0.200000
# 4                           9                0.222222
# 5                           9                0.222222
# 6                          61                0.295082
# 7                          61                0.311475
# 8                           9                0.444444
# 9                          10                0.500000
# 10                         61                0.557377
# 11                         10                0.600000
# 12                         10                0.600000
# 13                          8                0.625000
# 14                         61                0.655738
# 15                          9                0.777778
# 16                          1                1.000000
#
#                    dependentFullQualifiedPackageNames  \
# 0   [org.axonframework.commandhandling.callbacks, ...
# 1   [org.axonframework.common, org.axonframework.e...
# 2   [org.axonframework.modelling.command.inspectio...
# 3   [org.axonframework.modelling.command, org.axon...
# 4   [org.axonframework.eventsourcing.eventstore, o...
# 5   [org.axonframework.eventsourcing, org.axonfram...
# 6   [org.axonframework.eventhandling, org.axonfram...
# 7   [org.axonframework.messaging.unitofwork, org.a...
# 8   [org.axonframework.eventsourcing.eventstore.jp...
# 9   [org.axonframework.modelling.saga, org.axonfra...
# 10  [org.axonframework.eventhandling.pooled, org.a...
# 11  [org.axonframework.modelling.command, org.axon...
# 12  [org.axonframework.modelling.command.inspectio...
# 13  [org.axonframework.test, org.axonframework.tes...
# 14  [org.axonframework.messaging, org.axonframewor...
# 15  [org.axonframework.eventsourcing.eventstore, o...
# 16      [org.axonframework.disruptor.commandhandling]
#
#                                 dependentPackageNames
# 0   [callbacks, annotation, commandhandling, unito...
# 1   [common, eventhandling, messaging, commandhand...
# 2                               [inspection, command]
# 3                               [command, inspection]
# 4                         [eventstore, eventsourcing]
# 5                         [eventsourcing, eventstore]
# 6   [eventhandling, annotation, commandhandling, c...
# 7   [unitofwork, eventhandling, jdbc, serializatio...
# 8      [jpa, snapshotting, eventstore, eventsourcing]
# 9   [saga, repository, inmemory, command, inspection]
# 10  [pooled, unitofwork, jdbc, caching, tokenstore...
# 11  [command, metamodel, jpa, repository, saga, in...
# 12  [inspection, inmemory, saga, repository, comma...
# 13  [test, matchers, eventscheduler, deadline, utils]
# 14  [messaging, io, eventhandling, util, queryhand...
# 15  [eventstore, statements, snapshotting, eventso...
# 16                                  [commandhandling]

# %% [markdown]
# ### Packages that are used by multiple artifacts
#
# #### Table 6
# - List the top 20 packages that only use a few (compared to all existing) types of another package

# %%
queryCypherToDataFrame("../cypher/Package_Usage/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher").head(20)
# Out:
#                 artifactName dependentArtifactName  \
# 0            axon-test-4.7.5  axon-messaging-4.7.5
# 1   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 2       axon-modelling-4.7.5  axon-messaging-4.7.5
# 3       axon-modelling-4.7.5  axon-messaging-4.7.5
# 4   axon-eventsourcing-4.7.5  axon-modelling-4.7.5
# 5   axon-eventsourcing-4.7.5  axon-modelling-4.7.5
# 6            axon-test-4.7.5  axon-messaging-4.7.5
# 7   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 8       axon-modelling-4.7.5  axon-messaging-4.7.5
# 9       axon-modelling-4.7.5  axon-messaging-4.7.5
# 10           axon-test-4.7.5  axon-messaging-4.7.5
# 11           axon-test-4.7.5  axon-messaging-4.7.5
# 12  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 13  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 14  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 15  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 16  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 17  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 18  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 19           axon-test-4.7.5  axon-modelling-4.7.5
#
#                                           packageName  \
# 0                     org.axonframework.test.matchers
# 1        org.axonframework.eventsourcing.snapshotting
# 2          org.axonframework.modelling.saga.metamodel
# 3          org.axonframework.modelling.saga.metamodel
# 4   org.axonframework.eventsourcing.conflictresolu...
# 5     org.axonframework.eventsourcing.eventstore.jdbc
# 6               org.axonframework.test.eventscheduler
# 7   org.axonframework.eventsourcing.conflictresolu...
# 8                 org.axonframework.modelling.command
# 9       org.axonframework.modelling.command.legacyjpa
# 10                             org.axonframework.test
# 11                    org.axonframework.test.matchers
# 12  org.axonframework.eventsourcing.conflictresolu...
# 13         org.axonframework.eventsourcing.eventstore
# 14         org.axonframework.eventsourcing.eventstore
# 15    org.axonframework.eventsourcing.eventstore.jdbc
# 16     org.axonframework.eventsourcing.eventstore.jpa
# 17  org.axonframework.eventsourcing.eventstore.leg...
# 18  org.axonframework.eventsourcing.eventstore.jdb...
# 19                       org.axonframework.test.utils
#
#                       dependentPackage.fqn  dependentTypes  \
# 0          org.axonframework.eventhandling               1
# 1          org.axonframework.eventhandling               1
# 2          org.axonframework.eventhandling               1
# 3   org.axonframework.messaging.annotation               1
# 4      org.axonframework.modelling.command               1
# 5      org.axonframework.modelling.command               1
# 6          org.axonframework.eventhandling               2
# 7          org.axonframework.eventhandling               2
# 8          org.axonframework.eventhandling               2
# 9          org.axonframework.eventhandling               2
# 10             org.axonframework.messaging               1
# 11             org.axonframework.messaging               1
# 12             org.axonframework.messaging               1
# 13             org.axonframework.messaging               1
# 14         org.axonframework.serialization               1
# 15         org.axonframework.serialization               1
# 16         org.axonframework.serialization               1
# 17         org.axonframework.serialization               1
# 18         org.axonframework.eventhandling               3
# 19        org.axonframework.modelling.saga               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                      93             0.010753
# 1                      93             0.010753
# 2                      93             0.010753
# 3                      54             0.018519
# 4                      51             0.019608
# 5                      51             0.019608
# 6                      93             0.021505
# 7                      93             0.021505
# 8                      93             0.021505
# 9                      93             0.021505
# 10                     35             0.028571
# 11                     35             0.028571
# 12                     35             0.028571
# 13                     35             0.028571
# 14                     34             0.029412
# 15                     34             0.029412
# 16                     34             0.029412
# 17                     34             0.029412
# 18                     93             0.032258
# 19                     30             0.033333
#
#                                    dependentTypeNames
# 0      [org.axonframework.eventhandling.EventMessage]
# 1   [org.axonframework.eventhandling.DomainEventData]
# 2      [org.axonframework.eventhandling.EventMessage]
# 3   [org.axonframework.messaging.annotation.Messag...
# 4   [org.axonframework.modelling.command.Conflicti...
# 5   [org.axonframework.modelling.command.Concurren...
# 6   [org.axonframework.eventhandling.GenericEventM...
# 7   [org.axonframework.eventhandling.DomainEventMe...
# 8   [org.axonframework.eventhandling.EventBus, org...
# 9   [org.axonframework.eventhandling.EventBus, org...
# 10              [org.axonframework.messaging.Message]
# 11              [org.axonframework.messaging.Message]
# 12              [org.axonframework.messaging.Message]
# 13  [org.axonframework.messaging.StreamableMessage...
# 14       [org.axonframework.serialization.Serializer]
# 15       [org.axonframework.serialization.Serializer]
# 16       [org.axonframework.serialization.Serializer]
# 17       [org.axonframework.serialization.Serializer]
# 18  [org.axonframework.eventhandling.DomainEventMe...
# 19  [org.axonframework.modelling.saga.SimpleResour...
