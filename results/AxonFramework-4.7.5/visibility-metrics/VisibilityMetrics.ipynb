# %% [markdown]
# # Visibility Metrics for Java with Neo4j
# <br>
#
# ### References
# - [Visibility Metrics and the Importance of Hiding Things](https://dzone.com/articles/visibility-metrics-and-the-importance-of-hiding-th)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Controlling Access to Members of a Class](https://docs.oracle.com/javase/tutorial/java/javaOO/accesscontrol.html)
# - [py2neo](https://py2neo.org/2021.1/)

# %%
import os
import matplotlib.pyplot as plot
from py2neo import Graph

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.
graph = Graph("bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))

# %%
def getCypherQueryFromFile(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def queryCypherToDataFrame(cypherFileName):
    return graph.run(getCypherQueryFromFile(cypherFileName)).to_data_frame()

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Artifacts
#
# ### Table 1
#
# - List all the artifacts this notebook is based on

# %%
queryCypherToDataFrame("../cypher/List_all_existing_artifacts.cypher")
# Out:
#                    artifactName  packages  types
# 0  axon-eventsourcing-4.7.5.jar         9    130
# 1      axon-modelling-4.7.5.jar        10    149
# 2  axon-configuration-4.7.5.jar         1     39
# 3      axon-messaging-4.7.5.jar        61    729
# 4      axon-disruptor-4.7.5.jar         1     22
# 5           axon-test-4.7.5.jar         8     85

# %% [markdown]
# ## Relative Visibility Of Types
#
# A Java class or interface may be declared with the modifier public, in which case it is visible to all classes everywhere. If a class or interface has no modifier (the default, also known as package-private), it is visible only within its own package.
#
# The relative visibility is the number of inner components that are visible outside (public) divided by the number of all types:
#
# $$ relative visibility = \frac{public\:types}{all\:types} $$
#
# Using package protected types is one of many ways to improve encapsulation and implementation detail hiding.
#
# ### How to apply the results
#
# The relative visibility is between zero (all types are package protected) and one (all types are public). A value lower than one means that there are types that are declared package protected. The lower the value is, the better implementation details are hidden.
#
# Non public classes can't be accessed from another package so they can be changed without affecting code in other packages. They clearly indicate functionality that only belongs to one package. This also motivates to use more classes and to split up code into smaller pieces with a single responsibility and reason to change.
#
# ### Table 1
#
# - Show relative visibility statistics aggregated for all packages per artifact

# %%
queryCypherToDataFrame("../cypher/Visibility/Global_relative_visibility_statistics_for_types.cypher")
# Out:
#                    artifact  all  public       min       max   average  \
# 0  axon-configuration-4.7.5   39      26  0.666667  0.666667  0.666667
# 1      axon-disruptor-4.7.5   22       9  0.409091  0.409091  0.409091
# 2  axon-eventsourcing-4.7.5  130      95  0.500000  1.000000  0.769159
# 3      axon-messaging-4.7.5  729     592  0.100000  1.000000  0.861211
# 4      axon-modelling-4.7.5  149     128  0.500000  1.000000  0.804762
# 5           axon-test-4.7.5   85      64  0.473684  1.000000  0.812336
#
#    percentile25  percentile50  percentile75  percentile90
# 0      0.666667      0.666667      0.666667      0.666667
# 1      0.409091      0.409091      0.409091      0.409091
# 2      0.612903      0.785714      1.000000      1.000000
# 3      0.750000      0.947368      1.000000      1.000000
# 4      0.737500      0.813187      0.887255      1.000000
# 5      0.650000      0.879167      1.000000      1.000000

# %% [markdown]
# ### Table 2
#
# - List the top 40 packages and their artifact with the highest relative visibility

# %%
queryCypherToDataFrame("../cypher/Visibility/Relative_visibility_public_types_to_all_types_per_package.cypher").head(50)
# Out:
#                 artifactName  \
# 0       axon-modelling-4.7.5
# 1   axon-eventsourcing-4.7.5
# 2       axon-messaging-4.7.5
# 3       axon-messaging-4.7.5
# 4   axon-eventsourcing-4.7.5
# 5       axon-messaging-4.7.5
# 6       axon-messaging-4.7.5
# 7       axon-messaging-4.7.5
# 8       axon-messaging-4.7.5
# 9       axon-messaging-4.7.5
# 10      axon-messaging-4.7.5
# 11      axon-messaging-4.7.5
# 12      axon-messaging-4.7.5
# 13      axon-messaging-4.7.5
# 14      axon-messaging-4.7.5
# 15      axon-messaging-4.7.5
# 16      axon-messaging-4.7.5
# 17      axon-messaging-4.7.5
# 18           axon-test-4.7.5
# 19      axon-messaging-4.7.5
# 20      axon-messaging-4.7.5
# 21      axon-messaging-4.7.5
# 22      axon-messaging-4.7.5
# 23      axon-messaging-4.7.5
# 24      axon-messaging-4.7.5
# 25           axon-test-4.7.5
# 26  axon-eventsourcing-4.7.5
# 27      axon-messaging-4.7.5
# 28      axon-messaging-4.7.5
# 29      axon-messaging-4.7.5
# 30      axon-messaging-4.7.5
# 31      axon-messaging-4.7.5
# 32      axon-messaging-4.7.5
# 33      axon-modelling-4.7.5
# 34           axon-test-4.7.5
# 35      axon-messaging-4.7.5
# 36      axon-messaging-4.7.5
# 37      axon-messaging-4.7.5
# 38           axon-test-4.7.5
# 39      axon-messaging-4.7.5
# 40      axon-messaging-4.7.5
# 41      axon-messaging-4.7.5
# 42      axon-messaging-4.7.5
# 43      axon-messaging-4.7.5
# 44      axon-messaging-4.7.5
# 45      axon-modelling-4.7.5
# 46      axon-modelling-4.7.5
# 47      axon-messaging-4.7.5
# 48  axon-eventsourcing-4.7.5
# 49      axon-modelling-4.7.5
#
#                              fullQualifiedPackageName         packageName  \
# 0                    org.axonframework.modelling.saga                saga
# 1   org.axonframework.eventsourcing.eventstore.jdb...          statements
# 2     org.axonframework.serialization.upcasting.event               event
# 3                         org.axonframework.lifecycle           lifecycle
# 4   org.axonframework.eventsourcing.conflictresolu...  conflictresolution
# 5                   org.axonframework.common.property            property
# 6            org.axonframework.messaging.interceptors        interceptors
# 7           org.axonframework.messaging.responsetypes       responsetypes
# 8   org.axonframework.commandhandling.distributed....       commandfilter
# 9                org.axonframework.serialization.json                json
# 10         org.axonframework.eventhandling.tokenstore          tokenstore
# 11                org.axonframework.serialization.xml                 xml
# 12               org.axonframework.tracing.attributes          attributes
# 13  org.axonframework.eventhandling.scheduling.quartz              quartz
# 14          org.axonframework.serialization.upcasting           upcasting
# 15         org.axonframework.serialization.converters          converters
# 16            org.axonframework.eventhandling.gateway             gateway
# 17       org.axonframework.queryhandling.registration        registration
# 18              org.axonframework.test.eventscheduler      eventscheduler
# 19        org.axonframework.commandhandling.callbacks           callbacks
# 20            org.axonframework.messaging.correlation         correlation
# 21                       org.axonframework.common.jpa                 jpa
# 22     org.axonframework.eventhandling.tokenstore.jpa                 jpa
# 23                 org.axonframework.common.legacyjpa           legacyjpa
# 24                  org.axonframework.deadline.quartz              quartz
# 25                    org.axonframework.test.deadline            deadline
# 26       org.axonframework.eventsourcing.snapshotting        snapshotting
# 27                 org.axonframework.deadline.jobrunr             jobrunr
# 28  org.axonframework.eventhandling.scheduling.job...             jobrunr
# 29         org.axonframework.eventhandling.scheduling          scheduling
# 30                             org.axonframework.util                util
# 31  org.axonframework.eventhandling.tokenstore.leg...           legacyjpa
# 32  org.axonframework.messaging.interceptors.legac...    legacyvalidation
# 33      org.axonframework.modelling.command.legacyjpa           legacyjpa
# 34                      org.axonframework.test.server              server
# 35                    org.axonframework.common.digest              digest
# 36       org.axonframework.eventhandling.interceptors        interceptors
# 37                        org.axonframework.common.io                  io
# 38                    org.axonframework.test.matchers            matchers
# 39             org.axonframework.messaging.deadletter          deadletter
# 40      org.axonframework.commandhandling.distributed         distributed
# 41                        org.axonframework.messaging           messaging
# 42                  org.axonframework.commandhandling     commandhandling
# 43    org.axonframework.eventhandling.tokenstore.jdbc                jdbc
# 44     org.axonframework.eventhandling.deadletter.jpa                 jpa
# 45   org.axonframework.modelling.saga.repository.jdbc                jdbc
# 46                org.axonframework.modelling.command             command
# 47                           org.axonframework.common              common
# 48     org.axonframework.eventsourcing.eventstore.jpa                 jpa
# 49    org.axonframework.modelling.saga.repository.jpa                 jpa
#
#     publicTypes  allTypes  relativeVisibility
# 0            30        30            1.000000
# 1            15        15            1.000000
# 2            12        12            1.000000
# 3            10        10            1.000000
# 4             9         9            1.000000
# 5             9         9            1.000000
# 6             8         8            1.000000
# 7             8         8            1.000000
# 8             7         7            1.000000
# 9             7         7            1.000000
# 10            7         7            1.000000
# 11            7         7            1.000000
# 12            6         6            1.000000
# 13            6         6            1.000000
# 14            6         6            1.000000
# 15            5         5            1.000000
# 16            5         5            1.000000
# 17            5         5            1.000000
# 18            5         5            1.000000
# 19            4         4            1.000000
# 20            4         4            1.000000
# 21            4         4            1.000000
# 22            4         4            1.000000
# 23            4         4            1.000000
# 24            4         4            1.000000
# 25            4         4            1.000000
# 26            3         3            1.000000
# 27            3         3            1.000000
# 28            3         3            1.000000
# 29            3         3            1.000000
# 30            3         3            1.000000
# 31            2         2            1.000000
# 32            2         2            1.000000
# 33            2         2            1.000000
# 34            2         2            1.000000
# 35            1         1            1.000000
# 36            1         1            1.000000
# 37            1         1            1.000000
# 38           23        24            0.958333
# 39           18        19            0.947368
# 40           24        26            0.923077
# 41           32        35            0.914286
# 42           26        29            0.896552
# 43            8         9            0.888889
# 44            8         9            0.888889
# 45            8         9            0.888889
# 46           45        51            0.882353
# 47           24        28            0.857143
# 48            6         7            0.857143
# 49            6         7            0.857143
