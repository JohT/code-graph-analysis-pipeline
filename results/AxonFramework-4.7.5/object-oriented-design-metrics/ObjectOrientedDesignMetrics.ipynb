# %% [markdown]
# # Object Oriented Design Quality Metrics for Java with Neo4j
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [jqassistant](https://jqassistant.org)
# - [notebook walks through examples for integrating various packages with Neo4j](https://nicolewhite.github.io/neo4j-jupyter/hello-world.html)
# - [OO Design Quality Metrics](https://api.semanticscholar.org/CorpusID:18246616)
# - [py2neo](https://py2neo.org/2021.1/)

# %%
import os
import matplotlib.pyplot as plot
from py2neo import Graph

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.
graph = Graph("bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))

# %%
def getCypherQueryFromFile(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def queryCypherToDataFrame(cypherFileName):
    return graph.run(getCypherQueryFromFile(cypherFileName)).to_data_frame()

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Artifacts
#
# #### Table 1
#
# - List all the artifacts this notebook is based on

# %%
queryCypherToDataFrame("../cypher/List_all_existing_artifacts.cypher")
# Out:
#                    artifactName  packages  types
# 0      axon-disruptor-4.7.5.jar         1     22
# 1  axon-eventsourcing-4.7.5.jar         9    130
# 2           axon-test-4.7.5.jar         8     85
# 3      axon-messaging-4.7.5.jar        61    729
# 4      axon-modelling-4.7.5.jar        10    149
# 5  axon-configuration-4.7.5.jar         1     39

# %% [markdown]
# ## Incoming Dependencies
#
# Incoming dependencies are also denoted as "Fan-in", "Afferent Couplings" or "in-degree".
# These are the ones that use the listed package.
#
# If these packages get changed, the incoming dependencies might be affected by the change. The more incoming dependencies, the harder it gets to change the code without the need to adapt the dependent code (“rigid code”). Even worse, it might affect the behavior of the dependent code in an unwanted way (“fragile code”).
#
# #### Table 2
# - Show the top 20 packages with the most incoming dependencies
# - Set the "incomingDependencies" properties on Package nodes.

# %%
queryCypherToDataFrame("../cypher/Metrics/Set_Incoming_Package_Dependencies.cypher").head(20)
# Out:
#                                         packageName  incomingDependencies  \
# 0                       org.axonframework.messaging                  8245
# 1                   org.axonframework.eventhandling                  4324
# 2                 org.axonframework.commandhandling                  1440
# 3                   org.axonframework.serialization                  1057
# 4            org.axonframework.messaging.annotation                  1008
# 5                          org.axonframework.common                   858
# 6              org.axonframework.common.transaction                   276
# 7            org.axonframework.messaging.unitofwork                   246
# 8                  org.axonframework.modelling.saga                   242
# 9   org.axonframework.eventsourcing.eventstore.jdbc                   218
# 10              org.axonframework.modelling.command                   213
# 11                     org.axonframework.monitoring                   189
# 12                  org.axonframework.queryhandling                   175
# 13                        org.axonframework.tracing                   173
# 14       org.axonframework.eventsourcing.eventstore                   166
# 15                       org.axonframework.deadline                   159
# 16           org.axonframework.messaging.deadletter                   135
# 17                  org.axonframework.eventsourcing                   128
# 18                         org.axonframework.config                   115
# 19        org.axonframework.commandhandling.gateway                    94
#
#     incomingDependenciesWeight  incomingDependentTypes  \
# 0                        31931                     304
# 1                        27485                     277
# 2                         6444                     118
# 3                         5520                     124
# 4                         5191                     146
# 5                         2003                     308
# 6                         1060                      67
# 7                         1367                      78
# 8                         1482                      57
# 9                         1404                      26
# 10                         824                      71
# 11                         641                      39
# 12                         935                      47
# 13                         712                      65
# 14                         805                      59
# 15                        1331                      32
# 16                         978                      28
# 17                         630                      40
# 18                        1483                      34
# 19                         387                      34
#
#     incomingDependentInterfaces  incomingDependentPackages  \
# 0                            64                         50
# 1                            52                         44
# 2                            18                         18
# 3                            15                         30
# 4                            18                         25
# 5                            12                         74
# 6                             5                         24
# 7                             5                         34
# 8                            11                         10
# 9                            14                          2
# 10                            8                         10
# 11                            6                         10
# 12                           10                          9
# 13                            4                         16
# 14                            5                         10
# 15                            8                         11
# 16                            7                          5
# 17                            6                          5
# 18                            0                          1
# 19                            1                          3
#
#     incomingDependentArtifacts
# 0                            6
# 1                            5
# 2                            6
# 3                            4
# 4                            6
# 5                            6
# 6                            4
# 7                            6
# 8                            3
# 9                            1
# 10                           5
# 11                           4
# 12                           2
# 13                           4
# 14                           4
# 15                           4
# 16                           2
# 17                           4
# 18                           1
# 19                           3

# %% [markdown]
# ## Outgoing Dependencies
#
# Outcoming dependencies are also denoted as "Fan-out", "Efferent Couplings" or "out-degree".
# These are the ones that are used by the listed package.
#
# Code from other packages and libraries you’re depending on (outgoing) might change over time. The more outgoing changes, the more likely and frequently code changes are needed. This involves time and effort which can be reduced by automation of tests and version updates. Automated tests are crucial to reveal updates, that change the behavior of the code unexpectedly (“fragile code”). As soon as more effort is required, keeping up becomes difficult (“rigid code”). Not being able to use a newer version might not only restrict features, it can get problematic if there are security issues. This might force you to take “fast but ugly” solutions into account which further increases technical dept.
#
# #### Table 3
#
# - Show the top 20 packages with the most outgoing dependencies
# - Set the "outgoingDependencies" properties on Package nodes.

# %%
queryCypherToDataFrame("../cypher/Metrics/Set_Outgoing_Package_Dependencies.cypher").head(20)
# Out:
#                                           packageName  outgoingDependencies  \
# 0                            org.axonframework.config                  7942
# 1                     org.axonframework.eventhandling                  1545
# 2         org.axonframework.disruptor.commandhandling                  1419
# 3                         org.axonframework.test.saga                  1375
# 4     org.axonframework.eventsourcing.eventstore.jdbc                  1340
# 5                     org.axonframework.queryhandling                  1108
# 6              org.axonframework.eventhandling.pooled                  1022
# 7                     org.axonframework.eventsourcing                   976
# 8                    org.axonframework.test.aggregate                   859
# 9                   org.axonframework.commandhandling                   642
# 10                org.axonframework.modelling.command                   631
# 11      org.axonframework.commandhandling.distributed                   603
# 12         org.axonframework.eventsourcing.eventstore                   603
# 13     org.axonframework.modelling.command.inspection                   525
# 14                  org.axonframework.deadline.quartz                   481
# 15          org.axonframework.commandhandling.gateway                   420
# 16                   org.axonframework.modelling.saga                   386
# 17  org.axonframework.eventsourcing.eventstore.leg...                   375
# 18                 org.axonframework.deadline.jobrunr                   348
# 19                         org.axonframework.deadline                   347
#
#     outgoingDependentTypes  outgoingDependentInterfaces  \
# 0                      212                           84
# 1                      151                           54
# 2                       85                           31
# 3                       79                           26
# 4                       51                           27
# 5                       78                           28
# 6                       57                           26
# 7                       91                           31
# 8                       64                           33
# 9                       70                           28
# 10                      79                           28
# 11                      67                           23
# 12                      64                           25
# 13                      63                           23
# 14                      38                           18
# 15                      58                           11
# 16                      58                           21
# 17                      47                           17
# 18                      31                           15
# 19                      43                           21
#
#     outgoingDependentPackages  outgoingDependentArtifacts  \
# 0                          46                           5
# 1                          16                           1
# 2                          14                           4
# 3                          17                           3
# 4                          11                           3
# 5                          11                           1
# 6                          12                           1
# 7                          16                           3
# 8                          16                           4
# 9                           9                           1
# 10                         15                           2
# 11                         11                           1
# 12                         16                           3
# 13                         10                           2
# 14                         10                           1
# 15                         10                           1
# 16                          9                           2
# 17                         15                           2
# 18                          8                           1
# 19                          8                           1
#
#     outgoingDependenciesWeight
# 0                        34762
# 1                         7714
# 2                         7130
# 3                         4837
# 4                         8129
# 5                         6955
# 6                         5590
# 7                         4142
# 8                         3578
# 9                         2295
# 10                        2630
# 11                        2368
# 12                        2501
# 13                        2601
# 14                        2187
# 15                        1536
# 16                        1799
# 17                        1870
# 18                        1611
# 19                        1281

# %% [markdown]
# ## Instability
#
# $$ Instability = \frac{Outgoing\:Dependencies}{Outgoing\:Dependencies + Incoming\:Dependencies} $$
#
# *Instability* is expressed as the ratio of the number of outgoing dependencies of a module (i.e., the number of packages that depend on it) to the total number of dependencies (i.e., the sum of incoming and outgoing dependencies).
#
# Small values near zero indicate low *Instability*. With no outgoing but some incoming dependencies the Instability is zero which is denoted as maximally stable. Such code units are more rigid and difficult to change without impacting other parts of the system. If they are changed less because of that, they are considered stable.
#
# Conversely, high values approaching one indicate high *Instability*. With some outgoing dependencies but no incoming ones the *Instability* is denoted as maximally unstable. Such code units are easier to change without affecting other modules, making them more flexible and less prone to cascading changes throughout the system. If they are changed more often because of that, they are considered unstable.
#
# #### Table 4
#
# - Show the top 20 packages with the lowest *Instability*

# %%
queryCypherToDataFrame("../cypher/Metrics/Calculate_and_set_Instability_outgoing_incoming_Dependencies.cypher").head(20)
# Out:
#                                          p.fqn           p.name  instability  \
# 0                  org.axonframework.messaging        messaging     0.013756
# 1         org.axonframework.common.transaction      transaction     0.021277
# 2                     org.axonframework.common           common     0.026107
# 3                 org.axonframework.monitoring       monitoring     0.100000
# 4   org.axonframework.eventhandling.scheduling       scheduling     0.111111
# 5          org.axonframework.common.annotation       annotation     0.120000
# 6              org.axonframework.serialization    serialization     0.138549
# 7                  org.axonframework.lifecycle        lifecycle     0.138889
# 8              org.axonframework.common.stream           stream     0.147059
# 9       org.axonframework.messaging.annotation       annotation     0.229947
# 10             org.axonframework.eventhandling    eventhandling     0.263248
# 11                org.axonframework.common.jpa              jpa     0.272727
# 12          org.axonframework.common.legacyjpa        legacyjpa     0.300000
# 13           org.axonframework.commandhandling  commandhandling     0.308357
# 14   org.axonframework.serialization.upcasting        upcasting     0.312500
# 15      org.axonframework.messaging.unitofwork       unitofwork     0.333333
# 16               org.axonframework.common.lock             lock     0.352113
# 17     org.axonframework.messaging.correlation      correlation     0.358974
# 18  org.axonframework.eventhandling.tokenstore       tokenstore     0.378378
# 19           org.axonframework.common.property         property     0.394737
#
#     instabilityTypes  instabilityInterfaces  instabilityPackages  \
# 0           0.092537               0.189873             0.107143
# 1           0.056338               0.000000             0.040000
# 2           0.046440               0.000000             0.013333
# 3           0.152174               0.333333             0.230769
# 4           0.166667               0.000000             0.250000
# 5           0.120000               0.000000             0.166667
# 6           0.261905               0.318182             0.230769
# 7           0.259259               0.000000             0.214286
# 8           0.166667               0.000000             0.125000
# 9           0.314554               0.419355             0.218750
# 10          0.352804               0.509434             0.266667
# 11          0.250000               1.000000             0.300000
# 12          0.277778               1.000000             0.333333
# 13          0.372340               0.608696             0.333333
# 14          0.083333               0.000000             0.333333
# 15          0.204082               0.583333             0.128205
# 16          0.363636               0.500000             0.222222
# 17          0.230769               0.400000             0.333333
# 18          0.342105               0.571429             0.333333
# 19          0.380952               1.000000             0.285714
#
#     instabilityArtifacts  p.outgoingDependencies  p.incomingDependencies  \
# 0               0.142857                     115                    8245
# 1               0.200000                       6                     276
# 2               0.142857                      23                     858
# 3               0.200000                      21                     189
# 4               0.250000                       2                      16
# 5               0.250000                       3                      22
# 6               0.200000                     170                    1057
# 7               0.250000                      10                      62
# 8               0.250000                       5                      29
# 9               0.142857                     301                    1008
# 10              0.166667                    1545                    4324
# 11              0.200000                       6                      16
# 12              0.250000                       6                      14
# 13              0.142857                     642                    1440
# 14              0.500000                       5                      11
# 15              0.142857                     123                     246
# 16              0.200000                      25                      46
# 17              0.333333                      14                      25
# 18              0.333333                      42                      69
# 19              0.333333                      15                      23
#
#     p.outgoingDependentTypes  p.incomingDependentTypes  \
# 0                         31                       304
# 1                          4                        67
# 2                         15                       308
# 3                          7                        39
# 4                          2                        10
# 5                          3                        22
# 6                         44                       124
# 7                          7                        20
# 8                          3                        15
# 9                         67                       146
# 10                       151                       277
# 11                         5                        15
# 12                         5                        13
# 13                        70                       118
# 14                         1                        11
# 15                        20                        78
# 16                        12                        21
# 17                         3                        10
# 18                        13                        25
# 19                         8                        13
#
#     p.outgoingDependentInterfaces  p.incomingDependentInterfaces  \
# 0                              15                             64
# 1                               0                              5
# 2                               0                             12
# 3                               3                              6
# 4                               0                              2
# 5                               0                              0
# 6                               7                             15
# 7                               0                              3
# 8                               0                              2
# 9                              13                             18
# 10                             54                             52
# 11                              2                              0
# 12                              2                              0
# 13                             28                             18
# 14                              0                              1
# 15                              7                              5
# 16                              2                              2
# 17                              2                              3
# 18                              4                              3
# 19                              1                              0
#
#     p.outgoingDependentPackages  p.incomingDependentPackages  \
# 0                             6                           50
# 1                             1                           24
# 2                             1                           74
# 3                             3                           10
# 4                             2                            6
# 5                             2                           10
# 6                             9                           30
# 7                             3                           11
# 8                             1                            7
# 9                             7                           25
# 10                           16                           44
# 11                            3                            7
# 12                            3                            6
# 13                            9                           18
# 14                            1                            2
# 15                            5                           34
# 16                            2                            7
# 17                            2                            4
# 18                            4                            8
# 19                            2                            5
#
#     p.outgoingDependentArtifacts  p.incomingDependentArtifacts
# 0                              1                             6
# 1                              1                             4
# 2                              1                             6
# 3                              1                             4
# 4                              1                             3
# 5                              1                             3
# 6                              1                             4
# 7                              1                             3
# 8                              1                             3
# 9                              1                             6
# 10                             1                             5
# 11                             1                             4
# 12                             1                             3
# 13                             1                             6
# 14                             1                             1
# 15                             1                             6
# 16                             1                             4
# 17                             1                             2
# 18                             1                             2
# 19                             1                             2

# %% [markdown]
# ## Abstractness
#
# $$ Abstractness = \frac{abstract\:classes\:in\:category}{total\:number\:of\:classes\:in\:category} $$
#
# Package *Abstractness* is expressed as the ratio of the number of abstract classes and interfaces to the total number of classes of a package.
#
# Zero *Abstractness* means that there are no abstract types or interfaces in the package. On the other hand, a value of one means that there are only abstract types.
#
# #### Table 5
#
# - Show the top 30 packages with the lowest *Abstractness*

# %%
queryCypherToDataFrame("../cypher/Metrics/Calculate_and_set_Abstractness_including_Counts.cypher").head(30)
# Out:
#                              fullQualifiedPackageName       packageName  \
# 0   org.axonframework.eventsourcing.eventstore.leg...         legacyjpa
# 1   org.axonframework.commandhandling.distributed....     commandfilter
# 2                org.axonframework.serialization.json              json
# 3                 org.axonframework.serialization.xml               xml
# 4                org.axonframework.tracing.attributes        attributes
# 5          org.axonframework.serialization.converters        converters
# 6         org.axonframework.commandhandling.callbacks         callbacks
# 7                   org.axonframework.deadline.quartz            quartz
# 8          org.axonframework.eventhandling.deadletter        deadletter
# 9     org.axonframework.eventhandling.scheduling.java              java
# 10     org.axonframework.eventhandling.tokenstore.jpa               jpa
# 11                 org.axonframework.deadline.jobrunr           jobrunr
# 12  org.axonframework.eventhandling.scheduling.job...           jobrunr
# 13                             org.axonframework.util              util
# 14  org.axonframework.modelling.saga.repository.le...         legacyjpa
# 15  org.axonframework.eventsourcing.eventstore.inm...          inmemory
# 16                      org.axonframework.test.server            server
# 17  org.axonframework.eventhandling.tokenstore.inm...          inmemory
# 18  org.axonframework.eventhandling.tokenstore.leg...         legacyjpa
# 19  org.axonframework.messaging.interceptors.legac...  legacyvalidation
# 20      org.axonframework.modelling.command.legacyjpa         legacyjpa
# 21  org.axonframework.modelling.saga.repository.in...          inmemory
# 22                    org.axonframework.common.digest            digest
# 23                        org.axonframework.common.io                io
# 24       org.axonframework.eventhandling.interceptors      interceptors
# 25        org.axonframework.disruptor.commandhandling   commandhandling
# 26     org.axonframework.eventhandling.deadletter.jpa               jpa
# 27    org.axonframework.eventhandling.tokenstore.jdbc              jdbc
# 28   org.axonframework.modelling.saga.repository.jdbc              jdbc
# 29                    org.axonframework.test.matchers          matchers
#
#     abstractness  numberAbstractTypes  numberTypes
# 0       0.000000                    0           10
# 1       0.000000                    0            7
# 2       0.000000                    0            7
# 3       0.000000                    0            7
# 4       0.000000                    0            6
# 5       0.000000                    0            5
# 6       0.000000                    0            4
# 7       0.000000                    0            4
# 8       0.000000                    0            4
# 9       0.000000                    0            4
# 10      0.000000                    0            4
# 11      0.000000                    0            3
# 12      0.000000                    0            3
# 13      0.000000                    0            3
# 14      0.000000                    0            3
# 15      0.000000                    0            2
# 16      0.000000                    0            2
# 17      0.000000                    0            2
# 18      0.000000                    0            2
# 19      0.000000                    0            2
# 20      0.000000                    0            2
# 21      0.000000                    0            2
# 22      0.000000                    0            1
# 23      0.000000                    0            1
# 24      0.000000                    0            1
# 25      0.045455                    1           22
# 26      0.111111                    1            9
# 27      0.111111                    1            9
# 28      0.111111                    1            9
# 29      0.125000                    3           24

# %% [markdown]
# ## Distance from the main sequence
#
# The *main sequence* is a imaginary line that represents a good compromise between *Abstractness* and *Instability*. A high distance to this line may indicate problems. For example is very *stable* (rigid) code with low abstractness hard to change.
#
# Read more details on that in [OO Design Quality Metrics](https://api.semanticscholar.org/CorpusID:18246616) and [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html).
#
# #### Table 6
#
# - Show the top 20 packages with the highest distance from the "main sequence"

# %%
instabilityPerAbstractness = queryCypherToDataFrame("../cypher/Metrics/Calculate_distance_between_abstractness_and_instability.cypher")
instabilityPerAbstractness.head(20)
# Out:
#                 artifactName  \
# 0            axon-test-4.7.5
# 1       axon-messaging-4.7.5
# 2   axon-eventsourcing-4.7.5
# 3       axon-messaging-4.7.5
# 4       axon-messaging-4.7.5
# 5       axon-messaging-4.7.5
# 6       axon-messaging-4.7.5
# 7       axon-messaging-4.7.5
# 8       axon-messaging-4.7.5
# 9       axon-messaging-4.7.5
# 10      axon-messaging-4.7.5
# 11      axon-messaging-4.7.5
# 12  axon-configuration-4.7.5
# 13           axon-test-4.7.5
# 14      axon-messaging-4.7.5
# 15      axon-messaging-4.7.5
# 16      axon-messaging-4.7.5
# 17      axon-messaging-4.7.5
# 18      axon-messaging-4.7.5
# 19      axon-messaging-4.7.5
#
#                              fullQualifiedPackageName    packageName  \
# 0                       org.axonframework.test.server         server
# 1                         org.axonframework.common.io             io
# 2   org.axonframework.eventsourcing.eventstore.jdb...     statements
# 3                     org.axonframework.serialization  serialization
# 4                        org.axonframework.monitoring     monitoring
# 5                     org.axonframework.common.digest         digest
# 6              org.axonframework.messaging.annotation     annotation
# 7                org.axonframework.common.transaction    transaction
# 8                        org.axonframework.common.jpa            jpa
# 9                       org.axonframework.common.lock           lock
# 10                 org.axonframework.common.legacyjpa      legacyjpa
# 11            org.axonframework.eventhandling.gateway        gateway
# 12                           org.axonframework.config         config
# 13                    org.axonframework.test.matchers       matchers
# 14            org.axonframework.messaging.correlation    correlation
# 15                        org.axonframework.messaging      messaging
# 16             org.axonframework.messaging.unitofwork     unitofwork
# 17                org.axonframework.serialization.xml            xml
# 18                          org.axonframework.tracing        tracing
# 19         org.axonframework.eventhandling.tokenstore     tokenstore
#
#     distance  abstractness  instability  typesInPackage
# 0   1.000000      0.000000     0.000000               2
# 1   1.000000      0.000000     0.000000               1
# 2   0.727273      1.000000     0.727273              15
# 3   0.567333      0.294118     0.138549              34
# 4   0.566667      0.333333     0.100000               6
# 5   0.500000      0.000000     0.500000               1
# 6   0.492276      0.277778     0.229947              54
# 7   0.478723      0.500000     0.021277               4
# 8   0.477273      0.250000     0.272727               4
# 9   0.466069      0.181818     0.352113              11
# 10  0.450000      0.250000     0.300000               4
# 11  0.425397      0.600000     0.825397               5
# 12  0.421624      0.435897     0.985727              39
# 13  0.403302      0.125000     0.471698              24
# 14  0.391026      0.250000     0.358974               4
# 15  0.386244      0.600000     0.013756              35
# 16  0.380952      0.285714     0.333333              14
# 17  0.377778      0.000000     0.622222               7
# 18  0.364218      0.222222     0.413559              18
# 19  0.335907      0.285714     0.378378               7

# %% [markdown]
# ### *Abstractness* vs. *Instability* Plot with "Main Sequence" line as reference
#
# #### Figure 1
# - Plot *Abstractness* vs. *Instability* of all packages
# - Draw the "main sequence" as dashed green line
# - Scale the packages by the number of types they contain
# - Color the packages by their distance to the "main sequence" (blue=near, red=far)

# %%
# Function that returns the number of past (index smaller than given index) rows 
# with the same value in columnName1 and columnName2
# If there was a row with the same columnName1 and columnName2 values
def countPastEntriesWithSameValues(dataFrame, index, columnName1, columnName2):
    columnValue1 = dataFrame[columnName1][index]
    columnValue2 = dataFrame[columnName2][index]
    return len(dataFrame[
        (dataFrame.index.isin(range(0, index + 1))) & 
        (dataFrame[columnName1]==columnValue1) & 
        (dataFrame[columnName2]==columnValue2)
    ]) - 1

# %%
# data points scaled by the number of types and colored by the distance to the "main sequence"
plot.scatter(
    instabilityPerAbstractness.abstractness, # x axis shows abstractness
    instabilityPerAbstractness.instability, # y axis shows instability
    s=instabilityPerAbstractness.typesInPackage * 2, # scale depends on number of contained types
    c=instabilityPerAbstractness.distance, # color depends on distance to the main sequence
    cmap='bwr' # colormap that prints high values in red and lower values in blue
)
# green "main sequence" line
plot.plot([0,1], [1,0], c='lightgreen', linestyle='dashed') 

# add the packagenames to the those with the 15 highest distance values
distanceAnnotationThreshold = instabilityPerAbstractness.distance.nlargest(15).iloc[-1]
# (variant) highest 15% (quantile) of all distance values
# distanceAnnotationThreshold = instabilityPerAbstractness.distance.quantile(0.85)
for i, name in enumerate(instabilityPerAbstractness.packageName):
    if (instabilityPerAbstractness.distance[i] >= distanceAnnotationThreshold):
        x_position = instabilityPerAbstractness.abstractness[i]
        y_position = instabilityPerAbstractness.instability[i]
        # To overcome overlapping text annotations for multiple data points on the same position, 
        # entries with same position values in the past indizes are count and used to offset the y-position
        # so that multiple names are written underneath each other.
        alreadyExistingPositions = countPastEntriesWithSameValues(instabilityPerAbstractness, i, 'abstractness', 'instability')
        y_position = y_position - alreadyExistingPositions / len(instabilityPerAbstractness) * 2
        
        plot.annotate(name, (x_position, y_position), size=6)
            
plot.title('Abstractness vs. Instability ("Main Sequence")')
plot.xlabel('Abstractness')
plot.ylabel('Instability')
plot.show()
