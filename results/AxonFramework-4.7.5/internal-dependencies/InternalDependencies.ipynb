# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename : str, limit: int = 10_000):
    cypher_query_template = "{query} LIMIT {row_limit}"
    cypher_query = get_cypher_query_from_file(filename)
    cypher_query = cypher_query_template.format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Artifacts
#
# List the artifacts this notebook is based on. Different sorting variations help finding artifacts by their features and support larger code bases where the list of all artifacts gets too long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_existing_artifacts`

# %%
artifacts = query_cypher_to_data_frame("../cypher/List_all_existing_artifacts.cypher")

# %% [markdown]
# ### Table 1a - Top 30 artifacts with the highest package count

# %%
# Sort by number of packages descending
artifacts.sort_values(by=['packages','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0      axon-messaging-4.7.5.jar        61    729                     5
# 1      axon-modelling-4.7.5.jar        10    149                     4
# 2  axon-eventsourcing-4.7.5.jar         9    130                     3
# 3           axon-test-4.7.5.jar         8     85                     0
# 4  axon-configuration-4.7.5.jar         1     39                     0
# 5      axon-disruptor-4.7.5.jar         1     22                     1
#
#    outgoingDependencies
# 0                     0
# 1                     1
# 2                     2
# 3                     3
# 4                     4
# 5                     3

# %% [markdown]
# ### Table 1b - Top 30 artifacts with the highest type count

# %%
# Sort by number of types descending
artifacts.sort_values(by=['types','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0      axon-messaging-4.7.5.jar        61    729                     5
# 1      axon-modelling-4.7.5.jar        10    149                     4
# 2  axon-eventsourcing-4.7.5.jar         9    130                     3
# 3           axon-test-4.7.5.jar         8     85                     0
# 4  axon-configuration-4.7.5.jar         1     39                     0
# 5      axon-disruptor-4.7.5.jar         1     22                     1
#
#    outgoingDependencies
# 0                     0
# 1                     1
# 2                     2
# 3                     3
# 4                     4
# 5                     3

# %% [markdown]
# ### Table 1c - Top 30 artifacts with the highest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the most by other artifacts (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0      axon-messaging-4.7.5.jar        61    729                     5
# 1      axon-modelling-4.7.5.jar        10    149                     4
# 2  axon-eventsourcing-4.7.5.jar         9    130                     3
# 3      axon-disruptor-4.7.5.jar         1     22                     1
# 4  axon-configuration-4.7.5.jar         1     39                     0
# 5           axon-test-4.7.5.jar         8     85                     0
#
#    outgoingDependencies
# 0                     0
# 1                     1
# 2                     2
# 3                     3
# 4                     4
# 5                     3

# %% [markdown]
# ### Table 1d - Top 30 artifacts with the highest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the highest number of other artifacts (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0  axon-configuration-4.7.5.jar         1     39                     0
# 1      axon-disruptor-4.7.5.jar         1     22                     1
# 2           axon-test-4.7.5.jar         8     85                     0
# 3  axon-eventsourcing-4.7.5.jar         9    130                     3
# 4      axon-modelling-4.7.5.jar        10    149                     4
# 5      axon-messaging-4.7.5.jar        61    729                     5
#
#    outgoingDependencies
# 0                     4
# 1                     3
# 2                     3
# 3                     2
# 4                     1
# 5                     0

# %% [markdown]
# ### Table 1e - Top 30 artifacts with the lowest package count

# %%
# Sort by number of packages ascending
artifacts.sort_values(by=['packages','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0  axon-configuration-4.7.5.jar         1     39                     0
# 1      axon-disruptor-4.7.5.jar         1     22                     1
# 2           axon-test-4.7.5.jar         8     85                     0
# 3  axon-eventsourcing-4.7.5.jar         9    130                     3
# 4      axon-modelling-4.7.5.jar        10    149                     4
# 5      axon-messaging-4.7.5.jar        61    729                     5
#
#    outgoingDependencies
# 0                     4
# 1                     3
# 2                     3
# 3                     2
# 4                     1
# 5                     0

# %% [markdown]
# ### Table 1f - Top 30 artifacts with the lowest type count

# %%
# Sort by number of types ascending
artifacts.sort_values(by=['types','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0      axon-disruptor-4.7.5.jar         1     22                     1
# 1  axon-configuration-4.7.5.jar         1     39                     0
# 2           axon-test-4.7.5.jar         8     85                     0
# 3  axon-eventsourcing-4.7.5.jar         9    130                     3
# 4      axon-modelling-4.7.5.jar        10    149                     4
# 5      axon-messaging-4.7.5.jar        61    729                     5
#
#    outgoingDependencies
# 0                     3
# 1                     4
# 2                     3
# 3                     2
# 4                     1
# 5                     0

# %% [markdown]
# ### Table 1g - Top 30 artifacts with the lowest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the least by other artifacts (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0  axon-configuration-4.7.5.jar         1     39                     0
# 1           axon-test-4.7.5.jar         8     85                     0
# 2      axon-disruptor-4.7.5.jar         1     22                     1
# 3  axon-eventsourcing-4.7.5.jar         9    130                     3
# 4      axon-modelling-4.7.5.jar        10    149                     4
# 5      axon-messaging-4.7.5.jar        61    729                     5
#
#    outgoingDependencies
# 0                     4
# 1                     3
# 2                     3
# 3                     2
# 4                     1
# 5                     0

# %% [markdown]
# ### Table 1h - Top 30 artifacts with the lowest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the lowest number of other artifacts (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0      axon-messaging-4.7.5.jar        61    729                     5
# 1      axon-modelling-4.7.5.jar        10    149                     4
# 2  axon-eventsourcing-4.7.5.jar         9    130                     3
# 3      axon-disruptor-4.7.5.jar         1     22                     1
# 4           axon-test-4.7.5.jar         8     85                     0
# 5  axon-configuration-4.7.5.jar         1     39                     0
#
#    outgoingDependencies
# 0                     0
# 1                     1
# 2                     2
# 3                     3
# 4                     3
# 5                     4

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to problems when one of these packages needs to be changed.

# %% [markdown]
# ## Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies`
#
# **Columns:**
# - *artifactName* identifies the artifact of the first participant of the cycle
# - *packageName* identifies the package of the first participant of the cycle
# - *dependentArtifactName* identifies the artifact of the second participant of the cycle
# - *dependentPackageName* identifies the package of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies.cypher")
cyclic_dependencies.head(40)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.7.5
# 1       axon-messaging-4.7.5
# 2       axon-messaging-4.7.5
# 3       axon-messaging-4.7.5
# 4       axon-messaging-4.7.5
# 5   axon-eventsourcing-4.7.5
# 6       axon-messaging-4.7.5
# 7       axon-messaging-4.7.5
# 8       axon-messaging-4.7.5
# 9       axon-messaging-4.7.5
# 10      axon-messaging-4.7.5
# 11      axon-messaging-4.7.5
# 12      axon-messaging-4.7.5
# 13      axon-messaging-4.7.5
# 14  axon-eventsourcing-4.7.5
# 15      axon-modelling-4.7.5
# 16      axon-messaging-4.7.5
# 17      axon-messaging-4.7.5
# 18      axon-messaging-4.7.5
# 19      axon-messaging-4.7.5
# 20      axon-modelling-4.7.5
# 21      axon-messaging-4.7.5
#
#                                           packageName  \
# 0                     org.axonframework.queryhandling
# 1                     org.axonframework.eventhandling
# 2                     org.axonframework.eventhandling
# 3                     org.axonframework.eventhandling
# 4                     org.axonframework.queryhandling
# 5                     org.axonframework.eventsourcing
# 6                          org.axonframework.deadline
# 7         org.axonframework.commandhandling.callbacks
# 8                   org.axonframework.commandhandling
# 9                     org.axonframework.eventhandling
# 10             org.axonframework.messaging.unitofwork
# 11              org.axonframework.eventhandling.async
# 12             org.axonframework.eventhandling.replay
# 13    org.axonframework.serialization.upcasting.event
# 14    org.axonframework.eventsourcing.eventstore.jdbc
# 15     org.axonframework.modelling.command.inspection
# 16       org.axonframework.queryhandling.registration
# 17                        org.axonframework.messaging
# 18                    org.axonframework.eventhandling
# 19             org.axonframework.messaging.annotation
# 20                   org.axonframework.modelling.saga
# 21  org.axonframework.commandhandling.distributed....
#
#        dependentArtifactName  \
# 0       axon-messaging-4.7.5
# 1       axon-messaging-4.7.5
# 2       axon-messaging-4.7.5
# 3       axon-messaging-4.7.5
# 4       axon-messaging-4.7.5
# 5   axon-eventsourcing-4.7.5
# 6       axon-messaging-4.7.5
# 7       axon-messaging-4.7.5
# 8       axon-messaging-4.7.5
# 9       axon-messaging-4.7.5
# 10      axon-messaging-4.7.5
# 11      axon-messaging-4.7.5
# 12      axon-messaging-4.7.5
# 13      axon-messaging-4.7.5
# 14  axon-eventsourcing-4.7.5
# 15      axon-modelling-4.7.5
# 16      axon-messaging-4.7.5
# 17      axon-messaging-4.7.5
# 18      axon-messaging-4.7.5
# 19      axon-messaging-4.7.5
# 20      axon-modelling-4.7.5
# 21      axon-messaging-4.7.5
#
#                                  dependentPackageName  \
# 0           org.axonframework.messaging.responsetypes
# 1                           org.axonframework.tracing
# 2                         org.axonframework.messaging
# 3              org.axonframework.messaging.annotation
# 4                           org.axonframework.tracing
# 5          org.axonframework.eventsourcing.eventstore
# 6                           org.axonframework.tracing
# 7                   org.axonframework.commandhandling
# 8                           org.axonframework.tracing
# 9                     org.axonframework.serialization
# 10                        org.axonframework.messaging
# 11                    org.axonframework.eventhandling
# 12                    org.axonframework.eventhandling
# 13                    org.axonframework.eventhandling
# 14  org.axonframework.eventsourcing.eventstore.jdb...
# 15                org.axonframework.modelling.command
# 16                    org.axonframework.queryhandling
# 17                    org.axonframework.serialization
# 18         org.axonframework.eventhandling.tokenstore
# 19           org.axonframework.messaging.interceptors
# 20         org.axonframework.modelling.saga.metamodel
# 21      org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.882353             16               1
# 1                   0.857143             13               1
# 2                   0.853659             38               3
# 3                   0.840000             23               2
# 4                   0.800000              9               1
# 5                   0.777778             16               2
# 6                   0.750000              7               1
# 7                   0.733333             13               2
# 8                   0.666667              5               1
# 9                   0.647059             14               3
# 10                  0.647059             14               3
# 11                  0.538462             10               3
# 12                  0.454545              8               3
# 13                  0.333333              6               3
# 14                  0.317073             27              14
# 15                  0.250000             20              12
# 16                  0.250000              5               3
# 17                  0.238095             13               8
# 18                  0.230769              8               5
# 19                  0.200000              3               2
# 20                  0.142857              4               3
# 21                  0.076923              7               6
#
#                               someForwardDependencies  \
# 0   [GenericStreamingQueryMessage->ResponseType, G...
# 1   [TrackingEventProcessor->SpanFactory, Tracking...
# 2   [ConcludesBatchParameterResolverFactory->Messa...
# 3   [ConcludesBatchParameterResolverFactory->Param...
# 4   [SimpleQueryUpdateEmitter->Span, SimpleQueryUp...
# 5   [AggregateSnapshotter->DomainEventStream, Filt...
# 6   [SimpleDeadlineManager->SpanFactory, SimpleDea...
# 7   [LoggingCallback->CommandMessage, LoggingCallb...
# 8   [AsynchronousCommandBus$Builder->SpanFactory, ...
# 9   [AbstractEventEntry->SimpleSerializedType, Abs...
# 10  [AbstractUnitOfWork->MetaData, AbstractUnitOfW...
# 11  [PropertySequencingPolicy$Builder$ExceptionRai...
# 12  [ReplayParameterResolverFactory$ReplayParamete...
# 13  [IntermediateEventRepresentation->TrackingToke...
# 14  [JdbcEventStorageEngine->ReadSnapshotDataState...
# 15  [AggregateMemberAnnotatedChildEntityCollection...
# 16  [DuplicateQueryHandlerResolver->QuerySubscript...
# 17  [Headers->SerializedType, Headers->SerializedO...
# 18  [TrackingEventProcessor$MergeSegmentInstructio...
# 19  [ResultParameterResolverFactory->ResultHandler...
# 20  [AnnotatedSagaManager->SagaModel, AnnotatedSag...
# 21  [CommandNameFilter->CommandMessageFilter, AndC...
#
#                                  backwardDependencies
# 0   [ConvertingResponseMessage->QueryResponseMessage]
# 1                  [NestingSpanFactory->EventMessage]
# 2   [Headers->EventMessage, Headers->DomainEventMe...
# 3   [SourceIdParameterResolverFactory$SourceIdPara...
# 4                           [SpanUtils->QueryMessage]
# 5   [AbstractEventStorageEngine->EventStreamUtils,...
# 6                        [SpanUtils->DeadlineMessage]
# 7   [SimpleCommandBus$Builder->LoggingCallback, Si...
# 8                         [SpanUtils->CommandMessage]
# 9   [AbstractXStreamSerializer->GenericDomainEvent...
# 10  [GenericMessage->CurrentUnitOfWork, MessageHan...
# 11  [SimpleEventHandlerInvoker->SequencingPolicy, ...
# 12  [ResetHandler->ResetContext, AnnotationEventHa...
# 13  [EventUtils->IntermediateEventRepresentation, ...
# 14  [CreateTailTokenStatementBuilder->EventSchema,...
# 15  [AggregateAnnotationCommandHandler$Builder->Ag...
# 16  [SimpleQueryBus$Builder->DuplicateQueryHandler...
# 17  [AbstractXStreamSerializer$MetaDataConverter->...
# 18  [TokenStore->Segment, TokenStore->TrackingToke...
# 19  [MessageHandlerInterceptor->MessageHandler, Re...
# 20  [AnnotationSagaMetaModelFactory$InspectedSagaM...
# 21  [DistributedCommandBus->DenyAll, DistributedCo...

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#             artifactName                      packageName  \
# 0   axon-messaging-4.7.5  org.axonframework.queryhandling
# 1   axon-messaging-4.7.5  org.axonframework.queryhandling
# 2   axon-messaging-4.7.5  org.axonframework.queryhandling
# 3   axon-messaging-4.7.5  org.axonframework.queryhandling
# 4   axon-messaging-4.7.5  org.axonframework.queryhandling
# 5   axon-messaging-4.7.5  org.axonframework.queryhandling
# 6   axon-messaging-4.7.5  org.axonframework.queryhandling
# 7   axon-messaging-4.7.5  org.axonframework.queryhandling
# 8   axon-messaging-4.7.5  org.axonframework.queryhandling
# 9   axon-messaging-4.7.5  org.axonframework.queryhandling
# 10  axon-messaging-4.7.5  org.axonframework.queryhandling
# 11  axon-messaging-4.7.5  org.axonframework.queryhandling
# 12  axon-messaging-4.7.5  org.axonframework.queryhandling
# 13  axon-messaging-4.7.5  org.axonframework.queryhandling
# 14  axon-messaging-4.7.5  org.axonframework.queryhandling
# 15  axon-messaging-4.7.5  org.axonframework.queryhandling
# 16  axon-messaging-4.7.5  org.axonframework.queryhandling
# 17  axon-messaging-4.7.5  org.axonframework.eventhandling
# 18  axon-messaging-4.7.5  org.axonframework.eventhandling
# 19  axon-messaging-4.7.5  org.axonframework.eventhandling
# 20  axon-messaging-4.7.5  org.axonframework.eventhandling
# 21  axon-messaging-4.7.5  org.axonframework.eventhandling
# 22  axon-messaging-4.7.5  org.axonframework.eventhandling
# 23  axon-messaging-4.7.5  org.axonframework.eventhandling
# 24  axon-messaging-4.7.5  org.axonframework.eventhandling
# 25  axon-messaging-4.7.5  org.axonframework.eventhandling
# 26  axon-messaging-4.7.5  org.axonframework.eventhandling
# 27  axon-messaging-4.7.5  org.axonframework.eventhandling
# 28  axon-messaging-4.7.5  org.axonframework.eventhandling
# 29  axon-messaging-4.7.5  org.axonframework.eventhandling
# 30  axon-messaging-4.7.5  org.axonframework.eventhandling
# 31  axon-messaging-4.7.5  org.axonframework.eventhandling
# 32  axon-messaging-4.7.5  org.axonframework.eventhandling
# 33  axon-messaging-4.7.5  org.axonframework.eventhandling
# 34  axon-messaging-4.7.5  org.axonframework.eventhandling
# 35  axon-messaging-4.7.5  org.axonframework.eventhandling
# 36  axon-messaging-4.7.5  org.axonframework.eventhandling
# 37  axon-messaging-4.7.5  org.axonframework.eventhandling
# 38  axon-messaging-4.7.5  org.axonframework.eventhandling
# 39  axon-messaging-4.7.5  org.axonframework.eventhandling
#
#    dependentArtifactName                       dependentPackageName  \
# 0   axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 1   axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 2   axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 3   axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 4   axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 5   axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 6   axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 7   axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 8   axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 9   axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 10  axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 11  axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 12  axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 13  axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 14  axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 15  axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 16  axon-messaging-4.7.5  org.axonframework.messaging.responsetypes
# 17  axon-messaging-4.7.5                  org.axonframework.tracing
# 18  axon-messaging-4.7.5                  org.axonframework.tracing
# 19  axon-messaging-4.7.5                  org.axonframework.tracing
# 20  axon-messaging-4.7.5                  org.axonframework.tracing
# 21  axon-messaging-4.7.5                  org.axonframework.tracing
# 22  axon-messaging-4.7.5                  org.axonframework.tracing
# 23  axon-messaging-4.7.5                  org.axonframework.tracing
# 24  axon-messaging-4.7.5                  org.axonframework.tracing
# 25  axon-messaging-4.7.5                  org.axonframework.tracing
# 26  axon-messaging-4.7.5                  org.axonframework.tracing
# 27  axon-messaging-4.7.5                  org.axonframework.tracing
# 28  axon-messaging-4.7.5                  org.axonframework.tracing
# 29  axon-messaging-4.7.5                  org.axonframework.tracing
# 30  axon-messaging-4.7.5                  org.axonframework.tracing
# 31  axon-messaging-4.7.5                org.axonframework.messaging
# 32  axon-messaging-4.7.5                org.axonframework.messaging
# 33  axon-messaging-4.7.5                org.axonframework.messaging
# 34  axon-messaging-4.7.5                org.axonframework.messaging
# 35  axon-messaging-4.7.5                org.axonframework.messaging
# 36  axon-messaging-4.7.5                org.axonframework.messaging
# 37  axon-messaging-4.7.5                org.axonframework.messaging
# 38  axon-messaging-4.7.5                org.axonframework.messaging
# 39  axon-messaging-4.7.5                org.axonframework.messaging
#
#                                            dependency  \
# 0      SimpleQueryUpdateEmitter->OptionalResponseType
# 1                   DefaultQueryGateway->ResponseType
# 2                     QuerySubscription->ResponseType
# 3              SimpleQueryUpdateEmitter->ResponseType
# 4                 StreamingQueryMessage->ResponseType
# 5   GenericStreamingQueryMessage->PublisherRespons...
# 6          GenericStreamingQueryMessage->ResponseType
# 7                          QueryMessage->ResponseType
# 8                         QueryGateway->ResponseTypes
# 9     SimpleQueryUpdateEmitter->PublisherResponseType
# 10                       SimpleQueryBus->ResponseType
# 11             SubscriptionQueryMessage->ResponseType
# 12                         QueryGateway->ResponseType
# 13      GenericSubscriptionQueryMessage->ResponseType
# 14    QueryResponseMessage<-ConvertingResponseMessage
# 15  SimpleQueryUpdateEmitter->MultipleInstancesRes...
# 16                  GenericQueryMessage->ResponseType
# 17                AbstractEventProcessor->SpanFactory
# 18     SubscribingEventProcessor$Builder->SpanFactory
# 19              AbstractEventBus$Builder->SpanFactory
# 20                SimpleEventBus$Builder->SpanFactory
# 21                             AbstractEventBus->Span
# 22          AbstractEventBus$Builder->NoOpSpanFactory
# 23                      AbstractEventBus->SpanFactory
# 24                       AbstractEventProcessor->Span
# 25                TrackingEventProcessor->SpanFactory
# 26                   EventMessage<-NestingSpanFactory
# 27                       TrackingEventProcessor->Span
# 28        TrackingEventProcessor$Builder->SpanFactory
# 29    AbstractEventProcessor$Builder->NoOpSpanFactory
# 30        AbstractEventProcessor$Builder->SpanFactory
# 31   StreamingEventProcessor->StreamableMessageSource
# 32    ConcludesBatchParameterResolverFactory->Message
# 33       AbstractEventBus->MessageDispatchInterceptor
# 34           TrackingEventProcessor->InterceptorChain
# 35             TrackingToken<-StreamableMessageSource
# 36  SubscribingEventProcessor$Builder->Subscribabl...
# 37          GenericTrackedDomainEventMessage->Message
# 38                EventMessageHandler->MessageHandler
# 39                       EventMessageHandler->Message
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.882353             16               1
# 1                   0.882353             16               1
# 2                   0.882353             16               1
# 3                   0.882353             16               1
# 4                   0.882353             16               1
# 5                   0.882353             16               1
# 6                   0.882353             16               1
# 7                   0.882353             16               1
# 8                   0.882353             16               1
# 9                   0.882353             16               1
# 10                  0.882353             16               1
# 11                  0.882353             16               1
# 12                  0.882353             16               1
# 13                  0.882353             16               1
# 14                  0.882353             16               1
# 15                  0.882353             16               1
# 16                  0.882353             16               1
# 17                  0.857143             13               1
# 18                  0.857143             13               1
# 19                  0.857143             13               1
# 20                  0.857143             13               1
# 21                  0.857143             13               1
# 22                  0.857143             13               1
# 23                  0.857143             13               1
# 24                  0.857143             13               1
# 25                  0.857143             13               1
# 26                  0.857143             13               1
# 27                  0.857143             13               1
# 28                  0.857143             13               1
# 29                  0.857143             13               1
# 30                  0.857143             13               1
# 31                  0.853659             38               3
# 32                  0.853659             38               3
# 33                  0.853659             38               3
# 34                  0.853659             38               3
# 35                  0.853659             38               3
# 36                  0.853659             38               3
# 37                  0.853659             38               3
# 38                  0.853659             38               3
# 39                  0.853659             38               3

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#                 artifactName                                      packageName  \
# 0       axon-messaging-4.7.5                  org.axonframework.queryhandling
# 1       axon-messaging-4.7.5                  org.axonframework.eventhandling
# 2       axon-messaging-4.7.5                  org.axonframework.eventhandling
# 3       axon-messaging-4.7.5                  org.axonframework.eventhandling
# 4       axon-messaging-4.7.5                  org.axonframework.eventhandling
# 5       axon-messaging-4.7.5                  org.axonframework.eventhandling
# 6       axon-messaging-4.7.5                  org.axonframework.eventhandling
# 7       axon-messaging-4.7.5                  org.axonframework.queryhandling
# 8   axon-eventsourcing-4.7.5                  org.axonframework.eventsourcing
# 9   axon-eventsourcing-4.7.5                  org.axonframework.eventsourcing
# 10      axon-messaging-4.7.5                       org.axonframework.deadline
# 11      axon-messaging-4.7.5      org.axonframework.commandhandling.callbacks
# 12      axon-messaging-4.7.5      org.axonframework.commandhandling.callbacks
# 13      axon-messaging-4.7.5                org.axonframework.commandhandling
# 14      axon-messaging-4.7.5                  org.axonframework.eventhandling
# 15      axon-messaging-4.7.5                  org.axonframework.eventhandling
# 16      axon-messaging-4.7.5                  org.axonframework.eventhandling
# 17      axon-messaging-4.7.5           org.axonframework.messaging.unitofwork
# 18      axon-messaging-4.7.5           org.axonframework.messaging.unitofwork
# 19      axon-messaging-4.7.5           org.axonframework.messaging.unitofwork
# 20      axon-messaging-4.7.5            org.axonframework.eventhandling.async
# 21      axon-messaging-4.7.5            org.axonframework.eventhandling.async
# 22      axon-messaging-4.7.5            org.axonframework.eventhandling.async
# 23      axon-messaging-4.7.5           org.axonframework.eventhandling.replay
# 24      axon-messaging-4.7.5           org.axonframework.eventhandling.replay
# 25      axon-messaging-4.7.5           org.axonframework.eventhandling.replay
# 26      axon-messaging-4.7.5  org.axonframework.serialization.upcasting.event
# 27      axon-messaging-4.7.5  org.axonframework.serialization.upcasting.event
# 28      axon-messaging-4.7.5  org.axonframework.serialization.upcasting.event
# 29  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
# 30  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
# 31  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
# 32  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
# 33  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
# 34  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
# 35  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
# 36  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
# 37  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
# 38  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
# 39  axon-eventsourcing-4.7.5  org.axonframework.eventsourcing.eventstore.jdbc
#
#        dependentArtifactName  \
# 0       axon-messaging-4.7.5
# 1       axon-messaging-4.7.5
# 2       axon-messaging-4.7.5
# 3       axon-messaging-4.7.5
# 4       axon-messaging-4.7.5
# 5       axon-messaging-4.7.5
# 6       axon-messaging-4.7.5
# 7       axon-messaging-4.7.5
# 8   axon-eventsourcing-4.7.5
# 9   axon-eventsourcing-4.7.5
# 10      axon-messaging-4.7.5
# 11      axon-messaging-4.7.5
# 12      axon-messaging-4.7.5
# 13      axon-messaging-4.7.5
# 14      axon-messaging-4.7.5
# 15      axon-messaging-4.7.5
# 16      axon-messaging-4.7.5
# 17      axon-messaging-4.7.5
# 18      axon-messaging-4.7.5
# 19      axon-messaging-4.7.5
# 20      axon-messaging-4.7.5
# 21      axon-messaging-4.7.5
# 22      axon-messaging-4.7.5
# 23      axon-messaging-4.7.5
# 24      axon-messaging-4.7.5
# 25      axon-messaging-4.7.5
# 26      axon-messaging-4.7.5
# 27      axon-messaging-4.7.5
# 28      axon-messaging-4.7.5
# 29  axon-eventsourcing-4.7.5
# 30  axon-eventsourcing-4.7.5
# 31  axon-eventsourcing-4.7.5
# 32  axon-eventsourcing-4.7.5
# 33  axon-eventsourcing-4.7.5
# 34  axon-eventsourcing-4.7.5
# 35  axon-eventsourcing-4.7.5
# 36  axon-eventsourcing-4.7.5
# 37  axon-eventsourcing-4.7.5
# 38  axon-eventsourcing-4.7.5
# 39  axon-eventsourcing-4.7.5
#
#                                  dependentPackageName  \
# 0           org.axonframework.messaging.responsetypes
# 1                           org.axonframework.tracing
# 2                         org.axonframework.messaging
# 3                         org.axonframework.messaging
# 4                         org.axonframework.messaging
# 5              org.axonframework.messaging.annotation
# 6              org.axonframework.messaging.annotation
# 7                           org.axonframework.tracing
# 8          org.axonframework.eventsourcing.eventstore
# 9          org.axonframework.eventsourcing.eventstore
# 10                          org.axonframework.tracing
# 11                  org.axonframework.commandhandling
# 12                  org.axonframework.commandhandling
# 13                          org.axonframework.tracing
# 14                    org.axonframework.serialization
# 15                    org.axonframework.serialization
# 16                    org.axonframework.serialization
# 17                        org.axonframework.messaging
# 18                        org.axonframework.messaging
# 19                        org.axonframework.messaging
# 20                    org.axonframework.eventhandling
# 21                    org.axonframework.eventhandling
# 22                    org.axonframework.eventhandling
# 23                    org.axonframework.eventhandling
# 24                    org.axonframework.eventhandling
# 25                    org.axonframework.eventhandling
# 26                    org.axonframework.eventhandling
# 27                    org.axonframework.eventhandling
# 28                    org.axonframework.eventhandling
# 29  org.axonframework.eventsourcing.eventstore.jdb...
# 30  org.axonframework.eventsourcing.eventstore.jdb...
# 31  org.axonframework.eventsourcing.eventstore.jdb...
# 32  org.axonframework.eventsourcing.eventstore.jdb...
# 33  org.axonframework.eventsourcing.eventstore.jdb...
# 34  org.axonframework.eventsourcing.eventstore.jdb...
# 35  org.axonframework.eventsourcing.eventstore.jdb...
# 36  org.axonframework.eventsourcing.eventstore.jdb...
# 37  org.axonframework.eventsourcing.eventstore.jdb...
# 38  org.axonframework.eventsourcing.eventstore.jdb...
# 39  org.axonframework.eventsourcing.eventstore.jdb...
#
#                                            dependency  \
# 0     QueryResponseMessage<-ConvertingResponseMessage
# 1                    EventMessage<-NestingSpanFactory
# 2                               EventMessage<-Headers
# 3              TrackingToken<-StreamableMessageSource
# 4                         DomainEventMessage<-Headers
# 5   DomainEventMessage<-AggregateTypeParameterReso...
# 6   DomainEventMessage<-SourceIdParameterResolverF...
# 7                             QueryMessage<-SpanUtils
# 8        EventStreamUtils<-AbstractEventStorageEngine
# 9                 EventStreamUtils<-DomainEventStream
# 10                         DeadlineMessage<-SpanUtils
# 11             NoOpCallback<-SimpleCommandBus$Builder
# 12          LoggingCallback<-SimpleCommandBus$Builder
# 13                          CommandMessage<-SpanUtils
# 14  GapAwareTrackingToken<-GapAwareTrackingTokenCo...
# 15     GenericEventMessage<-AbstractXStreamSerializer
# 16  GenericDomainEventMessage<-AbstractXStreamSeri...
# 17                  CurrentUnitOfWork<-GenericMessage
# 18                UnitOfWork<-DefaultInterceptorChain
# 19              UnitOfWork<-MessageHandlerInterceptor
# 20  SequentialPerAggregatePolicy<-SimpleEventHandl...
# 21  SequencingPolicy<-SimpleEventHandlerInvoker$Bu...
# 22        SequencingPolicy<-SimpleEventHandlerInvoker
# 23        ResetContext<-AnnotationEventHandlerAdapter
# 24  GenericResetContext<-AnnotationEventHandlerAda...
# 25                         ResetContext<-ResetHandler
# 26                          EventUpcaster<-EventUtils
# 27        IntermediateEventRepresentation<-EventUtils
# 28             InitialEventRepresentation<-EventUtils
# 29         EventSchema<-CreateTokenAtStatementBuilder
# 30  EventSchema<-ReadEventDataForAggregateStatemen...
# 31    EventSchema<-FetchTrackedEventsStatementBuilder
# 32          EventSchema<-AppendEventsStatementBuilder
# 33      EventSchema<-ReadSnapshotDataStatementBuilder
# 34  EventSchema<-ReadEventDataWithGapsStatementBui...
# 35  EventSchema<-ReadEventDataWithoutGapsStatement...
# 36             EventSchema<-CleanGapsStatementBuilder
# 37      EventSchema<-JdbcEventStorageEngineStatements
# 38       EventSchema<-CreateHeadTokenStatementBuilder
# 39        EventSchema<-AppendSnapshotStatementBuilder
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.882353             16               1
# 1                   0.857143             13               1
# 2                   0.853659             38               3
# 3                   0.853659             38               3
# 4                   0.853659             38               3
# 5                   0.840000             23               2
# 6                   0.840000             23               2
# 7                   0.800000              9               1
# 8                   0.777778             16               2
# 9                   0.777778             16               2
# 10                  0.750000              7               1
# 11                  0.733333             13               2
# 12                  0.733333             13               2
# 13                  0.666667              5               1
# 14                  0.647059             14               3
# 15                  0.647059             14               3
# 16                  0.647059             14               3
# 17                  0.647059             14               3
# 18                  0.647059             14               3
# 19                  0.647059             14               3
# 20                  0.538462             10               3
# 21                  0.538462             10               3
# 22                  0.538462             10               3
# 23                  0.454545              8               3
# 24                  0.454545              8               3
# 25                  0.454545              8               3
# 26                  0.333333              6               3
# 27                  0.333333              6               3
# 28                  0.333333              6               3
# 29                  0.317073             27              14
# 30                  0.317073             27              14
# 31                  0.317073             27              14
# 32                  0.317073             27              14
# 33                  0.317073             27              14
# 34                  0.317073             27              14
# 35                  0.317073             27              14
# 36                  0.317073             27              14
# 37                  0.317073             27              14
# 38                  0.317073             27              14
# 39                  0.317073             27              14

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.

# %% [markdown]
# ### Table 4 - Top 40 most used combinations of methods
#
# The following table shows the top 40 most used combinations of methods of larger types that might benefit from applying the *Interface Segregation Principle*. The whole table can be found in the CSV report `Candidates_for_Interface_Segregation`.

# %%
interface_segregation_candidates=query_cypher_to_data_frame("../cypher/Candidates_for_Interface_Segregation.cypher", limit=40)
interface_segregation_candidates
# Out:
#                                 fullDependentTypeName  declaredMethods  \
# 0    org.axonframework.commandhandling.CommandMessage                9
# 1   org.axonframework.eventhandling.DomainEventMes...               10
# 2        org.axonframework.eventhandling.EventMessage                9
# 3        org.axonframework.eventhandling.EventMessage                9
# 4   org.axonframework.eventhandling.TrackedEventMe...               10
# 5   org.axonframework.eventhandling.DomainEventMes...               10
# 6           org.axonframework.messaging.ResultMessage                9
# 7   org.axonframework.commandhandling.GenericComma...               15
# 8   org.axonframework.commandhandling.GenericComma...               14
# 9   org.axonframework.messaging.annotation.Wrapped...               14
# 10  org.axonframework.eventhandling.TrackedEventMe...               12
# 11  org.axonframework.deadline.GenericDeadlineMessage               11
# 12         org.axonframework.deadline.DeadlineMessage               10
# 13  org.axonframework.eventhandling.DomainEventMes...               10
# 14  org.axonframework.eventhandling.DomainEventMes...               10
# 15  org.axonframework.eventhandling.GenericEventMe...               10
# 16  org.axonframework.common.transaction.NoTransac...                4
# 17  org.axonframework.modelling.command.inspection...               13
# 18  org.axonframework.eventhandling.DomainEventMes...               11
# 19  org.axonframework.eventhandling.DomainEventMes...               10
# 20  org.axonframework.eventhandling.GapAwareTracki...               10
# 21       org.axonframework.eventhandling.EventMessage                9
# 22       org.axonframework.messaging.MessageDecorator                9
# 23   org.axonframework.eventhandling.TrackedEventData                5
# 24  org.axonframework.eventhandling.tokenstore.Con...                5
# 25      org.axonframework.eventhandling.TrackerStatus               17
# 26  org.axonframework.modelling.command.inspection...               17
# 27  org.axonframework.queryhandling.SimpleQueryUpd...               17
# 28  org.axonframework.messaging.annotation.Wrapped...               15
# 29  org.axonframework.commandhandling.CommandMessa...               14
# 30  org.axonframework.commandhandling.GenericComma...               14
# 31         org.axonframework.deadline.DeadlineMessage               14
# 32   org.axonframework.messaging.GenericResultMessage               14
# 33  org.axonframework.messaging.annotation.Wrapped...               14
# 34  org.axonframework.eventhandling.DomainEventMes...               13
# 35        org.axonframework.eventhandling.ReplayToken               13
# 36        org.axonframework.eventhandling.ReplayToken               13
# 37  org.axonframework.queryhandling.SubscriptionQu...               12
# 38  org.axonframework.commandhandling.GenericComma...               11
# 39  org.axonframework.eventhandling.DomainEventMes...               11
#
#                                     calledMethodNames  calledMethods  \
# 0                                    [getCommandName]              1
# 1                                 [getSequenceNumber]              1
# 2                       [getIdentifier, getTimestamp]              2
# 3                                     [getIdentifier]              1
# 4                                     [trackingToken]              1
# 5   [getSequenceNumber, getType, getAggregateIdent...              3
# 6                    [exceptionResult, isExceptional]              2
# 7                            [asCommandResultMessage]              1
# 8                            [asCommandResultMessage]              1
# 9                                            [handle]              1
# 10                                    [trackingToken]              1
# 11                                [asDeadlineMessage]              1
# 12                                  [getDeadlineName]              1
# 13                                          [getType]              1
# 14                           [getAggregateIdentifier]              1
# 15                                   [asEventMessage]              1
# 16                                         [instance]              1
# 17                                             [type]              1
# 18  [getSequenceNumber, getType, getAggregateIdent...              3
# 19        [getSequenceNumber, getAggregateIdentifier]              2
# 20  [withGapsTruncatedAt, newInstance, advanceTo, ...              5
# 21                                     [getTimestamp]              1
# 22                                       [describeTo]              1
# 23                                    [trackingToken]              1
# 24                                              [get]              1
# 25              [split, getTrackingToken, getSegment]              3
# 26       [getAggregateRoot, initialize, initSequence]              4
# 27                                          [builder]              1
# 28                                [canHandle, handle]              2
# 29                    [isFactoryHandler, commandName]              2
# 30                           [asCommandResultMessage]              2
# 31                                  [getDeadlineName]              1
# 32                                  [asResultMessage]              1
# 33                                        [canHandle]              1
# 34        [getSequenceNumber, getAggregateIdentifier]              2
# 35                                [createReplayToken]              1
# 36                                         [isReplay]              1
# 37                            [getUpdateResponseType]              1
# 38                                 [asCommandMessage]              1
# 39                                [getSequenceNumber]              1
#
#     callerTypes
# 0            18
# 1             9
# 2             8
# 3             8
# 4             7
# 5             5
# 6             5
# 7             4
# 8             4
# 9             4
# 10            4
# 11            4
# 12            4
# 13            4
# 14            4
# 15            4
# 16            4
# 17            3
# 18            3
# 19            3
# 20            3
# 21            3
# 22            3
# 23            3
# 24            3
# 25            2
# 26            2
# 27            2
# 28            2
# 29            2
# 30            2
# 31            2
# 32            2
# 33            2
# 34            2
# 35            2
# 36            2
# 37            2
# 38            2
# 39            2

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Table 5 - Types that are used by multiple packages
#
# This table shows the top 40 packages that are used by the highest number of different packages. The whole table can be found in the CSV report `List_types_that_are_used_by_many_different_packages`.

# %%
types_used_by_many_packages=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_types_that_are_used_by_many_different_packages.cypher", limit=40)
types_used_by_many_packages
# Out:
#                        fullQualifiedDependentTypeName  \
# 0               org.axonframework.common.BuilderUtils
# 1                 org.axonframework.messaging.Message
# 2   org.axonframework.common.AxonConfigurationExce...
# 3        org.axonframework.eventhandling.EventMessage
# 4                org.axonframework.messaging.MetaData
# 5   org.axonframework.messaging.unitofwork.UnitOfWork
# 6                     org.axonframework.common.Assert
# 7          org.axonframework.serialization.Serializer
# 8   org.axonframework.common.transaction.Transacti...
# 9    org.axonframework.serialization.SerializedObject
# 10  org.axonframework.messaging.unitofwork.Current...
# 11     org.axonframework.serialization.SerializedType
# 12  org.axonframework.common.AxonNonTransientExcep...
# 13  org.axonframework.messaging.annotation.Paramet...
# 14  org.axonframework.eventhandling.DomainEventMes...
# 15      org.axonframework.eventhandling.TrackingToken
# 16  org.axonframework.eventhandling.GenericEventMe...
# 17              org.axonframework.common.Registration
# 18  org.axonframework.messaging.MessageDispatchInt...
# 19  org.axonframework.messaging.MessageHandlerInte...
# 20               org.axonframework.common.ObjectUtils
# 21   org.axonframework.commandhandling.CommandMessage
# 22  org.axonframework.messaging.annotation.Handler...
# 23           org.axonframework.common.ReflectionUtils
# 24  org.axonframework.serialization.SimpleSerializ...
# 25              org.axonframework.tracing.SpanFactory
# 26  org.axonframework.messaging.unitofwork.Default...
# 27           org.axonframework.eventhandling.EventBus
# 28       org.axonframework.messaging.InterceptorChain
# 29          org.axonframework.messaging.ResultMessage
# 30    org.axonframework.common.AxonTransientException
# 31  org.axonframework.messaging.annotation.Classpa...
# 32  org.axonframework.messaging.annotation.Classpa...
# 33             org.axonframework.common.DateTimeUtils
# 34  org.axonframework.common.transaction.NoTransac...
# 35        org.axonframework.messaging.ScopeDescriptor
# 36  org.axonframework.messaging.DefaultInterceptor...
# 37  org.axonframework.eventhandling.GenericDomainE...
# 38  org.axonframework.messaging.annotation.Handler...
# 39              org.axonframework.lifecycle.Lifecycle
#
#                     dependentTypeName  \
# 0                        BuilderUtils
# 1                             Message
# 2          AxonConfigurationException
# 3                        EventMessage
# 4                            MetaData
# 5                          UnitOfWork
# 6                              Assert
# 7                          Serializer
# 8                  TransactionManager
# 9                    SerializedObject
# 10                  CurrentUnitOfWork
# 11                     SerializedType
# 12          AxonNonTransientException
# 13           ParameterResolverFactory
# 14                 DomainEventMessage
# 15                      TrackingToken
# 16                GenericEventMessage
# 17                       Registration
# 18         MessageDispatchInterceptor
# 19          MessageHandlerInterceptor
# 20                        ObjectUtils
# 21                     CommandMessage
# 22                  HandlerDefinition
# 23                    ReflectionUtils
# 24             SimpleSerializedObject
# 25                        SpanFactory
# 26                  DefaultUnitOfWork
# 27                           EventBus
# 28                   InterceptorChain
# 29                      ResultMessage
# 30             AxonTransientException
# 31         ClasspathHandlerDefinition
# 32  ClasspathParameterResolverFactory
# 33                      DateTimeUtils
# 34               NoTransactionManager
# 35                    ScopeDescriptor
# 36            DefaultInterceptorChain
# 37          GenericDomainEventMessage
# 38          HandlerEnhancerDefinition
# 39                          Lifecycle
#
#                                   dependentTypeLabels  numberOfUsingPackages
# 0   [Type, File, Java, ByteCode, Class, TopCentral...                     41
# 1   [Type, File, Java, ByteCode, GenericDeclaratio...                     36
# 2   [Type, File, Java, ByteCode, Class, TopCentral...                     35
# 3   [Type, File, Java, ByteCode, GenericDeclaratio...                     30
# 4   [Type, File, Java, ByteCode, Class, TopCentral...                     30
# 5   [Type, File, Java, ByteCode, GenericDeclaratio...                     29
# 6   [Type, File, Java, ByteCode, Class, TopCentral...                     26
# 7   [Type, File, Java, ByteCode, Interface, TopCen...                     26
# 8   [Type, File, Java, ByteCode, Interface, TopCen...                     23
# 9   [Type, File, Java, ByteCode, GenericDeclaratio...                     22
# 10  [Type, File, Java, ByteCode, Class, TopCentral...                     21
# 11  [Type, File, Java, ByteCode, Interface, TopCen...                     21
# 12  [Type, File, Java, ByteCode, Class, TopCentral...                     18
# 13  [Type, File, Java, ByteCode, Interface, TopCen...                     18
# 14  [Type, File, Java, ByteCode, GenericDeclaratio...                     17
# 15  [Type, File, Java, ByteCode, Interface, TopCen...                     17
# 16  [Type, File, Java, ByteCode, Class, GenericDec...                     16
# 17  [Type, File, Java, ByteCode, Interface, TypeLe...                     16
# 18  [Type, File, Java, ByteCode, GenericDeclaratio...                     15
# 19  [Type, File, Java, ByteCode, GenericDeclaratio...                     15
# 20  [Type, File, Java, ByteCode, Class, TypeLeiden...                     15
# 21  [Type, File, Java, ByteCode, GenericDeclaratio...                     14
# 22  [Type, File, Java, ByteCode, Interface, TopCen...                     14
# 23  [Type, File, Java, ByteCode, Class, TypeLeiden...                     14
# 24  [Type, File, Java, ByteCode, Class, GenericDec...                     14
# 25  [Type, File, Java, ByteCode, Interface, TypeLe...                     14
# 26  [Type, File, Java, ByteCode, Class, GenericDec...                     12
# 27  [Type, File, Java, ByteCode, Interface, TypeLe...                     12
# 28  [Type, File, Java, ByteCode, Interface, TypeLe...                     12
# 29  [Type, File, Java, ByteCode, GenericDeclaratio...                     12
# 30  [Type, File, Java, ByteCode, Class, TypeLeiden...                     11
# 31  [Type, File, Java, ByteCode, Class, TypeLeiden...                     11
# 32  [Type, File, Java, ByteCode, Class, TypeLeiden...                     11
# 33  [Type, File, Java, ByteCode, Class, TypeLeiden...                     11
# 34  [Type, File, Java, ByteCode, Enum, TypeLeidenC...                     11
# 35  [Type, File, Java, ByteCode, Interface, TypeLe...                     11
# 36  [Type, File, Java, ByteCode, Class, GenericDec...                     10
# 37  [Type, File, Java, ByteCode, Class, GenericDec...                     10
# 38  [Type, File, Java, ByteCode, Interface, TopCen...                     10
# 39  [Type, File, Java, ByteCode, Interface, TypeLe...                     10

# %% [markdown]
# ### Table 6 - Packages that are used by multiple artifacts
#
# This table shows the top 30 artifacts that only use a few (compared to all existing) packages of another artifact.
# The whole table can be found in the CSV report `ArtifactPackageUsage`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#                 artifactName     dependentArtifactName  dependentPackages  \
# 0       axon-disruptor-4.7.5      axon-messaging-4.7.5                  9
# 1            axon-test-4.7.5      axon-messaging-4.7.5                 10
# 2       axon-disruptor-4.7.5      axon-modelling-4.7.5                  2
# 3   axon-eventsourcing-4.7.5      axon-modelling-4.7.5                  2
# 4       axon-disruptor-4.7.5  axon-eventsourcing-4.7.5                  2
# 5            axon-test-4.7.5  axon-eventsourcing-4.7.5                  2
# 6       axon-modelling-4.7.5      axon-messaging-4.7.5                 18
# 7   axon-eventsourcing-4.7.5      axon-messaging-4.7.5                 20
# 8   axon-configuration-4.7.5  axon-eventsourcing-4.7.5                  4
# 9            axon-test-4.7.5      axon-modelling-4.7.5                  5
# 10  axon-configuration-4.7.5      axon-messaging-4.7.5                 34
# 11      axon-modelling-4.7.5      axon-modelling-4.7.5                  6
# 12  axon-configuration-4.7.5      axon-modelling-4.7.5                  6
# 13           axon-test-4.7.5           axon-test-4.7.5                  5
# 14      axon-messaging-4.7.5      axon-messaging-4.7.5                 40
# 15  axon-eventsourcing-4.7.5  axon-eventsourcing-4.7.5                  7
# 16  axon-configuration-4.7.5      axon-disruptor-4.7.5                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          61                0.147541
# 1                          61                0.163934
# 2                          10                0.200000
# 3                          10                0.200000
# 4                           9                0.222222
# 5                           9                0.222222
# 6                          61                0.295082
# 7                          61                0.327869
# 8                           9                0.444444
# 9                          10                0.500000
# 10                         61                0.557377
# 11                         10                0.600000
# 12                         10                0.600000
# 13                          8                0.625000
# 14                         61                0.655738
# 15                          9                0.777778
# 16                          1                1.000000
#
#                    dependentFullQualifiedPackageNames  \
# 0   [org.axonframework.common.caching, org.axonfra...
# 1   [org.axonframework.commandhandling, org.axonfr...
# 2   [org.axonframework.modelling.command.inspectio...
# 3   [org.axonframework.modelling.command, org.axon...
# 4   [org.axonframework.eventsourcing, org.axonfram...
# 5   [org.axonframework.eventsourcing, org.axonfram...
# 6   [org.axonframework.eventhandling, org.axonfram...
# 7   [org.axonframework.eventhandling, org.axonfram...
# 8   [org.axonframework.eventsourcing, org.axonfram...
# 9   [org.axonframework.modelling.command.inspectio...
# 10  [org.axonframework.messaging, org.axonframewor...
# 11  [org.axonframework.modelling.saga, org.axonfra...
# 12  [org.axonframework.modelling.saga.repository.j...
# 13  [org.axonframework.test, org.axonframework.tes...
# 14  [org.axonframework.common, org.axonframework.m...
# 15  [org.axonframework.eventsourcing.eventstore.jd...
# 16      [org.axonframework.disruptor.commandhandling]
#
#                                 dependentPackageNames
# 0   [caching, monitoring, annotation, unitofwork, ...
# 1   [commandhandling, eventhandling, messaging, co...
# 2                               [inspection, command]
# 3                               [command, inspection]
# 4                         [eventsourcing, eventstore]
# 5                         [eventsourcing, eventstore]
# 6   [eventhandling, annotation, legacyjpa, tracing...
# 7   [eventhandling, common, serialization, io, xml...
# 8      [eventsourcing, eventstore, jpa, snapshotting]
# 9   [inspection, command, saga, repository, inmemory]
# 10  [messaging, caching, annotation, event, deadle...
# 11  [saga, repository, inspection, command, metamo...
# 12  [jpa, inmemory, saga, inspection, repository, ...
# 13  [test, matchers, deadline, utils, eventscheduler]
# 14  [common, unitofwork, messaging, deadline, seri...
# 15  [jdbc, eventsourcing, snapshotting, eventstore...
# 16                                  [commandhandling]

# %% [markdown]
# ### Table 7 - Types that are used by multiple artifacts
#
# This table shows the top 30 types that only use a few (compared to all existing) types of another artifact. The whole table can be found in the CSV report `ClassesPerPackageUsageAcrossArtifacts`.

# %%
used_types_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher", limit=30)
used_types_of_dependent_artifact
# Out:
#                 artifactName dependentArtifactName  \
# 0       axon-modelling-4.7.5  axon-messaging-4.7.5
# 1            axon-test-4.7.5  axon-messaging-4.7.5
# 2   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 3   axon-eventsourcing-4.7.5  axon-modelling-4.7.5
# 4   axon-eventsourcing-4.7.5  axon-modelling-4.7.5
# 5       axon-modelling-4.7.5  axon-messaging-4.7.5
# 6       axon-modelling-4.7.5  axon-messaging-4.7.5
# 7   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 8            axon-test-4.7.5  axon-messaging-4.7.5
# 9   axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 10  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 11           axon-test-4.7.5  axon-messaging-4.7.5
# 12           axon-test-4.7.5  axon-messaging-4.7.5
# 13  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 14  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 15  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 16  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 17           axon-test-4.7.5  axon-modelling-4.7.5
# 18  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 19           axon-test-4.7.5  axon-messaging-4.7.5
# 20           axon-test-4.7.5  axon-messaging-4.7.5
# 21  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 22  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 23      axon-modelling-4.7.5  axon-messaging-4.7.5
# 24  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 25           axon-test-4.7.5  axon-messaging-4.7.5
# 26  axon-eventsourcing-4.7.5  axon-messaging-4.7.5
# 27           axon-test-4.7.5  axon-messaging-4.7.5
# 28      axon-modelling-4.7.5  axon-messaging-4.7.5
# 29      axon-modelling-4.7.5  axon-messaging-4.7.5
#
#                                           packageName  \
# 0          org.axonframework.modelling.saga.metamodel
# 1                     org.axonframework.test.matchers
# 2        org.axonframework.eventsourcing.snapshotting
# 3   org.axonframework.eventsourcing.conflictresolu...
# 4     org.axonframework.eventsourcing.eventstore.jdbc
# 5       org.axonframework.modelling.command.legacyjpa
# 6                 org.axonframework.modelling.command
# 7   org.axonframework.eventsourcing.conflictresolu...
# 8               org.axonframework.test.eventscheduler
# 9          org.axonframework.eventsourcing.eventstore
# 10  org.axonframework.eventsourcing.conflictresolu...
# 11                    org.axonframework.test.matchers
# 12                             org.axonframework.test
# 13     org.axonframework.eventsourcing.eventstore.jpa
# 14  org.axonframework.eventsourcing.eventstore.leg...
# 15    org.axonframework.eventsourcing.eventstore.jdbc
# 16  org.axonframework.eventsourcing.eventstore.jdb...
# 17                       org.axonframework.test.utils
# 18  org.axonframework.eventsourcing.conflictresolu...
# 19                    org.axonframework.test.matchers
# 20                       org.axonframework.test.utils
# 21  org.axonframework.eventsourcing.conflictresolu...
# 22       org.axonframework.eventsourcing.snapshotting
# 23      org.axonframework.modelling.command.legacyjpa
# 24  org.axonframework.eventsourcing.eventstore.jdb...
# 25              org.axonframework.test.eventscheduler
# 26  org.axonframework.eventsourcing.conflictresolu...
# 27                             org.axonframework.test
# 28      org.axonframework.modelling.command.legacyjpa
# 29        org.axonframework.modelling.saga.repository
#
#                       dependentPackage.fqn  dependentTypes  \
# 0          org.axonframework.eventhandling               1
# 1          org.axonframework.eventhandling               1
# 2          org.axonframework.eventhandling               1
# 3      org.axonframework.modelling.command               1
# 4      org.axonframework.modelling.command               1
# 5          org.axonframework.eventhandling               2
# 6          org.axonframework.eventhandling               2
# 7          org.axonframework.eventhandling               2
# 8          org.axonframework.eventhandling               2
# 9              org.axonframework.messaging               1
# 10             org.axonframework.messaging               1
# 11             org.axonframework.messaging               1
# 12             org.axonframework.messaging               1
# 13         org.axonframework.serialization               1
# 14         org.axonframework.serialization               1
# 15         org.axonframework.serialization               1
# 16         org.axonframework.eventhandling               3
# 17        org.axonframework.modelling.saga               1
# 18       org.axonframework.commandhandling               1
# 19       org.axonframework.commandhandling               1
# 20                org.axonframework.common               1
# 21                org.axonframework.common               1
# 22                org.axonframework.common               1
# 23                org.axonframework.common               1
# 24                org.axonframework.common               1
# 25                org.axonframework.common               1
# 26  org.axonframework.messaging.annotation               2
# 27  org.axonframework.messaging.annotation               2
# 28  org.axonframework.messaging.annotation               2
# 29  org.axonframework.messaging.annotation               2
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                      93             0.010753
# 1                      93             0.010753
# 2                      93             0.010753
# 3                      51             0.019608
# 4                      51             0.019608
# 5                      93             0.021505
# 6                      93             0.021505
# 7                      93             0.021505
# 8                      93             0.021505
# 9                      35             0.028571
# 10                     35             0.028571
# 11                     35             0.028571
# 12                     35             0.028571
# 13                     34             0.029412
# 14                     34             0.029412
# 15                     34             0.029412
# 16                     93             0.032258
# 17                     30             0.033333
# 18                     29             0.034483
# 19                     29             0.034483
# 20                     28             0.035714
# 21                     28             0.035714
# 22                     28             0.035714
# 23                     28             0.035714
# 24                     28             0.035714
# 25                     28             0.035714
# 26                     54             0.037037
# 27                     54             0.037037
# 28                     54             0.037037
# 29                     54             0.037037
#
#                                    dependentTypeNames
# 0      [org.axonframework.eventhandling.EventMessage]
# 1      [org.axonframework.eventhandling.EventMessage]
# 2   [org.axonframework.eventhandling.DomainEventData]
# 3   [org.axonframework.modelling.command.Conflicti...
# 4   [org.axonframework.modelling.command.Concurren...
# 5   [org.axonframework.eventhandling.EventBus, org...
# 6   [org.axonframework.eventhandling.EventBus, org...
# 7   [org.axonframework.eventhandling.DomainEventMe...
# 8   [org.axonframework.eventhandling.GenericEventM...
# 9   [org.axonframework.messaging.StreamableMessage...
# 10              [org.axonframework.messaging.Message]
# 11              [org.axonframework.messaging.Message]
# 12              [org.axonframework.messaging.Message]
# 13       [org.axonframework.serialization.Serializer]
# 14       [org.axonframework.serialization.Serializer]
# 15       [org.axonframework.serialization.Serializer]
# 16  [org.axonframework.eventhandling.GenericDomain...
# 17  [org.axonframework.modelling.saga.SimpleResour...
# 18  [org.axonframework.commandhandling.CommandMess...
# 19  [org.axonframework.commandhandling.CommandMess...
# 20            [org.axonframework.common.Registration]
# 21                  [org.axonframework.common.Assert]
# 22            [org.axonframework.common.BuilderUtils]
# 23            [org.axonframework.common.BuilderUtils]
# 24           [org.axonframework.common.DateTimeUtils]
# 25           [org.axonframework.common.DateTimeUtils]
# 26  [org.axonframework.messaging.annotation.Parame...
# 27  [org.axonframework.messaging.annotation.Parame...
# 28  [org.axonframework.messaging.annotation.Parame...
# 29  [org.axonframework.messaging.annotation.Parame...
