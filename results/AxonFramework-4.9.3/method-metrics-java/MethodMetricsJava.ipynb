# %% [markdown]
# # Method Metrics
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## Effective Method Line Count

# %% [markdown]
# ### Table 1a - Effective method line count distribution
#
# This table shows the distribution of the effective method line count per artifact.
# For each artifact the number of methods with effective line count = 1,2,3,... is shown to get an overview of how line counts are distributed over methods.
#
# Only the 15 artifacts with the highest method count and their effective method line count distribution (limited by 40)is shown here. The whole table can be found in the CSV report `Effective_Method_Line_Count_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
effective_method_line_count_distribution_max_artifacts=20

effective_method_line_count_distribution=query_cypher_to_data_frame("../cypher/Overview/Effective_Method_Line_Count_Distribution.cypher")
effective_method_line_count_distribution=effective_method_line_count_distribution.pivot(index='effectiveLineCount', columns='artifactName', values='methods')

# Fill missing values with zero
effective_method_line_count_distribution.fillna(0, inplace=True)

# Convert to integer
effective_method_line_count_distribution=effective_method_line_count_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
effective_method_line_count_distribution = effective_method_line_count_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:effective_method_line_count_distribution_max_artifacts]]

effective_method_line_count_distribution.head(40)
# Out:
# artifactName        axon-messaging-4.9.3.jar  axon-eventsourcing-4.9.3.jar  \
# effectiveLineCount
# 1                                       2820                           573
# 2                                        823                           204
# 3                                        674                           127
# 4                                        269                            64
# 5                                        220                            39
# 6                                        161                            34
# 7                                        103                            32
# 8                                         80                            12
# 9                                         76                            17
# 10                                        46                             8
# 11                                        45                             2
# 12                                        41                             5
# 13                                        26                             2
# 14                                        17                             3
# 15                                         9                             2
# 16                                         8                             6
# 17                                        10                             0
# 18                                         9                             3
# 19                                         6                             0
# 20                                         5                             2
# 21                                         7                             2
# 22                                         2                             1
# 23                                         5                             2
# 24                                         3                             1
# 25                                         2                             1
# 26                                         2                             0
# 28                                         2                             0
# 29                                         0                             0
# 30                                         1                             0
# 31                                         1                             0
# 32                                         1                             0
# 33                                         1                             0
# 34                                         1                             0
# 36                                         2                             0
# 38                                         0                             0
# 43                                         0                             0
# 44                                         1                             0
# 45                                         0                             0
# 50                                         1                             0
# 63                                         1                             0
#
# artifactName        axon-modelling-4.9.3.jar  axon-test-4.9.3.jar  \
# effectiveLineCount
# 1                                        532                  279
# 2                                        158                  170
# 3                                        141                   64
# 4                                         57                   49
# 5                                         45                   24
# 6                                         45                   18
# 7                                         24                   20
# 8                                         10                   11
# 9                                         17                   10
# 10                                         8                    4
# 11                                         8                    9
# 12                                         2                    9
# 13                                         9                    5
# 14                                         3                    3
# 15                                         5                    2
# 16                                         2                    4
# 17                                         2                    3
# 18                                         0                    3
# 19                                         1                    0
# 20                                         2                    1
# 21                                         1                    1
# 22                                         2                    1
# 23                                         0                    1
# 24                                         1                    1
# 25                                         0                    0
# 26                                         1                    1
# 28                                         0                    0
# 29                                         0                    1
# 30                                         0                    0
# 31                                         0                    1
# 32                                         0                    0
# 33                                         0                    0
# 34                                         0                    0
# 36                                         0                    0
# 38                                         1                    0
# 43                                         0                    0
# 44                                         0                    0
# 45                                         0                    1
# 50                                         0                    0
# 63                                         0                    0
#
# artifactName        axon-configuration-4.9.3.jar  axon-disruptor-4.9.3.jar
# effectiveLineCount
# 1                                            310                        84
# 2                                            146                        31
# 3                                             34                        30
# 4                                             42                         8
# 5                                             16                         5
# 6                                             17                         6
# 7                                              3                         2
# 8                                              7                         0
# 9                                              8                         4
# 10                                             6                         3
# 11                                             5                         1
# 12                                             1                         1
# 13                                             2                         1
# 14                                             1                         2
# 15                                             0                         0
# 16                                             0                         0
# 17                                             1                         1
# 18                                             1                         1
# 19                                             1                         1
# 20                                             0                         0
# 21                                             1                         0
# 22                                             0                         1
# 23                                             1                         0
# 24                                             0                         1
# 25                                             0                         0
# 26                                             1                         0
# 28                                             0                         0
# 29                                             0                         0
# 30                                             0                         0
# 31                                             0                         0
# 32                                             0                         1
# 33                                             0                         0
# 34                                             0                         0
# 36                                             0                         0
# 38                                             0                         0
# 43                                             1                         0
# 44                                             0                         0
# 45                                             0                         0
# 50                                             1                         0
# 63                                             0                         0

# %% [markdown]
# ### Table 1b - Effective method line count distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
effective_method_line_count_distribution_normalized = effective_method_line_count_distribution.div(effective_method_line_count_distribution.sum(axis=0), axis=1).multiply(100)
effective_method_line_count_distribution_normalized.head(40)
# Out:
# artifactName        axon-messaging-4.9.3.jar  axon-eventsourcing-4.9.3.jar  \
# effectiveLineCount
# 1                                  51.431698                     50.175131
# 2                                  15.010031                     17.863398
# 3                                  12.292541                     11.120841
# 4                                   4.906073                      5.604203
# 5                                   4.012402                      3.415061
# 6                                   2.936349                      2.977233
# 7                                   1.878534                      2.802102
# 8                                   1.459055                      1.050788
# 9                                   1.386102                      1.488616
# 10                                  0.838957                      0.700525
# 11                                  0.820719                      0.175131
# 12                                  0.747766                      0.437828
# 13                                  0.474193                      0.175131
# 14                                  0.310049                      0.262697
# 15                                  0.164144                      0.175131
# 16                                  0.145906                      0.525394
# 17                                  0.182382                      0.000000
# 18                                  0.164144                      0.262697
# 19                                  0.109429                      0.000000
# 20                                  0.091191                      0.175131
# 21                                  0.127667                      0.175131
# 22                                  0.036476                      0.087566
# 23                                  0.091191                      0.175131
# 24                                  0.054715                      0.087566
# 25                                  0.036476                      0.087566
# 26                                  0.036476                      0.000000
# 28                                  0.036476                      0.000000
# 29                                  0.000000                      0.000000
# 30                                  0.018238                      0.000000
# 31                                  0.018238                      0.000000
# 32                                  0.018238                      0.000000
# 33                                  0.018238                      0.000000
# 34                                  0.018238                      0.000000
# 36                                  0.036476                      0.000000
# 38                                  0.000000                      0.000000
# 43                                  0.000000                      0.000000
# 44                                  0.018238                      0.000000
# 45                                  0.000000                      0.000000
# 50                                  0.018238                      0.000000
# 63                                  0.018238                      0.000000
#
# artifactName        axon-modelling-4.9.3.jar  axon-test-4.9.3.jar  \
# effectiveLineCount
# 1                                  49.396472            40.086207
# 2                                  14.670381            24.425287
# 3                                  13.091922             9.195402
# 4                                   5.292479             7.040230
# 5                                   4.178273             3.448276
# 6                                   4.178273             2.586207
# 7                                   2.228412             2.873563
# 8                                   0.928505             1.580460
# 9                                   1.578459             1.436782
# 10                                  0.742804             0.574713
# 11                                  0.742804             1.293103
# 12                                  0.185701             1.293103
# 13                                  0.835655             0.718391
# 14                                  0.278552             0.431034
# 15                                  0.464253             0.287356
# 16                                  0.185701             0.574713
# 17                                  0.185701             0.431034
# 18                                  0.000000             0.431034
# 19                                  0.092851             0.000000
# 20                                  0.185701             0.143678
# 21                                  0.092851             0.143678
# 22                                  0.185701             0.143678
# 23                                  0.000000             0.143678
# 24                                  0.092851             0.143678
# 25                                  0.000000             0.000000
# 26                                  0.092851             0.143678
# 28                                  0.000000             0.000000
# 29                                  0.000000             0.143678
# 30                                  0.000000             0.000000
# 31                                  0.000000             0.143678
# 32                                  0.000000             0.000000
# 33                                  0.000000             0.000000
# 34                                  0.000000             0.000000
# 36                                  0.000000             0.000000
# 38                                  0.092851             0.000000
# 43                                  0.000000             0.000000
# 44                                  0.000000             0.000000
# 45                                  0.000000             0.143678
# 50                                  0.000000             0.000000
# 63                                  0.000000             0.000000
#
# artifactName        axon-configuration-4.9.3.jar  axon-disruptor-4.9.3.jar
# effectiveLineCount
# 1                                      51.155116                 45.652174
# 2                                      24.092409                 16.847826
# 3                                       5.610561                 16.304348
# 4                                       6.930693                  4.347826
# 5                                       2.640264                  2.717391
# 6                                       2.805281                  3.260870
# 7                                       0.495050                  1.086957
# 8                                       1.155116                  0.000000
# 9                                       1.320132                  2.173913
# 10                                      0.990099                  1.630435
# 11                                      0.825083                  0.543478
# 12                                      0.165017                  0.543478
# 13                                      0.330033                  0.543478
# 14                                      0.165017                  1.086957
# 15                                      0.000000                  0.000000
# 16                                      0.000000                  0.000000
# 17                                      0.165017                  0.543478
# 18                                      0.165017                  0.543478
# 19                                      0.165017                  0.543478
# 20                                      0.000000                  0.000000
# 21                                      0.165017                  0.000000
# 22                                      0.000000                  0.543478
# 23                                      0.165017                  0.000000
# 24                                      0.000000                  0.543478
# 25                                      0.000000                  0.000000
# 26                                      0.165017                  0.000000
# 28                                      0.000000                  0.000000
# 29                                      0.000000                  0.000000
# 30                                      0.000000                  0.000000
# 31                                      0.000000                  0.000000
# 32                                      0.000000                  0.543478
# 33                                      0.000000                  0.000000
# 34                                      0.000000                  0.000000
# 36                                      0.000000                  0.000000
# 38                                      0.000000                  0.000000
# 43                                      0.165017                  0.000000
# 44                                      0.000000                  0.000000
# 45                                      0.000000                  0.000000
# 50                                      0.165017                  0.000000
# 63                                      0.000000                  0.000000

# %% [markdown]
# ### Table 1b Chart 1 - Effective method line count distribution (normalized)

# %%
if effective_method_line_count_distribution_normalized.empty:
    print("No data to plot")
else:
    plot.figure();
    method_line_count_x_ticks=range(1,20)
    axes = effective_method_line_count_distribution_normalized.head(20).plot(
        kind='line',
        logx=True,
        grid=True,
        xlim=[2, 20],
        ylim=[0, 20],
        xticks=method_line_count_x_ticks,
        title='Effective Method Line Count Distribution', 
        xlabel='effective line count',
        ylabel='percent of methods',
        cmap=main_color_map,
        figsize=(10, 6),
        lw=2,
    )
    axes.set_xticklabels(method_line_count_x_ticks)
    axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plot.show()

# %% [markdown]
# ### Table 1c - Top 30 packages with highest effective line counts
#
# The following table shows the top 30 packages with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Query artifacts and packages and find the method with the highest effective lines of code and cyclomatic complexity
# The result of this query will be also used further below. 
method_statistics_per_package = query_cypher_to_data_frame("../cypher/Overview/Effective_lines_of_method_code_per_package.cypher")

# %%
# Select and order the columns for this particular table 
effective_line_count_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'linesInPackage', 'methodCount', 'maxLinesMethod','maxLinesMethodName']]

# Print out the top 30 (head) rows
effective_line_count_per_package.head(30)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.9.3
# 1   axon-configuration-4.9.3
# 2       axon-messaging-4.9.3
# 3            axon-test-4.9.3
# 4       axon-messaging-4.9.3
# 5       axon-messaging-4.9.3
# 6       axon-modelling-4.9.3
# 7   axon-eventsourcing-4.9.3
# 8       axon-messaging-4.9.3
# 9       axon-modelling-4.9.3
# 10  axon-eventsourcing-4.9.3
# 11      axon-disruptor-4.9.3
# 12  axon-eventsourcing-4.9.3
# 13  axon-eventsourcing-4.9.3
# 14      axon-messaging-4.9.3
# 15      axon-messaging-4.9.3
# 16      axon-messaging-4.9.3
# 17           axon-test-4.9.3
# 18      axon-modelling-4.9.3
# 19      axon-messaging-4.9.3
# 20      axon-messaging-4.9.3
# 21      axon-messaging-4.9.3
# 22      axon-messaging-4.9.3
# 23      axon-messaging-4.9.3
# 24      axon-modelling-4.9.3
# 25      axon-messaging-4.9.3
# 26           axon-test-4.9.3
# 27      axon-messaging-4.9.3
# 28      axon-messaging-4.9.3
# 29  axon-eventsourcing-4.9.3
#
#                                       fullPackageName  linesInPackage  \
# 0                     org.axonframework.eventhandling            2333
# 1                            org.axonframework.config            1587
# 2              org.axonframework.eventhandling.pooled            1021
# 3                    org.axonframework.test.aggregate             951
# 4                     org.axonframework.queryhandling             927
# 5     org.axonframework.eventhandling.deadletter.jdbc             849
# 6                 org.axonframework.modelling.command             824
# 7          org.axonframework.eventsourcing.eventstore             712
# 8              org.axonframework.messaging.annotation             673
# 9      org.axonframework.modelling.command.inspection             637
# 10                    org.axonframework.eventsourcing             623
# 11        org.axonframework.disruptor.commandhandling             605
# 12  org.axonframework.eventsourcing.eventstore.leg...             573
# 13    org.axonframework.eventsourcing.eventstore.jdbc             568
# 14                    org.axonframework.serialization             537
# 15     org.axonframework.eventhandling.deadletter.jpa             522
# 16                           org.axonframework.common             501
# 17                        org.axonframework.test.saga             492
# 18                   org.axonframework.modelling.saga             490
# 19          org.axonframework.commandhandling.gateway             488
# 20      org.axonframework.commandhandling.distributed             477
# 21    org.axonframework.eventhandling.tokenstore.jdbc             430
# 22  org.axonframework.eventhandling.deadletter.leg...             401
# 23                  org.axonframework.commandhandling             377
# 24   org.axonframework.modelling.saga.repository.jdbc             374
# 25             org.axonframework.messaging.unitofwork             363
# 26                    org.axonframework.test.matchers             351
# 27                        org.axonframework.messaging             348
# 28             org.axonframework.deadline.dbscheduler             321
# 29     org.axonframework.eventsourcing.eventstore.jpa             318
#
#     methodCount  maxLinesMethod  \
# 0           838              64
# 1           606              50
# 2           333              78
# 3           249              45
# 4           381              36
# 5           249              31
# 6           329              17
# 7           264              21
# 8           239              23
# 9           218              26
# 10          251              20
# 11          184              32
# 12          187              25
# 13          236              24
# 14          181              22
# 15          132              28
# 16          144              24
# 17          168              29
# 18          194              22
# 19          174              50
# 20          175              23
# 21          130              26
# 22           97              21
# 23          169              13
# 24           84              38
# 25          129              32
# 26          108              21
# 27          156              13
# 28          103              18
# 29          101              23
#
#                                    maxLinesMethodName
# 0                                        processBatch
# 1                                              <init>
# 2                                                 run
# 3                                 appendEventOverview
# 4                                             doQuery
# 5                                     convertToLetter
# 6                          lambda$initializeHandler$7
# 7                                   peekPrivateStream
# 8                                              <init>
# 9                             inspectFieldsAndMethods
# 10                                 doScheduleSnapshot
# 11                                             <init>
# 12                                 fetchTrackedEvents
# 13                                             <init>
# 14                                             <init>
# 15                                             equals
# 16  getExactDirectSuperTypesOfParameterizedTypeOrC...
# 17                                             <init>
# 18                                             handle
# 19                                      createGateway
# 20                                           dispatch
# 21                                        updateToken
# 22                                            convert
# 23                                             <init>
# 24                                         updateSaga
# 25                                  executeWithResult
# 26                                     matchingFields
# 27                                     defaultHeaders
# 28                                            execute
# 29                                 fetchTrackedEvents

# %% [markdown]
# ### Table 1d - Top 30 methods with the highest effective line count
#
# The following table shows the top 30 methods with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
effective_line_count_method_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxLinesMethodType', 'maxLinesMethodName', 'maxLinesMethod', 'linesInPackage']]

# Sort by the maximum of effective lines of code per package descending
effective_line_count_method_per_package=effective_line_count_method_per_package.sort_values(by='maxLinesMethod', ascending=False)

# Reset the index to the new sort order
effective_line_count_method_per_package=effective_line_count_method_per_package.reset_index()

# Print out the top 30 (head) rows
effective_line_count_method_per_package.head(30)
# Out:
#     index              artifactName  \
# 0       2      axon-messaging-4.9.3
# 1       0      axon-messaging-4.9.3
# 2      19      axon-messaging-4.9.3
# 3       1  axon-configuration-4.9.3
# 4       3           axon-test-4.9.3
# 5      35      axon-messaging-4.9.3
# 6      24      axon-modelling-4.9.3
# 7       4      axon-messaging-4.9.3
# 8      30      axon-messaging-4.9.3
# 9      25      axon-messaging-4.9.3
# 10     11      axon-disruptor-4.9.3
# 11      5      axon-messaging-4.9.3
# 12     17           axon-test-4.9.3
# 13     15      axon-messaging-4.9.3
# 14      9      axon-modelling-4.9.3
# 15     21      axon-messaging-4.9.3
# 16     12  axon-eventsourcing-4.9.3
# 17     34      axon-messaging-4.9.3
# 18     13  axon-eventsourcing-4.9.3
# 19     16      axon-messaging-4.9.3
# 20     20      axon-messaging-4.9.3
# 21     29  axon-eventsourcing-4.9.3
# 22      8      axon-messaging-4.9.3
# 23     47      axon-messaging-4.9.3
# 24     32      axon-modelling-4.9.3
# 25     18      axon-modelling-4.9.3
# 26     14      axon-messaging-4.9.3
# 27     26           axon-test-4.9.3
# 28     22      axon-messaging-4.9.3
# 29      7  axon-eventsourcing-4.9.3
#
#                                       fullPackageName  \
# 0              org.axonframework.eventhandling.pooled
# 1                     org.axonframework.eventhandling
# 2           org.axonframework.commandhandling.gateway
# 3                            org.axonframework.config
# 4                    org.axonframework.test.aggregate
# 5                   org.axonframework.deadline.quartz
# 6    org.axonframework.modelling.saga.repository.jdbc
# 7                     org.axonframework.queryhandling
# 8              org.axonframework.messaging.deadletter
# 9              org.axonframework.messaging.unitofwork
# 10        org.axonframework.disruptor.commandhandling
# 11    org.axonframework.eventhandling.deadletter.jdbc
# 12                        org.axonframework.test.saga
# 13     org.axonframework.eventhandling.deadletter.jpa
# 14     org.axonframework.modelling.command.inspection
# 15    org.axonframework.eventhandling.tokenstore.jdbc
# 16  org.axonframework.eventsourcing.eventstore.leg...
# 17                         org.axonframework.deadline
# 18    org.axonframework.eventsourcing.eventstore.jdbc
# 19                           org.axonframework.common
# 20      org.axonframework.commandhandling.distributed
# 21     org.axonframework.eventsourcing.eventstore.jpa
# 22             org.axonframework.messaging.annotation
# 23                 org.axonframework.deadline.jobrunr
# 24        org.axonframework.modelling.saga.repository
# 25                   org.axonframework.modelling.saga
# 26                    org.axonframework.serialization
# 27                    org.axonframework.test.matchers
# 28  org.axonframework.eventhandling.deadletter.leg...
# 29         org.axonframework.eventsourcing.eventstore
#
#                                    maxLinesMethodType  \
# 0                        Coordinator$CoordinationTask
# 1                              TrackingEventProcessor
# 2                               CommandGatewayFactory
# 3                                   DefaultConfigurer
# 4                                            Reporter
# 5                                         DeadlineJob
# 6                                       JdbcSagaStore
# 7                                      SimpleQueryBus
# 8                    InMemorySequencedDeadLetterQueue
# 9                                  BatchingUnitOfWork
# 10                                DisruptorCommandBus
# 11                     DefaultDeadLetterJdbcConverter
# 12                                    SagaTestFixture
# 13                               DeadLetterEventEntry
# 14  AnnotatedAggregateMetaModelFactory$AnnotatedAg...
# 15                                     JdbcTokenStore
# 16                              JpaEventStorageEngine
# 17                 SimpleDeadlineManager$DeadlineTask
# 18                             JdbcEventStorageEngine
# 19                                TypeReflectionUtils
# 20                              DistributedCommandBus
# 21                              JpaEventStorageEngine
# 22                     AnnotatedMessageHandlingMember
# 23                             JobRunrDeadlineManager
# 24     AssociationValueMap$AssociationValueComparator
# 25                                AbstractSagaManager
# 26                          AbstractXStreamSerializer
# 27                                  DeepEqualsMatcher
# 28                 EventMessageDeadLetterJpaConverter
# 29                   EmbeddedEventStore$EventConsumer
#
#                                    maxLinesMethodName  maxLinesMethod  \
# 0                                                 run              78
# 1                                        processBatch              64
# 2                                       createGateway              50
# 3                                              <init>              50
# 4                                 appendEventOverview              45
# 5                                             execute              44
# 6                                          updateSaga              38
# 7                                             doQuery              36
# 8                                             process              33
# 9                                   executeWithResult              32
# 10                                             <init>              32
# 11                                    convertToLetter              31
# 12                                             <init>              29
# 13                                             equals              28
# 14                            inspectFieldsAndMethods              26
# 15                                        updateToken              26
# 16                                 fetchTrackedEvents              25
# 17                                                run              25
# 18                                             <init>              24
# 19  getExactDirectSuperTypesOfParameterizedTypeOrC...              24
# 20                                           dispatch              23
# 21                                 fetchTrackedEvents              23
# 22                                             <init>              23
# 23                                            execute              23
# 24                                            compare              22
# 25                                             handle              22
# 26                                             <init>              22
# 27                                     matchingFields              21
# 28                                            convert              21
# 29                                  peekPrivateStream              21
#
#     linesInPackage
# 0             1021
# 1             2333
# 2              488
# 3             1587
# 4              951
# 5              245
# 6              374
# 7              927
# 8              297
# 9              363
# 10             605
# 11             849
# 12             492
# 13             522
# 14             637
# 15             430
# 16             573
# 17             265
# 18             568
# 19             501
# 20             477
# 21             318
# 22             673
# 23             165
# 24             281
# 25             490
# 26             537
# 27             351
# 28             401
# 29             712

# %% [markdown]
# ## Cyclomatic Complexity

# %% [markdown]
# ### Table 2a - Cyclomatic method complexity distribution
#
# This table shows the distribution of the cyclomatic complexity of methods per artifact.
# For each artifact the number of methods with the cyclomatic complexity = 1,2,3,... is shown to get an overview of how cyclomatic complexity is distributed over methods.
#
# Only the 15 artifacts with the highest method count sum and their cyclomatic method complexity distribution (limited by 40) is shown here. The whole table can be found in the CSV report `Cyclomatic_Method_Complexity_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
cyclomatic_method_complexity_distribution_max_artifacts=15

cyclomatic_method_complexity_distribution=query_cypher_to_data_frame("../cypher/Overview/Cyclomatic_Method_Complexity_Distribution.cypher")
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.pivot(index='cyclomaticComplexity', columns='artifactName', values='methods')

# Fill missing values with zero
cyclomatic_method_complexity_distribution.fillna(0, inplace=True)

# Convert to integer
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
cyclomatic_method_complexity_distribution = cyclomatic_method_complexity_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:cyclomatic_method_complexity_distribution_max_artifacts]]

cyclomatic_method_complexity_distribution.head(40)
# Out:
# artifactName          axon-messaging-4.9.3.jar  axon-eventsourcing-4.9.3.jar  \
# cyclomaticComplexity
# 1                                         4414                           943
# 2                                          462                            94
# 3                                          283                            53
# 4                                          140                            24
# 5                                           74                             9
# 6                                           46                             4
# 7                                           20                             7
# 8                                           12                             7
# 9                                            7                             0
# 10                                           4                             0
# 11                                           9                             0
# 12                                           4                             0
# 13                                           2                             1
# 14                                           1                             0
# 15                                           1                             0
# 16                                           0                             0
# 17                                           1                             0
# 21                                           1                             0
# 22                                           1                             0
# 40                                           1                             0
#
# artifactName          axon-modelling-4.9.3.jar  axon-test-4.9.3.jar  \
# cyclomaticComplexity
# 1                                          895                  519
# 2                                           75                   60
# 3                                           38                   60
# 4                                           29                   22
# 5                                           24                   12
# 6                                           10                    9
# 7                                            2                    4
# 8                                            1                    3
# 9                                            2                    1
# 10                                           0                    1
# 11                                           0                    2
# 12                                           0                    2
# 13                                           0                    1
# 14                                           0                    0
# 15                                           0                    0
# 16                                           1                    0
# 17                                           0                    0
# 21                                           0                    0
# 22                                           0                    0
# 40                                           0                    0
#
# artifactName          axon-configuration-4.9.3.jar  axon-disruptor-4.9.3.jar
# cyclomaticComplexity
# 1                                              542                       146
# 2                                               37                        20
# 3                                               17                         5
# 4                                                5                         4
# 5                                                3                         3
# 6                                                0                         2
# 7                                                2                         2
# 8                                                0                         2
# 9                                                0                         0
# 10                                               0                         0
# 11                                               0                         0
# 12                                               0                         0
# 13                                               0                         0
# 14                                               0                         0
# 15                                               0                         0
# 16                                               0                         0
# 17                                               0                         0
# 21                                               0                         0
# 22                                               0                         0
# 40                                               0                         0

# %% [markdown]
# ### Table 2b - Cyclomatic method complexity distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
cyclomatic_method_complexity_distribution_normalized = cyclomatic_method_complexity_distribution.div(cyclomatic_method_complexity_distribution.sum(axis=0), axis=1).multiply(100)
cyclomatic_method_complexity_distribution_normalized.head(40)
# Out:
# artifactName          axon-messaging-4.9.3.jar  axon-eventsourcing-4.9.3.jar  \
# cyclomaticComplexity
# 1                                    80.503374                     82.574431
# 2                                     8.426044                      8.231173
# 3                                     5.161408                      4.640981
# 4                                     2.553347                      2.101576
# 5                                     1.349626                      0.788091
# 6                                     0.838957                      0.350263
# 7                                     0.364764                      0.612960
# 8                                     0.218858                      0.612960
# 9                                     0.127667                      0.000000
# 10                                    0.072953                      0.000000
# 11                                    0.164144                      0.000000
# 12                                    0.072953                      0.000000
# 13                                    0.036476                      0.087566
# 14                                    0.018238                      0.000000
# 15                                    0.018238                      0.000000
# 16                                    0.000000                      0.000000
# 17                                    0.018238                      0.000000
# 21                                    0.018238                      0.000000
# 22                                    0.018238                      0.000000
# 40                                    0.018238                      0.000000
#
# artifactName          axon-modelling-4.9.3.jar  axon-test-4.9.3.jar  \
# cyclomaticComplexity
# 1                                    83.101207            74.568966
# 2                                     6.963788             8.620690
# 3                                     3.528319             8.620690
# 4                                     2.692665             3.160920
# 5                                     2.228412             1.724138
# 6                                     0.928505             1.293103
# 7                                     0.185701             0.574713
# 8                                     0.092851             0.431034
# 9                                     0.185701             0.143678
# 10                                    0.000000             0.143678
# 11                                    0.000000             0.287356
# 12                                    0.000000             0.287356
# 13                                    0.000000             0.143678
# 14                                    0.000000             0.000000
# 15                                    0.000000             0.000000
# 16                                    0.092851             0.000000
# 17                                    0.000000             0.000000
# 21                                    0.000000             0.000000
# 22                                    0.000000             0.000000
# 40                                    0.000000             0.000000
#
# artifactName          axon-configuration-4.9.3.jar  axon-disruptor-4.9.3.jar
# cyclomaticComplexity
# 1                                        89.438944                 79.347826
# 2                                         6.105611                 10.869565
# 3                                         2.805281                  2.717391
# 4                                         0.825083                  2.173913
# 5                                         0.495050                  1.630435
# 6                                         0.000000                  1.086957
# 7                                         0.330033                  1.086957
# 8                                         0.000000                  1.086957
# 9                                         0.000000                  0.000000
# 10                                        0.000000                  0.000000
# 11                                        0.000000                  0.000000
# 12                                        0.000000                  0.000000
# 13                                        0.000000                  0.000000
# 14                                        0.000000                  0.000000
# 15                                        0.000000                  0.000000
# 16                                        0.000000                  0.000000
# 17                                        0.000000                  0.000000
# 21                                        0.000000                  0.000000
# 22                                        0.000000                  0.000000
# 40                                        0.000000                  0.000000

# %% [markdown]
# ### Table 2b Chart 1 - Cyclomatic method complexity distribution (normalized)

# %%
if cyclomatic_method_complexity_distribution_normalized.empty:
    print("No data to plot")
else:
    plot.figure();
    method_line_count_x_ticks=range(1,11)
    cyclomatic_complexity_y_ticks=[1, 2, 3, 4, 5, 7, 10, 20, 30, 40, 50, 100]
    axes = cyclomatic_method_complexity_distribution_normalized.plot(
        kind='line', 
        logx=True,
        logy=True,
        grid=True,
        xlim=[1,11],
        ylim=[1,100],
        xticks=method_line_count_x_ticks,
        yticks=cyclomatic_complexity_y_ticks,
        title='Cyclomatic complexity distribution of methods', 
        xlabel='cyclomatic complexity',
        ylabel='percentage of methods',
        cmap=main_color_map,
    )
    axes.set_xticklabels(method_line_count_x_ticks)
    axes.set_yticklabels(cyclomatic_complexity_y_ticks)
    axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plot.show()

# %% [markdown]
# ### Table 2c - Top 30 packages with highest cyclomatic complexity
#
# The following table shows the top 30 packages with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'complexityInPackage', 'methodCount', 'maxComplexity','maxComplexityMethod']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_package=cyclomatic_complexity_per_package.sort_values(by='complexityInPackage', ascending=False)

# Print out the top 30 (head) rows
cyclomatic_complexity_per_package.head(30)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.9.3
# 1   axon-configuration-4.9.3
# 4       axon-messaging-4.9.3
# 2       axon-messaging-4.9.3
# 6       axon-modelling-4.9.3
# 3            axon-test-4.9.3
# 7   axon-eventsourcing-4.9.3
# 8       axon-messaging-4.9.3
# 9       axon-modelling-4.9.3
# 10  axon-eventsourcing-4.9.3
# 5       axon-messaging-4.9.3
# 16      axon-messaging-4.9.3
# 12  axon-eventsourcing-4.9.3
# 14      axon-messaging-4.9.3
# 18      axon-modelling-4.9.3
# 11      axon-disruptor-4.9.3
# 13  axon-eventsourcing-4.9.3
# 19      axon-messaging-4.9.3
# 20      axon-messaging-4.9.3
# 17           axon-test-4.9.3
# 15      axon-messaging-4.9.3
# 27      axon-messaging-4.9.3
# 25      axon-messaging-4.9.3
# 23      axon-messaging-4.9.3
# 26           axon-test-4.9.3
# 31      axon-messaging-4.9.3
# 21      axon-messaging-4.9.3
# 30      axon-messaging-4.9.3
# 33      axon-messaging-4.9.3
# 29  axon-eventsourcing-4.9.3
#
#                                       fullPackageName  complexityInPackage  \
# 0                     org.axonframework.eventhandling                 1276
# 1                            org.axonframework.config                  716
# 4                     org.axonframework.queryhandling                  477
# 2              org.axonframework.eventhandling.pooled                  449
# 6                 org.axonframework.modelling.command                  445
# 3                    org.axonframework.test.aggregate                  434
# 7          org.axonframework.eventsourcing.eventstore                  397
# 8              org.axonframework.messaging.annotation                  386
# 9      org.axonframework.modelling.command.inspection                  339
# 10                    org.axonframework.eventsourcing                  325
# 5     org.axonframework.eventhandling.deadletter.jdbc                  304
# 16                           org.axonframework.common                  301
# 12  org.axonframework.eventsourcing.eventstore.leg...                  292
# 14                    org.axonframework.serialization                  285
# 18                   org.axonframework.modelling.saga                  277
# 11        org.axonframework.disruptor.commandhandling                  274
# 13    org.axonframework.eventsourcing.eventstore.jdbc                  273
# 19          org.axonframework.commandhandling.gateway                  249
# 20      org.axonframework.commandhandling.distributed                  243
# 17                        org.axonframework.test.saga                  235
# 15     org.axonframework.eventhandling.deadletter.jpa                  212
# 27                        org.axonframework.messaging                  209
# 25             org.axonframework.messaging.unitofwork                  206
# 23                  org.axonframework.commandhandling                  201
# 26                    org.axonframework.test.matchers                  191
# 31                   org.axonframework.common.caching                  182
# 21    org.axonframework.eventhandling.tokenstore.jdbc                  173
# 30             org.axonframework.messaging.deadletter                  169
# 33                          org.axonframework.tracing                  156
# 29     org.axonframework.eventsourcing.eventstore.jpa                  155
#
#     methodCount  maxComplexity  \
# 0           838             21
# 1           606              7
# 4           381             11
# 2           333             22
# 6           329              9
# 3           249             13
# 7           264             13
# 8           239             14
# 9           218              9
# 10          251              8
# 5           249             12
# 16          144              9
# 12          187              8
# 14          181              7
# 18          194              6
# 11          184              8
# 13          236              7
# 19          174             12
# 20          175             12
# 17          168              9
# 15          132             15
# 27          156              4
# 25          129             11
# 23          169             10
# 26          108              8
# 31          110              8
# 21          130              9
# 30          112             10
# 33          126              7
# 29          101              8
#
#                                   maxComplexityMethod
# 0                                        processBatch
# 1                             invokeLifecycleHandlers
# 4                                             doQuery
# 2                                                 run
# 6                                       resolveTarget
# 3                                   ensureValuesEqual
# 7                                             hasNext
# 8                                              handle
# 9                                     prepareHandlers
# 10                                 doScheduleSnapshot
# 5                                              equals
# 16  getExactDirectSuperTypesOfParameterizedTypeOrC...
# 12                                 fetchTrackedEvents
# 14                                     calculateRoute
# 18                     instantiateAssociationResolver
# 11                                           onResult
# 13                       lambda$fetchTrackedEvents$32
# 19                                      createGateway
# 20                                             equals
# 17                            assertDispatchedEqualTo
# 15                                             equals
# 27                                           endScope
# 25                                  executeWithResult
# 23                                             <init>
# 26                                        matchesList
# 31                                            onEvent
# 21                                        updateToken
# 30                                             equals
# 33                               determineMessageName
# 29                              loadKeyViolationCodes

# %% [markdown]
# ### Table 2d - Top 30 methods with highest cyclomatic complexity
#
# The following table shows the top 30 packages containing the methods with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_method=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxComplexityType', 'maxComplexityMethod', 'maxComplexity']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.sort_values(by='maxComplexity', ascending=False)

# Reset the index to the new sort order
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.reset_index()

# Print out the top 30 (head) rows
cyclomatic_complexity_per_method.head(30)
# Out:
#     index              artifactName  \
# 0      51      axon-messaging-4.9.3
# 1       2      axon-messaging-4.9.3
# 2       0      axon-messaging-4.9.3
# 3      32      axon-modelling-4.9.3
# 4      15      axon-messaging-4.9.3
# 5       8      axon-messaging-4.9.3
# 6       7  axon-eventsourcing-4.9.3
# 7      52      axon-messaging-4.9.3
# 8      47      axon-messaging-4.9.3
# 9       3           axon-test-4.9.3
# 10      5      axon-messaging-4.9.3
# 11     37      axon-messaging-4.9.3
# 12     39           axon-test-4.9.3
# 13     19      axon-messaging-4.9.3
# 14     20      axon-messaging-4.9.3
# 15     22      axon-messaging-4.9.3
# 16     35      axon-messaging-4.9.3
# 17      4      axon-messaging-4.9.3
# 18     28      axon-messaging-4.9.3
# 19     25      axon-messaging-4.9.3
# 20     23      axon-messaging-4.9.3
# 21     40      axon-messaging-4.9.3
# 22     49      axon-messaging-4.9.3
# 23     30      axon-messaging-4.9.3
# 24     21      axon-messaging-4.9.3
# 25      6      axon-modelling-4.9.3
# 26     17           axon-test-4.9.3
# 27     16      axon-messaging-4.9.3
# 28     50      axon-messaging-4.9.3
# 29      9      axon-modelling-4.9.3
#
#                                       fullPackageName  \
# 0   org.axonframework.eventhandling.scheduling.job...
# 1              org.axonframework.eventhandling.pooled
# 2                     org.axonframework.eventhandling
# 3         org.axonframework.modelling.saga.repository
# 4      org.axonframework.eventhandling.deadletter.jpa
# 5              org.axonframework.messaging.annotation
# 6          org.axonframework.eventsourcing.eventstore
# 7   org.axonframework.commandhandling.distributed....
# 8                  org.axonframework.deadline.jobrunr
# 9                    org.axonframework.test.aggregate
# 10    org.axonframework.eventhandling.deadletter.jdbc
# 11                      org.axonframework.common.jdbc
# 12                      org.axonframework.test.server
# 13          org.axonframework.commandhandling.gateway
# 14      org.axonframework.commandhandling.distributed
# 15  org.axonframework.eventhandling.deadletter.leg...
# 16                  org.axonframework.deadline.quartz
# 17                    org.axonframework.queryhandling
# 18             org.axonframework.deadline.dbscheduler
# 19             org.axonframework.messaging.unitofwork
# 20                  org.axonframework.commandhandling
# 21          org.axonframework.messaging.responsetypes
# 22                      org.axonframework.common.lock
# 23             org.axonframework.messaging.deadletter
# 24    org.axonframework.eventhandling.tokenstore.jdbc
# 25                org.axonframework.modelling.command
# 26                        org.axonframework.test.saga
# 27                           org.axonframework.common
# 28               org.axonframework.serialization.json
# 29     org.axonframework.modelling.command.inspection
#
#                                     maxComplexityType  \
# 0                               JobRunrEventScheduler
# 1                        Coordinator$CoordinationTask
# 2                              TrackingEventProcessor
# 3      AssociationValueMap$AssociationValueComparator
# 4                                DeadLetterEventEntry
# 5                      AnnotatedMessageHandlingMember
# 6                      ConcatenatingDomainEventStream
# 7                                   CommandNameFilter
# 8                              JobRunrDeadlineManager
# 9                                AggregateTestFixture
# 10                                     JdbcDeadLetter
# 11                           ConnectionWrapperFactory
# 12                                AxonServerContainer
# 13                              CommandGatewayFactory
# 14                                       ReplyMessage
# 15                                      JpaDeadLetter
# 16                                        DeadlineJob
# 17                                     SimpleQueryBus
# 18                   DbSchedulerBinaryDeadlineDetails
# 19                                 BatchingUnitOfWork
# 20  MethodCommandHandlerDefinition$MethodCommandMe...
# 21                      MultipleInstancesResponseType
# 22              PessimisticLockFactory$DisposableLock
# 23                                  GenericDeadLetter
# 24                                     JdbcTokenStore
# 25                    AnnotationCommandTargetResolver
# 26                                   CommandValidator
# 27                                TypeReflectionUtils
# 28                                  JacksonSerializer
# 29  AnnotatedAggregateMetaModelFactory$AnnotatedAg...
#
#                                   maxComplexityMethod  maxComplexity
# 0                                 $deserializeLambda$             40
# 1                                                 run             22
# 2                                        processBatch             21
# 3                                             compare             16
# 4                                              equals             15
# 5                                              handle             14
# 6                                             hasNext             13
# 7                                 $deserializeLambda$             13
# 8                                 $deserializeLambda$             13
# 9                                   ensureValuesEqual             13
# 10                                             equals             12
# 11                                      lambda$wrap$0             12
# 12                                             equals             12
# 13                                      createGateway             12
# 14                                             equals             12
# 15                                             equals             11
# 16                                            execute             11
# 17                                            doQuery             11
# 18                                             equals             11
# 19                                  executeWithResult             11
# 20                                             <init>             10
# 21                                            convert             10
# 22                                               lock             10
# 23                                             equals             10
# 24                                        updateToken              9
# 25                                      resolveTarget              9
# 26                            assertDispatchedEqualTo              9
# 27  getExactDirectSuperTypesOfParameterizedTypeOrC...              9
# 28                                        deserialize              9
# 29                                    prepareHandlers              9
