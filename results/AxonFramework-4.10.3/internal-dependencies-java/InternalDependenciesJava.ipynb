# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename : str, limit: int = 10_000):
    cypher_query_template = "{query}\nLIMIT {row_limit}"
    cypher_query = get_cypher_query_from_file(filename)
    cypher_query = cypher_query_template.format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = 10_000):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Pandas DataFrame Display Configuration
pd.set_option('display.max_colwidth', 300)

# %% [markdown]
# ## Artifacts
#
# List the artifacts this notebook is based on. Different sorting variations help finding artifacts by their features and support larger code bases where the list of all artifacts gets too long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_Java_artifacts`

# %%
artifacts = query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_all_Java_artifacts.cypher")

# %% [markdown]
# ### Table 1a - Top 30 artifacts with the highest package count

# %%
# Sort by number of packages descending
artifacts.sort_values(by=['packages','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.10.3.jar        64    787
# 1           axon-server-connector-4.10.3.jar        11    136
# 2                  axon-modelling-4.10.3.jar        10    158
# 3              axon-eventsourcing-4.10.3.jar         9    133
# 4  axon-spring-boot-autoconfigure-4.10.3.jar         9     75
# 5                       axon-test-4.10.3.jar         8     87
# 6              axon-configuration-4.10.3.jar         1     41
# 7                  axon-disruptor-4.10.3.jar         1     22
# 8      axon-tracing-opentelemetry-4.10.3.jar         1      5
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     1                     4
# 2                     6                     1
# 3                     5                     2
# 4                     0                     7
# 5                     1                     3
# 6                     2                     4
# 7                     1                     3
# 8                     1                     1

# %% [markdown]
# ### Table 1b - Top 30 artifacts with the highest type count

# %%
# Sort by number of types descending
artifacts.sort_values(by=['types','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.10.3.jar        64    787
# 1                  axon-modelling-4.10.3.jar        10    158
# 2           axon-server-connector-4.10.3.jar        11    136
# 3              axon-eventsourcing-4.10.3.jar         9    133
# 4                       axon-test-4.10.3.jar         8     87
# 5  axon-spring-boot-autoconfigure-4.10.3.jar         9     75
# 6              axon-configuration-4.10.3.jar         1     41
# 7                  axon-disruptor-4.10.3.jar         1     22
# 8      axon-tracing-opentelemetry-4.10.3.jar         1      5
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     1                     4
# 3                     5                     2
# 4                     1                     3
# 5                     0                     7
# 6                     2                     4
# 7                     1                     3
# 8                     1                     1

# %% [markdown]
# ### Table 1c - Top 30 artifacts with the highest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the most by other artifacts (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.10.3.jar        64    787
# 1                  axon-modelling-4.10.3.jar        10    158
# 2              axon-eventsourcing-4.10.3.jar         9    133
# 3              axon-configuration-4.10.3.jar         1     41
# 4                  axon-disruptor-4.10.3.jar         1     22
# 5           axon-server-connector-4.10.3.jar        11    136
# 6                       axon-test-4.10.3.jar         8     87
# 7      axon-tracing-opentelemetry-4.10.3.jar         1      5
# 8  axon-spring-boot-autoconfigure-4.10.3.jar         9     75
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     5                     2
# 3                     2                     4
# 4                     1                     3
# 5                     1                     4
# 6                     1                     3
# 7                     1                     1
# 8                     0                     7

# %% [markdown]
# ### Table 1d - Top 30 artifacts with the highest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the highest number of other artifacts (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0  axon-spring-boot-autoconfigure-4.10.3.jar         9     75
# 1              axon-configuration-4.10.3.jar         1     41
# 2           axon-server-connector-4.10.3.jar        11    136
# 3                  axon-disruptor-4.10.3.jar         1     22
# 4                       axon-test-4.10.3.jar         8     87
# 5              axon-eventsourcing-4.10.3.jar         9    133
# 6                  axon-modelling-4.10.3.jar        10    158
# 7      axon-tracing-opentelemetry-4.10.3.jar         1      5
# 8                  axon-messaging-4.10.3.jar        64    787
#
#    incomingDependencies  outgoingDependencies
# 0                     0                     7
# 1                     2                     4
# 2                     1                     4
# 3                     1                     3
# 4                     1                     3
# 5                     5                     2
# 6                     6                     1
# 7                     1                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1e - Top 30 artifacts with the lowest package count

# %%
# Sort by number of packages ascending
artifacts.sort_values(by=['packages','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0              axon-configuration-4.10.3.jar         1     41
# 1                  axon-disruptor-4.10.3.jar         1     22
# 2      axon-tracing-opentelemetry-4.10.3.jar         1      5
# 3                       axon-test-4.10.3.jar         8     87
# 4              axon-eventsourcing-4.10.3.jar         9    133
# 5  axon-spring-boot-autoconfigure-4.10.3.jar         9     75
# 6                  axon-modelling-4.10.3.jar        10    158
# 7           axon-server-connector-4.10.3.jar        11    136
# 8                  axon-messaging-4.10.3.jar        64    787
#
#    incomingDependencies  outgoingDependencies
# 0                     2                     4
# 1                     1                     3
# 2                     1                     1
# 3                     1                     3
# 4                     5                     2
# 5                     0                     7
# 6                     6                     1
# 7                     1                     4
# 8                     8                     0

# %% [markdown]
# ### Table 1f - Top 30 artifacts with the lowest type count

# %%
# Sort by number of types ascending
artifacts.sort_values(by=['types','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0      axon-tracing-opentelemetry-4.10.3.jar         1      5
# 1                  axon-disruptor-4.10.3.jar         1     22
# 2              axon-configuration-4.10.3.jar         1     41
# 3  axon-spring-boot-autoconfigure-4.10.3.jar         9     75
# 4                       axon-test-4.10.3.jar         8     87
# 5              axon-eventsourcing-4.10.3.jar         9    133
# 6           axon-server-connector-4.10.3.jar        11    136
# 7                  axon-modelling-4.10.3.jar        10    158
# 8                  axon-messaging-4.10.3.jar        64    787
#
#    incomingDependencies  outgoingDependencies
# 0                     1                     1
# 1                     1                     3
# 2                     2                     4
# 3                     0                     7
# 4                     1                     3
# 5                     5                     2
# 6                     1                     4
# 7                     6                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1g - Top 30 artifacts with the lowest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the least by other artifacts (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0  axon-spring-boot-autoconfigure-4.10.3.jar         9     75
# 1                  axon-disruptor-4.10.3.jar         1     22
# 2           axon-server-connector-4.10.3.jar        11    136
# 3                       axon-test-4.10.3.jar         8     87
# 4      axon-tracing-opentelemetry-4.10.3.jar         1      5
# 5              axon-configuration-4.10.3.jar         1     41
# 6              axon-eventsourcing-4.10.3.jar         9    133
# 7                  axon-modelling-4.10.3.jar        10    158
# 8                  axon-messaging-4.10.3.jar        64    787
#
#    incomingDependencies  outgoingDependencies
# 0                     0                     7
# 1                     1                     3
# 2                     1                     4
# 3                     1                     3
# 4                     1                     1
# 5                     2                     4
# 6                     5                     2
# 7                     6                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1h - Top 30 artifacts with the lowest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the lowest number of other artifacts (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.10.3.jar        64    787
# 1                  axon-modelling-4.10.3.jar        10    158
# 2      axon-tracing-opentelemetry-4.10.3.jar         1      5
# 3              axon-eventsourcing-4.10.3.jar         9    133
# 4                  axon-disruptor-4.10.3.jar         1     22
# 5                       axon-test-4.10.3.jar         8     87
# 6              axon-configuration-4.10.3.jar         1     41
# 7           axon-server-connector-4.10.3.jar        11    136
# 8  axon-spring-boot-autoconfigure-4.10.3.jar         9     75
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     1                     1
# 3                     5                     2
# 4                     1                     3
# 5                     1                     3
# 6                     2                     4
# 7                     1                     4
# 8                     0                     7

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to problems when one of these packages needs to be changed.

# %% [markdown]
# ## Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies`
#
# **Columns:**
# - *artifactName* identifies the artifact of the first participant of the cycle
# - *packageName* identifies the package of the first participant of the cycle
# - *dependentArtifactName* identifies the artifact of the second participant of the cycle
# - *dependentPackageName* identifies the package of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies.cypher")
cyclic_dependencies.head(40)
# Out:
#                     artifactName  \
# 0          axon-messaging-4.10.3
# 1          axon-messaging-4.10.3
# 2          axon-messaging-4.10.3
# 3          axon-messaging-4.10.3
# 4          axon-messaging-4.10.3
# 5          axon-messaging-4.10.3
# 6          axon-messaging-4.10.3
# 7      axon-eventsourcing-4.10.3
# 8          axon-messaging-4.10.3
# 9   axon-server-connector-4.10.3
# 10         axon-messaging-4.10.3
# 11         axon-messaging-4.10.3
# 12  axon-server-connector-4.10.3
# 13  axon-server-connector-4.10.3
# 14         axon-messaging-4.10.3
# 15         axon-messaging-4.10.3
# 16  axon-server-connector-4.10.3
# 17  axon-server-connector-4.10.3
# 18         axon-messaging-4.10.3
# 19     axon-eventsourcing-4.10.3
# 20         axon-messaging-4.10.3
# 21         axon-modelling-4.10.3
# 22         axon-messaging-4.10.3
# 23         axon-messaging-4.10.3
# 24  axon-server-connector-4.10.3
# 25         axon-messaging-4.10.3
# 26         axon-modelling-4.10.3
# 27         axon-messaging-4.10.3
#
#                                                     packageName  \
# 0                               org.axonframework.eventhandling
# 1                               org.axonframework.queryhandling
# 2                               org.axonframework.queryhandling
# 3                               org.axonframework.eventhandling
# 4                               org.axonframework.eventhandling
# 5                                    org.axonframework.deadline
# 6                             org.axonframework.commandhandling
# 7                               org.axonframework.eventsourcing
# 8                   org.axonframework.commandhandling.callbacks
# 9                   org.axonframework.axonserver.connector.util
# 10                              org.axonframework.eventhandling
# 11                       org.axonframework.messaging.unitofwork
# 12            org.axonframework.axonserver.connector.event.axon
# 13                 org.axonframework.axonserver.connector.query
# 14                        org.axonframework.eventhandling.async
# 15                       org.axonframework.eventhandling.replay
# 16                       org.axonframework.axonserver.connector
# 17                 org.axonframework.axonserver.connector.query
# 18              org.axonframework.serialization.upcasting.event
# 19              org.axonframework.eventsourcing.eventstore.jdbc
# 20                              org.axonframework.eventhandling
# 21               org.axonframework.modelling.command.inspection
# 22                 org.axonframework.queryhandling.registration
# 23                                  org.axonframework.messaging
# 24               org.axonframework.axonserver.connector.command
# 25                       org.axonframework.messaging.annotation
# 26                             org.axonframework.modelling.saga
# 27  org.axonframework.commandhandling.distributed.commandfilter
#
#            dependentArtifactName  \
# 0          axon-messaging-4.10.3
# 1          axon-messaging-4.10.3
# 2          axon-messaging-4.10.3
# 3          axon-messaging-4.10.3
# 4          axon-messaging-4.10.3
# 5          axon-messaging-4.10.3
# 6          axon-messaging-4.10.3
# 7      axon-eventsourcing-4.10.3
# 8          axon-messaging-4.10.3
# 9   axon-server-connector-4.10.3
# 10         axon-messaging-4.10.3
# 11         axon-messaging-4.10.3
# 12  axon-server-connector-4.10.3
# 13  axon-server-connector-4.10.3
# 14         axon-messaging-4.10.3
# 15         axon-messaging-4.10.3
# 16  axon-server-connector-4.10.3
# 17  axon-server-connector-4.10.3
# 18         axon-messaging-4.10.3
# 19     axon-eventsourcing-4.10.3
# 20         axon-messaging-4.10.3
# 21         axon-modelling-4.10.3
# 22         axon-messaging-4.10.3
# 23         axon-messaging-4.10.3
# 24  axon-server-connector-4.10.3
# 25         axon-messaging-4.10.3
# 26         axon-modelling-4.10.3
# 27         axon-messaging-4.10.3
#
#                                           dependentPackageName  \
# 0                                    org.axonframework.tracing
# 1                    org.axonframework.messaging.responsetypes
# 2                                    org.axonframework.tracing
# 3                                  org.axonframework.messaging
# 4                       org.axonframework.messaging.annotation
# 5                                    org.axonframework.tracing
# 6                                    org.axonframework.tracing
# 7                   org.axonframework.eventsourcing.eventstore
# 8                            org.axonframework.commandhandling
# 9                       org.axonframework.axonserver.connector
# 10                             org.axonframework.serialization
# 11                                 org.axonframework.messaging
# 12                      org.axonframework.axonserver.connector
# 13                      org.axonframework.axonserver.connector
# 14                             org.axonframework.eventhandling
# 15                             org.axonframework.eventhandling
# 16           org.axonframework.axonserver.connector.event.util
# 17   org.axonframework.axonserver.connector.query.subscription
# 18                             org.axonframework.eventhandling
# 19  org.axonframework.eventsourcing.eventstore.jdbc.statements
# 20                  org.axonframework.eventhandling.tokenstore
# 21                         org.axonframework.modelling.command
# 22                             org.axonframework.queryhandling
# 23                             org.axonframework.serialization
# 24                      org.axonframework.axonserver.connector
# 25                    org.axonframework.messaging.interceptors
# 26                  org.axonframework.modelling.saga.metamodel
# 27               org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.840000             23               2
# 5                   0.800000              9               1
# 6                   0.777778              8               1
# 7                   0.777778             16               2
# 8                   0.733333             13               2
# 9                   0.666667              5               1
# 10                  0.647059             14               3
# 11                  0.647059             14               3
# 12                  0.615385             21               5
# 13                  0.571429             22               6
# 14                  0.538462             10               3
# 15                  0.454545              8               3
# 16                  0.333333              2               1
# 17                  0.333333              4               2
# 18                  0.333333              6               3
# 19                  0.317073             27              14
# 20                  0.285714              9               5
# 21                  0.250000             20              12
# 22                  0.250000              5               3
# 23                  0.238095             13               8
# 24                  0.222222             11               7
# 25                  0.200000              3               2
# 26                  0.142857              4               3
# 27                  0.076923              7               6
#
#                                                                                                                                                                                                                                                                                         someForwardDependencies  \
# 0   [DefaultEventProcessorSpanFactory->NoOpSpanFactory$NoOpSpan, DefaultEventProcessorSpanFactory->SpanFactory, DefaultEventProcessorSpanFactory->Span, SubscribingEventProcessor$Builder->SpanFactory, DefaultEventProcessorSpanFactory$Builder->SpanFactory, EventProcessorSpanFactory->Span, SimpleEventB...
# 1   [SubscriptionQueryMessage->ResponseType, QueryMessage->ResponseType, QuerySubscription->ResponseType, GenericQueryMessage->ResponseType, QueryGateway->ResponseType, QueryGateway->ResponseTypes, StreamingQueryMessage->ResponseType, SimpleQueryBus->ResponseType, GenericStreamingQueryMessage->Respo...
# 2   [DefaultQueryBusSpanFactory->Span, DefaultQueryBusSpanFactory->SpanFactory, QueryBusSpanFactory->Span, SimpleQueryBus->Span, SimpleQueryBus->SpanScope, DefaultQueryUpdateEmitterSpanFactory->SpanFactory, DefaultQueryUpdateEmitterSpanFactory->Span, SimpleQueryBus$Builder->SpanFactory, SimpleQueryB...
# 3   [MultiStreamableMessageSource$Builder->StreamableMessageSource, MultiStreamableMessageSource->StreamableMessageSource, EventMessageHandler->Message, EventMessageHandler->MessageHandler, DefaultEventProcessorSpanFactory->Message, TrackingTokenParameterResolverFactory$TrackingTokenParameterResolve...
# 4   [TrackingTokenParameterResolverFactory$TrackingTokenParameterResolver->ParameterResolver, TimestampParameterResolverFactory->ParameterResolver, TimestampParameterResolverFactory->AbstractAnnotatedParameterResolverFactory, ResetHandler->MessageHandler, ConcludesBatchParameterResolverFactory->Abst...
# 5   [SimpleDeadlineManager$DeadlineTask->SpanScope, SimpleDeadlineManager$DeadlineTask->Span, DefaultDeadlineManagerSpanFactory$Builder->SpanFactory, SimpleDeadlineManager->Span, DeadlineManagerSpanFactory->Span, SimpleDeadlineManager$Builder->SpanFactory, SimpleDeadlineManager$Builder->NoOpSpanFact...
# 6   [DefaultCommandBusSpanFactory$Builder->SpanFactory, AsynchronousCommandBus$Builder->SpanFactory, SimpleCommandBus->Span, CommandBusSpanFactory->Span, DefaultCommandBusSpanFactory->SpanFactory, DefaultCommandBusSpanFactory->Span, SimpleCommandBus$Builder->NoOpSpanFactory, SimpleCommandBus$Builder...
# 7   [AbstractSnapshotter$CreateSnapshotTask->EventStore, AbstractSnapshotter$CreateSnapshotTask->DomainEventStream, AggregateCacheEntry->EventStore, AggregateSnapshotter$Builder->EventStore, FilteringEventStorageEngine->DomainEventStream, FilteringEventStorageEngine->EventStorageEngine, AbstractSnap...
# 8   [FutureCallback->CommandResultMessage, FutureCallback->GenericCommandResultMessage, FutureCallback->CommandCallback, FutureCallback->CommandMessage, NoOpCallback->CommandMessage, NoOpCallback->CommandResultMessage, NoOpCallback->CommandCallback, LoggingCallback->CommandMessage, LoggingCallback->...
# 9                              [PriorityExecutorService->PriorityCallable, PriorityExecutorService->PriorityRunnable, ExecutorServiceBuilder->AxonServerConfiguration, FlowControllingStreamObserver->AxonServerConfiguration, FlowControllingStreamObserver->AxonServerConfiguration$FlowControlConfiguration]
# 10  [AbstractEventEntry->SimpleSerializedObject, AbstractEventEntry->SerializedType, AbstractEventEntry->SerializedObject, AbstractEventEntry->Serializer, AbstractEventEntry->SimpleSerializedType, AbstractEventEntry->SerializedMetaData, AbstractSequencedDomainEventEntry->Serializer, AbstractDomainEv...
# 11  [BatchingUnitOfWork->ResultMessage, BatchingUnitOfWork->Message, BatchingUnitOfWork->GenericResultMessage, MessageProcessingContext->Message, AbstractUnitOfWork->MetaData, AbstractUnitOfWork->Message, DefaultUnitOfWork->Message, DefaultUnitOfWork->ResultMessage, DefaultUnitOfWork->GenericResultM...
# 12  [AxonServerEventStore$AxonIQEventStorageEngine->AxonServerConnectionManager, AxonServerEventStore$AxonIQEventStorageEngine->AxonServerConfiguration, AxonServerEventStore$AxonIQEventStorageEngine->AxonServerConfiguration$FlowControlConfiguration, AxonServerEventStore$AxonIQEventStorageEngine$Buil...
# 13  [AxonServerQueryBus->DispatchInterceptors, AxonServerQueryBus->AxonServerConfiguration, AxonServerQueryBus->TargetContextResolver, AxonServerQueryBus->ErrorCode, AxonServerQueryBus->PriorityRunnable, AxonServerQueryBus->AxonServerConnectionManager, AxonServerQueryBus->AxonServerConfiguration$Flo...
# 14  [AsynchronousEventProcessingStrategy->EventProcessingStrategy, AsynchronousEventProcessingStrategy->EventMessage, EventProcessorTask$ProcessingTask->EventMessage, EventProcessorTask->EventMessage, FullConcurrencyPolicy->EventMessage, PropertySequencingPolicy->EventMessage, PropertySequencingPoli...
# 15  [ReplayParameterResolverFactory->ReplayStatus, ReplayAwareMessageHandlerWrapper->AllowReplay, ReplayContextParameterResolverFactory$ReplayContextParameterResolver->TrackedEventMessage, ReplayContextParameterResolverFactory$ReplayContextParameterResolver->EventMessage, ReplayContextParameterResol...
# 16                                                                                                                                                                                                                         [AxonServerConfiguration->EventCipher, AxonServerConfiguration$Builder->EventCipher]
# 17                                                                 [AxonServerQueryBus->SubscriptionMessageSerializer, AxonServerQueryBus->AxonServerSubscriptionQueryResult, AxonServerQueryBus$LocalSegmentAdapter->SubscriptionMessageSerializer, AxonServerQueryBus$Builder->SubscriptionMessageSerializer]
# 18                                    [InitialEventRepresentation->EventData, InitialEventRepresentation->DomainEventData, InitialEventRepresentation->TrackedEventData, InitialEventRepresentation->TrackingToken, UpcastedEventRepresentation->TrackingToken, IntermediateEventRepresentation->TrackingToken]
# 19  [JdbcEventStorageEngine$Builder->ReadEventDataForAggregateStatementBuilder, JdbcEventStorageEngine$Builder->CreateTailTokenStatementBuilder, JdbcEventStorageEngine$Builder->DeleteSnapshotsStatementBuilder, JdbcEventStorageEngine$Builder->ReadSnapshotDataStatementBuilder, JdbcEventStorageEngine$B...
# 20  [TrackingEventProcessor$WorkerLauncher->TokenStore, TrackingEventProcessor$WorkerLauncher->UnableToClaimTokenException, TrackingEventProcessor$Instruction->UnableToClaimTokenException, TrackingEventProcessor$SplitSegmentInstruction->TokenStore, TrackingEventProcessor$MergeSegmentInstruction->Tok...
# 21  [MethodCreationPolicyDefinition->CreationPolicy, AggregateMemberAnnotatedChildEntityCollectionDefinition->ForwardingMode, AnnotatedAggregate->Aggregate, AnnotatedAggregate->AggregateLifecycle, AnnotatedAggregate->RepositoryProvider, AnnotatedAggregate->AggregateInvocationException, AnnotatedAggr...
# 22                      [FailingDuplicateQueryHandlerResolver->QuerySubscription, DuplicateQueryHandlerResolution->QuerySubscription, DuplicateQueryHandlerSubscriptionException->QuerySubscription, DuplicateQueryHandlerResolver->QuerySubscription, LoggingDuplicateQueryHandlerResolver->QuerySubscription]
# 23                 [GenericMessage->SerializedObjectHolder, GenericMessage->SerializedObject, GenericMessage->Serializer, ResultMessage->SerializedObject, ResultMessage->Serializer, GenericResultMessage->SerializedObject, GenericResultMessage->Serializer, Message->SerializedObject, Message->Serializer]
# 24  [AxonServerCommandBus$Builder->AxonServerConnectionManager, AxonServerCommandBus$Builder->TargetContextResolver, AxonServerCommandBus$Builder->AxonServerConfiguration, AxonServerCommandBus->AxonServerConnectionManager, AxonServerCommandBus->AxonServerConfiguration, AxonServerCommandBus->TargetCo...
# 25                                                                                                                                          [ResultParameterResolverFactory->ResultHandler, MessageHandlerInterceptorDefinition->ResultHandler, MessageHandlerInterceptorDefinition->MessageHandlerInterceptor]
# 26                                                                                                                                           [AnnotatedSagaManager$Builder->AnnotationSagaMetaModelFactory, AnnotatedSagaManager$Builder->SagaModel, AnnotatedSagaManager->SagaModel, AnnotatedSaga->SagaModel]
# 27        [NegateCommandMessageFilter->CommandMessageFilter, DenyCommandNameFilter->CommandMessageFilter, DenyAll->CommandMessageFilter, CommandNameFilter->CommandMessageFilter, OrCommandMessageFilter->CommandMessageFilter, AcceptAll->CommandMessageFilter, AndCommandMessageFilter->CommandMessageFilter]
#
#                                                                                                                                                                                                                                                                                            backwardDependencies
# 0                                                                                                                                                                                                                                                                            [NestingSpanFactory->EventMessage]
# 1                                                                                                                                                                                                                                                             [ConvertingResponseMessage->QueryResponseMessage]
# 2                                                                                                                                                                                                                                                                                     [SpanUtils->QueryMessage]
# 3                                                                                                                                                                                                                  [StreamableMessageSource->TrackingToken, Headers->EventMessage, Headers->DomainEventMessage]
# 4                                                                                                                                    [SourceIdParameterResolverFactory$SourceIdParameterResolver->DomainEventMessage, AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->DomainEventMessage]
# 5                                                                                                                                                                                                                                                                                  [SpanUtils->DeadlineMessage]
# 6                                                                                                                                                                                                                                                                                   [SpanUtils->CommandMessage]
# 7                                                                                                                                                                                                                           [AbstractEventStorageEngine->EventStreamUtils, DomainEventStream->EventStreamUtils]
# 8                                                                                                                                                                                                                           [SimpleCommandBus$Builder->NoOpCallback, SimpleCommandBus$Builder->LoggingCallback]
# 9                                                                                                                                                                                                                                                                              [ErrorCode->ExceptionSerializer]
# 10                                                                                                                                                [GapAwareTrackingTokenConverter->GapAwareTrackingToken, AbstractXStreamSerializer->GenericDomainEventMessage, AbstractXStreamSerializer->GenericEventMessage]
# 11                                                                                                                                                                                              [GenericMessage->CurrentUnitOfWork, MessageHandlerInterceptor->UnitOfWork, DefaultInterceptorChain->UnitOfWork]
# 12  [ServerConnectorConfigurerModule->AxonServerEventStoreFactory, ServerConnectorConfigurerModule->AxonServerEventStore, ServerConnectorConfigurerModule->AxonServerEventStore$Builder, ServerConnectorConfigurerModule->AxonServerEventStoreFactory$Builder, ServerConnectorConfigurerModule->EventProcess...
# 13  [ServerConnectorConfigurerModule->AxonServerQueryBus$Builder, ServerConnectorConfigurerModule->AxonServerQueryBus, ServerConnectorConfigurerModule->QueryPriorityCalculator, ErrorCode->AxonServerQueryDispatchException, ErrorCode->AxonServerNonTransientRemoteQueryHandlingException, ErrorCode->Axon...
# 14                                                                                                                                          [SimpleEventHandlerInvoker$Builder->SequentialPerAggregatePolicy, SimpleEventHandlerInvoker$Builder->SequencingPolicy, SimpleEventHandlerInvoker->SequencingPolicy]
# 15                                                                                                                                                                                [ResetHandler->ResetContext, AnnotationEventHandlerAdapter->GenericResetContext, AnnotationEventHandlerAdapter->ResetContext]
# 16                                                                                                                                                                                                                                                                             [GrpcExceptionParser->ErrorCode]
# 17                                                                                                                                                                                       [SubscriptionMessageSerializer->GrpcBackedResponseMessage, GrpcBackedSubscriptionQueryMessage->GrpcBackedQueryMessage]
# 18                                                                                                                                                                                             [EventUtils->InitialEventRepresentation, EventUtils->EventUpcaster, EventUtils->IntermediateEventRepresentation]
# 19  [AppendSnapshotStatementBuilder->EventSchema, CleanGapsStatementBuilder->EventSchema, CreateHeadTokenStatementBuilder->EventSchema, JdbcEventStorageEngineStatements->EventSchema, ReadEventDataForAggregateStatementBuilder->EventSchema, DeleteSnapshotsStatementBuilder->EventSchema, FetchTrackedEve...
# 20                                                                                                                                                            [ConfigToken->TrackingToken, AbstractTokenEntry->TrackingToken, GenericTokenEntry->TrackingToken, TokenStore->Segment, TokenStore->TrackingToken]
# 21  [AggregateAnnotationCommandHandler->AggregateModel, AggregateAnnotationCommandHandler->CreationPolicyMember, AbstractRepository$Builder->AggregateModel, AbstractRepository$Builder->AnnotatedAggregateMetaModelFactory, AbstractRepository->AggregateModel, ForwardMatchingInstances->EntityModel, Gene...
# 22                                                                                                                                              [SimpleQueryBus->DuplicateQueryHandlerResolver, SimpleQueryBus$Builder->DuplicateQueryHandlerResolver, SimpleQueryBus$Builder->DuplicateQueryHandlerResolution]
# 23                  [SerializedObjectHolder->Message, AbstractXStreamSerializer$MetaDataConverter->MetaData, SerializedMetaData->MetaData, AbstractXStreamSerializer->MetaData, SerializedMessage->GenericMessage, SerializedMessage->MetaData, SerializedMessage->Message, SerializedMessage->AbstractMessage]
# 24  [ServerConnectorConfigurerModule->CommandLoadFactorProvider, ServerConnectorConfigurerModule->CommandPriorityCalculator, ServerConnectorConfigurerModule->AxonServerCommandBus, ServerConnectorConfigurerModule->AxonServerCommandBus$Builder, ErrorCode->AxonServerRemoteCommandHandlingException, Erro...
# 25                                                                                                                                                                                                                             [MessageHandlerInterceptor->MessageHandler, ResultHandler->HasHandlerAttributes]
# 26                                                                                                                       [AnnotationSagaMetaModelFactory$InspectedSagaModel->SagaMethodMessageHandlingMember, AnnotationSagaMetaModelFactory$InspectedSagaModel->AssociationValue, SagaModel->AssociationValue]
# 27                                      [CommandMessageFilter->OrCommandMessageFilter, CommandMessageFilter->AndCommandMessageFilter, CommandMessageFilter->NegateCommandMessageFilter, DistributedCommandBus->DenyAll, DistributedCommandBus->CommandNameFilter, DistributedCommandBus->DenyCommandNameFilter]

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#              artifactName                      packageName  \
# 0   axon-messaging-4.10.3  org.axonframework.eventhandling
# 1   axon-messaging-4.10.3  org.axonframework.eventhandling
# 2   axon-messaging-4.10.3  org.axonframework.eventhandling
# 3   axon-messaging-4.10.3  org.axonframework.eventhandling
# 4   axon-messaging-4.10.3  org.axonframework.eventhandling
# 5   axon-messaging-4.10.3  org.axonframework.eventhandling
# 6   axon-messaging-4.10.3  org.axonframework.eventhandling
# 7   axon-messaging-4.10.3  org.axonframework.eventhandling
# 8   axon-messaging-4.10.3  org.axonframework.eventhandling
# 9   axon-messaging-4.10.3  org.axonframework.eventhandling
# 10  axon-messaging-4.10.3  org.axonframework.eventhandling
# 11  axon-messaging-4.10.3  org.axonframework.eventhandling
# 12  axon-messaging-4.10.3  org.axonframework.eventhandling
# 13  axon-messaging-4.10.3  org.axonframework.eventhandling
# 14  axon-messaging-4.10.3  org.axonframework.eventhandling
# 15  axon-messaging-4.10.3  org.axonframework.eventhandling
# 16  axon-messaging-4.10.3  org.axonframework.eventhandling
# 17  axon-messaging-4.10.3  org.axonframework.eventhandling
# 18  axon-messaging-4.10.3  org.axonframework.eventhandling
# 19  axon-messaging-4.10.3  org.axonframework.eventhandling
# 20  axon-messaging-4.10.3  org.axonframework.queryhandling
# 21  axon-messaging-4.10.3  org.axonframework.queryhandling
# 22  axon-messaging-4.10.3  org.axonframework.queryhandling
# 23  axon-messaging-4.10.3  org.axonframework.queryhandling
# 24  axon-messaging-4.10.3  org.axonframework.queryhandling
# 25  axon-messaging-4.10.3  org.axonframework.queryhandling
# 26  axon-messaging-4.10.3  org.axonframework.queryhandling
# 27  axon-messaging-4.10.3  org.axonframework.queryhandling
# 28  axon-messaging-4.10.3  org.axonframework.queryhandling
# 29  axon-messaging-4.10.3  org.axonframework.queryhandling
# 30  axon-messaging-4.10.3  org.axonframework.queryhandling
# 31  axon-messaging-4.10.3  org.axonframework.queryhandling
# 32  axon-messaging-4.10.3  org.axonframework.queryhandling
# 33  axon-messaging-4.10.3  org.axonframework.queryhandling
# 34  axon-messaging-4.10.3  org.axonframework.queryhandling
# 35  axon-messaging-4.10.3  org.axonframework.queryhandling
# 36  axon-messaging-4.10.3  org.axonframework.queryhandling
# 37  axon-messaging-4.10.3  org.axonframework.queryhandling
# 38  axon-messaging-4.10.3  org.axonframework.queryhandling
# 39  axon-messaging-4.10.3  org.axonframework.queryhandling
#
#     dependentArtifactName                       dependentPackageName  \
# 0   axon-messaging-4.10.3                  org.axonframework.tracing
# 1   axon-messaging-4.10.3                  org.axonframework.tracing
# 2   axon-messaging-4.10.3                  org.axonframework.tracing
# 3   axon-messaging-4.10.3                  org.axonframework.tracing
# 4   axon-messaging-4.10.3                  org.axonframework.tracing
# 5   axon-messaging-4.10.3                  org.axonframework.tracing
# 6   axon-messaging-4.10.3                  org.axonframework.tracing
# 7   axon-messaging-4.10.3                  org.axonframework.tracing
# 8   axon-messaging-4.10.3                  org.axonframework.tracing
# 9   axon-messaging-4.10.3                  org.axonframework.tracing
# 10  axon-messaging-4.10.3                  org.axonframework.tracing
# 11  axon-messaging-4.10.3                  org.axonframework.tracing
# 12  axon-messaging-4.10.3                  org.axonframework.tracing
# 13  axon-messaging-4.10.3                  org.axonframework.tracing
# 14  axon-messaging-4.10.3                  org.axonframework.tracing
# 15  axon-messaging-4.10.3                  org.axonframework.tracing
# 16  axon-messaging-4.10.3                  org.axonframework.tracing
# 17  axon-messaging-4.10.3                  org.axonframework.tracing
# 18  axon-messaging-4.10.3                  org.axonframework.tracing
# 19  axon-messaging-4.10.3                  org.axonframework.tracing
# 20  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 21  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 22  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 23  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 24  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 25  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 26  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 27  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 28  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 29  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 30  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 31  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 32  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 33  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 34  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 35  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 36  axon-messaging-4.10.3  org.axonframework.messaging.responsetypes
# 37  axon-messaging-4.10.3                  org.axonframework.tracing
# 38  axon-messaging-4.10.3                  org.axonframework.tracing
# 39  axon-messaging-4.10.3                  org.axonframework.tracing
#
#                                                     dependency  \
# 0               SubscribingEventProcessor$Builder->SpanFactory
# 1                                    EventBusSpanFactory->Span
# 2                                       AbstractEventBus->Span
# 3                          SimpleEventBus$Builder->SpanFactory
# 4                             EventMessage<-NestingSpanFactory
# 5                    AbstractEventBus$Builder->NoOpSpanFactory
# 6                              EventProcessorSpanFactory->Span
# 7                      DefaultEventBusSpanFactory->SpanFactory
# 8                  AbstractEventProcessor$Builder->SpanFactory
# 9                                 AbstractEventProcessor->Span
# 10  DefaultEventProcessorSpanFactory->NoOpSpanFactory$NoOpSpan
# 11                                 AbstractEventBus->SpanScope
# 12                      DefaultEventProcessorSpanFactory->Span
# 13                       AbstractEventBus$Builder->SpanFactory
# 14               DefaultEventProcessorSpanFactory->SpanFactory
# 15       DefaultEventProcessorSpanFactory$Builder->SpanFactory
# 16             DefaultEventBusSpanFactory$Builder->SpanFactory
# 17                            DefaultEventBusSpanFactory->Span
# 18                 TrackingEventProcessor$Builder->SpanFactory
# 19             AbstractEventProcessor$Builder->NoOpSpanFactory
# 20               GenericSubscriptionQueryMessage->ResponseType
# 21                      SubscriptionQueryMessage->ResponseType
# 22              SimpleQueryUpdateEmitter->OptionalResponseType
# 23         GenericStreamingQueryMessage->PublisherResponseType
# 24                  GenericStreamingQueryMessage->ResponseType
# 25                           DefaultQueryGateway->ResponseType
# 26                         StreamingQueryMessage->ResponseType
# 27     SimpleQueryUpdateEmitter->MultipleInstancesResponseType
# 28             QueryResponseMessage<-ConvertingResponseMessage
# 29             SimpleQueryUpdateEmitter->PublisherResponseType
# 30                                  QueryMessage->ResponseType
# 31                                SimpleQueryBus->ResponseType
# 32                      SimpleQueryUpdateEmitter->ResponseType
# 33                             QuerySubscription->ResponseType
# 34                           GenericQueryMessage->ResponseType
# 35                                  QueryGateway->ResponseType
# 36                                 QueryGateway->ResponseTypes
# 37             DefaultQueryBusSpanFactory$Builder->SpanFactory
# 38           SimpleQueryUpdateEmitter$Builder->NoOpSpanFactory
# 39                              SimpleQueryUpdateEmitter->Span
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.900000             19               1
# 2                   0.900000             19               1
# 3                   0.900000             19               1
# 4                   0.900000             19               1
# 5                   0.900000             19               1
# 6                   0.900000             19               1
# 7                   0.900000             19               1
# 8                   0.900000             19               1
# 9                   0.900000             19               1
# 10                  0.900000             19               1
# 11                  0.900000             19               1
# 12                  0.900000             19               1
# 13                  0.900000             19               1
# 14                  0.900000             19               1
# 15                  0.900000             19               1
# 16                  0.900000             19               1
# 17                  0.900000             19               1
# 18                  0.900000             19               1
# 19                  0.900000             19               1
# 20                  0.882353             16               1
# 21                  0.882353             16               1
# 22                  0.882353             16               1
# 23                  0.882353             16               1
# 24                  0.882353             16               1
# 25                  0.882353             16               1
# 26                  0.882353             16               1
# 27                  0.882353             16               1
# 28                  0.882353             16               1
# 29                  0.882353             16               1
# 30                  0.882353             16               1
# 31                  0.882353             16               1
# 32                  0.882353             16               1
# 33                  0.882353             16               1
# 34                  0.882353             16               1
# 35                  0.882353             16               1
# 36                  0.882353             16               1
# 37                  0.875000             15               1
# 38                  0.875000             15               1
# 39                  0.875000             15               1

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#                     artifactName  \
# 0          axon-messaging-4.10.3
# 1          axon-messaging-4.10.3
# 2          axon-messaging-4.10.3
# 3          axon-messaging-4.10.3
# 4          axon-messaging-4.10.3
# 5          axon-messaging-4.10.3
# 6          axon-messaging-4.10.3
# 7          axon-messaging-4.10.3
# 8          axon-messaging-4.10.3
# 9          axon-messaging-4.10.3
# 10     axon-eventsourcing-4.10.3
# 11     axon-eventsourcing-4.10.3
# 12         axon-messaging-4.10.3
# 13         axon-messaging-4.10.3
# 14  axon-server-connector-4.10.3
# 15         axon-messaging-4.10.3
# 16         axon-messaging-4.10.3
# 17         axon-messaging-4.10.3
# 18         axon-messaging-4.10.3
# 19         axon-messaging-4.10.3
# 20         axon-messaging-4.10.3
# 21  axon-server-connector-4.10.3
# 22  axon-server-connector-4.10.3
# 23  axon-server-connector-4.10.3
# 24  axon-server-connector-4.10.3
# 25  axon-server-connector-4.10.3
# 26  axon-server-connector-4.10.3
# 27  axon-server-connector-4.10.3
# 28  axon-server-connector-4.10.3
# 29  axon-server-connector-4.10.3
# 30  axon-server-connector-4.10.3
# 31  axon-server-connector-4.10.3
# 32         axon-messaging-4.10.3
# 33         axon-messaging-4.10.3
# 34         axon-messaging-4.10.3
# 35         axon-messaging-4.10.3
# 36         axon-messaging-4.10.3
# 37         axon-messaging-4.10.3
# 38  axon-server-connector-4.10.3
# 39  axon-server-connector-4.10.3
#
#                                           packageName  \
# 0                     org.axonframework.eventhandling
# 1                     org.axonframework.queryhandling
# 2                     org.axonframework.queryhandling
# 3                     org.axonframework.eventhandling
# 4                     org.axonframework.eventhandling
# 5                     org.axonframework.eventhandling
# 6                     org.axonframework.eventhandling
# 7                     org.axonframework.eventhandling
# 8                          org.axonframework.deadline
# 9                   org.axonframework.commandhandling
# 10                    org.axonframework.eventsourcing
# 11                    org.axonframework.eventsourcing
# 12        org.axonframework.commandhandling.callbacks
# 13        org.axonframework.commandhandling.callbacks
# 14        org.axonframework.axonserver.connector.util
# 15                    org.axonframework.eventhandling
# 16                    org.axonframework.eventhandling
# 17                    org.axonframework.eventhandling
# 18             org.axonframework.messaging.unitofwork
# 19             org.axonframework.messaging.unitofwork
# 20             org.axonframework.messaging.unitofwork
# 21  org.axonframework.axonserver.connector.event.axon
# 22  org.axonframework.axonserver.connector.event.axon
# 23  org.axonframework.axonserver.connector.event.axon
# 24  org.axonframework.axonserver.connector.event.axon
# 25  org.axonframework.axonserver.connector.event.axon
# 26       org.axonframework.axonserver.connector.query
# 27       org.axonframework.axonserver.connector.query
# 28       org.axonframework.axonserver.connector.query
# 29       org.axonframework.axonserver.connector.query
# 30       org.axonframework.axonserver.connector.query
# 31       org.axonframework.axonserver.connector.query
# 32              org.axonframework.eventhandling.async
# 33              org.axonframework.eventhandling.async
# 34              org.axonframework.eventhandling.async
# 35             org.axonframework.eventhandling.replay
# 36             org.axonframework.eventhandling.replay
# 37             org.axonframework.eventhandling.replay
# 38             org.axonframework.axonserver.connector
# 39       org.axonframework.axonserver.connector.query
#
#            dependentArtifactName  \
# 0          axon-messaging-4.10.3
# 1          axon-messaging-4.10.3
# 2          axon-messaging-4.10.3
# 3          axon-messaging-4.10.3
# 4          axon-messaging-4.10.3
# 5          axon-messaging-4.10.3
# 6          axon-messaging-4.10.3
# 7          axon-messaging-4.10.3
# 8          axon-messaging-4.10.3
# 9          axon-messaging-4.10.3
# 10     axon-eventsourcing-4.10.3
# 11     axon-eventsourcing-4.10.3
# 12         axon-messaging-4.10.3
# 13         axon-messaging-4.10.3
# 14  axon-server-connector-4.10.3
# 15         axon-messaging-4.10.3
# 16         axon-messaging-4.10.3
# 17         axon-messaging-4.10.3
# 18         axon-messaging-4.10.3
# 19         axon-messaging-4.10.3
# 20         axon-messaging-4.10.3
# 21  axon-server-connector-4.10.3
# 22  axon-server-connector-4.10.3
# 23  axon-server-connector-4.10.3
# 24  axon-server-connector-4.10.3
# 25  axon-server-connector-4.10.3
# 26  axon-server-connector-4.10.3
# 27  axon-server-connector-4.10.3
# 28  axon-server-connector-4.10.3
# 29  axon-server-connector-4.10.3
# 30  axon-server-connector-4.10.3
# 31  axon-server-connector-4.10.3
# 32         axon-messaging-4.10.3
# 33         axon-messaging-4.10.3
# 34         axon-messaging-4.10.3
# 35         axon-messaging-4.10.3
# 36         axon-messaging-4.10.3
# 37         axon-messaging-4.10.3
# 38  axon-server-connector-4.10.3
# 39  axon-server-connector-4.10.3
#
#                                          dependentPackageName  \
# 0                                   org.axonframework.tracing
# 1                   org.axonframework.messaging.responsetypes
# 2                                   org.axonframework.tracing
# 3                                 org.axonframework.messaging
# 4                                 org.axonframework.messaging
# 5                                 org.axonframework.messaging
# 6                      org.axonframework.messaging.annotation
# 7                      org.axonframework.messaging.annotation
# 8                                   org.axonframework.tracing
# 9                                   org.axonframework.tracing
# 10                 org.axonframework.eventsourcing.eventstore
# 11                 org.axonframework.eventsourcing.eventstore
# 12                          org.axonframework.commandhandling
# 13                          org.axonframework.commandhandling
# 14                     org.axonframework.axonserver.connector
# 15                            org.axonframework.serialization
# 16                            org.axonframework.serialization
# 17                            org.axonframework.serialization
# 18                                org.axonframework.messaging
# 19                                org.axonframework.messaging
# 20                                org.axonframework.messaging
# 21                     org.axonframework.axonserver.connector
# 22                     org.axonframework.axonserver.connector
# 23                     org.axonframework.axonserver.connector
# 24                     org.axonframework.axonserver.connector
# 25                     org.axonframework.axonserver.connector
# 26                     org.axonframework.axonserver.connector
# 27                     org.axonframework.axonserver.connector
# 28                     org.axonframework.axonserver.connector
# 29                     org.axonframework.axonserver.connector
# 30                     org.axonframework.axonserver.connector
# 31                     org.axonframework.axonserver.connector
# 32                            org.axonframework.eventhandling
# 33                            org.axonframework.eventhandling
# 34                            org.axonframework.eventhandling
# 35                            org.axonframework.eventhandling
# 36                            org.axonframework.eventhandling
# 37                            org.axonframework.eventhandling
# 38          org.axonframework.axonserver.connector.event.util
# 39  org.axonframework.axonserver.connector.query.subscription
#
#                                                                                   dependency  \
# 0                                                           EventMessage<-NestingSpanFactory
# 1                                            QueryResponseMessage<-ConvertingResponseMessage
# 2                                                                    QueryMessage<-SpanUtils
# 3                                                     TrackingToken<-StreamableMessageSource
# 4                                                                      EventMessage<-Headers
# 5                                                                DomainEventMessage<-Headers
# 6   DomainEventMessage<-AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver
# 7             DomainEventMessage<-SourceIdParameterResolverFactory$SourceIdParameterResolver
# 8                                                                 DeadlineMessage<-SpanUtils
# 9                                                                  CommandMessage<-SpanUtils
# 10                                              EventStreamUtils<-AbstractEventStorageEngine
# 11                                                       EventStreamUtils<-DomainEventStream
# 12                                                    NoOpCallback<-SimpleCommandBus$Builder
# 13                                                 LoggingCallback<-SimpleCommandBus$Builder
# 14                                                            ExceptionSerializer<-ErrorCode
# 15                                     GapAwareTrackingToken<-GapAwareTrackingTokenConverter
# 16                                      GenericDomainEventMessage<-AbstractXStreamSerializer
# 17                                            GenericEventMessage<-AbstractXStreamSerializer
# 18                                                         CurrentUnitOfWork<-GenericMessage
# 19                                                       UnitOfWork<-DefaultInterceptorChain
# 20                                                     UnitOfWork<-MessageHandlerInterceptor
# 21                          EventProcessorInfoConfiguration<-ServerConnectorConfigurerModule
# 22                      AxonServerEventStoreFactory$Builder<-ServerConnectorConfigurerModule
# 23                             AxonServerEventStore$Builder<-ServerConnectorConfigurerModule
# 24                                     AxonServerEventStore<-ServerConnectorConfigurerModule
# 25                              AxonServerEventStoreFactory<-ServerConnectorConfigurerModule
# 26                                         AxonServerRemoteQueryHandlingException<-ErrorCode
# 27                             AxonServerNonTransientRemoteQueryHandlingException<-ErrorCode
# 28                                               AxonServerQueryDispatchException<-ErrorCode
# 29                                  QueryPriorityCalculator<-ServerConnectorConfigurerModule
# 30                                       AxonServerQueryBus<-ServerConnectorConfigurerModule
# 31                               AxonServerQueryBus$Builder<-ServerConnectorConfigurerModule
# 32                                       SequencingPolicy<-SimpleEventHandlerInvoker$Builder
# 33                                               SequencingPolicy<-SimpleEventHandlerInvoker
# 34                           SequentialPerAggregatePolicy<-SimpleEventHandlerInvoker$Builder
# 35                                               ResetContext<-AnnotationEventHandlerAdapter
# 36                                        GenericResetContext<-AnnotationEventHandlerAdapter
# 37                                                                ResetContext<-ResetHandler
# 38                                                            ErrorCode<-GrpcExceptionParser
# 39                                GrpcBackedQueryMessage<-GrpcBackedSubscriptionQueryMessage
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.857143             39               3
# 5                   0.857143             39               3
# 6                   0.840000             23               2
# 7                   0.840000             23               2
# 8                   0.800000              9               1
# 9                   0.777778              8               1
# 10                  0.777778             16               2
# 11                  0.777778             16               2
# 12                  0.733333             13               2
# 13                  0.733333             13               2
# 14                  0.666667              5               1
# 15                  0.647059             14               3
# 16                  0.647059             14               3
# 17                  0.647059             14               3
# 18                  0.647059             14               3
# 19                  0.647059             14               3
# 20                  0.647059             14               3
# 21                  0.615385             21               5
# 22                  0.615385             21               5
# 23                  0.615385             21               5
# 24                  0.615385             21               5
# 25                  0.615385             21               5
# 26                  0.571429             22               6
# 27                  0.571429             22               6
# 28                  0.571429             22               6
# 29                  0.571429             22               6
# 30                  0.571429             22               6
# 31                  0.571429             22               6
# 32                  0.538462             10               3
# 33                  0.538462             10               3
# 34                  0.538462             10               3
# 35                  0.454545              8               3
# 36                  0.454545              8               3
# 37                  0.454545              8               3
# 38                  0.333333              2               1
# 39                  0.333333              4               2

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.

# %% [markdown]
# ### Table 4 - Top 40 most used combinations of methods
#
# The following table shows the top 40 most used combinations of methods of larger types that might benefit from applying the *Interface Segregation Principle*. The whole table can be found in the CSV report `Candidates_for_Interface_Segregation`.

# %%
interface_segregation_candidates=query_cypher_to_data_frame("../cypher/Internal_Dependencies/Candidates_for_Interface_Segregation.cypher", limit=40)
interface_segregation_candidates
# Out:
#                                                    fullDependentTypeName  \
# 0                       org.axonframework.commandhandling.CommandMessage
# 1                           org.axonframework.eventhandling.EventMessage
# 2                     org.axonframework.eventhandling.DomainEventMessage
# 3                           org.axonframework.eventhandling.EventMessage
# 4                    org.axonframework.eventhandling.TrackedEventMessage
# 5          org.axonframework.commandhandling.GenericCommandResultMessage
# 6                     org.axonframework.eventhandling.DomainEventMessage
# 7                              org.axonframework.messaging.ResultMessage
# 8                            org.axonframework.eventhandling.ReplayToken
# 9                      org.axonframework.deadline.GenericDeadlineMessage
# 10                    org.axonframework.eventhandling.DomainEventMessage
# 11                   org.axonframework.eventhandling.TrackedEventMessage
# 12                            org.axonframework.deadline.DeadlineMessage
# 13                    org.axonframework.eventhandling.DomainEventMessage
# 14                   org.axonframework.eventhandling.GenericEventMessage
# 15                          org.axonframework.eventhandling.EventMessage
# 16          org.axonframework.deadline.DefaultDeadlineManagerSpanFactory
# 17             org.axonframework.common.transaction.NoTransactionManager
# 18              org.axonframework.queryhandling.SimpleQueryUpdateEmitter
# 19         org.axonframework.commandhandling.GenericCommandResultMessage
# 20         org.axonframework.modelling.command.inspection.AggregateModel
# 21              org.axonframework.queryhandling.SubscriptionQueryMessage
# 22                    org.axonframework.eventhandling.DomainEventMessage
# 23                   org.axonframework.eventhandling.GenericEventMessage
# 24                        org.axonframework.queryhandling.SimpleQueryBus
# 25                    org.axonframework.eventhandling.DomainEventMessage
# 26                 org.axonframework.eventhandling.GapAwareTrackingToken
# 27            org.axonframework.queryhandling.DefaultQueryBusSpanFactory
# 28       org.axonframework.commandhandling.gateway.DefaultCommandGateway
# 29                                org.axonframework.config.Configuration
# 30                                org.axonframework.config.Configuration
# 31                          org.axonframework.messaging.MessageDecorator
# 32                          org.axonframework.queryhandling.QueryMessage
# 33        org.axonframework.commandhandling.DefaultCommandBusSpanFactory
# 34                      org.axonframework.eventhandling.TrackedEventData
# 35                org.axonframework.eventhandling.tokenstore.ConfigToken
# 36            org.axonframework.eventhandling.DefaultEventBusSpanFactory
# 37  org.axonframework.queryhandling.DefaultQueryUpdateEmitterSpanFactory
# 38     org.axonframework.modelling.command.inspection.AnnotatedAggregate
# 39                   org.axonframework.queryhandling.DefaultQueryGateway
#
#     declaredMethods  \
# 0                 9
# 1                 9
# 2                10
# 3                 9
# 4                10
# 5                14
# 6                10
# 7                 9
# 8                13
# 9                11
# 10               10
# 11               12
# 12               10
# 13               10
# 14               10
# 15                9
# 16                8
# 17                4
# 18               17
# 19               15
# 20               13
# 21               12
# 22               11
# 23               11
# 24               11
# 25               10
# 26               10
# 27               10
# 28                9
# 29                9
# 30                9
# 31                9
# 32                9
# 33                5
# 34                5
# 35                5
# 36                4
# 37                4
# 38               17
# 39               17
#
#                                                    calledMethodNames  \
# 0                                                   [getCommandName]
# 1                                      [getTimestamp, getIdentifier]
# 2                                                [getSequenceNumber]
# 3                                                    [getIdentifier]
# 4                                                    [trackingToken]
# 5                                           [asCommandResultMessage]
# 6               [getType, getAggregateIdentifier, getSequenceNumber]
# 7                                   [isExceptional, exceptionResult]
# 8                                                [createReplayToken]
# 9                                                [asDeadlineMessage]
# 10                                          [getAggregateIdentifier]
# 11                                                   [trackingToken]
# 12                                                 [getDeadlineName]
# 13                                                         [getType]
# 14                                                  [asEventMessage]
# 15                                                    [getTimestamp]
# 16                                                         [builder]
# 17                                                        [instance]
# 18                                                         [builder]
# 19                                          [asCommandResultMessage]
# 20                                                            [type]
# 21                                           [getUpdateResponseType]
# 22              [getType, getAggregateIdentifier, getSequenceNumber]
# 23                                                  [asEventMessage]
# 24                                                         [builder]
# 25                       [getAggregateIdentifier, getSequenceNumber]
# 26  [getIndex, withGapsTruncatedAt, getGaps, newInstance, advanceTo]
# 27                                                         [builder]
# 28                                                         [builder]
# 29                                   [upcasterChain, snapshotFilter]
# 30                                                    [getComponent]
# 31                                                      [describeTo]
# 32                                   [getQueryName, getResponseType]
# 33                                                         [builder]
# 34                                                   [trackingToken]
# 35                                                             [get]
# 36                                                         [builder]
# 37                                                         [builder]
# 38                      [initSequence, getAggregateRoot, initialize]
# 39                                                         [builder]
#
#     calledMethods  callerTypes
# 0               1           20
# 1               2           11
# 2               1            9
# 3               1            9
# 4               1            8
# 5               1            6
# 6               3            6
# 7               2            6
# 8               1            5
# 9               1            5
# 10              1            5
# 11              1            4
# 12              1            4
# 13              1            4
# 14              1            4
# 15              1            4
# 16              1            4
# 17              1            4
# 18              1            3
# 19              1            3
# 20              1            3
# 21              1            3
# 22              3            3
# 23              1            3
# 24              1            3
# 25              2            3
# 26              5            3
# 27              1            3
# 28              1            3
# 29              2            3
# 30              1            3
# 31              1            3
# 32              2            3
# 33              1            3
# 34              1            3
# 35              1            3
# 36              1            3
# 37              1            3
# 38              4            2
# 39              1            2

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Table 5 - Types that are used by multiple packages
#
# This table shows the top 40 packages that are used by the highest number of different packages. The whole table can be found in the CSV report `List_types_that_are_used_by_many_different_packages`.

# %%
types_used_by_many_packages=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_types_that_are_used_by_many_different_packages.cypher", limit=40)
types_used_by_many_packages
# Out:
#                                      fullQualifiedDependentTypeName  \
# 0                             org.axonframework.common.BuilderUtils
# 1               org.axonframework.common.AxonConfigurationException
# 2                               org.axonframework.messaging.Message
# 3                              org.axonframework.messaging.MetaData
# 4                        org.axonframework.serialization.Serializer
# 5                      org.axonframework.eventhandling.EventMessage
# 6                 org.axonframework.messaging.unitofwork.UnitOfWork
# 7           org.axonframework.common.transaction.TransactionManager
# 8                                   org.axonframework.common.Assert
# 9                  org.axonframework.serialization.SerializedObject
# 10                   org.axonframework.serialization.SerializedType
# 11         org.axonframework.messaging.unitofwork.CurrentUnitOfWork
# 12                            org.axonframework.common.Registration
# 13                            org.axonframework.tracing.SpanFactory
# 14                            org.axonframework.lifecycle.Lifecycle
# 15          org.axonframework.lifecycle.Lifecycle$LifecycleRegistry
# 16                             org.axonframework.common.ObjectUtils
# 17                    org.axonframework.eventhandling.TrackingToken
# 18               org.axonframework.eventhandling.DomainEventMessage
# 19  org.axonframework.messaging.annotation.ParameterResolverFactory
# 20               org.axonframework.common.AxonNonTransientException
# 21              org.axonframework.eventhandling.GenericEventMessage
# 22           org.axonframework.messaging.MessageDispatchInterceptor
# 23            org.axonframework.messaging.MessageHandlerInterceptor
# 24           org.axonframework.serialization.SimpleSerializedObject
# 25                        org.axonframework.tracing.NoOpSpanFactory
# 26                 org.axonframework.commandhandling.CommandMessage
# 27                         org.axonframework.eventhandling.EventBus
# 28         org.axonframework.messaging.annotation.HandlerDefinition
# 29        org.axonframework.common.transaction.NoTransactionManager
# 30                        org.axonframework.messaging.ResultMessage
# 31                                   org.axonframework.tracing.Span
# 32         org.axonframework.messaging.unitofwork.DefaultUnitOfWork
# 33                         org.axonframework.common.ReflectionUtils
# 34              org.axonframework.eventhandling.TrackedEventMessage
# 35                           org.axonframework.common.AxonException
# 36                           org.axonframework.common.DateTimeUtils
# 37              org.axonframework.messaging.DefaultInterceptorChain
# 38        org.axonframework.eventhandling.GenericDomainEventMessage
# 39                     org.axonframework.messaging.InterceptorChain
#
#               dependentTypeName  \
# 0                  BuilderUtils
# 1    AxonConfigurationException
# 2                       Message
# 3                      MetaData
# 4                    Serializer
# 5                  EventMessage
# 6                    UnitOfWork
# 7            TransactionManager
# 8                        Assert
# 9              SerializedObject
# 10               SerializedType
# 11            CurrentUnitOfWork
# 12                 Registration
# 13                  SpanFactory
# 14                    Lifecycle
# 15  Lifecycle$LifecycleRegistry
# 16                  ObjectUtils
# 17                TrackingToken
# 18           DomainEventMessage
# 19     ParameterResolverFactory
# 20    AxonNonTransientException
# 21          GenericEventMessage
# 22   MessageDispatchInterceptor
# 23    MessageHandlerInterceptor
# 24       SimpleSerializedObject
# 25              NoOpSpanFactory
# 26               CommandMessage
# 27                     EventBus
# 28            HandlerDefinition
# 29         NoTransactionManager
# 30                ResultMessage
# 31                         Span
# 32            DefaultUnitOfWork
# 33              ReflectionUtils
# 34          TrackedEventMessage
# 35                AxonException
# 36                DateTimeUtils
# 37      DefaultInterceptorChain
# 38    GenericDomainEventMessage
# 39             InterceptorChain
#
#                                                                                                                                                                                                                                                                                             dependentTypeLabels  \
# 0                                             [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 1                                             [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 2   [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInduce...
# 3              [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 4          [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 5                     [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 6                  [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 7                                                                     [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 8                                             [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 9   [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInduce...
# 10                                        [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 11                                                                                                                                                                                  [Type, File, Java, ByteCode, Class, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness]
# 12                                                                                                   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 13                                                                                                                             [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 14                                                                                                                                                                                                                                                                      [Type, File, Java, ByteCode, Interface]
# 15                                                                                                                                                                                                                                                                      [Type, File, Java, ByteCode, Interface]
# 16                                                                                                                                                                                                                                                                          [Type, File, Java, ByteCode, Class]
# 17                                        [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 18                                                                             [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 19                                                                                                                [Type, File, Java, ByteCode, Interface, Mark4TopCentralityCostEffectiveLazyForward, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 20                                                                                                                                                      [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness]
# 21                                                                                                                                            [Type, File, Java, ByteCode, Class, GenericDeclaration, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 22                                                                                                                                        [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 23                                                                                                         [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityBetweenness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 24                                                                                                                                                                                             [Type, File, Java, ByteCode, Class, GenericDeclaration, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness]
# 25                                                                                                                                                                                                                                                                          [Type, File, Java, ByteCode, Class]
# 26                    [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 27                                                                                                                                                            [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 28                                                                                                                [Type, File, Java, ByteCode, Interface, Mark4TopCentralityCostEffectiveLazyForward, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 29                                                                                                                                                                                                                                                                           [Type, File, Java, ByteCode, Enum]
# 30                                                                                                                           [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness]
# 31                                                                                                 [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 32                                                                                                                                                                                                                                                      [Type, File, Java, ByteCode, Class, GenericDeclaration]
# 33                                                                                                                                                                                                                                                                          [Type, File, Java, ByteCode, Class]
# 34                                                                                                         [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub]
# 35                                                                                                                                                      [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness]
# 36                                                                                                                                                                                                                                                                          [Type, File, Java, ByteCode, Class]
# 37                                                                                                                                                                                                                                                      [Type, File, Java, ByteCode, Class, GenericDeclaration]
# 38                                                                                                                                                                                                                                                      [Type, File, Java, ByteCode, Class, GenericDeclaration]
# 39                                                                                                                                                                                                                                                                      [Type, File, Java, ByteCode, Interface]
#
#     numberOfUsingPackages
# 0                      49
# 1                      42
# 2                      41
# 3                      39
# 4                      36
# 5                      35
# 6                      32
# 7                      31
# 8                      29
# 9                      27
# 10                     27
# 11                     22
# 12                     22
# 13                     22
# 14                     20
# 15                     20
# 16                     20
# 17                     20
# 18                     19
# 19                     19
# 20                     18
# 21                     18
# 22                     18
# 23                     18
# 24                     18
# 25                     17
# 26                     16
# 27                     15
# 28                     15
# 29                     15
# 30                     15
# 31                     15
# 32                     14
# 33                     14
# 34                     13
# 35                     12
# 36                     12
# 37                     12
# 38                     12
# 39                     12

# %% [markdown]
# ### Table 6 - Packages that are used by multiple artifacts
#
# This table shows the top 30 artifacts that only use a few (compared to all existing) packages of another artifact.
# The whole table can be found in the CSV report `ArtifactPackageUsage`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#                              artifactName  \
# 0       axon-tracing-opentelemetry-4.10.3
# 1            axon-server-connector-4.10.3
# 2   axon-spring-boot-autoconfigure-4.10.3
# 3                   axon-disruptor-4.10.3
# 4                        axon-test-4.10.3
# 5                   axon-disruptor-4.10.3
# 6               axon-eventsourcing-4.10.3
# 7                   axon-disruptor-4.10.3
# 8                        axon-test-4.10.3
# 9                   axon-modelling-4.10.3
# 10              axon-eventsourcing-4.10.3
# 11           axon-server-connector-4.10.3
# 12  axon-spring-boot-autoconfigure-4.10.3
# 13           axon-server-connector-4.10.3
# 14              axon-configuration-4.10.3
# 15                       axon-test-4.10.3
# 16              axon-configuration-4.10.3
# 17  axon-spring-boot-autoconfigure-4.10.3
# 18                  axon-modelling-4.10.3
# 19              axon-configuration-4.10.3
# 20  axon-spring-boot-autoconfigure-4.10.3
# 21  axon-spring-boot-autoconfigure-4.10.3
# 22                       axon-test-4.10.3
# 23                  axon-messaging-4.10.3
# 24              axon-eventsourcing-4.10.3
# 25           axon-server-connector-4.10.3
# 26  axon-spring-boot-autoconfigure-4.10.3
# 27              axon-configuration-4.10.3
# 28           axon-server-connector-4.10.3
# 29  axon-spring-boot-autoconfigure-4.10.3
#
#                     dependentArtifactName  dependentPackages  \
# 0                   axon-messaging-4.10.3                  3
# 1                   axon-modelling-4.10.3                  1
# 2                        axon-test-4.10.3                  1
# 3                   axon-messaging-4.10.3                  9
# 4                   axon-messaging-4.10.3                 10
# 5                   axon-modelling-4.10.3                  2
# 6                   axon-modelling-4.10.3                  2
# 7               axon-eventsourcing-4.10.3                  2
# 8               axon-eventsourcing-4.10.3                  2
# 9                   axon-messaging-4.10.3                 18
# 10                  axon-messaging-4.10.3                 20
# 11              axon-eventsourcing-4.10.3                  3
# 12           axon-server-connector-4.10.3                  4
# 13                  axon-messaging-4.10.3                 25
# 14              axon-eventsourcing-4.10.3                  4
# 15                  axon-modelling-4.10.3                  5
# 16                  axon-messaging-4.10.3                 34
# 17              axon-eventsourcing-4.10.3                  5
# 18                  axon-modelling-4.10.3                  6
# 19                  axon-modelling-4.10.3                  6
# 20                  axon-modelling-4.10.3                  6
# 21                  axon-messaging-4.10.3                 39
# 22                       axon-test-4.10.3                  5
# 23                  axon-messaging-4.10.3                 41
# 24              axon-eventsourcing-4.10.3                  7
# 25           axon-server-connector-4.10.3                  9
# 26  axon-spring-boot-autoconfigure-4.10.3                  8
# 27                  axon-disruptor-4.10.3                  1
# 28              axon-configuration-4.10.3                  1
# 29              axon-configuration-4.10.3                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          64                0.046875
# 1                          10                0.100000
# 2                           8                0.125000
# 3                          64                0.140625
# 4                          64                0.156250
# 5                          10                0.200000
# 6                          10                0.200000
# 7                           9                0.222222
# 8                           9                0.222222
# 9                          64                0.281250
# 10                         64                0.312500
# 11                          9                0.333333
# 12                         11                0.363636
# 13                         64                0.390625
# 14                          9                0.444444
# 15                         10                0.500000
# 16                         64                0.531250
# 17                          9                0.555556
# 18                         10                0.600000
# 19                         10                0.600000
# 20                         10                0.600000
# 21                         64                0.609375
# 22                          8                0.625000
# 23                         64                0.640625
# 24                          9                0.777778
# 25                         11                0.818182
# 26                          9                0.888889
# 27                          1                1.000000
# 28                          1                1.000000
# 29                          1                1.000000
#
#                                                                                                                                                                                                                                                                              dependentFullQualifiedPackageNames  \
# 0                                                                                                                                                                                                                            [org.axonframework.tracing, org.axonframework.messaging, org.axonframework.common]
# 1                                                                                                                                                                                                                                                                         [org.axonframework.modelling.command]
# 2                                                                                                                                                                                                                                                                               [org.axonframework.test.server]
# 3   [org.axonframework.commandhandling, org.axonframework.monitoring, org.axonframework.common.transaction, org.axonframework.common.caching, org.axonframework.messaging.unitofwork, org.axonframework.common, org.axonframework.messaging, org.axonframework.messaging.annotation, org.axonframework.comma...
# 4   [org.axonframework.messaging, org.axonframework.commandhandling, org.axonframework.common, org.axonframework.eventhandling, org.axonframework.eventhandling.scheduling, org.axonframework.deadline, org.axonframework.messaging.unitofwork, org.axonframework.common.stream, org.axonframework.messaging...
# 5                                                                                                                                                                                                                         [org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 6                                                                                                                                                                                                                         [org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 7                                                                                                                                                                                                                                 [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing]
# 8                                                                                                                                                                                                                                 [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing]
# 9   [org.axonframework.messaging.unitofwork, org.axonframework.messaging.annotation, org.axonframework.common.property, org.axonframework.eventhandling, org.axonframework.common.annotation, org.axonframework.common, org.axonframework.common.jpa, org.axonframework.commandhandling, org.axonframework.c...
# 10  [org.axonframework.messaging.unitofwork, org.axonframework.eventhandling, org.axonframework.serialization, org.axonframework.common, org.axonframework.messaging.annotation, org.axonframework.messaging, org.axonframework.tracing, org.axonframework.common.lock, org.axonframework.serialization.upca...
# 11                                                                                                                                                                                  [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing, org.axonframework.eventsourcing.snapshotting]
# 12                                                                                                                    [org.axonframework.axonserver.connector, org.axonframework.axonserver.connector.query, org.axonframework.axonserver.connector.command, org.axonframework.axonserver.connector.event.axon]
# 13  [org.axonframework.common, org.axonframework.lifecycle, org.axonframework.messaging.responsetypes, org.axonframework.util, org.axonframework.tracing, org.axonframework.messaging, org.axonframework.serialization, org.axonframework.queryhandling, org.axonframework.eventhandling.tokenstore, org.axo...
# 14                                                                                                                                  [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore.jpa, org.axonframework.eventsourcing.snapshotting]
# 15                                                                                   [org.axonframework.modelling.saga, org.axonframework.modelling.command.inspection, org.axonframework.modelling.command, org.axonframework.modelling.saga.repository.inmemory, org.axonframework.modelling.saga.repository]
# 16  [org.axonframework.common, org.axonframework.messaging, org.axonframework.commandhandling.gateway, org.axonframework.eventhandling.tokenstore.inmemory, org.axonframework.eventhandling, org.axonframework.queryhandling.annotation, org.axonframework.eventhandling.scheduling, org.axonframework.traci...
# 17                                                                         [org.axonframework.eventsourcing.eventstore.legacyjpa, org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.eventstore.jpa, org.axonframework.eventsourcing.eventstore.jdbc, org.axonframework.eventsourcing]
# 18                                            [org.axonframework.modelling.command.inspection, org.axonframework.modelling.saga.metamodel, org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga, org.axonframework.modelling.command, org.axonframework.modelling.saga.repository.jpa]
# 19                                  [org.axonframework.modelling.command.inspection, org.axonframework.modelling.saga, org.axonframework.modelling.saga.repository, org.axonframework.modelling.command, org.axonframework.modelling.saga.repository.inmemory, org.axonframework.modelling.saga.repository.jpa]
# 20                               [org.axonframework.modelling.saga.repository.legacyjpa, org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.command, org.axonframework.modelling.saga, org.axonframework.modelling.saga.repository.jdbc]
# 21  [org.axonframework.messaging.deadletter, org.axonframework.eventhandling, org.axonframework.common.jpa, org.axonframework.eventhandling.tokenstore, org.axonframework.common.legacyjpa, org.axonframework.eventhandling.tokenstore.legacyjpa, org.axonframework.common.jdbc, org.axonframework.eventhand...
# 22                                                                                                                                              [org.axonframework.test, org.axonframework.test.matchers, org.axonframework.test.deadline, org.axonframework.test.eventscheduler, org.axonframework.test.utils]
# 23  [org.axonframework.common, org.axonframework.serialization, org.axonframework.eventhandling, org.axonframework.messaging, org.axonframework.serialization.upcasting, org.axonframework.common.jdbc, org.axonframework.common.transaction, org.axonframework.messaging.deadletter, org.axonframework.mess...
# 24  [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.eventstore.jdbc, org.axonframework.eventsourcing.conflictresolution, org.axonframework.eventsourcing.snapshotting, org.axonframework.eventsourcing.eventstore.jdbc.statements, org.axonframework.eventsourcing.eventstore.j...
# 25  [org.axonframework.axonserver.connector, org.axonframework.axonserver.connector.util, org.axonframework.axonserver.connector.command, org.axonframework.axonserver.connector.query.subscription, org.axonframework.axonserver.connector.event.util, org.axonframework.axonserver.connector.query, org.ax...
# 26  [org.axonframework.springboot, org.axonframework.actuator, org.axonframework.springboot.util, org.axonframework.springboot.util.legacyjpa, org.axonframework.springboot.autoconfig, org.axonframework.springboot.util.jpa, org.axonframework.springboot.service.connection, org.axonframework.actuator.a...
# 27                                                                                                                                                                                                                                                                [org.axonframework.disruptor.commandhandling]
# 28                                                                                                                                                                                                                                                                                   [org.axonframework.config]
# 29                                                                                                                                                                                                                                                                                   [org.axonframework.config]
#
#                                                                                                                                                                                                                                                                                           dependentPackageNames
# 0                                                                                                                                                                                                                                                                                  [tracing, messaging, common]
# 1                                                                                                                                                                                                                                                                                                     [command]
# 2                                                                                                                                                                                                                                                                                                      [server]
# 3                                                                                                                                                                                                     [commandhandling, monitoring, transaction, caching, unitofwork, common, messaging, annotation, callbacks]
# 4                                                                                                                                                                                            [messaging, commandhandling, common, eventhandling, scheduling, deadline, unitofwork, stream, annotation, gateway]
# 5                                                                                                                                                                                                                                                                                         [command, inspection]
# 6                                                                                                                                                                                                                                                                                         [command, inspection]
# 7                                                                                                                                                                                                                                                                                   [eventstore, eventsourcing]
# 8                                                                                                                                                                                                                                                                                   [eventstore, eventsourcing]
# 9                                                                                                                               [unitofwork, annotation, property, eventhandling, common, jpa, commandhandling, lock, messaging, interceptors, tracing, deadline, xml, serialization, legacyjpa, jdbc, caching]
# 10                                                                                                         [unitofwork, eventhandling, serialization, common, annotation, messaging, tracing, lock, event, caching, transaction, jdbc, commandhandling, io, monitoring, legacyjpa, stream, jpa, xml, lifecycle]
# 11                                                                                                                                                                                                                                                                    [eventstore, eventsourcing, snapshotting]
# 12                                                                                                                                                                                                                                                                            [connector, query, command, axon]
# 13                                     [common, lifecycle, responsetypes, util, tracing, messaging, serialization, queryhandling, tokenstore, eventhandling, transaction, pooled, commandhandling, callbacks, distributed, inmemory, scheduling, unitofwork, monitoring, stream, xml, java, async, event, jdbc]
# 14                                                                                                                                                                                                                                                               [eventstore, eventsourcing, jpa, snapshotting]
# 15                                                                                                                                                                                                                                                            [saga, inspection, command, inmemory, repository]
# 16  [common, messaging, gateway, inmemory, eventhandling, annotation, scheduling, tracing, pooled, jpa, async, deadline, serialization, event, commandhandling, lifecycle, caching, util, correlation, unitofwork, queryhandling, interceptors, deadletter, transaction, monitoring, xml, tokenstore, lock, ...
# 17                                                                                                                                                                                                                                                            [legacyjpa, eventstore, jpa, jdbc, eventsourcing]
# 18                                                                                                                                                                                                                                                      [inspection, metamodel, repository, saga, command, jpa]
# 19                                                                                                                                                                                                                                                       [inspection, saga, repository, command, inmemory, jpa]
# 20                                                                                                                                                                                                                                                            [legacyjpa, repository, jpa, command, saga, jdbc]
# 21  [deadletter, eventhandling, jpa, tokenstore, legacyjpa, jdbc, serialization, transaction, lifecycle, common, commandhandling, messaging, pooled, jobrunr, annotation, xml, gateway, dbscheduler, deadline, event, queryhandling, interceptors, correlation, attributes, json, distributed, async, schedu...
# 22                                                                                                                                                                                                                                                            [test, matchers, deadline, eventscheduler, utils]
# 23  [common, serialization, eventhandling, messaging, upcasting, jdbc, transaction, deadletter, unitofwork, property, jpa, scheduling, jobrunr, lifecycle, tracing, xml, deadline, registration, monitoring, interceptors, annotation, responsetypes, queryhandling, digest, callbacks, commandhandling, com...
# 24                                                                                                                                                                                                                         [eventstore, jdbc, conflictresolution, snapshotting, statements, jpa, eventsourcing]
# 25                                                                                                                                                                                                                                  [connector, util, command, subscription, query, heartbeat, axon, processor]
# 26                                                                                                                                                                                                                             [springboot, actuator, util, legacyjpa, autoconfig, jpa, connection, axonserver]
# 27                                                                                                                                                                                                                                                                                            [commandhandling]
# 28                                                                                                                                                                                                                                                                                                     [config]
# 29                                                                                                                                                                                                                                                                                                     [config]

# %% [markdown]
# ### Table 7 - Types that are used by multiple artifacts
#
# This table shows the top 30 types that only use a few (compared to all existing) types of another artifact. The whole table can be found in the CSV report `ClassesPerPackageUsageAcrossArtifacts`.

# %%
used_types_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher", limit=30)
used_types_of_dependent_artifact
# Out:
#                              artifactName      dependentArtifactName  \
# 0            axon-server-connector-4.10.3      axon-messaging-4.10.3
# 1                        axon-test-4.10.3      axon-messaging-4.10.3
# 2                   axon-modelling-4.10.3      axon-messaging-4.10.3
# 3   axon-spring-boot-autoconfigure-4.10.3      axon-messaging-4.10.3
# 4               axon-eventsourcing-4.10.3      axon-messaging-4.10.3
# 5   axon-spring-boot-autoconfigure-4.10.3      axon-messaging-4.10.3
# 6            axon-server-connector-4.10.3      axon-modelling-4.10.3
# 7               axon-eventsourcing-4.10.3      axon-modelling-4.10.3
# 8               axon-eventsourcing-4.10.3      axon-modelling-4.10.3
# 9               axon-eventsourcing-4.10.3      axon-messaging-4.10.3
# 10                       axon-test-4.10.3      axon-messaging-4.10.3
# 11                  axon-modelling-4.10.3      axon-messaging-4.10.3
# 12                  axon-modelling-4.10.3      axon-messaging-4.10.3
# 13           axon-server-connector-4.10.3  axon-eventsourcing-4.10.3
# 14           axon-server-connector-4.10.3  axon-configuration-4.10.3
# 15  axon-spring-boot-autoconfigure-4.10.3  axon-configuration-4.10.3
# 16  axon-spring-boot-autoconfigure-4.10.3  axon-configuration-4.10.3
# 17                       axon-test-4.10.3      axon-messaging-4.10.3
# 18              axon-eventsourcing-4.10.3      axon-messaging-4.10.3
# 19              axon-eventsourcing-4.10.3      axon-messaging-4.10.3
# 20                       axon-test-4.10.3      axon-messaging-4.10.3
# 21              axon-eventsourcing-4.10.3      axon-messaging-4.10.3
# 22              axon-eventsourcing-4.10.3      axon-messaging-4.10.3
# 23              axon-eventsourcing-4.10.3      axon-messaging-4.10.3
# 24  axon-spring-boot-autoconfigure-4.10.3      axon-messaging-4.10.3
# 25              axon-eventsourcing-4.10.3      axon-messaging-4.10.3
# 26                       axon-test-4.10.3      axon-modelling-4.10.3
# 27              axon-eventsourcing-4.10.3      axon-messaging-4.10.3
# 28                       axon-test-4.10.3      axon-messaging-4.10.3
# 29           axon-server-connector-4.10.3  axon-eventsourcing-4.10.3
#
#                                                    packageName  \
# 0                       org.axonframework.axonserver.connector
# 1                              org.axonframework.test.matchers
# 2                   org.axonframework.modelling.saga.metamodel
# 3                            org.axonframework.springboot.util
# 4                 org.axonframework.eventsourcing.snapshotting
# 5            org.axonframework.springboot.autoconfig.legacyjpa
# 6                       org.axonframework.axonserver.connector
# 7           org.axonframework.eventsourcing.conflictresolution
# 8              org.axonframework.eventsourcing.eventstore.jdbc
# 9           org.axonframework.eventsourcing.conflictresolution
# 10                       org.axonframework.test.eventscheduler
# 11               org.axonframework.modelling.command.legacyjpa
# 12                         org.axonframework.modelling.command
# 13           org.axonframework.axonserver.connector.event.axon
# 14            org.axonframework.axonserver.connector.processor
# 15                                org.axonframework.springboot
# 16           org.axonframework.springboot.autoconfig.legacyjpa
# 17                                      org.axonframework.test
# 18          org.axonframework.eventsourcing.conflictresolution
# 19                  org.axonframework.eventsourcing.eventstore
# 20                             org.axonframework.test.matchers
# 21        org.axonframework.eventsourcing.eventstore.legacyjpa
# 22             org.axonframework.eventsourcing.eventstore.jdbc
# 23              org.axonframework.eventsourcing.eventstore.jpa
# 24           org.axonframework.springboot.autoconfig.legacyjpa
# 25  org.axonframework.eventsourcing.eventstore.jdbc.statements
# 26                                org.axonframework.test.utils
# 27          org.axonframework.eventsourcing.conflictresolution
# 28                             org.axonframework.test.matchers
# 29                      org.axonframework.axonserver.connector
#
#                           dependentPackage.fqn  dependentTypes  \
# 0              org.axonframework.eventhandling               1
# 1              org.axonframework.eventhandling               1
# 2              org.axonframework.eventhandling               1
# 3              org.axonframework.eventhandling               1
# 4              org.axonframework.eventhandling               1
# 5              org.axonframework.eventhandling               1
# 6          org.axonframework.modelling.command               1
# 7          org.axonframework.modelling.command               1
# 8          org.axonframework.modelling.command               1
# 9              org.axonframework.eventhandling               2
# 10             org.axonframework.eventhandling               2
# 11             org.axonframework.eventhandling               2
# 12             org.axonframework.eventhandling               2
# 13             org.axonframework.eventsourcing               1
# 14                    org.axonframework.config               1
# 15                    org.axonframework.config               1
# 16                    org.axonframework.config               1
# 17                 org.axonframework.messaging               1
# 18                 org.axonframework.messaging               1
# 19                 org.axonframework.messaging               1
# 20                 org.axonframework.messaging               1
# 21             org.axonframework.serialization               1
# 22             org.axonframework.serialization               1
# 23             org.axonframework.serialization               1
# 24             org.axonframework.serialization               1
# 25             org.axonframework.eventhandling               3
# 26            org.axonframework.modelling.saga               1
# 27           org.axonframework.commandhandling               1
# 28           org.axonframework.commandhandling               1
# 29  org.axonframework.eventsourcing.eventstore               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                     100             0.010000
# 1                     100             0.010000
# 2                     100             0.010000
# 3                     100             0.010000
# 4                     100             0.010000
# 5                     100             0.010000
# 6                      56             0.017857
# 7                      56             0.017857
# 8                      56             0.017857
# 9                     100             0.020000
# 10                    100             0.020000
# 11                    100             0.020000
# 12                    100             0.020000
# 13                     42             0.023810
# 14                     41             0.024390
# 15                     41             0.024390
# 16                     41             0.024390
# 17                     35             0.028571
# 18                     35             0.028571
# 19                     35             0.028571
# 20                     35             0.028571
# 21                     34             0.029412
# 22                     34             0.029412
# 23                     34             0.029412
# 24                     34             0.029412
# 25                    100             0.030000
# 26                     33             0.030303
# 27                     32             0.031250
# 28                     32             0.031250
# 29                     31             0.032258
#
#                                                                                                                                                dependentTypeNames
# 0                                                                                                           [org.axonframework.eventhandling.EventBusSpanFactory]
# 1                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 2                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 3                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 4                                                                                                               [org.axonframework.eventhandling.DomainEventData]
# 5                                                                                                                      [org.axonframework.eventhandling.EventBus]
# 6                                                                                                      [org.axonframework.modelling.command.ConcurrencyException]
# 7                                                                                      [org.axonframework.modelling.command.ConflictingAggregateVersionException]
# 8                                                                                                      [org.axonframework.modelling.command.ConcurrencyException]
# 9                                                              [org.axonframework.eventhandling.EventMessage, org.axonframework.eventhandling.DomainEventMessage]
# 10                                                            [org.axonframework.eventhandling.EventMessage, org.axonframework.eventhandling.GenericEventMessage]
# 11                                                           [org.axonframework.eventhandling.EventBus, org.axonframework.eventhandling.DomainEventSequenceAware]
# 12                                                           [org.axonframework.eventhandling.EventBus, org.axonframework.eventhandling.DomainEventSequenceAware]
# 13                                                                                                             [org.axonframework.eventsourcing.EventStreamUtils]
# 14                                                                                                        [org.axonframework.config.EventProcessingConfiguration]
# 15                                                                                                                   [org.axonframework.config.TagsConfiguration]
# 16                                                                                                                       [org.axonframework.config.Configuration]
# 17                                                                                                                          [org.axonframework.messaging.Message]
# 18                                                                                                                          [org.axonframework.messaging.Message]
# 19                                                                                                          [org.axonframework.messaging.StreamableMessageSource]
# 20                                                                                                                          [org.axonframework.messaging.Message]
# 21                                                                                                                   [org.axonframework.serialization.Serializer]
# 22                                                                                                                   [org.axonframework.serialization.Serializer]
# 23                                                                                                                   [org.axonframework.serialization.Serializer]
# 24                                                                                                                   [org.axonframework.serialization.Serializer]
# 25  [org.axonframework.eventhandling.GenericDomainEventMessage, org.axonframework.eventhandling.EventMessage, org.axonframework.eventhandling.DomainEventMessage]
# 26                                                                                                      [org.axonframework.modelling.saga.SimpleResourceInjector]
# 27                                                                                                             [org.axonframework.commandhandling.CommandMessage]
# 28                                                                                                             [org.axonframework.commandhandling.CommandMessage]
# 29                                                                                               [org.axonframework.eventsourcing.eventstore.EventStoreException]

# %% [markdown]
# ### Table 8 - Duplicate package names across artifacts
#
# This table shows the top 30 duplicate package names across artifacts. They are ordered by the number of duplicates descending.
#
# This might lead to confusion, makes importing more error prone and might even lead to duplicate classes where only one of them will be loaded by the class loader. If a package is named the same way in two or more artifacts this even allows another artifact to access package protected classes, methods or members which might not be intended.
#
# The whole table can be found in the CSV report `DuplicatePackageNamesAcrossArtifacts`.

# %%
duplicate_package_names_across_artifacts=query_cypher_to_data_frame("../cypher/Artifact_Dependencies/Artifacts_with_duplicate_packages.cypher", limit=30)
duplicate_package_names_across_artifacts
# Out:
# Empty DataFrame
# Columns: [packageName, duplicates, artifactNames]
# Index: []

# %% [markdown]
# ### Table 9 - Annotated elements
#
# This table shows 30 most used Java Annotations including some examples where they are used.

# %%
annotated_elements=query_cypher_to_data_frame("../cypher/Java/Annotated_code_elements.cypher", limit=30)
annotated_elements
# Out:
#                                                                annotationName  \
# 0                                                    javax.annotation.Nonnull
# 1                                                        java.lang.Deprecated
# 2                                 org.springframework.context.annotation.Bean
# 3   org.springframework.boot.autoconfigure.condition.ConditionalOnMissingBean
# 4                                               java.lang.FunctionalInterface
# 5                                                   javax.annotation.Nullable
# 6                                                    javax.annotation.Nonnull
# 7                                                        java.lang.Deprecated
# 8                                                 java.lang.annotation.Target
# 9                                              java.lang.annotation.Retention
# 10                                                    javax.persistence.Basic
# 11                                                  jakarta.persistence.Basic
# 12                              com.fasterxml.jackson.annotation.JsonProperty
# 13                                            java.lang.annotation.Documented
# 14                   org.springframework.boot.autoconfigure.AutoConfiguration
# 15                                           java.beans.ConstructorProperties
# 16                                                       java.lang.Deprecated
# 17                     org.springframework.beans.factory.annotation.Qualifier
# 18                  org.springframework.boot.autoconfigure.AutoConfigureAfter
# 19                               com.fasterxml.jackson.annotation.JsonCreator
# 20     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 21                 org.springframework.boot.autoconfigure.AutoConfigureBefore
# 22        org.springframework.boot.autoconfigure.condition.ConditionalOnClass
# 23                                                   javax.persistence.Column
# 24                                          org.axonframework.common.Priority
# 25                                                 jakarta.persistence.Column
# 26  org.springframework.boot.context.properties.EnableConfigurationProperties
# 27                                                      javax.persistence.Lob
# 28                                                       javax.persistence.Id
# 29         org.springframework.boot.autoconfigure.condition.ConditionalOnBean
#
#    languageElement  numberOfAnnotatedElements  \
# 0        Parameter                       1617
# 1           Method                        132
# 2           Method                        111
# 3           Method                         78
# 4        Interface                         65
# 5        Parameter                         61
# 6           Method                         50
# 7            Class                         43
# 8       Annotation                         43
# 9       Annotation                         43
# 10           Field                         39
# 11           Field                         33
# 12       Parameter                         32
# 13      Annotation                         23
# 14           Class                         22
# 15     Constructor                         21
# 16     Constructor                         20
# 17       Parameter                         20
# 18           Class                         16
# 19     Constructor                         16
# 20          Method                         15
# 21           Class                         14
# 22           Class                         12
# 23           Field                         12
# 24           Class                         11
# 25           Field                         11
# 26           Class                         11
# 27           Field                         10
# 28           Field                         10
# 29          Method                         10
#
#                                                                                                                                                                                                                                                                                                        examples
# 0   [org.axonframework.commandhandling.AsynchronousCommandBus$Builder.spanFactory(0), org.axonframework.commandhandling.AsynchronousCommandBus$Builder.defaultCommandCallback(0), org.axonframework.commandhandling.AsynchronousCommandBus$Builder.duplicateCommandHandlerResolver(0), org.axonframework.com...
# 1   [org.axonframework.commandhandling.SimpleCommandBus$Builder.spanFactory, org.axonframework.commandhandling.distributed.DistributedCommandBus$Builder.spanFactory, org.axonframework.deadline.GenericDeadlineMessage.asDeadlineMessage, org.axonframework.deadline.SimpleDeadlineManager$Builder.spanFact...
# 2   [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.axonServerCommandBus, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.queryBus, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.eventStore, org.axonframework.springboot.autoconfi...
# 3   [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.queryBus, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.eventStore, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.axonServerEventStoreFactory, org.axonframework.springboot.au...
# 4   [org.axonframework.commandhandling.CommandCallback, org.axonframework.commandhandling.DuplicateCommandHandlerResolver, org.axonframework.commandhandling.distributed.CommandMessageFilter, org.axonframework.commandhandling.distributed.ConsistentHashChangeListener, org.axonframework.common.Registra...
# 5   [org.axonframework.commandhandling.GenericCommandResultMessage.<init>(0), org.axonframework.commandhandling.GenericCommandResultMessage.<init>(1), org.axonframework.commandhandling.MonitorAwareCallback.<init>(0), org.axonframework.deadline.DeadlineManager.schedule(2), org.axonframework.deadline....
# 6   [org.axonframework.commandhandling.gateway.DefaultCommandGateway.registerDispatchInterceptor, org.axonframework.eventhandling.GenericEventMessage.getTimestamp, org.axonframework.eventhandling.MultiEventHandlerInvoker.delegates, org.axonframework.eventhandling.interceptors.EventLoggingInterceptor...
# 7   [org.axonframework.common.caching.EhCacheAdapter, org.axonframework.common.legacyjpa.SimpleEntityManagerProvider, org.axonframework.common.legacyjpa.PagingJpaQueryIterable, org.axonframework.eventhandling.deadletter.legacyjpa.EventMessageDeadLetterJpaConverter, org.axonframework.eventhandling.de...
# 8   [org.axonframework.commandhandling.CommandHandler, org.axonframework.commandhandling.RoutingKey, org.axonframework.commandhandling.gateway.Timeout, org.axonframework.common.Priority, org.axonframework.deadline.annotation.DeadlineHandler, org.axonframework.eventhandling.AllowReplay, org.axonframe...
# 9   [org.axonframework.commandhandling.CommandHandler, org.axonframework.commandhandling.RoutingKey, org.axonframework.commandhandling.gateway.Timeout, org.axonframework.common.Priority, org.axonframework.deadline.annotation.DeadlineHandler, org.axonframework.eventhandling.AllowReplay, org.axonframe...
# 10  [org.axonframework.eventhandling.AbstractDomainEventEntry.type, org.axonframework.eventhandling.AbstractDomainEventEntry.aggregateIdentifier, org.axonframework.eventhandling.AbstractDomainEventEntry.sequenceNumber, org.axonframework.eventhandling.AbstractEventEntry.timeStamp, org.axonframework.e...
# 11  [org.axonframework.eventhandling.AbstractDomainEventEntry.type, org.axonframework.eventhandling.AbstractDomainEventEntry.aggregateIdentifier, org.axonframework.eventhandling.AbstractDomainEventEntry.sequenceNumber, org.axonframework.eventhandling.AbstractEventEntry.timeStamp, org.axonframework.e...
# 12  [org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>(0), org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>(1), org.axonframework.commandhandling.distributed.commandfilter.CommandNameFilter.<init>(0), org.axonframewor...
# 13  [org.axonframework.commandhandling.CommandHandler, org.axonframework.eventhandling.AllowReplay, org.axonframework.eventhandling.DisallowReplay, org.axonframework.eventhandling.EventHandler, org.axonframework.lifecycle.ShutdownHandler, org.axonframework.lifecycle.StartHandler, org.axonframework.m...
# 14  [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguratio...
# 15  [org.axonframework.commandhandling.distributed.commandfilter.CommandNameFilter.<init>, org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>, org.axonframework.commandhandling.distributed.commandfilter.DenyCommandNameFilter.<init>, org.axonframework.commandha...
# 16  [org.axonframework.commandhandling.callbacks.FailureLoggingCallback.<init>, org.axonframework.commandhandling.distributed.AbstractRoutingStrategy.<init>, org.axonframework.commandhandling.distributed.AnnotationRoutingStrategy.<init>, org.axonframework.commandhandling.distributed.MetaDataRoutingS...
# 17  [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.axonServerCommandBus(2), org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.axonServerCommandBus(3), org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.queryBus(4), org.axonframework.s...
# 18  [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguratio...
# 19  [org.axonframework.eventhandling.GapAwareTrackingToken.<init>, org.axonframework.eventhandling.GlobalSequenceTrackingToken.<init>, org.axonframework.eventhandling.MergedTrackingToken.<init>, org.axonframework.eventhandling.MultiSourceTrackingToken.<init>, org.axonframework.eventhandling.ReplayTo...
# 20  [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.eventStore, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.axonServerEventStoreFactory, org.axonframework.springboot.autoconfig.MicrometerMetricsAutoConfiguration.metricsConfigurerModule, org.axonfram...
# 21  [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration, org.axonframework.springboot.autoconfig.JpaEventStoreAutoCo...
# 22  [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration, org.axonframework.springboot.autoconfig.MicrometerMetricsAutoConfiguration, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration, org.axonframework.springboot.autoconfig.OpenTelemetryAutoConfiguration, org.axonf...
# 23  [org.axonframework.eventhandling.AbstractEventEntry.eventIdentifier, org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.causeMessage, org.axonframework.eventhandli...
# 24  [org.axonframework.commandhandling.CurrentUnitOfWorkParameterResolverFactory, org.axonframework.eventhandling.SequenceNumberParameterResolverFactory, org.axonframework.eventhandling.TimestampParameterResolverFactory, org.axonframework.messaging.annotation.AggregateTypeParameterResolverFactory, o...
# 25  [org.axonframework.eventhandling.AbstractEventEntry.eventIdentifier, org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.causeMessage, org.axonframework.eventhandli...
# 26  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.springboot.autoconfig.MicrometerMetricsAutoConfiguration, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration, org.axonframew...
# 27  [org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.diagnostics, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEventEntry.payload, org.axonframework.eve...
# 28  [org.axonframework.eventhandling.AbstractSequencedDomainEventEntry.globalIndex, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.deadLetterId, org.axonframework.eventhandling.tokenstore.jpa.TokenEntry.processorName, org.axonframework.eventhandling.tokenstore.jpa.TokenEntry.segment,...
# 29  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.persistenceExceptionResolver, org.axonframework.springboot.autoconfig.MicrometerMetricsAutoConfiguration.globalMetricRegistry, org.axonframework.springboot.autoconfig.MicrometerMetricsAutoConfiguration.metricsConfigurer...

# %% [markdown]
# ### Table 10 - Distance distribution between dependent files
#
# This table shows the file directory distance distribution between dependent files. Intuitively, the distance is given by the fewest number of change directory commands needed to navigate between a file and a dependency it uses. Those are aggregate to see how many dependent files are in the same directory, how many are just one change directory command apart, and so on.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Internal_Dependencies/Get_file_distance_as_shortest_contains_path_for_dependencies.cypher",
                                           "../cypher/Internal_Dependencies/Set_file_distance_as_shortest_contains_path_for_dependencies.cypher", limit=20)
# Out:
#    dependency.fileDistanceAsFewestChangeDirectoryCommands  \
# 0                                                       0
# 1                                                       1
# 2                                                       2
# 3                                                       4
#
#    numberOfDependencies  numberOfDependencyUsers  numberOfDependencyProviders  \
# 0                  2618                     1029                         1164
# 1                    90                       82                           38
# 2                  2503                      760                          472
# 3                  2594                      449                          540
#
#                                                                                                                                                                                                                                                                                                       examples
# 0                                              [/axon-eventsourcing-4.10.3.jar uses /axon-messaging-4.10.3.jar, /axon-disruptor-4.10.3.jar uses /axon-messaging-4.10.3.jar, /axon-test-4.10.3.jar uses /axon-messaging-4.10.3.jar, /axon-spring-boot-autoconfigure-4.10.3.jar uses /axon-messaging-4.10.3.jar]
# 1  [/org/axonframework/commandhandling/distributed uses /org/axonframework/commandhandling, /org/axonframework/commandhandling/callbacks uses /org/axonframework/commandhandling, /org/axonframework/commandhandling/gateway uses /org/axonframework/commandhandling, /org/axonframework/commandhandling us...
# 2  [/org/axonframework/eventhandling/async/PropertySequencingPolicy$Builder.class uses /org/axonframework/common/property/PropertyAccessStrategy.class, /org/axonframework/queryhandling/annotation/AnnotationQueryHandlerAdapter.class uses /org/axonframework/messaging/annotation/HandlerDefinition.clas...
# 3  [/org/axonframework/modelling/command/inspection/AbstractChildEntityDefinition.class uses /org/axonframework/common/property/PropertyAccessStrategy.class, /org/axonframework/modelling/saga/PayloadAssociationResolver.class uses /org/axonframework/common/property/PropertyAccessStrategy.class, /org...
