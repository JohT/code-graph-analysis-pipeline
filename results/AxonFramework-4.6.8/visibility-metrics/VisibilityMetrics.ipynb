# %% [markdown]
# # Visibility Metrics
# <br>
#
# ### References
# - [Visibility Metrics and the Importance of Hiding Things](https://dzone.com/articles/visibility-metrics-and-the-importance-of-hiding-th)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Controlling Access to Members of a Class](https://docs.oracle.com/javase/tutorial/java/javaOO/accesscontrol.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Relative Visibility Of Types
#
# A Java class or interface may be declared with the modifier public, in which case it is visible to all classes everywhere. If a class or interface has no modifier (the default, also known as package-private), it is visible only within its own package.
#
# The relative visibility is the number of inner components that are visible outside (public) divided by the number of all types:
#
# $$ relative visibility = \frac{public\:types}{all\:types} $$
#
# Using package protected types is one of many ways to improve encapsulation and implementation detail hiding.
#
# ### How to apply the results
#
# The relative visibility is between zero (all types are package protected) and one (all types are public). A value lower than one means that there are types that are declared package protected. The lower the value is, the better implementation details are hidden.
#
# Non public classes can't be accessed from another package so they can be changed without affecting code in other packages. They clearly indicate functionality that only belongs to one package. This also motivates to use more classes and to split up code into smaller pieces with a single responsibility and reason to change.

# %% [markdown]
# ### Table 1a - Top 40 artifacts with lowest median of package protection encapsulation
#
# This table shows the relative visibility statistics aggregated for all packages per artifact and focusses on artifacts with many packages and hardly any package protected types (lowest median, high visibility). Package protected types would help to  improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Global_relative_visibility_statistics_for_types`

# %%
# Query the visibility statistics per artifact (all packages aggregated)
# The results Will be used in multiple tables below.
relative_visibility_per_artifact_aggregated=query_cypher_to_data_frame("../cypher/Visibility/Global_relative_visibility_statistics_for_types.cypher")

# %%
# Sort by the "percentile50" (median) and "all" (number of packages in the artifact) descending
relative_visibility_statistics_highest_median=relative_visibility_per_artifact_aggregated.sort_values(by=['percentile50', 'all'], ascending=[False, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
relative_visibility_statistics_highest_median=relative_visibility_statistics_highest_median.reset_index(drop=True)

relative_visibility_statistics_highest_median.head(40)
# Out:
#                    artifact  all  public       min       max   average  \
# 0      axon-messaging-4.6.8  700     567  0.100000  1.000000  0.849854
# 1           axon-test-4.6.8   85      64  0.473684  1.000000  0.812336
# 2  axon-eventsourcing-4.6.8  120      90  0.500000  1.000000  0.802803
# 3      axon-modelling-4.6.8  144     124  0.500000  1.000000  0.797619
# 4  axon-configuration-4.6.8   39      26  0.666667  0.666667  0.666667
# 5      axon-disruptor-4.6.8   22       9  0.409091  0.409091  0.409091
#
#    percentile25  percentile50  percentile75  percentile90
# 0      0.726381      0.914286      1.000000      1.000000
# 1      0.650000      0.879167      1.000000      1.000000
# 2      0.653226      0.821429      1.000000      1.000000
# 3      0.745833      0.813187      0.883987      0.922222
# 4      0.666667      0.666667      0.666667      0.666667
# 5      0.409091      0.409091      0.409091      0.409091

# %% [markdown]
# ### Table 1b - Top 40 artifacts with highest median of package protection encapsulation
#
# This table shows the relative visibility statistics aggregated for all packages per artifact and focusses on artifacts with many packages and the highest median of package protected types (low visibility). Package protected types help to improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Global_relative_visibility_statistics_for_types`

# %%
# Sort by the "percentile50" (median) ascending and "all" (number of packages in the artifact) descending
relative_visibility_statistics_lowest_median=relative_visibility_per_artifact_aggregated.sort_values(by=['percentile50', 'all'], ascending=[True, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
relative_visibility_statistics_lowest_median=relative_visibility_statistics_lowest_median.reset_index(drop=True)

relative_visibility_statistics_lowest_median.head(40)
# Out:
#                    artifact  all  public       min       max   average  \
# 0      axon-disruptor-4.6.8   22       9  0.409091  0.409091  0.409091
# 1  axon-configuration-4.6.8   39      26  0.666667  0.666667  0.666667
# 2      axon-modelling-4.6.8  144     124  0.500000  1.000000  0.797619
# 3  axon-eventsourcing-4.6.8  120      90  0.500000  1.000000  0.802803
# 4           axon-test-4.6.8   85      64  0.473684  1.000000  0.812336
# 5      axon-messaging-4.6.8  700     567  0.100000  1.000000  0.849854
#
#    percentile25  percentile50  percentile75  percentile90
# 0      0.409091      0.409091      0.409091      0.409091
# 1      0.666667      0.666667      0.666667      0.666667
# 2      0.745833      0.813187      0.883987      0.922222
# 3      0.653226      0.821429      1.000000      1.000000
# 4      0.650000      0.879167      1.000000      1.000000
# 5      0.726381      0.914286      1.000000      1.000000

# %% [markdown]
# ### Table 1 Chart 1 - Relative visibility in artifacts

# %%
plot.figure();
fig, axes = plot.subplots(nrows=3, ncols=1, sharex=True)

number_of_packages_grid_ticks=[1, 2, 5, 10, 20, 50, 100, 200, 500, 1_000, 2_000, 5_000, 10_000]

relative_visibility_per_artifact_aggregated.plot(
    ax=axes[0],
    kind='scatter',
    title='Relative visibility in artifacts (75% percentile)', 
    x='percentile75',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_packages_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of packages',
    cmap=main_color_map,
    figsize=(10,4),
)
relative_visibility_per_artifact_aggregated.plot(
    ax=axes[1],
    kind='scatter',
    title='Relative visibility in artifacts (50% percentile)', 
    x='percentile50',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_packages_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of packages',
    cmap=main_color_map,
    figsize=(10,4),
)
relative_visibility_per_artifact_aggregated.plot(
    ax=axes[2],
    kind='scatter',
    title='Relative visibility in artifacts (25% percentile)', 
    x='percentile25',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_packages_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of packages',
    cmap=main_color_map,
    figsize=(10,10),
)
axes[0].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
axes[1].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
axes[2].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
plot.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/codegraph/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ### Table 2a - Top 40 packages with the highest visibility and lowest encapsulation
#
# This table shows the relative visibility statistics per packages and artifact and focusses on packages with many types, hardly any package protected ones and therefore the highest relative visibility (lowest encapsulation). Package protected types would help to improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Relative_visibility_public_types_to_all_types_per_package`

# %%
# Query the visibility statistics per package and artifact (all types aggregated)
# The results Will be used in multiple tables below.
relative_visibility_per_package=query_cypher_to_data_frame("../cypher/Visibility/Relative_visibility_public_types_to_all_types_per_package.cypher")

# %%
# Sort by the "relativeVisibility" and "allTypes" (number of types in the package) descending
highest_relative_visibility_packages=relative_visibility_per_package.sort_values(by=['relativeVisibility', 'allTypes'], ascending=[False, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
highest_relative_visibility_packages=highest_relative_visibility_packages.reset_index(drop=True)

highest_relative_visibility_packages.head(40)
# Out:
#                 artifactName  \
# 0       axon-modelling-4.6.8
# 1       axon-messaging-4.6.8
# 2   axon-eventsourcing-4.6.8
# 3       axon-messaging-4.6.8
# 4       axon-messaging-4.6.8
# 5   axon-eventsourcing-4.6.8
# 6       axon-messaging-4.6.8
# 7       axon-messaging-4.6.8
# 8       axon-messaging-4.6.8
# 9       axon-messaging-4.6.8
# 10      axon-messaging-4.6.8
# 11      axon-messaging-4.6.8
# 12      axon-messaging-4.6.8
# 13      axon-messaging-4.6.8
# 14      axon-messaging-4.6.8
# 15      axon-messaging-4.6.8
# 16      axon-messaging-4.6.8
# 17      axon-messaging-4.6.8
# 18      axon-messaging-4.6.8
# 19           axon-test-4.6.8
# 20      axon-messaging-4.6.8
# 21      axon-messaging-4.6.8
# 22      axon-messaging-4.6.8
# 23      axon-messaging-4.6.8
# 24      axon-messaging-4.6.8
# 25           axon-test-4.6.8
# 26  axon-eventsourcing-4.6.8
# 27      axon-messaging-4.6.8
# 28      axon-messaging-4.6.8
# 29           axon-test-4.6.8
# 30      axon-messaging-4.6.8
# 31      axon-messaging-4.6.8
# 32      axon-messaging-4.6.8
# 33           axon-test-4.6.8
# 34      axon-messaging-4.6.8
# 35      axon-messaging-4.6.8
# 36      axon-messaging-4.6.8
# 37      axon-messaging-4.6.8
# 38      axon-messaging-4.6.8
# 39      axon-modelling-4.6.8
#
#                              fullQualifiedPackageName         packageName  \
# 0                    org.axonframework.modelling.saga                saga
# 1              org.axonframework.messaging.deadletter          deadletter
# 2   org.axonframework.eventsourcing.eventstore.jdb...          statements
# 3     org.axonframework.serialization.upcasting.event               event
# 4                         org.axonframework.lifecycle           lifecycle
# 5   org.axonframework.eventsourcing.conflictresolu...  conflictresolution
# 6                   org.axonframework.common.property            property
# 7            org.axonframework.messaging.interceptors        interceptors
# 8           org.axonframework.messaging.responsetypes       responsetypes
# 9   org.axonframework.commandhandling.distributed....       commandfilter
# 10               org.axonframework.serialization.json                json
# 11         org.axonframework.eventhandling.tokenstore          tokenstore
# 12                org.axonframework.serialization.xml                 xml
# 13               org.axonframework.tracing.attributes          attributes
# 14  org.axonframework.eventhandling.scheduling.quartz              quartz
# 15          org.axonframework.serialization.upcasting           upcasting
# 16         org.axonframework.serialization.converters          converters
# 17            org.axonframework.eventhandling.gateway             gateway
# 18       org.axonframework.queryhandling.registration        registration
# 19              org.axonframework.test.eventscheduler      eventscheduler
# 20        org.axonframework.commandhandling.callbacks           callbacks
# 21            org.axonframework.messaging.correlation         correlation
# 22                       org.axonframework.common.jpa                 jpa
# 23     org.axonframework.eventhandling.tokenstore.jpa                 jpa
# 24                  org.axonframework.deadline.quartz              quartz
# 25                    org.axonframework.test.deadline            deadline
# 26       org.axonframework.eventsourcing.snapshotting        snapshotting
# 27         org.axonframework.eventhandling.scheduling          scheduling
# 28                             org.axonframework.util                util
# 29                      org.axonframework.test.server              server
# 30                    org.axonframework.common.digest              digest
# 31       org.axonframework.eventhandling.interceptors        interceptors
# 32                        org.axonframework.common.io                  io
# 33                    org.axonframework.test.matchers            matchers
# 34      org.axonframework.commandhandling.distributed         distributed
# 35                        org.axonframework.messaging           messaging
# 36                  org.axonframework.commandhandling     commandhandling
# 37    org.axonframework.eventhandling.tokenstore.jdbc                jdbc
# 38     org.axonframework.eventhandling.deadletter.jpa                 jpa
# 39   org.axonframework.modelling.saga.repository.jdbc                jdbc
#
#     publicTypes  allTypes  relativeVisibility
# 0            30        30            1.000000
# 1            17        17            1.000000
# 2            15        15            1.000000
# 3            12        12            1.000000
# 4            10        10            1.000000
# 5             9         9            1.000000
# 6             9         9            1.000000
# 7             8         8            1.000000
# 8             8         8            1.000000
# 9             7         7            1.000000
# 10            7         7            1.000000
# 11            7         7            1.000000
# 12            7         7            1.000000
# 13            6         6            1.000000
# 14            6         6            1.000000
# 15            6         6            1.000000
# 16            5         5            1.000000
# 17            5         5            1.000000
# 18            5         5            1.000000
# 19            5         5            1.000000
# 20            4         4            1.000000
# 21            4         4            1.000000
# 22            4         4            1.000000
# 23            4         4            1.000000
# 24            4         4            1.000000
# 25            4         4            1.000000
# 26            3         3            1.000000
# 27            3         3            1.000000
# 28            3         3            1.000000
# 29            2         2            1.000000
# 30            1         1            1.000000
# 31            1         1            1.000000
# 32            1         1            1.000000
# 33           23        24            0.958333
# 34           24        26            0.923077
# 35           32        35            0.914286
# 36           26        29            0.896552
# 37            8         9            0.888889
# 38            8         9            0.888889
# 39            8         9            0.888889

# %% [markdown]
# ### Table 2b - Top 40 packages with the lowest visibility and highest encapsulation
#
# This table shows the relative visibility statistics per packages and artifact and focusses on packages with many types, many package protected ones and therefore the lowest relative visibility (highest encapsulation). Package protected types help to improve encapsulation. Zero percent visibility and therefore packages with no public visible type are suspicious to be dead code.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Relative_visibility_public_types_to_all_types_per_package`

# %%
# Sort by the "relativeVisibility" ascending and "allTypes" (number of types in the package) descending
lowest_relative_visibility_packages=relative_visibility_per_package.sort_values(by=['relativeVisibility', 'allTypes'], ascending=[True, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
lowest_relative_visibility_packages=lowest_relative_visibility_packages.reset_index(drop=True)

lowest_relative_visibility_packages.head(40)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.6.8
# 1       axon-disruptor-4.6.8
# 2            axon-test-4.6.8
# 3       axon-messaging-4.6.8
# 4   axon-eventsourcing-4.6.8
# 5       axon-messaging-4.6.8
# 6       axon-modelling-4.6.8
# 7       axon-messaging-4.6.8
# 8       axon-messaging-4.6.8
# 9       axon-messaging-4.6.8
# 10      axon-messaging-4.6.8
# 11           axon-test-4.6.8
# 12  axon-eventsourcing-4.6.8
# 13  axon-configuration-4.6.8
# 14  axon-eventsourcing-4.6.8
# 15           axon-test-4.6.8
# 16      axon-messaging-4.6.8
# 17      axon-messaging-4.6.8
# 18      axon-messaging-4.6.8
# 19      axon-messaging-4.6.8
# 20      axon-messaging-4.6.8
# 21      axon-messaging-4.6.8
# 22      axon-messaging-4.6.8
# 23      axon-messaging-4.6.8
# 24      axon-modelling-4.6.8
# 25      axon-messaging-4.6.8
# 26      axon-messaging-4.6.8
# 27      axon-messaging-4.6.8
# 28      axon-modelling-4.6.8
# 29      axon-modelling-4.6.8
# 30  axon-eventsourcing-4.6.8
# 31      axon-messaging-4.6.8
# 32           axon-test-4.6.8
# 33      axon-messaging-4.6.8
# 34      axon-messaging-4.6.8
# 35      axon-messaging-4.6.8
# 36      axon-messaging-4.6.8
# 37      axon-messaging-4.6.8
# 38  axon-eventsourcing-4.6.8
# 39      axon-modelling-4.6.8
#
#                              fullQualifiedPackageName      packageName  \
# 0              org.axonframework.eventhandling.pooled           pooled
# 1         org.axonframework.disruptor.commandhandling  commandhandling
# 2                    org.axonframework.test.aggregate        aggregate
# 3          org.axonframework.eventhandling.deadletter       deadletter
# 4   org.axonframework.eventsourcing.eventstore.inm...         inmemory
# 5   org.axonframework.eventhandling.tokenstore.inm...         inmemory
# 6   org.axonframework.modelling.saga.repository.in...         inmemory
# 7           org.axonframework.commandhandling.gateway          gateway
# 8               org.axonframework.eventhandling.async            async
# 9              org.axonframework.eventhandling.replay           replay
# 10              org.axonframework.deadline.annotation       annotation
# 11                             org.axonframework.test             test
# 12         org.axonframework.eventsourcing.eventstore       eventstore
# 13                           org.axonframework.config           config
# 14                    org.axonframework.eventsourcing    eventsourcing
# 15                        org.axonframework.test.saga             saga
# 16                   org.axonframework.common.caching          caching
# 17                org.axonframework.common.annotation       annotation
# 18                    org.axonframework.common.stream           stream
# 19                          org.axonframework.tracing          tracing
# 20                         org.axonframework.deadline         deadline
# 21             org.axonframework.messaging.unitofwork       unitofwork
# 22             org.axonframework.messaging.annotation       annotation
# 23                      org.axonframework.common.lock             lock
# 24        org.axonframework.modelling.saga.repository       repository
# 25         org.axonframework.queryhandling.annotation       annotation
# 26    org.axonframework.eventhandling.scheduling.java             java
# 27               org.axonframework.common.transaction      transaction
# 28         org.axonframework.modelling.saga.metamodel        metamodel
# 29     org.axonframework.modelling.command.inspection       inspection
# 30    org.axonframework.eventsourcing.eventstore.jdbc             jdbc
# 31                      org.axonframework.common.jdbc             jdbc
# 32                       org.axonframework.test.utils            utils
# 33                    org.axonframework.queryhandling    queryhandling
# 34                       org.axonframework.monitoring       monitoring
# 35                    org.axonframework.eventhandling    eventhandling
# 36                    org.axonframework.serialization    serialization
# 37                           org.axonframework.common           common
# 38     org.axonframework.eventsourcing.eventstore.jpa              jpa
# 39    org.axonframework.modelling.saga.repository.jpa              jpa
#
#     publicTypes  allTypes  relativeVisibility
# 0             2        20            0.100000
# 1             9        22            0.409091
# 2             9        19            0.473684
# 3             2         4            0.500000
# 4             1         2            0.500000
# 5             1         2            0.500000
# 6             1         2            0.500000
# 7            19        36            0.527778
# 8             9        15            0.600000
# 9             6        10            0.600000
# 10            3         5            0.600000
# 11            3         5            0.600000
# 12           19        31            0.612903
# 13           26        39            0.666667
# 14           26        39            0.666667
# 15           14        21            0.666667
# 16            8        12            0.666667
# 17            2         3            0.666667
# 18            2         3            0.666667
# 19           11        16            0.687500
# 20            7        10            0.700000
# 21           10        14            0.714286
# 22           37        51            0.725490
# 23            8        11            0.727273
# 24           11        15            0.733333
# 25            3         4            0.750000
# 26            3         4            0.750000
# 27            3         4            0.750000
# 28            3         4            0.750000
# 29           20        26            0.769231
# 30           11        14            0.785714
# 31           12        15            0.800000
# 32            4         5            0.800000
# 33           33        40            0.825000
# 34            5         6            0.833333
# 35           78        93            0.838710
# 36           27        32            0.843750
# 37           24        28            0.857143
# 38            6         7            0.857143
# 39            6         7            0.857143

# %% [markdown]
# ### Table 2 Chart 1 - Relative visibility of packages

# %%
plot.figure();

number_of_types_grid_ticks=[1, 2, 5, 10, 20, 50, 100, 200, 500, 1_000, 2_000, 5_000, 10_000]

relative_visibility_per_package.plot(
    kind='scatter',
    title='Relative visibility of packages', 
    x='relativeVisibility',
    y='allTypes',
    grid=True,
    logy=True,
    yticks=number_of_types_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of types',
    cmap=main_color_map,
    figsize=(10,4),
)

plot.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/codegraph/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
