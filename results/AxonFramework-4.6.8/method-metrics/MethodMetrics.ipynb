# %% [markdown]
# # Method Metrics
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## Effective Method Line Count

# %% [markdown]
# ### Table 1a - Effective method line count distribution
#
# This table shows the distribution of the effective method line count per artifact.
# For each artifact the number of methods with effective line count = 1,2,3,... is shown to get an overview of how line counts are distributed over methods.
#
# Only the 15 artifacts with the highest method count and their effective method line count distribution (limited by 40)is shown here. The whole table can be found in the CSV report `Effective_Method_Line_Count_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
effective_method_line_count_distribution_max_artifacts=20

effective_method_line_count_distribution=query_cypher_to_data_frame("../cypher/Overview/Effective_Method_Line_Count_Distribution.cypher")
effective_method_line_count_distribution=effective_method_line_count_distribution.pivot(index='effectiveLineCount', columns='artifactName', values='methods')

# Fill missing values with zero
effective_method_line_count_distribution.fillna(0, inplace=True)

# Convert to integer
effective_method_line_count_distribution=effective_method_line_count_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
effective_method_line_count_distribution = effective_method_line_count_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:effective_method_line_count_distribution_max_artifacts]]

effective_method_line_count_distribution.head(40)
# Out:
# artifactName        axon-messaging-4.6.8.jar  axon-eventsourcing-4.6.8.jar  \
# effectiveLineCount
# 1                                       2375                           478
# 2                                        694                           170
# 3                                        512                           103
# 4                                        225                            52
# 5                                        192                            33
# 6                                        124                            25
# 7                                         90                            22
# 8                                         67                             9
# 9                                         58                            12
# 10                                        32                             7
# 11                                        35                             2
# 12                                        29                             3
# 13                                        20                             2
# 14                                        14                             3
# 15                                         5                             2
# 16                                         7                             5
# 17                                         7                             0
# 18                                         7                             2
# 19                                         4                             0
# 20                                         5                             2
# 21                                         8                             1
# 22                                         1                             0
# 23                                         2                             1
# 24                                         3                             2
# 25                                         0                             1
# 26                                         1                             0
# 27                                         0                             0
# 28                                         1                             0
# 29                                         1                             0
# 31                                         0                             0
# 32                                         1                             0
# 33                                         2                             0
# 36                                         2                             0
# 38                                         0                             0
# 39                                         0                             0
# 42                                         1                             0
# 45                                         0                             0
# 50                                         1                             0
# 57                                         1                             0
# 64                                         1                             0
#
# artifactName        axon-modelling-4.6.8.jar  axon-test-4.6.8.jar  \
# effectiveLineCount
# 1                                        464                  262
# 2                                        131                  162
# 3                                        122                   61
# 4                                         54                   44
# 5                                         41                   22
# 6                                         37                   15
# 7                                         23                   18
# 8                                          9                   11
# 9                                          8                    9
# 10                                         6                    6
# 11                                         8                    8
# 12                                         2                    8
# 13                                         5                    3
# 14                                         2                    2
# 15                                         3                    2
# 16                                         2                    2
# 17                                         2                    4
# 18                                         0                    2
# 19                                         1                    0
# 20                                         1                    0
# 21                                         1                    2
# 22                                         1                    2
# 23                                         1                    0
# 24                                         2                    0
# 25                                         0                    0
# 26                                         0                    0
# 27                                         0                    1
# 28                                         0                    0
# 29                                         0                    1
# 31                                         0                    1
# 32                                         0                    0
# 33                                         0                    0
# 36                                         0                    0
# 38                                         1                    0
# 39                                         0                    0
# 42                                         0                    0
# 45                                         0                    1
# 50                                         0                    0
# 57                                         0                    0
# 64                                         0                    0
#
# artifactName        axon-configuration-4.6.8.jar  axon-disruptor-4.6.8.jar
# effectiveLineCount
# 1                                            304                        84
# 2                                            135                        31
# 3                                             33                        30
# 4                                             33                         8
# 5                                             14                         5
# 6                                             16                         6
# 7                                              2                         2
# 8                                              9                         0
# 9                                              8                         4
# 10                                             4                         3
# 11                                             3                         1
# 12                                             1                         1
# 13                                             2                         1
# 14                                             0                         2
# 15                                             0                         0
# 16                                             1                         0
# 17                                             0                         1
# 18                                             2                         1
# 19                                             1                         1
# 20                                             0                         0
# 21                                             1                         0
# 22                                             0                         1
# 23                                             1                         0
# 24                                             0                         1
# 25                                             0                         0
# 26                                             1                         0
# 27                                             0                         0
# 28                                             0                         0
# 29                                             0                         0
# 31                                             0                         0
# 32                                             0                         1
# 33                                             0                         0
# 36                                             0                         0
# 38                                             0                         0
# 39                                             1                         0
# 42                                             1                         0
# 45                                             0                         0
# 50                                             0                         0
# 57                                             0                         0
# 64                                             0                         0

# %% [markdown]
# ### Table 1b - Effective method line count distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
effective_method_line_count_distribution_normalized = effective_method_line_count_distribution.div(effective_method_line_count_distribution.sum(axis=0), axis=1).multiply(100)
effective_method_line_count_distribution_normalized.head(40)
# Out:
# artifactName        axon-messaging-4.6.8.jar  axon-eventsourcing-4.6.8.jar  \
# effectiveLineCount
# 1                                  52.439832                     51.013874
# 2                                  15.323471                     18.143010
# 3                                  11.304924                     10.992529
# 4                                   4.967984                      5.549626
# 5                                   4.239346                      3.521878
# 6                                   2.737911                      2.668090
# 7                                   1.987194                      2.347919
# 8                                   1.479355                      0.960512
# 9                                   1.280636                      1.280683
# 10                                  0.706558                      0.747065
# 11                                  0.772798                      0.213447
# 12                                  0.640318                      0.320171
# 13                                  0.441599                      0.213447
# 14                                  0.309119                      0.320171
# 15                                  0.110400                      0.213447
# 16                                  0.154560                      0.533618
# 17                                  0.154560                      0.000000
# 18                                  0.154560                      0.213447
# 19                                  0.088320                      0.000000
# 20                                  0.110400                      0.213447
# 21                                  0.176639                      0.106724
# 22                                  0.022080                      0.000000
# 23                                  0.044160                      0.106724
# 24                                  0.066240                      0.213447
# 25                                  0.000000                      0.106724
# 26                                  0.022080                      0.000000
# 27                                  0.000000                      0.000000
# 28                                  0.022080                      0.000000
# 29                                  0.022080                      0.000000
# 31                                  0.000000                      0.000000
# 32                                  0.022080                      0.000000
# 33                                  0.044160                      0.000000
# 36                                  0.044160                      0.000000
# 38                                  0.000000                      0.000000
# 39                                  0.000000                      0.000000
# 42                                  0.022080                      0.000000
# 45                                  0.000000                      0.000000
# 50                                  0.022080                      0.000000
# 57                                  0.022080                      0.000000
# 64                                  0.022080                      0.000000
#
# artifactName        axon-modelling-4.6.8.jar  axon-test-4.6.8.jar  \
# effectiveLineCount
# 1                                  50.053937            40.369800
# 2                                  14.131607            24.961479
# 3                                  13.160734             9.399076
# 4                                   5.825243             6.779661
# 5                                   4.422869             3.389831
# 6                                   3.991370             2.311248
# 7                                   2.481122             2.773498
# 8                                   0.970874             1.694915
# 9                                   0.862999             1.386749
# 10                                  0.647249             0.924499
# 11                                  0.862999             1.232666
# 12                                  0.215750             1.232666
# 13                                  0.539374             0.462250
# 14                                  0.215750             0.308166
# 15                                  0.323625             0.308166
# 16                                  0.215750             0.308166
# 17                                  0.215750             0.616333
# 18                                  0.000000             0.308166
# 19                                  0.107875             0.000000
# 20                                  0.107875             0.000000
# 21                                  0.107875             0.308166
# 22                                  0.107875             0.308166
# 23                                  0.107875             0.000000
# 24                                  0.215750             0.000000
# 25                                  0.000000             0.000000
# 26                                  0.000000             0.000000
# 27                                  0.000000             0.154083
# 28                                  0.000000             0.000000
# 29                                  0.000000             0.154083
# 31                                  0.000000             0.154083
# 32                                  0.000000             0.000000
# 33                                  0.000000             0.000000
# 36                                  0.000000             0.000000
# 38                                  0.107875             0.000000
# 39                                  0.000000             0.000000
# 42                                  0.000000             0.000000
# 45                                  0.000000             0.154083
# 50                                  0.000000             0.000000
# 57                                  0.000000             0.000000
# 64                                  0.000000             0.000000
#
# artifactName        axon-configuration-4.6.8.jar  axon-disruptor-4.6.8.jar
# effectiveLineCount
# 1                                      53.054101                 45.652174
# 2                                      23.560209                 16.847826
# 3                                       5.759162                 16.304348
# 4                                       5.759162                  4.347826
# 5                                       2.443281                  2.717391
# 6                                       2.792321                  3.260870
# 7                                       0.349040                  1.086957
# 8                                       1.570681                  0.000000
# 9                                       1.396161                  2.173913
# 10                                      0.698080                  1.630435
# 11                                      0.523560                  0.543478
# 12                                      0.174520                  0.543478
# 13                                      0.349040                  0.543478
# 14                                      0.000000                  1.086957
# 15                                      0.000000                  0.000000
# 16                                      0.174520                  0.000000
# 17                                      0.000000                  0.543478
# 18                                      0.349040                  0.543478
# 19                                      0.174520                  0.543478
# 20                                      0.000000                  0.000000
# 21                                      0.174520                  0.000000
# 22                                      0.000000                  0.543478
# 23                                      0.174520                  0.000000
# 24                                      0.000000                  0.543478
# 25                                      0.000000                  0.000000
# 26                                      0.174520                  0.000000
# 27                                      0.000000                  0.000000
# 28                                      0.000000                  0.000000
# 29                                      0.000000                  0.000000
# 31                                      0.000000                  0.000000
# 32                                      0.000000                  0.543478
# 33                                      0.000000                  0.000000
# 36                                      0.000000                  0.000000
# 38                                      0.000000                  0.000000
# 39                                      0.174520                  0.000000
# 42                                      0.174520                  0.000000
# 45                                      0.000000                  0.000000
# 50                                      0.000000                  0.000000
# 57                                      0.000000                  0.000000
# 64                                      0.000000                  0.000000

# %% [markdown]
# ### Table 1b Chart 1 - Effective method line count distribution (normalized)

# %%
plot.figure();
method_line_count_x_ticks=range(1,20)
axes = effective_method_line_count_distribution_normalized.head(20).plot(
    kind='line',
    logx=True,
    grid=True,
    xlim=[2, 20],
    ylim=[0, 20],
    xticks=method_line_count_x_ticks,
    title='Effective Method Line Count Distribution', 
    xlabel='effective line count',
    ylabel='percent of methods',
    cmap=main_color_map,
    figsize=(10, 6),
    lw=2,
)
axes.set_xticklabels(method_line_count_x_ticks)
axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 1c - Top 30 packages with highest effective line counts
#
# The following table shows the top 30 packages with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Query artifacts and packages and find the method with the highest effective lines of code and cyclomatic complexity
# The result of this query will be also used further below. 
method_statistics_per_package = query_cypher_to_data_frame("../cypher/Overview/Effective_lines_of_method_code_per_package.cypher")

# %%
# Select and order the columns for this particular table 
effective_line_count_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'linesInPackage', 'methodCount', 'maxLinesMethod','maxLinesMethodName']]

# Print out the top 30 (head) rows
effective_line_count_per_package.head(30)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.6.8
# 1   axon-configuration-4.6.8
# 2       axon-messaging-4.6.8
# 3            axon-test-4.6.8
# 4       axon-messaging-4.6.8
# 5       axon-modelling-4.6.8
# 6   axon-eventsourcing-4.6.8
# 7       axon-messaging-4.6.8
# 8       axon-modelling-4.6.8
# 9       axon-disruptor-4.6.8
# 10  axon-eventsourcing-4.6.8
# 11  axon-eventsourcing-4.6.8
# 12      axon-messaging-4.6.8
# 13      axon-messaging-4.6.8
# 14      axon-messaging-4.6.8
# 15      axon-messaging-4.6.8
# 16           axon-test-4.6.8
# 17      axon-messaging-4.6.8
# 18      axon-modelling-4.6.8
# 19      axon-messaging-4.6.8
# 20      axon-messaging-4.6.8
# 21           axon-test-4.6.8
# 22      axon-messaging-4.6.8
# 23      axon-messaging-4.6.8
# 24  axon-eventsourcing-4.6.8
# 25      axon-messaging-4.6.8
# 26      axon-modelling-4.6.8
# 27      axon-modelling-4.6.8
# 28      axon-messaging-4.6.8
# 29      axon-messaging-4.6.8
#
#                                      fullPackageName  linesInPackage  \
# 0                    org.axonframework.eventhandling            2213
# 1                           org.axonframework.config            1462
# 2             org.axonframework.eventhandling.pooled             935
# 3                   org.axonframework.test.aggregate             877
# 4                    org.axonframework.queryhandling             832
# 5                org.axonframework.modelling.command             757
# 6         org.axonframework.eventsourcing.eventstore             707
# 7             org.axonframework.messaging.annotation             665
# 8     org.axonframework.modelling.command.inspection             631
# 9        org.axonframework.disruptor.commandhandling             605
# 10                   org.axonframework.eventsourcing             582
# 11   org.axonframework.eventsourcing.eventstore.jdbc             569
# 12    org.axonframework.eventhandling.deadletter.jpa             521
# 13         org.axonframework.commandhandling.gateway             504
# 14                          org.axonframework.common             501
# 15                   org.axonframework.serialization             488
# 16                       org.axonframework.test.saga             487
# 17     org.axonframework.commandhandling.distributed             479
# 18                  org.axonframework.modelling.saga             456
# 19   org.axonframework.eventhandling.tokenstore.jdbc             430
# 20            org.axonframework.messaging.unitofwork             363
# 21                   org.axonframework.test.matchers             351
# 22                       org.axonframework.messaging             348
# 23                 org.axonframework.commandhandling             341
# 24    org.axonframework.eventsourcing.eventstore.jpa             320
# 25            org.axonframework.messaging.deadletter             282
# 26       org.axonframework.modelling.saga.repository             268
# 27  org.axonframework.modelling.saga.repository.jdbc             263
# 28                 org.axonframework.deadline.quartz             242
# 29                  org.axonframework.common.caching             240
#
#     methodCount  maxLinesMethod  \
# 0           793              64
# 1           573              42
# 2           308              70
# 3           240              45
# 4           333              36
# 5           307              17
# 6           261              21
# 7           233              23
# 8           216              24
# 9           184              32
# 10          236              20
# 11          236              24
# 12          132              28
# 13          180              50
# 14          144              24
# 15          170              21
# 16          164              29
# 17          172              21
# 18          182              23
# 19          130              26
# 20          129              32
# 21          108              21
# 22          156              13
# 23          151              13
# 24          101              25
# 25          102              33
# 26           97              22
# 27           56              38
# 28           57              42
# 29           93              13
#
#                                    maxLinesMethodName
# 0                                        processBatch
# 1                                              <init>
# 2                                                 run
# 3                                 appendEventOverview
# 4                                             doQuery
# 5                          lambda$initializeHandler$7
# 6                                   peekPrivateStream
# 7                                              <init>
# 8                             inspectFieldsAndMethods
# 9                                              <init>
# 10                                 doScheduleSnapshot
# 11                                getTrackedEventData
# 12                                             equals
# 13                                      createGateway
# 14  getExactDirectSuperTypesOfParameterizedTypeOrC...
# 15                                             <init>
# 16                            assertDispatchedEqualTo
# 17                                           dispatch
# 18                                             handle
# 19                                        updateToken
# 20                                  executeWithResult
# 21                                     matchingFields
# 22                                     defaultHeaders
# 23                                             <init>
# 24                                 fetchTrackedEvents
# 25                                            process
# 26                                            compare
# 27                                         updateSaga
# 28                                            execute
# 29                                    computeIfAbsent

# %% [markdown]
# ### Table 1d - Top 30 methods with the highest effective line count
#
# The following table shows the top 30 methods with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
effective_line_count_method_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxLinesMethodType', 'maxLinesMethodName', 'maxLinesMethod', 'linesInPackage']]

# Sort by the maximum of effective lines of code per package descending
effective_line_count_method_per_package=effective_line_count_method_per_package.sort_values(by='maxLinesMethod', ascending=False)

# Reset the index to the new sort order
effective_line_count_method_per_package=effective_line_count_method_per_package.reset_index()

# Print out the top 30 (head) rows
effective_line_count_method_per_package.head(30)
# Out:
#     index              artifactName  \
# 0       2      axon-messaging-4.6.8
# 1       0      axon-messaging-4.6.8
# 2      13      axon-messaging-4.6.8
# 3       3           axon-test-4.6.8
# 4      28      axon-messaging-4.6.8
# 5       1  axon-configuration-4.6.8
# 6      27      axon-modelling-4.6.8
# 7       4      axon-messaging-4.6.8
# 8      25      axon-messaging-4.6.8
# 9      20      axon-messaging-4.6.8
# 10      9      axon-disruptor-4.6.8
# 11     16           axon-test-4.6.8
# 12     12      axon-messaging-4.6.8
# 13     19      axon-messaging-4.6.8
# 14     24  axon-eventsourcing-4.6.8
# 15     31      axon-messaging-4.6.8
# 16     14      axon-messaging-4.6.8
# 17     11  axon-eventsourcing-4.6.8
# 18      8      axon-modelling-4.6.8
# 19      7      axon-messaging-4.6.8
# 20     18      axon-modelling-4.6.8
# 21     26      axon-modelling-4.6.8
# 22     21           axon-test-4.6.8
# 23     43      axon-messaging-4.6.8
# 24     17      axon-messaging-4.6.8
# 25     15      axon-messaging-4.6.8
# 26      6  axon-eventsourcing-4.6.8
# 27     36      axon-messaging-4.6.8
# 28     37      axon-modelling-4.6.8
# 29     10  axon-eventsourcing-4.6.8
#
#                                       fullPackageName  \
# 0              org.axonframework.eventhandling.pooled
# 1                     org.axonframework.eventhandling
# 2           org.axonframework.commandhandling.gateway
# 3                    org.axonframework.test.aggregate
# 4                   org.axonframework.deadline.quartz
# 5                            org.axonframework.config
# 6    org.axonframework.modelling.saga.repository.jdbc
# 7                     org.axonframework.queryhandling
# 8              org.axonframework.messaging.deadletter
# 9              org.axonframework.messaging.unitofwork
# 10        org.axonframework.disruptor.commandhandling
# 11                        org.axonframework.test.saga
# 12     org.axonframework.eventhandling.deadletter.jpa
# 13    org.axonframework.eventhandling.tokenstore.jdbc
# 14     org.axonframework.eventsourcing.eventstore.jpa
# 15                         org.axonframework.deadline
# 16                           org.axonframework.common
# 17    org.axonframework.eventsourcing.eventstore.jdbc
# 18     org.axonframework.modelling.command.inspection
# 19             org.axonframework.messaging.annotation
# 20                   org.axonframework.modelling.saga
# 21        org.axonframework.modelling.saga.repository
# 22                    org.axonframework.test.matchers
# 23    org.axonframework.serialization.upcasting.event
# 24      org.axonframework.commandhandling.distributed
# 25                    org.axonframework.serialization
# 26         org.axonframework.eventsourcing.eventstore
# 27  org.axonframework.eventhandling.scheduling.quartz
# 28    org.axonframework.modelling.saga.repository.jpa
# 29                    org.axonframework.eventsourcing
#
#                                    maxLinesMethodType  \
# 0                        Coordinator$CoordinationTask
# 1                              TrackingEventProcessor
# 2                               CommandGatewayFactory
# 3                                            Reporter
# 4                                         DeadlineJob
# 5                               EventProcessingModule
# 6                                       JdbcSagaStore
# 7                                      SimpleQueryBus
# 8                    InMemorySequencedDeadLetterQueue
# 9                                  BatchingUnitOfWork
# 10                                DisruptorCommandBus
# 11                                   CommandValidator
# 12                               DeadLetterEventEntry
# 13                                     JdbcTokenStore
# 14                              JpaEventStorageEngine
# 15                 SimpleDeadlineManager$DeadlineTask
# 16                                TypeReflectionUtils
# 17                             JdbcEventStorageEngine
# 18  AnnotatedAggregateMetaModelFactory$AnnotatedAg...
# 19                     AnnotatedMessageHandlingMember
# 20                                AbstractSagaManager
# 21     AssociationValueMap$AssociationValueComparator
# 22                                  DeepEqualsMatcher
# 23                         InitialEventRepresentation
# 24                              DistributedCommandBus
# 25                          AbstractXStreamSerializer
# 26                   EmbeddedEventStore$EventConsumer
# 27                                       FireEventJob
# 28                                       JpaSagaStore
# 29                                AbstractSnapshotter
#
#                                    maxLinesMethodName  maxLinesMethod  \
# 0                                                 run              70
# 1                                        processBatch              64
# 2                                       createGateway              50
# 3                                 appendEventOverview              45
# 4                                             execute              42
# 5                                              <init>              42
# 6                                          updateSaga              38
# 7                                             doQuery              36
# 8                                             process              33
# 9                                   executeWithResult              32
# 10                                             <init>              32
# 11                            assertDispatchedEqualTo              29
# 12                                             equals              28
# 13                                        updateToken              26
# 14                                 fetchTrackedEvents              25
# 15                                                run              24
# 16  getExactDirectSuperTypesOfParameterizedTypeOrC...              24
# 17                                getTrackedEventData              24
# 18                            inspectFieldsAndMethods              24
# 19                                             <init>              23
# 20                                             handle              23
# 21                                            compare              22
# 22                                     matchingFields              21
# 23                                             <init>              21
# 24                                           dispatch              21
# 25                                             <init>              21
# 26                                  peekPrivateStream              21
# 27                                            execute              21
# 28                                         updateSaga              20
# 29                                 doScheduleSnapshot              20
#
#     linesInPackage
# 0              935
# 1             2213
# 2              504
# 3              877
# 4              242
# 5             1462
# 6              263
# 7              832
# 8              282
# 9              363
# 10             605
# 11             487
# 12             521
# 13             430
# 14             320
# 15             218
# 16             501
# 17             569
# 18             631
# 19             665
# 20             456
# 21             268
# 22             351
# 23             104
# 24             479
# 25             488
# 26             707
# 27             178
# 28             174
# 29             582

# %% [markdown]
# ## Cyclomatic Complexity

# %% [markdown]
# ### Table 2a - Cyclomatic method complexity distribution
#
# This table shows the distribution of the cyclomatic complexity of methods per artifact.
# For each artifact the number of methods with the cyclomatic complexity = 1,2,3,... is shown to get an overview of how cyclomatic complexity is distributed over methods.
#
# Only the 15 artifacts with the highest method count sum and their cyclomatic method complexity distribution (limited by 40) is shown here. The whole table can be found in the CSV report `Cyclomatic_Method_Complexity_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
cyclomatic_method_complexity_distribution_max_artifacts=15

cyclomatic_method_complexity_distribution=query_cypher_to_data_frame("../cypher/Overview/Cyclomatic_Method_Complexity_Distribution.cypher")
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.pivot(index='cyclomaticComplexity', columns='artifactName', values='methods')

# Fill missing values with zero
cyclomatic_method_complexity_distribution.fillna(0, inplace=True)

# Convert to integer
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
cyclomatic_method_complexity_distribution = cyclomatic_method_complexity_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:cyclomatic_method_complexity_distribution_max_artifacts]]

cyclomatic_method_complexity_distribution.head(40)
# Out:
# artifactName          axon-messaging-4.6.8.jar  axon-eventsourcing-4.6.8.jar  \
# cyclomaticComplexity
# 1                                         3621                           782
# 2                                          382                            79
# 3                                          252                            40
# 4                                          117                            16
# 5                                           60                             7
# 6                                           42                             2
# 7                                           19                             6
# 8                                           10                             4
# 9                                            7                             0
# 10                                           4                             0
# 11                                           6                             0
# 12                                           3                             0
# 13                                           1                             1
# 14                                           1                             0
# 15                                           1                             0
# 16                                           1                             0
# 21                                           2                             0
#
# artifactName          axon-modelling-4.6.8.jar  axon-test-4.6.8.jar  \
# cyclomaticComplexity
# 1                                          764                  488
# 2                                           70                   59
# 3                                           33                   49
# 4                                           22                   20
# 5                                           22                   12
# 6                                           10                    8
# 7                                            2                    4
# 8                                            1                    3
# 9                                            2                    1
# 10                                           0                    1
# 11                                           0                    2
# 12                                           0                    1
# 13                                           0                    1
# 14                                           0                    0
# 15                                           0                    0
# 16                                           1                    0
# 21                                           0                    0
#
# artifactName          axon-configuration-4.6.8.jar  axon-disruptor-4.6.8.jar
# cyclomaticComplexity
# 1                                              515                       146
# 2                                               36                        20
# 3                                               13                         5
# 4                                                3                         4
# 5                                                3                         3
# 6                                                1                         2
# 7                                                2                         2
# 8                                                0                         2
# 9                                                0                         0
# 10                                               0                         0
# 11                                               0                         0
# 12                                               0                         0
# 13                                               0                         0
# 14                                               0                         0
# 15                                               0                         0
# 16                                               0                         0
# 21                                               0                         0

# %% [markdown]
# ### Table 2b - Cyclomatic method complexity distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
cyclomatic_method_complexity_distribution_normalized = cyclomatic_method_complexity_distribution.div(cyclomatic_method_complexity_distribution.sum(axis=0), axis=1).multiply(100)
cyclomatic_method_complexity_distribution_normalized.head(40)
# Out:
# artifactName          axon-messaging-4.6.8.jar  axon-eventsourcing-4.6.8.jar  \
# cyclomaticComplexity
# 1                                    79.951424                     83.457844
# 2                                     8.434533                      8.431163
# 3                                     5.564142                      4.268943
# 4                                     2.583352                      1.707577
# 5                                     1.324796                      0.747065
# 6                                     0.927357                      0.213447
# 7                                     0.419519                      0.640342
# 8                                     0.220799                      0.426894
# 9                                     0.154560                      0.000000
# 10                                    0.088320                      0.000000
# 11                                    0.132480                      0.000000
# 12                                    0.066240                      0.000000
# 13                                    0.022080                      0.106724
# 14                                    0.022080                      0.000000
# 15                                    0.022080                      0.000000
# 16                                    0.022080                      0.000000
# 21                                    0.044160                      0.000000
#
# artifactName          axon-modelling-4.6.8.jar  axon-test-4.6.8.jar  \
# cyclomaticComplexity
# 1                                    82.416397            75.192604
# 2                                     7.551241             9.090909
# 3                                     3.559871             7.550077
# 4                                     2.373247             3.081664
# 5                                     2.373247             1.848998
# 6                                     1.078749             1.232666
# 7                                     0.215750             0.616333
# 8                                     0.107875             0.462250
# 9                                     0.215750             0.154083
# 10                                    0.000000             0.154083
# 11                                    0.000000             0.308166
# 12                                    0.000000             0.154083
# 13                                    0.000000             0.154083
# 14                                    0.000000             0.000000
# 15                                    0.000000             0.000000
# 16                                    0.107875             0.000000
# 21                                    0.000000             0.000000
#
# artifactName          axon-configuration-4.6.8.jar  axon-disruptor-4.6.8.jar
# cyclomaticComplexity
# 1                                        89.877836                 79.347826
# 2                                         6.282723                 10.869565
# 3                                         2.268761                  2.717391
# 4                                         0.523560                  2.173913
# 5                                         0.523560                  1.630435
# 6                                         0.174520                  1.086957
# 7                                         0.349040                  1.086957
# 8                                         0.000000                  1.086957
# 9                                         0.000000                  0.000000
# 10                                        0.000000                  0.000000
# 11                                        0.000000                  0.000000
# 12                                        0.000000                  0.000000
# 13                                        0.000000                  0.000000
# 14                                        0.000000                  0.000000
# 15                                        0.000000                  0.000000
# 16                                        0.000000                  0.000000
# 21                                        0.000000                  0.000000

# %% [markdown]
# ### Table 2b Chart 1 - Cyclomatic method complexity distribution (normalized)

# %%
plot.figure();
method_line_count_x_ticks=range(1,11)
cyclomatic_complexity_y_ticks=[1, 2, 3, 4, 5, 7, 10, 20, 30, 40, 50, 100]
axes = cyclomatic_method_complexity_distribution_normalized.plot(
    kind='line', 
    logx=True,
    logy=True,
    grid=True,
    xlim=[1,11],
    ylim=[1,100],
    xticks=method_line_count_x_ticks,
    yticks=cyclomatic_complexity_y_ticks,
    title='Cyclomatic complexity distribution of methods', 
    xlabel='cyclomatic complexity',
    ylabel='percentage of methods',
    cmap=main_color_map,
)
axes.set_xticklabels(method_line_count_x_ticks)
axes.set_yticklabels(cyclomatic_complexity_y_ticks)
axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 2c - Top 30 packages with highest cyclomatic complexity
#
# The following table shows the top 30 packages with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'complexityInPackage', 'methodCount', 'maxComplexity','maxComplexityMethod']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_package=cyclomatic_complexity_per_package.sort_values(by='complexityInPackage', ascending=False)

# Print out the top 30 (head) rows
cyclomatic_complexity_per_package.head(30)
# Out:
#                 artifactName                                  fullPackageName  \
# 0       axon-messaging-4.6.8                  org.axonframework.eventhandling
# 1   axon-configuration-4.6.8                         org.axonframework.config
# 4       axon-messaging-4.6.8                  org.axonframework.queryhandling
# 2       axon-messaging-4.6.8           org.axonframework.eventhandling.pooled
# 5       axon-modelling-4.6.8              org.axonframework.modelling.command
# 3            axon-test-4.6.8                 org.axonframework.test.aggregate
# 6   axon-eventsourcing-4.6.8       org.axonframework.eventsourcing.eventstore
# 7       axon-messaging-4.6.8           org.axonframework.messaging.annotation
# 8       axon-modelling-4.6.8   org.axonframework.modelling.command.inspection
# 10  axon-eventsourcing-4.6.8                  org.axonframework.eventsourcing
# 14      axon-messaging-4.6.8                         org.axonframework.common
# 9       axon-disruptor-4.6.8      org.axonframework.disruptor.commandhandling
# 11  axon-eventsourcing-4.6.8  org.axonframework.eventsourcing.eventstore.jdbc
# 18      axon-modelling-4.6.8                 org.axonframework.modelling.saga
# 15      axon-messaging-4.6.8                  org.axonframework.serialization
# 13      axon-messaging-4.6.8        org.axonframework.commandhandling.gateway
# 17      axon-messaging-4.6.8    org.axonframework.commandhandling.distributed
# 16           axon-test-4.6.8                      org.axonframework.test.saga
# 12      axon-messaging-4.6.8   org.axonframework.eventhandling.deadletter.jpa
# 22      axon-messaging-4.6.8                      org.axonframework.messaging
# 20      axon-messaging-4.6.8           org.axonframework.messaging.unitofwork
# 21           axon-test-4.6.8                  org.axonframework.test.matchers
# 23      axon-messaging-4.6.8                org.axonframework.commandhandling
# 19      axon-messaging-4.6.8  org.axonframework.eventhandling.tokenstore.jdbc
# 25      axon-messaging-4.6.8           org.axonframework.messaging.deadletter
# 24  axon-eventsourcing-4.6.8   org.axonframework.eventsourcing.eventstore.jpa
# 34      axon-messaging-4.6.8        org.axonframework.messaging.responsetypes
# 29      axon-messaging-4.6.8                 org.axonframework.common.caching
# 26      axon-modelling-4.6.8      org.axonframework.modelling.saga.repository
# 30      axon-messaging-4.6.8                        org.axonframework.tracing
#
#     complexityInPackage  methodCount  maxComplexity  \
# 0                  1214          793             21
# 1                   673          573              7
# 4                   419          333             11
# 2                   415          308             21
# 5                   411          307              9
# 3                   410          240             13
# 6                   394          261             13
# 7                   380          233             14
# 8                   338          216              9
# 10                  305          236              8
# 14                  301          144              9
# 9                   274          184              8
# 11                  273          236              7
# 18                  262          182              6
# 15                  260          170              7
# 13                  257          180             12
# 17                  240          172             12
# 16                  230          164              9
# 12                  212          132             15
# 22                  209          156              4
# 20                  206          129             11
# 21                  191          108              8
# 23                  180          151             10
# 19                  173          130              9
# 25                  156          102             10
# 24                  155          101              8
# 34                  148           76             10
# 29                  146           93              6
# 26                  133           97             16
# 30                  127          101              7
#
#                                   maxComplexityMethod
# 0                                        processBatch
# 1                                   getFactoryForType
# 4                                             doQuery
# 2                                                 run
# 5                                       resolveTarget
# 3                                   ensureValuesEqual
# 6                                             hasNext
# 7                                              handle
# 8                                     prepareHandlers
# 10                                 doScheduleSnapshot
# 14  getExactDirectSuperTypesOfParameterizedTypeOrC...
# 9                                            onResult
# 11                                lambda$cleanGaps$37
# 18                     instantiateAssociationResolver
# 15                                     calculateRoute
# 13                                      createGateway
# 17                                             equals
# 16                            assertDispatchedEqualTo
# 12                                             equals
# 22                                               from
# 20                                  executeWithResult
# 21                                     matchingFields
# 23                                             <init>
# 19                                        updateToken
# 25                                             equals
# 24                              loadKeyViolationCodes
# 34                                            convert
# 29                                                put
# 26                                            compare
# 30                               determineMessageName

# %% [markdown]
# ### Table 2d - Top 30 methods with highest cyclomatic complexity
#
# The following table shows the top 30 packages containing the methods with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_method=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxComplexityType', 'maxComplexityMethod', 'maxComplexity']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.sort_values(by='maxComplexity', ascending=False)

# Reset the index to the new sort order
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.reset_index()

# Print out the top 30 (head) rows
cyclomatic_complexity_per_method.head(30)
# Out:
#     index              artifactName  \
# 0       0      axon-messaging-4.6.8
# 1       2      axon-messaging-4.6.8
# 2      26      axon-modelling-4.6.8
# 3      12      axon-messaging-4.6.8
# 4       7      axon-messaging-4.6.8
# 5       3           axon-test-4.6.8
# 6       6  axon-eventsourcing-4.6.8
# 7      41      axon-messaging-4.6.8
# 8      17      axon-messaging-4.6.8
# 9      32      axon-messaging-4.6.8
# 10     13      axon-messaging-4.6.8
# 11      4      axon-messaging-4.6.8
# 12     48           axon-test-4.6.8
# 13     20      axon-messaging-4.6.8
# 14     28      axon-messaging-4.6.8
# 15     25      axon-messaging-4.6.8
# 16     39      axon-messaging-4.6.8
# 17     34      axon-messaging-4.6.8
# 18     23      axon-messaging-4.6.8
# 19     40      axon-messaging-4.6.8
# 20     19      axon-messaging-4.6.8
# 21     14      axon-messaging-4.6.8
# 22      8      axon-modelling-4.6.8
# 23     16           axon-test-4.6.8
# 24      5      axon-modelling-4.6.8
# 25     44      axon-messaging-4.6.8
# 26     10  axon-eventsourcing-4.6.8
# 27      9      axon-disruptor-4.6.8
# 28     27      axon-modelling-4.6.8
# 29     24  axon-eventsourcing-4.6.8
#
#                                       fullPackageName  \
# 0                     org.axonframework.eventhandling
# 1              org.axonframework.eventhandling.pooled
# 2         org.axonframework.modelling.saga.repository
# 3      org.axonframework.eventhandling.deadletter.jpa
# 4              org.axonframework.messaging.annotation
# 5                    org.axonframework.test.aggregate
# 6          org.axonframework.eventsourcing.eventstore
# 7   org.axonframework.commandhandling.distributed....
# 8       org.axonframework.commandhandling.distributed
# 9                       org.axonframework.common.jdbc
# 10          org.axonframework.commandhandling.gateway
# 11                    org.axonframework.queryhandling
# 12                      org.axonframework.test.server
# 13             org.axonframework.messaging.unitofwork
# 14                  org.axonframework.deadline.quartz
# 15             org.axonframework.messaging.deadletter
# 16                      org.axonframework.common.lock
# 17          org.axonframework.messaging.responsetypes
# 18                  org.axonframework.commandhandling
# 19               org.axonframework.serialization.json
# 20    org.axonframework.eventhandling.tokenstore.jdbc
# 21                           org.axonframework.common
# 22     org.axonframework.modelling.command.inspection
# 23                        org.axonframework.test.saga
# 24                org.axonframework.modelling.command
# 25         org.axonframework.eventhandling.deadletter
# 26                    org.axonframework.eventsourcing
# 27        org.axonframework.disruptor.commandhandling
# 28   org.axonframework.modelling.saga.repository.jdbc
# 29     org.axonframework.eventsourcing.eventstore.jpa
#
#                                     maxComplexityType  \
# 0                              TrackingEventProcessor
# 1                        Coordinator$CoordinationTask
# 2      AssociationValueMap$AssociationValueComparator
# 3                                DeadLetterEventEntry
# 4                      AnnotatedMessageHandlingMember
# 5                                AggregateTestFixture
# 6                      ConcatenatingDomainEventStream
# 7                                   CommandNameFilter
# 8                                        ReplyMessage
# 9                            ConnectionWrapperFactory
# 10                              CommandGatewayFactory
# 11                                     SimpleQueryBus
# 12                              AxonServerEEContainer
# 13                                 BatchingUnitOfWork
# 14                                        DeadlineJob
# 15                                  GenericDeadLetter
# 16              PessimisticLockFactory$DisposableLock
# 17                      MultipleInstancesResponseType
# 18  MethodCommandHandlerDefinition$MethodCommandMe...
# 19                                  JacksonSerializer
# 20                                     JdbcTokenStore
# 21                                TypeReflectionUtils
# 22  AnnotatedAggregateMetaModelFactory$AnnotatedAg...
# 23                                   CommandValidator
# 24                    AnnotationCommandTargetResolver
# 25                   DeadLetteringEventHandlerInvoker
# 26                                AbstractSnapshotter
# 27                         BlacklistDetectingCallback
# 28                                      JdbcSagaStore
# 29                              SQLErrorCodesResolver
#
#                                   maxComplexityMethod  maxComplexity
# 0                                        processBatch             21
# 1                                                 run             21
# 2                                             compare             16
# 3                                              equals             15
# 4                                              handle             14
# 5                                   ensureValuesEqual             13
# 6                                             hasNext             13
# 7                                 $deserializeLambda$             13
# 8                                              equals             12
# 9                                       lambda$wrap$0             12
# 10                                      createGateway             12
# 11                                            doQuery             11
# 12                                             equals             11
# 13                                  executeWithResult             11
# 14                                            execute             11
# 15                                             equals             10
# 16                                               lock             10
# 17                                            convert             10
# 18                                             <init>             10
# 19                                        deserialize              9
# 20                                        updateToken              9
# 21  getExactDirectSuperTypesOfParameterizedTypeOrC...              9
# 22                                    prepareHandlers              9
# 23                            assertDispatchedEqualTo              9
# 24                                      resolveTarget              9
# 25                                             handle              8
# 26                                 doScheduleSnapshot              8
# 27                                           onResult              8
# 28                                         updateSaga              8
# 29                              loadKeyViolationCodes              8
