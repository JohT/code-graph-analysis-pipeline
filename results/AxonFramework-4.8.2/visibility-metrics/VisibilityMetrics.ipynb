# %% [markdown]
# # Visibility Metrics
# <br>
#
# ### References
# - [Visibility Metrics and the Importance of Hiding Things](https://dzone.com/articles/visibility-metrics-and-the-importance-of-hiding-th)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Controlling Access to Members of a Class](https://docs.oracle.com/javase/tutorial/java/javaOO/accesscontrol.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Relative Visibility Of Types
#
# A Java class or interface may be declared with the modifier public, in which case it is visible to all classes everywhere. If a class or interface has no modifier (the default, also known as package-private), it is visible only within its own package.
#
# The relative visibility is the number of inner components that are visible outside (public) divided by the number of all types:
#
# $$ relative visibility = \frac{public\:types}{all\:types} $$
#
# Using package protected types is one of many ways to improve encapsulation and implementation detail hiding.
#
# ### How to apply the results
#
# The relative visibility is between zero (all types are package protected) and one (all types are public). A value lower than one means that there are types that are declared package protected. The lower the value is, the better implementation details are hidden.
#
# Non public classes can't be accessed from another package so they can be changed without affecting code in other packages. They clearly indicate functionality that only belongs to one package. This also motivates to use more classes and to split up code into smaller pieces with a single responsibility and reason to change.

# %% [markdown]
# ### Table 1a - Top 40 artifacts with lowest median of package protection encapsulation
#
# This table shows the relative visibility statistics aggregated for all packages per artifact and focusses on artifacts with many packages and hardly any package protected types (lowest median, high visibility). Package protected types would help to  improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Global_relative_visibility_statistics_for_types`

# %%
# Query the visibility statistics per artifact (all packages aggregated)
# The results Will be used in multiple tables below.
relative_visibility_per_artifact_aggregated=query_cypher_to_data_frame("../cypher/Visibility/Global_relative_visibility_statistics_for_types.cypher")

# %%
# Sort by the "percentile50" (median) and "all" (number of packages in the artifact) descending
relative_visibility_statistics_highest_median=relative_visibility_per_artifact_aggregated.sort_values(by=['percentile50', 'all'], ascending=[False, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
relative_visibility_statistics_highest_median=relative_visibility_statistics_highest_median.reset_index(drop=True)

relative_visibility_statistics_highest_median.head(40)
# Out:
#                    artifact  all  public       min       max   average  \
# 0      axon-messaging-4.8.2  762     623  0.100000  1.000000  0.866241
# 1      axon-modelling-4.8.2  150     129  0.500000  1.000000  0.805873
# 2  axon-eventsourcing-4.8.2  130      95  0.500000  1.000000  0.769159
# 3           axon-test-4.8.2   87      65  0.473684  1.000000  0.781086
# 4  axon-configuration-4.8.2   39      26  0.666667  0.666667  0.666667
# 5      axon-disruptor-4.8.2   22       9  0.409091  0.409091  0.409091
#
#    percentile25  percentile50  percentile75  percentile90
# 0      0.750000      0.973684      1.000000      1.000000
# 1      0.737500      0.813187      0.895588      1.000000
# 2      0.612903      0.785714      1.000000      1.000000
# 3      0.650000      0.775000      0.968750      1.000000
# 4      0.666667      0.666667      0.666667      0.666667
# 5      0.409091      0.409091      0.409091      0.409091

# %% [markdown]
# ### Table 1b - Top 40 artifacts with highest median of package protection encapsulation
#
# This table shows the relative visibility statistics aggregated for all packages per artifact and focusses on artifacts with many packages and the highest median of package protected types (low visibility). Package protected types help to improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Global_relative_visibility_statistics_for_types`

# %%
# Sort by the "percentile50" (median) ascending and "all" (number of packages in the artifact) descending
relative_visibility_statistics_lowest_median=relative_visibility_per_artifact_aggregated.sort_values(by=['percentile50', 'all'], ascending=[True, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
relative_visibility_statistics_lowest_median=relative_visibility_statistics_lowest_median.reset_index(drop=True)

relative_visibility_statistics_lowest_median.head(40)
# Out:
#                    artifact  all  public       min       max   average  \
# 0      axon-disruptor-4.8.2   22       9  0.409091  0.409091  0.409091
# 1  axon-configuration-4.8.2   39      26  0.666667  0.666667  0.666667
# 2           axon-test-4.8.2   87      65  0.473684  1.000000  0.781086
# 3  axon-eventsourcing-4.8.2  130      95  0.500000  1.000000  0.769159
# 4      axon-modelling-4.8.2  150     129  0.500000  1.000000  0.805873
# 5      axon-messaging-4.8.2  762     623  0.100000  1.000000  0.866241
#
#    percentile25  percentile50  percentile75  percentile90
# 0      0.409091      0.409091      0.409091      0.409091
# 1      0.666667      0.666667      0.666667      0.666667
# 2      0.650000      0.775000      0.968750      1.000000
# 3      0.612903      0.785714      1.000000      1.000000
# 4      0.737500      0.813187      0.895588      1.000000
# 5      0.750000      0.973684      1.000000      1.000000

# %% [markdown]
# ### Table 1 Chart 1 - Relative visibility in artifacts

# %%
plot.figure();
fig, axes = plot.subplots(nrows=3, ncols=1, sharex=True)

number_of_packages_grid_ticks=[1, 2, 5, 10, 20, 50, 100, 200, 500, 1_000, 2_000, 5_000, 10_000]

relative_visibility_per_artifact_aggregated.plot(
    ax=axes[0],
    kind='scatter',
    title='Relative visibility in artifacts (75% percentile)', 
    x='percentile75',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_packages_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of packages',
    cmap=main_color_map,
    figsize=(10,4),
)
relative_visibility_per_artifact_aggregated.plot(
    ax=axes[1],
    kind='scatter',
    title='Relative visibility in artifacts (50% percentile)', 
    x='percentile50',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_packages_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of packages',
    cmap=main_color_map,
    figsize=(10,4),
)
relative_visibility_per_artifact_aggregated.plot(
    ax=axes[2],
    kind='scatter',
    title='Relative visibility in artifacts (25% percentile)', 
    x='percentile25',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_packages_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of packages',
    cmap=main_color_map,
    figsize=(10,10),
)
axes[0].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
axes[1].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
axes[2].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
plot.show()
# Out:
# /usr/share/miniconda3/envs/codegraph/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ### Table 2a - Top 40 packages with the highest visibility and lowest encapsulation
#
# This table shows the relative visibility statistics per packages and artifact and focusses on packages with many types, hardly any package protected ones and therefore the highest relative visibility (lowest encapsulation). Package protected types would help to improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Relative_visibility_public_types_to_all_types_per_package`

# %%
# Query the visibility statistics per package and artifact (all types aggregated)
# The results Will be used in multiple tables below.
relative_visibility_per_package=query_cypher_to_data_frame("../cypher/Visibility/Relative_visibility_public_types_to_all_types_per_package.cypher")

# %%
# Sort by the "relativeVisibility" and "allTypes" (number of types in the package) descending
highest_relative_visibility_packages=relative_visibility_per_package.sort_values(by=['relativeVisibility', 'allTypes'], ascending=[False, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
highest_relative_visibility_packages=highest_relative_visibility_packages.reset_index(drop=True)

highest_relative_visibility_packages.head(40)
# Out:
#                 artifactName  \
# 0       axon-modelling-4.8.2
# 1   axon-eventsourcing-4.8.2
# 2       axon-messaging-4.8.2
# 3       axon-messaging-4.8.2
# 4   axon-eventsourcing-4.8.2
# 5       axon-messaging-4.8.2
# 6       axon-messaging-4.8.2
# 7       axon-messaging-4.8.2
# 8       axon-messaging-4.8.2
# 9       axon-messaging-4.8.2
# 10      axon-messaging-4.8.2
# 11      axon-messaging-4.8.2
# 12      axon-messaging-4.8.2
# 13      axon-messaging-4.8.2
# 14      axon-messaging-4.8.2
# 15      axon-messaging-4.8.2
# 16      axon-messaging-4.8.2
# 17      axon-messaging-4.8.2
# 18      axon-messaging-4.8.2
# 19      axon-messaging-4.8.2
# 20           axon-test-4.8.2
# 21      axon-messaging-4.8.2
# 22      axon-messaging-4.8.2
# 23      axon-messaging-4.8.2
# 24      axon-messaging-4.8.2
# 25      axon-messaging-4.8.2
# 26      axon-messaging-4.8.2
# 27      axon-messaging-4.8.2
# 28           axon-test-4.8.2
# 29  axon-eventsourcing-4.8.2
# 30      axon-messaging-4.8.2
# 31      axon-messaging-4.8.2
# 32      axon-messaging-4.8.2
# 33      axon-messaging-4.8.2
# 34      axon-messaging-4.8.2
# 35      axon-modelling-4.8.2
# 36      axon-messaging-4.8.2
# 37      axon-messaging-4.8.2
# 38      axon-messaging-4.8.2
# 39           axon-test-4.8.2
#
#                              fullQualifiedPackageName         packageName  \
# 0                    org.axonframework.modelling.saga                saga
# 1   org.axonframework.eventsourcing.eventstore.jdb...          statements
# 2     org.axonframework.serialization.upcasting.event               event
# 3                         org.axonframework.lifecycle           lifecycle
# 4   org.axonframework.eventsourcing.conflictresolu...  conflictresolution
# 5                   org.axonframework.common.property            property
# 6            org.axonframework.messaging.interceptors        interceptors
# 7           org.axonframework.messaging.responsetypes       responsetypes
# 8   org.axonframework.commandhandling.distributed....       commandfilter
# 9                org.axonframework.serialization.json                json
# 10         org.axonframework.eventhandling.tokenstore          tokenstore
# 11                org.axonframework.serialization.xml                 xml
# 12               org.axonframework.tracing.attributes          attributes
# 13             org.axonframework.deadline.dbscheduler         dbscheduler
# 14  org.axonframework.eventhandling.scheduling.dbs...         dbscheduler
# 15  org.axonframework.eventhandling.scheduling.quartz              quartz
# 16          org.axonframework.serialization.upcasting           upcasting
# 17         org.axonframework.serialization.converters          converters
# 18            org.axonframework.eventhandling.gateway             gateway
# 19       org.axonframework.queryhandling.registration        registration
# 20              org.axonframework.test.eventscheduler      eventscheduler
# 21        org.axonframework.commandhandling.callbacks           callbacks
# 22            org.axonframework.messaging.correlation         correlation
# 23                 org.axonframework.deadline.jobrunr             jobrunr
# 24                       org.axonframework.common.jpa                 jpa
# 25     org.axonframework.eventhandling.tokenstore.jpa                 jpa
# 26                 org.axonframework.common.legacyjpa           legacyjpa
# 27                  org.axonframework.deadline.quartz              quartz
# 28                    org.axonframework.test.deadline            deadline
# 29       org.axonframework.eventsourcing.snapshotting        snapshotting
# 30  org.axonframework.eventhandling.scheduling.job...             jobrunr
# 31         org.axonframework.eventhandling.scheduling          scheduling
# 32                             org.axonframework.util                util
# 33  org.axonframework.eventhandling.tokenstore.leg...           legacyjpa
# 34  org.axonframework.messaging.interceptors.legac...    legacyvalidation
# 35      org.axonframework.modelling.command.legacyjpa           legacyjpa
# 36                    org.axonframework.common.digest              digest
# 37       org.axonframework.eventhandling.interceptors        interceptors
# 38                        org.axonframework.common.io                  io
# 39                    org.axonframework.test.matchers            matchers
#
#     publicTypes  allTypes  relativeVisibility
# 0            30        30            1.000000
# 1            15        15            1.000000
# 2            12        12            1.000000
# 3            10        10            1.000000
# 4             9         9            1.000000
# 5             9         9            1.000000
# 6             8         8            1.000000
# 7             8         8            1.000000
# 8             7         7            1.000000
# 9             7         7            1.000000
# 10            7         7            1.000000
# 11            7         7            1.000000
# 12            6         6            1.000000
# 13            6         6            1.000000
# 14            6         6            1.000000
# 15            6         6            1.000000
# 16            6         6            1.000000
# 17            5         5            1.000000
# 18            5         5            1.000000
# 19            5         5            1.000000
# 20            5         5            1.000000
# 21            4         4            1.000000
# 22            4         4            1.000000
# 23            4         4            1.000000
# 24            4         4            1.000000
# 25            4         4            1.000000
# 26            4         4            1.000000
# 27            4         4            1.000000
# 28            4         4            1.000000
# 29            3         3            1.000000
# 30            3         3            1.000000
# 31            3         3            1.000000
# 32            3         3            1.000000
# 33            2         2            1.000000
# 34            2         2            1.000000
# 35            2         2            1.000000
# 36            1         1            1.000000
# 37            1         1            1.000000
# 38            1         1            1.000000
# 39           23        24            0.958333

# %% [markdown]
# ### Table 2b - Top 40 packages with the lowest visibility and highest encapsulation
#
# This table shows the relative visibility statistics per packages and artifact and focusses on packages with many types, many package protected ones and therefore the lowest relative visibility (highest encapsulation). Package protected types help to improve encapsulation. Zero percent visibility and therefore packages with no public visible type are suspicious to be dead code.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Relative_visibility_public_types_to_all_types_per_package`

# %%
# Sort by the "relativeVisibility" ascending and "allTypes" (number of types in the package) descending
lowest_relative_visibility_packages=relative_visibility_per_package.sort_values(by=['relativeVisibility', 'allTypes'], ascending=[True, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
lowest_relative_visibility_packages=lowest_relative_visibility_packages.reset_index(drop=True)

lowest_relative_visibility_packages.head(40)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.8.2
# 1       axon-disruptor-4.8.2
# 2            axon-test-4.8.2
# 3   axon-eventsourcing-4.8.2
# 4       axon-messaging-4.8.2
# 5   axon-eventsourcing-4.8.2
# 6       axon-messaging-4.8.2
# 7       axon-modelling-4.8.2
# 8       axon-messaging-4.8.2
# 9       axon-messaging-4.8.2
# 10      axon-messaging-4.8.2
# 11      axon-messaging-4.8.2
# 12      axon-messaging-4.8.2
# 13           axon-test-4.8.2
# 14  axon-eventsourcing-4.8.2
# 15  axon-configuration-4.8.2
# 16  axon-eventsourcing-4.8.2
# 17           axon-test-4.8.2
# 18      axon-messaging-4.8.2
# 19      axon-messaging-4.8.2
# 20      axon-modelling-4.8.2
# 21      axon-messaging-4.8.2
# 22      axon-messaging-4.8.2
# 23      axon-messaging-4.8.2
# 24      axon-messaging-4.8.2
# 25      axon-modelling-4.8.2
# 26      axon-messaging-4.8.2
# 27      axon-messaging-4.8.2
# 28      axon-messaging-4.8.2
# 29      axon-messaging-4.8.2
# 30      axon-modelling-4.8.2
# 31           axon-test-4.8.2
# 32      axon-modelling-4.8.2
# 33      axon-messaging-4.8.2
# 34  axon-eventsourcing-4.8.2
# 35           axon-test-4.8.2
# 36      axon-messaging-4.8.2
# 37      axon-messaging-4.8.2
# 38      axon-messaging-4.8.2
# 39      axon-messaging-4.8.2
#
#                              fullQualifiedPackageName      packageName  \
# 0              org.axonframework.eventhandling.pooled           pooled
# 1         org.axonframework.disruptor.commandhandling  commandhandling
# 2                    org.axonframework.test.aggregate        aggregate
# 3   org.axonframework.eventsourcing.eventstore.leg...        legacyjpa
# 4          org.axonframework.eventhandling.deadletter       deadletter
# 5   org.axonframework.eventsourcing.eventstore.inm...         inmemory
# 6   org.axonframework.eventhandling.tokenstore.inm...         inmemory
# 7   org.axonframework.modelling.saga.repository.in...         inmemory
# 8           org.axonframework.commandhandling.gateway          gateway
# 9               org.axonframework.eventhandling.async            async
# 10                   org.axonframework.common.caching          caching
# 11             org.axonframework.eventhandling.replay           replay
# 12              org.axonframework.deadline.annotation       annotation
# 13                             org.axonframework.test             test
# 14         org.axonframework.eventsourcing.eventstore       eventstore
# 15                           org.axonframework.config           config
# 16                    org.axonframework.eventsourcing    eventsourcing
# 17                        org.axonframework.test.saga             saga
# 18                org.axonframework.common.annotation       annotation
# 19                    org.axonframework.common.stream           stream
# 20  org.axonframework.modelling.saga.repository.le...        legacyjpa
# 21                         org.axonframework.deadline         deadline
# 22             org.axonframework.messaging.unitofwork       unitofwork
# 23                          org.axonframework.tracing          tracing
# 24                      org.axonframework.common.lock             lock
# 25        org.axonframework.modelling.saga.repository       repository
# 26             org.axonframework.messaging.annotation       annotation
# 27         org.axonframework.queryhandling.annotation       annotation
# 28    org.axonframework.eventhandling.scheduling.java             java
# 29               org.axonframework.common.transaction      transaction
# 30         org.axonframework.modelling.saga.metamodel        metamodel
# 31                      org.axonframework.test.server           server
# 32     org.axonframework.modelling.command.inspection       inspection
# 33                    org.axonframework.queryhandling    queryhandling
# 34    org.axonframework.eventsourcing.eventstore.jdbc             jdbc
# 35                       org.axonframework.test.utils            utils
# 36                    org.axonframework.serialization    serialization
# 37                      org.axonframework.common.jdbc             jdbc
# 38  org.axonframework.eventhandling.deadletter.leg...        legacyjpa
# 39                       org.axonframework.monitoring       monitoring
#
#     publicTypes  allTypes  relativeVisibility
# 0             2        20            0.100000
# 1             9        22            0.409091
# 2             9        19            0.473684
# 3             5        10            0.500000
# 4             2         4            0.500000
# 5             1         2            0.500000
# 6             1         2            0.500000
# 7             1         2            0.500000
# 8            19        34            0.558824
# 9             9        15            0.600000
# 10            9        15            0.600000
# 11            6        10            0.600000
# 12            3         5            0.600000
# 13            3         5            0.600000
# 14           19        31            0.612903
# 15           26        39            0.666667
# 16           26        39            0.666667
# 17           14        21            0.666667
# 18            2         3            0.666667
# 19            2         3            0.666667
# 20            2         3            0.666667
# 21            7        10            0.700000
# 22           10        14            0.714286
# 23           13        18            0.722222
# 24            8        11            0.727273
# 25           11        15            0.733333
# 26           40        54            0.740741
# 27            3         4            0.750000
# 28            3         4            0.750000
# 29            3         4            0.750000
# 30            3         4            0.750000
# 31            3         4            0.750000
# 32           20        26            0.769231
# 33           33        42            0.785714
# 34           11        14            0.785714
# 35            4         5            0.800000
# 36           28        34            0.823529
# 37           15        18            0.833333
# 38            5         6            0.833333
# 39            5         6            0.833333

# %% [markdown]
# ### Table 2 Chart 1 - Relative visibility of packages

# %%
plot.figure();

number_of_types_grid_ticks=[1, 2, 5, 10, 20, 50, 100, 200, 500, 1_000, 2_000, 5_000, 10_000]

relative_visibility_per_package.plot(
    kind='scatter',
    title='Relative visibility of packages', 
    x='relativeVisibility',
    y='allTypes',
    grid=True,
    logy=True,
    yticks=number_of_types_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of types',
    cmap=main_color_map,
    figsize=(10,4),
)

plot.show()
# Out:
# /usr/share/miniconda3/envs/codegraph/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
