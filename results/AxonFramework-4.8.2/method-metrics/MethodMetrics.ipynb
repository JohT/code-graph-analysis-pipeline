# %% [markdown]
# # Method Metrics
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## Effective Method Line Count

# %% [markdown]
# ### Table 1a - Effective method line count distribution
#
# This table shows the distribution of the effective method line count per artifact.
# For each artifact the number of methods with effective line count = 1,2,3,... is shown to get an overview of how line counts are distributed over methods.
#
# Only the 15 artifacts with the highest method count and their effective method line count distribution (limited by 40)is shown here. The whole table can be found in the CSV report `Effective_Method_Line_Count_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
effective_method_line_count_distribution_max_artifacts=20

effective_method_line_count_distribution=query_cypher_to_data_frame("../cypher/Overview/Effective_Method_Line_Count_Distribution.cypher")
effective_method_line_count_distribution=effective_method_line_count_distribution.pivot(index='effectiveLineCount', columns='artifactName', values='methods')

# Fill missing values with zero
effective_method_line_count_distribution.fillna(0, inplace=True)

# Convert to integer
effective_method_line_count_distribution=effective_method_line_count_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
effective_method_line_count_distribution = effective_method_line_count_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:effective_method_line_count_distribution_max_artifacts]]

effective_method_line_count_distribution.head(40)
# Out:
# artifactName        axon-messaging-4.8.2.jar  axon-eventsourcing-4.8.2.jar  \
# effectiveLineCount
# 1                                       2743                           567
# 2                                        790                           197
# 3                                        642                           123
# 4                                        270                            64
# 5                                        217                            40
# 6                                        150                            33
# 7                                        100                            31
# 8                                         79                            11
# 9                                         73                            17
# 10                                        46                             8
# 11                                        47                             2
# 12                                        39                             5
# 13                                        25                             2
# 14                                        15                             3
# 15                                         8                             2
# 16                                         8                             6
# 17                                         9                             0
# 18                                         8                             3
# 19                                         7                             0
# 20                                         4                             2
# 21                                         7                             2
# 22                                         5                             0
# 23                                         3                             1
# 24                                         6                             2
# 25                                         0                             2
# 26                                         2                             0
# 28                                         2                             0
# 29                                         1                             0
# 31                                         1                             0
# 32                                         1                             0
# 33                                         1                             0
# 34                                         1                             0
# 36                                         2                             0
# 38                                         0                             0
# 40                                         0                             0
# 42                                         1                             0
# 43                                         0                             0
# 45                                         0                             0
# 50                                         1                             0
# 57                                         1                             0
#
# artifactName        axon-modelling-4.8.2.jar  axon-test-4.8.2.jar  \
# effectiveLineCount
# 1                                        523                  279
# 2                                        147                  169
# 3                                        135                   64
# 4                                         57                   49
# 5                                         44                   24
# 6                                         44                   18
# 7                                         23                   20
# 8                                         10                   11
# 9                                         17                   11
# 10                                         8                    3
# 11                                         8                    9
# 12                                         2                    9
# 13                                         9                    5
# 14                                         3                    3
# 15                                         5                    2
# 16                                         2                    4
# 17                                         2                    4
# 18                                         0                    2
# 19                                         1                    0
# 20                                         2                    1
# 21                                         1                    1
# 22                                         1                    1
# 23                                         1                    1
# 24                                         1                    1
# 25                                         0                    0
# 26                                         1                    1
# 28                                         0                    1
# 29                                         0                    0
# 31                                         0                    1
# 32                                         0                    0
# 33                                         0                    0
# 34                                         0                    0
# 36                                         0                    0
# 38                                         1                    0
# 40                                         0                    0
# 42                                         0                    0
# 43                                         0                    0
# 45                                         0                    1
# 50                                         0                    0
# 57                                         0                    0
#
# artifactName        axon-configuration-4.8.2.jar  axon-disruptor-4.8.2.jar
# effectiveLineCount
# 1                                            308                        84
# 2                                            135                        31
# 3                                             35                        30
# 4                                             32                         8
# 5                                             16                         5
# 6                                             16                         6
# 7                                              2                         2
# 8                                              7                         0
# 9                                              8                         4
# 10                                             6                         3
# 11                                             5                         1
# 12                                             1                         1
# 13                                             2                         1
# 14                                             1                         2
# 15                                             0                         0
# 16                                             0                         0
# 17                                             1                         1
# 18                                             1                         1
# 19                                             1                         1
# 20                                             0                         0
# 21                                             1                         0
# 22                                             0                         1
# 23                                             1                         0
# 24                                             0                         1
# 25                                             0                         0
# 26                                             1                         0
# 28                                             0                         0
# 29                                             0                         0
# 31                                             0                         0
# 32                                             0                         1
# 33                                             0                         0
# 34                                             0                         0
# 36                                             0                         0
# 38                                             0                         0
# 40                                             1                         0
# 42                                             0                         0
# 43                                             1                         0
# 45                                             0                         0
# 50                                             0                         0
# 57                                             0                         0

# %% [markdown]
# ### Table 1b - Effective method line count distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
effective_method_line_count_distribution_normalized = effective_method_line_count_distribution.div(effective_method_line_count_distribution.sum(axis=0), axis=1).multiply(100)
effective_method_line_count_distribution_normalized.head(40)
# Out:
# artifactName        axon-messaging-4.8.2.jar  axon-eventsourcing-4.8.2.jar  \
# effectiveLineCount
# 1                                  51.589242                     50.489760
# 2                                  14.858003                     17.542297
# 3                                  12.074478                     10.952805
# 4                                   5.078052                      5.699020
# 5                                   4.081249                      3.561888
# 6                                   2.821140                      2.938557
# 7                                   1.880760                      2.760463
# 8                                   1.485800                      0.979519
# 9                                   1.372955                      1.513802
# 10                                  0.865150                      0.712378
# 11                                  0.883957                      0.178094
# 12                                  0.733496                      0.445236
# 13                                  0.470190                      0.178094
# 14                                  0.282114                      0.267142
# 15                                  0.150461                      0.178094
# 16                                  0.150461                      0.534283
# 17                                  0.169268                      0.000000
# 18                                  0.150461                      0.267142
# 19                                  0.131653                      0.000000
# 20                                  0.075230                      0.178094
# 21                                  0.131653                      0.178094
# 22                                  0.094038                      0.000000
# 23                                  0.056423                      0.089047
# 24                                  0.112846                      0.178094
# 25                                  0.000000                      0.178094
# 26                                  0.037615                      0.000000
# 28                                  0.037615                      0.000000
# 29                                  0.018808                      0.000000
# 31                                  0.018808                      0.000000
# 32                                  0.018808                      0.000000
# 33                                  0.018808                      0.000000
# 34                                  0.018808                      0.000000
# 36                                  0.037615                      0.000000
# 38                                  0.000000                      0.000000
# 40                                  0.000000                      0.000000
# 42                                  0.018808                      0.000000
# 43                                  0.000000                      0.000000
# 45                                  0.000000                      0.000000
# 50                                  0.018808                      0.000000
# 57                                  0.018808                      0.000000
#
# artifactName        axon-modelling-4.8.2.jar  axon-test-4.8.2.jar  \
# effectiveLineCount
# 1                                  49.904580            40.143885
# 2                                  14.026718            24.316547
# 3                                  12.881679             9.208633
# 4                                   5.438931             7.050360
# 5                                   4.198473             3.453237
# 6                                   4.198473             2.589928
# 7                                   2.194656             2.877698
# 8                                   0.954198             1.582734
# 9                                   1.622137             1.582734
# 10                                  0.763359             0.431655
# 11                                  0.763359             1.294964
# 12                                  0.190840             1.294964
# 13                                  0.858779             0.719424
# 14                                  0.286260             0.431655
# 15                                  0.477099             0.287770
# 16                                  0.190840             0.575540
# 17                                  0.190840             0.575540
# 18                                  0.000000             0.287770
# 19                                  0.095420             0.000000
# 20                                  0.190840             0.143885
# 21                                  0.095420             0.143885
# 22                                  0.095420             0.143885
# 23                                  0.095420             0.143885
# 24                                  0.095420             0.143885
# 25                                  0.000000             0.000000
# 26                                  0.095420             0.143885
# 28                                  0.000000             0.143885
# 29                                  0.000000             0.000000
# 31                                  0.000000             0.143885
# 32                                  0.000000             0.000000
# 33                                  0.000000             0.000000
# 34                                  0.000000             0.000000
# 36                                  0.000000             0.000000
# 38                                  0.095420             0.000000
# 40                                  0.000000             0.000000
# 42                                  0.000000             0.000000
# 43                                  0.000000             0.000000
# 45                                  0.000000             0.143885
# 50                                  0.000000             0.000000
# 57                                  0.000000             0.000000
#
# artifactName        axon-configuration-4.8.2.jar  axon-disruptor-4.8.2.jar
# effectiveLineCount
# 1                                      52.920962                 45.652174
# 2                                      23.195876                 16.847826
# 3                                       6.013746                 16.304348
# 4                                       5.498282                  4.347826
# 5                                       2.749141                  2.717391
# 6                                       2.749141                  3.260870
# 7                                       0.343643                  1.086957
# 8                                       1.202749                  0.000000
# 9                                       1.374570                  2.173913
# 10                                      1.030928                  1.630435
# 11                                      0.859107                  0.543478
# 12                                      0.171821                  0.543478
# 13                                      0.343643                  0.543478
# 14                                      0.171821                  1.086957
# 15                                      0.000000                  0.000000
# 16                                      0.000000                  0.000000
# 17                                      0.171821                  0.543478
# 18                                      0.171821                  0.543478
# 19                                      0.171821                  0.543478
# 20                                      0.000000                  0.000000
# 21                                      0.171821                  0.000000
# 22                                      0.000000                  0.543478
# 23                                      0.171821                  0.000000
# 24                                      0.000000                  0.543478
# 25                                      0.000000                  0.000000
# 26                                      0.171821                  0.000000
# 28                                      0.000000                  0.000000
# 29                                      0.000000                  0.000000
# 31                                      0.000000                  0.000000
# 32                                      0.000000                  0.543478
# 33                                      0.000000                  0.000000
# 34                                      0.000000                  0.000000
# 36                                      0.000000                  0.000000
# 38                                      0.000000                  0.000000
# 40                                      0.171821                  0.000000
# 42                                      0.000000                  0.000000
# 43                                      0.171821                  0.000000
# 45                                      0.000000                  0.000000
# 50                                      0.000000                  0.000000
# 57                                      0.000000                  0.000000

# %% [markdown]
# ### Table 1b Chart 1 - Effective method line count distribution (normalized)

# %%
plot.figure();
method_line_count_x_ticks=range(1,20)
axes = effective_method_line_count_distribution_normalized.head(20).plot(
    kind='line',
    logx=True,
    grid=True,
    xlim=[2, 20],
    ylim=[0, 20],
    xticks=method_line_count_x_ticks,
    title='Effective Method Line Count Distribution', 
    xlabel='effective line count',
    ylabel='percent of methods',
    cmap=main_color_map,
    figsize=(10, 6),
    lw=2,
)
axes.set_xticklabels(method_line_count_x_ticks)
axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 1c - Top 30 packages with highest effective line counts
#
# The following table shows the top 30 packages with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Query artifacts and packages and find the method with the highest effective lines of code and cyclomatic complexity
# The result of this query will be also used further below. 
method_statistics_per_package = query_cypher_to_data_frame("../cypher/Overview/Effective_lines_of_method_code_per_package.cypher")

# %%
# Select and order the columns for this particular table 
effective_line_count_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'linesInPackage', 'methodCount', 'maxLinesMethod','maxLinesMethodName']]

# Print out the top 30 (head) rows
effective_line_count_per_package.head(30)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.8.2
# 1   axon-configuration-4.8.2
# 2       axon-messaging-4.8.2
# 3            axon-test-4.8.2
# 4       axon-messaging-4.8.2
# 5       axon-messaging-4.8.2
# 6       axon-modelling-4.8.2
# 7   axon-eventsourcing-4.8.2
# 8       axon-messaging-4.8.2
# 9       axon-modelling-4.8.2
# 10      axon-disruptor-4.8.2
# 11  axon-eventsourcing-4.8.2
# 12  axon-eventsourcing-4.8.2
# 13  axon-eventsourcing-4.8.2
# 14      axon-messaging-4.8.2
# 15      axon-messaging-4.8.2
# 16      axon-messaging-4.8.2
# 17      axon-messaging-4.8.2
# 18           axon-test-4.8.2
# 19      axon-messaging-4.8.2
# 20      axon-modelling-4.8.2
# 21      axon-messaging-4.8.2
# 22      axon-messaging-4.8.2
# 23      axon-modelling-4.8.2
# 24      axon-messaging-4.8.2
# 25           axon-test-4.8.2
# 26      axon-messaging-4.8.2
# 27      axon-messaging-4.8.2
# 28  axon-eventsourcing-4.8.2
# 29      axon-messaging-4.8.2
#
#                                       fullPackageName  linesInPackage  \
# 0                     org.axonframework.eventhandling            2213
# 1                            org.axonframework.config            1503
# 2              org.axonframework.eventhandling.pooled             971
# 3                    org.axonframework.test.aggregate             951
# 4                     org.axonframework.queryhandling             855
# 5     org.axonframework.eventhandling.deadletter.jdbc             849
# 6                 org.axonframework.modelling.command             792
# 7          org.axonframework.eventsourcing.eventstore             709
# 8              org.axonframework.messaging.annotation             673
# 9      org.axonframework.modelling.command.inspection             637
# 10        org.axonframework.disruptor.commandhandling             605
# 11                    org.axonframework.eventsourcing             582
# 12  org.axonframework.eventsourcing.eventstore.leg...             570
# 13    org.axonframework.eventsourcing.eventstore.jdbc             569
# 14                    org.axonframework.serialization             537
# 15     org.axonframework.eventhandling.deadletter.jpa             522
# 16                           org.axonframework.common             501
# 17          org.axonframework.commandhandling.gateway             488
# 18                        org.axonframework.test.saga             487
# 19      org.axonframework.commandhandling.distributed             474
# 20                   org.axonframework.modelling.saga             459
# 21    org.axonframework.eventhandling.tokenstore.jdbc             430
# 22  org.axonframework.eventhandling.deadletter.leg...             401
# 23   org.axonframework.modelling.saga.repository.jdbc             374
# 24             org.axonframework.messaging.unitofwork             363
# 25                    org.axonframework.test.matchers             351
# 26                        org.axonframework.messaging             348
# 27                  org.axonframework.commandhandling             340
# 28     org.axonframework.eventsourcing.eventstore.jpa             320
# 29             org.axonframework.deadline.dbscheduler             310
#
#     methodCount  maxLinesMethod  \
# 0           793              64
# 1           582              43
# 2           318              77
# 3           249              45
# 4           342              36
# 5           249              31
# 6           315              17
# 7           262              21
# 8           239              23
# 9           218              26
# 10          184              32
# 11          236              20
# 12          185              25
# 13          236              24
# 14          181              22
# 15          132              28
# 16          144              24
# 17          174              50
# 18          167              28
# 19          175              23
# 20          181              23
# 21          130              26
# 22           97              21
# 23           84              38
# 24          129              32
# 25          108              21
# 26          156              13
# 27          151              13
# 28          101              25
# 29          101              17
#
#                                    maxLinesMethodName
# 0                                        processBatch
# 1                                              <init>
# 2                                                 run
# 3                                 appendEventOverview
# 4                                             doQuery
# 5                                     convertToLetter
# 6                          lambda$initializeHandler$7
# 7                                   peekPrivateStream
# 8                                              <init>
# 9                             inspectFieldsAndMethods
# 10                                             <init>
# 11                                 doScheduleSnapshot
# 12                                 fetchTrackedEvents
# 13                                getTrackedEventData
# 14                                             <init>
# 15                                             equals
# 16  getExactDirectSuperTypesOfParameterizedTypeOrC...
# 17                                      createGateway
# 18                                             <init>
# 19                                           dispatch
# 20                                             handle
# 21                                        updateToken
# 22                                            convert
# 23                                         updateSaga
# 24                                  executeWithResult
# 25                                     matchingFields
# 26                                         describeTo
# 27                                             <init>
# 28                                 fetchTrackedEvents
# 29                                            execute

# %% [markdown]
# ### Table 1d - Top 30 methods with the highest effective line count
#
# The following table shows the top 30 methods with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
effective_line_count_method_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxLinesMethodType', 'maxLinesMethodName', 'maxLinesMethod', 'linesInPackage']]

# Sort by the maximum of effective lines of code per package descending
effective_line_count_method_per_package=effective_line_count_method_per_package.sort_values(by='maxLinesMethod', ascending=False)

# Reset the index to the new sort order
effective_line_count_method_per_package=effective_line_count_method_per_package.reset_index()

# Print out the top 30 (head) rows
effective_line_count_method_per_package.head(30)
# Out:
#     index              artifactName  \
# 0       2      axon-messaging-4.8.2
# 1       0      axon-messaging-4.8.2
# 2      17      axon-messaging-4.8.2
# 3       3           axon-test-4.8.2
# 4       1  axon-configuration-4.8.2
# 5      34      axon-messaging-4.8.2
# 6      23      axon-modelling-4.8.2
# 7       4      axon-messaging-4.8.2
# 8      30      axon-messaging-4.8.2
# 9      24      axon-messaging-4.8.2
# 10     10      axon-disruptor-4.8.2
# 11      5      axon-messaging-4.8.2
# 12     18           axon-test-4.8.2
# 13     15      axon-messaging-4.8.2
# 14      9      axon-modelling-4.8.2
# 15     21      axon-messaging-4.8.2
# 16     12  axon-eventsourcing-4.8.2
# 17     28  axon-eventsourcing-4.8.2
# 18     13  axon-eventsourcing-4.8.2
# 19     16      axon-messaging-4.8.2
# 20     37      axon-messaging-4.8.2
# 21     19      axon-messaging-4.8.2
# 22     20      axon-modelling-4.8.2
# 23      8      axon-messaging-4.8.2
# 24     32      axon-modelling-4.8.2
# 25     52      axon-messaging-4.8.2
# 26     46      axon-messaging-4.8.2
# 27     14      axon-messaging-4.8.2
# 28     54      axon-messaging-4.8.2
# 29     25           axon-test-4.8.2
#
#                                       fullPackageName  \
# 0              org.axonframework.eventhandling.pooled
# 1                     org.axonframework.eventhandling
# 2           org.axonframework.commandhandling.gateway
# 3                    org.axonframework.test.aggregate
# 4                            org.axonframework.config
# 5                   org.axonframework.deadline.quartz
# 6    org.axonframework.modelling.saga.repository.jdbc
# 7                     org.axonframework.queryhandling
# 8              org.axonframework.messaging.deadletter
# 9              org.axonframework.messaging.unitofwork
# 10        org.axonframework.disruptor.commandhandling
# 11    org.axonframework.eventhandling.deadletter.jdbc
# 12                        org.axonframework.test.saga
# 13     org.axonframework.eventhandling.deadletter.jpa
# 14     org.axonframework.modelling.command.inspection
# 15    org.axonframework.eventhandling.tokenstore.jdbc
# 16  org.axonframework.eventsourcing.eventstore.leg...
# 17     org.axonframework.eventsourcing.eventstore.jpa
# 18    org.axonframework.eventsourcing.eventstore.jdbc
# 19                           org.axonframework.common
# 20                         org.axonframework.deadline
# 21      org.axonframework.commandhandling.distributed
# 22                   org.axonframework.modelling.saga
# 23             org.axonframework.messaging.annotation
# 24        org.axonframework.modelling.saga.repository
# 25         org.axonframework.eventhandling.deadletter
# 26                 org.axonframework.deadline.jobrunr
# 27                    org.axonframework.serialization
# 28    org.axonframework.serialization.upcasting.event
# 29                    org.axonframework.test.matchers
#
#                                    maxLinesMethodType  \
# 0                        Coordinator$CoordinationTask
# 1                              TrackingEventProcessor
# 2                               CommandGatewayFactory
# 3                                            Reporter
# 4                               EventProcessingModule
# 5                                         DeadlineJob
# 6                                       JdbcSagaStore
# 7                                      SimpleQueryBus
# 8                    InMemorySequencedDeadLetterQueue
# 9                                  BatchingUnitOfWork
# 10                                DisruptorCommandBus
# 11                     DefaultDeadLetterJdbcConverter
# 12                                    SagaTestFixture
# 13                               DeadLetterEventEntry
# 14  AnnotatedAggregateMetaModelFactory$AnnotatedAg...
# 15                                     JdbcTokenStore
# 16                              JpaEventStorageEngine
# 17                              JpaEventStorageEngine
# 18                             JdbcEventStorageEngine
# 19                                TypeReflectionUtils
# 20                 SimpleDeadlineManager$DeadlineTask
# 21                              DistributedCommandBus
# 22                                AbstractSagaManager
# 23                     AnnotatedMessageHandlingMember
# 24     AssociationValueMap$AssociationValueComparator
# 25                   DeadLetteringEventHandlerInvoker
# 26                             JobRunrDeadlineManager
# 27                          AbstractXStreamSerializer
# 28                         InitialEventRepresentation
# 29                                  DeepEqualsMatcher
#
#                                    maxLinesMethodName  maxLinesMethod  \
# 0                                                 run              77
# 1                                        processBatch              64
# 2                                       createGateway              50
# 3                                 appendEventOverview              45
# 4                                              <init>              43
# 5                                             execute              42
# 6                                          updateSaga              38
# 7                                             doQuery              36
# 8                                             process              33
# 9                                   executeWithResult              32
# 10                                             <init>              32
# 11                                    convertToLetter              31
# 12                                             <init>              28
# 13                                             equals              28
# 14                            inspectFieldsAndMethods              26
# 15                                        updateToken              26
# 16                                 fetchTrackedEvents              25
# 17                                 fetchTrackedEvents              25
# 18                                getTrackedEventData              24
# 19  getExactDirectSuperTypesOfParameterizedTypeOrC...              24
# 20                                                run              24
# 21                                           dispatch              23
# 22                                             handle              23
# 23                                             <init>              23
# 24                                            compare              22
# 25                                             handle              22
# 26                                            execute              22
# 27                                             <init>              22
# 28                                             <init>              21
# 29                                     matchingFields              21
#
#     linesInPackage
# 0              971
# 1             2213
# 2              488
# 3              951
# 4             1503
# 5              242
# 6              374
# 7              855
# 8              297
# 9              363
# 10             605
# 11             849
# 12             487
# 13             522
# 14             637
# 15             430
# 16             570
# 17             320
# 18             569
# 19             501
# 20             220
# 21             474
# 22             459
# 23             673
# 24             281
# 25             115
# 26             160
# 27             537
# 28             104
# 29             351

# %% [markdown]
# ## Cyclomatic Complexity

# %% [markdown]
# ### Table 2a - Cyclomatic method complexity distribution
#
# This table shows the distribution of the cyclomatic complexity of methods per artifact.
# For each artifact the number of methods with the cyclomatic complexity = 1,2,3,... is shown to get an overview of how cyclomatic complexity is distributed over methods.
#
# Only the 15 artifacts with the highest method count sum and their cyclomatic method complexity distribution (limited by 40) is shown here. The whole table can be found in the CSV report `Cyclomatic_Method_Complexity_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
cyclomatic_method_complexity_distribution_max_artifacts=15

cyclomatic_method_complexity_distribution=query_cypher_to_data_frame("../cypher/Overview/Cyclomatic_Method_Complexity_Distribution.cypher")
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.pivot(index='cyclomaticComplexity', columns='artifactName', values='methods')

# Fill missing values with zero
cyclomatic_method_complexity_distribution.fillna(0, inplace=True)

# Convert to integer
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
cyclomatic_method_complexity_distribution = cyclomatic_method_complexity_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:cyclomatic_method_complexity_distribution_max_artifacts]]

cyclomatic_method_complexity_distribution.head(40)
# Out:
# artifactName          axon-messaging-4.8.2.jar  axon-eventsourcing-4.8.2.jar  \
# cyclomaticComplexity
# 1                                         4276                           926
# 2                                          445                            92
# 3                                          280                            54
# 4                                          138                            24
# 5                                           68                             9
# 6                                           45                             3
# 7                                           20                             7
# 8                                           13                             7
# 9                                            7                             0
# 10                                           4                             0
# 11                                           9                             0
# 12                                           4                             0
# 13                                           2                             1
# 14                                           1                             0
# 15                                           1                             0
# 16                                           1                             0
# 21                                           1                             0
# 22                                           1                             0
# 40                                           1                             0
#
# artifactName          axon-modelling-4.8.2.jar  axon-test-4.8.2.jar  \
# cyclomaticComplexity
# 1                                          866                  518
# 2                                           75                   60
# 3                                           38                   60
# 4                                           29                   22
# 5                                           24                   12
# 6                                           10                    9
# 7                                            2                    4
# 8                                            1                    3
# 9                                            2                    1
# 10                                           0                    1
# 11                                           0                    2
# 12                                           0                    2
# 13                                           0                    1
# 14                                           0                    0
# 15                                           0                    0
# 16                                           1                    0
# 21                                           0                    0
# 22                                           0                    0
# 40                                           0                    0
#
# artifactName          axon-configuration-4.8.2.jar  axon-disruptor-4.8.2.jar
# cyclomaticComplexity
# 1                                              521                       146
# 2                                               35                        20
# 3                                               16                         5
# 4                                                5                         4
# 5                                                3                         3
# 6                                                0                         2
# 7                                                2                         2
# 8                                                0                         2
# 9                                                0                         0
# 10                                               0                         0
# 11                                               0                         0
# 12                                               0                         0
# 13                                               0                         0
# 14                                               0                         0
# 15                                               0                         0
# 16                                               0                         0
# 21                                               0                         0
# 22                                               0                         0
# 40                                               0                         0

# %% [markdown]
# ### Table 2b - Cyclomatic method complexity distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
cyclomatic_method_complexity_distribution_normalized = cyclomatic_method_complexity_distribution.div(cyclomatic_method_complexity_distribution.sum(axis=0), axis=1).multiply(100)
cyclomatic_method_complexity_distribution_normalized.head(40)
# Out:
# artifactName          axon-messaging-4.8.2.jar  axon-eventsourcing-4.8.2.jar  \
# cyclomaticComplexity
# 1                                    80.421290                     82.457703
# 2                                     8.369381                      8.192342
# 3                                     5.266128                      4.808549
# 4                                     2.595449                      2.137133
# 5                                     1.278917                      0.801425
# 6                                     0.846342                      0.267142
# 7                                     0.376152                      0.623330
# 8                                     0.244499                      0.623330
# 9                                     0.131653                      0.000000
# 10                                    0.075230                      0.000000
# 11                                    0.169268                      0.000000
# 12                                    0.075230                      0.000000
# 13                                    0.037615                      0.089047
# 14                                    0.018808                      0.000000
# 15                                    0.018808                      0.000000
# 16                                    0.018808                      0.000000
# 21                                    0.018808                      0.000000
# 22                                    0.018808                      0.000000
# 40                                    0.018808                      0.000000
#
# artifactName          axon-modelling-4.8.2.jar  axon-test-4.8.2.jar  \
# cyclomaticComplexity
# 1                                    82.633588            74.532374
# 2                                     7.156489             8.633094
# 3                                     3.625954             8.633094
# 4                                     2.767176             3.165468
# 5                                     2.290076             1.726619
# 6                                     0.954198             1.294964
# 7                                     0.190840             0.575540
# 8                                     0.095420             0.431655
# 9                                     0.190840             0.143885
# 10                                    0.000000             0.143885
# 11                                    0.000000             0.287770
# 12                                    0.000000             0.287770
# 13                                    0.000000             0.143885
# 14                                    0.000000             0.000000
# 15                                    0.000000             0.000000
# 16                                    0.095420             0.000000
# 21                                    0.000000             0.000000
# 22                                    0.000000             0.000000
# 40                                    0.000000             0.000000
#
# artifactName          axon-configuration-4.8.2.jar  axon-disruptor-4.8.2.jar
# cyclomaticComplexity
# 1                                        89.518900                 79.347826
# 2                                         6.013746                 10.869565
# 3                                         2.749141                  2.717391
# 4                                         0.859107                  2.173913
# 5                                         0.515464                  1.630435
# 6                                         0.000000                  1.086957
# 7                                         0.343643                  1.086957
# 8                                         0.000000                  1.086957
# 9                                         0.000000                  0.000000
# 10                                        0.000000                  0.000000
# 11                                        0.000000                  0.000000
# 12                                        0.000000                  0.000000
# 13                                        0.000000                  0.000000
# 14                                        0.000000                  0.000000
# 15                                        0.000000                  0.000000
# 16                                        0.000000                  0.000000
# 21                                        0.000000                  0.000000
# 22                                        0.000000                  0.000000
# 40                                        0.000000                  0.000000

# %% [markdown]
# ### Table 2b Chart 1 - Cyclomatic method complexity distribution (normalized)

# %%
plot.figure();
method_line_count_x_ticks=range(1,11)
cyclomatic_complexity_y_ticks=[1, 2, 3, 4, 5, 7, 10, 20, 30, 40, 50, 100]
axes = cyclomatic_method_complexity_distribution_normalized.plot(
    kind='line', 
    logx=True,
    logy=True,
    grid=True,
    xlim=[1,11],
    ylim=[1,100],
    xticks=method_line_count_x_ticks,
    yticks=cyclomatic_complexity_y_ticks,
    title='Cyclomatic complexity distribution of methods', 
    xlabel='cyclomatic complexity',
    ylabel='percentage of methods',
    cmap=main_color_map,
)
axes.set_xticklabels(method_line_count_x_ticks)
axes.set_yticklabels(cyclomatic_complexity_y_ticks)
axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 2c - Top 30 packages with highest cyclomatic complexity
#
# The following table shows the top 30 packages with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'complexityInPackage', 'methodCount', 'maxComplexity','maxComplexityMethod']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_package=cyclomatic_complexity_per_package.sort_values(by='complexityInPackage', ascending=False)

# Print out the top 30 (head) rows
cyclomatic_complexity_per_package.head(30)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.8.2
# 1   axon-configuration-4.8.2
# 3            axon-test-4.8.2
# 4       axon-messaging-4.8.2
# 6       axon-modelling-4.8.2
# 2       axon-messaging-4.8.2
# 7   axon-eventsourcing-4.8.2
# 8       axon-messaging-4.8.2
# 9       axon-modelling-4.8.2
# 11  axon-eventsourcing-4.8.2
# 5       axon-messaging-4.8.2
# 16      axon-messaging-4.8.2
# 12  axon-eventsourcing-4.8.2
# 14      axon-messaging-4.8.2
# 10      axon-disruptor-4.8.2
# 13  axon-eventsourcing-4.8.2
# 20      axon-modelling-4.8.2
# 17      axon-messaging-4.8.2
# 19      axon-messaging-4.8.2
# 18           axon-test-4.8.2
# 15      axon-messaging-4.8.2
# 26      axon-messaging-4.8.2
# 24      axon-messaging-4.8.2
# 25           axon-test-4.8.2
# 31      axon-messaging-4.8.2
# 27      axon-messaging-4.8.2
# 21      axon-messaging-4.8.2
# 30      axon-messaging-4.8.2
# 28  axon-eventsourcing-4.8.2
# 33      axon-messaging-4.8.2
#
#                                       fullPackageName  complexityInPackage  \
# 0                     org.axonframework.eventhandling                 1214
# 1                            org.axonframework.config                  688
# 3                    org.axonframework.test.aggregate                  434
# 4                     org.axonframework.queryhandling                  433
# 6                 org.axonframework.modelling.command                  431
# 2              org.axonframework.eventhandling.pooled                  429
# 7          org.axonframework.eventsourcing.eventstore                  395
# 8              org.axonframework.messaging.annotation                  386
# 9      org.axonframework.modelling.command.inspection                  339
# 11                    org.axonframework.eventsourcing                  305
# 5     org.axonframework.eventhandling.deadletter.jdbc                  304
# 16                           org.axonframework.common                  301
# 12  org.axonframework.eventsourcing.eventstore.leg...                  290
# 14                    org.axonframework.serialization                  285
# 10        org.axonframework.disruptor.commandhandling                  274
# 13    org.axonframework.eventsourcing.eventstore.jdbc                  273
# 20                   org.axonframework.modelling.saga                  264
# 17          org.axonframework.commandhandling.gateway                  249
# 19      org.axonframework.commandhandling.distributed                  243
# 18                        org.axonframework.test.saga                  234
# 15     org.axonframework.eventhandling.deadletter.jpa                  212
# 26                        org.axonframework.messaging                  209
# 24             org.axonframework.messaging.unitofwork                  206
# 25                    org.axonframework.test.matchers                  191
# 31                   org.axonframework.common.caching                  182
# 27                  org.axonframework.commandhandling                  180
# 21    org.axonframework.eventhandling.tokenstore.jdbc                  173
# 30             org.axonframework.messaging.deadletter                  169
# 28     org.axonframework.eventsourcing.eventstore.jpa                  155
# 33                          org.axonframework.tracing                  150
#
#     methodCount  maxComplexity  \
# 0           793             21
# 1           582              7
# 3           249             13
# 4           342             11
# 6           315              9
# 2           318             22
# 7           262             13
# 8           239             14
# 9           218              9
# 11          236              8
# 5           249             12
# 16          144              9
# 12          185              8
# 14          181              7
# 10          184              8
# 13          236              7
# 20          181              6
# 17          174             12
# 19          175             12
# 18          167              9
# 15          132             15
# 26          156              4
# 24          129             11
# 25          108              8
# 31          110              8
# 27          151             10
# 21          130              9
# 30          112             10
# 28          101              8
# 33          120              7
#
#                                   maxComplexityMethod
# 0                                        processBatch
# 1                             invokeLifecycleHandlers
# 3                                   ensureValuesEqual
# 4                                             doQuery
# 6                                       resolveTarget
# 2                                                 run
# 7                                             hasNext
# 8                                              handle
# 9                                     prepareHandlers
# 11                                 doScheduleSnapshot
# 5                                              equals
# 16  getExactDirectSuperTypesOfParameterizedTypeOrC...
# 12                              loadKeyViolationCodes
# 14                                             equals
# 10                                           onResult
# 13                       lambda$fetchTrackedEvents$32
# 20                                             equals
# 17                                      createGateway
# 19                                             equals
# 18                            assertDispatchedEqualTo
# 15                                             equals
# 26                                               from
# 24                                  executeWithResult
# 25                                        matchesList
# 31                                            onEvent
# 27                                             <init>
# 21                                        updateToken
# 30                                             equals
# 28                                 fetchTrackedEvents
# 33                               determineMessageName

# %% [markdown]
# ### Table 2d - Top 30 methods with highest cyclomatic complexity
#
# The following table shows the top 30 packages containing the methods with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_method=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxComplexityType', 'maxComplexityMethod', 'maxComplexity']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.sort_values(by='maxComplexity', ascending=False)

# Reset the index to the new sort order
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.reset_index()

# Print out the top 30 (head) rows
cyclomatic_complexity_per_method.head(30)
# Out:
#     index              artifactName  \
# 0      50      axon-messaging-4.8.2
# 1       2      axon-messaging-4.8.2
# 2       0      axon-messaging-4.8.2
# 3      32      axon-modelling-4.8.2
# 4      15      axon-messaging-4.8.2
# 5       8      axon-messaging-4.8.2
# 6      51      axon-messaging-4.8.2
# 7      46      axon-messaging-4.8.2
# 8       7  axon-eventsourcing-4.8.2
# 9       3           axon-test-4.8.2
# 10     19      axon-messaging-4.8.2
# 11     39           axon-test-4.8.2
# 12     36      axon-messaging-4.8.2
# 13      5      axon-messaging-4.8.2
# 14     17      axon-messaging-4.8.2
# 15     34      axon-messaging-4.8.2
# 16     29      axon-messaging-4.8.2
# 17     24      axon-messaging-4.8.2
# 18     22      axon-messaging-4.8.2
# 19      4      axon-messaging-4.8.2
# 20     30      axon-messaging-4.8.2
# 21     27      axon-messaging-4.8.2
# 22     48      axon-messaging-4.8.2
# 23     40      axon-messaging-4.8.2
# 24     16      axon-messaging-4.8.2
# 25      6      axon-modelling-4.8.2
# 26     21      axon-messaging-4.8.2
# 27     18           axon-test-4.8.2
# 28      9      axon-modelling-4.8.2
# 29     49      axon-messaging-4.8.2
#
#                                       fullPackageName  \
# 0   org.axonframework.eventhandling.scheduling.job...
# 1              org.axonframework.eventhandling.pooled
# 2                     org.axonframework.eventhandling
# 3         org.axonframework.modelling.saga.repository
# 4      org.axonframework.eventhandling.deadletter.jpa
# 5              org.axonframework.messaging.annotation
# 6   org.axonframework.commandhandling.distributed....
# 7                  org.axonframework.deadline.jobrunr
# 8          org.axonframework.eventsourcing.eventstore
# 9                    org.axonframework.test.aggregate
# 10      org.axonframework.commandhandling.distributed
# 11                      org.axonframework.test.server
# 12                      org.axonframework.common.jdbc
# 13    org.axonframework.eventhandling.deadletter.jdbc
# 14          org.axonframework.commandhandling.gateway
# 15                  org.axonframework.deadline.quartz
# 16             org.axonframework.deadline.dbscheduler
# 17             org.axonframework.messaging.unitofwork
# 18  org.axonframework.eventhandling.deadletter.leg...
# 19                    org.axonframework.queryhandling
# 20             org.axonframework.messaging.deadletter
# 21                  org.axonframework.commandhandling
# 22                      org.axonframework.common.lock
# 23          org.axonframework.messaging.responsetypes
# 24                           org.axonframework.common
# 25                org.axonframework.modelling.command
# 26    org.axonframework.eventhandling.tokenstore.jdbc
# 27                        org.axonframework.test.saga
# 28     org.axonframework.modelling.command.inspection
# 29               org.axonframework.serialization.json
#
#                                     maxComplexityType  \
# 0                               JobRunrEventScheduler
# 1                        Coordinator$CoordinationTask
# 2                              TrackingEventProcessor
# 3      AssociationValueMap$AssociationValueComparator
# 4                                DeadLetterEventEntry
# 5                      AnnotatedMessageHandlingMember
# 6                                   CommandNameFilter
# 7                              JobRunrDeadlineManager
# 8                      ConcatenatingDomainEventStream
# 9                                AggregateTestFixture
# 10                                       ReplyMessage
# 11                                AxonServerContainer
# 12                           ConnectionWrapperFactory
# 13                                     JdbcDeadLetter
# 14                              CommandGatewayFactory
# 15                                        DeadlineJob
# 16            DbSchedulerHumanReadableDeadlineDetails
# 17                                 BatchingUnitOfWork
# 18                                      JpaDeadLetter
# 19                                     SimpleQueryBus
# 20                                  GenericDeadLetter
# 21  MethodCommandHandlerDefinition$MethodCommandMe...
# 22              PessimisticLockFactory$DisposableLock
# 23                      MultipleInstancesResponseType
# 24                                TypeReflectionUtils
# 25                    AnnotationCommandTargetResolver
# 26                                     JdbcTokenStore
# 27                                   CommandValidator
# 28  AnnotatedAggregateMetaModelFactory$AnnotatedAg...
# 29                                  JacksonSerializer
#
#                                   maxComplexityMethod  maxComplexity
# 0                                 $deserializeLambda$             40
# 1                                                 run             22
# 2                                        processBatch             21
# 3                                             compare             16
# 4                                              equals             15
# 5                                              handle             14
# 6                                 $deserializeLambda$             13
# 7                                 $deserializeLambda$             13
# 8                                             hasNext             13
# 9                                   ensureValuesEqual             13
# 10                                             equals             12
# 11                                             equals             12
# 12                                      lambda$wrap$0             12
# 13                                             equals             12
# 14                                      createGateway             12
# 15                                            execute             11
# 16                                             equals             11
# 17                                  executeWithResult             11
# 18                                             equals             11
# 19                                            doQuery             11
# 20                                             equals             10
# 21                                             <init>             10
# 22                                               lock             10
# 23                                            convert             10
# 24  getExactDirectSuperTypesOfParameterizedTypeOrC...              9
# 25                                      resolveTarget              9
# 26                                        updateToken              9
# 27                            assertDispatchedEqualTo              9
# 28                                    prepareHandlers              9
# 29                                        deserialize              9
