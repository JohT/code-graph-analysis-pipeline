# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename : str, limit: int = 10_000):
    cypher_query_template = "{query}\nLIMIT {row_limit}"
    cypher_query = get_cypher_query_from_file(filename)
    cypher_query = cypher_query_template.format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = 10_000):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Pandas DataFrame Display Configuration
pd.set_option('display.max_colwidth', 300)

# %% [markdown]
# ## Artifacts
#
# List the artifacts this notebook is based on. Different sorting variations help finding artifacts by their features and support larger code bases where the list of all artifacts gets too long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_Java_artifacts`

# %%
artifacts = query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_all_Java_artifacts.cypher")

# %% [markdown]
# ### Table 1a - Top 30 artifacts with the highest package count

# %%
# Sort by number of packages descending
artifacts.sort_values(by=['packages','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.10.1.jar        64    787
# 1           axon-server-connector-4.10.1.jar        11    132
# 2                  axon-modelling-4.10.1.jar        10    158
# 3              axon-eventsourcing-4.10.1.jar         9    133
# 4  axon-spring-boot-autoconfigure-4.10.1.jar         9     75
# 5                       axon-test-4.10.1.jar         8     87
# 6              axon-configuration-4.10.1.jar         1     41
# 7                  axon-disruptor-4.10.1.jar         1     22
# 8      axon-tracing-opentelemetry-4.10.1.jar         1      5
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     1                     4
# 2                     6                     1
# 3                     5                     2
# 4                     0                     7
# 5                     1                     3
# 6                     2                     4
# 7                     1                     3
# 8                     1                     1

# %% [markdown]
# ### Table 1b - Top 30 artifacts with the highest type count

# %%
# Sort by number of types descending
artifacts.sort_values(by=['types','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.10.1.jar        64    787
# 1                  axon-modelling-4.10.1.jar        10    158
# 2              axon-eventsourcing-4.10.1.jar         9    133
# 3           axon-server-connector-4.10.1.jar        11    132
# 4                       axon-test-4.10.1.jar         8     87
# 5  axon-spring-boot-autoconfigure-4.10.1.jar         9     75
# 6              axon-configuration-4.10.1.jar         1     41
# 7                  axon-disruptor-4.10.1.jar         1     22
# 8      axon-tracing-opentelemetry-4.10.1.jar         1      5
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     5                     2
# 3                     1                     4
# 4                     1                     3
# 5                     0                     7
# 6                     2                     4
# 7                     1                     3
# 8                     1                     1

# %% [markdown]
# ### Table 1c - Top 30 artifacts with the highest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the most by other artifacts (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.10.1.jar        64    787
# 1                  axon-modelling-4.10.1.jar        10    158
# 2              axon-eventsourcing-4.10.1.jar         9    133
# 3              axon-configuration-4.10.1.jar         1     41
# 4                  axon-disruptor-4.10.1.jar         1     22
# 5           axon-server-connector-4.10.1.jar        11    132
# 6                       axon-test-4.10.1.jar         8     87
# 7      axon-tracing-opentelemetry-4.10.1.jar         1      5
# 8  axon-spring-boot-autoconfigure-4.10.1.jar         9     75
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     5                     2
# 3                     2                     4
# 4                     1                     3
# 5                     1                     4
# 6                     1                     3
# 7                     1                     1
# 8                     0                     7

# %% [markdown]
# ### Table 1d - Top 30 artifacts with the highest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the highest number of other artifacts (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0  axon-spring-boot-autoconfigure-4.10.1.jar         9     75
# 1              axon-configuration-4.10.1.jar         1     41
# 2           axon-server-connector-4.10.1.jar        11    132
# 3                  axon-disruptor-4.10.1.jar         1     22
# 4                       axon-test-4.10.1.jar         8     87
# 5              axon-eventsourcing-4.10.1.jar         9    133
# 6                  axon-modelling-4.10.1.jar        10    158
# 7      axon-tracing-opentelemetry-4.10.1.jar         1      5
# 8                  axon-messaging-4.10.1.jar        64    787
#
#    incomingDependencies  outgoingDependencies
# 0                     0                     7
# 1                     2                     4
# 2                     1                     4
# 3                     1                     3
# 4                     1                     3
# 5                     5                     2
# 6                     6                     1
# 7                     1                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1e - Top 30 artifacts with the lowest package count

# %%
# Sort by number of packages ascending
artifacts.sort_values(by=['packages','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0              axon-configuration-4.10.1.jar         1     41
# 1                  axon-disruptor-4.10.1.jar         1     22
# 2      axon-tracing-opentelemetry-4.10.1.jar         1      5
# 3                       axon-test-4.10.1.jar         8     87
# 4              axon-eventsourcing-4.10.1.jar         9    133
# 5  axon-spring-boot-autoconfigure-4.10.1.jar         9     75
# 6                  axon-modelling-4.10.1.jar        10    158
# 7           axon-server-connector-4.10.1.jar        11    132
# 8                  axon-messaging-4.10.1.jar        64    787
#
#    incomingDependencies  outgoingDependencies
# 0                     2                     4
# 1                     1                     3
# 2                     1                     1
# 3                     1                     3
# 4                     5                     2
# 5                     0                     7
# 6                     6                     1
# 7                     1                     4
# 8                     8                     0

# %% [markdown]
# ### Table 1f - Top 30 artifacts with the lowest type count

# %%
# Sort by number of types ascending
artifacts.sort_values(by=['types','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0      axon-tracing-opentelemetry-4.10.1.jar         1      5
# 1                  axon-disruptor-4.10.1.jar         1     22
# 2              axon-configuration-4.10.1.jar         1     41
# 3  axon-spring-boot-autoconfigure-4.10.1.jar         9     75
# 4                       axon-test-4.10.1.jar         8     87
# 5           axon-server-connector-4.10.1.jar        11    132
# 6              axon-eventsourcing-4.10.1.jar         9    133
# 7                  axon-modelling-4.10.1.jar        10    158
# 8                  axon-messaging-4.10.1.jar        64    787
#
#    incomingDependencies  outgoingDependencies
# 0                     1                     1
# 1                     1                     3
# 2                     2                     4
# 3                     0                     7
# 4                     1                     3
# 5                     1                     4
# 6                     5                     2
# 7                     6                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1g - Top 30 artifacts with the lowest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the least by other artifacts (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0  axon-spring-boot-autoconfigure-4.10.1.jar         9     75
# 1                  axon-disruptor-4.10.1.jar         1     22
# 2           axon-server-connector-4.10.1.jar        11    132
# 3                       axon-test-4.10.1.jar         8     87
# 4      axon-tracing-opentelemetry-4.10.1.jar         1      5
# 5              axon-configuration-4.10.1.jar         1     41
# 6              axon-eventsourcing-4.10.1.jar         9    133
# 7                  axon-modelling-4.10.1.jar        10    158
# 8                  axon-messaging-4.10.1.jar        64    787
#
#    incomingDependencies  outgoingDependencies
# 0                     0                     7
# 1                     1                     3
# 2                     1                     4
# 3                     1                     3
# 4                     1                     1
# 5                     2                     4
# 6                     5                     2
# 7                     6                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1h - Top 30 artifacts with the lowest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the lowest number of other artifacts (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.10.1.jar        64    787
# 1                  axon-modelling-4.10.1.jar        10    158
# 2      axon-tracing-opentelemetry-4.10.1.jar         1      5
# 3              axon-eventsourcing-4.10.1.jar         9    133
# 4                  axon-disruptor-4.10.1.jar         1     22
# 5                       axon-test-4.10.1.jar         8     87
# 6              axon-configuration-4.10.1.jar         1     41
# 7           axon-server-connector-4.10.1.jar        11    132
# 8  axon-spring-boot-autoconfigure-4.10.1.jar         9     75
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     1                     1
# 3                     5                     2
# 4                     1                     3
# 5                     1                     3
# 6                     2                     4
# 7                     1                     4
# 8                     0                     7

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to problems when one of these packages needs to be changed.

# %% [markdown]
# ## Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies`
#
# **Columns:**
# - *artifactName* identifies the artifact of the first participant of the cycle
# - *packageName* identifies the package of the first participant of the cycle
# - *dependentArtifactName* identifies the artifact of the second participant of the cycle
# - *dependentPackageName* identifies the package of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies.cypher")
cyclic_dependencies.head(40)
# Out:
#                     artifactName  \
# 0          axon-messaging-4.10.1
# 1          axon-messaging-4.10.1
# 2          axon-messaging-4.10.1
# 3          axon-messaging-4.10.1
# 4          axon-messaging-4.10.1
# 5          axon-messaging-4.10.1
# 6          axon-messaging-4.10.1
# 7      axon-eventsourcing-4.10.1
# 8          axon-messaging-4.10.1
# 9   axon-server-connector-4.10.1
# 10         axon-messaging-4.10.1
# 11         axon-messaging-4.10.1
# 12  axon-server-connector-4.10.1
# 13  axon-server-connector-4.10.1
# 14         axon-messaging-4.10.1
# 15         axon-messaging-4.10.1
# 16  axon-server-connector-4.10.1
# 17  axon-server-connector-4.10.1
# 18         axon-messaging-4.10.1
# 19     axon-eventsourcing-4.10.1
# 20         axon-messaging-4.10.1
# 21         axon-modelling-4.10.1
# 22         axon-messaging-4.10.1
# 23         axon-messaging-4.10.1
# 24  axon-server-connector-4.10.1
# 25         axon-messaging-4.10.1
# 26         axon-modelling-4.10.1
# 27         axon-messaging-4.10.1
#
#                                                     packageName  \
# 0                               org.axonframework.eventhandling
# 1                               org.axonframework.queryhandling
# 2                               org.axonframework.queryhandling
# 3                               org.axonframework.eventhandling
# 4                               org.axonframework.eventhandling
# 5                                    org.axonframework.deadline
# 6                             org.axonframework.commandhandling
# 7                               org.axonframework.eventsourcing
# 8                   org.axonframework.commandhandling.callbacks
# 9                   org.axonframework.axonserver.connector.util
# 10                              org.axonframework.eventhandling
# 11                       org.axonframework.messaging.unitofwork
# 12            org.axonframework.axonserver.connector.event.axon
# 13                 org.axonframework.axonserver.connector.query
# 14                        org.axonframework.eventhandling.async
# 15                       org.axonframework.eventhandling.replay
# 16                       org.axonframework.axonserver.connector
# 17                 org.axonframework.axonserver.connector.query
# 18              org.axonframework.serialization.upcasting.event
# 19              org.axonframework.eventsourcing.eventstore.jdbc
# 20                              org.axonframework.eventhandling
# 21               org.axonframework.modelling.command.inspection
# 22                 org.axonframework.queryhandling.registration
# 23                                  org.axonframework.messaging
# 24               org.axonframework.axonserver.connector.command
# 25                       org.axonframework.messaging.annotation
# 26                             org.axonframework.modelling.saga
# 27  org.axonframework.commandhandling.distributed.commandfilter
#
#            dependentArtifactName  \
# 0          axon-messaging-4.10.1
# 1          axon-messaging-4.10.1
# 2          axon-messaging-4.10.1
# 3          axon-messaging-4.10.1
# 4          axon-messaging-4.10.1
# 5          axon-messaging-4.10.1
# 6          axon-messaging-4.10.1
# 7      axon-eventsourcing-4.10.1
# 8          axon-messaging-4.10.1
# 9   axon-server-connector-4.10.1
# 10         axon-messaging-4.10.1
# 11         axon-messaging-4.10.1
# 12  axon-server-connector-4.10.1
# 13  axon-server-connector-4.10.1
# 14         axon-messaging-4.10.1
# 15         axon-messaging-4.10.1
# 16  axon-server-connector-4.10.1
# 17  axon-server-connector-4.10.1
# 18         axon-messaging-4.10.1
# 19     axon-eventsourcing-4.10.1
# 20         axon-messaging-4.10.1
# 21         axon-modelling-4.10.1
# 22         axon-messaging-4.10.1
# 23         axon-messaging-4.10.1
# 24  axon-server-connector-4.10.1
# 25         axon-messaging-4.10.1
# 26         axon-modelling-4.10.1
# 27         axon-messaging-4.10.1
#
#                                           dependentPackageName  \
# 0                                    org.axonframework.tracing
# 1                    org.axonframework.messaging.responsetypes
# 2                                    org.axonframework.tracing
# 3                                  org.axonframework.messaging
# 4                       org.axonframework.messaging.annotation
# 5                                    org.axonframework.tracing
# 6                                    org.axonframework.tracing
# 7                   org.axonframework.eventsourcing.eventstore
# 8                            org.axonframework.commandhandling
# 9                       org.axonframework.axonserver.connector
# 10                             org.axonframework.serialization
# 11                                 org.axonframework.messaging
# 12                      org.axonframework.axonserver.connector
# 13                      org.axonframework.axonserver.connector
# 14                             org.axonframework.eventhandling
# 15                             org.axonframework.eventhandling
# 16           org.axonframework.axonserver.connector.event.util
# 17   org.axonframework.axonserver.connector.query.subscription
# 18                             org.axonframework.eventhandling
# 19  org.axonframework.eventsourcing.eventstore.jdbc.statements
# 20                  org.axonframework.eventhandling.tokenstore
# 21                         org.axonframework.modelling.command
# 22                             org.axonframework.queryhandling
# 23                             org.axonframework.serialization
# 24                      org.axonframework.axonserver.connector
# 25                    org.axonframework.messaging.interceptors
# 26                  org.axonframework.modelling.saga.metamodel
# 27               org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.840000             23               2
# 5                   0.800000              9               1
# 6                   0.777778              8               1
# 7                   0.777778             16               2
# 8                   0.733333             13               2
# 9                   0.666667              5               1
# 10                  0.647059             14               3
# 11                  0.647059             14               3
# 12                  0.615385             21               5
# 13                  0.571429             22               6
# 14                  0.538462             10               3
# 15                  0.454545              8               3
# 16                  0.333333              2               1
# 17                  0.333333              4               2
# 18                  0.333333              6               3
# 19                  0.317073             27              14
# 20                  0.285714              9               5
# 21                  0.250000             20              12
# 22                  0.250000              5               3
# 23                  0.238095             13               8
# 24                  0.222222             11               7
# 25                  0.200000              3               2
# 26                  0.142857              4               3
# 27                  0.076923              7               6
#
#                                                                                                                                                                                                                                                                                         someForwardDependencies  \
# 0   [SimpleEventBus$Builder->SpanFactory, AbstractEventProcessor$Builder->NoOpSpanFactory, AbstractEventProcessor$Builder->SpanFactory, DefaultEventProcessorSpanFactory$Builder->SpanFactory, AbstractEventProcessor->Span, TrackingEventProcessor$Builder->SpanFactory, EventBusSpanFactory->Span, Abstrac...
# 1   [GenericStreamingQueryMessage->PublisherResponseType, GenericStreamingQueryMessage->ResponseType, SimpleQueryUpdateEmitter->OptionalResponseType, SimpleQueryUpdateEmitter->MultipleInstancesResponseType, SimpleQueryUpdateEmitter->ResponseType, SimpleQueryUpdateEmitter->PublisherResponseType, Defa...
# 2   [SimpleQueryUpdateEmitter->Span, DefaultQueryUpdateEmitterSpanFactory$Builder->SpanFactory, DefaultQueryBusSpanFactory$Builder->SpanFactory, DefaultQueryUpdateEmitterSpanFactory->SpanFactory, DefaultQueryUpdateEmitterSpanFactory->Span, QueryUpdateEmitterSpanFactory->Span, DefaultQueryBusSpanFact...
# 3   [TimestampParameterResolverFactory$TimestampParameterResolver->Message, MultiStreamableMessageSource$IdentifiedStreamableMessageSource->StreamableMessageSource, ConcludesBatchParameterResolverFactory->Message, ReplayToken->Message, AbstractEventProcessor->ResultMessage, AbstractEventProcessor->M...
# 4   [TimestampParameterResolverFactory$TimestampParameterResolver->ParameterResolver, ConcludesBatchParameterResolverFactory->AbstractAnnotatedParameterResolverFactory, ConcludesBatchParameterResolverFactory->ParameterResolver, SequenceNumberParameterResolverFactory->ParameterResolver, SequenceNumbe...
# 5   [DefaultDeadlineManagerSpanFactory$Builder->SpanFactory, DeadlineManagerSpanFactory->Span, DefaultDeadlineManagerSpanFactory->Span, DefaultDeadlineManagerSpanFactory->SpanFactory, SimpleDeadlineManager->Span, SimpleDeadlineManager$Builder->SpanFactory, SimpleDeadlineManager$Builder->NoOpSpanFact...
# 6   [DefaultCommandBusSpanFactory->Span, DefaultCommandBusSpanFactory->SpanFactory, CommandBusSpanFactory->Span, SimpleCommandBus->Span, DefaultCommandBusSpanFactory$Builder->SpanFactory, AsynchronousCommandBus$Builder->SpanFactory, SimpleCommandBus$Builder->SpanFactory, SimpleCommandBus$Builder->No...
# 7   [AggregateSnapshotter->DomainEventStream, AbstractSnapshotter$CreateSnapshotTask->DomainEventStream, AbstractSnapshotter$CreateSnapshotTask->EventStore, AbstractSnapshotter->EventStore, AbstractSnapshotter->DomainEventStream, FilteringEventStorageEngine->DomainEventStream, FilteringEventStorageE...
# 8   [LoggingCallback->CommandCallback, LoggingCallback->CommandResultMessage, LoggingCallback->CommandMessage, FailureLoggingCallback->CommandMessage, FailureLoggingCallback->CommandCallback, FailureLoggingCallback->CommandResultMessage, FutureCallback->CommandCallback, FutureCallback->GenericComman...
# 9                              [FlowControllingStreamObserver->AxonServerConfiguration$FlowControlConfiguration, FlowControllingStreamObserver->AxonServerConfiguration, ExecutorServiceBuilder->AxonServerConfiguration, PriorityExecutorService->PriorityRunnable, PriorityExecutorService->PriorityCallable]
# 10  [EventData->SerializedObject, AbstractDomainEventEntry->Serializer, AbstractEventEntry->SerializedMetaData, AbstractEventEntry->Serializer, AbstractEventEntry->SimpleSerializedType, AbstractEventEntry->SimpleSerializedObject, AbstractEventEntry->SerializedObject, AbstractEventEntry->SerializedTy...
# 11  [CurrentUnitOfWork->MetaData, MessageProcessingContext->Message, ExecutionResult->ResultMessage, AbstractUnitOfWork->Message, AbstractUnitOfWork->MetaData, BatchingUnitOfWork->GenericResultMessage, BatchingUnitOfWork->Message, BatchingUnitOfWork->ResultMessage, DefaultUnitOfWork->GenericResultMe...
# 12  [AxonServerEventStore$AxonIQEventStorageEngine$1->AxonServerConfiguration, AxonServerEventStore$AxonIQEventStorageEngine$1->AxonServerConnectionManager, AxonServerEventStore$AxonIQEventStorageEngine$Builder->AxonServerConfiguration, AxonServerEventStore$AxonIQEventStorageEngine$Builder->AxonServ...
# 13  [AxonServerQueryBus->PriorityRunnable, AxonServerQueryBus->DispatchInterceptors, AxonServerQueryBus->AxonServerConfiguration, AxonServerQueryBus->AxonServerConnectionManager, AxonServerQueryBus->TargetContextResolver, AxonServerQueryBus->ErrorCode, AxonServerQueryBus->AxonServerConfiguration$Flo...
# 14  [EventProcessorTask->EventMessage, FullConcurrencyPolicy->EventMessage, SequentialPerAggregatePolicy->EventMessage, SequentialPerAggregatePolicy->DomainEventMessage, PropertySequencingPolicy->EventMessage, EventProcessorTask$ProcessingTask->EventMessage, PropertySequencingPolicy$Builder$Exceptio...
# 15  [ReplayParameterResolverFactory->ReplayStatus, ReplayContextParameterResolverFactory$ReplayContextParameterResolver->ReplayToken, ReplayContextParameterResolverFactory$ReplayContextParameterResolver->EventMessage, ReplayContextParameterResolverFactory$ReplayContextParameterResolver->TrackedEvent...
# 16                                                                                                                                                                                                                         [AxonServerConfiguration$Builder->EventCipher, AxonServerConfiguration->EventCipher]
# 17                                                                 [AxonServerQueryBus->SubscriptionMessageSerializer, AxonServerQueryBus->AxonServerSubscriptionQueryResult, AxonServerQueryBus$Builder->SubscriptionMessageSerializer, AxonServerQueryBus$LocalSegmentAdapter->SubscriptionMessageSerializer]
# 18                                    [InitialEventRepresentation->TrackedEventData, InitialEventRepresentation->DomainEventData, InitialEventRepresentation->EventData, InitialEventRepresentation->TrackingToken, UpcastedEventRepresentation->TrackingToken, IntermediateEventRepresentation->TrackingToken]
# 19  [JdbcEventStorageEngine$Builder->AppendSnapshotStatementBuilder, JdbcEventStorageEngine$Builder->AppendEventsStatementBuilder, JdbcEventStorageEngine$Builder->FetchTrackedEventsStatementBuilder, JdbcEventStorageEngine$Builder->CreateTokenAtStatementBuilder, JdbcEventStorageEngine$Builder->LastSe...
# 20  [TrackingEventProcessor$Instruction->UnableToClaimTokenException, TrackingEventProcessor$ClaimSegmentInstruction->TokenStore, TrackingEventProcessor$Builder->TokenStore, TrackingEventProcessor$MergeSegmentInstruction->TokenStore, TrackingEventProcessor->UnableToClaimTokenException, TrackingEvent...
# 21  [CreationPolicyMember->AggregateCreationPolicy, MethodCreationPolicyDefinition$MethodCreationPolicyHandlingMember->AggregateCreationPolicy, ChildForwardingCommandMessageHandlingMember->AggregateEntityNotFoundException, AggregateMemberAnnotatedChildEntityCollectionDefinition->ForwardingMode, Anno...
# 22                      [DuplicateQueryHandlerResolver->QuerySubscription, LoggingDuplicateQueryHandlerResolver->QuerySubscription, DuplicateQueryHandlerResolution->QuerySubscription, DuplicateQueryHandlerSubscriptionException->QuerySubscription, FailingDuplicateQueryHandlerResolver->QuerySubscription]
# 23       [GenericResultMessage->SerializedObject, GenericResultMessage->Serializer, Headers->SerializedType, Headers->SerializedObject, MessageDecorator->SerializedObject, MessageDecorator->Serializer, GenericMessage->SerializedObjectHolder, GenericMessage->SerializedObject, GenericMessage->Serializer]
# 24  [CommandSerializer->ErrorCode, CommandSerializer->AxonServerConfiguration, AxonServerCommandBus$Builder->AxonServerConfiguration, AxonServerCommandBus$Builder->AxonServerConnectionManager, AxonServerCommandBus$Builder->TargetContextResolver, AxonServerCommandBus->TargetContextResolver, AxonServe...
# 25                                                                                                                                          [ResultParameterResolverFactory->ResultHandler, MessageHandlerInterceptorDefinition->MessageHandlerInterceptor, MessageHandlerInterceptorDefinition->ResultHandler]
# 26                                                                                                                                           [AnnotatedSagaManager$Builder->AnnotationSagaMetaModelFactory, AnnotatedSagaManager$Builder->SagaModel, AnnotatedSaga->SagaModel, AnnotatedSagaManager->SagaModel]
# 27        [CommandNameFilter->CommandMessageFilter, DenyCommandNameFilter->CommandMessageFilter, DenyAll->CommandMessageFilter, AcceptAll->CommandMessageFilter, NegateCommandMessageFilter->CommandMessageFilter, OrCommandMessageFilter->CommandMessageFilter, AndCommandMessageFilter->CommandMessageFilter]
#
#                                                                                                                                                                                                                                                                                            backwardDependencies
# 0                                                                                                                                                                                                                                                                            [NestingSpanFactory->EventMessage]
# 1                                                                                                                                                                                                                                                             [ConvertingResponseMessage->QueryResponseMessage]
# 2                                                                                                                                                                                                                                                                                     [SpanUtils->QueryMessage]
# 3                                                                                                                                                                                                                  [StreamableMessageSource->TrackingToken, Headers->EventMessage, Headers->DomainEventMessage]
# 4                                                                                                                                    [AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->DomainEventMessage, SourceIdParameterResolverFactory$SourceIdParameterResolver->DomainEventMessage]
# 5                                                                                                                                                                                                                                                                                  [SpanUtils->DeadlineMessage]
# 6                                                                                                                                                                                                                                                                                   [SpanUtils->CommandMessage]
# 7                                                                                                                                                                                                                           [DomainEventStream->EventStreamUtils, AbstractEventStorageEngine->EventStreamUtils]
# 8                                                                                                                                                                                                                           [SimpleCommandBus$Builder->LoggingCallback, SimpleCommandBus$Builder->NoOpCallback]
# 9                                                                                                                                                                                                                                                                              [ErrorCode->ExceptionSerializer]
# 10                                                                                                                                                [GapAwareTrackingTokenConverter->GapAwareTrackingToken, AbstractXStreamSerializer->GenericDomainEventMessage, AbstractXStreamSerializer->GenericEventMessage]
# 11                                                                                                                                                                                              [DefaultInterceptorChain->UnitOfWork, MessageHandlerInterceptor->UnitOfWork, GenericMessage->CurrentUnitOfWork]
# 12  [ServerConnectorConfigurerModule->EventProcessorInfoConfiguration, ServerConnectorConfigurerModule->AxonServerEventStoreFactory$Builder, ServerConnectorConfigurerModule->AxonServerEventStore, ServerConnectorConfigurerModule->AxonServerEventStoreFactory, ServerConnectorConfigurerModule->AxonServe...
# 13  [ErrorCode->AxonServerRemoteQueryHandlingException, ErrorCode->AxonServerNonTransientRemoteQueryHandlingException, ErrorCode->AxonServerQueryDispatchException, ServerConnectorConfigurerModule->QueryPriorityCalculator, ServerConnectorConfigurerModule->AxonServerQueryBus, ServerConnectorConfigurer...
# 14                                                                                                                                          [SimpleEventHandlerInvoker$Builder->SequencingPolicy, SimpleEventHandlerInvoker$Builder->SequentialPerAggregatePolicy, SimpleEventHandlerInvoker->SequencingPolicy]
# 15                                                                                                                                                                                [AnnotationEventHandlerAdapter->GenericResetContext, AnnotationEventHandlerAdapter->ResetContext, ResetHandler->ResetContext]
# 16                                                                                                                                                                                                                                                                             [GrpcExceptionParser->ErrorCode]
# 17                                                                                                                                                                                       [GrpcBackedSubscriptionQueryMessage->GrpcBackedQueryMessage, SubscriptionMessageSerializer->GrpcBackedResponseMessage]
# 18                                                                                                                                                                                             [EventUtils->InitialEventRepresentation, EventUtils->EventUpcaster, EventUtils->IntermediateEventRepresentation]
# 19  [AppendEventsStatementBuilder->EventSchema, ReadEventDataForAggregateStatementBuilder->EventSchema, DeleteSnapshotsStatementBuilder->EventSchema, FetchTrackedEventsStatementBuilder->EventSchema, ReadEventDataWithoutGapsStatementBuilder->EventSchema, CleanGapsStatementBuilder->EventSchema, Create...
# 20                                                                                                                                                            [GenericTokenEntry->TrackingToken, ConfigToken->TrackingToken, AbstractTokenEntry->TrackingToken, TokenStore->TrackingToken, TokenStore->Segment]
# 21  [ForwardingMode->EntityModel, ForwardMatchingInstances->EntityModel, AggregateAnnotationCommandHandler$Builder->AggregateModel, AggregateAnnotationCommandHandler$Builder->AnnotatedAggregateMetaModelFactory, GenericJpaRepository$Builder->AggregateModel, AggregateAnnotationCommandHandler->Creation...
# 22                                                                                                                                              [SimpleQueryBus->DuplicateQueryHandlerResolver, SimpleQueryBus$Builder->DuplicateQueryHandlerResolution, SimpleQueryBus$Builder->DuplicateQueryHandlerResolver]
# 23                  [SerializedObjectHolder->Message, AbstractXStreamSerializer$MetaDataConverter->MetaData, SerializedMetaData->MetaData, SerializedMessage->MetaData, SerializedMessage->Message, SerializedMessage->AbstractMessage, SerializedMessage->GenericMessage, AbstractXStreamSerializer->MetaData]
# 24  [ErrorCode->AxonServerRemoteCommandHandlingException, ErrorCode->AxonServerNonTransientRemoteCommandHandlingException, ErrorCode->AxonServerCommandDispatchException, ServerConnectorConfigurerModule->AxonServerCommandBus$Builder, ServerConnectorConfigurerModule->CommandPriorityCalculator, ServerC...
# 25                                                                                                                                                                                                                             [MessageHandlerInterceptor->MessageHandler, ResultHandler->HasHandlerAttributes]
# 26                                                                                                                       [AnnotationSagaMetaModelFactory$InspectedSagaModel->AssociationValue, AnnotationSagaMetaModelFactory$InspectedSagaModel->SagaMethodMessageHandlingMember, SagaModel->AssociationValue]
# 27                                      [CommandMessageFilter->NegateCommandMessageFilter, CommandMessageFilter->AndCommandMessageFilter, CommandMessageFilter->OrCommandMessageFilter, DistributedCommandBus->DenyAll, DistributedCommandBus->DenyCommandNameFilter, DistributedCommandBus->CommandNameFilter]

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#              artifactName                      packageName  \
# 0   axon-messaging-4.10.1  org.axonframework.eventhandling
# 1   axon-messaging-4.10.1  org.axonframework.eventhandling
# 2   axon-messaging-4.10.1  org.axonframework.eventhandling
# 3   axon-messaging-4.10.1  org.axonframework.eventhandling
# 4   axon-messaging-4.10.1  org.axonframework.eventhandling
# 5   axon-messaging-4.10.1  org.axonframework.eventhandling
# 6   axon-messaging-4.10.1  org.axonframework.eventhandling
# 7   axon-messaging-4.10.1  org.axonframework.eventhandling
# 8   axon-messaging-4.10.1  org.axonframework.eventhandling
# 9   axon-messaging-4.10.1  org.axonframework.eventhandling
# 10  axon-messaging-4.10.1  org.axonframework.eventhandling
# 11  axon-messaging-4.10.1  org.axonframework.eventhandling
# 12  axon-messaging-4.10.1  org.axonframework.eventhandling
# 13  axon-messaging-4.10.1  org.axonframework.eventhandling
# 14  axon-messaging-4.10.1  org.axonframework.eventhandling
# 15  axon-messaging-4.10.1  org.axonframework.eventhandling
# 16  axon-messaging-4.10.1  org.axonframework.eventhandling
# 17  axon-messaging-4.10.1  org.axonframework.eventhandling
# 18  axon-messaging-4.10.1  org.axonframework.eventhandling
# 19  axon-messaging-4.10.1  org.axonframework.eventhandling
# 20  axon-messaging-4.10.1  org.axonframework.queryhandling
# 21  axon-messaging-4.10.1  org.axonframework.queryhandling
# 22  axon-messaging-4.10.1  org.axonframework.queryhandling
# 23  axon-messaging-4.10.1  org.axonframework.queryhandling
# 24  axon-messaging-4.10.1  org.axonframework.queryhandling
# 25  axon-messaging-4.10.1  org.axonframework.queryhandling
# 26  axon-messaging-4.10.1  org.axonframework.queryhandling
# 27  axon-messaging-4.10.1  org.axonframework.queryhandling
# 28  axon-messaging-4.10.1  org.axonframework.queryhandling
# 29  axon-messaging-4.10.1  org.axonframework.queryhandling
# 30  axon-messaging-4.10.1  org.axonframework.queryhandling
# 31  axon-messaging-4.10.1  org.axonframework.queryhandling
# 32  axon-messaging-4.10.1  org.axonframework.queryhandling
# 33  axon-messaging-4.10.1  org.axonframework.queryhandling
# 34  axon-messaging-4.10.1  org.axonframework.queryhandling
# 35  axon-messaging-4.10.1  org.axonframework.queryhandling
# 36  axon-messaging-4.10.1  org.axonframework.queryhandling
# 37  axon-messaging-4.10.1  org.axonframework.queryhandling
# 38  axon-messaging-4.10.1  org.axonframework.queryhandling
# 39  axon-messaging-4.10.1  org.axonframework.queryhandling
#
#     dependentArtifactName                       dependentPackageName  \
# 0   axon-messaging-4.10.1                  org.axonframework.tracing
# 1   axon-messaging-4.10.1                  org.axonframework.tracing
# 2   axon-messaging-4.10.1                  org.axonframework.tracing
# 3   axon-messaging-4.10.1                  org.axonframework.tracing
# 4   axon-messaging-4.10.1                  org.axonframework.tracing
# 5   axon-messaging-4.10.1                  org.axonframework.tracing
# 6   axon-messaging-4.10.1                  org.axonframework.tracing
# 7   axon-messaging-4.10.1                  org.axonframework.tracing
# 8   axon-messaging-4.10.1                  org.axonframework.tracing
# 9   axon-messaging-4.10.1                  org.axonframework.tracing
# 10  axon-messaging-4.10.1                  org.axonframework.tracing
# 11  axon-messaging-4.10.1                  org.axonframework.tracing
# 12  axon-messaging-4.10.1                  org.axonframework.tracing
# 13  axon-messaging-4.10.1                  org.axonframework.tracing
# 14  axon-messaging-4.10.1                  org.axonframework.tracing
# 15  axon-messaging-4.10.1                  org.axonframework.tracing
# 16  axon-messaging-4.10.1                  org.axonframework.tracing
# 17  axon-messaging-4.10.1                  org.axonframework.tracing
# 18  axon-messaging-4.10.1                  org.axonframework.tracing
# 19  axon-messaging-4.10.1                  org.axonframework.tracing
# 20  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 21  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 22  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 23  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 24  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 25  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 26  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 27  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 28  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 29  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 30  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 31  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 32  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 33  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 34  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 35  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 36  axon-messaging-4.10.1  org.axonframework.messaging.responsetypes
# 37  axon-messaging-4.10.1                  org.axonframework.tracing
# 38  axon-messaging-4.10.1                  org.axonframework.tracing
# 39  axon-messaging-4.10.1                  org.axonframework.tracing
#
#                                                     dependency  \
# 0                                 AbstractEventProcessor->Span
# 1              AbstractEventProcessor$Builder->NoOpSpanFactory
# 2                  TrackingEventProcessor$Builder->SpanFactory
# 3                      DefaultEventBusSpanFactory->SpanFactory
# 4                             EventMessage<-NestingSpanFactory
# 5                DefaultEventProcessorSpanFactory->SpanFactory
# 6                                    EventBusSpanFactory->Span
# 7                    AbstractEventBus$Builder->NoOpSpanFactory
# 8   DefaultEventProcessorSpanFactory->NoOpSpanFactory$NoOpSpan
# 9                             DefaultEventBusSpanFactory->Span
# 10             DefaultEventBusSpanFactory$Builder->SpanFactory
# 11                         SimpleEventBus$Builder->SpanFactory
# 12       DefaultEventProcessorSpanFactory$Builder->SpanFactory
# 13              SubscribingEventProcessor$Builder->SpanFactory
# 14                                 AbstractEventBus->SpanScope
# 15                             EventProcessorSpanFactory->Span
# 16                                      AbstractEventBus->Span
# 17                       AbstractEventBus$Builder->SpanFactory
# 18                 AbstractEventProcessor$Builder->SpanFactory
# 19                      DefaultEventProcessorSpanFactory->Span
# 20                                SimpleQueryBus->ResponseType
# 21                      SubscriptionQueryMessage->ResponseType
# 22                                 QueryGateway->ResponseTypes
# 23                         StreamingQueryMessage->ResponseType
# 24                           DefaultQueryGateway->ResponseType
# 25                             QuerySubscription->ResponseType
# 26                      SimpleQueryUpdateEmitter->ResponseType
# 27                                  QueryGateway->ResponseType
# 28                                  QueryMessage->ResponseType
# 29               GenericSubscriptionQueryMessage->ResponseType
# 30     SimpleQueryUpdateEmitter->MultipleInstancesResponseType
# 31             SimpleQueryUpdateEmitter->PublisherResponseType
# 32                           GenericQueryMessage->ResponseType
# 33             QueryResponseMessage<-ConvertingResponseMessage
# 34         GenericStreamingQueryMessage->PublisherResponseType
# 35                  GenericStreamingQueryMessage->ResponseType
# 36              SimpleQueryUpdateEmitter->OptionalResponseType
# 37                                     QueryMessage<-SpanUtils
# 38                              SimpleQueryUpdateEmitter->Span
# 39   DefaultQueryUpdateEmitterSpanFactory$Builder->SpanFactory
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.900000             19               1
# 2                   0.900000             19               1
# 3                   0.900000             19               1
# 4                   0.900000             19               1
# 5                   0.900000             19               1
# 6                   0.900000             19               1
# 7                   0.900000             19               1
# 8                   0.900000             19               1
# 9                   0.900000             19               1
# 10                  0.900000             19               1
# 11                  0.900000             19               1
# 12                  0.900000             19               1
# 13                  0.900000             19               1
# 14                  0.900000             19               1
# 15                  0.900000             19               1
# 16                  0.900000             19               1
# 17                  0.900000             19               1
# 18                  0.900000             19               1
# 19                  0.900000             19               1
# 20                  0.882353             16               1
# 21                  0.882353             16               1
# 22                  0.882353             16               1
# 23                  0.882353             16               1
# 24                  0.882353             16               1
# 25                  0.882353             16               1
# 26                  0.882353             16               1
# 27                  0.882353             16               1
# 28                  0.882353             16               1
# 29                  0.882353             16               1
# 30                  0.882353             16               1
# 31                  0.882353             16               1
# 32                  0.882353             16               1
# 33                  0.882353             16               1
# 34                  0.882353             16               1
# 35                  0.882353             16               1
# 36                  0.882353             16               1
# 37                  0.875000             15               1
# 38                  0.875000             15               1
# 39                  0.875000             15               1

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#                     artifactName  \
# 0          axon-messaging-4.10.1
# 1          axon-messaging-4.10.1
# 2          axon-messaging-4.10.1
# 3          axon-messaging-4.10.1
# 4          axon-messaging-4.10.1
# 5          axon-messaging-4.10.1
# 6          axon-messaging-4.10.1
# 7          axon-messaging-4.10.1
# 8          axon-messaging-4.10.1
# 9          axon-messaging-4.10.1
# 10     axon-eventsourcing-4.10.1
# 11     axon-eventsourcing-4.10.1
# 12         axon-messaging-4.10.1
# 13         axon-messaging-4.10.1
# 14  axon-server-connector-4.10.1
# 15         axon-messaging-4.10.1
# 16         axon-messaging-4.10.1
# 17         axon-messaging-4.10.1
# 18         axon-messaging-4.10.1
# 19         axon-messaging-4.10.1
# 20         axon-messaging-4.10.1
# 21  axon-server-connector-4.10.1
# 22  axon-server-connector-4.10.1
# 23  axon-server-connector-4.10.1
# 24  axon-server-connector-4.10.1
# 25  axon-server-connector-4.10.1
# 26  axon-server-connector-4.10.1
# 27  axon-server-connector-4.10.1
# 28  axon-server-connector-4.10.1
# 29  axon-server-connector-4.10.1
# 30  axon-server-connector-4.10.1
# 31  axon-server-connector-4.10.1
# 32         axon-messaging-4.10.1
# 33         axon-messaging-4.10.1
# 34         axon-messaging-4.10.1
# 35         axon-messaging-4.10.1
# 36         axon-messaging-4.10.1
# 37         axon-messaging-4.10.1
# 38  axon-server-connector-4.10.1
# 39  axon-server-connector-4.10.1
#
#                                           packageName  \
# 0                     org.axonframework.eventhandling
# 1                     org.axonframework.queryhandling
# 2                     org.axonframework.queryhandling
# 3                     org.axonframework.eventhandling
# 4                     org.axonframework.eventhandling
# 5                     org.axonframework.eventhandling
# 6                     org.axonframework.eventhandling
# 7                     org.axonframework.eventhandling
# 8                          org.axonframework.deadline
# 9                   org.axonframework.commandhandling
# 10                    org.axonframework.eventsourcing
# 11                    org.axonframework.eventsourcing
# 12        org.axonframework.commandhandling.callbacks
# 13        org.axonframework.commandhandling.callbacks
# 14        org.axonframework.axonserver.connector.util
# 15                    org.axonframework.eventhandling
# 16                    org.axonframework.eventhandling
# 17                    org.axonframework.eventhandling
# 18             org.axonframework.messaging.unitofwork
# 19             org.axonframework.messaging.unitofwork
# 20             org.axonframework.messaging.unitofwork
# 21  org.axonframework.axonserver.connector.event.axon
# 22  org.axonframework.axonserver.connector.event.axon
# 23  org.axonframework.axonserver.connector.event.axon
# 24  org.axonframework.axonserver.connector.event.axon
# 25  org.axonframework.axonserver.connector.event.axon
# 26       org.axonframework.axonserver.connector.query
# 27       org.axonframework.axonserver.connector.query
# 28       org.axonframework.axonserver.connector.query
# 29       org.axonframework.axonserver.connector.query
# 30       org.axonframework.axonserver.connector.query
# 31       org.axonframework.axonserver.connector.query
# 32              org.axonframework.eventhandling.async
# 33              org.axonframework.eventhandling.async
# 34              org.axonframework.eventhandling.async
# 35             org.axonframework.eventhandling.replay
# 36             org.axonframework.eventhandling.replay
# 37             org.axonframework.eventhandling.replay
# 38             org.axonframework.axonserver.connector
# 39       org.axonframework.axonserver.connector.query
#
#            dependentArtifactName  \
# 0          axon-messaging-4.10.1
# 1          axon-messaging-4.10.1
# 2          axon-messaging-4.10.1
# 3          axon-messaging-4.10.1
# 4          axon-messaging-4.10.1
# 5          axon-messaging-4.10.1
# 6          axon-messaging-4.10.1
# 7          axon-messaging-4.10.1
# 8          axon-messaging-4.10.1
# 9          axon-messaging-4.10.1
# 10     axon-eventsourcing-4.10.1
# 11     axon-eventsourcing-4.10.1
# 12         axon-messaging-4.10.1
# 13         axon-messaging-4.10.1
# 14  axon-server-connector-4.10.1
# 15         axon-messaging-4.10.1
# 16         axon-messaging-4.10.1
# 17         axon-messaging-4.10.1
# 18         axon-messaging-4.10.1
# 19         axon-messaging-4.10.1
# 20         axon-messaging-4.10.1
# 21  axon-server-connector-4.10.1
# 22  axon-server-connector-4.10.1
# 23  axon-server-connector-4.10.1
# 24  axon-server-connector-4.10.1
# 25  axon-server-connector-4.10.1
# 26  axon-server-connector-4.10.1
# 27  axon-server-connector-4.10.1
# 28  axon-server-connector-4.10.1
# 29  axon-server-connector-4.10.1
# 30  axon-server-connector-4.10.1
# 31  axon-server-connector-4.10.1
# 32         axon-messaging-4.10.1
# 33         axon-messaging-4.10.1
# 34         axon-messaging-4.10.1
# 35         axon-messaging-4.10.1
# 36         axon-messaging-4.10.1
# 37         axon-messaging-4.10.1
# 38  axon-server-connector-4.10.1
# 39  axon-server-connector-4.10.1
#
#                                          dependentPackageName  \
# 0                                   org.axonframework.tracing
# 1                   org.axonframework.messaging.responsetypes
# 2                                   org.axonframework.tracing
# 3                                 org.axonframework.messaging
# 4                                 org.axonframework.messaging
# 5                                 org.axonframework.messaging
# 6                      org.axonframework.messaging.annotation
# 7                      org.axonframework.messaging.annotation
# 8                                   org.axonframework.tracing
# 9                                   org.axonframework.tracing
# 10                 org.axonframework.eventsourcing.eventstore
# 11                 org.axonframework.eventsourcing.eventstore
# 12                          org.axonframework.commandhandling
# 13                          org.axonframework.commandhandling
# 14                     org.axonframework.axonserver.connector
# 15                            org.axonframework.serialization
# 16                            org.axonframework.serialization
# 17                            org.axonframework.serialization
# 18                                org.axonframework.messaging
# 19                                org.axonframework.messaging
# 20                                org.axonframework.messaging
# 21                     org.axonframework.axonserver.connector
# 22                     org.axonframework.axonserver.connector
# 23                     org.axonframework.axonserver.connector
# 24                     org.axonframework.axonserver.connector
# 25                     org.axonframework.axonserver.connector
# 26                     org.axonframework.axonserver.connector
# 27                     org.axonframework.axonserver.connector
# 28                     org.axonframework.axonserver.connector
# 29                     org.axonframework.axonserver.connector
# 30                     org.axonframework.axonserver.connector
# 31                     org.axonframework.axonserver.connector
# 32                            org.axonframework.eventhandling
# 33                            org.axonframework.eventhandling
# 34                            org.axonframework.eventhandling
# 35                            org.axonframework.eventhandling
# 36                            org.axonframework.eventhandling
# 37                            org.axonframework.eventhandling
# 38          org.axonframework.axonserver.connector.event.util
# 39  org.axonframework.axonserver.connector.query.subscription
#
#                                                                                   dependency  \
# 0                                                           EventMessage<-NestingSpanFactory
# 1                                            QueryResponseMessage<-ConvertingResponseMessage
# 2                                                                    QueryMessage<-SpanUtils
# 3                                                                DomainEventMessage<-Headers
# 4                                                                      EventMessage<-Headers
# 5                                                     TrackingToken<-StreamableMessageSource
# 6             DomainEventMessage<-SourceIdParameterResolverFactory$SourceIdParameterResolver
# 7   DomainEventMessage<-AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver
# 8                                                                 DeadlineMessage<-SpanUtils
# 9                                                                  CommandMessage<-SpanUtils
# 10                                                       EventStreamUtils<-DomainEventStream
# 11                                              EventStreamUtils<-AbstractEventStorageEngine
# 12                                                 LoggingCallback<-SimpleCommandBus$Builder
# 13                                                    NoOpCallback<-SimpleCommandBus$Builder
# 14                                                            ExceptionSerializer<-ErrorCode
# 15                                            GenericEventMessage<-AbstractXStreamSerializer
# 16                                      GenericDomainEventMessage<-AbstractXStreamSerializer
# 17                                     GapAwareTrackingToken<-GapAwareTrackingTokenConverter
# 18                                                       UnitOfWork<-DefaultInterceptorChain
# 19                                                     UnitOfWork<-MessageHandlerInterceptor
# 20                                                         CurrentUnitOfWork<-GenericMessage
# 21                             AxonServerEventStore$Builder<-ServerConnectorConfigurerModule
# 22                              AxonServerEventStoreFactory<-ServerConnectorConfigurerModule
# 23                                     AxonServerEventStore<-ServerConnectorConfigurerModule
# 24                      AxonServerEventStoreFactory$Builder<-ServerConnectorConfigurerModule
# 25                          EventProcessorInfoConfiguration<-ServerConnectorConfigurerModule
# 26                             AxonServerNonTransientRemoteQueryHandlingException<-ErrorCode
# 27                                         AxonServerRemoteQueryHandlingException<-ErrorCode
# 28                               AxonServerQueryBus$Builder<-ServerConnectorConfigurerModule
# 29                                       AxonServerQueryBus<-ServerConnectorConfigurerModule
# 30                                  QueryPriorityCalculator<-ServerConnectorConfigurerModule
# 31                                               AxonServerQueryDispatchException<-ErrorCode
# 32                           SequentialPerAggregatePolicy<-SimpleEventHandlerInvoker$Builder
# 33                                       SequencingPolicy<-SimpleEventHandlerInvoker$Builder
# 34                                               SequencingPolicy<-SimpleEventHandlerInvoker
# 35                                               ResetContext<-AnnotationEventHandlerAdapter
# 36                                        GenericResetContext<-AnnotationEventHandlerAdapter
# 37                                                                ResetContext<-ResetHandler
# 38                                                            ErrorCode<-GrpcExceptionParser
# 39                                  GrpcBackedResponseMessage<-SubscriptionMessageSerializer
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.857143             39               3
# 5                   0.857143             39               3
# 6                   0.840000             23               2
# 7                   0.840000             23               2
# 8                   0.800000              9               1
# 9                   0.777778              8               1
# 10                  0.777778             16               2
# 11                  0.777778             16               2
# 12                  0.733333             13               2
# 13                  0.733333             13               2
# 14                  0.666667              5               1
# 15                  0.647059             14               3
# 16                  0.647059             14               3
# 17                  0.647059             14               3
# 18                  0.647059             14               3
# 19                  0.647059             14               3
# 20                  0.647059             14               3
# 21                  0.615385             21               5
# 22                  0.615385             21               5
# 23                  0.615385             21               5
# 24                  0.615385             21               5
# 25                  0.615385             21               5
# 26                  0.571429             22               6
# 27                  0.571429             22               6
# 28                  0.571429             22               6
# 29                  0.571429             22               6
# 30                  0.571429             22               6
# 31                  0.571429             22               6
# 32                  0.538462             10               3
# 33                  0.538462             10               3
# 34                  0.538462             10               3
# 35                  0.454545              8               3
# 36                  0.454545              8               3
# 37                  0.454545              8               3
# 38                  0.333333              2               1
# 39                  0.333333              4               2

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.

# %% [markdown]
# ### Table 4 - Top 40 most used combinations of methods
#
# The following table shows the top 40 most used combinations of methods of larger types that might benefit from applying the *Interface Segregation Principle*. The whole table can be found in the CSV report `Candidates_for_Interface_Segregation`.

# %%
interface_segregation_candidates=query_cypher_to_data_frame("../cypher/Internal_Dependencies/Candidates_for_Interface_Segregation.cypher", limit=40)
interface_segregation_candidates
# Out:
#                                                    fullDependentTypeName  \
# 0                       org.axonframework.commandhandling.CommandMessage
# 1                           org.axonframework.eventhandling.EventMessage
# 2                     org.axonframework.eventhandling.DomainEventMessage
# 3                           org.axonframework.eventhandling.EventMessage
# 4                    org.axonframework.eventhandling.TrackedEventMessage
# 5          org.axonframework.commandhandling.GenericCommandResultMessage
# 6                     org.axonframework.eventhandling.DomainEventMessage
# 7                              org.axonframework.messaging.ResultMessage
# 8                            org.axonframework.eventhandling.ReplayToken
# 9                      org.axonframework.deadline.GenericDeadlineMessage
# 10                    org.axonframework.eventhandling.DomainEventMessage
# 11                   org.axonframework.eventhandling.TrackedEventMessage
# 12                            org.axonframework.deadline.DeadlineMessage
# 13                    org.axonframework.eventhandling.DomainEventMessage
# 14                   org.axonframework.eventhandling.GenericEventMessage
# 15          org.axonframework.deadline.DefaultDeadlineManagerSpanFactory
# 16             org.axonframework.common.transaction.NoTransactionManager
# 17              org.axonframework.queryhandling.SimpleQueryUpdateEmitter
# 18         org.axonframework.commandhandling.GenericCommandResultMessage
# 19                           org.axonframework.eventhandling.ReplayToken
# 20         org.axonframework.modelling.command.inspection.AggregateModel
# 21              org.axonframework.queryhandling.SubscriptionQueryMessage
# 22                    org.axonframework.eventhandling.DomainEventMessage
# 23                   org.axonframework.eventhandling.GenericEventMessage
# 24                        org.axonframework.queryhandling.SimpleQueryBus
# 25                    org.axonframework.eventhandling.DomainEventMessage
# 26                 org.axonframework.eventhandling.GapAwareTrackingToken
# 27            org.axonframework.queryhandling.DefaultQueryBusSpanFactory
# 28       org.axonframework.commandhandling.gateway.DefaultCommandGateway
# 29                                org.axonframework.config.Configuration
# 30                                org.axonframework.config.Configuration
# 31                          org.axonframework.eventhandling.EventMessage
# 32                          org.axonframework.messaging.MessageDecorator
# 33                          org.axonframework.queryhandling.QueryMessage
# 34        org.axonframework.commandhandling.DefaultCommandBusSpanFactory
# 35                      org.axonframework.eventhandling.TrackedEventData
# 36                org.axonframework.eventhandling.tokenstore.ConfigToken
# 37                  org.axonframework.serialization.SimpleSerializedType
# 38            org.axonframework.eventhandling.DefaultEventBusSpanFactory
# 39  org.axonframework.queryhandling.DefaultQueryUpdateEmitterSpanFactory
#
#     declaredMethods  \
# 0                 9
# 1                 9
# 2                10
# 3                 9
# 4                10
# 5                14
# 6                10
# 7                 9
# 8                13
# 9                11
# 10               10
# 11               12
# 12               10
# 13               10
# 14               10
# 15                8
# 16                4
# 17               17
# 18               15
# 19               13
# 20               13
# 21               12
# 22               11
# 23               11
# 24               11
# 25               10
# 26               10
# 27               10
# 28                9
# 29                9
# 30                9
# 31                9
# 32                9
# 33                9
# 34                5
# 35                5
# 36                5
# 37                5
# 38                4
# 39                4
#
#                                                    calledMethodNames  \
# 0                                                   [getCommandName]
# 1                                      [getTimestamp, getIdentifier]
# 2                                                [getSequenceNumber]
# 3                                                    [getIdentifier]
# 4                                                    [trackingToken]
# 5                                           [asCommandResultMessage]
# 6               [getSequenceNumber, getAggregateIdentifier, getType]
# 7                                   [isExceptional, exceptionResult]
# 8                                                [createReplayToken]
# 9                                                [asDeadlineMessage]
# 10                                          [getAggregateIdentifier]
# 11                                                   [trackingToken]
# 12                                                 [getDeadlineName]
# 13                                                         [getType]
# 14                                                  [asEventMessage]
# 15                                                         [builder]
# 16                                                        [instance]
# 17                                                         [builder]
# 18                                          [asCommandResultMessage]
# 19                                                        [isReplay]
# 20                                                            [type]
# 21                                           [getUpdateResponseType]
# 22              [getSequenceNumber, getAggregateIdentifier, getType]
# 23                                                  [asEventMessage]
# 24                                                         [builder]
# 25                       [getSequenceNumber, getAggregateIdentifier]
# 26  [withGapsTruncatedAt, getIndex, getGaps, newInstance, advanceTo]
# 27                                                         [builder]
# 28                                                         [builder]
# 29                                   [snapshotFilter, upcasterChain]
# 30                                                    [getComponent]
# 31                                                    [getTimestamp]
# 32                                                      [describeTo]
# 33                                   [getResponseType, getQueryName]
# 34                                                         [builder]
# 35                                                   [trackingToken]
# 36                                                             [get]
# 37                                                       [emptyType]
# 38                                                         [builder]
# 39                                                         [builder]
#
#     calledMethods  callerTypes
# 0               1           20
# 1               2           10
# 2               1            9
# 3               1            9
# 4               1            8
# 5               1            6
# 6               3            6
# 7               2            6
# 8               1            5
# 9               1            5
# 10              1            5
# 11              1            4
# 12              1            4
# 13              1            4
# 14              1            4
# 15              1            4
# 16              1            4
# 17              1            3
# 18              1            3
# 19              1            3
# 20              1            3
# 21              1            3
# 22              3            3
# 23              1            3
# 24              1            3
# 25              2            3
# 26              5            3
# 27              1            3
# 28              1            3
# 29              2            3
# 30              1            3
# 31              1            3
# 32              1            3
# 33              2            3
# 34              1            3
# 35              1            3
# 36              1            3
# 37              1            3
# 38              1            3
# 39              1            3

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Table 5 - Types that are used by multiple packages
#
# This table shows the top 40 packages that are used by the highest number of different packages. The whole table can be found in the CSV report `List_types_that_are_used_by_many_different_packages`.

# %%
types_used_by_many_packages=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_types_that_are_used_by_many_different_packages.cypher", limit=40)
types_used_by_many_packages
# Out:
#                                      fullQualifiedDependentTypeName  \
# 0                             org.axonframework.common.BuilderUtils
# 1               org.axonframework.common.AxonConfigurationException
# 2                               org.axonframework.messaging.Message
# 3                              org.axonframework.messaging.MetaData
# 4                        org.axonframework.serialization.Serializer
# 5                      org.axonframework.eventhandling.EventMessage
# 6                 org.axonframework.messaging.unitofwork.UnitOfWork
# 7           org.axonframework.common.transaction.TransactionManager
# 8                                   org.axonframework.common.Assert
# 9                  org.axonframework.serialization.SerializedObject
# 10                   org.axonframework.serialization.SerializedType
# 11         org.axonframework.messaging.unitofwork.CurrentUnitOfWork
# 12                            org.axonframework.common.Registration
# 13                            org.axonframework.tracing.SpanFactory
# 14                            org.axonframework.lifecycle.Lifecycle
# 15          org.axonframework.lifecycle.Lifecycle$LifecycleRegistry
# 16                             org.axonframework.common.ObjectUtils
# 17                    org.axonframework.eventhandling.TrackingToken
# 18               org.axonframework.eventhandling.DomainEventMessage
# 19  org.axonframework.messaging.annotation.ParameterResolverFactory
# 20               org.axonframework.common.AxonNonTransientException
# 21              org.axonframework.eventhandling.GenericEventMessage
# 22           org.axonframework.messaging.MessageDispatchInterceptor
# 23            org.axonframework.messaging.MessageHandlerInterceptor
# 24           org.axonframework.serialization.SimpleSerializedObject
# 25                        org.axonframework.tracing.NoOpSpanFactory
# 26                 org.axonframework.commandhandling.CommandMessage
# 27                         org.axonframework.eventhandling.EventBus
# 28         org.axonframework.messaging.annotation.HandlerDefinition
# 29        org.axonframework.common.transaction.NoTransactionManager
# 30                        org.axonframework.messaging.ResultMessage
# 31                                   org.axonframework.tracing.Span
# 32         org.axonframework.messaging.unitofwork.DefaultUnitOfWork
# 33                         org.axonframework.common.ReflectionUtils
# 34              org.axonframework.eventhandling.TrackedEventMessage
# 35                           org.axonframework.common.AxonException
# 36                           org.axonframework.common.DateTimeUtils
# 37              org.axonframework.messaging.DefaultInterceptorChain
# 38        org.axonframework.eventhandling.GenericDomainEventMessage
# 39                     org.axonframework.messaging.InterceptorChain
#
#               dependentTypeName  \
# 0                  BuilderUtils
# 1    AxonConfigurationException
# 2                       Message
# 3                      MetaData
# 4                    Serializer
# 5                  EventMessage
# 6                    UnitOfWork
# 7            TransactionManager
# 8                        Assert
# 9              SerializedObject
# 10               SerializedType
# 11            CurrentUnitOfWork
# 12                 Registration
# 13                  SpanFactory
# 14                    Lifecycle
# 15  Lifecycle$LifecycleRegistry
# 16                  ObjectUtils
# 17                TrackingToken
# 18           DomainEventMessage
# 19     ParameterResolverFactory
# 20    AxonNonTransientException
# 21          GenericEventMessage
# 22   MessageDispatchInterceptor
# 23    MessageHandlerInterceptor
# 24       SimpleSerializedObject
# 25              NoOpSpanFactory
# 26               CommandMessage
# 27                     EventBus
# 28            HandlerDefinition
# 29         NoTransactionManager
# 30                ResultMessage
# 31                         Span
# 32            DefaultUnitOfWork
# 33              ReflectionUtils
# 34          TrackedEventMessage
# 35                AxonException
# 36                DateTimeUtils
# 37      DefaultInterceptorChain
# 38    GenericDomainEventMessage
# 39             InterceptorChain
#
#                                                                                                                                                                                                                                                                                             dependentTypeLabels  \
# 0   [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunit...
# 1   [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation14, Mark4TypeLouvainCommuni...
# 2   [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent...
# 3   [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropaga...
# 4   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPro...
# 5   [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation6, ...
# 6   [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation...
# 7   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation42, Mark4TypeLouvainCommunity12, Mark4TypeLeidenCom...
# 8   [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunit...
# 9   [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent...
# 10  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation38, Mark4TypeLouvainCom...
# 11                           [Type, File, Java, ByteCode, Class, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation24, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity0, Mark4TypeKCoreDecomposition10]
# 12  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity7, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposit...
# 13                         [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity0, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10]
# 14                                                                                                               [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation14, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10]
# 15                                                                                                               [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation14, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10]
# 16                                                                                                                    [Type, File, Java, ByteCode, Class, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity9, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition10]
# 17  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation29, Mark4TypeLouvainCom...
# 18  [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation21, Mark4TypeLouvainCommunity11, Mark4TypeLeidenCommunity10,...
# 19                                                        [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecomposition10]
# 20  [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation17, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposit...
# 21                                        [Type, File, Java, ByteCode, Class, GenericDeclaration, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10]
# 22                                    [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity7, Mark4TypeLeidenCommunity6, Mark4TypeKCoreDecomposition10]
# 23     [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityBetweenness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation6, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity9, Mark4TypeKCoreDecomposition10]
# 24                                      [Type, File, Java, ByteCode, Class, GenericDeclaration, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation38, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10]
# 25                                                                                                                    [Type, File, Java, ByteCode, Class, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity0, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10]
# 26  [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, ...
# 27                                                       [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation18, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposition10]
# 28             [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation20, Mark4TypeLouvainCommunity10, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.15615615615615616]
# 29                                                                           [Type, File, Java, ByteCode, Enum, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation14, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity9, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.14285714285714285]
# 30  [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity...
# 31  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity0, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecompos...
# 32                                                                                                [Type, File, Java, ByteCode, Class, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity0, Mark4TypeKCoreDecomposition10]
# 33                                                                                                                    [Type, File, Java, ByteCode, Class, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation7, Mark4TypeLouvainCommunity10, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecomposition7]
# 34  [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation26, Mark4TypeLouvainCommunity12, Mark4TypeLeidenCommunity11, Mark4TypeKCoreDecomposition10]
# 35  [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation8, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecompositi...
# 36                                                                                                                    [Type, File, Java, ByteCode, Class, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation12, Mark4TypeLouvainCommunity9, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition8]
# 37                                                                                                [Type, File, Java, ByteCode, Class, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation6, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10]
# 38                                                        [Type, File, Java, ByteCode, Class, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.2727272727272727]
# 39                                                                                                               [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation13, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity0, Mark4TypeKCoreDecomposition10]
#
#     numberOfUsingPackages
# 0                      49
# 1                      42
# 2                      41
# 3                      39
# 4                      36
# 5                      35
# 6                      32
# 7                      31
# 8                      29
# 9                      27
# 10                     27
# 11                     22
# 12                     22
# 13                     22
# 14                     20
# 15                     20
# 16                     20
# 17                     20
# 18                     19
# 19                     19
# 20                     18
# 21                     18
# 22                     18
# 23                     18
# 24                     18
# 25                     17
# 26                     16
# 27                     15
# 28                     15
# 29                     15
# 30                     15
# 31                     15
# 32                     14
# 33                     14
# 34                     13
# 35                     12
# 36                     12
# 37                     12
# 38                     12
# 39                     12

# %% [markdown]
# ### Table 6 - Packages that are used by multiple artifacts
#
# This table shows the top 30 artifacts that only use a few (compared to all existing) packages of another artifact.
# The whole table can be found in the CSV report `ArtifactPackageUsage`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#                              artifactName  \
# 0       axon-tracing-opentelemetry-4.10.1
# 1            axon-server-connector-4.10.1
# 2   axon-spring-boot-autoconfigure-4.10.1
# 3                   axon-disruptor-4.10.1
# 4                        axon-test-4.10.1
# 5               axon-eventsourcing-4.10.1
# 6                   axon-disruptor-4.10.1
# 7                        axon-test-4.10.1
# 8                   axon-disruptor-4.10.1
# 9                   axon-modelling-4.10.1
# 10              axon-eventsourcing-4.10.1
# 11           axon-server-connector-4.10.1
# 12  axon-spring-boot-autoconfigure-4.10.1
# 13           axon-server-connector-4.10.1
# 14              axon-configuration-4.10.1
# 15                       axon-test-4.10.1
# 16              axon-configuration-4.10.1
# 17  axon-spring-boot-autoconfigure-4.10.1
# 18              axon-configuration-4.10.1
# 19  axon-spring-boot-autoconfigure-4.10.1
# 20                  axon-modelling-4.10.1
# 21  axon-spring-boot-autoconfigure-4.10.1
# 22                       axon-test-4.10.1
# 23                  axon-messaging-4.10.1
# 24              axon-eventsourcing-4.10.1
# 25           axon-server-connector-4.10.1
# 26  axon-spring-boot-autoconfigure-4.10.1
# 27           axon-server-connector-4.10.1
# 28  axon-spring-boot-autoconfigure-4.10.1
# 29              axon-configuration-4.10.1
#
#                     dependentArtifactName  dependentPackages  \
# 0                   axon-messaging-4.10.1                  3
# 1                   axon-modelling-4.10.1                  1
# 2                        axon-test-4.10.1                  1
# 3                   axon-messaging-4.10.1                  9
# 4                   axon-messaging-4.10.1                 10
# 5                   axon-modelling-4.10.1                  2
# 6                   axon-modelling-4.10.1                  2
# 7               axon-eventsourcing-4.10.1                  2
# 8               axon-eventsourcing-4.10.1                  2
# 9                   axon-messaging-4.10.1                 18
# 10                  axon-messaging-4.10.1                 20
# 11              axon-eventsourcing-4.10.1                  3
# 12           axon-server-connector-4.10.1                  4
# 13                  axon-messaging-4.10.1                 25
# 14              axon-eventsourcing-4.10.1                  4
# 15                  axon-modelling-4.10.1                  5
# 16                  axon-messaging-4.10.1                 34
# 17              axon-eventsourcing-4.10.1                  5
# 18                  axon-modelling-4.10.1                  6
# 19                  axon-modelling-4.10.1                  6
# 20                  axon-modelling-4.10.1                  6
# 21                  axon-messaging-4.10.1                 39
# 22                       axon-test-4.10.1                  5
# 23                  axon-messaging-4.10.1                 41
# 24              axon-eventsourcing-4.10.1                  7
# 25           axon-server-connector-4.10.1                  9
# 26  axon-spring-boot-autoconfigure-4.10.1                  8
# 27              axon-configuration-4.10.1                  1
# 28      axon-tracing-opentelemetry-4.10.1                  1
# 29                  axon-disruptor-4.10.1                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          64                0.046875
# 1                          10                0.100000
# 2                           8                0.125000
# 3                          64                0.140625
# 4                          64                0.156250
# 5                          10                0.200000
# 6                          10                0.200000
# 7                           9                0.222222
# 8                           9                0.222222
# 9                          64                0.281250
# 10                         64                0.312500
# 11                          9                0.333333
# 12                         11                0.363636
# 13                         64                0.390625
# 14                          9                0.444444
# 15                         10                0.500000
# 16                         64                0.531250
# 17                          9                0.555556
# 18                         10                0.600000
# 19                         10                0.600000
# 20                         10                0.600000
# 21                         64                0.609375
# 22                          8                0.625000
# 23                         64                0.640625
# 24                          9                0.777778
# 25                         11                0.818182
# 26                          9                0.888889
# 27                          1                1.000000
# 28                          1                1.000000
# 29                          1                1.000000
#
#                                                                                                                                                                                                                                                                              dependentFullQualifiedPackageNames  \
# 0                                                                                                                                                                                                                            [org.axonframework.messaging, org.axonframework.tracing, org.axonframework.common]
# 1                                                                                                                                                                                                                                                                         [org.axonframework.modelling.command]
# 2                                                                                                                                                                                                                                                                               [org.axonframework.test.server]
# 3   [org.axonframework.messaging, org.axonframework.common.caching, org.axonframework.commandhandling.callbacks, org.axonframework.messaging.unitofwork, org.axonframework.common.transaction, org.axonframework.commandhandling, org.axonframework.common, org.axonframework.monitoring, org.axonframework....
# 4   [org.axonframework.commandhandling.gateway, org.axonframework.commandhandling, org.axonframework.messaging, org.axonframework.eventhandling, org.axonframework.messaging.unitofwork, org.axonframework.common, org.axonframework.deadline, org.axonframework.messaging.annotation, org.axonframework.eve...
# 5                                                                                                                                                                                                                         [org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 6                                                                                                                                                                                                                         [org.axonframework.modelling.command.inspection, org.axonframework.modelling.command]
# 7                                                                                                                                                                                                                                 [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing]
# 8                                                                                                                                                                                                                                 [org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore]
# 9   [org.axonframework.deadline, org.axonframework.messaging.interceptors, org.axonframework.common.lock, org.axonframework.messaging.annotation, org.axonframework.common, org.axonframework.commandhandling, org.axonframework.common.jpa, org.axonframework.common.annotation, org.axonframework.eventhan...
# 10  [org.axonframework.common.jdbc, org.axonframework.eventhandling, org.axonframework.serialization, org.axonframework.common, org.axonframework.common.transaction, org.axonframework.serialization.upcasting.event, org.axonframework.tracing, org.axonframework.common.io, org.axonframework.lifecycle, ...
# 11                                                                                                                                                                                  [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing, org.axonframework.eventsourcing.snapshotting]
# 12                                                                                                                    [org.axonframework.axonserver.connector, org.axonframework.axonserver.connector.event.axon, org.axonframework.axonserver.connector.command, org.axonframework.axonserver.connector.query]
# 13  [org.axonframework.common, org.axonframework.serialization, org.axonframework.messaging, org.axonframework.eventhandling.scheduling, org.axonframework.monitoring, org.axonframework.eventhandling.scheduling.java, org.axonframework.eventhandling.async, org.axonframework.common.jdbc, org.axonframew...
# 14                                                                                                                                  [org.axonframework.eventsourcing.snapshotting, org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore.jpa]
# 15                                                                                   [org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.inmemory, org.axonframework.modelling.saga, org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 16  [org.axonframework.messaging.unitofwork, org.axonframework.queryhandling.annotation, org.axonframework.eventhandling.tokenstore.jpa, org.axonframework.tracing, org.axonframework.util, org.axonframework.messaging.deadletter, org.axonframework.serialization, org.axonframework.eventhandling.pooled,...
# 17                                                                         [org.axonframework.eventsourcing.eventstore.jpa, org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.eventstore.jdbc, org.axonframework.eventsourcing.eventstore.legacyjpa]
# 18                                  [org.axonframework.modelling.saga.repository.inmemory, org.axonframework.modelling.command.inspection, org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.saga, org.axonframework.modelling.command]
# 19                               [org.axonframework.modelling.command, org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga, org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.saga.repository.jdbc, org.axonframework.modelling.saga.repository.legacyjpa]
# 20                                            [org.axonframework.modelling.command.inspection, org.axonframework.modelling.saga, org.axonframework.modelling.saga.repository, org.axonframework.modelling.command, org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.saga.metamodel]
# 21  [org.axonframework.common.legacyjpa, org.axonframework.eventhandling, org.axonframework.messaging.deadletter, org.axonframework.eventhandling.deadletter.jdbc, org.axonframework.serialization.xml, org.axonframework.common, org.axonframework.common.transaction, org.axonframework.messaging.correlat...
# 22                                                                                                                                              [org.axonframework.test.deadline, org.axonframework.test.utils, org.axonframework.test, org.axonframework.test.matchers, org.axonframework.test.eventscheduler]
# 23  [org.axonframework.messaging, org.axonframework.serialization, org.axonframework.eventhandling.deadletter.jpa, org.axonframework.common.transaction, org.axonframework.eventhandling, org.axonframework.messaging.deadletter, org.axonframework.common.legacyjpa, org.axonframework.common, org.axonfram...
# 24  [org.axonframework.eventsourcing.eventstore.jdbc.statements, org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.snapshotting, org.axonframework.eventsourcing, org.axonframework.eventsourcing.conflictresolution, org.axonframework.eventsourcing.eventstore.jdbc, org.axonfra...
# 25  [org.axonframework.axonserver.connector, org.axonframework.axonserver.connector.processor, org.axonframework.axonserver.connector.event.util, org.axonframework.axonserver.connector.util, org.axonframework.axonserver.connector.heartbeat, org.axonframework.axonserver.connector.query, org.axonframe...
# 26  [org.axonframework.actuator, org.axonframework.springboot, org.axonframework.actuator.axonserver, org.axonframework.springboot.util.jpa, org.axonframework.springboot.service.connection, org.axonframework.springboot.util, org.axonframework.springboot.autoconfig, org.axonframework.springboot.util....
# 27                                                                                                                                                                                                                                                                                   [org.axonframework.config]
# 28                                                                                                                                                                                                                                                                    [org.axonframework.tracing.opentelemetry]
# 29                                                                                                                                                                                                                                                                [org.axonframework.disruptor.commandhandling]
#
#                                                                                                                                                                                                                                                                                           dependentPackageNames
# 0                                                                                                                                                                                                                                                                                  [messaging, tracing, common]
# 1                                                                                                                                                                                                                                                                                                     [command]
# 2                                                                                                                                                                                                                                                                                                      [server]
# 3                                                                                                                                                                                                     [messaging, caching, callbacks, unitofwork, transaction, commandhandling, common, monitoring, annotation]
# 4                                                                                                                                                                                            [gateway, commandhandling, messaging, eventhandling, unitofwork, common, deadline, annotation, scheduling, stream]
# 5                                                                                                                                                                                                                                                                                         [command, inspection]
# 6                                                                                                                                                                                                                                                                                         [inspection, command]
# 7                                                                                                                                                                                                                                                                                   [eventstore, eventsourcing]
# 8                                                                                                                                                                                                                                                                                   [eventsourcing, eventstore]
# 9                                                                                                                               [deadline, interceptors, lock, annotation, common, commandhandling, jpa, eventhandling, tracing, property, messaging, unitofwork, xml, jdbc, serialization, caching, legacyjpa]
# 10                                                                                                         [jdbc, eventhandling, serialization, common, transaction, event, tracing, io, lifecycle, stream, monitoring, messaging, xml, unitofwork, annotation, lock, caching, jpa, commandhandling, legacyjpa]
# 11                                                                                                                                                                                                                                                                    [eventstore, eventsourcing, snapshotting]
# 12                                                                                                                                                                                                                                                                            [connector, axon, command, query]
# 13                                     [common, serialization, messaging, scheduling, monitoring, java, async, jdbc, xml, lifecycle, stream, event, tracing, eventhandling, unitofwork, tokenstore, transaction, pooled, queryhandling, responsetypes, util, distributed, callbacks, commandhandling, inmemory]
# 14                                                                                                                                                                                                                                                               [snapshotting, eventstore, eventsourcing, jpa]
# 15                                                                                                                                                                                                                                                            [repository, inmemory, saga, command, inspection]
# 16  [unitofwork, annotation, jpa, tracing, util, deadletter, serialization, pooled, caching, xml, commandhandling, interceptors, monitoring, lock, correlation, event, inmemory, scheduling, jdbc, transaction, queryhandling, deadline, common, async, eventhandling, lifecycle, gateway, messaging, tokens...
# 17                                                                                                                                                                                                                                                            [jpa, eventsourcing, eventstore, jdbc, legacyjpa]
# 18                                                                                                                                                                                                                                                       [inmemory, inspection, repository, jpa, saga, command]
# 19                                                                                                                                                                                                                                                            [command, repository, saga, jpa, jdbc, legacyjpa]
# 20                                                                                                                                                                                                                                                      [inspection, saga, repository, command, jpa, metamodel]
# 21  [legacyjpa, eventhandling, deadletter, jdbc, xml, common, transaction, correlation, commandhandling, json, serialization, interceptors, pooled, async, dbscheduler, jobrunr, attributes, lifecycle, annotation, gateway, queryhandling, scheduling, jpa, deadline, tokenstore, messaging, event, distrib...
# 22                                                                                                                                                                                                                                                            [deadline, utils, test, matchers, eventscheduler]
# 23  [messaging, serialization, jpa, transaction, eventhandling, deadletter, legacyjpa, common, util, queryhandling, unitofwork, tokenstore, commandhandling, distributed, annotation, tracing, lifecycle, xml, deadline, io, stream, responsetypes, scheduling, callbacks, monitoring, commandfilter, digest...
# 24                                                                                                                                                                                                                         [statements, eventstore, snapshotting, eventsourcing, conflictresolution, jdbc, jpa]
# 25                                                                                                                                                                                                                                  [connector, processor, util, heartbeat, query, command, subscription, axon]
# 26                                                                                                                                                                                                                             [actuator, springboot, axonserver, jpa, connection, util, autoconfig, legacyjpa]
# 27                                                                                                                                                                                                                                                                                                     [config]
# 28                                                                                                                                                                                                                                                                                              [opentelemetry]
# 29                                                                                                                                                                                                                                                                                            [commandhandling]

# %% [markdown]
# ### Table 7 - Types that are used by multiple artifacts
#
# This table shows the top 30 types that only use a few (compared to all existing) types of another artifact. The whole table can be found in the CSV report `ClassesPerPackageUsageAcrossArtifacts`.

# %%
used_types_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher", limit=30)
used_types_of_dependent_artifact
# Out:
#                              artifactName      dependentArtifactName  \
# 0                   axon-modelling-4.10.1      axon-messaging-4.10.1
# 1            axon-server-connector-4.10.1      axon-messaging-4.10.1
# 2                        axon-test-4.10.1      axon-messaging-4.10.1
# 3               axon-eventsourcing-4.10.1      axon-messaging-4.10.1
# 4   axon-spring-boot-autoconfigure-4.10.1      axon-messaging-4.10.1
# 5   axon-spring-boot-autoconfigure-4.10.1      axon-messaging-4.10.1
# 6               axon-eventsourcing-4.10.1      axon-modelling-4.10.1
# 7            axon-server-connector-4.10.1      axon-modelling-4.10.1
# 8               axon-eventsourcing-4.10.1      axon-modelling-4.10.1
# 9                   axon-modelling-4.10.1      axon-messaging-4.10.1
# 10                       axon-test-4.10.1      axon-messaging-4.10.1
# 11              axon-eventsourcing-4.10.1      axon-messaging-4.10.1
# 12                  axon-modelling-4.10.1      axon-messaging-4.10.1
# 13           axon-server-connector-4.10.1  axon-eventsourcing-4.10.1
# 14           axon-server-connector-4.10.1  axon-configuration-4.10.1
# 15  axon-spring-boot-autoconfigure-4.10.1  axon-configuration-4.10.1
# 16  axon-spring-boot-autoconfigure-4.10.1  axon-configuration-4.10.1
# 17                       axon-test-4.10.1      axon-messaging-4.10.1
# 18                       axon-test-4.10.1      axon-messaging-4.10.1
# 19              axon-eventsourcing-4.10.1      axon-messaging-4.10.1
# 20              axon-eventsourcing-4.10.1      axon-messaging-4.10.1
# 21  axon-spring-boot-autoconfigure-4.10.1      axon-messaging-4.10.1
# 22              axon-eventsourcing-4.10.1      axon-messaging-4.10.1
# 23              axon-eventsourcing-4.10.1      axon-messaging-4.10.1
# 24              axon-eventsourcing-4.10.1      axon-messaging-4.10.1
# 25              axon-eventsourcing-4.10.1      axon-messaging-4.10.1
# 26                       axon-test-4.10.1      axon-modelling-4.10.1
# 27              axon-eventsourcing-4.10.1      axon-messaging-4.10.1
# 28                       axon-test-4.10.1      axon-messaging-4.10.1
# 29           axon-server-connector-4.10.1  axon-eventsourcing-4.10.1
#
#                                                    packageName  \
# 0                   org.axonframework.modelling.saga.metamodel
# 1                       org.axonframework.axonserver.connector
# 2                              org.axonframework.test.matchers
# 3                 org.axonframework.eventsourcing.snapshotting
# 4            org.axonframework.springboot.autoconfig.legacyjpa
# 5                            org.axonframework.springboot.util
# 6           org.axonframework.eventsourcing.conflictresolution
# 7                       org.axonframework.axonserver.connector
# 8              org.axonframework.eventsourcing.eventstore.jdbc
# 9                org.axonframework.modelling.command.legacyjpa
# 10                       org.axonframework.test.eventscheduler
# 11          org.axonframework.eventsourcing.conflictresolution
# 12                         org.axonframework.modelling.command
# 13           org.axonframework.axonserver.connector.event.axon
# 14            org.axonframework.axonserver.connector.processor
# 15                                org.axonframework.springboot
# 16           org.axonframework.springboot.autoconfig.legacyjpa
# 17                             org.axonframework.test.matchers
# 18                                      org.axonframework.test
# 19          org.axonframework.eventsourcing.conflictresolution
# 20                  org.axonframework.eventsourcing.eventstore
# 21           org.axonframework.springboot.autoconfig.legacyjpa
# 22        org.axonframework.eventsourcing.eventstore.legacyjpa
# 23              org.axonframework.eventsourcing.eventstore.jpa
# 24             org.axonframework.eventsourcing.eventstore.jdbc
# 25  org.axonframework.eventsourcing.eventstore.jdbc.statements
# 26                                org.axonframework.test.utils
# 27          org.axonframework.eventsourcing.conflictresolution
# 28                             org.axonframework.test.matchers
# 29                      org.axonframework.axonserver.connector
#
#                           dependentPackage.fqn  dependentTypes  \
# 0              org.axonframework.eventhandling               1
# 1              org.axonframework.eventhandling               1
# 2              org.axonframework.eventhandling               1
# 3              org.axonframework.eventhandling               1
# 4              org.axonframework.eventhandling               1
# 5              org.axonframework.eventhandling               1
# 6          org.axonframework.modelling.command               1
# 7          org.axonframework.modelling.command               1
# 8          org.axonframework.modelling.command               1
# 9              org.axonframework.eventhandling               2
# 10             org.axonframework.eventhandling               2
# 11             org.axonframework.eventhandling               2
# 12             org.axonframework.eventhandling               2
# 13             org.axonframework.eventsourcing               1
# 14                    org.axonframework.config               1
# 15                    org.axonframework.config               1
# 16                    org.axonframework.config               1
# 17                 org.axonframework.messaging               1
# 18                 org.axonframework.messaging               1
# 19                 org.axonframework.messaging               1
# 20                 org.axonframework.messaging               1
# 21             org.axonframework.serialization               1
# 22             org.axonframework.serialization               1
# 23             org.axonframework.serialization               1
# 24             org.axonframework.serialization               1
# 25             org.axonframework.eventhandling               3
# 26            org.axonframework.modelling.saga               1
# 27           org.axonframework.commandhandling               1
# 28           org.axonframework.commandhandling               1
# 29  org.axonframework.eventsourcing.eventstore               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                     100             0.010000
# 1                     100             0.010000
# 2                     100             0.010000
# 3                     100             0.010000
# 4                     100             0.010000
# 5                     100             0.010000
# 6                      56             0.017857
# 7                      56             0.017857
# 8                      56             0.017857
# 9                     100             0.020000
# 10                    100             0.020000
# 11                    100             0.020000
# 12                    100             0.020000
# 13                     42             0.023810
# 14                     41             0.024390
# 15                     41             0.024390
# 16                     41             0.024390
# 17                     35             0.028571
# 18                     35             0.028571
# 19                     35             0.028571
# 20                     35             0.028571
# 21                     34             0.029412
# 22                     34             0.029412
# 23                     34             0.029412
# 24                     34             0.029412
# 25                    100             0.030000
# 26                     33             0.030303
# 27                     32             0.031250
# 28                     32             0.031250
# 29                     31             0.032258
#
#                                                                                                                                                dependentTypeNames
# 0                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 1                                                                                                           [org.axonframework.eventhandling.EventBusSpanFactory]
# 2                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 3                                                                                                               [org.axonframework.eventhandling.DomainEventData]
# 4                                                                                                                      [org.axonframework.eventhandling.EventBus]
# 5                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 6                                                                                      [org.axonframework.modelling.command.ConflictingAggregateVersionException]
# 7                                                                                                      [org.axonframework.modelling.command.ConcurrencyException]
# 8                                                                                                      [org.axonframework.modelling.command.ConcurrencyException]
# 9                                                            [org.axonframework.eventhandling.DomainEventSequenceAware, org.axonframework.eventhandling.EventBus]
# 10                                                            [org.axonframework.eventhandling.GenericEventMessage, org.axonframework.eventhandling.EventMessage]
# 11                                                             [org.axonframework.eventhandling.DomainEventMessage, org.axonframework.eventhandling.EventMessage]
# 12                                                           [org.axonframework.eventhandling.DomainEventSequenceAware, org.axonframework.eventhandling.EventBus]
# 13                                                                                                             [org.axonframework.eventsourcing.EventStreamUtils]
# 14                                                                                                        [org.axonframework.config.EventProcessingConfiguration]
# 15                                                                                                                   [org.axonframework.config.TagsConfiguration]
# 16                                                                                                                       [org.axonframework.config.Configuration]
# 17                                                                                                                          [org.axonframework.messaging.Message]
# 18                                                                                                                          [org.axonframework.messaging.Message]
# 19                                                                                                                          [org.axonframework.messaging.Message]
# 20                                                                                                          [org.axonframework.messaging.StreamableMessageSource]
# 21                                                                                                                   [org.axonframework.serialization.Serializer]
# 22                                                                                                                   [org.axonframework.serialization.Serializer]
# 23                                                                                                                   [org.axonframework.serialization.Serializer]
# 24                                                                                                                   [org.axonframework.serialization.Serializer]
# 25  [org.axonframework.eventhandling.GenericDomainEventMessage, org.axonframework.eventhandling.DomainEventMessage, org.axonframework.eventhandling.EventMessage]
# 26                                                                                                      [org.axonframework.modelling.saga.SimpleResourceInjector]
# 27                                                                                                             [org.axonframework.commandhandling.CommandMessage]
# 28                                                                                                             [org.axonframework.commandhandling.CommandMessage]
# 29                                                                                               [org.axonframework.eventsourcing.eventstore.EventStoreException]

# %% [markdown]
# ### Table 8 - Duplicate package names across artifacts
#
# This table shows the top 30 duplicate package names across artifacts. They are ordered by the number of duplicates descending.
#
# This might lead to confusion, makes importing more error prone and might even lead to duplicate classes where only one of them will be loaded by the class loader. If a package is named the same way in two or more artifacts this even allows another artifact to access package protected classes, methods or members which might not be intended.
#
# The whole table can be found in the CSV report `DuplicatePackageNamesAcrossArtifacts`.

# %%
duplicate_package_names_across_artifacts=query_cypher_to_data_frame("../cypher/Artifact_Dependencies/Artifacts_with_duplicate_packages.cypher", limit=30)
duplicate_package_names_across_artifacts
# Out:
# Empty DataFrame
# Columns: [packageName, duplicates, artifactNames]
# Index: []

# %% [markdown]
# ### Table 9 - Annotated elements
#
# This table shows 30 most used Java Annotations including some examples where they are used.

# %%
annotated_elements=query_cypher_to_data_frame("../cypher/Java/Annotated_code_elements.cypher", limit=30)
annotated_elements
# Out:
#                                                                annotationName  \
# 0                                                    javax.annotation.Nonnull
# 1                                                        java.lang.Deprecated
# 2                                 org.springframework.context.annotation.Bean
# 3   org.springframework.boot.autoconfigure.condition.ConditionalOnMissingBean
# 4                                               java.lang.FunctionalInterface
# 5                                                   javax.annotation.Nullable
# 6                                                    javax.annotation.Nonnull
# 7                                                        java.lang.Deprecated
# 8                                                 java.lang.annotation.Target
# 9                                              java.lang.annotation.Retention
# 10                                                    javax.persistence.Basic
# 11                                                  jakarta.persistence.Basic
# 12                              com.fasterxml.jackson.annotation.JsonProperty
# 13                                            java.lang.annotation.Documented
# 14                   org.springframework.boot.autoconfigure.AutoConfiguration
# 15                                           java.beans.ConstructorProperties
# 16                     org.springframework.beans.factory.annotation.Qualifier
# 17                                                       java.lang.Deprecated
# 18                               com.fasterxml.jackson.annotation.JsonCreator
# 19                  org.springframework.boot.autoconfigure.AutoConfigureAfter
# 20     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 21                 org.springframework.boot.autoconfigure.AutoConfigureBefore
# 22        org.springframework.boot.autoconfigure.condition.ConditionalOnClass
# 23                                                   javax.persistence.Column
# 24                                                 jakarta.persistence.Column
# 25                                          org.axonframework.common.Priority
# 26  org.springframework.boot.context.properties.EnableConfigurationProperties
# 27         org.springframework.boot.autoconfigure.condition.ConditionalOnBean
# 28                                                       javax.persistence.Id
# 29                                                      javax.persistence.Lob
#
#    languageElement  numberOfAnnotatedElements  \
# 0        Parameter                       1616
# 1           Method                        132
# 2           Method                        111
# 3           Method                         78
# 4        Interface                         65
# 5        Parameter                         61
# 6           Method                         50
# 7            Class                         43
# 8       Annotation                         43
# 9       Annotation                         43
# 10           Field                         39
# 11           Field                         33
# 12       Parameter                         32
# 13      Annotation                         23
# 14           Class                         22
# 15     Constructor                         21
# 16       Parameter                         20
# 17     Constructor                         20
# 18     Constructor                         16
# 19           Class                         16
# 20          Method                         15
# 21           Class                         14
# 22           Class                         12
# 23           Field                         12
# 24           Field                         11
# 25           Class                         11
# 26           Class                         11
# 27          Method                         10
# 28           Field                         10
# 29           Field                         10
#
#                                                                                                                                                                                                                                                                                                        examples
# 0   [org.axonframework.test.aggregate.ResultValidatorImpl.onResult(0), org.axonframework.test.aggregate.ResultValidatorImpl.onResult(1), org.axonframework.test.aggregate.AggregateTestFixture$CreationalRepository.load(0), org.axonframework.test.aggregate.AggregateTestFixture$CreationalRepository.newI...
# 1   [org.axonframework.test.aggregate.ResultValidator.expectDeadlinesMetMatching, org.axonframework.test.aggregate.ResultValidator.expectDeadlinesMet, org.axonframework.test.aggregate.Reporter.reportWrongEvent, org.axonframework.test.aggregate.AggregateTestFixture.whenThenTimeElapses, org.axonframew...
# 2   [org.axonframework.springboot.autoconfig.InfraConfiguration.messageHandlerLookup, org.axonframework.springboot.autoconfig.InfraConfiguration.springAggregateLookup, org.axonframework.springboot.autoconfig.InfraConfiguration.springSagaLookup, org.axonframework.springboot.autoconfig.InfraConfigurat...
# 3   [org.axonframework.springboot.autoconfig.InfraConfiguration.springAxonConfiguration, org.axonframework.springboot.autoconfig.InfraConfiguration.springAxonConfigurer, org.axonframework.springboot.autoconfig.InfraConfiguration.resourceInjector, org.axonframework.springboot.autoconfig.MetricsAutoCo...
# 4   [org.axonframework.test.matchers.FieldFilter, org.axonframework.test.deadline.DeadlineConsumer, org.axonframework.test.eventscheduler.EventConsumer, org.axonframework.axonserver.connector.util.ExecutorServiceBuilder, org.axonframework.axonserver.connector.ErrorCode$ExceptionBuilder, org.axonfram...
# 5   [org.axonframework.eventsourcing.eventstore.EventStorageEngine.readEvents(0), org.axonframework.commandhandling.GenericCommandResultMessage.<init>(0), org.axonframework.commandhandling.GenericCommandResultMessage.<init>(1), org.axonframework.commandhandling.MonitorAwareCallback.<init>(0), org.ax...
# 6   [org.axonframework.test.aggregate.AggregateTestFixture$RecordingEventStore.subscribe, org.axonframework.test.aggregate.AggregateTestFixture$RecordingEventStore.registerDispatchInterceptor, org.axonframework.test.deadline.StubDeadlineManager.schedule, org.axonframework.test.deadline.StubDeadlineM...
# 7   [org.axonframework.test.aggregate.StubAggregateLifecycleRule, org.axonframework.test.server.AxonServerSEContainer, org.axonframework.test.server.AxonServerEEContainer, org.axonframework.test.utils.AutowiredResourceInjector, org.axonframework.axonserver.connector.util.GrpcBufferingInterceptor, or...
# 8   [org.axonframework.eventsourcing.EventSourcingHandler, org.axonframework.commandhandling.CommandHandler, org.axonframework.commandhandling.RoutingKey, org.axonframework.commandhandling.gateway.Timeout, org.axonframework.common.Priority, org.axonframework.deadline.annotation.DeadlineHandler, org....
# 9   [org.axonframework.eventsourcing.EventSourcingHandler, org.axonframework.commandhandling.CommandHandler, org.axonframework.commandhandling.RoutingKey, org.axonframework.commandhandling.gateway.Timeout, org.axonframework.common.Priority, org.axonframework.deadline.annotation.DeadlineHandler, org....
# 10  [org.axonframework.eventhandling.AbstractDomainEventEntry.type, org.axonframework.eventhandling.AbstractDomainEventEntry.aggregateIdentifier, org.axonframework.eventhandling.AbstractDomainEventEntry.sequenceNumber, org.axonframework.eventhandling.AbstractEventEntry.timeStamp, org.axonframework.e...
# 11  [org.axonframework.eventhandling.AbstractDomainEventEntry.type, org.axonframework.eventhandling.AbstractDomainEventEntry.aggregateIdentifier, org.axonframework.eventhandling.AbstractDomainEventEntry.sequenceNumber, org.axonframework.eventhandling.AbstractEventEntry.timeStamp, org.axonframework.e...
# 12  [org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>(0), org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>(1), org.axonframework.commandhandling.distributed.commandfilter.CommandNameFilter.<init>(0), org.axonframewor...
# 13  [org.axonframework.eventsourcing.EventSourcingHandler, org.axonframework.commandhandling.CommandHandler, org.axonframework.eventhandling.AllowReplay, org.axonframework.eventhandling.DisallowReplay, org.axonframework.eventhandling.EventHandler, org.axonframework.lifecycle.ShutdownHandler, org.axo...
# 14  [org.axonframework.springboot.autoconfig.InfraConfiguration, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.spring...
# 15  [org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>, org.axonframework.commandhandling.distributed.commandfilter.CommandNameFilter.<init>, org.axonframework.commandhandling.distributed.commandfilter.DenyCommandNameFilter.<init>, org.axonframework.commandha...
# 16  [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.axonServerCommandBus(2), org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.axonServerCommandBus(3), org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.queryBus(4), org.axonframework.s...
# 17  [org.axonframework.axonserver.connector.query.subscription.AxonServerSubscriptionQueryResult.<init>, org.axonframework.axonserver.connector.processor.EventProcessorControlService.<init>, org.axonframework.eventsourcing.MultiStreamableMessageSource.<init>, org.axonframework.eventsourcing.snapshot...
# 18  [org.axonframework.eventhandling.GapAwareTrackingToken.<init>, org.axonframework.eventhandling.GlobalSequenceTrackingToken.<init>, org.axonframework.eventhandling.MergedTrackingToken.<init>, org.axonframework.eventhandling.ReplayToken.<init>, org.axonframework.eventhandling.MultiSourceTrackingTo...
# 19  [org.axonframework.springboot.autoconfig.InfraConfiguration, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.spring...
# 20  [org.axonframework.springboot.autoconfig.MetricsAutoConfiguration.metricsConfigurerModule, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.eventStore, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.axonServerEventStoreFactory, org.axonframework.spri...
# 21  [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration, org.axonframework.springboot.autoconfig.JpaEventStoreAutoCo...
# 22  [org.axonframework.springboot.autoconfig.InfraConfiguration, org.axonframework.springboot.autoconfig.AxonServerAutoConfiguration$ConnectionDetailsConnectionManagerConfiguration, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration, org.axonframework.springboot.autoconfig.Microm...
# 23  [org.axonframework.eventhandling.AbstractEventEntry.eventIdentifier, org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.causeMessage, org.axonframework.eventhandli...
# 24  [org.axonframework.eventhandling.AbstractEventEntry.eventIdentifier, org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.causeMessage, org.axonframework.eventhandli...
# 25  [org.axonframework.test.FixtureResourceParameterResolverFactory, org.axonframework.commandhandling.CurrentUnitOfWorkParameterResolverFactory, org.axonframework.eventhandling.SequenceNumberParameterResolverFactory, org.axonframework.eventhandling.TimestampParameterResolverFactory, org.axonframewo...
# 26  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.springboot.autoconfig.MicrometerMetricsAutoConfiguration, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration, org.axonframew...
# 27  [org.axonframework.springboot.autoconfig.MetricsAutoConfiguration.globalMetricRegistry, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration.metricsConfigurerModule, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.persistenceExceptionResolver, org.axonfram...
# 28  [org.axonframework.eventsourcing.eventstore.AbstractSnapshotEventEntry.aggregateIdentifier, org.axonframework.eventsourcing.eventstore.AbstractSnapshotEventEntry.sequenceNumber, org.axonframework.eventsourcing.eventstore.AbstractSnapshotEventEntry.type, org.axonframework.eventhandling.AbstractSe...
# 29  [org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.diagnostics, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEventEntry.payload, org.axonframework.eve...

# %% [markdown]
# ### Table 10 - Distance distribution between dependent files
#
# This table shows the file directory distance distribution between dependent files. Intuitively, the distance is given by the fewest number of change directory commands needed to navigate between a file and a dependency it uses. Those are aggregate to see how many dependent files are in the same directory, how many are just one change directory command apart, and so on.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Internal_Dependencies/Get_file_distance_as_shortest_contains_path_for_dependencies.cypher",
                                           "../cypher/Internal_Dependencies/Set_file_distance_as_shortest_contains_path_for_dependencies.cypher", limit=20)
# Out:
#    dependency.fileDistanceAsFewestChangeDirectoryCommands  \
# 0                                                       0
# 1                                                       1
# 2                                                       2
# 3                                                       4
#
#    numberOfDependencies  numberOfDependencyUsers  numberOfDependencyProviders  \
# 0                  2600                     1026                         1160
# 1                    90                       82                           38
# 2                  2503                      760                          472
# 3                  2595                      449                          541
#
#                                                                                                                                                                                                                                                                                                       examples
# 0                 [/axon-spring-boot-autoconfigure-4.10.1.jar uses /axon-test-4.10.1.jar, /org/axonframework/test/deadline uses /org/axonframework/test/matchers, /org/axonframework/test/saga uses /org/axonframework/test/matchers, /org/axonframework/test/aggregate uses /org/axonframework/test/matchers]
# 1                                              [/org/axonframework/test/eventscheduler uses /org/axonframework/test, /org/axonframework/test/aggregate uses /org/axonframework/test, /org/axonframework/test/matchers uses /org/axonframework/test, /org/axonframework/test/saga uses /org/axonframework/test]
# 2  [/org/axonframework/test/aggregate/ResultValidatorImpl.class uses /org/axonframework/test/matchers/FieldFilter.class, /org/axonframework/test/deadline/DeadlineManagerValidator.class uses /org/axonframework/test/matchers/FieldFilter.class, /org/axonframework/test/saga/SagaTestFixture$MutableField...
# 3  [/org/axonframework/springboot/service/connection uses /org/axonframework/test/server, /org/axonframework/springboot/service/connection/AxonServerTestContainerConnectionDetailsFactory.class uses /org/axonframework/test/server/AxonServerContainer.class, /org/axonframework/springboot/service/conne...
