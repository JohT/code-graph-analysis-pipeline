# %% [markdown]
# # External Dependencies
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## External Package Usage
#
# ### External Package
#
# An external type has no `byteCodeVersion` since it only occurs as a dependency but wasn't analyzed itself (missing bytecode). Core Java types like `java.lang.Integer` and primitives like `int` are considered "build-in" and therefore aren't interpreted as "external" even though their byte code is also missing. A package is categorized as "external" if the types it contains are classified as external.
#
# ### External annotation dependency
#
# The aforementioned classification encompasses external annotation dependencies as well. These dependencies introduce significantly less coupling and are not indispensable for compiling code. Without the external annotation the code would most probably behave differently. Hence, they are included in the first more overall and general tables and then left out in the later more specific ones.

# %% [markdown]
# ### Table 1 - Top 20 most used external packages overall
#
# This table shows the external packages that are used by the most different internal types overall.
# Additionally, it shows which types of the external package are actually used. External annotations are also listed.
#
# Only the top 20 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_overall`
#
# **Columns:**
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalCallerPackages* refers to the distinct packages that make use of the external package
# - *numberOfExternalCallerTypes* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every dependency to the types in the external package
# - *numberOfExternalTypeCallsWeighted* includes every invocation or reference (sum of weights) to the types in the external package
# - *allPackages* contains the total count of all analyzed packages in general
# - *allTypes* contains the total count of all analyzed types in general
# - *externalTypeNames* contains a list of actually utilized types of the external package

# %%
external_package_usage=query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_overall.cypher")

# Select columns and only show the first 20 entries (head)
external_package_usage.head(20)
# Out:
#                       externalPackageName  numberOfExternalCallerPackages  \
# 0                        javax.annotation                              63
# 1                               org.slf4j                              53
# 2        com.fasterxml.jackson.annotation                              13
# 3                       javax.persistence                              13
# 4                     jakarta.persistence                               8
# 5                            org.hamcrest                               5
# 6        com.github.kagkarlsson.scheduler                               2
# 7   com.github.kagkarlsson.scheduler.task                               2
# 8             com.thoughtworks.xstream.io                               2
# 9                  org.jobrunr.scheduling                               2
# 10                             org.quartz                               2
# 11                 reactor.core.publisher                               2
# 12             com.fasterxml.jackson.core                               1
# 13         com.fasterxml.jackson.databind                               1
# 14    com.fasterxml.jackson.databind.node                               1
# 15                        com.google.gson                               1
# 16                     com.lmax.disruptor                               1
# 17                 com.lmax.disruptor.dsl                               1
# 18    com.thoughtworks.xstream.converters                               1
# 19        com.thoughtworks.xstream.io.xml                               1
#
#     numberOfExternalCallerTypes  numberOfExternalTypeCalls  \
# 0                           310                        342
# 1                           117                        208
# 2                            23                         57
# 3                            24                         78
# 4                            22                         69
# 5                            27                         61
# 6                             4                          7
# 7                             4                         10
# 8                             4                          9
# 9                             4                          6
# 10                            9                         39
# 11                           18                         35
# 12                            3                          4
# 13                            7                         15
# 14                            2                          3
# 15                            1                          4
# 16                            7                          9
# 17                            4                          5
# 18                            3                          6
# 19                            2                          4
#
#     numberOfExternalTypeCallsWeighted  allPackages  allTypes  \
# 0                                1602           93      1224
# 1                                 608           93      1224
# 2                                  87           93      1224
# 3                                 340           93      1224
# 4                                 328           93      1224
# 5                                 498           93      1224
# 6                                  54           93      1224
# 7                                  52           93      1224
# 8                                  46           93      1224
# 9                                  37           93      1224
# 10                                232           93      1224
# 11                                157           93      1224
# 12                                 11           93      1224
# 13                                 73           93      1224
# 14                                 14           93      1224
# 15                                  9           93      1224
# 16                                 29           93      1224
# 17                                 22           93      1224
# 18                                 12           93      1224
# 19                                 13           93      1224
#
#                                  tenExternalTypeNames
# 0                     [Nonnull, Nullable, PreDestroy]
# 1                             [Logger, LoggerFactory]
# 2   [JsonCreator, JsonProperty, JsonTypeInfo, Json...
# 3   [LockModeType, EntityManager, GeneratedValue, ...
# 4   [EntityManager, LockModeType, EntityManagerFac...
# 5   [Matcher, StringDescription, Description, Core...
# 6     [Scheduler, ScheduledExecution, SchedulerState]
# 7   [TaskInstanceId, TaskInstance, ExecutionContex...
# 8   [HierarchicalStreamReader, HierarchicalStreamW...
# 9                          [JobScheduler, JobBuilder]
# 10  [SchedulerContext, JobExecutionContext, Trigge...
# 11  [Mono, Flux, Sinks$EmitResult, Sinks$Many, Sig...
# 12  [JsonParser, JacksonException, JsonProcessingE...
# 13  [JsonDeserializer, DeserializationContext, Obj...
# 14                         [JsonNodeType, ObjectNode]
# 15   [JsonObject, JsonElement, JsonParser, JsonArray]
# 16  [BlockingWaitStrategy, WaitStrategy, Exception...
# 17       [ProducerType, Disruptor, EventHandlerGroup]
# 18         [MarshallingContext, UnmarshallingContext]
# 19  [XomReader, Dom4JReader, CompactWriter, XppDri...

# %% [markdown]
# #### Table 1 Chart 1 - Most called external packages in % by types
#
# External packages that are used less than 0.7% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
def group_to_others_below_threshold(data_frame : pd.DataFrame, value_column : str, name_column: str, threshold: float) -> pd.DataFrame:    
    """Adds a new percentage column for the value column and 
    groups all values below the given threshold to "others" in the name column.

    Parameters:
    - data_frame (pd.DataFrame): Input pandas DataFrame
    - value_column (str): Name of the column that contains the numeric value
    - name_column (str): Name of the column that contains the group name that will be replaced by "others" for small values
    - threshold (float): Threshold in % that is used to group values below it into the "others" group

    Returns:
    int:Returning value

    """
    result_data_frame = data_frame.copy();

    percent_column_name = value_column + 'Percent';

    # Add column with the name given in "percent_column_name" with the percentage of the value column.
    result_data_frame[percent_column_name] = result_data_frame[value_column] / result_data_frame[value_column].sum() * 100.0;

    # Change the external package name to "others" if it is called less than the specified threshold
    result_data_frame.loc[result_data_frame[percent_column_name] < threshold, name_column] = 'others';

    # Group external package name (foremost the new "others" entries) and sum their percentage
    result_data_frame = result_data_frame.groupby(name_column)[percent_column_name].sum();

    # Sort by values descending
    return result_data_frame.sort_values(ascending=False);

# %%
external_package_by_type_usage_significant = group_to_others_below_threshold(
    data_frame=external_package_usage,
    value_column='numberOfExternalCallerTypes',
    name_column='externalPackageName',
    threshold= 0.7
);

# %%
plot.figure();

axis = external_package_by_type_usage_significant.plot(
    kind='pie',
    title='Top external package usage [%] by type',
    legend=True,
    labeldistance=None,
    autopct='%1.2f%%',
    textprops={'fontsize': 5},
    pctdistance=1.2,
    cmap=main_color_map
)
axis.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# #### Table 1 Chart 2 - Most called external packages in % by packages
#
# External packages that are used less than 0.7% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_package_by_package_usage_significant = group_to_others_below_threshold(
    data_frame=external_package_usage,
    value_column='numberOfExternalCallerPackages',
    name_column='externalPackageName',
    threshold= 0.7
);

# %%
plot.figure();

axis = external_package_by_package_usage_significant.plot(
    kind='pie',
    title='Top external package usage [%] by package',
    legend=True,
    labeldistance=None,
    autopct='%1.2f%%',
    textprops={'fontsize': 5},
    pctdistance=1.2,
    cmap=main_color_map
)
axis.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 2 - Top 20 most used external packages grouped by their first 2 layers
#
# This table shows external packages grouped by their first 2 layers that are used by the most different internal types overall including external annotations. For example, "javax.xml.stream" and "javax.xml.parsers" are grouped together to "javax.xml".
#
# Additionally, it shows which types of the external packages are actually used.
#
# Only the top 20 entries are shown. The whole table can be found in the following CSV report:
# `External_second_level_package_usage_overall`
#
# **Columns:**
# - *externalSecondLevelPackageName* identifies the first 2 levels of the external package as described above
# - *numberOfExternalCallerPackages* refers to the distinct packages that make use of the external package
# - *numberOfExternalCallerTypes* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every dependency to the types in the external package
# - *numberOfExternalTypeCallsWeighted* includes every invocation or reference (sum of weights) to the types in the external package
# - *allPackages* contains the total count of all analyzed packages in general
# - *allTypes* contains the total count of all analyzed types in general
# - *externalTypeNames* contains a list of actually utilized types of the external package

# %%
external_grouped_package_usage=query_cypher_to_data_frame("../cypher/External_Dependencies/External_second_level_package_usage_overall.cypher")
external_grouped_package_usage.head(20)
# Out:
#    externalSecondLevelPackageName  numberOfExternalCallerPackages  \
# 0                javax.annotation                              63
# 1                       org.slf4j                              53
# 2                   com.fasterxml                              14
# 3               javax.persistence                              13
# 4             jakarta.persistence                               8
# 5                    org.hamcrest                               5
# 6                      com.github                               2
# 7                com.thoughtworks                               2
# 8                     org.jobrunr                               2
# 9                       org.junit                               2
# 10                     org.quartz                               2
# 11                   reactor.core                               2
# 12                     com.google                               1
# 13                       com.lmax                               1
# 14             jakarta.validation                               1
# 15                    javax.cache                               1
# 16               javax.validation                               1
# 17                         net.sf                               1
# 18                         nu.xom                               1
# 19                      org.dom4j                               1
#
#     numberOfExternalCallerTypes  numberOfExternalTypeCalls  \
# 0                           310                        342
# 1                           117                        208
# 2                            30                         85
# 3                            24                         78
# 4                            22                         69
# 5                            27                         61
# 6                             6                         19
# 7                             8                         31
# 8                             4                          8
# 9                             4                          8
# 10                            9                         40
# 11                           18                         36
# 12                            1                          4
# 13                            7                         14
# 14                            2                          5
# 15                            2                         12
# 16                            2                          5
# 17                            2                          8
# 18                            3                          5
# 19                            3                          4
#
#     numberOfExternalTypeCallsWeighted  allPackages  allTypes  \
# 0                                1602           93      1224
# 1                                 608           93      1224
# 2                                 196           93      1224
# 3                                 340           93      1224
# 4                                 328           93      1224
# 5                                 498           93      1224
# 6                                 120           93      1224
# 7                                 135           93      1224
# 8                                  39           93      1224
# 9                                  18           93      1224
# 10                                234           93      1224
# 11                                159           93      1224
# 12                                  9           93      1224
# 13                                 51           93      1224
# 14                                 22           93      1224
# 15                                 59           93      1224
# 16                                 22           93      1224
# 17                                 72           93      1224
# 18                                 16           93      1224
# 19                                 15           93      1224
#
#                                  tenExternalTypeNames
# 0                     [Nonnull, Nullable, PreDestroy]
# 1                             [Logger, LoggerFactory]
# 2   [JsonCreator, JsonProperty, JsonTypeInfo, Json...
# 3   [LockModeType, EntityManager, GeneratedValue, ...
# 4   [EntityManager, LockModeType, EntityManagerFac...
# 5   [Matcher, StringDescription, Description, Core...
# 6   [Scheduler, TaskInstanceId, TaskInstance, Sche...
# 7   [MarshallingContext, Mapper, HierarchicalStrea...
# 8                   [JobScheduler, JobBuilder, JobId]
# 9   [Statement, TestRule, Description, AfterEachCa...
# 10  [SchedulerContext, JobExecutionContext, Trigge...
# 11  [Mono, Flux, Sinks$EmitResult, Sinks$Many, Sig...
# 12   [JsonObject, JsonElement, JsonParser, JsonArray]
# 13  [BlockingWaitStrategy, WaitStrategy, ProducerT...
# 14  [ConstraintViolation, Validation, ValidatorFac...
# 15  [CacheEntryCreatedListener, CacheEntryListener...
# 16  [Validation, Validator, ConstraintViolation, V...
# 17  [CacheException, Ehcache, Element, CacheEventL...
# 18              [Document, ParsingException, Builder]
# 19                        [Document, STAXEventReader]

# %% [markdown]
# #### Table 2 Chart 1 - Most called second level external packages in % by type
#
# External package groups that are used less than 0.7% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_grouped_package_by_type_usage_significant = group_to_others_below_threshold(
    data_frame=external_grouped_package_usage,
    value_column='numberOfExternalCallerTypes',
    name_column='externalSecondLevelPackageName',
    threshold= 0.7
);

plot.figure();

axis = external_grouped_package_by_type_usage_significant.plot(
    kind='pie',
    title='Top external package (grouped by first 2 layers) usage [%] by type',
    legend=True,
    labeldistance=None,
    autopct='%1.2f%%',
    textprops={'fontsize': 5},
    pctdistance=1.2,
    cmap=main_color_map
)
axis.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# #### Table 2 Chart 2 - Most called second level external packages in % by package
#
# External package groups that are used less than 0.7% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_grouped_package_by_package_usage_significant = group_to_others_below_threshold(
    data_frame=external_grouped_package_usage,
    value_column='numberOfExternalCallerPackages',
    name_column='externalSecondLevelPackageName',
    threshold= 0.7
);

plot.figure();
axis = external_grouped_package_by_package_usage_significant.plot(
    kind='pie',
    title='Top external package (grouped by first 2 layers) usage [%] by package',
    legend=True,
    labeldistance=None,
    autopct='%1.2f%%',
    textprops={'fontsize': 5},
    pctdistance=1.2,
    cmap=main_color_map
)
axis.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 3 - Top 20 most widely spread external packages
#
# The following tables shows external packages that are used by many different artifacts with the highest number of artifacts first. External annotations are filtered out to only get those external packages that significantly add to coupling.
#
# Statistics like minimum, maximum, average, median and standard deviation are provided for the number of packages and number of types in every artifact that uses the listed external package.
#
# The intuition behind that is to find external package dependencies that are used in a widely spread manner. This should uncover libraries and frameworks and make it easier to distinguish them from external dependencies that are used for specific tasks. It can also be used to find external dependencies that are used sparsely regarding artifacts but are used in many different packages there. This could then be improved by applying a [Hexagonal architecture](https://alistair.cockburn.us/hexagonal-architecture).
#
# Only the top 20 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_spread`
#
# **Columns:**
# - *externalPackageName* identifies the external package as defined above. All other columns contain aggregated data for this external package.
# - *numberOfArtifacts* contains the number of artifacts that use the external package
# - *sumNumberOfPackages* contains the sum of all packages that use the external package
# - *min/max/med/avg/stdNumberOfPackages* provide statistics based on the number of packages of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfPackagesPercentage* provide statistics in percent (%) based on the number of packages of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfTypes* provide statistics based on the number of types of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfPackagesPercentage* provide statistics in percent (%) based on the number of types of each artifact that uses the external package
# - *someArtifactNames* contain some of the artifacts that contain the external package for reference

# %%
# Query the graph database to provide the 
# most widely spread external dependencies for the tables/charts below.
external_package_usage_spread=query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_spread.cypher")
external_package_usage_spread.head(10)
# Out:
#                        externalPackageName  numberOfArtifacts  \
# 0                                org.slf4j                  6
# 1                      jakarta.persistence                  3
# 2                        javax.persistence                  3
# 3              AggregateEventPublisherImpl                  1
# 4                                WeakValue                  1
# 5         com.fasterxml.jackson.annotation                  1
# 6               com.fasterxml.jackson.core                  1
# 7           com.fasterxml.jackson.databind                  1
# 8  com.fasterxml.jackson.databind.jsontype                  1
# 9    com.fasterxml.jackson.databind.module                  1
#
#    sumNumberOfPackages  minNumberOfPackages  maxNumberOfPackages  \
# 0                   53                    1                   38
# 1                    6                    1                    3
# 2                    9                    2                    4
# 3                    1                    1                    1
# 4                    1                    1                    1
# 5                    3                    3                    3
# 6                    1                    1                    1
# 7                    1                    1                    1
# 8                    1                    1                    1
# 9                    1                    1                    1
#
#    medNumberOfPackages  avgNumberOfPackages  stdNumberOfPackages  \
# 0                  3.5             8.833333            14.441837
# 1                  2.0             2.000000             1.000000
# 2                  3.0             3.000000             1.000000
# 3                  1.0             1.000000             0.000000
# 4                  1.0             1.000000             0.000000
# 5                  3.0             3.000000             0.000000
# 6                  1.0             1.000000             0.000000
# 7                  1.0             1.000000             0.000000
# 8                  1.0             1.000000             0.000000
# 9                  1.0             1.000000             0.000000
#
#    minNumberOfPackagesPercentage  maxNumberOfPackagesPercentage  ...  \
# 0                        25.0000                       100.0000  ...
# 1                         4.6875                        20.0000  ...
# 2                         6.2500                        30.0000  ...
# 3                        12.5000                        12.5000  ...
# 4                       100.0000                       100.0000  ...
# 5                         4.6875                         4.6875  ...
# 6                         1.5625                         1.5625  ...
# 7                         1.5625                         1.5625  ...
# 8                         1.5625                         1.5625  ...
# 9                         1.5625                         1.5625  ...
#
#    maxNumberOfTypes  medNumberOfTypes  avgNumberOfTypes  stdNumberOfTypes  \
# 0                78               8.5         19.500000         28.925767
# 1                 8               3.0          4.666667          2.886751
# 2                 8               3.0          4.666667          2.886751
# 3                 1               1.0          1.000000          0.000000
# 4                 1               1.0          1.000000          0.000000
# 5                 5               5.0          5.000000          0.000000
# 6                 3               3.0          3.000000          0.000000
# 7                 7               7.0          7.000000          0.000000
# 8                 1               1.0          1.000000          0.000000
# 9                 1               1.0          1.000000          0.000000
#
#    minNumberOfTypesPercentage  maxNumberOfTypesPercentage  \
# 0                    2.298851                   36.363636
# 1                    1.017812                    2.255639
# 2                    1.017812                    2.255639
# 3                    1.149425                    1.149425
# 4                    4.545455                    4.545455
# 5                    0.636132                    0.636132
# 6                    0.381679                    0.381679
# 7                    0.890585                    0.890585
# 8                    0.127226                    0.127226
# 9                    0.127226                    0.127226
#
#    medNumberOfTypesPercentage  avgNumberOfTypesPercentage  \
# 0                   10.224990                   13.313616
# 1                    1.923077                    1.732176
# 2                    1.923077                    1.732176
# 3                    1.149425                    1.149425
# 4                    4.545455                    4.545455
# 5                    0.636132                    0.636132
# 6                    0.381679                    0.381679
# 7                    0.890585                    0.890585
# 8                    0.127226                    0.127226
# 9                    0.127226                    0.127226
#
#    stdNumberOfTypesPercentage  \
# 0                   12.096702
# 1                    0.640614
# 2                    0.640614
# 3                    0.000000
# 4                    0.000000
# 5                    0.000000
# 6                    0.000000
# 7                    0.000000
# 8                    0.000000
# 9                    0.000000
#
#                                    someArtifactNames
# 0  [axon-disruptor-4.9.1, axon-modelling-4.9.1, a...
# 1  [axon-modelling-4.9.1, axon-messaging-4.9.1, a...
# 2  [axon-modelling-4.9.1, axon-messaging-4.9.1, a...
# 3                                  [axon-test-4.9.1]
# 4                             [axon-disruptor-4.9.1]
# 5                             [axon-messaging-4.9.1]
# 6                             [axon-messaging-4.9.1]
# 7                             [axon-messaging-4.9.1]
# 8                             [axon-messaging-4.9.1]
# 9                             [axon-messaging-4.9.1]
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Table 3a - Top 20 most widely spread external packages - number of internal packages
#
# This table shows the top 20 most widely spread external packages focussing on the spread across the number of internal packages.

# %%
external_package_usage_spread_packages=external_package_usage_spread[['externalPackageName', 'numberOfArtifacts', 'minNumberOfPackages', 'maxNumberOfPackages', 'medNumberOfPackages', 'avgNumberOfPackages', 'stdNumberOfPackages']]
external_package_usage_spread_packages.head(20)
# Out:
#                              externalPackageName  numberOfArtifacts  \
# 0                                      org.slf4j                  6
# 1                            jakarta.persistence                  3
# 2                              javax.persistence                  3
# 3                    AggregateEventPublisherImpl                  1
# 4                                      WeakValue                  1
# 5               com.fasterxml.jackson.annotation                  1
# 6                     com.fasterxml.jackson.core                  1
# 7                 com.fasterxml.jackson.databind                  1
# 8        com.fasterxml.jackson.databind.jsontype                  1
# 9          com.fasterxml.jackson.databind.module                  1
# 10           com.fasterxml.jackson.databind.node                  1
# 11           com.fasterxml.jackson.databind.type                  1
# 12         com.fasterxml.jackson.datatype.jsr310                  1
# 13              com.github.kagkarlsson.scheduler                  1
# 14         com.github.kagkarlsson.scheduler.task                  1
# 15  com.github.kagkarlsson.scheduler.task.helper                  1
# 16                               com.google.gson                  1
# 17                            com.lmax.disruptor                  1
# 18                        com.lmax.disruptor.dsl                  1
# 19                      com.thoughtworks.xstream                  1
#
#     minNumberOfPackages  maxNumberOfPackages  medNumberOfPackages  \
# 0                     1                   38                  3.5
# 1                     1                    3                  2.0
# 2                     2                    4                  3.0
# 3                     1                    1                  1.0
# 4                     1                    1                  1.0
# 5                     3                    3                  3.0
# 6                     1                    1                  1.0
# 7                     1                    1                  1.0
# 8                     1                    1                  1.0
# 9                     1                    1                  1.0
# 10                    1                    1                  1.0
# 11                    1                    1                  1.0
# 12                    1                    1                  1.0
# 13                    2                    2                  2.0
# 14                    2                    2                  2.0
# 15                    2                    2                  2.0
# 16                    1                    1                  1.0
# 17                    1                    1                  1.0
# 18                    1                    1                  1.0
# 19                    2                    2                  2.0
#
#     avgNumberOfPackages  stdNumberOfPackages
# 0              8.833333            14.441837
# 1              2.000000             1.000000
# 2              3.000000             1.000000
# 3              1.000000             0.000000
# 4              1.000000             0.000000
# 5              3.000000             0.000000
# 6              1.000000             0.000000
# 7              1.000000             0.000000
# 8              1.000000             0.000000
# 9              1.000000             0.000000
# 10             1.000000             0.000000
# 11             1.000000             0.000000
# 12             1.000000             0.000000
# 13             2.000000             0.000000
# 14             2.000000             0.000000
# 15             2.000000             0.000000
# 16             1.000000             0.000000
# 17             1.000000             0.000000
# 18             1.000000             0.000000
# 19             2.000000             0.000000

# %% [markdown]
# ### Table 3b - Top 20 most widely spread external packages - percentage of internal packages
#
# This table shows the top 20 most widely spread external packages focussing on the spread across the percentage of internal packages.

# %%
external_package_usage_spread_packages_percentage=external_package_usage_spread[['externalPackageName', 'numberOfArtifacts', 'minNumberOfPackagesPercentage', 'maxNumberOfPackagesPercentage', 'medNumberOfPackagesPercentage', 'avgNumberOfPackagesPercentage', 'stdNumberOfPackagesPercentage']]
external_package_usage_spread_packages_percentage.head(20)
# Out:
#                              externalPackageName  numberOfArtifacts  \
# 0                                      org.slf4j                  6
# 1                            jakarta.persistence                  3
# 2                              javax.persistence                  3
# 3                    AggregateEventPublisherImpl                  1
# 4                                      WeakValue                  1
# 5               com.fasterxml.jackson.annotation                  1
# 6                     com.fasterxml.jackson.core                  1
# 7                 com.fasterxml.jackson.databind                  1
# 8        com.fasterxml.jackson.databind.jsontype                  1
# 9          com.fasterxml.jackson.databind.module                  1
# 10           com.fasterxml.jackson.databind.node                  1
# 11           com.fasterxml.jackson.databind.type                  1
# 12         com.fasterxml.jackson.datatype.jsr310                  1
# 13              com.github.kagkarlsson.scheduler                  1
# 14         com.github.kagkarlsson.scheduler.task                  1
# 15  com.github.kagkarlsson.scheduler.task.helper                  1
# 16                               com.google.gson                  1
# 17                            com.lmax.disruptor                  1
# 18                        com.lmax.disruptor.dsl                  1
# 19                      com.thoughtworks.xstream                  1
#
#     minNumberOfPackagesPercentage  maxNumberOfPackagesPercentage  \
# 0                         25.0000                       100.0000
# 1                          4.6875                        20.0000
# 2                          6.2500                        30.0000
# 3                         12.5000                        12.5000
# 4                        100.0000                       100.0000
# 5                          4.6875                         4.6875
# 6                          1.5625                         1.5625
# 7                          1.5625                         1.5625
# 8                          1.5625                         1.5625
# 9                          1.5625                         1.5625
# 10                         1.5625                         1.5625
# 11                         1.5625                         1.5625
# 12                         1.5625                         1.5625
# 13                         3.1250                         3.1250
# 14                         3.1250                         3.1250
# 15                         3.1250                         3.1250
# 16                        12.5000                        12.5000
# 17                       100.0000                       100.0000
# 18                       100.0000                       100.0000
# 19                         3.1250                         3.1250
#
#     medNumberOfPackagesPercentage  avgNumberOfPackagesPercentage  \
# 0                       59.687500                      66.655093
# 1                       11.111111                      11.932870
# 2                       22.222222                      19.490741
# 3                       12.500000                      12.500000
# 4                      100.000000                     100.000000
# 5                        4.687500                       4.687500
# 6                        1.562500                       1.562500
# 7                        1.562500                       1.562500
# 8                        1.562500                       1.562500
# 9                        1.562500                       1.562500
# 10                       1.562500                       1.562500
# 11                       1.562500                       1.562500
# 12                       1.562500                       1.562500
# 13                       3.125000                       3.125000
# 14                       3.125000                       3.125000
# 15                       3.125000                       3.125000
# 16                      12.500000                      12.500000
# 17                     100.000000                     100.000000
# 18                     100.000000                     100.000000
# 19                       3.125000                       3.125000
#
#     stdNumberOfPackagesPercentage
# 0                       28.911597
# 1                        7.689254
# 2                       12.108318
# 3                        0.000000
# 4                        0.000000
# 5                        0.000000
# 6                        0.000000
# 7                        0.000000
# 8                        0.000000
# 9                        0.000000
# 10                       0.000000
# 11                       0.000000
# 12                       0.000000
# 13                       0.000000
# 14                       0.000000
# 15                       0.000000
# 16                       0.000000
# 17                       0.000000
# 18                       0.000000
# 19                       0.000000

# %% [markdown]
# ### Table 3c - Top 20 most widely spread external packages - number of internal types
#
# This table shows the top 20 most widely spread external packages focussing on the spread across the number of internal types.

# %%
external_package_usage_spread_types=external_package_usage_spread[['externalPackageName', 'numberOfArtifacts', 'minNumberOfTypes', 'maxNumberOfTypes', 'medNumberOfTypes', 'avgNumberOfTypes', 'stdNumberOfTypes']]
external_package_usage_spread_types.head(20)
# Out:
#                              externalPackageName  numberOfArtifacts  \
# 0                                      org.slf4j                  6
# 1                            jakarta.persistence                  3
# 2                              javax.persistence                  3
# 3                    AggregateEventPublisherImpl                  1
# 4                                      WeakValue                  1
# 5               com.fasterxml.jackson.annotation                  1
# 6                     com.fasterxml.jackson.core                  1
# 7                 com.fasterxml.jackson.databind                  1
# 8        com.fasterxml.jackson.databind.jsontype                  1
# 9          com.fasterxml.jackson.databind.module                  1
# 10           com.fasterxml.jackson.databind.node                  1
# 11           com.fasterxml.jackson.databind.type                  1
# 12         com.fasterxml.jackson.datatype.jsr310                  1
# 13              com.github.kagkarlsson.scheduler                  1
# 14         com.github.kagkarlsson.scheduler.task                  1
# 15  com.github.kagkarlsson.scheduler.task.helper                  1
# 16                               com.google.gson                  1
# 17                            com.lmax.disruptor                  1
# 18                        com.lmax.disruptor.dsl                  1
# 19                      com.thoughtworks.xstream                  1
#
#     minNumberOfTypes  maxNumberOfTypes  medNumberOfTypes  avgNumberOfTypes  \
# 0                  2                78               8.5         19.500000
# 1                  3                 8               3.0          4.666667
# 2                  3                 8               3.0          4.666667
# 3                  1                 1               1.0          1.000000
# 4                  1                 1               1.0          1.000000
# 5                  5                 5               5.0          5.000000
# 6                  3                 3               3.0          3.000000
# 7                  7                 7               7.0          7.000000
# 8                  1                 1               1.0          1.000000
# 9                  1                 1               1.0          1.000000
# 10                 2                 2               2.0          2.000000
# 11                 3                 3               3.0          3.000000
# 12                 1                 1               1.0          1.000000
# 13                 4                 4               4.0          4.000000
# 14                 4                 4               4.0          4.000000
# 15                 2                 2               2.0          2.000000
# 16                 1                 1               1.0          1.000000
# 17                 7                 7               7.0          7.000000
# 18                 4                 4               4.0          4.000000
# 19                 4                 4               4.0          4.000000
#
#     stdNumberOfTypes
# 0          28.925767
# 1           2.886751
# 2           2.886751
# 3           0.000000
# 4           0.000000
# 5           0.000000
# 6           0.000000
# 7           0.000000
# 8           0.000000
# 9           0.000000
# 10          0.000000
# 11          0.000000
# 12          0.000000
# 13          0.000000
# 14          0.000000
# 15          0.000000
# 16          0.000000
# 17          0.000000
# 18          0.000000
# 19          0.000000

# %% [markdown]
# ### Table 3d - Top 20 most widely spread external packages - percentage of internal types
#
# This table shows the top 20 most widely spread external packages focussing on the spread across the percentage of internal types.

# %%
external_package_usage_spread_types_percentage=external_package_usage_spread[['externalPackageName', 'numberOfArtifacts', 'minNumberOfTypesPercentage', 'maxNumberOfTypesPercentage', 'medNumberOfTypesPercentage', 'avgNumberOfTypesPercentage', 'stdNumberOfTypesPercentage']]
external_package_usage_spread_types_percentage.head(20)
# Out:
#                              externalPackageName  numberOfArtifacts  \
# 0                                      org.slf4j                  6
# 1                            jakarta.persistence                  3
# 2                              javax.persistence                  3
# 3                    AggregateEventPublisherImpl                  1
# 4                                      WeakValue                  1
# 5               com.fasterxml.jackson.annotation                  1
# 6                     com.fasterxml.jackson.core                  1
# 7                 com.fasterxml.jackson.databind                  1
# 8        com.fasterxml.jackson.databind.jsontype                  1
# 9          com.fasterxml.jackson.databind.module                  1
# 10           com.fasterxml.jackson.databind.node                  1
# 11           com.fasterxml.jackson.databind.type                  1
# 12         com.fasterxml.jackson.datatype.jsr310                  1
# 13              com.github.kagkarlsson.scheduler                  1
# 14         com.github.kagkarlsson.scheduler.task                  1
# 15  com.github.kagkarlsson.scheduler.task.helper                  1
# 16                               com.google.gson                  1
# 17                            com.lmax.disruptor                  1
# 18                        com.lmax.disruptor.dsl                  1
# 19                      com.thoughtworks.xstream                  1
#
#     minNumberOfTypesPercentage  maxNumberOfTypesPercentage  \
# 0                     2.298851                   36.363636
# 1                     1.017812                    2.255639
# 2                     1.017812                    2.255639
# 3                     1.149425                    1.149425
# 4                     4.545455                    4.545455
# 5                     0.636132                    0.636132
# 6                     0.381679                    0.381679
# 7                     0.890585                    0.890585
# 8                     0.127226                    0.127226
# 9                     0.127226                    0.127226
# 10                    0.254453                    0.254453
# 11                    0.381679                    0.381679
# 12                    0.127226                    0.127226
# 13                    0.508906                    0.508906
# 14                    0.508906                    0.508906
# 15                    0.254453                    0.254453
# 16                    1.149425                    1.149425
# 17                   31.818182                   31.818182
# 18                   18.181818                   18.181818
# 19                    0.508906                    0.508906
#
#     medNumberOfTypesPercentage  avgNumberOfTypesPercentage  \
# 0                    10.224990                   13.313616
# 1                     1.923077                    1.732176
# 2                     1.923077                    1.732176
# 3                     1.149425                    1.149425
# 4                     4.545455                    4.545455
# 5                     0.636132                    0.636132
# 6                     0.381679                    0.381679
# 7                     0.890585                    0.890585
# 8                     0.127226                    0.127226
# 9                     0.127226                    0.127226
# 10                    0.254453                    0.254453
# 11                    0.381679                    0.381679
# 12                    0.127226                    0.127226
# 13                    0.508906                    0.508906
# 14                    0.508906                    0.508906
# 15                    0.254453                    0.254453
# 16                    1.149425                    1.149425
# 17                   31.818182                   31.818182
# 18                   18.181818                   18.181818
# 19                    0.508906                    0.508906
#
#     stdNumberOfTypesPercentage
# 0                    12.096702
# 1                     0.640614
# 2                     0.640614
# 3                     0.000000
# 4                     0.000000
# 5                     0.000000
# 6                     0.000000
# 7                     0.000000
# 8                     0.000000
# 9                     0.000000
# 10                    0.000000
# 11                    0.000000
# 12                    0.000000
# 13                    0.000000
# 14                    0.000000
# 15                    0.000000
# 16                    0.000000
# 17                    0.000000
# 18                    0.000000
# 19                    0.000000

# %% [markdown]
# #### Table 3 Chart 1 - Most widely spread external packages in % by types
#
# External packages that are used less than 0.5% are grouped into the name "others" to get a cleaner chart with the most significant external packages.

# %%
external_package_type_usage_spread_significant = group_to_others_below_threshold(
    data_frame=external_package_usage_spread,
    value_column='sumNumberOfTypes',
    name_column='externalPackageName',
    threshold= 0.5
);

plot.figure();
axis = external_package_type_usage_spread_significant.plot(
    kind='pie',
    title='Top external package usage spread [%] by type',
    legend=True,
    labeldistance=None,
    autopct='%1.2f%%',
    textprops={'fontsize': 5},
    pctdistance=1.2,
    cmap=main_color_map
)
axis.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# #### Table 3 Chart 2 - Most widely spread external packages in % by packages
#
# External packages that are used less than 0.5% are grouped into the name "others" to get a cleaner chart with the most significant external packages.

# %%
external_package_usage_package_spread_significant = group_to_others_below_threshold(
    data_frame=external_package_usage_spread,
    value_column='sumNumberOfPackages',
    name_column='externalPackageName',
    threshold= 0.5
);

plot.figure();
axis = external_package_usage_package_spread_significant.plot(
    kind='pie',
    title='Top external package usage spread [%] by package',
    legend=True,
    labeldistance=None,
    autopct='%1.2f%%',
    textprops={'fontsize': 5},
    pctdistance=1.2,
    cmap=main_color_map
)
axis.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 4 - Top 20 most widely spread external packages grouped by their first 2 layers
#
# This table shows external packages grouped by their first 2 layers that are used by many different artifacts with the highest number of artifacts first. External annotations are filtered out to only get those external packages that significantly add to coupling.
#
# Statistics like minimum, maximum, average, median and standard deviation are provided for the number of packages and number of types in every artifact that uses the listed external package.
#
# The intuition behind that is to find external package dependencies that are used in a widely spread manner. This should uncover libraries and frameworks and make it easier to distinguish them from external dependencies that are used for specific tasks. It can also be used to find external dependencies that are used sparsely regarding artifacts but are used in many different packages there. This could then be improved by applying a [Hexagonal architecture](https://alistair.cockburn.us/hexagonal-architecture).
#
# Only the top 20 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_spread`
#
# **Columns:**
# - *externalPackageName* identifies the external package as defined above. All other columns contain aggregated data for this external package.
# - *numberOfArtifacts* contains the number of artifacts that use the external package
# - *sumNumberOfPackages* contains the sum of all packages that use the external package
# - *min/max/med/avg/stdNumberOfPackages* provide statistics based on the number of packages of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfPackagesPercentage* provide statistics in percent (%) based on the number of packages of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfTypes* provide statistics based on the number of types of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfPackagesPercentage* provide statistics in percent (%) based on the number of types of each artifact that uses the external package
# - *someArtifactNames* contain some of the artifacts that contain the external package for reference

# %%
external_grouped_package_usage_spread=query_cypher_to_data_frame("../cypher/External_Dependencies/External_second_level_package_usage_spread.cypher")
external_grouped_package_usage_spread.head(20)
# Out:
#    externalSecondLevelPackageName  numberOfArtifacts  sumNumberOfPackages  \
# 0                       org.slf4j                  6                   53
# 1             jakarta.persistence                  3                    6
# 2               javax.persistence                  3                    9
# 3     AggregateEventPublisherImpl                  1                    1
# 4                       WeakValue                  1                    1
# 5                   com.fasterxml                  1                    4
# 6                      com.github                  1                    2
# 7                      com.google                  1                    1
# 8                        com.lmax                  1                    1
# 9                com.thoughtworks                  1                    2
# 10             jakarta.validation                  1                    1
# 11                    javax.cache                  1                    1
# 12               javax.validation                  1                    1
# 13                         net.sf                  1                    1
# 14                         nu.xom                  1                    1
# 15                      org.dom4j                  1                    1
# 16                    org.ehcache                  1                    1
# 17                   org.hamcrest                  1                    5
# 18                    org.jobrunr                  1                    2
# 19                      org.junit                  1                    2
#
#     minNumberOfPackages  maxNumberOfPackages  medNumberOfPackages  \
# 0                     1                   38                  3.5
# 1                     1                    3                  2.0
# 2                     2                    4                  3.0
# 3                     1                    1                  1.0
# 4                     1                    1                  1.0
# 5                     4                    4                  4.0
# 6                     2                    2                  2.0
# 7                     1                    1                  1.0
# 8                     1                    1                  1.0
# 9                     2                    2                  2.0
# 10                    1                    1                  1.0
# 11                    1                    1                  1.0
# 12                    1                    1                  1.0
# 13                    1                    1                  1.0
# 14                    1                    1                  1.0
# 15                    1                    1                  1.0
# 16                    1                    1                  1.0
# 17                    5                    5                  5.0
# 18                    2                    2                  2.0
# 19                    2                    2                  2.0
#
#     avgNumberOfPackages  stdNumberOfPackages  minNumberOfPackagesPercentage  \
# 0              8.833333            14.441837                        25.0000
# 1              2.000000             1.000000                         4.6875
# 2              3.000000             1.000000                         6.2500
# 3              1.000000             0.000000                        12.5000
# 4              1.000000             0.000000                       100.0000
# 5              4.000000             0.000000                         6.2500
# 6              2.000000             0.000000                         3.1250
# 7              1.000000             0.000000                        12.5000
# 8              1.000000             0.000000                       100.0000
# 9              2.000000             0.000000                         3.1250
# 10             1.000000             0.000000                         1.5625
# 11             1.000000             0.000000                         1.5625
# 12             1.000000             0.000000                         1.5625
# 13             1.000000             0.000000                         1.5625
# 14             1.000000             0.000000                         1.5625
# 15             1.000000             0.000000                         1.5625
# 16             1.000000             0.000000                         1.5625
# 17             5.000000             0.000000                        62.5000
# 18             2.000000             0.000000                         3.1250
# 19             2.000000             0.000000                        25.0000
#
#     maxNumberOfPackagesPercentage  ...  maxNumberOfTypes  medNumberOfTypes  \
# 0                        100.0000  ...                78               8.5
# 1                         20.0000  ...                 8               3.0
# 2                         30.0000  ...                 8               3.0
# 3                         12.5000  ...                 1               1.0
# 4                        100.0000  ...                 1               1.0
# 5                          6.2500  ...                12              12.0
# 6                          3.1250  ...                 6               6.0
# 7                         12.5000  ...                 1               1.0
# 8                        100.0000  ...                 7               7.0
# 9                          3.1250  ...                 8               8.0
# 10                         1.5625  ...                 2               2.0
# 11                         1.5625  ...                 2               2.0
# 12                         1.5625  ...                 2               2.0
# 13                         1.5625  ...                 2               2.0
# 14                         1.5625  ...                 3               3.0
# 15                         1.5625  ...                 3               3.0
# 16                         1.5625  ...                 3               3.0
# 17                        62.5000  ...                27              27.0
# 18                         3.1250  ...                 4               4.0
# 19                        25.0000  ...                 4               4.0
#
#     avgNumberOfTypes  stdNumberOfTypes  minNumberOfTypesPercentage  \
# 0          19.500000         28.925767                    2.298851
# 1           4.666667          2.886751                    1.017812
# 2           4.666667          2.886751                    1.017812
# 3           1.000000          0.000000                    1.149425
# 4           1.000000          0.000000                    4.545455
# 5          12.000000          0.000000                    1.526718
# 6           6.000000          0.000000                    0.763359
# 7           1.000000          0.000000                    1.149425
# 8           7.000000          0.000000                   31.818182
# 9           8.000000          0.000000                    1.017812
# 10          2.000000          0.000000                    0.254453
# 11          2.000000          0.000000                    0.254453
# 12          2.000000          0.000000                    0.254453
# 13          2.000000          0.000000                    0.254453
# 14          3.000000          0.000000                    0.381679
# 15          3.000000          0.000000                    0.381679
# 16          3.000000          0.000000                    0.381679
# 17         27.000000          0.000000                   31.034483
# 18          4.000000          0.000000                    0.508906
# 19          4.000000          0.000000                    4.597701
#
#     maxNumberOfTypesPercentage  medNumberOfTypesPercentage  \
# 0                    36.363636                   10.224990
# 1                     2.255639                    1.923077
# 2                     2.255639                    1.923077
# 3                     1.149425                    1.149425
# 4                     4.545455                    4.545455
# 5                     1.526718                    1.526718
# 6                     0.763359                    0.763359
# 7                     1.149425                    1.149425
# 8                    31.818182                   31.818182
# 9                     1.017812                    1.017812
# 10                    0.254453                    0.254453
# 11                    0.254453                    0.254453
# 12                    0.254453                    0.254453
# 13                    0.254453                    0.254453
# 14                    0.381679                    0.381679
# 15                    0.381679                    0.381679
# 16                    0.381679                    0.381679
# 17                   31.034483                   31.034483
# 18                    0.508906                    0.508906
# 19                    4.597701                    4.597701
#
#     avgNumberOfTypesPercentage  stdNumberOfTypesPercentage  \
# 0                    13.313616                   12.096702
# 1                     1.732176                    0.640614
# 2                     1.732176                    0.640614
# 3                     1.149425                    0.000000
# 4                     4.545455                    0.000000
# 5                     1.526718                    0.000000
# 6                     0.763359                    0.000000
# 7                     1.149425                    0.000000
# 8                    31.818182                    0.000000
# 9                     1.017812                    0.000000
# 10                    0.254453                    0.000000
# 11                    0.254453                    0.000000
# 12                    0.254453                    0.000000
# 13                    0.254453                    0.000000
# 14                    0.381679                    0.000000
# 15                    0.381679                    0.000000
# 16                    0.381679                    0.000000
# 17                   31.034483                    0.000000
# 18                    0.508906                    0.000000
# 19                    4.597701                    0.000000
#
#                                     someArtifactNames
# 0   [axon-disruptor-4.9.1, axon-modelling-4.9.1, a...
# 1   [axon-modelling-4.9.1, axon-messaging-4.9.1, a...
# 2   [axon-modelling-4.9.1, axon-messaging-4.9.1, a...
# 3                                   [axon-test-4.9.1]
# 4                              [axon-disruptor-4.9.1]
# 5                              [axon-messaging-4.9.1]
# 6                              [axon-messaging-4.9.1]
# 7                                   [axon-test-4.9.1]
# 8                              [axon-disruptor-4.9.1]
# 9                              [axon-messaging-4.9.1]
# 10                             [axon-messaging-4.9.1]
# 11                             [axon-messaging-4.9.1]
# 12                             [axon-messaging-4.9.1]
# 13                             [axon-messaging-4.9.1]
# 14                             [axon-messaging-4.9.1]
# 15                             [axon-messaging-4.9.1]
# 16                             [axon-messaging-4.9.1]
# 17                                  [axon-test-4.9.1]
# 18                             [axon-messaging-4.9.1]
# 19                                  [axon-test-4.9.1]
#
# [20 rows x 25 columns]

# %% [markdown]
# #### Table 4 Chart 1 - Most widely spread second level external packages in % by type
#
# External package groups that are used less than 0.5% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_grouped_package_type_usage_spread_significant = group_to_others_below_threshold(
    data_frame=external_grouped_package_usage_spread,
    value_column='sumNumberOfTypes',
    name_column='externalSecondLevelPackageName',
    threshold= 0.5
);

plot.figure();

axis = external_grouped_package_type_usage_spread_significant.plot(
    kind='pie',
    title='Top external package (grouped by first 2 layers) usage spread [%] by type',
    legend=True,
    labeldistance=None,
    autopct='%1.2f%%',
    textprops={'fontsize': 5},
    pctdistance=1.2,
    cmap=main_color_map
)
axis.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# #### Table 4 Chart 2 - Most widely spread second level external packages in % by package
#
# External package groups that are used less than 0.5% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_grouped_package_package_usage_spread_significant = group_to_others_below_threshold(
    data_frame=external_grouped_package_usage_spread,
    value_column='sumNumberOfPackages',
    name_column='externalSecondLevelPackageName',
    threshold= 0.5
);

plot.figure();

axis = external_grouped_package_package_usage_spread_significant.plot(
    kind='pie',
    title='Top external package (grouped by first 2 layers) usage spread [%] by package',
    legend=True,
    labeldistance=None,
    autopct='%1.2f%%',
    textprops={'fontsize': 5},
    pctdistance=1.2,
    cmap=main_color_map
)
axis.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 5 - Top 20 least used external packages overall
#
# This table identifies external packages that aren't used very often. This could help to find libraries that aren't actually needed or maybe easily replaceable. Some of them might be used sparsely on purpose for example as an adapter to an external library that is actually important. Thus, decisions need to be made on a case-by-case basis.
#
# Only the last 20 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_overall`
#
# **Columns:**
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package

# %%
# Sort by number of external type calls
external_package_least_used=external_package_usage.sort_values(by='numberOfExternalTypeCalls', ascending=True)

# Reset index
external_package_least_used = external_package_least_used.reset_index(drop=True)

# Select columns and only show the first 10 entries (head)
external_package_least_used[['externalPackageName','numberOfExternalTypeCalls']].head(20)
# Out:
#                             externalPackageName  numberOfExternalTypeCalls
# 0               org.junit.jupiter.api.extension                          3
# 1                          net.sf.ehcache.event                          3
# 2           com.fasterxml.jackson.databind.node                          3
# 3                     javax.cache.configuration                          3
# 4                 org.testcontainers.containers                          4
# 5   org.testcontainers.containers.wait.strategy                          4
# 6                               com.google.gson                          4
# 7                    com.fasterxml.jackson.core                          4
# 8               com.thoughtworks.xstream.io.xml                          4
# 9                    org.testcontainers.utility                          5
# 10                       com.lmax.disruptor.dsl                          5
# 11                           jakarta.validation                          5
# 12              com.thoughtworks.xstream.mapper                          5
# 13                             javax.validation                          5
# 14                               net.sf.ehcache                          5
# 15                                       nu.xom                          5
# 16          com.thoughtworks.xstream.converters                          6
# 17                       org.jobrunr.scheduling                          6
# 18             com.github.kagkarlsson.scheduler                          7
# 19                            org.ehcache.event                          8

# %% [markdown]
# ### Table 6 - External usage per artifact sorted by highest external type rate descending
#
# The following table shows the most used external packages separately for each artifact including external annotations. The results are sorted by the artifacts with the highest external type usage rate descending.
#
# The intention of this table is to find artifacts that use a lot of external dependencies in relation to their size and get all the external packages and their usage.
#
# Only the last 40 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_sorted`
#
# **Columns:**
# - *artifactName* is used to group the the external package usage per artifact for a more detailed analysis.
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalTypeCaller* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfTypesInArtifact* represents the total count of all analyzed types for the artifact
# - *numberOfExternalTypesInArtifact* is the number of all external types that are used by the artifact
# - *numberOfExternalPackagesInArtifact* is the number of all external packages that are used by the artifact
# - *externalTypeRate* is the numberOfExternalTypesInArtifact / numberOfTypesInArtifact * 100
# - *externalTypeNames* contains a list of actually utilized types of the external package

# %%
query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_sorted.cypher").head(40)
# Out:
#             artifactName                          externalPackageName  \
# 0   axon-disruptor-4.9.1                                    org.slf4j
# 1   axon-disruptor-4.9.1                           com.lmax.disruptor
# 2   axon-disruptor-4.9.1                             javax.annotation
# 3   axon-disruptor-4.9.1                       com.lmax.disruptor.dsl
# 4   axon-disruptor-4.9.1                                    WeakValue
# 5        axon-test-4.9.1                                 org.hamcrest
# 6        axon-test-4.9.1                             javax.annotation
# 7        axon-test-4.9.1                   org.testcontainers.utility
# 8        axon-test-4.9.1                              com.google.gson
# 9        axon-test-4.9.1                                    org.slf4j
# 10       axon-test-4.9.1                org.testcontainers.containers
# 11       axon-test-4.9.1  org.testcontainers.containers.wait.strategy
# 12       axon-test-4.9.1              org.junit.jupiter.api.extension
# 13       axon-test-4.9.1                      org.junit.runners.model
# 14       axon-test-4.9.1                  AggregateEventPublisherImpl
# 15       axon-test-4.9.1                        org.junit.jupiter.api
# 16       axon-test-4.9.1                              org.junit.rules
# 17       axon-test-4.9.1                             org.junit.runner
# 18  axon-modelling-4.9.1                             javax.annotation
# 19  axon-modelling-4.9.1                            javax.persistence
# 20  axon-modelling-4.9.1                          jakarta.persistence
# 21  axon-modelling-4.9.1                                    org.slf4j
# 22  axon-modelling-4.9.1             com.fasterxml.jackson.annotation
# 23  axon-messaging-4.9.1                             javax.annotation
# 24  axon-messaging-4.9.1                                    org.slf4j
# 25  axon-messaging-4.9.1             com.fasterxml.jackson.annotation
# 26  axon-messaging-4.9.1                            javax.persistence
# 27  axon-messaging-4.9.1                          jakarta.persistence
# 28  axon-messaging-4.9.1                                   org.quartz
# 29  axon-messaging-4.9.1                       reactor.core.publisher
# 30  axon-messaging-4.9.1               com.fasterxml.jackson.databind
# 31  axon-messaging-4.9.1                          org.reactivestreams
# 32  axon-messaging-4.9.1        com.github.kagkarlsson.scheduler.task
# 33  axon-messaging-4.9.1                  com.thoughtworks.xstream.io
# 34  axon-messaging-4.9.1                            javax.cache.event
# 35  axon-messaging-4.9.1                            org.ehcache.event
# 36  axon-messaging-4.9.1             com.github.kagkarlsson.scheduler
# 37  axon-messaging-4.9.1          com.thoughtworks.xstream.converters
# 38  axon-messaging-4.9.1                       org.jobrunr.scheduling
# 39  axon-messaging-4.9.1              com.thoughtworks.xstream.mapper
#
#     numberOfExternalTypeCaller  numberOfExternalTypeCalls  \
# 0                           12                         22
# 1                            9                         29
# 2                            6                         23
# 3                            5                         22
# 4                            1                          5
# 5                           61                        498
# 6                           10                         52
# 7                            5                         27
# 8                            4                          9
# 9                            4                         13
# 10                           4                         15
# 11                           4                          5
# 12                           3                          6
# 13                           2                          8
# 14                           1                          2
# 15                           1                          1
# 16                           1                          1
# 17                           1                          2
# 18                          37                        132
# 19                          23                         96
# 20                          18                         90
# 21                          17                         58
# 22                           4                          6
# 23                         247                       1191
# 24                         141                        440
# 25                          53                         81
# 26                          44                        194
# 27                          40                        188
# 28                          39                        232
# 29                          35                        157
# 30                          15                         73
# 31                          13                         41
# 32                          10                         52
# 33                           9                         46
# 34                           8                         34
# 35                           8                         33
# 36                           7                         54
# 37                           6                         12
# 38                           6                         37
# 39                           5                         10
#
#     numberOfTypesInArtifact  numberOfExternalTypesInArtifact  \
# 0                        22                               13
# 1                        22                               13
# 2                        22                               13
# 3                        22                               13
# 4                        22                               13
# 5                        87                               28
# 6                        87                               28
# 7                        87                               28
# 8                        87                               28
# 9                        87                               28
# 10                       87                               28
# 11                       87                               28
# 12                       87                               28
# 13                       87                               28
# 14                       87                               28
# 15                       87                               28
# 16                       87                               28
# 17                       87                               28
# 18                      156                               35
# 19                      156                               35
# 20                      156                               35
# 21                      156                               35
# 22                      156                               35
# 23                      786                              155
# 24                      786                              155
# 25                      786                              155
# 26                      786                              155
# 27                      786                              155
# 28                      786                              155
# 29                      786                              155
# 30                      786                              155
# 31                      786                              155
# 32                      786                              155
# 33                      786                              155
# 34                      786                              155
# 35                      786                              155
# 36                      786                              155
# 37                      786                              155
# 38                      786                              155
# 39                      786                              155
#
#     numberOfExternalPackagesInArtifact  externalTypeRate  \
# 0                                    5         59.090909
# 1                                    5         59.090909
# 2                                    5         59.090909
# 3                                    5         59.090909
# 4                                    5         59.090909
# 5                                   13         32.183908
# 6                                   13         32.183908
# 7                                   13         32.183908
# 8                                   13         32.183908
# 9                                   13         32.183908
# 10                                  13         32.183908
# 11                                  13         32.183908
# 12                                  13         32.183908
# 13                                  13         32.183908
# 14                                  13         32.183908
# 15                                  13         32.183908
# 16                                  13         32.183908
# 17                                  13         32.183908
# 18                                   5         22.435897
# 19                                   5         22.435897
# 20                                   5         22.435897
# 21                                   5         22.435897
# 22                                   5         22.435897
# 23                                  43         19.720102
# 24                                  43         19.720102
# 25                                  43         19.720102
# 26                                  43         19.720102
# 27                                  43         19.720102
# 28                                  43         19.720102
# 29                                  43         19.720102
# 30                                  43         19.720102
# 31                                  43         19.720102
# 32                                  43         19.720102
# 33                                  43         19.720102
# 34                                  43         19.720102
# 35                                  43         19.720102
# 36                                  43         19.720102
# 37                                  43         19.720102
# 38                                  43         19.720102
# 39                                  43         19.720102
#
#                                     externalTypeNames
# 0                             [Logger, LoggerFactory]
# 1   [RingBuffer, EventHandler, LifecycleAware, Blo...
# 2                                           [Nonnull]
# 3        [Disruptor, EventHandlerGroup, ProducerType]
# 4                                         [WeakValue]
# 5   [StringDescription, Matcher, Description, Type...
# 6                                           [Nonnull]
# 7                    [DockerImageName, MountableFile]
# 8    [JsonObject, JsonElement, JsonParser, JsonArray]
# 9                             [Logger, LoggerFactory]
# 10       [GenericContainer, ContainerLaunchException]
# 11                           [Wait, HttpWaitStrategy]
# 12  [AfterEachCallback, ExtensionContext, BeforeEa...
# 13                                        [Statement]
# 14                      [AggregateEventPublisherImpl]
# 15                                       [Assertions]
# 16                                         [TestRule]
# 17                                      [Description]
# 18                                [Nonnull, Nullable]
# 19  [EntityNotFoundException, EntityManager, Query...
# 20  [Column, Lob, Basic, Entity, Id, EntityManager...
# 21                            [Logger, LoggerFactory]
# 22                        [JsonCreator, JsonProperty]
# 23                                [Nonnull, Nullable]
# 24                            [LoggerFactory, Logger]
# 25  [JsonCreator, JsonProperty, JsonGetter, JsonTy...
# 26  [Embeddable, Column, Basic, Lob, EntityManager...
# 27  [Embeddable, Basic, Column, Lob, TypedQuery, M...
# 28  [Scheduler, JobDataMap, JobExecutionContext, J...
# 29  [FluxSink$OverflowStrategy, Signal, MonoSink, ...
# 30  [JsonNode, ObjectMapper, ObjectReader, ObjectW...
# 31                                        [Publisher]
# 32  [TaskInstance, ExecutionContext, Task, TaskWit...
# 33  [HierarchicalStreamWriter, HierarchicalStreamR...
# 34  [CacheEntryCreatedListener, CacheEntryListener...
# 35  [CacheEventListener, EventOrdering, EventFirin...
# 36    [Scheduler, ScheduledExecution, SchedulerState]
# 37         [UnmarshallingContext, MarshallingContext]
# 38                         [JobScheduler, JobBuilder]
# 39              [Mapper, CannotResolveClassException]

# %% [markdown]
# ### Table 7 - Artifacts and their external packages
#
# The following table shows the artifacts with the highest external dependency usage broken down by each external package including external annotations. The results are sorted by the artifacts with the highest external package usage rate descending.
#
# The intention of this table is to find artifacts that use a lot of external dependencies and show in detail which external packages are used by them and how many internal packages.
#
# Only the last 30 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_and_external_package`
#
# **Columns:**
# - *artifactName* is the name of the artifact with external dependencies (first grouping column)
# - *artifactPackages* is the number of packages in the artifact
# - *artifactTypes* is the number of types in the artifact
# - *artifactExternalPackages* is the number of external packages used by the artifact
# - *artifactExternalCallingPackages* is the number of packages that use external packages in the artifact
# - *artifactExternalCallingPackagesRate* is artifactExternalCallingPackages / artifactPackages * 100%
# - *externalPackageName* the name of the external package (second grouping column)
# - *numberOfPackages* is the number of internal packages of the artifact that use the external packages
# - *numberOfTypes* is the number of internal types of the artifact that use the external packages
# - *packagesCallingExternalRate* is numberOfPackages / artifactPackages * 100%
# - *typesCallingExternalRate* is numberOfTypes / artifactTypes * 100%
# - *nameOfPackages* names of the internal packages that use the external package in the artifact
# - *someTypeNames* some (10) names of the internal types that use the external package in the artifact

# %%
external_packages_per_artifact = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_and_external_package.cypher")
external_packages_per_artifact.head(30)
# Out:
#                 artifactName  artifactPackages  artifactTypes  \
# 0   axon-configuration-4.9.1                 1             40
# 1   axon-configuration-4.9.1                 1             40
# 2       axon-disruptor-4.9.1                 1             22
# 3       axon-disruptor-4.9.1                 1             22
# 4       axon-disruptor-4.9.1                 1             22
# 5       axon-disruptor-4.9.1                 1             22
# 6       axon-disruptor-4.9.1                 1             22
# 7            axon-test-4.9.1                 8             87
# 8            axon-test-4.9.1                 8             87
# 9            axon-test-4.9.1                 8             87
# 10           axon-test-4.9.1                 8             87
# 11           axon-test-4.9.1                 8             87
# 12           axon-test-4.9.1                 8             87
# 13           axon-test-4.9.1                 8             87
# 14           axon-test-4.9.1                 8             87
# 15           axon-test-4.9.1                 8             87
# 16           axon-test-4.9.1                 8             87
# 17           axon-test-4.9.1                 8             87
# 18           axon-test-4.9.1                 8             87
# 19           axon-test-4.9.1                 8             87
# 20      axon-messaging-4.9.1                64            786
# 21      axon-messaging-4.9.1                64            786
# 22      axon-messaging-4.9.1                64            786
# 23      axon-messaging-4.9.1                64            786
# 24      axon-messaging-4.9.1                64            786
# 25      axon-messaging-4.9.1                64            786
# 26      axon-messaging-4.9.1                64            786
# 27      axon-messaging-4.9.1                64            786
# 28      axon-messaging-4.9.1                64            786
# 29      axon-messaging-4.9.1                64            786
#
#     artifactExternalPackages  artifactExternalCallingPackages  \
# 0                          2                                1
# 1                          2                                1
# 2                          5                                1
# 3                          5                                1
# 4                          5                                1
# 5                          5                                1
# 6                          5                                1
# 7                         13                                7
# 8                         13                                7
# 9                         13                                7
# 10                        13                                7
# 11                        13                                7
# 12                        13                                7
# 13                        13                                7
# 14                        13                                7
# 15                        13                                7
# 16                        13                                7
# 17                        13                                7
# 18                        13                                7
# 19                        13                                7
# 20                        43                               52
# 21                        43                               52
# 22                        43                               52
# 23                        43                               52
# 24                        43                               52
# 25                        43                               52
# 26                        43                               52
# 27                        43                               52
# 28                        43                               52
# 29                        43                               52
#
#     artifactExternalCallingPackagesRate  \
# 0                                100.00
# 1                                100.00
# 2                                100.00
# 3                                100.00
# 4                                100.00
# 5                                100.00
# 6                                100.00
# 7                                 87.50
# 8                                 87.50
# 9                                 87.50
# 10                                87.50
# 11                                87.50
# 12                                87.50
# 13                                87.50
# 14                                87.50
# 15                                87.50
# 16                                87.50
# 17                                87.50
# 18                                87.50
# 19                                87.50
# 20                                81.25
# 21                                81.25
# 22                                81.25
# 23                                81.25
# 24                                81.25
# 25                                81.25
# 26                                81.25
# 27                                81.25
# 28                                81.25
# 29                                81.25
#
#                              externalPackageName  numberOfPackages  \
# 0                               javax.annotation                 1
# 1                                      org.slf4j                 1
# 2                                      WeakValue                 1
# 3                             com.lmax.disruptor                 1
# 4                         com.lmax.disruptor.dsl                 1
# 5                               javax.annotation                 1
# 6                                      org.slf4j                 1
# 7                                   org.hamcrest                 5
# 8                               javax.annotation                 4
# 9                                      org.slf4j                 2
# 10                   AggregateEventPublisherImpl                 1
# 11                               com.google.gson                 1
# 12                         org.junit.jupiter.api                 1
# 13               org.junit.jupiter.api.extension                 1
# 14                               org.junit.rules                 1
# 15                              org.junit.runner                 1
# 16                       org.junit.runners.model                 1
# 17                 org.testcontainers.containers                 1
# 18   org.testcontainers.containers.wait.strategy                 1
# 19                    org.testcontainers.utility                 1
# 20                              javax.annotation                47
# 21                                     org.slf4j                38
# 22              com.fasterxml.jackson.annotation                11
# 23                             javax.persistence                 7
# 24                           jakarta.persistence                 4
# 25              com.github.kagkarlsson.scheduler                 2
# 26         com.github.kagkarlsson.scheduler.task                 2
# 27  com.github.kagkarlsson.scheduler.task.helper                 2
# 28                      com.thoughtworks.xstream                 2
# 29                   com.thoughtworks.xstream.io                 2
#
#     numberOfTypes  packagesCallingExternalRate  typesCallingExternalRate  \
# 0              13                     100.0000                 32.500000
# 1               6                     100.0000                 15.000000
# 2               1                     100.0000                  4.545455
# 3               7                     100.0000                 31.818182
# 4               4                     100.0000                 18.181818
# 5               6                     100.0000                 27.272727
# 6               8                     100.0000                 36.363636
# 7              27                      62.5000                 31.034483
# 8              10                      50.0000                 11.494253
# 9               2                      25.0000                  2.298851
# 10              1                      12.5000                  1.149425
# 11              1                      12.5000                  1.149425
# 12              1                      12.5000                  1.149425
# 13              1                      12.5000                  1.149425
# 14              1                      12.5000                  1.149425
# 15              1                      12.5000                  1.149425
# 16              2                      12.5000                  2.298851
# 17              3                      12.5000                  3.448276
# 18              3                      12.5000                  3.448276
# 19              3                      12.5000                  3.448276
# 20            221                      73.4375                 28.117048
# 21             78                      59.3750                  9.923664
# 22             21                      17.1875                  2.671756
# 23             14                      10.9375                  1.781170
# 24             13                       6.2500                  1.653944
# 25              4                       3.1250                  0.508906
# 26              4                       3.1250                  0.508906
# 27              2                       3.1250                  0.254453
# 28              4                       3.1250                  0.508906
# 29              4                       3.1250                  0.508906
#
#                                        nameOfPackages  \
# 0                          [org.axonframework.config]
# 1                          [org.axonframework.config]
# 2       [org.axonframework.disruptor.commandhandling]
# 3       [org.axonframework.disruptor.commandhandling]
# 4       [org.axonframework.disruptor.commandhandling]
# 5       [org.axonframework.disruptor.commandhandling]
# 6       [org.axonframework.disruptor.commandhandling]
# 7   [org.axonframework.test.aggregate, org.axonfra...
# 8   [org.axonframework.test.aggregate, org.axonfra...
# 9   [org.axonframework.test.aggregate, org.axonfra...
# 10                      [org.axonframework.test.saga]
# 11                    [org.axonframework.test.server]
# 12                      [org.axonframework.test.saga]
# 13                 [org.axonframework.test.aggregate]
# 14                 [org.axonframework.test.aggregate]
# 15                 [org.axonframework.test.aggregate]
# 16                 [org.axonframework.test.aggregate]
# 17                    [org.axonframework.test.server]
# 18                    [org.axonframework.test.server]
# 19                    [org.axonframework.test.server]
# 20  [org.axonframework.commandhandling, org.axonfr...
# 21  [org.axonframework.commandhandling, org.axonfr...
# 22  [org.axonframework.commandhandling.distributed...
# 23  [org.axonframework.common.legacyjpa, org.axonf...
# 24  [org.axonframework.common.jpa, org.axonframewo...
# 25  [org.axonframework.deadline.dbscheduler, org.a...
# 26  [org.axonframework.deadline.dbscheduler, org.a...
# 27  [org.axonframework.deadline.dbscheduler, org.a...
# 28  [org.axonframework.serialization, org.axonfram...
# 29  [org.axonframework.serialization, org.axonfram...
#
#                                         someTypeNames
# 0   [org.axonframework.config.EventProcessingModul...
# 1   [org.axonframework.config.LifecycleHandlerInsp...
# 2   [org.axonframework.disruptor.commandhandling.F...
# 3   [org.axonframework.disruptor.commandhandling.D...
# 4   [org.axonframework.disruptor.commandhandling.D...
# 5   [org.axonframework.disruptor.commandhandling.C...
# 6   [org.axonframework.disruptor.commandhandling.C...
# 7   [org.axonframework.test.aggregate.ResultValida...
# 8   [org.axonframework.test.aggregate.AggregateTes...
# 9   [org.axonframework.test.aggregate.AggregateTes...
# 10      [org.axonframework.test.saga.SagaTestFixture]
# 11  [org.axonframework.test.server.AxonServerConta...
# 12  [org.axonframework.test.saga.FixtureExecutionR...
# 13  [org.axonframework.test.aggregate.StubAggregat...
# 14  [org.axonframework.test.aggregate.StubAggregat...
# 15  [org.axonframework.test.aggregate.StubAggregat...
# 16  [org.axonframework.test.aggregate.StubAggregat...
# 17  [org.axonframework.test.server.AxonServerEECon...
# 18  [org.axonframework.test.server.AxonServerEECon...
# 19  [org.axonframework.test.server.AxonServerEECon...
# 20  [org.axonframework.commandhandling.CommandMess...
# 21  [org.axonframework.commandhandling.SimpleComma...
# 22  [org.axonframework.commandhandling.distributed...
# 23  [org.axonframework.common.legacyjpa.SimpleEnti...
# 24  [org.axonframework.common.jpa.PagingJpaQueryIt...
# 25  [org.axonframework.deadline.dbscheduler.DbSche...
# 26  [org.axonframework.deadline.dbscheduler.DbSche...
# 27  [org.axonframework.deadline.dbscheduler.DbSche...
# 28  [org.axonframework.serialization.AbstractXStre...
# 29  [org.axonframework.serialization.AbstractXStre...

# %% [markdown]
# ### Table 7a - Artifacts and their external packages (first 2 levels)
#
# The following table groups the external packages by their first two levels. For example `javax.xml.namespace` and `javax.xml.stream` will be grouped together to `javax.xml`.

# %%
external_second_level_packages_per_artifact = query_cypher_to_data_frame("../cypher/External_Dependencies/External_second_level_package_usage_per_artifact_and_external_package.cypher")
external_second_level_packages_per_artifact.head(30)
# Out:
#                 artifactName  artifactPackages  artifactTypes  \
# 0   axon-configuration-4.9.1                 1             40
# 1   axon-configuration-4.9.1                 1             40
# 2       axon-disruptor-4.9.1                 1             22
# 3       axon-disruptor-4.9.1                 1             22
# 4       axon-disruptor-4.9.1                 1             22
# 5       axon-disruptor-4.9.1                 1             22
# 6            axon-test-4.9.1                 8             87
# 7            axon-test-4.9.1                 8             87
# 8            axon-test-4.9.1                 8             87
# 9            axon-test-4.9.1                 8             87
# 10           axon-test-4.9.1                 8             87
# 11           axon-test-4.9.1                 8             87
# 12           axon-test-4.9.1                 8             87
# 13      axon-messaging-4.9.1                64            786
# 14      axon-messaging-4.9.1                64            786
# 15      axon-messaging-4.9.1                64            786
# 16      axon-messaging-4.9.1                64            786
# 17      axon-messaging-4.9.1                64            786
# 18      axon-messaging-4.9.1                64            786
# 19      axon-messaging-4.9.1                64            786
# 20      axon-messaging-4.9.1                64            786
# 21      axon-messaging-4.9.1                64            786
# 22      axon-messaging-4.9.1                64            786
# 23      axon-messaging-4.9.1                64            786
# 24      axon-messaging-4.9.1                64            786
# 25      axon-messaging-4.9.1                64            786
# 26      axon-messaging-4.9.1                64            786
# 27      axon-messaging-4.9.1                64            786
# 28      axon-messaging-4.9.1                64            786
# 29      axon-messaging-4.9.1                64            786
#
#     artifactExternalPackagesFirst2Levels  artifactExternalCallingPackages  \
# 0                                      2                                1
# 1                                      2                                1
# 2                                      4                                1
# 3                                      4                                1
# 4                                      4                                1
# 5                                      4                                1
# 6                                      7                                7
# 7                                      7                                7
# 8                                      7                                7
# 9                                      7                                7
# 10                                     7                                7
# 11                                     7                                7
# 12                                     7                                7
# 13                                    19                               52
# 14                                    19                               52
# 15                                    19                               52
# 16                                    19                               52
# 17                                    19                               52
# 18                                    19                               52
# 19                                    19                               52
# 20                                    19                               52
# 21                                    19                               52
# 22                                    19                               52
# 23                                    19                               52
# 24                                    19                               52
# 25                                    19                               52
# 26                                    19                               52
# 27                                    19                               52
# 28                                    19                               52
# 29                                    19                               52
#
#     artifactExternalCallingPackagesRate externalPackageNameFirst2Levels  \
# 0                                100.00                javax.annotation
# 1                                100.00                       org.slf4j
# 2                                100.00                       WeakValue
# 3                                100.00                        com.lmax
# 4                                100.00                javax.annotation
# 5                                100.00                       org.slf4j
# 6                                 87.50                    org.hamcrest
# 7                                 87.50                javax.annotation
# 8                                 87.50                       org.junit
# 9                                 87.50                       org.slf4j
# 10                                87.50     AggregateEventPublisherImpl
# 11                                87.50                      com.google
# 12                                87.50              org.testcontainers
# 13                                81.25                javax.annotation
# 14                                81.25                       org.slf4j
# 15                                81.25                   com.fasterxml
# 16                                81.25               javax.persistence
# 17                                81.25             jakarta.persistence
# 18                                81.25                      com.github
# 19                                81.25                com.thoughtworks
# 20                                81.25                     org.jobrunr
# 21                                81.25                      org.quartz
# 22                                81.25             org.reactivestreams
# 23                                81.25                    reactor.core
# 24                                81.25              jakarta.validation
# 25                                81.25                     javax.cache
# 26                                81.25                javax.validation
# 27                                81.25                          net.sf
# 28                                81.25                          nu.xom
# 29                                81.25                       org.dom4j
#
#     numberOfPackages  numberOfTypes  packagesCallingExternalRate  \
# 0                  1             13                     100.0000
# 1                  1              6                     100.0000
# 2                  1              1                     100.0000
# 3                  1              7                     100.0000
# 4                  1              6                     100.0000
# 5                  1              8                     100.0000
# 6                  5             27                      62.5000
# 7                  4             10                      50.0000
# 8                  2              4                      25.0000
# 9                  2              2                      25.0000
# 10                 1              1                      12.5000
# 11                 1              1                      12.5000
# 12                 1              3                      12.5000
# 13                47            221                      73.4375
# 14                38             78                      59.3750
# 15                12             28                      18.7500
# 16                 7             14                      10.9375
# 17                 4             13                       6.2500
# 18                 2              6                       3.1250
# 19                 2              8                       3.1250
# 20                 2              4                       3.1250
# 21                 2              9                       3.1250
# 22                 2             13                       3.1250
# 23                 2             18                       3.1250
# 24                 1              2                       1.5625
# 25                 1              2                       1.5625
# 26                 1              2                       1.5625
# 27                 1              2                       1.5625
# 28                 1              3                       1.5625
# 29                 1              3                       1.5625
#
#     typesCallingExternalRate  \
# 0                  32.500000
# 1                  15.000000
# 2                   4.545455
# 3                  31.818182
# 4                  27.272727
# 5                  36.363636
# 6                  31.034483
# 7                  11.494253
# 8                   4.597701
# 9                   2.298851
# 10                  1.149425
# 11                  1.149425
# 12                  3.448276
# 13                 28.117048
# 14                  9.923664
# 15                  3.562341
# 16                  1.781170
# 17                  1.653944
# 18                  0.763359
# 19                  1.017812
# 20                  0.508906
# 21                  1.145038
# 22                  1.653944
# 23                  2.290076
# 24                  0.254453
# 25                  0.254453
# 26                  0.254453
# 27                  0.254453
# 28                  0.381679
# 29                  0.381679
#
#                                        nameOfPackages  \
# 0                          [org.axonframework.config]
# 1                          [org.axonframework.config]
# 2       [org.axonframework.disruptor.commandhandling]
# 3       [org.axonframework.disruptor.commandhandling]
# 4       [org.axonframework.disruptor.commandhandling]
# 5       [org.axonframework.disruptor.commandhandling]
# 6   [org.axonframework.test.aggregate, org.axonfra...
# 7   [org.axonframework.test.aggregate, org.axonfra...
# 8   [org.axonframework.test.aggregate, org.axonfra...
# 9   [org.axonframework.test.aggregate, org.axonfra...
# 10                      [org.axonframework.test.saga]
# 11                    [org.axonframework.test.server]
# 12                    [org.axonframework.test.server]
# 13  [org.axonframework.commandhandling, org.axonfr...
# 14  [org.axonframework.commandhandling, org.axonfr...
# 15  [org.axonframework.commandhandling.distributed...
# 16  [org.axonframework.common.legacyjpa, org.axonf...
# 17  [org.axonframework.common.jpa, org.axonframewo...
# 18  [org.axonframework.deadline.dbscheduler, org.a...
# 19  [org.axonframework.serialization, org.axonfram...
# 20  [org.axonframework.deadline.jobrunr, org.axonf...
# 21  [org.axonframework.deadline.quartz, org.axonfr...
# 22  [org.axonframework.messaging.responsetypes, or...
# 23  [org.axonframework.messaging.responsetypes, or...
# 24         [org.axonframework.messaging.interceptors]
# 25                 [org.axonframework.common.caching]
# 26  [org.axonframework.messaging.interceptors.lega...
# 27                 [org.axonframework.common.caching]
# 28              [org.axonframework.serialization.xml]
# 29              [org.axonframework.serialization.xml]
#
#                                         someTypeNames
# 0   [org.axonframework.config.EventProcessingModul...
# 1   [org.axonframework.config.LifecycleHandlerInsp...
# 2   [org.axonframework.disruptor.commandhandling.F...
# 3   [org.axonframework.disruptor.commandhandling.D...
# 4   [org.axonframework.disruptor.commandhandling.C...
# 5   [org.axonframework.disruptor.commandhandling.C...
# 6   [org.axonframework.test.aggregate.ResultValida...
# 7   [org.axonframework.test.aggregate.AggregateTes...
# 8   [org.axonframework.test.aggregate.StubAggregat...
# 9   [org.axonframework.test.aggregate.AggregateTes...
# 10      [org.axonframework.test.saga.SagaTestFixture]
# 11  [org.axonframework.test.server.AxonServerConta...
# 12  [org.axonframework.test.server.AxonServerEECon...
# 13  [org.axonframework.commandhandling.CommandMess...
# 14  [org.axonframework.commandhandling.SimpleComma...
# 15  [org.axonframework.commandhandling.distributed...
# 16  [org.axonframework.common.legacyjpa.SimpleEnti...
# 17  [org.axonframework.common.jpa.PagingJpaQueryIt...
# 18  [org.axonframework.deadline.dbscheduler.DbSche...
# 19  [org.axonframework.serialization.AbstractXStre...
# 20  [org.axonframework.deadline.jobrunr.JobRunrDea...
# 21  [org.axonframework.deadline.quartz.DeadlineJob...
# 22  [org.axonframework.messaging.responsetypes.Opt...
# 23  [org.axonframework.messaging.responsetypes.Opt...
# 24  [org.axonframework.messaging.interceptors.JSR3...
# 25  [org.axonframework.common.caching.JCacheAdapte...
# 26  [org.axonframework.messaging.interceptors.lega...
# 27  [org.axonframework.common.caching.EhCacheAdapt...
# 28  [org.axonframework.serialization.xml.XomToStri...
# 29  [org.axonframework.serialization.xml.Dom4JToBy...

# %% [markdown]
# #### Table 7b - Top 15 external dependency using artifacts as columns with their external packages
#
# The following table uses pivot to show the artifacts in columns, the external dependencies in rows and the number of internal packages as values.

# %%
# Calculate the percentage for each value based on the global sum of all values
def percentage_global(data_frame : pd.DataFrame):
    total = data_frame.sum().sum()
    return data_frame / total * 100

# %%
external_packages_per_artifact_pivot = external_packages_per_artifact.copy()

# Every row represents the number of external package
external_packages_per_artifact_pivot=external_packages_per_artifact_pivot.pivot(index='externalPackageName', columns='artifactName', values='numberOfPackages')

# Sort by column sum and then take only the first 10 columns
sum_of_external_packages_per_artifact = external_packages_per_artifact_pivot.sum()
external_packages_per_artifact_pivot = external_packages_per_artifact_pivot[sum_of_external_packages_per_artifact.sort_values(ascending=False).index[:15]]

# Fill missing values with zeroes
external_packages_per_artifact_pivot.fillna(0, inplace=True)

external_packages_per_artifact_pivot.astype('int')
# Out:
# artifactName                                     axon-messaging-4.9.1  \
# externalPackageName
# AggregateEventPublisherImpl                                         0
# WeakValue                                                           0
# com.fasterxml.jackson.annotation                                   11
# com.fasterxml.jackson.core                                          1
# com.fasterxml.jackson.databind                                      1
# com.fasterxml.jackson.databind.jsontype                             1
# com.fasterxml.jackson.databind.module                               1
# com.fasterxml.jackson.databind.node                                 1
# com.fasterxml.jackson.databind.type                                 1
# com.fasterxml.jackson.datatype.jsr310                               1
# com.github.kagkarlsson.scheduler                                    2
# com.github.kagkarlsson.scheduler.task                               2
# com.github.kagkarlsson.scheduler.task.helper                        2
# com.google.gson                                                     0
# com.lmax.disruptor                                                  0
# com.lmax.disruptor.dsl                                              0
# com.thoughtworks.xstream                                            2
# com.thoughtworks.xstream.converters                                 1
# com.thoughtworks.xstream.converters.collections                     1
# com.thoughtworks.xstream.io                                         2
# com.thoughtworks.xstream.io.xml                                     1
# com.thoughtworks.xstream.mapper                                     1
# jakarta.persistence                                                 4
# jakarta.validation                                                  1
# javax.annotation                                                   47
# javax.cache                                                         1
# javax.cache.configuration                                           1
# javax.cache.event                                                   1
# javax.persistence                                                   7
# javax.validation                                                    1
# net.sf.ehcache                                                      1
# net.sf.ehcache.event                                                1
# nu.xom                                                              1
# org.dom4j                                                           1
# org.dom4j.io                                                        1
# org.ehcache.config                                                  1
# org.ehcache.core                                                    1
# org.ehcache.event                                                   1
# org.hamcrest                                                        0
# org.jobrunr.jobs                                                    2
# org.jobrunr.scheduling                                              2
# org.junit.jupiter.api                                               0
# org.junit.jupiter.api.extension                                     0
# org.junit.rules                                                     0
# org.junit.runner                                                    0
# org.junit.runners.model                                             0
# org.quartz                                                          2
# org.quartz.impl.matchers                                            1
# org.reactivestreams                                                 2
# org.slf4j                                                          38
# org.testcontainers.containers                                       0
# org.testcontainers.containers.wait.strategy                         0
# org.testcontainers.utility                                          0
# reactor.core                                                        1
# reactor.core.publisher                                              2
# reactor.util.concurrent                                             1
# reactor.util.context                                                1
#
# artifactName                                     axon-test-4.9.1  \
# externalPackageName
# AggregateEventPublisherImpl                                    1
# WeakValue                                                      0
# com.fasterxml.jackson.annotation                               0
# com.fasterxml.jackson.core                                     0
# com.fasterxml.jackson.databind                                 0
# com.fasterxml.jackson.databind.jsontype                        0
# com.fasterxml.jackson.databind.module                          0
# com.fasterxml.jackson.databind.node                            0
# com.fasterxml.jackson.databind.type                            0
# com.fasterxml.jackson.datatype.jsr310                          0
# com.github.kagkarlsson.scheduler                               0
# com.github.kagkarlsson.scheduler.task                          0
# com.github.kagkarlsson.scheduler.task.helper                   0
# com.google.gson                                                1
# com.lmax.disruptor                                             0
# com.lmax.disruptor.dsl                                         0
# com.thoughtworks.xstream                                       0
# com.thoughtworks.xstream.converters                            0
# com.thoughtworks.xstream.converters.collections                0
# com.thoughtworks.xstream.io                                    0
# com.thoughtworks.xstream.io.xml                                0
# com.thoughtworks.xstream.mapper                                0
# jakarta.persistence                                            0
# jakarta.validation                                             0
# javax.annotation                                               4
# javax.cache                                                    0
# javax.cache.configuration                                      0
# javax.cache.event                                              0
# javax.persistence                                              0
# javax.validation                                               0
# net.sf.ehcache                                                 0
# net.sf.ehcache.event                                           0
# nu.xom                                                         0
# org.dom4j                                                      0
# org.dom4j.io                                                   0
# org.ehcache.config                                             0
# org.ehcache.core                                               0
# org.ehcache.event                                              0
# org.hamcrest                                                   5
# org.jobrunr.jobs                                               0
# org.jobrunr.scheduling                                         0
# org.junit.jupiter.api                                          1
# org.junit.jupiter.api.extension                                1
# org.junit.rules                                                1
# org.junit.runner                                               1
# org.junit.runners.model                                        1
# org.quartz                                                     0
# org.quartz.impl.matchers                                       0
# org.reactivestreams                                            0
# org.slf4j                                                      2
# org.testcontainers.containers                                  1
# org.testcontainers.containers.wait.strategy                    1
# org.testcontainers.utility                                     1
# reactor.core                                                   0
# reactor.core.publisher                                         0
# reactor.util.concurrent                                        0
# reactor.util.context                                           0
#
# artifactName                                     axon-modelling-4.9.1  \
# externalPackageName
# AggregateEventPublisherImpl                                         0
# WeakValue                                                           0
# com.fasterxml.jackson.annotation                                    2
# com.fasterxml.jackson.core                                          0
# com.fasterxml.jackson.databind                                      0
# com.fasterxml.jackson.databind.jsontype                             0
# com.fasterxml.jackson.databind.module                               0
# com.fasterxml.jackson.databind.node                                 0
# com.fasterxml.jackson.databind.type                                 0
# com.fasterxml.jackson.datatype.jsr310                               0
# com.github.kagkarlsson.scheduler                                    0
# com.github.kagkarlsson.scheduler.task                               0
# com.github.kagkarlsson.scheduler.task.helper                        0
# com.google.gson                                                     0
# com.lmax.disruptor                                                  0
# com.lmax.disruptor.dsl                                              0
# com.thoughtworks.xstream                                            0
# com.thoughtworks.xstream.converters                                 0
# com.thoughtworks.xstream.converters.collections                     0
# com.thoughtworks.xstream.io                                         0
# com.thoughtworks.xstream.io.xml                                     0
# com.thoughtworks.xstream.mapper                                     0
# jakarta.persistence                                                 2
# jakarta.validation                                                  0
# javax.annotation                                                    4
# javax.cache                                                         0
# javax.cache.configuration                                           0
# javax.cache.event                                                   0
# javax.persistence                                                   3
# javax.validation                                                    0
# net.sf.ehcache                                                      0
# net.sf.ehcache.event                                                0
# nu.xom                                                              0
# org.dom4j                                                           0
# org.dom4j.io                                                        0
# org.ehcache.config                                                  0
# org.ehcache.core                                                    0
# org.ehcache.event                                                   0
# org.hamcrest                                                        0
# org.jobrunr.jobs                                                    0
# org.jobrunr.scheduling                                              0
# org.junit.jupiter.api                                               0
# org.junit.jupiter.api.extension                                     0
# org.junit.rules                                                     0
# org.junit.runner                                                    0
# org.junit.runners.model                                             0
# org.quartz                                                          0
# org.quartz.impl.matchers                                            0
# org.reactivestreams                                                 0
# org.slf4j                                                           6
# org.testcontainers.containers                                       0
# org.testcontainers.containers.wait.strategy                         0
# org.testcontainers.utility                                          0
# reactor.core                                                        0
# reactor.core.publisher                                              0
# reactor.util.concurrent                                             0
# reactor.util.context                                                0
#
# artifactName                                     axon-eventsourcing-4.9.1  \
# externalPackageName
# AggregateEventPublisherImpl                                             0
# WeakValue                                                               0
# com.fasterxml.jackson.annotation                                        0
# com.fasterxml.jackson.core                                              0
# com.fasterxml.jackson.databind                                          0
# com.fasterxml.jackson.databind.jsontype                                 0
# com.fasterxml.jackson.databind.module                                   0
# com.fasterxml.jackson.databind.node                                     0
# com.fasterxml.jackson.databind.type                                     0
# com.fasterxml.jackson.datatype.jsr310                                   0
# com.github.kagkarlsson.scheduler                                        0
# com.github.kagkarlsson.scheduler.task                                   0
# com.github.kagkarlsson.scheduler.task.helper                            0
# com.google.gson                                                         0
# com.lmax.disruptor                                                      0
# com.lmax.disruptor.dsl                                                  0
# com.thoughtworks.xstream                                                0
# com.thoughtworks.xstream.converters                                     0
# com.thoughtworks.xstream.converters.collections                         0
# com.thoughtworks.xstream.io                                             0
# com.thoughtworks.xstream.io.xml                                         0
# com.thoughtworks.xstream.mapper                                         0
# jakarta.persistence                                                     2
# jakarta.validation                                                      0
# javax.annotation                                                        6
# javax.cache                                                             0
# javax.cache.configuration                                               0
# javax.cache.event                                                       0
# javax.persistence                                                       3
# javax.validation                                                        0
# net.sf.ehcache                                                          0
# net.sf.ehcache.event                                                    0
# nu.xom                                                                  0
# org.dom4j                                                               0
# org.dom4j.io                                                            0
# org.ehcache.config                                                      0
# org.ehcache.core                                                        0
# org.ehcache.event                                                       0
# org.hamcrest                                                            0
# org.jobrunr.jobs                                                        0
# org.jobrunr.scheduling                                                  0
# org.junit.jupiter.api                                                   0
# org.junit.jupiter.api.extension                                         0
# org.junit.rules                                                         0
# org.junit.runner                                                        0
# org.junit.runners.model                                                 0
# org.quartz                                                              0
# org.quartz.impl.matchers                                                0
# org.reactivestreams                                                     0
# org.slf4j                                                               5
# org.testcontainers.containers                                           0
# org.testcontainers.containers.wait.strategy                             0
# org.testcontainers.utility                                              0
# reactor.core                                                            0
# reactor.core.publisher                                                  0
# reactor.util.concurrent                                                 0
# reactor.util.context                                                    0
#
# artifactName                                     axon-disruptor-4.9.1  \
# externalPackageName
# AggregateEventPublisherImpl                                         0
# WeakValue                                                           1
# com.fasterxml.jackson.annotation                                    0
# com.fasterxml.jackson.core                                          0
# com.fasterxml.jackson.databind                                      0
# com.fasterxml.jackson.databind.jsontype                             0
# com.fasterxml.jackson.databind.module                               0
# com.fasterxml.jackson.databind.node                                 0
# com.fasterxml.jackson.databind.type                                 0
# com.fasterxml.jackson.datatype.jsr310                               0
# com.github.kagkarlsson.scheduler                                    0
# com.github.kagkarlsson.scheduler.task                               0
# com.github.kagkarlsson.scheduler.task.helper                        0
# com.google.gson                                                     0
# com.lmax.disruptor                                                  1
# com.lmax.disruptor.dsl                                              1
# com.thoughtworks.xstream                                            0
# com.thoughtworks.xstream.converters                                 0
# com.thoughtworks.xstream.converters.collections                     0
# com.thoughtworks.xstream.io                                         0
# com.thoughtworks.xstream.io.xml                                     0
# com.thoughtworks.xstream.mapper                                     0
# jakarta.persistence                                                 0
# jakarta.validation                                                  0
# javax.annotation                                                    1
# javax.cache                                                         0
# javax.cache.configuration                                           0
# javax.cache.event                                                   0
# javax.persistence                                                   0
# javax.validation                                                    0
# net.sf.ehcache                                                      0
# net.sf.ehcache.event                                                0
# nu.xom                                                              0
# org.dom4j                                                           0
# org.dom4j.io                                                        0
# org.ehcache.config                                                  0
# org.ehcache.core                                                    0
# org.ehcache.event                                                   0
# org.hamcrest                                                        0
# org.jobrunr.jobs                                                    0
# org.jobrunr.scheduling                                              0
# org.junit.jupiter.api                                               0
# org.junit.jupiter.api.extension                                     0
# org.junit.rules                                                     0
# org.junit.runner                                                    0
# org.junit.runners.model                                             0
# org.quartz                                                          0
# org.quartz.impl.matchers                                            0
# org.reactivestreams                                                 0
# org.slf4j                                                           1
# org.testcontainers.containers                                       0
# org.testcontainers.containers.wait.strategy                         0
# org.testcontainers.utility                                          0
# reactor.core                                                        0
# reactor.core.publisher                                              0
# reactor.util.concurrent                                             0
# reactor.util.context                                                0
#
# artifactName                                     axon-configuration-4.9.1
# externalPackageName
# AggregateEventPublisherImpl                                             0
# WeakValue                                                               0
# com.fasterxml.jackson.annotation                                        0
# com.fasterxml.jackson.core                                              0
# com.fasterxml.jackson.databind                                          0
# com.fasterxml.jackson.databind.jsontype                                 0
# com.fasterxml.jackson.databind.module                                   0
# com.fasterxml.jackson.databind.node                                     0
# com.fasterxml.jackson.databind.type                                     0
# com.fasterxml.jackson.datatype.jsr310                                   0
# com.github.kagkarlsson.scheduler                                        0
# com.github.kagkarlsson.scheduler.task                                   0
# com.github.kagkarlsson.scheduler.task.helper                            0
# com.google.gson                                                         0
# com.lmax.disruptor                                                      0
# com.lmax.disruptor.dsl                                                  0
# com.thoughtworks.xstream                                                0
# com.thoughtworks.xstream.converters                                     0
# com.thoughtworks.xstream.converters.collections                         0
# com.thoughtworks.xstream.io                                             0
# com.thoughtworks.xstream.io.xml                                         0
# com.thoughtworks.xstream.mapper                                         0
# jakarta.persistence                                                     0
# jakarta.validation                                                      0
# javax.annotation                                                        1
# javax.cache                                                             0
# javax.cache.configuration                                               0
# javax.cache.event                                                       0
# javax.persistence                                                       0
# javax.validation                                                        0
# net.sf.ehcache                                                          0
# net.sf.ehcache.event                                                    0
# nu.xom                                                                  0
# org.dom4j                                                               0
# org.dom4j.io                                                            0
# org.ehcache.config                                                      0
# org.ehcache.core                                                        0
# org.ehcache.event                                                       0
# org.hamcrest                                                            0
# org.jobrunr.jobs                                                        0
# org.jobrunr.scheduling                                                  0
# org.junit.jupiter.api                                                   0
# org.junit.jupiter.api.extension                                         0
# org.junit.rules                                                         0
# org.junit.runner                                                        0
# org.junit.runners.model                                                 0
# org.quartz                                                              0
# org.quartz.impl.matchers                                                0
# org.reactivestreams                                                     0
# org.slf4j                                                               1
# org.testcontainers.containers                                           0
# org.testcontainers.containers.wait.strategy                             0
# org.testcontainers.utility                                              0
# reactor.core                                                            0
# reactor.core.publisher                                                  0
# reactor.util.concurrent                                                 0
# reactor.util.context                                                    0

# %% [markdown]
# #### Table 7c - Top 15 external dependency using artifacts as columns with their external packages (first 2 levels)
#
# The following table uses pivot to show the artifacts in columns, the external package name grouped by its first two levels in rows and the number of internal packages as values. For example `javax.xml.namespace` and `javax.xml.stream` will be grouped together to `javax.xml`.

# %%
external_second_level_packages_per_artifact_pivot = external_second_level_packages_per_artifact.copy()

# Every row represents the number of external package
external_second_level_packages_per_artifact_pivot=external_second_level_packages_per_artifact_pivot.pivot(index='externalPackageNameFirst2Levels', columns='artifactName', values='numberOfPackages')

# Sort by column sum and then take only the first 10 columns
sum_of_external_second_level_packages_per_artifact = external_second_level_packages_per_artifact_pivot.sum()
external_second_level_packages_per_artifact_pivot = external_second_level_packages_per_artifact_pivot[sum_of_external_second_level_packages_per_artifact.sort_values(ascending=False).index[:15]]

# Fill missing values with zeroes
external_second_level_packages_per_artifact_pivot.fillna(0, inplace=True)

external_second_level_packages_per_artifact_pivot.astype('int')
# Out:
# artifactName                     axon-messaging-4.9.1  axon-modelling-4.9.1  \
# externalPackageNameFirst2Levels
# AggregateEventPublisherImpl                         0                     0
# WeakValue                                           0                     0
# com.fasterxml                                      12                     2
# com.github                                          2                     0
# com.google                                          0                     0
# com.lmax                                            0                     0
# com.thoughtworks                                    2                     0
# jakarta.persistence                                 4                     2
# jakarta.validation                                  1                     0
# javax.annotation                                   47                     4
# javax.cache                                         1                     0
# javax.persistence                                   7                     3
# javax.validation                                    1                     0
# net.sf                                              1                     0
# nu.xom                                              1                     0
# org.dom4j                                           1                     0
# org.ehcache                                         1                     0
# org.hamcrest                                        0                     0
# org.jobrunr                                         2                     0
# org.junit                                           0                     0
# org.quartz                                          2                     0
# org.reactivestreams                                 2                     0
# org.slf4j                                          38                     6
# org.testcontainers                                  0                     0
# reactor.core                                        2                     0
# reactor.util                                        1                     0
#
# artifactName                     axon-eventsourcing-4.9.1  axon-test-4.9.1  \
# externalPackageNameFirst2Levels
# AggregateEventPublisherImpl                             0                1
# WeakValue                                               0                0
# com.fasterxml                                           0                0
# com.github                                              0                0
# com.google                                              0                1
# com.lmax                                                0                0
# com.thoughtworks                                        0                0
# jakarta.persistence                                     2                0
# jakarta.validation                                      0                0
# javax.annotation                                        6                4
# javax.cache                                             0                0
# javax.persistence                                       3                0
# javax.validation                                        0                0
# net.sf                                                  0                0
# nu.xom                                                  0                0
# org.dom4j                                               0                0
# org.ehcache                                             0                0
# org.hamcrest                                            0                5
# org.jobrunr                                             0                0
# org.junit                                               0                2
# org.quartz                                              0                0
# org.reactivestreams                                     0                0
# org.slf4j                                               5                2
# org.testcontainers                                      0                1
# reactor.core                                            0                0
# reactor.util                                            0                0
#
# artifactName                     axon-disruptor-4.9.1  \
# externalPackageNameFirst2Levels
# AggregateEventPublisherImpl                         0
# WeakValue                                           1
# com.fasterxml                                       0
# com.github                                          0
# com.google                                          0
# com.lmax                                            1
# com.thoughtworks                                    0
# jakarta.persistence                                 0
# jakarta.validation                                  0
# javax.annotation                                    1
# javax.cache                                         0
# javax.persistence                                   0
# javax.validation                                    0
# net.sf                                              0
# nu.xom                                              0
# org.dom4j                                           0
# org.ehcache                                         0
# org.hamcrest                                        0
# org.jobrunr                                         0
# org.junit                                           0
# org.quartz                                          0
# org.reactivestreams                                 0
# org.slf4j                                           1
# org.testcontainers                                  0
# reactor.core                                        0
# reactor.util                                        0
#
# artifactName                     axon-configuration-4.9.1
# externalPackageNameFirst2Levels
# AggregateEventPublisherImpl                             0
# WeakValue                                               0
# com.fasterxml                                           0
# com.github                                              0
# com.google                                              0
# com.lmax                                                0
# com.thoughtworks                                        0
# jakarta.persistence                                     0
# jakarta.validation                                      0
# javax.annotation                                        1
# javax.cache                                             0
# javax.persistence                                       0
# javax.validation                                        0
# net.sf                                                  0
# nu.xom                                                  0
# org.dom4j                                               0
# org.ehcache                                             0
# org.hamcrest                                            0
# org.jobrunr                                             0
# org.junit                                               0
# org.quartz                                              0
# org.reactivestreams                                     0
# org.slf4j                                               1
# org.testcontainers                                      0
# reactor.core                                            0
# reactor.util                                            0

# %% [markdown]
# #### Table 7 Chart 1 - Top 15 external dependency using artifacts and their external packages stacked
#
# The following chart shows the top 15 external package using artifacts and breaks down which external packages they use in how many different internal packages with stacked bars.
#
# Note that every external dependency is counted separately so that if on internal package uses two external packages it will be displayed for both and so stacked twice.

# %%
plot.figure();
axes = external_packages_per_artifact_pivot.transpose().plot(
    kind='bar', 
    grid=True,
    title='External package usage per artifact', 
    xlabel='artifact',
    ylabel='number of packages',
    stacked=True,
    legend=True,
    cmap=main_color_map
).legend(bbox_to_anchor=(1.0, 1.0))
plot.show()

# %% [markdown]
# #### Table 7 Chart 2 - Top 15 external dependency using artifacts and their external packages (first 2 levels) stacked
#
# The following chart shows the top 15 external package using artifacts and breaks down which external packages (first 2 levels) are used in how many different internal packages with stacked bars.
#
# Note that every external dependency is counted separately so that if on internal package uses two external packages it will be displayed for both and so stacked twice.

# %%
plot.figure();
axes = external_second_level_packages_per_artifact_pivot.transpose().plot(
    kind='bar', 
    grid=True,
    title='External package (first 2 levels) usage per artifact', 
    xlabel='artifact',
    ylabel='number of packages',
    stacked=True,
    legend=True,
    cmap=main_color_map
).legend(bbox_to_anchor=(1.0, 1.0))
plot.show()

# %% [markdown]
# ### Table 8 - External usage per artifact
#
# The following table shows the most used external packages separately for each artifact including external annotations. The results are grouped per artifact and sorted by the artifacts with the highest external type usage rate descending. Additionally, for each artifact the top 5 used external packages are listed in the top5ExternalPackages column.
#
# The intention of this table is to find artifacts that use a lot of external dependencies in relation to their size and get an overview per artifact with the top 5 used external packages, the number of external types and packages used etc. .
#
# Only the last 40 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_sorted_top`
#
# **Columns:**
# - *artifactName* is used to group the the external package usage per artifact for a more detailed analysis.
# - *numberOfTypesInArtifact* represents the total count of all analyzed types for the artifact
# - *numberOfExternalTypesInArtifact* is the number of all external types that are used by the artifact
# - *numberOfExternalPackagesInArtifact* is the number of all external packages that are used by the artifact
# - *externalTypeRate* is the numberOfExternalTypesInArtifact / numberOfTypesInArtifact * 100
# - *numberOfExternalTypeCaller* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfExternalPackages* is the number of distinct external packages used by the artifact
# - *top5ExternalPackages* contains a list of the top 5 most used external packages of the artifact
# - *someExternalTypes* contains a list of lists and is also mean't to provide some examples of external types used

# %%
query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_sorted_top.cypher").head(40)
# Out:
#                artifactName  numberOfTypesInArtifact  \
# 0      axon-disruptor-4.9.1                       22
# 1           axon-test-4.9.1                       87
# 2      axon-modelling-4.9.1                      156
# 3      axon-messaging-4.9.1                      786
# 4  axon-eventsourcing-4.9.1                      133
# 5  axon-configuration-4.9.1                       40
#
#    numberOfExternalTypesInArtifact  numberOfExternalPackagesInArtifact  \
# 0                               13                                   5
# 1                               28                                  13
# 2                               35                                   5
# 3                              155                                  43
# 4                               25                                   4
# 5                                4                                   2
#
#    externalTypeRate  numberOfExternalTypeCaller  numberOfExternalTypeCalls  \
# 0         59.090909                          33                        101
# 1         32.183908                         101                        639
# 2         22.435897                          99                        382
# 3         19.720102                         753                       3196
# 4         18.796992                          74                        242
# 5         10.000000                          24                        137
#
#    numberOfExternalPackages  \
# 0                         5
# 1                        13
# 2                         5
# 3                        43
# 4                         4
# 5                         2
#
#                                 top5ExternalPackages  \
# 0  [org.slf4j, com.lmax.disruptor, javax.annotati...
# 1  [org.hamcrest, javax.annotation, org.testconta...
# 2  [javax.annotation, javax.persistence, jakarta....
# 3  [javax.annotation, org.slf4j, com.fasterxml.ja...
# 4  [javax.annotation, org.slf4j, javax.persistenc...
# 5                      [javax.annotation, org.slf4j]
#
#                                    someExternalTypes
# 0  [Logger, LoggerFactory, RingBuffer, EventHandl...
# 1  [StringDescription, Matcher, Description, Type...
# 2  [Nonnull, Nullable, EntityNotFoundException, E...
# 3  [Nonnull, Nullable, LoggerFactory, Logger, Jso...
# 4  [Nonnull, Nullable, PreDestroy, Logger, Logger...
# 5         [Nullable, Nonnull, LoggerFactory, Logger]

# %% [markdown]
# ### Table 9 - External usage per artifact and package
#
# This table lists internal packages and the artifacts they belong to that use many different external types of a specific external package without taking external annotations into account.
#
# Only the last 40 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_and_package`
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *fullPackageName* is the package within the artifact that contains the type that calls the external package
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalTypeCaller* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfTypesInPackage* represents the total count of all types in that package
# - *externalTypeNames* contains a list of actually utilized types of the external package
# - *packageName* contains the name of the package (last part of *fullPackageName*)

# %%
external_package_usage_per_package = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_and_package.cypher")
external_package_usage_per_package.head(40)
# Out:
#                 artifactName  \
# 0            axon-test-4.9.1
# 1       axon-messaging-4.9.1
# 2       axon-messaging-4.9.1
# 3       axon-messaging-4.9.1
# 4       axon-messaging-4.9.1
# 5       axon-messaging-4.9.1
# 6       axon-messaging-4.9.1
# 7       axon-disruptor-4.9.1
# 8   axon-configuration-4.9.1
# 9       axon-disruptor-4.9.1
# 10           axon-test-4.9.1
# 11  axon-eventsourcing-4.9.1
# 12      axon-messaging-4.9.1
# 13      axon-messaging-4.9.1
# 14      axon-messaging-4.9.1
# 15      axon-messaging-4.9.1
# 16      axon-messaging-4.9.1
# 17      axon-messaging-4.9.1
# 18           axon-test-4.9.1
# 19  axon-eventsourcing-4.9.1
# 20      axon-messaging-4.9.1
# 21      axon-messaging-4.9.1
# 22      axon-messaging-4.9.1
# 23      axon-messaging-4.9.1
# 24      axon-modelling-4.9.1
# 25      axon-disruptor-4.9.1
# 26  axon-eventsourcing-4.9.1
# 27      axon-messaging-4.9.1
# 28      axon-messaging-4.9.1
# 29      axon-messaging-4.9.1
# 30      axon-messaging-4.9.1
# 31      axon-messaging-4.9.1
# 32      axon-messaging-4.9.1
# 33      axon-messaging-4.9.1
# 34      axon-messaging-4.9.1
# 35      axon-messaging-4.9.1
# 36      axon-messaging-4.9.1
# 37      axon-messaging-4.9.1
# 38      axon-messaging-4.9.1
# 39      axon-modelling-4.9.1
#
#                                       fullPackageName  \
# 0                     org.axonframework.test.matchers
# 1                     org.axonframework.queryhandling
# 2                   org.axonframework.deadline.quartz
# 3   org.axonframework.eventhandling.scheduling.quartz
# 4                     org.axonframework.eventhandling
# 5              org.axonframework.eventhandling.pooled
# 6                org.axonframework.serialization.json
# 7         org.axonframework.disruptor.commandhandling
# 8                            org.axonframework.config
# 9         org.axonframework.disruptor.commandhandling
# 10                        org.axonframework.test.saga
# 11  org.axonframework.eventsourcing.eventstore.leg...
# 12                   org.axonframework.common.caching
# 13                   org.axonframework.common.caching
# 14             org.axonframework.messaging.annotation
# 15          org.axonframework.messaging.responsetypes
# 16                    org.axonframework.queryhandling
# 17                    org.axonframework.queryhandling
# 18                   org.axonframework.test.aggregate
# 19         org.axonframework.eventsourcing.eventstore
# 20         org.axonframework.eventhandling.deadletter
# 21          org.axonframework.messaging.responsetypes
# 22                    org.axonframework.serialization
# 23                    org.axonframework.serialization
# 24    org.axonframework.modelling.saga.repository.jpa
# 25        org.axonframework.disruptor.commandhandling
# 26     org.axonframework.eventsourcing.eventstore.jpa
# 27                           org.axonframework.common
# 28                   org.axonframework.common.caching
# 29             org.axonframework.deadline.dbscheduler
# 30              org.axonframework.eventhandling.async
# 31     org.axonframework.eventhandling.deadletter.jpa
# 32  org.axonframework.eventhandling.scheduling.dbs...
# 33     org.axonframework.eventhandling.tokenstore.jpa
# 34  org.axonframework.eventhandling.tokenstore.leg...
# 35           org.axonframework.messaging.interceptors
# 36  org.axonframework.messaging.interceptors.legac...
# 37                    org.axonframework.serialization
# 38                org.axonframework.serialization.xml
# 39  org.axonframework.modelling.saga.repository.le...
#
#                       externalPackageName  numberOfExternalTypeCaller  \
# 0                            org.hamcrest                          38
# 1                  reactor.core.publisher                          28
# 2                              org.quartz                          20
# 3                              org.quartz                          19
# 4                               org.slf4j                          16
# 5                               org.slf4j                          15
# 6          com.fasterxml.jackson.databind                          15
# 7                               org.slf4j                          12
# 8                               org.slf4j                          11
# 9                      com.lmax.disruptor                           9
# 10                           org.hamcrest                           9
# 11                              org.slf4j                           8
# 12                      org.ehcache.event                           8
# 13                      javax.cache.event                           8
# 14                              org.slf4j                           8
# 15                 reactor.core.publisher                           7
# 16                              org.slf4j                           7
# 17                    org.reactivestreams                           7
# 18                           org.hamcrest                           7
# 19                              org.slf4j                           6
# 20                              org.slf4j                           6
# 21                    org.reactivestreams                           6
# 22    com.thoughtworks.xstream.converters                           6
# 23            com.thoughtworks.xstream.io                           6
# 24                    jakarta.persistence                           6
# 25                 com.lmax.disruptor.dsl                           5
# 26                    jakarta.persistence                           5
# 27                              org.slf4j                           5
# 28                         net.sf.ehcache                           5
# 29  com.github.kagkarlsson.scheduler.task                           5
# 30                              org.slf4j                           5
# 31                    jakarta.persistence                           5
# 32  com.github.kagkarlsson.scheduler.task                           5
# 33                    jakarta.persistence                           5
# 34                      javax.persistence                           5
# 35                     jakarta.validation                           5
# 36                       javax.validation                           5
# 37        com.thoughtworks.xstream.mapper                           5
# 38                                 nu.xom                           5
# 39                      javax.persistence                           5
#
#     numberOfExternalTypeCalls  numberOfTypesInPackage  \
# 0                         188                      24
# 1                         123                      48
# 2                         137                       4
# 3                          95                       6
# 4                          57                     100
# 5                          70                      21
# 6                          73                       7
# 7                          22                      22
# 8                          32                      40
# 9                          29                      22
# 10                         91                      21
# 11                         15                      10
# 12                         33                      15
# 13                         34                      15
# 14                         15                      54
# 15                         34                       8
# 16                         16                      48
# 17                         27                      48
# 18                        136                      19
# 19                          9                      31
# 20                         25                       5
# 21                         14                       8
# 22                         12                      34
# 23                         39                      34
# 24                         68                       7
# 25                         22                      22
# 26                         42                       7
# 27                         15                      28
# 28                         63                      15
# 29                         27                       7
# 30                         16                      15
# 31                         54                       9
# 32                         25                       7
# 33                         64                       4
# 34                         64                       2
# 35                         22                       8
# 36                         22                       2
# 37                         10                      34
# 38                         16                       7
# 39                         66                       3
#
#                                     externalTypeNames       packageName
# 0   [Matcher, Description, TypeSafeMatcher, BaseMa...          matchers
# 1   [Flux, Mono, Sinks$EmitResult, Sinks$Many, Sig...     queryhandling
# 2   [SchedulerContext, JobExecutionContext, Trigge...            quartz
# 3   [JobDataMap, Trigger, SchedulerContext, Schedu...            quartz
# 4                             [Logger, LoggerFactory]     eventhandling
# 5                             [Logger, LoggerFactory]            pooled
# 6   [JsonDeserializer, DeserializationContext, Obj...              json
# 7                             [Logger, LoggerFactory]   commandhandling
# 8                             [LoggerFactory, Logger]            config
# 9   [BlockingWaitStrategy, WaitStrategy, Exception...   commandhandling
# 10  [Matcher, Description, StringDescription, Core...              saga
# 11                            [LoggerFactory, Logger]         legacyjpa
# 12  [CacheEvent, CacheEventListener, EventType, Ev...           caching
# 13  [CacheEntryCreatedListener, CacheEntryListener...           caching
# 14                            [Logger, LoggerFactory]        annotation
# 15                                       [Mono, Flux]     responsetypes
# 16                            [LoggerFactory, Logger]     queryhandling
# 17                                        [Publisher]     queryhandling
# 18  [Matcher, StringDescription, Description, Core...         aggregate
# 19                            [LoggerFactory, Logger]        eventstore
# 20                            [Logger, LoggerFactory]        deadletter
# 21                                        [Publisher]     responsetypes
# 22         [MarshallingContext, UnmarshallingContext]     serialization
# 23  [HierarchicalStreamReader, HierarchicalStreamW...     serialization
# 24  [EntityManager, EntityManagerFactory, TypedQue...               jpa
# 25       [ProducerType, Disruptor, EventHandlerGroup]   commandhandling
# 26  [Query, EntityManager, TypedQuery, EntityExist...               jpa
# 27                            [LoggerFactory, Logger]            common
# 28                 [CacheException, Ehcache, Element]           caching
# 29  [TaskInstanceId, TaskInstance, ExecutionContex...       dbscheduler
# 30                            [Logger, LoggerFactory]             async
# 31  [Query, EntityManager, TypedQuery, NoResultExc...               jpa
# 32  [Task, TaskWithDataDescriptor, ExecutionContex...       dbscheduler
# 33   [LockModeType, Query, TypedQuery, EntityManager]               jpa
# 34   [LockModeType, TypedQuery, Query, EntityManager]         legacyjpa
# 35  [ConstraintViolation, Validation, ValidatorFac...      interceptors
# 36  [Validation, Validator, ConstraintViolation, V...  legacyvalidation
# 37              [Mapper, CannotResolveClassException]     serialization
# 38              [Document, ParsingException, Builder]               xml
# 39  [EntityNotFoundException, EntityManager, Query...         legacyjpa

# %% [markdown]
# ### Table 10 - Top 20 external package usage per type
#
# This table shows internal types that utilize the most different external types and packages. These have the highest probability of change depending on external libraries. A case-by-case approach is also advisable here because there could for example also be code units that encapsulate an external library and have this high count of external dependencies on purpose.
#
# Only the last 20 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_type`
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *fullPackageName* is the package within the artifact that contains the type that calls external types
# - *typeName* identifies the internal type within the package and artifact that calls external types
# - *numberOfExternalTypeCaller* and *numberOfExternalTypes* refers to the distinct external types that are used by the internal type
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfTypesInPackage* represents the total count of all types in that package
# - *numberOfExternalPackages* shows how many different external packages are used by the internal type
# - *externalPackageNames* contains the list of names of the different external packages that are used by the internal type
# - *externalTypeNames* contains a list of actually utilized types of the external package
# - *packageName* contains the name of the package (last part of *fullPackageName*)

# %%
external_package_usage_per_type = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_type.cypher")
external_package_usage_per_type.head(20)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.9.1
# 1       axon-messaging-4.9.1
# 2       axon-messaging-4.9.1
# 3       axon-messaging-4.9.1
# 4       axon-disruptor-4.9.1
# 5       axon-disruptor-4.9.1
# 6       axon-messaging-4.9.1
# 7       axon-messaging-4.9.1
# 8       axon-messaging-4.9.1
# 9       axon-messaging-4.9.1
# 10      axon-messaging-4.9.1
# 11      axon-messaging-4.9.1
# 12      axon-messaging-4.9.1
# 13      axon-messaging-4.9.1
# 14      axon-messaging-4.9.1
# 15      axon-messaging-4.9.1
# 16      axon-disruptor-4.9.1
# 17      axon-disruptor-4.9.1
# 18  axon-eventsourcing-4.9.1
# 19  axon-eventsourcing-4.9.1
#
#                                       fullPackageName  \
# 0                org.axonframework.serialization.json
# 1              org.axonframework.deadline.dbscheduler
# 2   org.axonframework.eventhandling.scheduling.dbs...
# 3                 org.axonframework.serialization.xml
# 4         org.axonframework.disruptor.commandhandling
# 5         org.axonframework.disruptor.commandhandling
# 6                  org.axonframework.deadline.jobrunr
# 7                   org.axonframework.deadline.quartz
# 8   org.axonframework.eventhandling.scheduling.job...
# 9           org.axonframework.messaging.responsetypes
# 10                    org.axonframework.queryhandling
# 11                    org.axonframework.queryhandling
# 12                    org.axonframework.serialization
# 13                    org.axonframework.serialization
# 14                    org.axonframework.serialization
# 15               org.axonframework.serialization.json
# 16        org.axonframework.disruptor.commandhandling
# 17        org.axonframework.disruptor.commandhandling
# 18     org.axonframework.eventsourcing.eventstore.jpa
# 19  org.axonframework.eventsourcing.eventstore.leg...
#
#                                              typeName  \
# 0                                   JacksonSerializer
# 1                          DbSchedulerDeadlineManager
# 2                           DbSchedulerEventScheduler
# 3                                   XStreamSerializer
# 4                                 DisruptorCommandBus
# 5             DisruptorCommandBus$DisruptorRepository
# 6                              JobRunrDeadlineManager
# 7                               QuartzDeadlineManager
# 8                               JobRunrEventScheduler
# 9                       MultipleInstancesResponseType
# 10                           SimpleQueryUpdateEmitter
# 11                                     SimpleQueryBus
# 12        AbstractXStreamSerializer$MetaDataConverter
# 13                     GapAwareTrackingTokenConverter
# 14  GapAwareTrackingTokenConverter$ReflectivelyCon...
# 15                               MetaDataDeserializer
# 16                         BlacklistDetectingCallback
# 17               DisruptorCommandBus$ExceptionHandler
# 18                              JpaEventStorageEngine
# 19                              JpaEventStorageEngine
#
#     numberOfExternalTypeCaller  numberOfExternalTypeCalls  \
# 0                            9                         29
# 1                           12                         93
# 2                           10                         46
# 3                            7                         22
# 4                            6                         34
# 5                            4                         14
# 6                            7                         29
# 7                           13                         78
# 8                            6                         27
# 9                            7                         17
# 10                          13                         33
# 11                           6                         54
# 12                           6                         14
# 13                           6                         25
# 14                           6                         25
# 15                           6                         21
# 16                           4                         11
# 17                           3                          5
# 18                           6                         47
# 19                           6                         47
#
#     numberOfExternalPackages  numberOfExternalTypes  \
# 0                          6                      9
# 1                          5                     12
# 2                          5                     10
# 3                          5                      7
# 4                          4                      6
# 5                          4                      4
# 6                          4                      7
# 7                          4                     13
# 8                          4                      6
# 9                          4                      7
# 10                         4                     13
# 11                         4                      6
# 12                         4                      6
# 13                         4                      6
# 14                         4                      6
# 15                         4                      6
# 16                         3                      4
# 17                         3                      3
# 18                         3                      6
# 19                         3                      6
#
#                                  externalPackageNames  \
# 0   [javax.annotation, com.fasterxml.jackson.datab...
# 1   [javax.annotation, org.slf4j, com.github.kagka...
# 2   [javax.annotation, org.slf4j, com.github.kagka...
# 3   [org.slf4j, com.thoughtworks.xstream, org.dom4...
# 4   [org.slf4j, com.lmax.disruptor, javax.annotati...
# 5   [org.slf4j, com.lmax.disruptor, javax.annotati...
# 6   [javax.annotation, org.slf4j, org.jobrunr.sche...
# 7   [javax.annotation, org.slf4j, org.quartz, org....
# 8   [javax.annotation, org.slf4j, org.jobrunr.sche...
# 9   [org.slf4j, com.fasterxml.jackson.annotation, ...
# 10  [javax.annotation, org.slf4j, org.reactivestre...
# 11  [javax.annotation, org.slf4j, org.reactivestre...
# 12  [com.thoughtworks.xstream.converters.collectio...
# 13  [com.thoughtworks.xstream.mapper, com.thoughtw...
# 14  [com.thoughtworks.xstream.mapper, com.thoughtw...
# 15  [com.fasterxml.jackson.databind.type, com.fast...
# 16  [org.slf4j, com.lmax.disruptor, javax.annotation]
# 17  [org.slf4j, com.lmax.disruptor.dsl, com.lmax.d...
# 18  [javax.annotation, org.slf4j, jakarta.persiste...
# 19   [javax.annotation, org.slf4j, javax.persistence]
#
#                                     externalTypeNames      packageName  \
# 0   [javax.annotation.Nonnull, com.fasterxml.jacks...             json
# 1   [javax.annotation.Nonnull, javax.annotation.Nu...      dbscheduler
# 2   [javax.annotation.Nonnull, org.slf4j.Logger, o...      dbscheduler
# 3   [org.slf4j.Logger, org.slf4j.LoggerFactory, co...              xml
# 4   [org.slf4j.LoggerFactory, org.slf4j.Logger, co...  commandhandling
# 5   [org.slf4j.Logger, com.lmax.disruptor.RingBuff...  commandhandling
# 6   [javax.annotation.Nonnull, javax.annotation.Nu...          jobrunr
# 7   [javax.annotation.Nonnull, org.slf4j.Logger, o...           quartz
# 8   [javax.annotation.Nonnull, org.slf4j.Logger, o...          jobrunr
# 9   [org.slf4j.Logger, org.slf4j.LoggerFactory, co...    responsetypes
# 10  [javax.annotation.Nonnull, org.slf4j.Logger, o...    queryhandling
# 11  [javax.annotation.Nonnull, org.slf4j.Logger, o...    queryhandling
# 12  [com.thoughtworks.xstream.converters.collectio...    serialization
# 13  [com.thoughtworks.xstream.mapper.Mapper, com.t...    serialization
# 14  [com.thoughtworks.xstream.mapper.Mapper, com.t...    serialization
# 15  [com.fasterxml.jackson.databind.type.TypeFacto...             json
# 16  [org.slf4j.LoggerFactory, org.slf4j.Logger, co...  commandhandling
# 17  [org.slf4j.Logger, com.lmax.disruptor.dsl.Disr...  commandhandling
# 18  [javax.annotation.Nonnull, org.slf4j.Logger, o...              jpa
# 19  [javax.annotation.Nonnull, org.slf4j.Logger, o...        legacyjpa
#
#                                          fullTypeName
# 0   org.axonframework.serialization.json.JacksonSe...
# 1   org.axonframework.deadline.dbscheduler.DbSched...
# 2   org.axonframework.eventhandling.scheduling.dbs...
# 3   org.axonframework.serialization.xml.XStreamSer...
# 4   org.axonframework.disruptor.commandhandling.Di...
# 5   org.axonframework.disruptor.commandhandling.Di...
# 6   org.axonframework.deadline.jobrunr.JobRunrDead...
# 7   org.axonframework.deadline.quartz.QuartzDeadli...
# 8   org.axonframework.eventhandling.scheduling.job...
# 9   org.axonframework.messaging.responsetypes.Mult...
# 10  org.axonframework.queryhandling.SimpleQueryUpd...
# 11     org.axonframework.queryhandling.SimpleQueryBus
# 12  org.axonframework.serialization.AbstractXStrea...
# 13  org.axonframework.serialization.GapAwareTracki...
# 14  org.axonframework.serialization.GapAwareTracki...
# 15  org.axonframework.serialization.json.MetaDataD...
# 16  org.axonframework.disruptor.commandhandling.Bl...
# 17  org.axonframework.disruptor.commandhandling.Di...
# 18  org.axonframework.eventsourcing.eventstore.jpa...
# 19  org.axonframework.eventsourcing.eventstore.leg...

# %% [markdown]
# ### Table 11 - External package usage distribution per type
#
# This table shows how many types use one external package, how many use two, etc. .
# This gives an overview of the distribution of external package calls and the overall coupling to external libraries. The higher the count of distinct external packages the lower should be the count of types that use them. Dependencies to external annotations are left out here.
#
# More details about which types have the highest external package dependency usage can be in the tables 4 and 5 above.
#
# Only the last 40 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_distribution`
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *artifactTypes* the total count of types in the artifact
# - *numberOfExternalPackages* the number of distinct external packages used
# - *numberOfTypes* in the artifact where the *numberOfExternalPackages* applies
# - *numberOfTypesPercentage* in the artifact where the *numberOfExternalPackages* applies in %

# %%
external_package_usage_per_artifact_distribution = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_distribution.cypher")
external_package_usage_per_artifact_distribution_truncated=external_package_usage_per_artifact_distribution[['artifactName', 'artifactPackages', 'artifactTypes', 'numberOfExternalPackages', 'numberOfPackages', 'numberOfTypes', 'typesCallingExternalRate', 'packagesCallingExternalRate']].head(40)
external_package_usage_per_artifact_distribution_truncated
# Out:
#                artifactName  artifactPackages  artifactTypes  \
# 0      axon-messaging-4.9.1                64            786
# 1      axon-modelling-4.9.1                10            156
# 2           axon-test-4.9.1                 8             87
# 3  axon-eventsourcing-4.9.1                 9            133
# 4  axon-configuration-4.9.1                 1             40
# 5      axon-disruptor-4.9.1                 1             22
#
#    numberOfExternalPackages  numberOfPackages  numberOfTypes  \
# 0                        42                44            155
# 1                         3                 7             12
# 2                        12                 6             36
# 3                         3                 5             15
# 4                         1                 1              6
# 5                         4                 1             10
#
#    typesCallingExternalRate  packagesCallingExternalRate
# 0                 19.720102                    68.750000
# 1                  7.692308                    70.000000
# 2                 41.379310                    75.000000
# 3                 11.278195                    55.555556
# 4                 15.000000                   100.000000
# 5                 45.454545                   100.000000

# %% [markdown]
# ### Table 12 - External package usage per artifact grouped by number of internal packages
#
# The following table shows the external package usage for every artifact grouped by the number of distinct internal dependent packages. The intention is to find external package usage spread across multiple internal packages in artifacts.
#
# Artifacts that encapsulate external dependency calls in one internal package overall (or each) are easier to change if those external dependencies change and are most likely applying a [Hexagonal architecture](https://alistair.cockburn.us/hexagonal-architecture). Artifacts that use external dependencies in multiple internal packages need more effort to adapt to changes of those external dependencies. On one hand this could be intended e.g. when using standardized libraries. On the other hand this might indicate higher than necessary coupling.
#
# The whole table can be found in the following CSV report:
# `External_package_usage_per_internal_package_count`

# %%
#external_package_usage_per_package_distribution = external_package_usage_per_artifact_distribution
external_package_usage_per_package_distribution = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_internal_package_count.cypher")

# Only show external dependencies that are at least used in 2 internal packages. 
# Filter out all rows with "numberOfPackages" <= 2.
external_package_usage_per_package_distribution=external_package_usage_per_package_distribution.query("`numberOfPackages` >= 2")
# Organize artifacts in columns with the number of packages that call external packages as values using pivot
# Every row represents the number of external packages
external_package_usage_per_package_distribution=external_package_usage_per_package_distribution.pivot(index='numberOfPackages', columns='artifactName', values='maxPackagesCallingExternalRate')

# Fill missing values with zero
external_package_usage_per_package_distribution.fillna(0, inplace=True)

external_package_usage_per_package_distribution
# Out:
# artifactName      axon-eventsourcing-4.9.1  axon-messaging-4.9.1  \
# numberOfPackages
# 2                                22.222222                3.1250
# 3                                33.333333                0.0000
# 4                                 0.000000                6.2500
# 5                                55.555556                0.0000
# 6                                66.666667                0.0000
# 7                                 0.000000               10.9375
# 11                                0.000000               17.1875
# 38                                0.000000               59.3750
# 47                                0.000000               73.4375
#
# artifactName      axon-modelling-4.9.1  axon-test-4.9.1
# numberOfPackages
# 2                                 20.0             25.0
# 3                                 30.0              0.0
# 4                                 40.0             50.0
# 5                                  0.0             62.5
# 6                                 60.0              0.0
# 7                                  0.0              0.0
# 11                                 0.0              0.0
# 38                                 0.0              0.0
# 47                                 0.0              0.0

# %% [markdown]
# ### Table 13 - External package usage aggregated
#
# This table lists all artifacts and their external package dependencies usage aggregated over internal packages.
#
# The intention behind this is to find artifacts that use an external dependency across multiple internal packages. This might be intended for frameworks and standardized libraries and helps to quantify how widely those are used. For some external dependencies it might be beneficial to only access it from one package and provide an abstraction for internal usage following a [Hexagonal architecture](https://alistair.cockburn.us/hexagonal-architecture). Thus, this table may also help in finding application for the Hexagonal architecture or similar approaches (Domain Driven Design Anti Corruption Layer). After all it is easier to update or replace such external dependencies when they are used in specific areas and not all over the code.
#
# Only the last 40 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_package_aggregated`
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *artifactPackages* is the total count of packages in the artifact
# - *artifactTypes* is the total count of types in the artifact
# - *numberOfExternalPackages* the number of distinct external packages used
# - *[min,max,med,avg,std]NumberOfPackages* provide statistics based on each external package and its package usage within the artifact
# - *[min,max,med,avg,std]NumberOfPackagesPercentage* provide statistics in % based on each external package and its package usage within the artifact in respect to the overall count of packages in the artifact
# - *[min,max,med,avg,std]NumberOfTypes* provide statistics based on each external package and its type usage within the artifact
# - *[min,max,med,avg,std]NumberOfTypePercentage* provide statistics in % based on each external package and its type usage within the artifact in respect to the overall count of packages in the artifact
# - *numberOfTypes* in the artifact where the *numberOfExternalPackages* applies
# - *numberOfTypesPercentage* in the artifact where the *numberOfExternalPackages* applies in %

# %% [markdown]
# #### Table 13a - External package usage aggregated - count of internal packages

# %%
external_package_usage_aggregated = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_package_aggregated.cypher")

external_package_usage_aggregated_packages = external_package_usage_aggregated[['artifactName', 'artifactPackages', 'numberOfExternalPackages', 'minNumberOfPackages', 'medNumberOfPackages', 'avgNumberOfPackages', 'maxNumberOfPackages', 'stdNumberOfPackages']]
external_package_usage_aggregated_packages.head(30)
# Out:
#                artifactName  artifactPackages  numberOfExternalPackages  \
# 0      axon-messaging-4.9.1                64                        42
# 1      axon-modelling-4.9.1                10                         3
# 2  axon-eventsourcing-4.9.1                 9                         3
# 3           axon-test-4.9.1                 8                        12
# 4  axon-configuration-4.9.1                 1                         1
# 5      axon-disruptor-4.9.1                 1                         4
#
#    minNumberOfPackages  medNumberOfPackages  avgNumberOfPackages  \
# 0                    1                  1.0             2.285714
# 1                    2                  3.0             3.666667
# 2                    1                  2.0             2.666667
# 3                    1                  1.0             1.416667
# 4                    1                  1.0             1.000000
# 5                    1                  1.0             1.000000
#
#    maxNumberOfPackages  stdNumberOfPackages
# 0                   38             5.688181
# 1                    6             2.081666
# 2                    5             2.081666
# 3                    5             1.164500
# 4                    1             0.000000
# 5                    1             0.000000

# %% [markdown]
# #### Table 13b - External package usage aggregated - percentage of internal packages

# %%
external_package_usage_aggregated_packages_percentage = external_package_usage_aggregated[['artifactName', 'artifactPackages', 'numberOfExternalPackages', 'minNumberOfPackagesPercentage', 'medNumberOfPackagesPercentage', 'avgNumberOfPackagesPercentage', 'maxNumberOfPackagesPercentage', 'stdNumberOfPackagesPercentage']]
external_package_usage_aggregated_packages_percentage.head(30)
# Out:
#                artifactName  artifactPackages  numberOfExternalPackages  \
# 0      axon-messaging-4.9.1                64                        42
# 1      axon-modelling-4.9.1                10                         3
# 2  axon-eventsourcing-4.9.1                 9                         3
# 3           axon-test-4.9.1                 8                        12
# 4  axon-configuration-4.9.1                 1                         1
# 5      axon-disruptor-4.9.1                 1                         4
#
#    minNumberOfPackagesPercentage  medNumberOfPackagesPercentage  \
# 0                       1.562500                       1.562500
# 1                      20.000000                      30.000000
# 2                      11.111111                      22.222222
# 3                      12.500000                      12.500000
# 4                     100.000000                     100.000000
# 5                     100.000000                     100.000000
#
#    avgNumberOfPackagesPercentage  maxNumberOfPackagesPercentage  \
# 0                       3.571429                      59.375000
# 1                      36.666667                      60.000000
# 2                      29.629630                      55.555556
# 3                      17.708333                      62.500000
# 4                     100.000000                     100.000000
# 5                     100.000000                     100.000000
#
#    stdNumberOfPackagesPercentage
# 0                       8.887782
# 1                      20.816660
# 2                      23.129622
# 3                      14.556252
# 4                       0.000000
# 5                       0.000000

# %% [markdown]
# #### Table 13c - External package usage aggregated - count of internal types

# %%
external_package_usage_aggregated_types = external_package_usage_aggregated[['artifactName', 'artifactTypes', 'numberOfExternalPackages', 'minNumberOfTypes', 'medNumberOfTypes', 'avgNumberOfTypes', 'maxNumberOfTypes', 'stdNumberOfTypes']]
external_package_usage_aggregated_types.head(30)
# Out:
#                artifactName  artifactTypes  numberOfExternalPackages  \
# 0      axon-messaging-4.9.1            786                        42
# 1      axon-modelling-4.9.1            156                         3
# 2  axon-eventsourcing-4.9.1            133                         3
# 3           axon-test-4.9.1             87                        12
# 4  axon-configuration-4.9.1             40                         1
# 5      axon-disruptor-4.9.1             22                         4
#
#    minNumberOfTypes  medNumberOfTypes  avgNumberOfTypes  maxNumberOfTypes  \
# 0                 1               2.5          5.309524                78
# 1                 3               3.0          5.000000                 9
# 2                 3               3.0          6.666667                14
# 3                 1               1.5          3.833333                27
# 4                 6               6.0          6.000000                 6
# 5                 1               5.5          5.000000                 8
#
#    stdNumberOfTypes
# 0         11.984722
# 1          3.464102
# 2          6.350853
# 3          7.346407
# 4          0.000000
# 5          3.162278

# %% [markdown]
# #### Table 13d - External package usage aggregated - percentage of internal types

# %%
external_package_usage_aggregated_types_percentage = external_package_usage_aggregated[['artifactName', 'artifactTypes', 'numberOfExternalPackages', 'minNumberOfTypesPercentage', 'medNumberOfTypesPercentage', 'avgNumberOfTypesPercentage', 'maxNumberOfTypesPercentage', 'stdNumberOfTypesPercentage']]
external_package_usage_aggregated_types_percentage.head(30)
# Out:
#                artifactName  artifactTypes  numberOfExternalPackages  \
# 0      axon-messaging-4.9.1            786                        42
# 1      axon-modelling-4.9.1            156                         3
# 2  axon-eventsourcing-4.9.1            133                         3
# 3           axon-test-4.9.1             87                        12
# 4  axon-configuration-4.9.1             40                         1
# 5      axon-disruptor-4.9.1             22                         4
#
#    minNumberOfTypesPercentage  medNumberOfTypesPercentage  \
# 0                    0.127226                    0.318066
# 1                    1.923077                    1.923077
# 2                    2.255639                    2.255639
# 3                    1.149425                    1.724138
# 4                   15.000000                   15.000000
# 5                    4.545455                   25.000000
#
#    avgNumberOfTypesPercentage  maxNumberOfTypesPercentage  \
# 0                    0.675512                    9.923664
# 1                    3.205128                    5.769231
# 2                    5.012531                   10.526316
# 3                    4.406130                   31.034483
# 4                   15.000000                   15.000000
# 5                   22.727273                   36.363636
#
#    stdNumberOfTypesPercentage
# 0                    1.524774
# 1                    2.220578
# 2                    4.775077
# 3                    8.444146
# 4                    0.000000
# 5                   14.373989

# %% [markdown]
# #### Table 13 Chart 1 - External package usage - max percentage of internal types
#
# This chart shows per artifact the maximum percentage of internal packages (compared to all packages in that artifact) that use one specific external package.
#
# **Example:** One artifact might use 10 external packages where 7 of them are used in one internal package, 2 of them are used in two packages and one external dependency is used in 5 packages. So for this artifact there will be a point at x = 10 (external packages used by the artifact) and 5 (max internal packages). Instead of the count the percentage of internal packages compared to all packages in that artifact is used to get a normalized plot.

# %%
def annotate_plot(data_frame: pd.DataFrame, index: int):
    """
    Annotates the data points identified by the "index" in the plot of the "data_frame" 
    """
    x_position = data_frame.numberOfExternalPackages[index].item()
    y_position = data_frame.maxNumberOfPackagesPercentage[index].item()
    artifact_name = data_frame.artifactName[index].item()

    label_box=dict(boxstyle="round4,pad=0.5", fc="w", alpha=0.8)
    plot.annotate(artifact_name
        ,xy=(x_position, y_position)
        ,xycoords='data'
        ,xytext=(-30, -15)
        ,textcoords='offset points'
        ,size=6
        ,bbox=label_box
        ,arrowprops=dict(arrowstyle="-|>", mutation_scale=10, color="black")
    )

def index_of_sorted(data_frame: pd.DataFrame, highest: list[str] = []):
    """
    Sorts the "data_frame" by columns 'numberOfExternalPackages','maxNumberOfPackagesPercentage','artifactPackages', 'artifactName'
    and returns the index of the first row.
    Columns that are contained in the list of strings parameter "highest" will be sorted descending (highest first).
    """
    by = ['numberOfExternalPackages','maxNumberOfPackagesPercentage','artifactPackages', 'artifactName']
    ascending = [('numberOfExternalPackages' not in highest), ('maxNumberOfPackagesPercentage' not in highest), False, True]
    return data_frame.sort_values(by=by, ascending=ascending).head(1).index

# %%
plot.figure();
axes = external_package_usage_aggregated.plot(
    kind='scatter',
    title='External package usage - max internal packages %', 
    x='numberOfExternalPackages',
    y='maxNumberOfPackagesPercentage',
    s='artifactPackages',
    c='stdNumberOfPackagesPercentage',
    xlabel='external package count',
    ylabel='max percentage of internal packages',
    cmap=main_color_map,
)

# Annotate the largest artifact with the highest number of external packages and max number of packages in percentage
annotation_index = index_of_sorted(highest=['numberOfExternalPackages','maxNumberOfPackagesPercentage'], data_frame=external_package_usage_aggregated)
annotate_plot(external_package_usage_aggregated, annotation_index)


# Annotate the largest artifact with the lowest number of external packages and the highest max number of packages in percentage
annotation_index = index_of_sorted(highest=['maxNumberOfPackagesPercentage'], data_frame=external_package_usage_aggregated)
annotate_plot(external_package_usage_aggregated, annotation_index)

# Annotate the largest artifact with the lowest number of external packages and max number of packages in percentage
annotation_index = index_of_sorted(highest=[], data_frame=external_package_usage_aggregated)
annotate_plot(external_package_usage_aggregated, annotation_index)


plot.show()

# %% [markdown]
# #### Table 13 Chart 2 - External package usage - median percentage of internal types
#
# This chart shows per artifact the median (0.5 percentile) of internal packages (compared to all packages in that artifact) that use one specific external package.
#
# **Example:** One artifact might use 9 external packages where 3 of them are used in 1 internal package, 3 of them are used in 2 package and the last 3 ones are used in 3 packages. So for this artifact there will be a point at x = 10 (external packages used by the artifact) and 2 (median internal packages). Instead of the count the percentage of internal packages compared to all packages in that artifact is used to get a normalized plot.

# %%
plot.figure();
axes = external_package_usage_aggregated.plot(
    kind='scatter',
    title='External package usage - median internal packages %', 
    x='numberOfExternalPackages',
    y='medNumberOfPackagesPercentage',
    s='artifactPackages',
    c='stdNumberOfPackagesPercentage',
    xlabel='external package count',
    ylabel='median percentage of internal packages',
    cmap=main_color_map,
)
plot.show()

# %% [markdown]
# ## Maven POMs
#
#
# ### Table 14 - Maven POMs and their declared dependencies
#
# If Maven is used as for package and dependency management and a ".pom" file is included in the artifact, the following table shows the external dependencies that are declared there.

# %%
query_cypher_to_data_frame("../cypher/External_Dependencies/Maven_POMs_and_their_declared_dependencies.cypher")
# Out:
#          pom.artifactId                        pom.name    scope  \
# 0    axon-configuration  Axon Framework - Configuration     test
# 1    axon-configuration  Axon Framework - Configuration  default
# 2    axon-configuration  Axon Framework - Configuration     test
# 3    axon-configuration  Axon Framework - Configuration  default
# 4    axon-configuration  Axon Framework - Configuration  default
# ..                  ...                             ...      ...
# 111           axon-test  Axon Framework - Test Fixtures  default
# 112           axon-test  Axon Framework - Test Fixtures  default
# 113           axon-test  Axon Framework - Test Fixtures     test
# 114           axon-test  Axon Framework - Test Fixtures  default
# 115           axon-test  Axon Framework - Test Fixtures  default
#
#      dependency.optional dependentArtifact.group dependentArtifact.name
# 0                  False      ${project.groupId}         axon-messaging
# 1                  False      ${project.groupId}         axon-disruptor
# 2                  False    org.quartz-scheduler                 quartz
# 3                  False       org.axonframework         axon-messaging
# 4                  False       org.axonframework         axon-modelling
# ..                   ...                     ...                    ...
# 111                 True            org.hamcrest               hamcrest
# 112                 True    com.google.code.gson                   gson
# 113                False     org.springframework           spring-beans
# 114                 True      org.testcontainers         testcontainers
# 115                 True            org.hamcrest       hamcrest-library
#
# [116 rows x 6 columns]

# %%
driver.close()
