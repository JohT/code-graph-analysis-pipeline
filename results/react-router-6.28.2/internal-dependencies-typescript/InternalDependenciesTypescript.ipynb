# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename : str, limit: int = 10_000):
    cypher_query_template = "{query}\nLIMIT {row_limit}"
    cypher_query = get_cypher_query_from_file(filename)
    cypher_query = cypher_query_template.format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = 10_000):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Pandas DataFrame Display Configuration
pd.set_option('display.max_colwidth', 300)

# %% [markdown]
# ## 1 - Modules
#
# List the modules this notebook is based on. Different sorting variations help finding modules by their features and support larger code bases where the list of all modules gets very long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_Typescript_modules`

# %%
internalModules = query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_all_Typescript_modules.cypher")

# %% [markdown]
# ### Table 1a - Top 30 modules with the highest element count

# %%
# Sort by number of modules descending
internalModules.sort_values(by=['numberOfElements','moduleName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#         rootProjectName           moduleName  numberOfElements  \
# 0   react-router-6.28.2     react-router-dom                62
# 1   react-router-6.28.2  react-router-native                17
# 2   react-router-6.28.2         react-router                 7
# 3   react-router-6.28.2                todos                 7
# 4   react-router-6.28.2               server                 6
# 5   react-router-6.28.2                snkrs                 4
# 6   react-router-6.28.2                 data                 3
# 7   react-router-6.28.2               images                 2
# 8   react-router-6.28.2               images                 2
# 9   react-router-6.28.2                  App                 1
# 10  react-router-6.28.2                 auth                 1
# 11  react-router-6.28.2                 auth                 1
#
#     numberOfGitCommits  incomingDependencies  outgoingDependencies
# 0                  423                    26                   308
# 1                  154                    10                    48
# 2                  251                     0                    34
# 3                    7                     0                     0
# 4                  164                     0                    76
# 5                    4                     0                     0
# 6                    8                     0                     0
# 7                    5                     0                     0
# 8                    4                     0                     0
# 9                    6                     0                     1
# 10                   5                     0                     0
# 11                   4                     0                     0

# %% [markdown]
# ### Table 1b - Top 30 modules with the highest number of incoming dependencies
#
# The following table lists the top 30 internal modules that are used the most by other modules (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
internalModules.sort_values(by=['incomingDependencies','moduleName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#         rootProjectName           moduleName  numberOfElements  \
# 0   react-router-6.28.2     react-router-dom                62
# 1   react-router-6.28.2  react-router-native                17
# 2   react-router-6.28.2                  App                 1
# 3   react-router-6.28.2                 auth                 1
# 4   react-router-6.28.2                 auth                 1
# 5   react-router-6.28.2                 data                 3
# 6   react-router-6.28.2               images                 2
# 7   react-router-6.28.2               images                 2
# 8   react-router-6.28.2         react-router                 7
# 9   react-router-6.28.2               server                 6
# 10  react-router-6.28.2                snkrs                 4
# 11  react-router-6.28.2                todos                 7
#
#     numberOfGitCommits  incomingDependencies  outgoingDependencies
# 0                  423                    26                   308
# 1                  154                    10                    48
# 2                    6                     0                     1
# 3                    5                     0                     0
# 4                    4                     0                     0
# 5                    8                     0                     0
# 6                    5                     0                     0
# 7                    4                     0                     0
# 8                  251                     0                    34
# 9                  164                     0                    76
# 10                   4                     0                     0
# 11                   7                     0                     0

# %% [markdown]
# ### Table 1c - Top 30 modules with the highest number of outgoing dependencies
#
# The following table lists the top 30 internal modules that are depending on the highest number of other modules (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
internalModules.sort_values(by=['outgoingDependencies','moduleName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#         rootProjectName           moduleName  numberOfElements  \
# 0   react-router-6.28.2     react-router-dom                62
# 1   react-router-6.28.2               server                 6
# 2   react-router-6.28.2  react-router-native                17
# 3   react-router-6.28.2         react-router                 7
# 4   react-router-6.28.2                  App                 1
# 5   react-router-6.28.2                 auth                 1
# 6   react-router-6.28.2                 auth                 1
# 7   react-router-6.28.2                 data                 3
# 8   react-router-6.28.2               images                 2
# 9   react-router-6.28.2               images                 2
# 10  react-router-6.28.2                snkrs                 4
# 11  react-router-6.28.2                todos                 7
#
#     numberOfGitCommits  incomingDependencies  outgoingDependencies
# 0                  423                    26                   308
# 1                  164                     0                    76
# 2                  154                    10                    48
# 3                  251                     0                    34
# 4                    6                     0                     1
# 5                    5                     0                     0
# 6                    4                     0                     0
# 7                    8                     0                     0
# 8                    5                     0                     0
# 9                    4                     0                     0
# 10                   4                     0                     0
# 11                   7                     0                     0

# %% [markdown]
# ### Table 1d - Top 30 modules with the lowest element count

# %%
# Sort by number of elements ascending
internalModules.sort_values(by=['numberOfElements','moduleName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#         rootProjectName           moduleName  numberOfElements  \
# 0   react-router-6.28.2                  App                 1
# 1   react-router-6.28.2                 auth                 1
# 2   react-router-6.28.2                 auth                 1
# 3   react-router-6.28.2               images                 2
# 4   react-router-6.28.2               images                 2
# 5   react-router-6.28.2                 data                 3
# 6   react-router-6.28.2                snkrs                 4
# 7   react-router-6.28.2               server                 6
# 8   react-router-6.28.2         react-router                 7
# 9   react-router-6.28.2                todos                 7
# 10  react-router-6.28.2  react-router-native                17
# 11  react-router-6.28.2     react-router-dom                62
#
#     numberOfGitCommits  incomingDependencies  outgoingDependencies
# 0                    6                     0                     1
# 1                    5                     0                     0
# 2                    4                     0                     0
# 3                    5                     0                     0
# 4                    4                     0                     0
# 5                    8                     0                     0
# 6                    4                     0                     0
# 7                  164                     0                    76
# 8                  251                     0                    34
# 9                    7                     0                     0
# 10                 154                    10                    48
# 11                 423                    26                   308

# %% [markdown]
# ### Table 1e - Top 30 modules with the lowest number of incoming dependencies
#
# The following table lists the top 30 internal modules that are used the least by other modules (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
internalModules.sort_values(by=['incomingDependencies','moduleName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#         rootProjectName           moduleName  numberOfElements  \
# 0   react-router-6.28.2                  App                 1
# 1   react-router-6.28.2                 auth                 1
# 2   react-router-6.28.2                 auth                 1
# 3   react-router-6.28.2                 data                 3
# 4   react-router-6.28.2               images                 2
# 5   react-router-6.28.2               images                 2
# 6   react-router-6.28.2         react-router                 7
# 7   react-router-6.28.2               server                 6
# 8   react-router-6.28.2                snkrs                 4
# 9   react-router-6.28.2                todos                 7
# 10  react-router-6.28.2  react-router-native                17
# 11  react-router-6.28.2     react-router-dom                62
#
#     numberOfGitCommits  incomingDependencies  outgoingDependencies
# 0                    6                     0                     1
# 1                    5                     0                     0
# 2                    4                     0                     0
# 3                    8                     0                     0
# 4                    5                     0                     0
# 5                    4                     0                     0
# 6                  251                     0                    34
# 7                  164                     0                    76
# 8                    4                     0                     0
# 9                    7                     0                     0
# 10                 154                    10                    48
# 11                 423                    26                   308

# %% [markdown]
# ### Table 1f - Top 30 modules with the lowest number of outgoing dependencies
#
# The following table lists the top 30 internal modules that are depending on the lowest number of other modules (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
internalModules.sort_values(by=['outgoingDependencies','moduleName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#         rootProjectName           moduleName  numberOfElements  \
# 0   react-router-6.28.2                 auth                 1
# 1   react-router-6.28.2                 auth                 1
# 2   react-router-6.28.2                 data                 3
# 3   react-router-6.28.2               images                 2
# 4   react-router-6.28.2               images                 2
# 5   react-router-6.28.2                snkrs                 4
# 6   react-router-6.28.2                todos                 7
# 7   react-router-6.28.2                  App                 1
# 8   react-router-6.28.2         react-router                 7
# 9   react-router-6.28.2  react-router-native                17
# 10  react-router-6.28.2               server                 6
# 11  react-router-6.28.2     react-router-dom                62
#
#     numberOfGitCommits  incomingDependencies  outgoingDependencies
# 0                    5                     0                     0
# 1                    4                     0                     0
# 2                    8                     0                     0
# 3                    5                     0                     0
# 4                    4                     0                     0
# 5                    4                     0                     0
# 6                    7                     0                     0
# 7                    6                     0                     1
# 8                  251                     0                    34
# 9                  154                    10                    48
# 10                 164                     0                    76
# 11                 423                    26                   308

# %% [markdown]
# ## 2 - Cyclic Dependencies
#
# Cyclic dependencies occur when one module uses an elements of another module and vice versa.
# These dependencies can lead to problems when one of these modules needs to be changed.

# %% [markdown]
# ### Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_for_Typescript`
#
# **Columns:**
# - *projectFileName* identifies the project of the first participant of the cycle
# - *modulePathName* identifies the module of the first participant of the cycle
# - *dependentProjectFileName* identifies the project of the second participant of the cycle
# - *dependentModulePathName* identifies the module of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_for_Typescript.cypher")
cyclic_dependencies.head(40)
# Out:
#     projectFileName   moduleName dependentProjectFileName  \
# 0  react-router-dom  ./index.tsx      react-router-native
#
#   dependentModulePathName  forwardToBackwardBalance  numberForward  \
# 0             ./index.tsx                  0.222222             11
#
#    numberBackward  \
# 0               7
#
#                                                                                                                                                                                                                                         forwardDependencyExamples  \
# 0  [useFormAction->useLocation, NavLink->useLocation, useLinkClickHandler->useLocation, useScrollRestoration->useLocation, useSearchParams->useLocation, SetURLSearchParams->NavigateOptions, LinkProps->To, useLinkClickHandler->To, useViewTransitionState->To]
#
#                                                                                                                                                                                  backwardDependencyExamples
# 0  [To<-LinkProps, useNavigate<-useLinkPressHandler, To<-useLinkPressHandler, useNavigate<-useDeepLinking, useNavigate<-useSearchParams, useLocation<-useSearchParams, NavigateOptions<-SetURLSearchParams]

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists modules with cyclic dependencies with every dependency in a separate row sorted by the most promising dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_for_Typescript`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_for_Typescript.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#      projectFileName   moduleName dependentProjectFileName  \
# 0   react-router-dom  ./index.tsx      react-router-native
# 1   react-router-dom  ./index.tsx      react-router-native
# 2   react-router-dom  ./index.tsx      react-router-native
# 3   react-router-dom  ./index.tsx      react-router-native
# 4   react-router-dom  ./index.tsx      react-router-native
# 5   react-router-dom  ./index.tsx      react-router-native
# 6   react-router-dom  ./index.tsx      react-router-native
# 7   react-router-dom  ./index.tsx      react-router-native
# 8   react-router-dom  ./index.tsx      react-router-native
# 9   react-router-dom  ./index.tsx      react-router-native
# 10  react-router-dom  ./index.tsx      react-router-native
# 11  react-router-dom  ./index.tsx      react-router-native
# 12  react-router-dom  ./index.tsx      react-router-native
# 13  react-router-dom  ./index.tsx      react-router-native
# 14  react-router-dom  ./index.tsx      react-router-native
# 15  react-router-dom  ./index.tsx      react-router-native
# 16  react-router-dom  ./index.tsx      react-router-native
# 17  react-router-dom  ./index.tsx      react-router-native
#
#    dependentModulePathName                           dependency  \
# 0              ./index.tsx                        To<-LinkProps
# 1              ./index.tsx     useNavigate<-useLinkPressHandler
# 2              ./index.tsx              To<-useLinkPressHandler
# 3              ./index.tsx          useNavigate<-useDeepLinking
# 4              ./index.tsx         useNavigate<-useSearchParams
# 5              ./index.tsx         useLocation<-useSearchParams
# 6              ./index.tsx  NavigateOptions<-SetURLSearchParams
# 7              ./index.tsx           useFormAction->useLocation
# 8              ./index.tsx                 NavLink->useLocation
# 9              ./index.tsx     useLinkClickHandler->useLocation
# 10             ./index.tsx    useScrollRestoration->useLocation
# 11             ./index.tsx         useSearchParams->useLocation
# 12             ./index.tsx  SetURLSearchParams->NavigateOptions
# 13             ./index.tsx                        LinkProps->To
# 14             ./index.tsx              useLinkClickHandler->To
# 15             ./index.tsx           useViewTransitionState->To
# 16             ./index.tsx         useSearchParams->useNavigate
# 17             ./index.tsx     useLinkClickHandler->useNavigate
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.222222             11               7
# 1                   0.222222             11               7
# 2                   0.222222             11               7
# 3                   0.222222             11               7
# 4                   0.222222             11               7
# 5                   0.222222             11               7
# 6                   0.222222             11               7
# 7                   0.222222             11               7
# 8                   0.222222             11               7
# 9                   0.222222             11               7
# 10                  0.222222             11               7
# 11                  0.222222             11               7
# 12                  0.222222             11               7
# 13                  0.222222             11               7
# 14                  0.222222             11               7
# 15                  0.222222             11               7
# 16                  0.222222             11               7
# 17                  0.222222             11               7

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists modules with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly_for_Typescript`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only_for_Typescript.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#     projectFileName   moduleName dependentProjectFileName  \
# 0  react-router-dom  ./index.tsx      react-router-native
# 1  react-router-dom  ./index.tsx      react-router-native
# 2  react-router-dom  ./index.tsx      react-router-native
# 3  react-router-dom  ./index.tsx      react-router-native
# 4  react-router-dom  ./index.tsx      react-router-native
# 5  react-router-dom  ./index.tsx      react-router-native
# 6  react-router-dom  ./index.tsx      react-router-native
#
#   dependentModulePathName                           dependency  \
# 0             ./index.tsx                        To<-LinkProps
# 1             ./index.tsx     useNavigate<-useLinkPressHandler
# 2             ./index.tsx              To<-useLinkPressHandler
# 3             ./index.tsx          useNavigate<-useDeepLinking
# 4             ./index.tsx         useNavigate<-useSearchParams
# 5             ./index.tsx         useLocation<-useSearchParams
# 6             ./index.tsx  NavigateOptions<-SetURLSearchParams
#
#    forwardToBackwardBalance  numberForward  numberBackward
# 0                  0.222222             11               7
# 1                  0.222222             11               7
# 2                  0.222222             11               7
# 3                  0.222222             11               7
# 4                  0.222222             11               7
# 5                  0.222222             11               7
# 6                  0.222222             11               7

# %% [markdown]
# ## 3 - Module Usage

# %% [markdown]
# ### Table 3a - Elements that are used by multiple modules
#
# This table shows the top 40 modules that are used by the highest number of different modules. The whole table can be found in the CSV report `WidelyUsedTypescriptElements`.

# %%
elements_used_by_many_modules=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_elements_that_are_used_by_many_different_modules_for_Typescript.cypher", limit=40)
elements_used_by_many_modules
# Out:
#           fullQualifiedDependentElementName dependentElementModuleName  \
# 0       "@remix-run/router".NavigateOptions                     router
# 1                "@remix-run/router".Router                     router
# 2                    "@remix-run/router".To                     router
# 3           "@remix-run/router".useLocation                     router
# 4           "@remix-run/router".useNavigate                     router
# 5  "@remix-run/router".DataStrategyFunction                     router
# 6           "@remix-run/router".RouteObject                     router
# 7           "@remix-run/router".RouteObject                     router
# 8                "@remix-run/router".Router                     router
#
#    dependentElementName dependentElementLabels  numberOfUsingModules
# 0       NavigateOptions    ExternalDeclaration                     2
# 1                Router    ExternalDeclaration                     2
# 2                    To    ExternalDeclaration                     2
# 3           useLocation    ExternalDeclaration                     2
# 4           useNavigate    ExternalDeclaration                     2
# 5  DataStrategyFunction    ExternalDeclaration                     1
# 6           RouteObject    ExternalDeclaration                     1
# 7           RouteObject    ExternalDeclaration                     1
# 8                Router    ExternalDeclaration                     1

# %% [markdown]
# ### Table 3b - Elements that are used by multiple modules
#
# This table shows the top 30 modules that only use a few (compared to all existing) elements of another module.
# The whole table can be found in the CSV report `ModuleElementsUsageTypescript`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_elements_compared_to_all_existing_are_used_by_dependent_modules_for_Typescript.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#       sourceModuleName  dependentModuleName  dependentElementsCount  \
# 0               server     react-router-dom                       2
# 1         react-router     react-router-dom                       2
# 2  react-router-native     react-router-dom                       4
# 3     react-router-dom  react-router-native                       4
#
#    dependentModuleElementsCount  elementUsagePercentage  \
# 0                            62                0.032258
# 1                            62                0.032258
# 2                            62                0.064516
# 3                            17                0.235294
#
#                                                                                                   dependentElementFullNameExamples  \
# 0                                                                    ["@remix-run/router".RouteObject, "@remix-run/router".Router]
# 1                                                           ["@remix-run/router".DataStrategyFunction, "@remix-run/router".Router]
# 2  ["@remix-run/router".useNavigate, "@remix-run/router".NavigateOptions, "@remix-run/router".useLocation, "@remix-run/router".To]
# 3  ["@remix-run/router".useLocation, "@remix-run/router".NavigateOptions, "@remix-run/router".To, "@remix-run/router".useNavigate]
#
#                       dependentElementNameExamples
# 0                            [RouteObject, Router]
# 1                   [DataStrategyFunction, Router]
# 2  [useNavigate, NavigateOptions, useLocation, To]
# 3  [useLocation, NavigateOptions, To, useNavigate]

# %% [markdown]
# ### Table 3c - Distance distribution between dependent files
#
# This table shows the file directory distance distribution between dependent files. Intuitively, the distance is given by the fewest number of change directory commands needed to navigate between a file and a dependency it uses. Those are aggregate to see how many dependent files are in the same directory, how many are just one change directory command apart, and so on.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Internal_Dependencies/Get_file_distance_as_shortest_contains_path_for_dependencies.cypher",
                                           "../cypher/Internal_Dependencies/Set_file_distance_as_shortest_contains_path_for_dependencies.cypher", limit=20)
# Out:
#    dependency.fileDistanceAsFewestChangeDirectoryCommands  \
# 0                                                       0
# 1                                                       4
#
#    numberOfDependencies  numberOfDependencyUsers  numberOfDependencyProviders  \
# 0                     1                        1                            1
# 1                     4                        4                            2
#
#                                                                                                                    examples
# 0                                                                                           [./server.tsx uses ./index.tsx]
# 1  [./index.ts uses ./index.tsx, ./index.tsx uses ./index.tsx, ./server.tsx uses ./index.tsx, ./index.tsx uses ./index.tsx]
