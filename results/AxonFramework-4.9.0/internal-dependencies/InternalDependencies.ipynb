# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename : str, limit: int = 10_000):
    cypher_query_template = "{query} LIMIT {row_limit}"
    cypher_query = get_cypher_query_from_file(filename)
    cypher_query = cypher_query_template.format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Artifacts
#
# List the artifacts this notebook is based on. Different sorting variations help finding artifacts by their features and support larger code bases where the list of all artifacts gets too long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_existing_artifacts`

# %%
artifacts = query_cypher_to_data_frame("../cypher/List_all_existing_artifacts.cypher")

# %% [markdown]
# ### Table 1a - Top 30 artifacts with the highest package count

# %%
# Sort by number of packages descending
artifacts.sort_values(by=['packages','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0      axon-messaging-4.9.0.jar        64    786                     5
# 1      axon-modelling-4.9.0.jar        10    156                     4
# 2  axon-eventsourcing-4.9.0.jar         9    133                     3
# 3           axon-test-4.9.0.jar         8     87                     0
# 4  axon-configuration-4.9.0.jar         1     40                     0
# 5      axon-disruptor-4.9.0.jar         1     22                     1
#
#    outgoingDependencies
# 0                     0
# 1                     1
# 2                     2
# 3                     3
# 4                     4
# 5                     3

# %% [markdown]
# ### Table 1b - Top 30 artifacts with the highest type count

# %%
# Sort by number of types descending
artifacts.sort_values(by=['types','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0      axon-messaging-4.9.0.jar        64    786                     5
# 1      axon-modelling-4.9.0.jar        10    156                     4
# 2  axon-eventsourcing-4.9.0.jar         9    133                     3
# 3           axon-test-4.9.0.jar         8     87                     0
# 4  axon-configuration-4.9.0.jar         1     40                     0
# 5      axon-disruptor-4.9.0.jar         1     22                     1
#
#    outgoingDependencies
# 0                     0
# 1                     1
# 2                     2
# 3                     3
# 4                     4
# 5                     3

# %% [markdown]
# ### Table 1c - Top 30 artifacts with the highest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the most by other artifacts (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0      axon-messaging-4.9.0.jar        64    786                     5
# 1      axon-modelling-4.9.0.jar        10    156                     4
# 2  axon-eventsourcing-4.9.0.jar         9    133                     3
# 3      axon-disruptor-4.9.0.jar         1     22                     1
# 4  axon-configuration-4.9.0.jar         1     40                     0
# 5           axon-test-4.9.0.jar         8     87                     0
#
#    outgoingDependencies
# 0                     0
# 1                     1
# 2                     2
# 3                     3
# 4                     4
# 5                     3

# %% [markdown]
# ### Table 1d - Top 30 artifacts with the highest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the highest number of other artifacts (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0  axon-configuration-4.9.0.jar         1     40                     0
# 1      axon-disruptor-4.9.0.jar         1     22                     1
# 2           axon-test-4.9.0.jar         8     87                     0
# 3  axon-eventsourcing-4.9.0.jar         9    133                     3
# 4      axon-modelling-4.9.0.jar        10    156                     4
# 5      axon-messaging-4.9.0.jar        64    786                     5
#
#    outgoingDependencies
# 0                     4
# 1                     3
# 2                     3
# 3                     2
# 4                     1
# 5                     0

# %% [markdown]
# ### Table 1e - Top 30 artifacts with the lowest package count

# %%
# Sort by number of packages ascending
artifacts.sort_values(by=['packages','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0  axon-configuration-4.9.0.jar         1     40                     0
# 1      axon-disruptor-4.9.0.jar         1     22                     1
# 2           axon-test-4.9.0.jar         8     87                     0
# 3  axon-eventsourcing-4.9.0.jar         9    133                     3
# 4      axon-modelling-4.9.0.jar        10    156                     4
# 5      axon-messaging-4.9.0.jar        64    786                     5
#
#    outgoingDependencies
# 0                     4
# 1                     3
# 2                     3
# 3                     2
# 4                     1
# 5                     0

# %% [markdown]
# ### Table 1f - Top 30 artifacts with the lowest type count

# %%
# Sort by number of types ascending
artifacts.sort_values(by=['types','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0      axon-disruptor-4.9.0.jar         1     22                     1
# 1  axon-configuration-4.9.0.jar         1     40                     0
# 2           axon-test-4.9.0.jar         8     87                     0
# 3  axon-eventsourcing-4.9.0.jar         9    133                     3
# 4      axon-modelling-4.9.0.jar        10    156                     4
# 5      axon-messaging-4.9.0.jar        64    786                     5
#
#    outgoingDependencies
# 0                     3
# 1                     4
# 2                     3
# 3                     2
# 4                     1
# 5                     0

# %% [markdown]
# ### Table 1g - Top 30 artifacts with the lowest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the least by other artifacts (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0  axon-configuration-4.9.0.jar         1     40                     0
# 1           axon-test-4.9.0.jar         8     87                     0
# 2      axon-disruptor-4.9.0.jar         1     22                     1
# 3  axon-eventsourcing-4.9.0.jar         9    133                     3
# 4      axon-modelling-4.9.0.jar        10    156                     4
# 5      axon-messaging-4.9.0.jar        64    786                     5
#
#    outgoingDependencies
# 0                     4
# 1                     3
# 2                     3
# 3                     2
# 4                     1
# 5                     0

# %% [markdown]
# ### Table 1h - Top 30 artifacts with the lowest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the lowest number of other artifacts (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                    artifactName  packages  types  incomingDependencies  \
# 0      axon-messaging-4.9.0.jar        64    786                     5
# 1      axon-modelling-4.9.0.jar        10    156                     4
# 2  axon-eventsourcing-4.9.0.jar         9    133                     3
# 3      axon-disruptor-4.9.0.jar         1     22                     1
# 4           axon-test-4.9.0.jar         8     87                     0
# 5  axon-configuration-4.9.0.jar         1     40                     0
#
#    outgoingDependencies
# 0                     0
# 1                     1
# 2                     2
# 3                     3
# 4                     3
# 5                     4

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to problems when one of these packages needs to be changed.

# %% [markdown]
# ## Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies`
#
# **Columns:**
# - *artifactName* identifies the artifact of the first participant of the cycle
# - *packageName* identifies the package of the first participant of the cycle
# - *dependentArtifactName* identifies the artifact of the second participant of the cycle
# - *dependentPackageName* identifies the package of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies.cypher")
cyclic_dependencies.head(40)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.9.0
# 1       axon-messaging-4.9.0
# 2       axon-messaging-4.9.0
# 3       axon-messaging-4.9.0
# 4       axon-messaging-4.9.0
# 5       axon-messaging-4.9.0
# 6       axon-messaging-4.9.0
# 7   axon-eventsourcing-4.9.0
# 8       axon-messaging-4.9.0
# 9       axon-messaging-4.9.0
# 10      axon-messaging-4.9.0
# 11      axon-messaging-4.9.0
# 12      axon-messaging-4.9.0
# 13      axon-messaging-4.9.0
# 14  axon-eventsourcing-4.9.0
# 15      axon-messaging-4.9.0
# 16      axon-modelling-4.9.0
# 17      axon-messaging-4.9.0
# 18      axon-messaging-4.9.0
# 19      axon-messaging-4.9.0
# 20      axon-modelling-4.9.0
# 21      axon-messaging-4.9.0
#
#                                           packageName  \
# 0                     org.axonframework.eventhandling
# 1                     org.axonframework.queryhandling
# 2                     org.axonframework.queryhandling
# 3                     org.axonframework.eventhandling
# 4                     org.axonframework.eventhandling
# 5                          org.axonframework.deadline
# 6                   org.axonframework.commandhandling
# 7                     org.axonframework.eventsourcing
# 8         org.axonframework.commandhandling.callbacks
# 9                     org.axonframework.eventhandling
# 10             org.axonframework.messaging.unitofwork
# 11              org.axonframework.eventhandling.async
# 12             org.axonframework.eventhandling.replay
# 13    org.axonframework.serialization.upcasting.event
# 14    org.axonframework.eventsourcing.eventstore.jdbc
# 15                    org.axonframework.eventhandling
# 16     org.axonframework.modelling.command.inspection
# 17       org.axonframework.queryhandling.registration
# 18                        org.axonframework.messaging
# 19             org.axonframework.messaging.annotation
# 20                   org.axonframework.modelling.saga
# 21  org.axonframework.commandhandling.distributed....
#
#        dependentArtifactName  \
# 0       axon-messaging-4.9.0
# 1       axon-messaging-4.9.0
# 2       axon-messaging-4.9.0
# 3       axon-messaging-4.9.0
# 4       axon-messaging-4.9.0
# 5       axon-messaging-4.9.0
# 6       axon-messaging-4.9.0
# 7   axon-eventsourcing-4.9.0
# 8       axon-messaging-4.9.0
# 9       axon-messaging-4.9.0
# 10      axon-messaging-4.9.0
# 11      axon-messaging-4.9.0
# 12      axon-messaging-4.9.0
# 13      axon-messaging-4.9.0
# 14  axon-eventsourcing-4.9.0
# 15      axon-messaging-4.9.0
# 16      axon-modelling-4.9.0
# 17      axon-messaging-4.9.0
# 18      axon-messaging-4.9.0
# 19      axon-messaging-4.9.0
# 20      axon-modelling-4.9.0
# 21      axon-messaging-4.9.0
#
#                                  dependentPackageName  \
# 0                           org.axonframework.tracing
# 1           org.axonframework.messaging.responsetypes
# 2                           org.axonframework.tracing
# 3                         org.axonframework.messaging
# 4              org.axonframework.messaging.annotation
# 5                           org.axonframework.tracing
# 6                           org.axonframework.tracing
# 7          org.axonframework.eventsourcing.eventstore
# 8                   org.axonframework.commandhandling
# 9                     org.axonframework.serialization
# 10                        org.axonframework.messaging
# 11                    org.axonframework.eventhandling
# 12                    org.axonframework.eventhandling
# 13                    org.axonframework.eventhandling
# 14  org.axonframework.eventsourcing.eventstore.jdb...
# 15         org.axonframework.eventhandling.tokenstore
# 16                org.axonframework.modelling.command
# 17                    org.axonframework.queryhandling
# 18                    org.axonframework.serialization
# 19           org.axonframework.messaging.interceptors
# 20         org.axonframework.modelling.saga.metamodel
# 21      org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.840000             23               2
# 5                   0.800000              9               1
# 6                   0.777778              8               1
# 7                   0.777778             16               2
# 8                   0.733333             13               2
# 9                   0.647059             14               3
# 10                  0.647059             14               3
# 11                  0.538462             10               3
# 12                  0.454545              8               3
# 13                  0.333333              6               3
# 14                  0.317073             27              14
# 15                  0.285714              9               5
# 16                  0.250000             20              12
# 17                  0.250000              5               3
# 18                  0.238095             13               8
# 19                  0.200000              3               2
# 20                  0.142857              4               3
# 21                  0.076923              7               6
#
#                               someForwardDependencies  \
# 0   [SimpleEventBus$Builder->SpanFactory, Abstract...
# 1   [DefaultQueryGateway->ResponseType, QueryMessa...
# 2   [DefaultQueryBusSpanFactory->SpanFactory, Defa...
# 3   [SubscribingEventProcessor->SubscribableMessag...
# 4   [TrackingTokenParameterResolverFactory->Parame...
# 5   [DefaultDeadlineManagerSpanFactory$Builder->Sp...
# 6   [SimpleCommandBus$Builder->SpanFactory, Simple...
# 7   [EventSourcingRepository->EventStore, EventSou...
# 8   [LoggingCallback->CommandResultMessage, Loggin...
# 9   [EventUtils->SerializedMessage, EventUtils->Se...
# 10  [UnitOfWork->ResultMessage, UnitOfWork->Messag...
# 11  [PropertySequencingPolicy->EventMessage, Event...
# 12  [ReplayContextParameterResolverFactory$ReplayC...
# 13  [IntermediateEventRepresentation->TrackingToke...
# 14  [JdbcEventStorageEngine$Builder->CreateHeadTok...
# 15  [TrackingEventProcessor$Instruction->UnableToC...
# 16  [AbstractChildEntityDefinition->AggregateMembe...
# 17  [DuplicateQueryHandlerResolution->QuerySubscri...
# 18  [MessageDecorator->SerializedObject, MessageDe...
# 19  [MessageHandlerInterceptorDefinition->ResultHa...
# 20  [AnnotatedSagaManager$Builder->AnnotationSagaM...
# 21  [AcceptAll->CommandMessageFilter, DenyCommandN...
#
#                                  backwardDependencies
# 0                  [NestingSpanFactory->EventMessage]
# 1   [ConvertingResponseMessage->QueryResponseMessage]
# 2                           [SpanUtils->QueryMessage]
# 3   [StreamableMessageSource->TrackingToken, Heade...
# 4   [SourceIdParameterResolverFactory$SourceIdPara...
# 5                        [SpanUtils->DeadlineMessage]
# 6                         [SpanUtils->CommandMessage]
# 7   [AbstractEventStorageEngine->EventStreamUtils,...
# 8   [SimpleCommandBus$Builder->LoggingCallback, Si...
# 9   [AbstractXStreamSerializer->GenericEventMessag...
# 10  [DefaultInterceptorChain->UnitOfWork, MessageH...
# 11  [SimpleEventHandlerInvoker$Builder->Sequential...
# 12  [ResetHandler->ResetContext, AnnotationEventHa...
# 13  [EventUtils->IntermediateEventRepresentation, ...
# 14  [FetchTrackedEventsStatementBuilder->EventSche...
# 15  [TokenStore->TrackingToken, AbstractTokenEntry...
# 16  [GenericJpaRepository->AnnotatedAggregate, Agg...
# 17  [SimpleQueryBus$Builder->DuplicateQueryHandler...
# 18  [SerializedMessage->MetaData, SerializedMetaDa...
# 19  [ResultHandler->HasHandlerAttributes, MessageH...
# 20  [AnnotationSagaMetaModelFactory$InspectedSagaM...
# 21  [DistributedCommandBus->DenyCommandNameFilter,...

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#             artifactName                      packageName  \
# 0   axon-messaging-4.9.0  org.axonframework.eventhandling
# 1   axon-messaging-4.9.0  org.axonframework.eventhandling
# 2   axon-messaging-4.9.0  org.axonframework.eventhandling
# 3   axon-messaging-4.9.0  org.axonframework.eventhandling
# 4   axon-messaging-4.9.0  org.axonframework.eventhandling
# 5   axon-messaging-4.9.0  org.axonframework.eventhandling
# 6   axon-messaging-4.9.0  org.axonframework.eventhandling
# 7   axon-messaging-4.9.0  org.axonframework.eventhandling
# 8   axon-messaging-4.9.0  org.axonframework.eventhandling
# 9   axon-messaging-4.9.0  org.axonframework.eventhandling
# 10  axon-messaging-4.9.0  org.axonframework.eventhandling
# 11  axon-messaging-4.9.0  org.axonframework.eventhandling
# 12  axon-messaging-4.9.0  org.axonframework.eventhandling
# 13  axon-messaging-4.9.0  org.axonframework.eventhandling
# 14  axon-messaging-4.9.0  org.axonframework.eventhandling
# 15  axon-messaging-4.9.0  org.axonframework.eventhandling
# 16  axon-messaging-4.9.0  org.axonframework.eventhandling
# 17  axon-messaging-4.9.0  org.axonframework.eventhandling
# 18  axon-messaging-4.9.0  org.axonframework.eventhandling
# 19  axon-messaging-4.9.0  org.axonframework.eventhandling
# 20  axon-messaging-4.9.0  org.axonframework.queryhandling
# 21  axon-messaging-4.9.0  org.axonframework.queryhandling
# 22  axon-messaging-4.9.0  org.axonframework.queryhandling
# 23  axon-messaging-4.9.0  org.axonframework.queryhandling
# 24  axon-messaging-4.9.0  org.axonframework.queryhandling
# 25  axon-messaging-4.9.0  org.axonframework.queryhandling
# 26  axon-messaging-4.9.0  org.axonframework.queryhandling
# 27  axon-messaging-4.9.0  org.axonframework.queryhandling
# 28  axon-messaging-4.9.0  org.axonframework.queryhandling
# 29  axon-messaging-4.9.0  org.axonframework.queryhandling
# 30  axon-messaging-4.9.0  org.axonframework.queryhandling
# 31  axon-messaging-4.9.0  org.axonframework.queryhandling
# 32  axon-messaging-4.9.0  org.axonframework.queryhandling
# 33  axon-messaging-4.9.0  org.axonframework.queryhandling
# 34  axon-messaging-4.9.0  org.axonframework.queryhandling
# 35  axon-messaging-4.9.0  org.axonframework.queryhandling
# 36  axon-messaging-4.9.0  org.axonframework.queryhandling
# 37  axon-messaging-4.9.0  org.axonframework.queryhandling
# 38  axon-messaging-4.9.0  org.axonframework.queryhandling
# 39  axon-messaging-4.9.0  org.axonframework.queryhandling
#
#    dependentArtifactName                       dependentPackageName  \
# 0   axon-messaging-4.9.0                  org.axonframework.tracing
# 1   axon-messaging-4.9.0                  org.axonframework.tracing
# 2   axon-messaging-4.9.0                  org.axonframework.tracing
# 3   axon-messaging-4.9.0                  org.axonframework.tracing
# 4   axon-messaging-4.9.0                  org.axonframework.tracing
# 5   axon-messaging-4.9.0                  org.axonframework.tracing
# 6   axon-messaging-4.9.0                  org.axonframework.tracing
# 7   axon-messaging-4.9.0                  org.axonframework.tracing
# 8   axon-messaging-4.9.0                  org.axonframework.tracing
# 9   axon-messaging-4.9.0                  org.axonframework.tracing
# 10  axon-messaging-4.9.0                  org.axonframework.tracing
# 11  axon-messaging-4.9.0                  org.axonframework.tracing
# 12  axon-messaging-4.9.0                  org.axonframework.tracing
# 13  axon-messaging-4.9.0                  org.axonframework.tracing
# 14  axon-messaging-4.9.0                  org.axonframework.tracing
# 15  axon-messaging-4.9.0                  org.axonframework.tracing
# 16  axon-messaging-4.9.0                  org.axonframework.tracing
# 17  axon-messaging-4.9.0                  org.axonframework.tracing
# 18  axon-messaging-4.9.0                  org.axonframework.tracing
# 19  axon-messaging-4.9.0                  org.axonframework.tracing
# 20  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 21  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 22  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 23  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 24  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 25  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 26  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 27  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 28  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 29  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 30  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 31  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 32  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 33  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 34  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 35  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 36  axon-messaging-4.9.0  org.axonframework.messaging.responsetypes
# 37  axon-messaging-4.9.0                  org.axonframework.tracing
# 38  axon-messaging-4.9.0                  org.axonframework.tracing
# 39  axon-messaging-4.9.0                  org.axonframework.tracing
#
#                                            dependency  \
# 0                    DefaultEventBusSpanFactory->Span
# 1   DefaultEventProcessorSpanFactory$Builder->Span...
# 2         TrackingEventProcessor$Builder->SpanFactory
# 3           AbstractEventBus$Builder->NoOpSpanFactory
# 4                    EventMessage<-NestingSpanFactory
# 5       DefaultEventProcessorSpanFactory->SpanFactory
# 6     DefaultEventBusSpanFactory$Builder->SpanFactory
# 7                         AbstractEventBus->SpanScope
# 8                        AbstractEventProcessor->Span
# 9               AbstractEventBus$Builder->SpanFactory
# 10                SimpleEventBus$Builder->SpanFactory
# 11                    EventProcessorSpanFactory->Span
# 12        AbstractEventProcessor$Builder->SpanFactory
# 13  DefaultEventProcessorSpanFactory->NoOpSpanFact...
# 14    AbstractEventProcessor$Builder->NoOpSpanFactory
# 15            DefaultEventBusSpanFactory->SpanFactory
# 16             DefaultEventProcessorSpanFactory->Span
# 17                             AbstractEventBus->Span
# 18     SubscribingEventProcessor$Builder->SpanFactory
# 19                          EventBusSpanFactory->Span
# 20                  GenericQueryMessage->ResponseType
# 21    SimpleQueryUpdateEmitter->PublisherResponseType
# 22                    QuerySubscription->ResponseType
# 23      GenericSubscriptionQueryMessage->ResponseType
# 24             SubscriptionQueryMessage->ResponseType
# 25  SimpleQueryUpdateEmitter->MultipleInstancesRes...
# 26                       SimpleQueryBus->ResponseType
# 27             SimpleQueryUpdateEmitter->ResponseType
# 28                         QueryGateway->ResponseType
# 29                        QueryGateway->ResponseTypes
# 30  GenericStreamingQueryMessage->PublisherRespons...
# 31                StreamingQueryMessage->ResponseType
# 32     SimpleQueryUpdateEmitter->OptionalResponseType
# 33    QueryResponseMessage<-ConvertingResponseMessage
# 34                  DefaultQueryGateway->ResponseType
# 35                         QueryMessage->ResponseType
# 36         GenericStreamingQueryMessage->ResponseType
# 37                            QueryMessage<-SpanUtils
# 38            DefaultQueryBusSpanFactory->SpanFactory
# 39                   DefaultQueryBusSpanFactory->Span
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.900000             19               1
# 2                   0.900000             19               1
# 3                   0.900000             19               1
# 4                   0.900000             19               1
# 5                   0.900000             19               1
# 6                   0.900000             19               1
# 7                   0.900000             19               1
# 8                   0.900000             19               1
# 9                   0.900000             19               1
# 10                  0.900000             19               1
# 11                  0.900000             19               1
# 12                  0.900000             19               1
# 13                  0.900000             19               1
# 14                  0.900000             19               1
# 15                  0.900000             19               1
# 16                  0.900000             19               1
# 17                  0.900000             19               1
# 18                  0.900000             19               1
# 19                  0.900000             19               1
# 20                  0.882353             16               1
# 21                  0.882353             16               1
# 22                  0.882353             16               1
# 23                  0.882353             16               1
# 24                  0.882353             16               1
# 25                  0.882353             16               1
# 26                  0.882353             16               1
# 27                  0.882353             16               1
# 28                  0.882353             16               1
# 29                  0.882353             16               1
# 30                  0.882353             16               1
# 31                  0.882353             16               1
# 32                  0.882353             16               1
# 33                  0.882353             16               1
# 34                  0.882353             16               1
# 35                  0.882353             16               1
# 36                  0.882353             16               1
# 37                  0.875000             15               1
# 38                  0.875000             15               1
# 39                  0.875000             15               1

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#                 artifactName                                      packageName  \
# 0       axon-messaging-4.9.0                  org.axonframework.eventhandling
# 1       axon-messaging-4.9.0                  org.axonframework.queryhandling
# 2       axon-messaging-4.9.0                  org.axonframework.queryhandling
# 3       axon-messaging-4.9.0                  org.axonframework.eventhandling
# 4       axon-messaging-4.9.0                  org.axonframework.eventhandling
# 5       axon-messaging-4.9.0                  org.axonframework.eventhandling
# 6       axon-messaging-4.9.0                  org.axonframework.eventhandling
# 7       axon-messaging-4.9.0                  org.axonframework.eventhandling
# 8       axon-messaging-4.9.0                       org.axonframework.deadline
# 9       axon-messaging-4.9.0                org.axonframework.commandhandling
# 10  axon-eventsourcing-4.9.0                  org.axonframework.eventsourcing
# 11  axon-eventsourcing-4.9.0                  org.axonframework.eventsourcing
# 12      axon-messaging-4.9.0      org.axonframework.commandhandling.callbacks
# 13      axon-messaging-4.9.0      org.axonframework.commandhandling.callbacks
# 14      axon-messaging-4.9.0                  org.axonframework.eventhandling
# 15      axon-messaging-4.9.0                  org.axonframework.eventhandling
# 16      axon-messaging-4.9.0                  org.axonframework.eventhandling
# 17      axon-messaging-4.9.0           org.axonframework.messaging.unitofwork
# 18      axon-messaging-4.9.0           org.axonframework.messaging.unitofwork
# 19      axon-messaging-4.9.0           org.axonframework.messaging.unitofwork
# 20      axon-messaging-4.9.0            org.axonframework.eventhandling.async
# 21      axon-messaging-4.9.0            org.axonframework.eventhandling.async
# 22      axon-messaging-4.9.0            org.axonframework.eventhandling.async
# 23      axon-messaging-4.9.0           org.axonframework.eventhandling.replay
# 24      axon-messaging-4.9.0           org.axonframework.eventhandling.replay
# 25      axon-messaging-4.9.0           org.axonframework.eventhandling.replay
# 26      axon-messaging-4.9.0  org.axonframework.serialization.upcasting.event
# 27      axon-messaging-4.9.0  org.axonframework.serialization.upcasting.event
# 28      axon-messaging-4.9.0  org.axonframework.serialization.upcasting.event
# 29  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
# 30  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
# 31  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
# 32  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
# 33  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
# 34  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
# 35  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
# 36  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
# 37  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
# 38  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
# 39  axon-eventsourcing-4.9.0  org.axonframework.eventsourcing.eventstore.jdbc
#
#        dependentArtifactName  \
# 0       axon-messaging-4.9.0
# 1       axon-messaging-4.9.0
# 2       axon-messaging-4.9.0
# 3       axon-messaging-4.9.0
# 4       axon-messaging-4.9.0
# 5       axon-messaging-4.9.0
# 6       axon-messaging-4.9.0
# 7       axon-messaging-4.9.0
# 8       axon-messaging-4.9.0
# 9       axon-messaging-4.9.0
# 10  axon-eventsourcing-4.9.0
# 11  axon-eventsourcing-4.9.0
# 12      axon-messaging-4.9.0
# 13      axon-messaging-4.9.0
# 14      axon-messaging-4.9.0
# 15      axon-messaging-4.9.0
# 16      axon-messaging-4.9.0
# 17      axon-messaging-4.9.0
# 18      axon-messaging-4.9.0
# 19      axon-messaging-4.9.0
# 20      axon-messaging-4.9.0
# 21      axon-messaging-4.9.0
# 22      axon-messaging-4.9.0
# 23      axon-messaging-4.9.0
# 24      axon-messaging-4.9.0
# 25      axon-messaging-4.9.0
# 26      axon-messaging-4.9.0
# 27      axon-messaging-4.9.0
# 28      axon-messaging-4.9.0
# 29  axon-eventsourcing-4.9.0
# 30  axon-eventsourcing-4.9.0
# 31  axon-eventsourcing-4.9.0
# 32  axon-eventsourcing-4.9.0
# 33  axon-eventsourcing-4.9.0
# 34  axon-eventsourcing-4.9.0
# 35  axon-eventsourcing-4.9.0
# 36  axon-eventsourcing-4.9.0
# 37  axon-eventsourcing-4.9.0
# 38  axon-eventsourcing-4.9.0
# 39  axon-eventsourcing-4.9.0
#
#                                  dependentPackageName  \
# 0                           org.axonframework.tracing
# 1           org.axonframework.messaging.responsetypes
# 2                           org.axonframework.tracing
# 3                         org.axonframework.messaging
# 4                         org.axonframework.messaging
# 5                         org.axonframework.messaging
# 6              org.axonframework.messaging.annotation
# 7              org.axonframework.messaging.annotation
# 8                           org.axonframework.tracing
# 9                           org.axonframework.tracing
# 10         org.axonframework.eventsourcing.eventstore
# 11         org.axonframework.eventsourcing.eventstore
# 12                  org.axonframework.commandhandling
# 13                  org.axonframework.commandhandling
# 14                    org.axonframework.serialization
# 15                    org.axonframework.serialization
# 16                    org.axonframework.serialization
# 17                        org.axonframework.messaging
# 18                        org.axonframework.messaging
# 19                        org.axonframework.messaging
# 20                    org.axonframework.eventhandling
# 21                    org.axonframework.eventhandling
# 22                    org.axonframework.eventhandling
# 23                    org.axonframework.eventhandling
# 24                    org.axonframework.eventhandling
# 25                    org.axonframework.eventhandling
# 26                    org.axonframework.eventhandling
# 27                    org.axonframework.eventhandling
# 28                    org.axonframework.eventhandling
# 29  org.axonframework.eventsourcing.eventstore.jdb...
# 30  org.axonframework.eventsourcing.eventstore.jdb...
# 31  org.axonframework.eventsourcing.eventstore.jdb...
# 32  org.axonframework.eventsourcing.eventstore.jdb...
# 33  org.axonframework.eventsourcing.eventstore.jdb...
# 34  org.axonframework.eventsourcing.eventstore.jdb...
# 35  org.axonframework.eventsourcing.eventstore.jdb...
# 36  org.axonframework.eventsourcing.eventstore.jdb...
# 37  org.axonframework.eventsourcing.eventstore.jdb...
# 38  org.axonframework.eventsourcing.eventstore.jdb...
# 39  org.axonframework.eventsourcing.eventstore.jdb...
#
#                                            dependency  \
# 0                    EventMessage<-NestingSpanFactory
# 1     QueryResponseMessage<-ConvertingResponseMessage
# 2                             QueryMessage<-SpanUtils
# 3              TrackingToken<-StreamableMessageSource
# 4                         DomainEventMessage<-Headers
# 5                               EventMessage<-Headers
# 6   DomainEventMessage<-AggregateTypeParameterReso...
# 7   DomainEventMessage<-SourceIdParameterResolverF...
# 8                          DeadlineMessage<-SpanUtils
# 9                           CommandMessage<-SpanUtils
# 10       EventStreamUtils<-AbstractEventStorageEngine
# 11                EventStreamUtils<-DomainEventStream
# 12             NoOpCallback<-SimpleCommandBus$Builder
# 13          LoggingCallback<-SimpleCommandBus$Builder
# 14  GapAwareTrackingToken<-GapAwareTrackingTokenCo...
# 15  GenericDomainEventMessage<-AbstractXStreamSeri...
# 16     GenericEventMessage<-AbstractXStreamSerializer
# 17                  CurrentUnitOfWork<-GenericMessage
# 18              UnitOfWork<-MessageHandlerInterceptor
# 19                UnitOfWork<-DefaultInterceptorChain
# 20  SequencingPolicy<-SimpleEventHandlerInvoker$Bu...
# 21        SequencingPolicy<-SimpleEventHandlerInvoker
# 22  SequentialPerAggregatePolicy<-SimpleEventHandl...
# 23  GenericResetContext<-AnnotationEventHandlerAda...
# 24        ResetContext<-AnnotationEventHandlerAdapter
# 25                         ResetContext<-ResetHandler
# 26             InitialEventRepresentation<-EventUtils
# 27                          EventUpcaster<-EventUtils
# 28        IntermediateEventRepresentation<-EventUtils
# 29       EventSchema<-DeleteSnapshotsStatementBuilder
# 30      EventSchema<-ReadSnapshotDataStatementBuilder
# 31  EventSchema<-ReadEventDataForAggregateStatemen...
# 32             EventSchema<-CleanGapsStatementBuilder
# 33       EventSchema<-CreateHeadTokenStatementBuilder
# 34          EventSchema<-AppendEventsStatementBuilder
# 35       EventSchema<-CreateTailTokenStatementBuilder
# 36      EventSchema<-JdbcEventStorageEngineStatements
# 37        EventSchema<-AppendSnapshotStatementBuilder
# 38  EventSchema<-ReadEventDataWithoutGapsStatement...
# 39         EventSchema<-CreateTokenAtStatementBuilder
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.857143             39               3
# 5                   0.857143             39               3
# 6                   0.840000             23               2
# 7                   0.840000             23               2
# 8                   0.800000              9               1
# 9                   0.777778              8               1
# 10                  0.777778             16               2
# 11                  0.777778             16               2
# 12                  0.733333             13               2
# 13                  0.733333             13               2
# 14                  0.647059             14               3
# 15                  0.647059             14               3
# 16                  0.647059             14               3
# 17                  0.647059             14               3
# 18                  0.647059             14               3
# 19                  0.647059             14               3
# 20                  0.538462             10               3
# 21                  0.538462             10               3
# 22                  0.538462             10               3
# 23                  0.454545              8               3
# 24                  0.454545              8               3
# 25                  0.454545              8               3
# 26                  0.333333              6               3
# 27                  0.333333              6               3
# 28                  0.333333              6               3
# 29                  0.317073             27              14
# 30                  0.317073             27              14
# 31                  0.317073             27              14
# 32                  0.317073             27              14
# 33                  0.317073             27              14
# 34                  0.317073             27              14
# 35                  0.317073             27              14
# 36                  0.317073             27              14
# 37                  0.317073             27              14
# 38                  0.317073             27              14
# 39                  0.317073             27              14

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.

# %% [markdown]
# ### Table 4 - Top 40 most used combinations of methods
#
# The following table shows the top 40 most used combinations of methods of larger types that might benefit from applying the *Interface Segregation Principle*. The whole table can be found in the CSV report `Candidates_for_Interface_Segregation`.

# %%
interface_segregation_candidates=query_cypher_to_data_frame("../cypher/Candidates_for_Interface_Segregation.cypher", limit=40)
interface_segregation_candidates
# Out:
#                                 fullDependentTypeName  declaredMethods  \
# 0    org.axonframework.commandhandling.CommandMessage                9
# 1   org.axonframework.eventhandling.DomainEventMes...               10
# 2        org.axonframework.eventhandling.EventMessage                9
# 3   org.axonframework.eventhandling.TrackedEventMe...               10
# 4        org.axonframework.eventhandling.EventMessage                9
# 5   org.axonframework.eventhandling.DomainEventMes...               10
# 6           org.axonframework.messaging.ResultMessage                9
# 7   org.axonframework.commandhandling.GenericComma...               14
# 8   org.axonframework.deadline.GenericDeadlineMessage               11
# 9         org.axonframework.eventhandling.ReplayToken               13
# 10  org.axonframework.eventhandling.TrackedEventMe...               12
# 11         org.axonframework.deadline.DeadlineMessage               10
# 12  org.axonframework.eventhandling.DomainEventMes...               10
# 13  org.axonframework.eventhandling.DomainEventMes...               10
# 14  org.axonframework.eventhandling.GenericEventMe...               10
# 15  org.axonframework.deadline.DefaultDeadlineMana...                8
# 16  org.axonframework.common.transaction.NoTransac...                4
# 17  org.axonframework.commandhandling.GenericComma...               15
# 18  org.axonframework.modelling.command.inspection...               13
# 19  org.axonframework.eventhandling.DomainEventMes...               11
# 20  org.axonframework.eventhandling.GenericEventMe...               11
# 21  org.axonframework.eventhandling.DomainEventMes...               10
# 22  org.axonframework.eventhandling.GapAwareTracki...               10
# 23       org.axonframework.eventhandling.EventMessage                9
# 24       org.axonframework.messaging.MessageDecorator                9
# 25   org.axonframework.eventhandling.TrackedEventData                5
# 26  org.axonframework.eventhandling.tokenstore.Con...                5
# 27      org.axonframework.eventhandling.TrackerStatus               17
# 28  org.axonframework.modelling.command.inspection...               17
# 29  org.axonframework.queryhandling.SimpleQueryUpd...               17
# 30  org.axonframework.commandhandling.CommandMessa...               14
# 31  org.axonframework.commandhandling.GenericComma...               14
# 32         org.axonframework.deadline.DeadlineMessage               14
# 33   org.axonframework.messaging.GenericResultMessage               14
# 34  org.axonframework.messaging.annotation.Wrapped...               14
# 35  org.axonframework.eventhandling.DomainEventMes...               13
# 36        org.axonframework.eventhandling.ReplayToken               13
# 37  org.axonframework.modelling.command.inspection...               13
# 38  org.axonframework.queryhandling.SubscriptionQu...               12
# 39  org.axonframework.commandhandling.GenericComma...               11
#
#                                     calledMethodNames  calledMethods  \
# 0                                    [getCommandName]              1
# 1                                 [getSequenceNumber]              1
# 2                       [getIdentifier, getTimestamp]              2
# 3                                     [trackingToken]              1
# 4                                     [getIdentifier]              1
# 5   [getType, getSequenceNumber, getAggregateIdent...              3
# 6                    [isExceptional, exceptionResult]              2
# 7                            [asCommandResultMessage]              1
# 8                                 [asDeadlineMessage]              1
# 9                                 [createReplayToken]              1
# 10                                    [trackingToken]              1
# 11                                  [getDeadlineName]              1
# 12                           [getAggregateIdentifier]              1
# 13                                          [getType]              1
# 14                                   [asEventMessage]              1
# 15                                          [builder]              1
# 16                                         [instance]              1
# 17                           [asCommandResultMessage]              1
# 18                                             [type]              1
# 19  [getType, getSequenceNumber, getAggregateIdent...              3
# 20                                   [asEventMessage]              1
# 21        [getSequenceNumber, getAggregateIdentifier]              2
# 22  [newInstance, getIndex, advanceTo, getGaps, wi...              5
# 23                                     [getTimestamp]              1
# 24                                       [describeTo]              1
# 25                                    [trackingToken]              1
# 26                                              [get]              1
# 27              [split, getTrackingToken, getSegment]              3
# 28       [initialize, getAggregateRoot, initSequence]              4
# 29                                          [builder]              1
# 30                    [commandName, isFactoryHandler]              2
# 31                           [asCommandResultMessage]              2
# 32                                  [getDeadlineName]              1
# 33                                  [asResultMessage]              1
# 34                                           [handle]              1
# 35        [getSequenceNumber, getAggregateIdentifier]              2
# 36                                         [isReplay]              1
# 37                                            [types]              1
# 38                            [getUpdateResponseType]              1
# 39                                 [asCommandMessage]              1
#
#     callerTypes
# 0            18
# 1             9
# 2             9
# 3             8
# 4             7
# 5             6
# 6             6
# 7             5
# 8             5
# 9             4
# 10            4
# 11            4
# 12            4
# 13            4
# 14            4
# 15            4
# 16            4
# 17            3
# 18            3
# 19            3
# 20            3
# 21            3
# 22            3
# 23            3
# 24            3
# 25            3
# 26            3
# 27            2
# 28            2
# 29            2
# 30            2
# 31            2
# 32            2
# 33            2
# 34            2
# 35            2
# 36            2
# 37            2
# 38            2
# 39            2

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Table 5 - Types that are used by multiple packages
#
# This table shows the top 40 packages that are used by the highest number of different packages. The whole table can be found in the CSV report `List_types_that_are_used_by_many_different_packages`.

# %%
types_used_by_many_packages=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_types_that_are_used_by_many_different_packages.cypher", limit=40)
types_used_by_many_packages
# Out:
#                        fullQualifiedDependentTypeName  \
# 0               org.axonframework.common.BuilderUtils
# 1   org.axonframework.common.AxonConfigurationExce...
# 2                 org.axonframework.messaging.Message
# 3                org.axonframework.messaging.MetaData
# 4        org.axonframework.eventhandling.EventMessage
# 5   org.axonframework.messaging.unitofwork.UnitOfWork
# 6          org.axonframework.serialization.Serializer
# 7                     org.axonframework.common.Assert
# 8   org.axonframework.common.transaction.Transacti...
# 9    org.axonframework.serialization.SerializedObject
# 10     org.axonframework.serialization.SerializedType
# 11  org.axonframework.messaging.unitofwork.Current...
# 12  org.axonframework.common.AxonNonTransientExcep...
# 13  org.axonframework.eventhandling.DomainEventMes...
# 14  org.axonframework.eventhandling.GenericEventMe...
# 15  org.axonframework.messaging.annotation.Paramet...
# 16      org.axonframework.eventhandling.TrackingToken
# 17              org.axonframework.common.Registration
# 18  org.axonframework.serialization.SimpleSerializ...
# 19  org.axonframework.messaging.MessageHandlerInte...
# 20               org.axonframework.common.ObjectUtils
# 21              org.axonframework.tracing.SpanFactory
# 22  org.axonframework.messaging.MessageDispatchInt...
# 23   org.axonframework.commandhandling.CommandMessage
# 24  org.axonframework.messaging.unitofwork.Default...
# 25  org.axonframework.messaging.annotation.Handler...
# 26           org.axonframework.common.ReflectionUtils
# 27           org.axonframework.eventhandling.EventBus
# 28              org.axonframework.lifecycle.Lifecycle
# 29  org.axonframework.lifecycle.Lifecycle$Lifecycl...
# 30  org.axonframework.common.transaction.NoTransac...
# 31          org.axonframework.messaging.ResultMessage
# 32             org.axonframework.common.DateTimeUtils
# 33  org.axonframework.messaging.DefaultInterceptor...
# 34       org.axonframework.messaging.InterceptorChain
# 35          org.axonframework.tracing.NoOpSpanFactory
# 36        org.axonframework.messaging.ScopeDescriptor
# 37    org.axonframework.common.AxonTransientException
# 38  org.axonframework.messaging.annotation.Classpa...
# 39  org.axonframework.messaging.annotation.Classpa...
#
#                     dependentTypeName  \
# 0                        BuilderUtils
# 1          AxonConfigurationException
# 2                             Message
# 3                            MetaData
# 4                        EventMessage
# 5                          UnitOfWork
# 6                          Serializer
# 7                              Assert
# 8                  TransactionManager
# 9                    SerializedObject
# 10                     SerializedType
# 11                  CurrentUnitOfWork
# 12          AxonNonTransientException
# 13                 DomainEventMessage
# 14                GenericEventMessage
# 15           ParameterResolverFactory
# 16                      TrackingToken
# 17                       Registration
# 18             SimpleSerializedObject
# 19          MessageHandlerInterceptor
# 20                        ObjectUtils
# 21                        SpanFactory
# 22         MessageDispatchInterceptor
# 23                     CommandMessage
# 24                  DefaultUnitOfWork
# 25                  HandlerDefinition
# 26                    ReflectionUtils
# 27                           EventBus
# 28                          Lifecycle
# 29        Lifecycle$LifecycleRegistry
# 30               NoTransactionManager
# 31                      ResultMessage
# 32                      DateTimeUtils
# 33            DefaultInterceptorChain
# 34                   InterceptorChain
# 35                    NoOpSpanFactory
# 36                    ScopeDescriptor
# 37             AxonTransientException
# 38         ClasspathHandlerDefinition
# 39  ClasspathParameterResolverFactory
#
#                                   dependentTypeLabels  numberOfUsingPackages
# 0   [Type, File, Java, ByteCode, Class, TopCentral...                     44
# 1   [Type, File, Java, ByteCode, Class, TopCentral...                     37
# 2   [Type, File, Java, GenericDeclaration, ByteCod...                     34
# 3   [Type, File, Java, ByteCode, Class, TopCentral...                     33
# 4   [Type, File, Java, GenericDeclaration, ByteCod...                     32
# 5   [Type, File, Java, GenericDeclaration, ByteCod...                     31
# 6   [Type, File, Java, ByteCode, Interface, TopCen...                     29
# 7   [Type, File, Java, ByteCode, Class, TopCentral...                     27
# 8   [Type, File, Java, ByteCode, Interface, TopCen...                     27
# 9   [Type, File, Java, GenericDeclaration, ByteCod...                     25
# 10  [Type, File, Java, ByteCode, Interface, TopCen...                     24
# 11  [Type, File, Java, ByteCode, Class, TopCentral...                     21
# 12  [Type, File, Java, ByteCode, Class, TopCentral...                     18
# 13  [Type, File, Java, GenericDeclaration, ByteCod...                     18
# 14  [Type, File, Java, GenericDeclaration, ByteCod...                     18
# 15  [Type, File, Java, ByteCode, Interface, TopCen...                     18
# 16  [Type, File, Java, ByteCode, Interface, TopCen...                     18
# 17  [Type, File, Java, ByteCode, Interface, TypeWe...                     17
# 18  [Type, File, Java, GenericDeclaration, ByteCod...                     17
# 19  [Type, File, Java, GenericDeclaration, ByteCod...                     16
# 20  [Type, File, Java, ByteCode, Class, TypeWeakly...                     16
# 21  [Type, File, Java, ByteCode, Interface, TopCen...                     16
# 22  [Type, File, Java, GenericDeclaration, ByteCod...                     15
# 23  [Type, File, Java, GenericDeclaration, ByteCod...                     14
# 24  [Type, File, Java, GenericDeclaration, ByteCod...                     14
# 25  [Type, File, Java, ByteCode, Interface, TopCen...                     14
# 26  [Type, File, Java, ByteCode, Class, TypeWeakly...                     14
# 27  [Type, File, Java, ByteCode, Interface, TopCen...                     13
# 28  [Type, File, Java, ByteCode, Interface, TypeWe...                     13
# 29  [Type, File, Java, ByteCode, Interface, TypeWe...                     13
# 30  [Type, File, Java, ByteCode, Enum, TypeWeaklyC...                     13
# 31  [Type, File, Java, GenericDeclaration, ByteCod...                     13
# 32  [Type, File, Java, ByteCode, Class, TypeWeakly...                     12
# 33  [Type, File, Java, GenericDeclaration, ByteCod...                     12
# 34  [Type, File, Java, ByteCode, Interface, TypeWe...                     12
# 35  [Type, File, Java, ByteCode, Class, TypeWeakly...                     12
# 36  [Type, File, Java, ByteCode, Interface, TypeWe...                     12
# 37  [Type, File, Java, ByteCode, Class, TypeWeakly...                     11
# 38  [Type, File, Java, ByteCode, Class, TypeWeakly...                     11
# 39  [Type, File, Java, ByteCode, Class, TypeWeakly...                     11

# %% [markdown]
# ### Table 6 - Packages that are used by multiple artifacts
#
# This table shows the top 30 artifacts that only use a few (compared to all existing) packages of another artifact.
# The whole table can be found in the CSV report `ArtifactPackageUsage`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#                artifactName     dependentArtifactName  dependentPackages  \
# 0      axon-modelling-4.9.0      axon-modelling-4.9.0                  6
# 1           axon-test-4.9.0           axon-test-4.9.0                  5
# 2      axon-messaging-4.9.0      axon-messaging-4.9.0                 41
# 3  axon-eventsourcing-4.9.0  axon-eventsourcing-4.9.0                  7
#
#    dependentArtifactPackages  packageUsagePercentage  \
# 0                         10                0.600000
# 1                          8                0.625000
# 2                         64                0.640625
# 3                          9                0.777778
#
#                   dependentFullQualifiedPackageNames  \
# 0  [org.axonframework.modelling.command.inspectio...
# 1  [org.axonframework.test.deadline, org.axonfram...
# 2  [org.axonframework.queryhandling, org.axonfram...
# 3  [org.axonframework.eventsourcing.eventstore.jp...
#
#                                dependentPackageNames
# 0  [inspection, command, repository, saga, jpa, m...
# 1  [deadline, utils, test, eventscheduler, matchers]
# 2  [queryhandling, eventhandling, messaging, comm...
# 3  [jpa, snapshotting, eventstore, jdbc, conflict...

# %% [markdown]
# ### Table 7 - Types that are used by multiple artifacts
#
# This table shows the top 30 types that only use a few (compared to all existing) types of another artifact. The whole table can be found in the CSV report `ClassesPerPackageUsageAcrossArtifacts`.

# %%
used_types_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher", limit=30)
used_types_of_dependent_artifact
# Out:
#                 artifactName dependentArtifactName  \
# 0            axon-test-4.9.0  axon-messaging-4.9.0
# 1       axon-modelling-4.9.0  axon-messaging-4.9.0
# 2   axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 3   axon-eventsourcing-4.9.0  axon-modelling-4.9.0
# 4   axon-eventsourcing-4.9.0  axon-modelling-4.9.0
# 5   axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 6            axon-test-4.9.0  axon-messaging-4.9.0
# 7       axon-modelling-4.9.0  axon-messaging-4.9.0
# 8       axon-modelling-4.9.0  axon-messaging-4.9.0
# 9            axon-test-4.9.0  axon-messaging-4.9.0
# 10           axon-test-4.9.0  axon-messaging-4.9.0
# 11  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 12  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 13  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 14  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 15  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 16  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 17           axon-test-4.9.0  axon-modelling-4.9.0
# 18           axon-test-4.9.0  axon-messaging-4.9.0
# 19  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 20  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 21           axon-test-4.9.0  axon-messaging-4.9.0
# 22  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 23           axon-test-4.9.0  axon-messaging-4.9.0
# 24           axon-test-4.9.0  axon-messaging-4.9.0
# 25  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
# 26      axon-modelling-4.9.0  axon-messaging-4.9.0
# 27      axon-modelling-4.9.0  axon-messaging-4.9.0
# 28  axon-eventsourcing-4.9.0  axon-modelling-4.9.0
# 29  axon-eventsourcing-4.9.0  axon-messaging-4.9.0
#
#                                           packageName  \
# 0                     org.axonframework.test.matchers
# 1          org.axonframework.modelling.saga.metamodel
# 2        org.axonframework.eventsourcing.snapshotting
# 3     org.axonframework.eventsourcing.eventstore.jdbc
# 4   org.axonframework.eventsourcing.conflictresolu...
# 5   org.axonframework.eventsourcing.conflictresolu...
# 6               org.axonframework.test.eventscheduler
# 7       org.axonframework.modelling.command.legacyjpa
# 8                 org.axonframework.modelling.command
# 9                              org.axonframework.test
# 10                    org.axonframework.test.matchers
# 11  org.axonframework.eventsourcing.conflictresolu...
# 12         org.axonframework.eventsourcing.eventstore
# 13     org.axonframework.eventsourcing.eventstore.jpa
# 14  org.axonframework.eventsourcing.eventstore.leg...
# 15    org.axonframework.eventsourcing.eventstore.jdbc
# 16  org.axonframework.eventsourcing.eventstore.jdb...
# 17                       org.axonframework.test.utils
# 18                    org.axonframework.test.matchers
# 19  org.axonframework.eventsourcing.conflictresolu...
# 20  org.axonframework.eventsourcing.eventstore.jdb...
# 21                       org.axonframework.test.utils
# 22  org.axonframework.eventsourcing.conflictresolu...
# 23              org.axonframework.test.eventscheduler
# 24                      org.axonframework.test.server
# 25       org.axonframework.eventsourcing.snapshotting
# 26      org.axonframework.modelling.command.legacyjpa
# 27      org.axonframework.modelling.command.legacyjpa
# 28         org.axonframework.eventsourcing.eventstore
# 29  org.axonframework.eventsourcing.conflictresolu...
#
#                       dependentPackage.fqn  dependentTypes  \
# 0          org.axonframework.eventhandling               1
# 1          org.axonframework.eventhandling               1
# 2          org.axonframework.eventhandling               1
# 3      org.axonframework.modelling.command               1
# 4      org.axonframework.modelling.command               1
# 5          org.axonframework.eventhandling               2
# 6          org.axonframework.eventhandling               2
# 7          org.axonframework.eventhandling               2
# 8          org.axonframework.eventhandling               2
# 9              org.axonframework.messaging               1
# 10             org.axonframework.messaging               1
# 11             org.axonframework.messaging               1
# 12             org.axonframework.messaging               1
# 13         org.axonframework.serialization               1
# 14         org.axonframework.serialization               1
# 15         org.axonframework.serialization               1
# 16         org.axonframework.eventhandling               3
# 17        org.axonframework.modelling.saga               1
# 18       org.axonframework.commandhandling               1
# 19       org.axonframework.commandhandling               1
# 20                org.axonframework.common               1
# 21                org.axonframework.common               1
# 22                org.axonframework.common               1
# 23                org.axonframework.common               1
# 24                org.axonframework.common               1
# 25                org.axonframework.common               1
# 26                org.axonframework.common               1
# 27  org.axonframework.messaging.annotation               2
# 28     org.axonframework.modelling.command               2
# 29  org.axonframework.messaging.annotation               2
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                     100             0.010000
# 1                     100             0.010000
# 2                     100             0.010000
# 3                      54             0.018519
# 4                      54             0.018519
# 5                     100             0.020000
# 6                     100             0.020000
# 7                     100             0.020000
# 8                     100             0.020000
# 9                      35             0.028571
# 10                     35             0.028571
# 11                     35             0.028571
# 12                     35             0.028571
# 13                     34             0.029412
# 14                     34             0.029412
# 15                     34             0.029412
# 16                    100             0.030000
# 17                     33             0.030303
# 18                     32             0.031250
# 19                     32             0.031250
# 20                     28             0.035714
# 21                     28             0.035714
# 22                     28             0.035714
# 23                     28             0.035714
# 24                     28             0.035714
# 25                     28             0.035714
# 26                     28             0.035714
# 27                     54             0.037037
# 28                     54             0.037037
# 29                     54             0.037037
#
#                                    dependentTypeNames
# 0      [org.axonframework.eventhandling.EventMessage]
# 1      [org.axonframework.eventhandling.EventMessage]
# 2   [org.axonframework.eventhandling.DomainEventData]
# 3   [org.axonframework.modelling.command.Concurren...
# 4   [org.axonframework.modelling.command.Conflicti...
# 5   [org.axonframework.eventhandling.DomainEventMe...
# 6   [org.axonframework.eventhandling.GenericEventM...
# 7   [org.axonframework.eventhandling.EventBus, org...
# 8   [org.axonframework.eventhandling.EventBus, org...
# 9               [org.axonframework.messaging.Message]
# 10              [org.axonframework.messaging.Message]
# 11              [org.axonframework.messaging.Message]
# 12  [org.axonframework.messaging.StreamableMessage...
# 13       [org.axonframework.serialization.Serializer]
# 14       [org.axonframework.serialization.Serializer]
# 15       [org.axonframework.serialization.Serializer]
# 16  [org.axonframework.eventhandling.GenericDomain...
# 17  [org.axonframework.modelling.saga.SimpleResour...
# 18  [org.axonframework.commandhandling.CommandMess...
# 19  [org.axonframework.commandhandling.CommandMess...
# 20           [org.axonframework.common.DateTimeUtils]
# 21            [org.axonframework.common.Registration]
# 22                  [org.axonframework.common.Assert]
# 23           [org.axonframework.common.DateTimeUtils]
# 24                  [org.axonframework.common.Assert]
# 25            [org.axonframework.common.BuilderUtils]
# 26            [org.axonframework.common.BuilderUtils]
# 27  [org.axonframework.messaging.annotation.Handle...
# 28  [org.axonframework.modelling.command.Aggregate...
# 29  [org.axonframework.messaging.annotation.Parame...

# %% [markdown]
# ### Table 8 - Duplicate package names across artifacts
#
# This table shows the top 30 duplicate package names across artifacts. They are ordered by the number of duplicates descending.
#
# This might lead to confusion, makes importing more error prone and might even lead to duplicate classes where only one of them will be loaded by the class loader. If a package is named the same way in two or more artifacts this even allows another artifact to access package protected classes, methods or members which might not be intended.
#
# The whole table can be found in the CSV report `DuplicatePackageNamesAcrossArtifacts`.

# %%
duplicate_package_names_across_artifacts=query_cypher_to_data_frame("../cypher/Artifact_Dependencies/Artifacts_with_duplicate_packages.cypher", limit=30)
duplicate_package_names_across_artifacts
# Out:
# Empty DataFrame
# Columns: [packageName, duplicates, artifactNames]
# Index: []

# %% [markdown]
# ### Table 9 - Annotated elements
#
# This table shows 30 most used Java Annotations including some examples where they are used.

# %%
annotated_elements=query_cypher_to_data_frame("../cypher/Java/Annotated_code_elements.cypher", limit=30)
annotated_elements
# Out:
#                                        annotationName languageElement  \
# 0                            javax.annotation.Nonnull       Parameter
# 1                                java.lang.Deprecated          Method
# 2                           javax.annotation.Nullable       Parameter
# 3                       java.lang.FunctionalInterface       Interface
# 4                         java.lang.annotation.Target      Annotation
# 5                      java.lang.annotation.Retention      Annotation
# 6                             javax.persistence.Basic           Field
# 7                            javax.annotation.Nonnull          Method
# 8                           jakarta.persistence.Basic           Field
# 9       com.fasterxml.jackson.annotation.JsonProperty       Parameter
# 10                               java.lang.Deprecated           Class
# 11                    java.lang.annotation.Documented      Annotation
# 12                   java.beans.ConstructorProperties     Constructor
# 13                               java.lang.Deprecated     Constructor
# 14       com.fasterxml.jackson.annotation.JsonCreator     Constructor
# 15                           javax.persistence.Column           Field
# 16                         jakarta.persistence.Column           Field
# 17                  org.axonframework.common.Priority           Class
# 18                              javax.persistence.Lob           Field
# 19                               javax.persistence.Id           Field
# 20                             jakarta.persistence.Id           Field
# 21        com.fasterxml.jackson.annotation.JsonGetter          Method
# 22                              java.lang.SafeVarargs     Constructor
# 23  org.axonframework.messaging.annotation.HasHand...      Annotation
# 24                            jakarta.persistence.Lob           Field
# 25                           javax.persistence.Entity           Class
# 26                         jakarta.persistence.Entity           Class
# 27  org.axonframework.messaging.annotation.Message...      Annotation
# 28                              java.lang.SafeVarargs          Method
# 29                 javax.persistence.MappedSuperclass           Class
#
#     numberOfAnnotatedElements  \
# 0                        1501
# 1                          96
# 2                          61
# 3                          54
# 4                          40
# 5                          40
# 6                          39
# 7                          37
# 8                          33
# 9                          32
# 10                         25
# 11                         21
# 12                         21
# 13                         17
# 14                         16
# 15                         12
# 16                         11
# 17                         11
# 18                         10
# 19                         10
# 20                          9
# 21                          9
# 22                          9
# 23                          8
# 24                          8
# 25                          6
# 26                          6
# 27                          6
# 28                          6
# 29                          6
#
#                                              examples
# 0   [org.axonframework.config.Component.<init>(0),...
# 1   [org.axonframework.config.Configurer.registerC...
# 2   [org.axonframework.modelling.command.CreationP...
# 3   [org.axonframework.config.EventProcessingConfi...
# 4   [org.axonframework.config.ProcessingGroup, org...
# 5   [org.axonframework.config.ProcessingGroup, org...
# 6   [org.axonframework.modelling.saga.repository.j...
# 7   [org.axonframework.modelling.command.CreationP...
# 8   [org.axonframework.modelling.saga.repository.j...
# 9   [org.axonframework.modelling.command.Aggregate...
# 10  [org.axonframework.modelling.command.legacyjpa...
# 11  [org.axonframework.config.ProcessingGroup, org...
# 12  [org.axonframework.modelling.command.Aggregate...
# 13  [org.axonframework.modelling.command.Annotatio...
# 14  [org.axonframework.modelling.command.Aggregate...
# 15  [org.axonframework.modelling.saga.repository.j...
# 16  [org.axonframework.modelling.saga.repository.j...
# 17  [org.axonframework.config.ConfigurationParamet...
# 18  [org.axonframework.modelling.saga.repository.j...
# 19  [org.axonframework.modelling.saga.repository.j...
# 20  [org.axonframework.modelling.saga.repository.j...
# 21  [org.axonframework.commandhandling.distributed...
# 22  [org.axonframework.test.matchers.ListMatcher.<...
# 23  [org.axonframework.modelling.command.CreationP...
# 24  [org.axonframework.modelling.saga.repository.j...
# 25  [org.axonframework.modelling.saga.repository.j...
# 26  [org.axonframework.modelling.saga.repository.j...
# 27  [org.axonframework.commandhandling.CommandHand...
# 28  [org.axonframework.config.AggregateConfigurer....
# 29  [org.axonframework.modelling.saga.repository.j...
