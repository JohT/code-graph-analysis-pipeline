# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [py2neo](https://py2neo.org/2021.1/)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Artifacts
#
# ### Table 1
#
# - List all the artifacts this notebook is based on

# %%
query_cypher_to_data_frame("../cypher/List_all_existing_artifacts.cypher")
# Out:
#                    artifactName  packages  types
# 0  axon-configuration-4.8.0.jar         1     39
# 1           axon-test-4.8.0.jar         8     87
# 2  axon-eventsourcing-4.8.0.jar         9    130
# 3      axon-disruptor-4.8.0.jar         1     22
# 4      axon-modelling-4.8.0.jar        10    150
# 5      axon-messaging-4.8.0.jar        64    762

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to a lot of trouble when one of these packages needs to be changed.
#
# ### Table 2
# - List packages with cyclic dependencies as an overview

# %%
query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_as_List.cypher")
# Out:
#                                           packageName  \
# 0                     org.axonframework.queryhandling
# 1                     org.axonframework.eventhandling
# 2                     org.axonframework.eventhandling
# 3                     org.axonframework.eventhandling
# 4                     org.axonframework.queryhandling
# 5                     org.axonframework.eventsourcing
# 6                          org.axonframework.deadline
# 7         org.axonframework.commandhandling.callbacks
# 8                   org.axonframework.commandhandling
# 9                     org.axonframework.eventhandling
# 10             org.axonframework.messaging.unitofwork
# 11              org.axonframework.eventhandling.async
# 12             org.axonframework.eventhandling.replay
# 13    org.axonframework.serialization.upcasting.event
# 14    org.axonframework.eventsourcing.eventstore.jdbc
# 15     org.axonframework.modelling.command.inspection
# 16       org.axonframework.queryhandling.registration
# 17                        org.axonframework.messaging
# 18                    org.axonframework.eventhandling
# 19             org.axonframework.messaging.annotation
# 20                   org.axonframework.modelling.saga
# 21  org.axonframework.commandhandling.distributed....
#
#                                  dependentPackageName  \
# 0           org.axonframework.messaging.responsetypes
# 1                           org.axonframework.tracing
# 2                         org.axonframework.messaging
# 3              org.axonframework.messaging.annotation
# 4                           org.axonframework.tracing
# 5          org.axonframework.eventsourcing.eventstore
# 6                           org.axonframework.tracing
# 7                   org.axonframework.commandhandling
# 8                           org.axonframework.tracing
# 9                     org.axonframework.serialization
# 10                        org.axonframework.messaging
# 11                    org.axonframework.eventhandling
# 12                    org.axonframework.eventhandling
# 13                    org.axonframework.eventhandling
# 14  org.axonframework.eventsourcing.eventstore.jdb...
# 15                org.axonframework.modelling.command
# 16                    org.axonframework.queryhandling
# 17                    org.axonframework.serialization
# 18         org.axonframework.eventhandling.tokenstore
# 19           org.axonframework.messaging.interceptors
# 20         org.axonframework.modelling.saga.metamodel
# 21      org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.882353             16               1
# 1                   0.857143             13               1
# 2                   0.853659             38               3
# 3                   0.840000             23               2
# 4                   0.800000              9               1
# 5                   0.777778             16               2
# 6                   0.750000              7               1
# 7                   0.733333             13               2
# 8                   0.666667              5               1
# 9                   0.647059             14               3
# 10                  0.647059             14               3
# 11                  0.538462             10               3
# 12                  0.454545              8               3
# 13                  0.333333              6               3
# 14                  0.317073             27              14
# 15                  0.250000             20              12
# 16                  0.250000              5               3
# 17                  0.238095             13               8
# 18                  0.230769              8               5
# 19                  0.200000              3               2
# 20                  0.142857              4               3
# 21                  0.076923              7               6
#
#                                   forwardDependencies  \
# 0   [SubscriptionQueryMessage->ResponseType, Query...
# 1   [TrackingEventProcessor$Builder->SpanFactory, ...
# 2   [TrackingEventProcessor$Builder->StreamableMes...
# 3   [SequenceNumberParameterResolverFactory->Param...
# 4   [SimpleQueryUpdateEmitter$Builder->NoOpSpanFac...
# 5   [FilteringEventStorageEngine->EventStorageEngi...
# 6   [SimpleDeadlineManager->Span, SimpleDeadlineMa...
# 7   [LoggingCallback->CommandCallback, LoggingCall...
# 8   [SimpleCommandBus$Builder->SpanFactory, Simple...
# 9   [GenericEventMessage->CachingSupplier, Abstrac...
# 10  [UnitOfWork->ResultMessage, UnitOfWork->Messag...
# 11  [AsynchronousEventProcessingStrategy->EventMes...
# 12  [ReplayContextParameterResolverFactory$ReplayC...
# 13  [InitialEventRepresentation->TrackingToken, In...
# 14  [JdbcEventStorageEngine$Builder->ReadEventData...
# 15  [AnnotatedAggregateMetaModelFactory$AnnotatedA...
# 16  [FailingDuplicateQueryHandlerResolver->QuerySu...
# 17  [Headers->SerializedObject, Headers->Serialize...
# 18  [TrackingEventProcessor$Builder->TokenStore, T...
# 19  [ResultParameterResolverFactory->ResultHandler...
# 20  [AnnotatedSaga->SagaModel, AnnotatedSagaManage...
# 21  [NegateCommandMessageFilter->CommandMessageFil...
#
#                                  backwardDependencies
# 0   [ConvertingResponseMessage->QueryResponseMessage]
# 1                  [NestingSpanFactory->EventMessage]
# 2   [Headers->EventMessage, Headers->DomainEventMe...
# 3   [SourceIdParameterResolverFactory$SourceIdPara...
# 4                           [SpanUtils->QueryMessage]
# 5   [DomainEventStream->EventStreamUtils, Abstract...
# 6                        [SpanUtils->DeadlineMessage]
# 7   [SimpleCommandBus$Builder->LoggingCallback, Si...
# 8                         [SpanUtils->CommandMessage]
# 9   [AbstractXStreamSerializer->GenericEventMessag...
# 10  [MessageHandlerInterceptor->UnitOfWork, Defaul...
# 11  [SimpleEventHandlerInvoker$Builder->Sequential...
# 12  [AnnotationEventHandlerAdapter->GenericResetCo...
# 13  [EventUtils->InitialEventRepresentation, Event...
# 14  [CreateTokenAtStatementBuilder->EventSchema, C...
# 15  [AbstractRepository$Builder->AnnotatedAggregat...
# 16  [SimpleQueryBus->DuplicateQueryHandlerResolver...
# 17  [SerializedObjectHolder->Message, SerializedMe...
# 18  [TokenStore->Segment, TokenStore->TrackingToke...
# 19  [MessageHandlerInterceptor->MessageHandler, Re...
# 20  [AnnotationSagaMetaModelFactory$InspectedSagaM...
# 21  [CommandMessageFilter->NegateCommandMessageFil...

# %% [markdown]
# ### Table 3
# - List packages with cyclic dependencies with every dependency in a separate row sorted by the easiest and most valuable resolvable dependency first

# %%
query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_as_unwinded_List.cypher").head(60)
# Out:
#                         packageName  \
# 0   org.axonframework.queryhandling
# 1   org.axonframework.queryhandling
# 2   org.axonframework.queryhandling
# 3   org.axonframework.queryhandling
# 4   org.axonframework.queryhandling
# 5   org.axonframework.queryhandling
# 6   org.axonframework.queryhandling
# 7   org.axonframework.queryhandling
# 8   org.axonframework.queryhandling
# 9   org.axonframework.queryhandling
# 10  org.axonframework.queryhandling
# 11  org.axonframework.queryhandling
# 12  org.axonframework.queryhandling
# 13  org.axonframework.queryhandling
# 14  org.axonframework.queryhandling
# 15  org.axonframework.queryhandling
# 16  org.axonframework.queryhandling
# 17  org.axonframework.eventhandling
# 18  org.axonframework.eventhandling
# 19  org.axonframework.eventhandling
# 20  org.axonframework.eventhandling
# 21  org.axonframework.eventhandling
# 22  org.axonframework.eventhandling
# 23  org.axonframework.eventhandling
# 24  org.axonframework.eventhandling
# 25  org.axonframework.eventhandling
# 26  org.axonframework.eventhandling
# 27  org.axonframework.eventhandling
# 28  org.axonframework.eventhandling
# 29  org.axonframework.eventhandling
# 30  org.axonframework.eventhandling
# 31  org.axonframework.eventhandling
# 32  org.axonframework.eventhandling
# 33  org.axonframework.eventhandling
# 34  org.axonframework.eventhandling
# 35  org.axonframework.eventhandling
# 36  org.axonframework.eventhandling
# 37  org.axonframework.eventhandling
# 38  org.axonframework.eventhandling
# 39  org.axonframework.eventhandling
# 40  org.axonframework.eventhandling
# 41  org.axonframework.eventhandling
# 42  org.axonframework.eventhandling
# 43  org.axonframework.eventhandling
# 44  org.axonframework.eventhandling
# 45  org.axonframework.eventhandling
# 46  org.axonframework.eventhandling
# 47  org.axonframework.eventhandling
# 48  org.axonframework.eventhandling
# 49  org.axonframework.eventhandling
# 50  org.axonframework.eventhandling
# 51  org.axonframework.eventhandling
# 52  org.axonframework.eventhandling
# 53  org.axonframework.eventhandling
# 54  org.axonframework.eventhandling
# 55  org.axonframework.eventhandling
# 56  org.axonframework.eventhandling
# 57  org.axonframework.eventhandling
# 58  org.axonframework.eventhandling
# 59  org.axonframework.eventhandling
#
#                          dependentPackageName  \
# 0   org.axonframework.messaging.responsetypes
# 1   org.axonframework.messaging.responsetypes
# 2   org.axonframework.messaging.responsetypes
# 3   org.axonframework.messaging.responsetypes
# 4   org.axonframework.messaging.responsetypes
# 5   org.axonframework.messaging.responsetypes
# 6   org.axonframework.messaging.responsetypes
# 7   org.axonframework.messaging.responsetypes
# 8   org.axonframework.messaging.responsetypes
# 9   org.axonframework.messaging.responsetypes
# 10  org.axonframework.messaging.responsetypes
# 11  org.axonframework.messaging.responsetypes
# 12  org.axonframework.messaging.responsetypes
# 13  org.axonframework.messaging.responsetypes
# 14  org.axonframework.messaging.responsetypes
# 15  org.axonframework.messaging.responsetypes
# 16  org.axonframework.messaging.responsetypes
# 17                  org.axonframework.tracing
# 18                  org.axonframework.tracing
# 19                  org.axonframework.tracing
# 20                  org.axonframework.tracing
# 21                  org.axonframework.tracing
# 22                  org.axonframework.tracing
# 23                  org.axonframework.tracing
# 24                  org.axonframework.tracing
# 25                  org.axonframework.tracing
# 26                  org.axonframework.tracing
# 27                  org.axonframework.tracing
# 28                  org.axonframework.tracing
# 29                  org.axonframework.tracing
# 30                  org.axonframework.tracing
# 31                org.axonframework.messaging
# 32                org.axonframework.messaging
# 33                org.axonframework.messaging
# 34                org.axonframework.messaging
# 35                org.axonframework.messaging
# 36                org.axonframework.messaging
# 37                org.axonframework.messaging
# 38                org.axonframework.messaging
# 39                org.axonframework.messaging
# 40                org.axonframework.messaging
# 41                org.axonframework.messaging
# 42                org.axonframework.messaging
# 43                org.axonframework.messaging
# 44                org.axonframework.messaging
# 45                org.axonframework.messaging
# 46                org.axonframework.messaging
# 47                org.axonframework.messaging
# 48                org.axonframework.messaging
# 49                org.axonframework.messaging
# 50                org.axonframework.messaging
# 51                org.axonframework.messaging
# 52                org.axonframework.messaging
# 53                org.axonframework.messaging
# 54                org.axonframework.messaging
# 55                org.axonframework.messaging
# 56                org.axonframework.messaging
# 57                org.axonframework.messaging
# 58                org.axonframework.messaging
# 59                org.axonframework.messaging
#
#                                            dependency  \
# 0     QueryResponseMessage<-ConvertingResponseMessage
# 1              SubscriptionQueryMessage->ResponseType
# 2                     QuerySubscription->ResponseType
# 3                 StreamingQueryMessage->ResponseType
# 4                        SimpleQueryBus->ResponseType
# 5          GenericStreamingQueryMessage->ResponseType
# 6   GenericStreamingQueryMessage->PublisherRespons...
# 7                   GenericQueryMessage->ResponseType
# 8       GenericSubscriptionQueryMessage->ResponseType
# 9                          QueryGateway->ResponseType
# 10                        QueryGateway->ResponseTypes
# 11                         QueryMessage->ResponseType
# 12  SimpleQueryUpdateEmitter->MultipleInstancesRes...
# 13    SimpleQueryUpdateEmitter->PublisherResponseType
# 14     SimpleQueryUpdateEmitter->OptionalResponseType
# 15             SimpleQueryUpdateEmitter->ResponseType
# 16                  DefaultQueryGateway->ResponseType
# 17                   EventMessage<-NestingSpanFactory
# 18        TrackingEventProcessor$Builder->SpanFactory
# 19                AbstractEventProcessor->SpanFactory
# 20                       AbstractEventProcessor->Span
# 21                TrackingEventProcessor->SpanFactory
# 22                       TrackingEventProcessor->Span
# 23                SimpleEventBus$Builder->SpanFactory
# 24     SubscribingEventProcessor$Builder->SpanFactory
# 25              AbstractEventBus$Builder->SpanFactory
# 26          AbstractEventBus$Builder->NoOpSpanFactory
# 27                      AbstractEventBus->SpanFactory
# 28                             AbstractEventBus->Span
# 29    AbstractEventProcessor$Builder->NoOpSpanFactory
# 30        AbstractEventProcessor$Builder->SpanFactory
# 31                              EventMessage<-Headers
# 32                        DomainEventMessage<-Headers
# 33             TrackingToken<-StreamableMessageSource
# 34  TrackingEventProcessor$Builder->StreamableMess...
# 35  AbstractEventProcessor->MessageHandlerInterceptor
# 36    AbstractEventProcessor->DefaultInterceptorChain
# 37              AbstractEventProcessor->ResultMessage
# 38                       GenericEventMessage->Message
# 39                GenericEventMessage->GenericMessage
# 40                      GenericEventMessage->MetaData
# 41              GenericEventMessage->MessageDecorator
# 42    TrackingEventProcessor->StreamableMessageSource
# 43           TrackingEventProcessor->InterceptorChain
# 44                    TrackingEventProcessor->Message
# 45                EventBus->SubscribableMessageSource
# 46        EventBus->MessageDispatchInterceptorSupport
# 47                              EventMessage->Message
# 48  MultiStreamableMessageSource$Builder->Streamab...
# 49                GenericDomainEventMessage->MetaData
# 50          GenericDomainEventMessage->GenericMessage
# 51                 GenericDomainEventMessage->Message
# 52    ConcludesBatchParameterResolverFactory->Message
# 53   StreamingEventProcessor->StreamableMessageSource
# 54  TimestampParameterResolverFactory$TimestampPar...
# 55  TrackingTokenParameterResolverFactory$Tracking...
# 56  SubscribingEventProcessor$Builder->Subscribabl...
# 57                        DomainEventMessage->Message
# 58          GenericTrackedDomainEventMessage->Message
# 59                       EventMessageHandler->Message
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.882353             16               1
# 1                   0.882353             16               1
# 2                   0.882353             16               1
# 3                   0.882353             16               1
# 4                   0.882353             16               1
# 5                   0.882353             16               1
# 6                   0.882353             16               1
# 7                   0.882353             16               1
# 8                   0.882353             16               1
# 9                   0.882353             16               1
# 10                  0.882353             16               1
# 11                  0.882353             16               1
# 12                  0.882353             16               1
# 13                  0.882353             16               1
# 14                  0.882353             16               1
# 15                  0.882353             16               1
# 16                  0.882353             16               1
# 17                  0.857143             13               1
# 18                  0.857143             13               1
# 19                  0.857143             13               1
# 20                  0.857143             13               1
# 21                  0.857143             13               1
# 22                  0.857143             13               1
# 23                  0.857143             13               1
# 24                  0.857143             13               1
# 25                  0.857143             13               1
# 26                  0.857143             13               1
# 27                  0.857143             13               1
# 28                  0.857143             13               1
# 29                  0.857143             13               1
# 30                  0.857143             13               1
# 31                  0.853659             38               3
# 32                  0.853659             38               3
# 33                  0.853659             38               3
# 34                  0.853659             38               3
# 35                  0.853659             38               3
# 36                  0.853659             38               3
# 37                  0.853659             38               3
# 38                  0.853659             38               3
# 39                  0.853659             38               3
# 40                  0.853659             38               3
# 41                  0.853659             38               3
# 42                  0.853659             38               3
# 43                  0.853659             38               3
# 44                  0.853659             38               3
# 45                  0.853659             38               3
# 46                  0.853659             38               3
# 47                  0.853659             38               3
# 48                  0.853659             38               3
# 49                  0.853659             38               3
# 50                  0.853659             38               3
# 51                  0.853659             38               3
# 52                  0.853659             38               3
# 53                  0.853659             38               3
# 54                  0.853659             38               3
# 55                  0.853659             38               3
# 56                  0.853659             38               3
# 57                  0.853659             38               3
# 58                  0.853659             38               3
# 59                  0.853659             38               3

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.
#
# ### Table 4
# - List top 20 most used combinations of methods of larger Types that might benefit from *Interface Segregation*

# %%
query_cypher_to_data_frame("../cypher/Candidates_for_Interface_Segregation.cypher").head(20)
# Out:
#                                 fullDependentTypeName  declaredMethods  \
# 0    org.axonframework.commandhandling.CommandMessage                9
# 1        org.axonframework.eventhandling.EventMessage                9
# 2   org.axonframework.eventhandling.DomainEventMes...               10
# 3   org.axonframework.eventhandling.TrackedEventMe...               10
# 4        org.axonframework.eventhandling.EventMessage                9
# 5   org.axonframework.eventhandling.DomainEventMes...               10
# 6           org.axonframework.messaging.ResultMessage                9
# 7   org.axonframework.commandhandling.GenericComma...               14
# 8   org.axonframework.deadline.GenericDeadlineMessage               11
# 9   org.axonframework.eventhandling.TrackedEventMe...               12
# 10         org.axonframework.deadline.DeadlineMessage               10
# 11  org.axonframework.eventhandling.DomainEventMes...               10
# 12  org.axonframework.eventhandling.DomainEventMes...               10
# 13  org.axonframework.eventhandling.GenericEventMe...               10
# 14  org.axonframework.common.transaction.NoTransac...                4
# 15  org.axonframework.commandhandling.GenericComma...               15
# 16        org.axonframework.eventhandling.ReplayToken               13
# 17  org.axonframework.modelling.command.inspection...               13
# 18  org.axonframework.eventhandling.DomainEventMes...               11
# 19  org.axonframework.eventhandling.GenericEventMe...               11
#
#                                     calledMethodNames  calledMethods  \
# 0                                    [getCommandName]              1
# 1                       [getIdentifier, getTimestamp]              2
# 2                                 [getSequenceNumber]              1
# 3                                     [trackingToken]              1
# 4                                     [getIdentifier]              1
# 5   [getType, getAggregateIdentifier, getSequenceN...              3
# 6                    [isExceptional, exceptionResult]              2
# 7                            [asCommandResultMessage]              1
# 8                                 [asDeadlineMessage]              1
# 9                                     [trackingToken]              1
# 10                                  [getDeadlineName]              1
# 11                                          [getType]              1
# 12                           [getAggregateIdentifier]              1
# 13                                   [asEventMessage]              1
# 14                                         [instance]              1
# 15                           [asCommandResultMessage]              1
# 16                                         [isReplay]              1
# 17                                             [type]              1
# 18  [getType, getAggregateIdentifier, getSequenceN...              3
# 19                                   [asEventMessage]              1
#
#     callerTypes
# 0            18
# 1            10
# 2             9
# 3             8
# 4             8
# 5             6
# 6             6
# 7             5
# 8             5
# 9             4
# 10            4
# 11            4
# 12            4
# 13            4
# 14            4
# 15            3
# 16            3
# 17            3
# 18            3
# 19            3

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Types that are used by multiple packages
#
# #### Table 5
# - List the top 20 packages that are used by the highest count of different packages

# %%
query_cypher_to_data_frame("../cypher/Package_Usage/List_types_that_are_used_by_many_different_packages.cypher").head(20)
# Out:
#                                     dependentType.fqn  \
# 0               org.axonframework.common.BuilderUtils
# 1                 org.axonframework.messaging.Message
# 2   org.axonframework.common.AxonConfigurationExce...
# 3                org.axonframework.messaging.MetaData
# 4        org.axonframework.eventhandling.EventMessage
# 5   org.axonframework.messaging.unitofwork.UnitOfWork
# 6          org.axonframework.serialization.Serializer
# 7                     org.axonframework.common.Assert
# 8   org.axonframework.common.transaction.Transacti...
# 9    org.axonframework.serialization.SerializedObject
# 10     org.axonframework.serialization.SerializedType
# 11  org.axonframework.messaging.unitofwork.Current...
# 12  org.axonframework.common.AxonNonTransientExcep...
# 13  org.axonframework.eventhandling.GenericEventMe...
# 14  org.axonframework.eventhandling.DomainEventMes...
# 15      org.axonframework.eventhandling.TrackingToken
# 16  org.axonframework.messaging.annotation.Paramet...
# 17              org.axonframework.common.Registration
# 18  org.axonframework.serialization.SimpleSerializ...
# 19               org.axonframework.common.ObjectUtils
#
#             dependentType.name  \
# 0                 BuilderUtils
# 1                      Message
# 2   AxonConfigurationException
# 3                     MetaData
# 4                 EventMessage
# 5                   UnitOfWork
# 6                   Serializer
# 7                       Assert
# 8           TransactionManager
# 9             SerializedObject
# 10              SerializedType
# 11           CurrentUnitOfWork
# 12   AxonNonTransientException
# 13         GenericEventMessage
# 14          DomainEventMessage
# 15               TrackingToken
# 16    ParameterResolverFactory
# 17                Registration
# 18      SimpleSerializedObject
# 19                 ObjectUtils
#
#                                   dependentTypeLabels  numberOfUsingPackages
# 0                 [Type, File, Java, ByteCode, Class]                     44
# 1   [Type, File, Java, GenericDeclaration, ByteCod...                     39
# 2                 [Type, File, Java, ByteCode, Class]                     37
# 3                 [Type, File, Java, ByteCode, Class]                     33
# 4   [Type, File, Java, GenericDeclaration, ByteCod...                     32
# 5   [Type, File, Java, GenericDeclaration, ByteCod...                     31
# 6             [Type, File, Java, ByteCode, Interface]                     29
# 7                 [Type, File, Java, ByteCode, Class]                     27
# 8             [Type, File, Java, ByteCode, Interface]                     27
# 9   [Type, File, Java, GenericDeclaration, ByteCod...                     25
# 10            [Type, File, Java, ByteCode, Interface]                     24
# 11                [Type, File, Java, ByteCode, Class]                     21
# 12                [Type, File, Java, ByteCode, Class]                     18
# 13  [Type, File, Java, GenericDeclaration, ByteCod...                     18
# 14  [Type, File, Java, GenericDeclaration, ByteCod...                     18
# 15            [Type, File, Java, ByteCode, Interface]                     18
# 16            [Type, File, Java, ByteCode, Interface]                     18
# 17            [Type, File, Java, ByteCode, Interface]                     17
# 18  [Type, File, Java, GenericDeclaration, ByteCod...                     17
# 19                [Type, File, Java, ByteCode, Class]                     16

# %% [markdown]
# ### Packages that are used by multiple artifacts
#
# #### Table 6
# - List the top 20 artifacts that only use a few (compared to all existing) packages of another artifact

# %%
query_cypher_to_data_frame("../cypher/Package_Usage/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher").head(20)
# Out:
#                 artifactName     dependentArtifactName  dependentPackages  \
# 0       axon-disruptor-4.8.0      axon-messaging-4.8.0                  9
# 1            axon-test-4.8.0      axon-messaging-4.8.0                 10
# 2   axon-eventsourcing-4.8.0      axon-modelling-4.8.0                  2
# 3       axon-disruptor-4.8.0      axon-modelling-4.8.0                  2
# 4            axon-test-4.8.0  axon-eventsourcing-4.8.0                  2
# 5       axon-disruptor-4.8.0  axon-eventsourcing-4.8.0                  2
# 6       axon-modelling-4.8.0      axon-messaging-4.8.0                 18
# 7   axon-eventsourcing-4.8.0      axon-messaging-4.8.0                 20
# 8   axon-configuration-4.8.0  axon-eventsourcing-4.8.0                  4
# 9            axon-test-4.8.0      axon-modelling-4.8.0                  5
# 10  axon-configuration-4.8.0      axon-messaging-4.8.0                 34
# 11  axon-configuration-4.8.0      axon-modelling-4.8.0                  6
# 12      axon-modelling-4.8.0      axon-modelling-4.8.0                  6
# 13           axon-test-4.8.0           axon-test-4.8.0                  5
# 14      axon-messaging-4.8.0      axon-messaging-4.8.0                 41
# 15  axon-eventsourcing-4.8.0  axon-eventsourcing-4.8.0                  7
# 16  axon-configuration-4.8.0      axon-disruptor-4.8.0                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          64                0.140625
# 1                          64                0.156250
# 2                          10                0.200000
# 3                          10                0.200000
# 4                           9                0.222222
# 5                           9                0.222222
# 6                          64                0.281250
# 7                          64                0.312500
# 8                           9                0.444444
# 9                          10                0.500000
# 10                         64                0.531250
# 11                         10                0.600000
# 12                         10                0.600000
# 13                          8                0.625000
# 14                         64                0.640625
# 15                          9                0.777778
# 16                          1                1.000000
#
#                    dependentFullQualifiedPackageNames  \
# 0   [org.axonframework.common.caching, org.axonfra...
# 1   [org.axonframework.messaging, org.axonframewor...
# 2   [org.axonframework.modelling.command, org.axon...
# 3   [org.axonframework.modelling.command.inspectio...
# 4   [org.axonframework.eventsourcing, org.axonfram...
# 5   [org.axonframework.eventsourcing, org.axonfram...
# 6   [org.axonframework.serialization, org.axonfram...
# 7   [org.axonframework.serialization, org.axonfram...
# 8   [org.axonframework.eventsourcing.eventstore, o...
# 9   [org.axonframework.modelling.saga, org.axonfra...
# 10  [org.axonframework.messaging.unitofwork, org.a...
# 11  [org.axonframework.modelling.command, org.axon...
# 12  [org.axonframework.modelling.saga.repository, ...
# 13  [org.axonframework.test.matchers, org.axonfram...
# 14  [org.axonframework.eventhandling.tokenstore, o...
# 15  [org.axonframework.eventsourcing.snapshotting,...
# 16      [org.axonframework.disruptor.commandhandling]
#
#                                 dependentPackageNames
# 0   [caching, monitoring, commandhandling, transac...
# 1   [messaging, common, commandhandling, annotatio...
# 2                               [command, inspection]
# 3                               [inspection, command]
# 4                         [eventsourcing, eventstore]
# 5                         [eventsourcing, eventstore]
# 6   [serialization, xml, jpa, common, annotation, ...
# 7   [serialization, transaction, common, eventhand...
# 8      [eventstore, jpa, snapshotting, eventsourcing]
# 9   [saga, inspection, command, inmemory, repository]
# 10  [unitofwork, tracing, deadletter, event, sched...
# 11  [command, repository, inspection, jpa, saga, i...
# 12  [repository, saga, inspection, jpa, metamodel,...
# 13  [matchers, test, deadline, eventscheduler, utils]
# 14  [tokenstore, common, unitofwork, eventhandling...
# 15  [snapshotting, statements, eventstore, conflic...
# 16                                  [commandhandling]

# %% [markdown]
# ### Packages that are used by multiple artifacts
#
# #### Table 7
# - List the top 20 packages that only use a few (compared to all existing) types of another package

# %%
query_cypher_to_data_frame("../cypher/Package_Usage/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher").head(20)
# Out:
#                 artifactName dependentArtifactName  \
# 0            axon-test-4.8.0  axon-messaging-4.8.0
# 1   axon-eventsourcing-4.8.0  axon-messaging-4.8.0
# 2       axon-modelling-4.8.0  axon-messaging-4.8.0
# 3   axon-eventsourcing-4.8.0  axon-modelling-4.8.0
# 4   axon-eventsourcing-4.8.0  axon-modelling-4.8.0
# 5            axon-test-4.8.0  axon-messaging-4.8.0
# 6   axon-eventsourcing-4.8.0  axon-messaging-4.8.0
# 7       axon-modelling-4.8.0  axon-messaging-4.8.0
# 8       axon-modelling-4.8.0  axon-messaging-4.8.0
# 9            axon-test-4.8.0  axon-messaging-4.8.0
# 10           axon-test-4.8.0  axon-messaging-4.8.0
# 11  axon-eventsourcing-4.8.0  axon-messaging-4.8.0
# 12  axon-eventsourcing-4.8.0  axon-messaging-4.8.0
# 13  axon-eventsourcing-4.8.0  axon-messaging-4.8.0
# 14  axon-eventsourcing-4.8.0  axon-messaging-4.8.0
# 15  axon-eventsourcing-4.8.0  axon-messaging-4.8.0
# 16  axon-eventsourcing-4.8.0  axon-messaging-4.8.0
# 17           axon-test-4.8.0  axon-modelling-4.8.0
# 18           axon-test-4.8.0  axon-messaging-4.8.0
# 19  axon-eventsourcing-4.8.0  axon-messaging-4.8.0
#
#                                           packageName  \
# 0                     org.axonframework.test.matchers
# 1        org.axonframework.eventsourcing.snapshotting
# 2          org.axonframework.modelling.saga.metamodel
# 3   org.axonframework.eventsourcing.conflictresolu...
# 4     org.axonframework.eventsourcing.eventstore.jdbc
# 5               org.axonframework.test.eventscheduler
# 6   org.axonframework.eventsourcing.conflictresolu...
# 7                 org.axonframework.modelling.command
# 8       org.axonframework.modelling.command.legacyjpa
# 9                              org.axonframework.test
# 10                    org.axonframework.test.matchers
# 11  org.axonframework.eventsourcing.conflictresolu...
# 12         org.axonframework.eventsourcing.eventstore
# 13    org.axonframework.eventsourcing.eventstore.jdbc
# 14     org.axonframework.eventsourcing.eventstore.jpa
# 15  org.axonframework.eventsourcing.eventstore.leg...
# 16  org.axonframework.eventsourcing.eventstore.jdb...
# 17                       org.axonframework.test.utils
# 18                    org.axonframework.test.matchers
# 19  org.axonframework.eventsourcing.conflictresolu...
#
#                    dependentPackage.fqn  dependentTypes  \
# 0       org.axonframework.eventhandling               1
# 1       org.axonframework.eventhandling               1
# 2       org.axonframework.eventhandling               1
# 3   org.axonframework.modelling.command               1
# 4   org.axonframework.modelling.command               1
# 5       org.axonframework.eventhandling               2
# 6       org.axonframework.eventhandling               2
# 7       org.axonframework.eventhandling               2
# 8       org.axonframework.eventhandling               2
# 9           org.axonframework.messaging               1
# 10          org.axonframework.messaging               1
# 11          org.axonframework.messaging               1
# 12          org.axonframework.messaging               1
# 13      org.axonframework.serialization               1
# 14      org.axonframework.serialization               1
# 15      org.axonframework.serialization               1
# 16      org.axonframework.eventhandling               3
# 17     org.axonframework.modelling.saga               1
# 18    org.axonframework.commandhandling               1
# 19    org.axonframework.commandhandling               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                      93             0.010753
# 1                      93             0.010753
# 2                      93             0.010753
# 3                      51             0.019608
# 4                      51             0.019608
# 5                      93             0.021505
# 6                      93             0.021505
# 7                      93             0.021505
# 8                      93             0.021505
# 9                      35             0.028571
# 10                     35             0.028571
# 11                     35             0.028571
# 12                     35             0.028571
# 13                     34             0.029412
# 14                     34             0.029412
# 15                     34             0.029412
# 16                     93             0.032258
# 17                     30             0.033333
# 18                     29             0.034483
# 19                     29             0.034483
#
#                                    dependentTypeNames
# 0      [org.axonframework.eventhandling.EventMessage]
# 1   [org.axonframework.eventhandling.DomainEventData]
# 2      [org.axonframework.eventhandling.EventMessage]
# 3   [org.axonframework.modelling.command.Conflicti...
# 4   [org.axonframework.modelling.command.Concurren...
# 5   [org.axonframework.eventhandling.EventMessage,...
# 6   [org.axonframework.eventhandling.DomainEventMe...
# 7   [org.axonframework.eventhandling.EventBus, org...
# 8   [org.axonframework.eventhandling.DomainEventSe...
# 9               [org.axonframework.messaging.Message]
# 10              [org.axonframework.messaging.Message]
# 11              [org.axonframework.messaging.Message]
# 12  [org.axonframework.messaging.StreamableMessage...
# 13       [org.axonframework.serialization.Serializer]
# 14       [org.axonframework.serialization.Serializer]
# 15       [org.axonframework.serialization.Serializer]
# 16  [org.axonframework.eventhandling.GenericDomain...
# 17  [org.axonframework.modelling.saga.SimpleResour...
# 18  [org.axonframework.commandhandling.CommandMess...
# 19  [org.axonframework.commandhandling.CommandMess...
