# %% [markdown]
# # External Dependencies
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [py2neo](https://py2neo.org/2021.1/)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from py2neo import Graph

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.
graph = Graph("bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename):
    return graph.run(get_cypher_query_from_file(filename)).to_data_frame()

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## External Package Usage
#
# ### External Package
#
# A package is categorized as "external" if it is utilized as a dependency, or if any of its enclosed types are used as dependencies, but the code within it has not been analyzed (missing bytecode). This also applies to all build-in Java types, but they are explicitly filtered out here.
#
# ### External annotation dependency
#
# The aforementioned classification encompasses external annotation dependencies as well. These dependencies introduce significantly less coupling and are not indispensable for compiling code. Without the external annotation the code would most probably behave differently. Hence, they are included in the first more overall and general tables and then left out in the later more specific ones.

# %% [markdown]
# ### Table 1 - Top 20 most used external packages overall
#
# This table shows the external packages that are used by the most different internal types overall.
# Additionally, it shows which types of the external package are actually used. External annotations are also listed.
#
# **Columns:**
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalTypeCaller* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *allTypes* represents the total count of all analyzed types in general
# - *externalTypeNames* contains a list of actually utilized types of the external package

# %%
external_package_usage=query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_overall.cypher")

# Select columns and only show the first 20 entries (head)
external_package_usage.head(20)
# Out:
#                       externalPackageName  numberOfExternalTypeCaller  \
# 0                        javax.annotation                         339
# 1                               org.slf4j                         201
# 2                       javax.persistence                          78
# 3                     jakarta.persistence                          69
# 4                            org.hamcrest                          61
# 5        com.fasterxml.jackson.annotation                          57
# 6                              org.quartz                          37
# 7                  reactor.core.publisher                          35
# 8          com.fasterxml.jackson.databind                          15
# 9                     org.reactivestreams                          13
# 10  com.github.kagkarlsson.scheduler.task                          10
# 11                     com.lmax.disruptor                           9
# 12            com.thoughtworks.xstream.io                           9
# 13                      javax.cache.event                           8
# 14                      org.ehcache.event                           8
# 15       com.github.kagkarlsson.scheduler                           7
# 16    com.thoughtworks.xstream.converters                           6
# 17                              javax.sql                           6
# 18                 org.jobrunr.scheduling                           6
# 19                 com.lmax.disruptor.dsl                           5
#
#     numberOfExternalTypeCalls  allTypes  \
# 0                        1565      2584
# 1                         579      2584
# 2                         340      2584
# 3                         328      2584
# 4                         498      2584
# 5                          87      2584
# 6                         226      2584
# 7                         157      2584
# 8                          73      2584
# 9                          41      2584
# 10                         50      2584
# 11                         29      2584
# 12                         46      2584
# 13                         34      2584
# 14                         33      2584
# 15                         54      2584
# 16                         12      2584
# 17                         24      2584
# 18                         37      2584
# 19                         22      2584
#
#                                     externalTypeNames
# 0                     [Nonnull, Nullable, PreDestroy]
# 1                             [LoggerFactory, Logger]
# 2   [MappedSuperclass, IdClass, Id, Entity, Index,...
# 3   [IdClass, Id, MappedSuperclass, Entity, Table,...
# 4   [Matcher, CoreMatchers, StringDescription, Des...
# 5   [JsonGetter, JsonProperty, JsonTypeInfo$Id, Js...
# 6   [JobDataMap, JobExecutionContext, SchedulerCon...
# 7   [Mono, Flux, FluxSink$OverflowStrategy, FluxSi...
# 8   [DeserializationContext, JsonDeserializer, Obj...
# 9                                         [Publisher]
# 10  [TaskWithDataDescriptor, ExecutionContext, Tas...
# 11  [RingBuffer, EventHandler, LifecycleAware, Wai...
# 12  [HierarchicalStreamReader, HierarchicalStreamW...
# 13  [CacheEntryExpiredListener, CacheEntryCreatedL...
# 14  [EventType, EventFiring, EventOrdering, CacheE...
# 15    [Scheduler, SchedulerState, ScheduledExecution]
# 16         [UnmarshallingContext, MarshallingContext]
# 17                                       [DataSource]
# 18                         [JobScheduler, JobBuilder]
# 19       [Disruptor, EventHandlerGroup, ProducerType]

# %% [markdown]
# ### Chart 1 - Most called external packages in %
#
# Packages that are used less than 0.7% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_package_usage_significant = external_package_usage.copy();

# Add column "percentOfExternalTypeCalls" with the percentage of the "numberOfExternalTypeCalls".
external_package_usage_significant['percentOfExternalTypeCalls'] = external_package_usage_significant['numberOfExternalTypeCalls'] / external_package_usage_significant['numberOfExternalTypeCalls'].sum() * 100

# Change the external package name to "others" if it is called less than 0.7 percent
external_package_usage_significant.loc[external_package_usage_significant['percentOfExternalTypeCalls'] < 0.7, 'externalPackageName'] = 'others'

# Group external package name (foremost the new "others" entries) and sum their "percentOfExternalTypeCalls"
external_package_usage_significant = external_package_usage_significant.groupby('externalPackageName')['percentOfExternalTypeCalls'].sum()

# Sort by "percentOfExternalTypeCalls" descending
external_package_usage_significant.sort_values(ascending=False, inplace=True)

# %%
plot.figure();

# Set the name of the index to artifactName
#external_package_usage_significant=external_package_usage_significant.set_index('externalPackageName')

axis = external_package_usage_significant.plot(
    #y='numberOfExternalTypeCalls', 
    kind='pie',
    title='Significant External Package Usage',
    legend=True,
    labeldistance=None,
    autopct='%1.1f%%',
    pctdistance=1.2,
    cmap=main_color_map
)
axis.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 2 - Top 20 least used external packages overall
#
# This table identifies external packages that aren't used very often. This could help to find libraries that aren't actually needed or maybe easily replaceable. Some of them might be used sparsely on purpose for example as an adapter to an external library that is actually important. Thus, decisions need to be made on a case-by-case basis.
#
# **Columns:**
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package

# %%
# Sort by number of external type calls
external_package_least_used=external_package_usage.sort_values(by='numberOfExternalTypeCalls', ascending=True)

# Reset index
external_package_least_used = external_package_least_used.reset_index(drop=True)

# Select columns and only show the first 10 entries (head)
external_package_least_used[['externalPackageName','numberOfExternalTypeCalls']].head(20)
# Out:
#                                 externalPackageName  numberOfExternalTypeCalls
# 0                                   org.junit.rules                          1
# 1                             org.junit.jupiter.api                          1
# 2                                      reactor.core                          2
# 3                                  org.junit.runner                          2
# 4                                  org.jobrunr.jobs                          2
# 5                                org.ehcache.config                          2
# 6                                  javax.xml.stream                          2
# 7                          org.quartz.impl.matchers                          2
# 8             com.fasterxml.jackson.datatype.jsr310                          2
# 9           com.fasterxml.jackson.databind.jsontype                          3
# 10              com.fasterxml.jackson.databind.type                          3
# 11                          reactor.util.concurrent                          3
# 12            com.fasterxml.jackson.databind.module                          3
# 13                                     org.dom4j.io                          3
# 14      org.testcontainers.containers.wait.strategy                          5
# 15                  org.junit.jupiter.api.extension                          6
# 16  com.thoughtworks.xstream.converters.collections                          7
# 17                             reactor.util.context                          7
# 18                          org.junit.runners.model                          8
# 19                                  com.google.gson                          9

# %% [markdown]
# ### Table 3 - External usage per artifact
#
# The following table shows the most used external packages separately for each artifact including external annotations.
#
# **Columns:**
# - *artifactName* is used to group the the external package usage per artifact for a more detailed analysis.
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalTypeCaller* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfTypesInArtifact* represents the total count of all analyzed types for the artifact
# - *externalTypeNames* contains a list of actually utilized types of the external package

# %%
query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact.cypher")
# Out:
#                 artifactName              externalPackageName  \
# 0   axon-configuration-4.8.0                 javax.annotation
# 1   axon-configuration-4.8.0                        org.slf4j
# 2       axon-disruptor-4.8.0                        org.slf4j
# 3       axon-disruptor-4.8.0               com.lmax.disruptor
# 4       axon-disruptor-4.8.0                 javax.annotation
# ..                       ...                              ...
# 69           axon-test-4.8.0  org.junit.jupiter.api.extension
# 70           axon-test-4.8.0          org.junit.runners.model
# 71           axon-test-4.8.0            org.junit.jupiter.api
# 72           axon-test-4.8.0                  org.junit.rules
# 73           axon-test-4.8.0                 org.junit.runner
#
#     numberOfExternalTypeCaller  numberOfExternalTypeCalls  \
# 0                           12                        104
# 1                            9                         28
# 2                           12                         22
# 3                            9                         29
# 4                            6                         23
# ..                         ...                        ...
# 69                           3                          6
# 70                           2                          8
# 71                           1                          1
# 72                           1                          1
# 73                           1                          2
#
#     numberOfTypesInArtifact                                  externalTypeNames
# 0                        39                                          [Nonnull]
# 1                        39                            [Logger, LoggerFactory]
# 2                        22                            [Logger, LoggerFactory]
# 3                        22  [RingBuffer, EventHandler, LifecycleAware, Wai...
# 4                        22                                          [Nonnull]
# ..                      ...                                                ...
# 69                       87  [ExtensionContext, AfterEachCallback, BeforeEa...
# 70                       87                                        [Statement]
# 71                       87                                       [Assertions]
# 72                       87                                         [TestRule]
# 73                       87                                      [Description]
#
# [74 rows x 6 columns]

# %% [markdown]
# ### Table 4 - External usage per artifact and package
#
# The next table lists internal packages and the artifacts they belong to that use many different external types of a specific external package without taken external annotations into account. Only the first 30 rows are shown.
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *fullPackageName* is the package within the artifact that contains the type that calls the external package
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalTypeCaller* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfTypesInPackage* represents the total count of all types in that package
# - *externalTypeNames* contains a list of actually utilized types of the external package
# - *packageName* contains the name of the package (last part of *fullPackageName*)

# %%
external_package_usage_per_package = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_and_package.cypher")
external_package_usage_per_package.head(30)
# Out:
#                 artifactName  \
# 0            axon-test-4.8.0
# 1       axon-messaging-4.8.0
# 2       axon-messaging-4.8.0
# 3       axon-messaging-4.8.0
# 4       axon-messaging-4.8.0
# 5       axon-messaging-4.8.0
# 6       axon-messaging-4.8.0
# 7       axon-disruptor-4.8.0
# 8   axon-configuration-4.8.0
# 9       axon-disruptor-4.8.0
# 10           axon-test-4.8.0
# 11  axon-eventsourcing-4.8.0
# 12      axon-messaging-4.8.0
# 13      axon-messaging-4.8.0
# 14      axon-messaging-4.8.0
# 15      axon-messaging-4.8.0
# 16      axon-messaging-4.8.0
# 17      axon-messaging-4.8.0
# 18           axon-test-4.8.0
# 19  axon-eventsourcing-4.8.0
# 20      axon-messaging-4.8.0
# 21      axon-messaging-4.8.0
# 22      axon-messaging-4.8.0
# 23      axon-modelling-4.8.0
# 24      axon-disruptor-4.8.0
# 25  axon-eventsourcing-4.8.0
# 26      axon-messaging-4.8.0
# 27      axon-messaging-4.8.0
# 28      axon-messaging-4.8.0
# 29      axon-messaging-4.8.0
#
#                                       fullPackageName  \
# 0                     org.axonframework.test.matchers
# 1                     org.axonframework.queryhandling
# 2   org.axonframework.eventhandling.scheduling.quartz
# 3                   org.axonframework.deadline.quartz
# 4                     org.axonframework.eventhandling
# 5                org.axonframework.serialization.json
# 6              org.axonframework.eventhandling.pooled
# 7         org.axonframework.disruptor.commandhandling
# 8                            org.axonframework.config
# 9         org.axonframework.disruptor.commandhandling
# 10                        org.axonframework.test.saga
# 11  org.axonframework.eventsourcing.eventstore.leg...
# 12                   org.axonframework.common.caching
# 13                   org.axonframework.common.caching
# 14             org.axonframework.messaging.annotation
# 15          org.axonframework.messaging.responsetypes
# 16                    org.axonframework.queryhandling
# 17                    org.axonframework.queryhandling
# 18                   org.axonframework.test.aggregate
# 19         org.axonframework.eventsourcing.eventstore
# 20          org.axonframework.messaging.responsetypes
# 21                    org.axonframework.serialization
# 22                    org.axonframework.serialization
# 23    org.axonframework.modelling.saga.repository.jpa
# 24        org.axonframework.disruptor.commandhandling
# 25     org.axonframework.eventsourcing.eventstore.jpa
# 26                           org.axonframework.common
# 27                   org.axonframework.common.caching
# 28             org.axonframework.deadline.dbscheduler
# 29              org.axonframework.eventhandling.async
#
#                       externalPackageName  numberOfExternalTypeCaller  \
# 0                            org.hamcrest                          38
# 1                  reactor.core.publisher                          28
# 2                              org.quartz                          19
# 3                              org.quartz                          18
# 4                               org.slf4j                          15
# 5          com.fasterxml.jackson.databind                          15
# 6                               org.slf4j                          13
# 7                               org.slf4j                          12
# 8                               org.slf4j                           9
# 9                      com.lmax.disruptor                           9
# 10                           org.hamcrest                           9
# 11                              org.slf4j                           8
# 12                      org.ehcache.event                           8
# 13                      javax.cache.event                           8
# 14                              org.slf4j                           8
# 15                 reactor.core.publisher                           7
# 16                    org.reactivestreams                           7
# 17                              org.slf4j                           7
# 18                           org.hamcrest                           7
# 19                              org.slf4j                           6
# 20                    org.reactivestreams                           6
# 21    com.thoughtworks.xstream.converters                           6
# 22            com.thoughtworks.xstream.io                           6
# 23                    jakarta.persistence                           6
# 24                 com.lmax.disruptor.dsl                           5
# 25                    jakarta.persistence                           5
# 26                              org.slf4j                           5
# 27                         net.sf.ehcache                           5
# 28  com.github.kagkarlsson.scheduler.task                           5
# 29                              org.slf4j                           5
#
#     numberOfExternalTypeCalls  numberOfTypesInPackage  \
# 0                         188                      24
# 1                         123                      42
# 2                          95                       6
# 3                         131                       4
# 4                          55                      93
# 5                          73                       7
# 6                          59                      20
# 7                          22                      22
# 8                          28                      39
# 9                          29                      22
# 10                         91                      21
# 11                         15                      10
# 12                         33                      15
# 13                         34                      15
# 14                         15                      54
# 15                         34                       8
# 16                         27                      42
# 17                         16                      42
# 18                        136                      19
# 19                          9                      31
# 20                         14                       8
# 21                         12                      34
# 22                         39                      34
# 23                         68                       7
# 24                         22                      22
# 25                         42                       7
# 26                         15                      28
# 27                         63                      15
# 28                         25                       6
# 29                         16                      15
#
#                                     externalTypeNames      packageName
# 0   [Description, Matcher, TypeSafeMatcher, BaseMa...         matchers
# 1   [FluxSink, Mono, Signal, Flux, ConnectableFlux...    queryhandling
# 2   [JobDataMap, Scheduler, JobDetail, JobExecutio...           quartz
# 3   [JobDataMap, JobKey, SchedulerException, JobBu...           quartz
# 4                             [Logger, LoggerFactory]    eventhandling
# 5   [JsonNode, ObjectReader, ObjectMapper, ObjectW...             json
# 6                             [Logger, LoggerFactory]           pooled
# 7                             [Logger, LoggerFactory]  commandhandling
# 8                             [LoggerFactory, Logger]           config
# 9   [WaitStrategy, BlockingWaitStrategy, Exception...  commandhandling
# 10  [Matcher, CoreMatchers, StringDescription, Des...             saga
# 11                            [Logger, LoggerFactory]        legacyjpa
# 12  [EventFiring, EventOrdering, CacheEventListene...          caching
# 13  [CacheEntryExpiredListener, CacheEntryCreatedL...          caching
# 14                            [LoggerFactory, Logger]       annotation
# 15                                       [Mono, Flux]    responsetypes
# 16                                        [Publisher]    queryhandling
# 17                            [Logger, LoggerFactory]    queryhandling
# 18  [Description, StringDescription, Matcher, Core...        aggregate
# 19                            [LoggerFactory, Logger]       eventstore
# 20                                        [Publisher]    responsetypes
# 21         [MarshallingContext, UnmarshallingContext]    serialization
# 22  [HierarchicalStreamReader, HierarchicalStreamW...    serialization
# 23  [Query, TypedQuery, EntityNotFoundException, E...              jpa
# 24       [ProducerType, Disruptor, EventHandlerGroup]  commandhandling
# 25  [Query, TypedQuery, EntityManager, EntityExist...              jpa
# 26                            [Logger, LoggerFactory]           common
# 27                 [Ehcache, Element, CacheException]          caching
# 28  [TaskWithDataDescriptor, ExecutionContext, Tas...      dbscheduler
# 29                            [Logger, LoggerFactory]            async

# %% [markdown]
# ### Table 5 - Top 20 external package usage per type
#
# This table lists the internal types that utilize the most different external types and packages. These have the highest probability of change depending on external libraries. A case-by-case approach is also advisable here because there could for example also be code units that encapsulate an external library and have this high count of external dependencies on purpose.
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *fullPackageName* is the package within the artifact that contains the type that calls external types
# - *typeName* identifies the internal type within the package and artifact that calls external types
# - *numberOfExternalTypeCaller* and *numberOfExternalTypes* refers to the distinct external types that are used by the internal type
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfTypesInPackage* represents the total count of all types in that package
# - *numberOfExternalPackages* shows how many different external packages are used by the internal type
# - *externalPackageNames* contains the list of names of the different external packages that are used by the internal type
# - *externalTypeNames* contains a list of actually utilized types of the external package
# - *packageName* contains the name of the package (last part of *fullPackageName*)

# %%
external_package_usage_per_type = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_type.cypher")
external_package_usage_per_type.head(20)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.8.0
# 1       axon-messaging-4.8.0
# 2       axon-messaging-4.8.0
# 3       axon-messaging-4.8.0
# 4       axon-disruptor-4.8.0
# 5       axon-disruptor-4.8.0
# 6       axon-messaging-4.8.0
# 7       axon-messaging-4.8.0
# 8       axon-messaging-4.8.0
# 9       axon-messaging-4.8.0
# 10      axon-messaging-4.8.0
# 11      axon-messaging-4.8.0
# 12      axon-messaging-4.8.0
# 13      axon-messaging-4.8.0
# 14      axon-messaging-4.8.0
# 15      axon-messaging-4.8.0
# 16      axon-disruptor-4.8.0
# 17      axon-disruptor-4.8.0
# 18  axon-eventsourcing-4.8.0
# 19  axon-eventsourcing-4.8.0
#
#                                       fullPackageName  \
# 0                org.axonframework.serialization.json
# 1              org.axonframework.deadline.dbscheduler
# 2   org.axonframework.eventhandling.scheduling.dbs...
# 3                 org.axonframework.serialization.xml
# 4         org.axonframework.disruptor.commandhandling
# 5         org.axonframework.disruptor.commandhandling
# 6                  org.axonframework.deadline.jobrunr
# 7                   org.axonframework.deadline.quartz
# 8   org.axonframework.eventhandling.scheduling.job...
# 9           org.axonframework.messaging.responsetypes
# 10                    org.axonframework.queryhandling
# 11                    org.axonframework.queryhandling
# 12                    org.axonframework.serialization
# 13                    org.axonframework.serialization
# 14                    org.axonframework.serialization
# 15               org.axonframework.serialization.json
# 16        org.axonframework.disruptor.commandhandling
# 17        org.axonframework.disruptor.commandhandling
# 18     org.axonframework.eventsourcing.eventstore.jpa
# 19     org.axonframework.eventsourcing.eventstore.jpa
#
#                                              typeName  \
# 0                                   JacksonSerializer
# 1                          DbSchedulerDeadlineManager
# 2                           DbSchedulerEventScheduler
# 3                                   XStreamSerializer
# 4                                 DisruptorCommandBus
# 5             DisruptorCommandBus$DisruptorRepository
# 6                              JobRunrDeadlineManager
# 7                               QuartzDeadlineManager
# 8                               JobRunrEventScheduler
# 9                       MultipleInstancesResponseType
# 10                           SimpleQueryUpdateEmitter
# 11                                     SimpleQueryBus
# 12        AbstractXStreamSerializer$MetaDataConverter
# 13                     GapAwareTrackingTokenConverter
# 14  GapAwareTrackingTokenConverter$ReflectivelyCon...
# 15                               MetaDataDeserializer
# 16               DisruptorCommandBus$ExceptionHandler
# 17                         BlacklistDetectingCallback
# 18                              JpaEventStorageEngine
# 19                              SQLErrorCodesResolver
#
#     numberOfExternalTypeCaller  numberOfExternalTypeCalls  \
# 0                            9                         29
# 1                           12                         91
# 2                           10                         46
# 3                            7                         22
# 4                            6                         34
# 5                            4                         14
# 6                            7                         28
# 7                           13                         78
# 8                            6                         27
# 9                            7                         17
# 10                          13                         33
# 11                           6                         54
# 12                           6                         14
# 13                           6                         25
# 14                           6                         25
# 15                           6                         21
# 16                           3                          5
# 17                           4                         11
# 18                           6                         47
# 19                           4                         12
#
#     numberOfExternalPackages  numberOfExternalTypes  \
# 0                          6                      9
# 1                          5                     12
# 2                          5                     10
# 3                          5                      7
# 4                          4                      6
# 5                          4                      4
# 6                          4                      7
# 7                          4                     13
# 8                          4                      6
# 9                          4                      7
# 10                         4                     13
# 11                         4                      6
# 12                         4                      6
# 13                         4                      6
# 14                         4                      6
# 15                         4                      6
# 16                         3                      3
# 17                         3                      4
# 18                         3                      6
# 19                         3                      4
#
#                                  externalPackageNames  \
# 0   [javax.annotation, com.fasterxml.jackson.datab...
# 1   [javax.annotation, org.slf4j, com.github.kagka...
# 2   [javax.annotation, org.slf4j, com.github.kagka...
# 3   [org.slf4j, com.thoughtworks.xstream, org.dom4...
# 4   [org.slf4j, com.lmax.disruptor, javax.annotati...
# 5   [org.slf4j, com.lmax.disruptor, javax.annotati...
# 6   [javax.annotation, org.slf4j, org.jobrunr.sche...
# 7   [javax.annotation, org.slf4j, org.quartz, org....
# 8   [javax.annotation, org.slf4j, org.jobrunr.sche...
# 9   [org.slf4j, com.fasterxml.jackson.annotation, ...
# 10  [javax.annotation, org.slf4j, org.reactivestre...
# 11  [javax.annotation, org.slf4j, org.reactivestre...
# 12  [com.thoughtworks.xstream.converters.collectio...
# 13  [com.thoughtworks.xstream.mapper, com.thoughtw...
# 14  [com.thoughtworks.xstream.mapper, com.thoughtw...
# 15  [com.fasterxml.jackson.databind.type, com.fast...
# 16  [org.slf4j, com.lmax.disruptor.dsl, com.lmax.d...
# 17  [org.slf4j, com.lmax.disruptor, javax.annotation]
# 18  [javax.annotation, org.slf4j, jakarta.persiste...
# 19        [org.slf4j, javax.sql, jakarta.persistence]
#
#                                     externalTypeNames      packageName  \
# 0   [javax.annotation.Nonnull, com.fasterxml.jacks...             json
# 1   [javax.annotation.Nonnull, javax.annotation.Nu...      dbscheduler
# 2   [javax.annotation.Nonnull, org.slf4j.Logger, o...      dbscheduler
# 3   [org.slf4j.Logger, org.slf4j.LoggerFactory, co...              xml
# 4   [org.slf4j.Logger, com.lmax.disruptor.RingBuff...  commandhandling
# 5   [org.slf4j.Logger, com.lmax.disruptor.RingBuff...  commandhandling
# 6   [javax.annotation.Nonnull, javax.annotation.Nu...          jobrunr
# 7   [javax.annotation.Nonnull, org.slf4j.Logger, o...           quartz
# 8   [javax.annotation.Nonnull, org.slf4j.Logger, o...          jobrunr
# 9   [org.slf4j.Logger, org.slf4j.LoggerFactory, co...    responsetypes
# 10  [javax.annotation.Nonnull, org.slf4j.Logger, o...    queryhandling
# 11  [javax.annotation.Nonnull, org.slf4j.Logger, o...    queryhandling
# 12  [com.thoughtworks.xstream.converters.collectio...    serialization
# 13  [com.thoughtworks.xstream.mapper.Mapper, com.t...    serialization
# 14  [com.thoughtworks.xstream.mapper.Mapper, com.t...    serialization
# 15  [com.fasterxml.jackson.databind.type.TypeFacto...             json
# 16  [org.slf4j.Logger, com.lmax.disruptor.dsl.Disr...  commandhandling
# 17  [org.slf4j.Logger, com.lmax.disruptor.RingBuff...  commandhandling
# 18  [javax.annotation.Nonnull, org.slf4j.Logger, o...              jpa
# 19  [org.slf4j.Logger, org.slf4j.LoggerFactory, ja...              jpa
#
#                                          fullTypeName
# 0   org.axonframework.serialization.json.JacksonSe...
# 1   org.axonframework.deadline.dbscheduler.DbSched...
# 2   org.axonframework.eventhandling.scheduling.dbs...
# 3   org.axonframework.serialization.xml.XStreamSer...
# 4   org.axonframework.disruptor.commandhandling.Di...
# 5   org.axonframework.disruptor.commandhandling.Di...
# 6   org.axonframework.deadline.jobrunr.JobRunrDead...
# 7   org.axonframework.deadline.quartz.QuartzDeadli...
# 8   org.axonframework.eventhandling.scheduling.job...
# 9   org.axonframework.messaging.responsetypes.Mult...
# 10  org.axonframework.queryhandling.SimpleQueryUpd...
# 11     org.axonframework.queryhandling.SimpleQueryBus
# 12  org.axonframework.serialization.AbstractXStrea...
# 13  org.axonframework.serialization.GapAwareTracki...
# 14  org.axonframework.serialization.GapAwareTracki...
# 15  org.axonframework.serialization.json.MetaDataD...
# 16  org.axonframework.disruptor.commandhandling.Di...
# 17  org.axonframework.disruptor.commandhandling.Bl...
# 18  org.axonframework.eventsourcing.eventstore.jpa...
# 19  org.axonframework.eventsourcing.eventstore.jpa...

# %% [markdown]
# ### Table 6 - External package usage distribution per type
#
# The next table shown here only includes the first 20 rows.
# It shows how many types use one external package, how many use two, etc. .
# This gives an overview of the distribution of external package calls and the overall coupling to external libraries. The higher the count of distinct external packages the lower should be the count of types that use them. Dependencies to external annotations are left out here.
#
# Have a look above to find out which types have the highest external package dependency usage.
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *artifactTypes* the total count of types in the artifact
# - *numberOfExternalPackages* the number of distinct external packages used
# - *numberOfTypes* in the artifact where the *numberOfExternalPackages* applies
# - *numberOfTypesPercentage* in the artifact where the *numberOfExternalPackages* applies in %

# %%
external_package_usage_per_type_distribution = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_type_distribution.cypher")
external_package_usage_per_type_distribution[['artifactName', 'artifactTypes', 'numberOfExternalPackages', 'numberOfTypes', 'numberOfTypesPercentage']].head(20)
# Out:
#                artifactName  artifactTypes  numberOfExternalPackages  \
# 0  axon-configuration-4.8.0             39                         1
# 1      axon-disruptor-4.8.0             22                         1
# 2  axon-eventsourcing-4.8.0            130                         1
# 3  axon-eventsourcing-4.8.0            130                         2
# 4      axon-messaging-4.8.0            762                         1
# 5      axon-messaging-4.8.0            762                         2
# 6      axon-modelling-4.8.0            150                         1
# 7      axon-modelling-4.8.0            150                         2
# 8           axon-test-4.8.0             87                         1
#
#    numberOfTypes  numberOfTypesPercentage
# 0             12                30.769231
# 1              6                27.272727
# 2             28                21.538462
# 3              3                 2.307692
# 4            227                29.790026
# 5             13                 1.706037
# 6             35                23.333333
# 7              2                 1.333333
# 8             10                11.494253

# %% [markdown]
# ### Table 7 - External package usage distribution in percentage
#
# The following table uses the same data as Table 6 but has a column per internal artifact and a row for the number of different external packages used. The values are the percentages of types that fulfill both conditions so they belong to artifact and have the exact count of different external packages used. Dependencies to external annotations are left out here.

# %%
# Organize artifacts in columns with the number of types as values using pivot
# Every row represents the number of external packages
external_package_usage_per_type_distribution=external_package_usage_per_type_distribution.pivot(index='numberOfExternalPackages', columns='artifactName', values='numberOfTypesPercentage')

# Fill missing values with zero
external_package_usage_per_type_distribution.fillna(0, inplace=True)

# Convert to integer
# external_package_usage_per_type_distribution=external_package_usage_per_type_distribution.astype(int)

external_package_usage_per_type_distribution.head(10)
# Out:
# artifactName              axon-configuration-4.8.0  axon-disruptor-4.8.0  \
# numberOfExternalPackages
# 1                                        30.769231             27.272727
# 2                                         0.000000              0.000000
#
# artifactName              axon-eventsourcing-4.8.0  axon-messaging-4.8.0  \
# numberOfExternalPackages
# 1                                        21.538462             29.790026
# 2                                         2.307692              1.706037
#
# artifactName              axon-modelling-4.8.0  axon-test-4.8.0
# numberOfExternalPackages
# 1                                    23.333333        11.494253
# 2                                     1.333333         0.000000

# %% [markdown]
# ### Chart 2 - External package usage distribution in percentage
#
# The next chart shows the number of types per artifact that use the given number of different external packages as listed in Table 7. Dependencies to external annotations are left out here.

# %%
plot.figure();
axes = external_package_usage_per_type_distribution.plot(
    kind='bar', 
    grid=True,
    title='Relative External Package Usage', 
    xlabel='external package count',
    ylabel='percentage of types',
    cmap=main_color_map,
)
plot.show()

# %% [markdown]
# ### Chart 3 - External package usage distribution in percentage stacked per artifact
#
# The following chart shows a stacked bar for each artifact. Every color represents a different count of different external packages used. The y axis then shows how many percent of types (compared to all types of that artifact) use these external packages. By stacking them above each other it is easier to compare the artifacts and their external package usage. Dependencies to external annotations are left out here.

# %%
plot.figure();
axes = external_package_usage_per_type_distribution.transpose().plot(
    kind='bar', 
    grid=True,
    title='Relative External Package Usage', 
    xlabel='artifact',
    ylabel='percentage of types',
    stacked=True,
    cmap=main_color_map,
)
plot.show()

# %% [markdown]
# ## Maven POMs
#
#
# ### Table 8 - Maven POMs and their declared dependencies
#
# If Maven is used as for package and dependency management and a ".pom" file is included in the artifact, the following table shows the external dependencies that are declared there.

# %%
query_cypher_to_data_frame("../cypher/External_Dependencies/Maven_POMs_and_their_declared_dependencies.cypher")
# Out:
#          pom.artifactId                        pom.name    scope  \
# 0    axon-configuration  Axon Framework - Configuration     test
# 1    axon-configuration  Axon Framework - Configuration     test
# 2    axon-configuration  Axon Framework - Configuration  default
# 3    axon-configuration  Axon Framework - Configuration  default
# 4    axon-configuration  Axon Framework - Configuration     test
# ..                  ...                             ...      ...
# 109           axon-test  Axon Framework - Test Fixtures     test
# 110           axon-test  Axon Framework - Test Fixtures  default
# 111           axon-test  Axon Framework - Test Fixtures  default
# 112           axon-test  Axon Framework - Test Fixtures     test
# 113           axon-test  Axon Framework - Test Fixtures  default
#
#      dependency.optional dependentArtifact.group   dependentArtifact.name
# 0                  False     jakarta.persistence  jakarta.persistence-api
# 1                  False    org.quartz-scheduler                   quartz
# 2                  False      ${project.groupId}       axon-eventsourcing
# 3                  False      ${project.groupId}           axon-disruptor
# 4                  False            javax.inject             javax.inject
# ..                   ...                     ...                      ...
# 109                False     jakarta.persistence  jakarta.persistence-api
# 110                 True    com.google.code.gson                     gson
# 111                 True      org.testcontainers           testcontainers
# 112                False     org.springframework             spring-beans
# 113                 True            org.hamcrest         hamcrest-library
#
# [114 rows x 6 columns]
