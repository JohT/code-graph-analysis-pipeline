# %% [markdown]
# # Method Metrics
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## Effective Method Line Count

# %% [markdown]
# ### Table 1a - Effective method line count distribution
#
# This table shows the distribution of the effective method line count per artifact.
# For each artifact the number of methods with effective line count = 1,2,3,... is shown to get an overview of how line counts are distributed over methods.
#
# Only the 15 artifacts with the highest method count and their effective method line count distribution (limited by 40)is shown here. The whole table can be found in the CSV report `Effective_Method_Line_Count_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
effective_method_line_count_distribution_max_artifacts=20

effective_method_line_count_distribution=query_cypher_to_data_frame("../cypher/Overview/Effective_Method_Line_Count_Distribution.cypher")
effective_method_line_count_distribution=effective_method_line_count_distribution.pivot(index='effectiveLineCount', columns='artifactName', values='methods')

# Fill missing values with zero
effective_method_line_count_distribution.fillna(0, inplace=True)

# Convert to integer
effective_method_line_count_distribution=effective_method_line_count_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
effective_method_line_count_distribution = effective_method_line_count_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:effective_method_line_count_distribution_max_artifacts]]

effective_method_line_count_distribution.head(40)
# Out:
# artifactName        axon-messaging-4.7.6.jar  axon-eventsourcing-4.7.6.jar  \
# effectiveLineCount
# 1                                       2519                           567
# 2                                        724                           197
# 3                                        562                           123
# 4                                        248                            64
# 5                                        201                            40
# 6                                        132                            33
# 7                                         94                            31
# 8                                         74                            11
# 9                                         65                            17
# 10                                        38                             8
# 11                                        40                             2
# 12                                        31                             5
# 13                                        22                             2
# 14                                        15                             3
# 15                                         6                             2
# 16                                         7                             6
# 17                                         8                             0
# 18                                         8                             3
# 19                                         6                             0
# 20                                         4                             2
# 21                                         9                             2
# 22                                         4                             0
# 23                                         3                             1
# 24                                         3                             2
# 25                                         0                             2
# 26                                         1                             0
# 28                                         1                             0
# 29                                         1                             0
# 31                                         0                             0
# 32                                         1                             0
# 33                                         2                             0
# 36                                         2                             0
# 38                                         0                             0
# 40                                         0                             0
# 42                                         1                             0
# 45                                         0                             0
# 50                                         1                             0
# 57                                         1                             0
# 64                                         1                             0
# 70                                         1                             0
#
# artifactName        axon-modelling-4.7.6.jar  axon-test-4.7.6.jar  \
# effectiveLineCount
# 1                                        509                  267
# 2                                        141                  159
# 3                                        134                   62
# 4                                         56                   48
# 5                                         48                   23
# 6                                         38                   17
# 7                                         24                   19
# 8                                         11                   10
# 9                                          8                   10
# 10                                         7                    5
# 11                                         9                    9
# 12                                         2                    8
# 13                                         9                    3
# 14                                         3                    2
# 15                                         4                    2
# 16                                         2                    2
# 17                                         2                    4
# 18                                         0                    2
# 19                                         1                    0
# 20                                         2                    1
# 21                                         1                    2
# 22                                         1                    1
# 23                                         1                    0
# 24                                         1                    1
# 25                                         0                    0
# 26                                         1                    0
# 28                                         0                    1
# 29                                         0                    1
# 31                                         0                    1
# 32                                         0                    0
# 33                                         0                    0
# 36                                         0                    0
# 38                                         1                    0
# 40                                         0                    0
# 42                                         0                    0
# 45                                         0                    1
# 50                                         0                    0
# 57                                         0                    0
# 64                                         0                    0
# 70                                         0                    0
#
# artifactName        axon-configuration-4.7.6.jar  axon-disruptor-4.7.6.jar
# effectiveLineCount
# 1                                            305                        84
# 2                                            134                        31
# 3                                             36                        30
# 4                                             32                         8
# 5                                             14                         5
# 6                                             16                         6
# 7                                              2                         2
# 8                                              7                         0
# 9                                              8                         4
# 10                                             5                         3
# 11                                             4                         1
# 12                                             1                         1
# 13                                             2                         1
# 14                                             1                         2
# 15                                             0                         0
# 16                                             0                         0
# 17                                             1                         1
# 18                                             2                         1
# 19                                             1                         1
# 20                                             0                         0
# 21                                             1                         0
# 22                                             0                         1
# 23                                             1                         0
# 24                                             0                         1
# 25                                             0                         0
# 26                                             1                         0
# 28                                             0                         0
# 29                                             0                         0
# 31                                             0                         0
# 32                                             0                         1
# 33                                             0                         0
# 36                                             0                         0
# 38                                             0                         0
# 40                                             1                         0
# 42                                             1                         0
# 45                                             0                         0
# 50                                             0                         0
# 57                                             0                         0
# 64                                             0                         0
# 70                                             0                         0

# %% [markdown]
# ### Table 1b - Effective method line count distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
effective_method_line_count_distribution_normalized = effective_method_line_count_distribution.div(effective_method_line_count_distribution.sum(axis=0), axis=1).multiply(100)
effective_method_line_count_distribution_normalized.head(40)
# Out:
# artifactName        axon-messaging-4.7.6.jar  axon-eventsourcing-4.7.6.jar  \
# effectiveLineCount
# 1                                  52.088503                     50.489760
# 2                                  14.971050                     17.542297
# 3                                  11.621175                     10.952805
# 4                                   5.128205                      5.699020
# 5                                   4.156328                      3.561888
# 6                                   2.729529                      2.938557
# 7                                   1.943755                      2.760463
# 8                                   1.530190                      0.979519
# 9                                   1.344086                      1.513802
# 10                                  0.785773                      0.712378
# 11                                  0.827130                      0.178094
# 12                                  0.641026                      0.445236
# 13                                  0.454921                      0.178094
# 14                                  0.310174                      0.267142
# 15                                  0.124069                      0.178094
# 16                                  0.144748                      0.534283
# 17                                  0.165426                      0.000000
# 18                                  0.165426                      0.267142
# 19                                  0.124069                      0.000000
# 20                                  0.082713                      0.178094
# 21                                  0.186104                      0.178094
# 22                                  0.082713                      0.000000
# 23                                  0.062035                      0.089047
# 24                                  0.062035                      0.178094
# 25                                  0.000000                      0.178094
# 26                                  0.020678                      0.000000
# 28                                  0.020678                      0.000000
# 29                                  0.020678                      0.000000
# 31                                  0.000000                      0.000000
# 32                                  0.020678                      0.000000
# 33                                  0.041356                      0.000000
# 36                                  0.041356                      0.000000
# 38                                  0.000000                      0.000000
# 40                                  0.000000                      0.000000
# 42                                  0.020678                      0.000000
# 45                                  0.000000                      0.000000
# 50                                  0.020678                      0.000000
# 57                                  0.020678                      0.000000
# 64                                  0.020678                      0.000000
# 70                                  0.020678                      0.000000
#
# artifactName        axon-modelling-4.7.6.jar  axon-test-4.7.6.jar  \
# effectiveLineCount
# 1                                  50.098425            40.393343
# 2                                  13.877953            24.054463
# 3                                  13.188976             9.379728
# 4                                   5.511811             7.261725
# 5                                   4.724409             3.479576
# 6                                   3.740157             2.571861
# 7                                   2.362205             2.874433
# 8                                   1.082677             1.512859
# 9                                   0.787402             1.512859
# 10                                  0.688976             0.756430
# 11                                  0.885827             1.361573
# 12                                  0.196850             1.210287
# 13                                  0.885827             0.453858
# 14                                  0.295276             0.302572
# 15                                  0.393701             0.302572
# 16                                  0.196850             0.302572
# 17                                  0.196850             0.605144
# 18                                  0.000000             0.302572
# 19                                  0.098425             0.000000
# 20                                  0.196850             0.151286
# 21                                  0.098425             0.302572
# 22                                  0.098425             0.151286
# 23                                  0.098425             0.000000
# 24                                  0.098425             0.151286
# 25                                  0.000000             0.000000
# 26                                  0.098425             0.000000
# 28                                  0.000000             0.151286
# 29                                  0.000000             0.151286
# 31                                  0.000000             0.151286
# 32                                  0.000000             0.000000
# 33                                  0.000000             0.000000
# 36                                  0.000000             0.000000
# 38                                  0.098425             0.000000
# 40                                  0.000000             0.000000
# 42                                  0.000000             0.000000
# 45                                  0.000000             0.151286
# 50                                  0.000000             0.000000
# 57                                  0.000000             0.000000
# 64                                  0.000000             0.000000
# 70                                  0.000000             0.000000
#
# artifactName        axon-configuration-4.7.6.jar  axon-disruptor-4.7.6.jar
# effectiveLineCount
# 1                                      52.951389                 45.652174
# 2                                      23.263889                 16.847826
# 3                                       6.250000                 16.304348
# 4                                       5.555556                  4.347826
# 5                                       2.430556                  2.717391
# 6                                       2.777778                  3.260870
# 7                                       0.347222                  1.086957
# 8                                       1.215278                  0.000000
# 9                                       1.388889                  2.173913
# 10                                      0.868056                  1.630435
# 11                                      0.694444                  0.543478
# 12                                      0.173611                  0.543478
# 13                                      0.347222                  0.543478
# 14                                      0.173611                  1.086957
# 15                                      0.000000                  0.000000
# 16                                      0.000000                  0.000000
# 17                                      0.173611                  0.543478
# 18                                      0.347222                  0.543478
# 19                                      0.173611                  0.543478
# 20                                      0.000000                  0.000000
# 21                                      0.173611                  0.000000
# 22                                      0.000000                  0.543478
# 23                                      0.173611                  0.000000
# 24                                      0.000000                  0.543478
# 25                                      0.000000                  0.000000
# 26                                      0.173611                  0.000000
# 28                                      0.000000                  0.000000
# 29                                      0.000000                  0.000000
# 31                                      0.000000                  0.000000
# 32                                      0.000000                  0.543478
# 33                                      0.000000                  0.000000
# 36                                      0.000000                  0.000000
# 38                                      0.000000                  0.000000
# 40                                      0.173611                  0.000000
# 42                                      0.173611                  0.000000
# 45                                      0.000000                  0.000000
# 50                                      0.000000                  0.000000
# 57                                      0.000000                  0.000000
# 64                                      0.000000                  0.000000
# 70                                      0.000000                  0.000000

# %% [markdown]
# ### Table 1b Chart 1 - Effective method line count distribution (normalized)

# %%
plot.figure();
method_line_count_x_ticks=range(1,20)
axes = effective_method_line_count_distribution_normalized.head(20).plot(
    kind='line',
    logx=True,
    grid=True,
    xlim=[2, 20],
    ylim=[0, 20],
    xticks=method_line_count_x_ticks,
    title='Effective Method Line Count Distribution', 
    xlabel='effective line count',
    ylabel='percent of methods',
    cmap=main_color_map,
    figsize=(10, 6),
    lw=2,
)
axes.set_xticklabels(method_line_count_x_ticks)
axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 1c - Top 30 packages with highest effective line counts
#
# The following table shows the top 30 packages with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Query artifacts and packages and find the method with the highest effective lines of code and cyclomatic complexity
# The result of this query will be also used further below. 
method_statistics_per_package = query_cypher_to_data_frame("../cypher/Overview/Effective_lines_of_method_code_per_package.cypher")

# %%
# Select and order the columns for this particular table 
effective_line_count_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'linesInPackage', 'methodCount', 'maxLinesMethod','maxLinesMethodName']]

# Print out the top 30 (head) rows
effective_line_count_per_package.head(30)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.7.6
# 1   axon-configuration-4.7.6
# 2       axon-messaging-4.7.6
# 3            axon-test-4.7.6
# 4       axon-messaging-4.7.6
# 5       axon-modelling-4.7.6
# 6   axon-eventsourcing-4.7.6
# 7       axon-messaging-4.7.6
# 8       axon-modelling-4.7.6
# 9       axon-disruptor-4.7.6
# 10  axon-eventsourcing-4.7.6
# 11  axon-eventsourcing-4.7.6
# 12  axon-eventsourcing-4.7.6
# 13      axon-messaging-4.7.6
# 14      axon-messaging-4.7.6
# 15      axon-messaging-4.7.6
# 16      axon-messaging-4.7.6
# 17           axon-test-4.7.6
# 18      axon-messaging-4.7.6
# 19      axon-modelling-4.7.6
# 20      axon-messaging-4.7.6
# 21      axon-messaging-4.7.6
# 22      axon-messaging-4.7.6
# 23           axon-test-4.7.6
# 24      axon-messaging-4.7.6
# 25      axon-messaging-4.7.6
# 26  axon-eventsourcing-4.7.6
# 27      axon-messaging-4.7.6
# 28      axon-modelling-4.7.6
# 29      axon-modelling-4.7.6
#
#                                       fullPackageName  linesInPackage  \
# 0                     org.axonframework.eventhandling            2213
# 1                            org.axonframework.config            1487
# 2              org.axonframework.eventhandling.pooled             939
# 3                    org.axonframework.test.aggregate             937
# 4                     org.axonframework.queryhandling             832
# 5                 org.axonframework.modelling.command             784
# 6          org.axonframework.eventsourcing.eventstore             709
# 7              org.axonframework.messaging.annotation             673
# 8      org.axonframework.modelling.command.inspection             637
# 9         org.axonframework.disruptor.commandhandling             605
# 10                    org.axonframework.eventsourcing             582
# 11  org.axonframework.eventsourcing.eventstore.leg...             570
# 12    org.axonframework.eventsourcing.eventstore.jdbc             569
# 13                    org.axonframework.serialization             537
# 14     org.axonframework.eventhandling.deadletter.jpa             522
# 15          org.axonframework.commandhandling.gateway             504
# 16                           org.axonframework.common             501
# 17                        org.axonframework.test.saga             494
# 18      org.axonframework.commandhandling.distributed             479
# 19                   org.axonframework.modelling.saga             458
# 20    org.axonframework.eventhandling.tokenstore.jdbc             430
# 21  org.axonframework.eventhandling.deadletter.leg...             401
# 22             org.axonframework.messaging.unitofwork             363
# 23                    org.axonframework.test.matchers             351
# 24                        org.axonframework.messaging             348
# 25                  org.axonframework.commandhandling             341
# 26     org.axonframework.eventsourcing.eventstore.jpa             320
# 27             org.axonframework.messaging.deadletter             297
# 28   org.axonframework.modelling.saga.repository.jdbc             274
# 29        org.axonframework.modelling.saga.repository             268
#
#     methodCount  maxLinesMethod  \
# 0           793              64
# 1           576              42
# 2           308              70
# 3           249              45
# 4           333              36
# 5           315              17
# 6           262              21
# 7           239              23
# 8           218              26
# 9           184              32
# 10          236              20
# 11          185              25
# 12          236              24
# 13          181              22
# 14          132              28
# 15          180              50
# 16          144              24
# 17          167              29
# 18          172              21
# 19          181              23
# 20          130              26
# 21           97              21
# 22          129              32
# 23          108              21
# 24          156              13
# 25          151              13
# 26          101              25
# 27          112              33
# 28           58              38
# 29           97              22
#
#                                    maxLinesMethodName
# 0                                        processBatch
# 1                                              <init>
# 2                                                 run
# 3                                 appendEventOverview
# 4                                             doQuery
# 5                          lambda$initializeHandler$7
# 6                                   peekPrivateStream
# 7                                              <init>
# 8                             inspectFieldsAndMethods
# 9                                              <init>
# 10                                 doScheduleSnapshot
# 11                                 fetchTrackedEvents
# 12                                             <init>
# 13                                             <init>
# 14                                             equals
# 15                                      createGateway
# 16  getExactDirectSuperTypesOfParameterizedTypeOrC...
# 17                            assertDispatchedEqualTo
# 18                                           dispatch
# 19                                             handle
# 20                                        updateToken
# 21                                            convert
# 22                                  executeWithResult
# 23                                     matchingFields
# 24                                     defaultHeaders
# 25                                             <init>
# 26                                 fetchTrackedEvents
# 27                                            process
# 28                                         updateSaga
# 29                                            compare

# %% [markdown]
# ### Table 1d - Top 30 methods with the highest effective line count
#
# The following table shows the top 30 methods with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
effective_line_count_method_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxLinesMethodType', 'maxLinesMethodName', 'maxLinesMethod', 'linesInPackage']]

# Sort by the maximum of effective lines of code per package descending
effective_line_count_method_per_package=effective_line_count_method_per_package.sort_values(by='maxLinesMethod', ascending=False)

# Reset the index to the new sort order
effective_line_count_method_per_package=effective_line_count_method_per_package.reset_index()

# Print out the top 30 (head) rows
effective_line_count_method_per_package.head(30)
# Out:
#     index              artifactName  \
# 0       2      axon-messaging-4.7.6
# 1       0      axon-messaging-4.7.6
# 2      15      axon-messaging-4.7.6
# 3       3           axon-test-4.7.6
# 4       1  axon-configuration-4.7.6
# 5      31      axon-messaging-4.7.6
# 6      28      axon-modelling-4.7.6
# 7       4      axon-messaging-4.7.6
# 8      27      axon-messaging-4.7.6
# 9       9      axon-disruptor-4.7.6
# 10     22      axon-messaging-4.7.6
# 11     17           axon-test-4.7.6
# 12     14      axon-messaging-4.7.6
# 13      8      axon-modelling-4.7.6
# 14     20      axon-messaging-4.7.6
# 15     26  axon-eventsourcing-4.7.6
# 16     11  axon-eventsourcing-4.7.6
# 17     16      axon-messaging-4.7.6
# 18     12  axon-eventsourcing-4.7.6
# 19     33      axon-messaging-4.7.6
# 20      7      axon-messaging-4.7.6
# 21     19      axon-modelling-4.7.6
# 22     13      axon-messaging-4.7.6
# 23     29      axon-modelling-4.7.6
# 24     49      axon-messaging-4.7.6
# 25      6  axon-eventsourcing-4.7.6
# 26     43      axon-messaging-4.7.6
# 27     50      axon-messaging-4.7.6
# 28     23           axon-test-4.7.6
# 29     21      axon-messaging-4.7.6
#
#                                       fullPackageName  \
# 0              org.axonframework.eventhandling.pooled
# 1                     org.axonframework.eventhandling
# 2           org.axonframework.commandhandling.gateway
# 3                    org.axonframework.test.aggregate
# 4                            org.axonframework.config
# 5                   org.axonframework.deadline.quartz
# 6    org.axonframework.modelling.saga.repository.jdbc
# 7                     org.axonframework.queryhandling
# 8              org.axonframework.messaging.deadletter
# 9         org.axonframework.disruptor.commandhandling
# 10             org.axonframework.messaging.unitofwork
# 11                        org.axonframework.test.saga
# 12     org.axonframework.eventhandling.deadletter.jpa
# 13     org.axonframework.modelling.command.inspection
# 14    org.axonframework.eventhandling.tokenstore.jdbc
# 15     org.axonframework.eventsourcing.eventstore.jpa
# 16  org.axonframework.eventsourcing.eventstore.leg...
# 17                           org.axonframework.common
# 18    org.axonframework.eventsourcing.eventstore.jdbc
# 19                         org.axonframework.deadline
# 20             org.axonframework.messaging.annotation
# 21                   org.axonframework.modelling.saga
# 22                    org.axonframework.serialization
# 23        org.axonframework.modelling.saga.repository
# 24         org.axonframework.eventhandling.deadletter
# 25         org.axonframework.eventsourcing.eventstore
# 26                 org.axonframework.deadline.jobrunr
# 27    org.axonframework.serialization.upcasting.event
# 28                    org.axonframework.test.matchers
# 29  org.axonframework.eventhandling.deadletter.leg...
#
#                                    maxLinesMethodType  \
# 0                        Coordinator$CoordinationTask
# 1                              TrackingEventProcessor
# 2                               CommandGatewayFactory
# 3                                            Reporter
# 4                               EventProcessingModule
# 5                                         DeadlineJob
# 6                                       JdbcSagaStore
# 7                                      SimpleQueryBus
# 8                    InMemorySequencedDeadLetterQueue
# 9                                 DisruptorCommandBus
# 10                                 BatchingUnitOfWork
# 11                                   CommandValidator
# 12                               DeadLetterEventEntry
# 13  AnnotatedAggregateMetaModelFactory$AnnotatedAg...
# 14                                     JdbcTokenStore
# 15                              JpaEventStorageEngine
# 16                              JpaEventStorageEngine
# 17                                TypeReflectionUtils
# 18                             JdbcEventStorageEngine
# 19                 SimpleDeadlineManager$DeadlineTask
# 20                     AnnotatedMessageHandlingMember
# 21                                AbstractSagaManager
# 22                          AbstractXStreamSerializer
# 23     AssociationValueMap$AssociationValueComparator
# 24                   DeadLetteringEventHandlerInvoker
# 25                   EmbeddedEventStore$EventConsumer
# 26                             JobRunrDeadlineManager
# 27                         InitialEventRepresentation
# 28                                  DeepEqualsMatcher
# 29                 EventMessageDeadLetterJpaConverter
#
#                                    maxLinesMethodName  maxLinesMethod  \
# 0                                                 run              70
# 1                                        processBatch              64
# 2                                       createGateway              50
# 3                                 appendEventOverview              45
# 4                                              <init>              42
# 5                                             execute              42
# 6                                          updateSaga              38
# 7                                             doQuery              36
# 8                                             process              33
# 9                                              <init>              32
# 10                                  executeWithResult              32
# 11                            assertDispatchedEqualTo              29
# 12                                             equals              28
# 13                            inspectFieldsAndMethods              26
# 14                                        updateToken              26
# 15                                 fetchTrackedEvents              25
# 16                                 fetchTrackedEvents              25
# 17  getExactDirectSuperTypesOfParameterizedTypeOrC...              24
# 18                                             <init>              24
# 19                                                run              24
# 20                                             <init>              23
# 21                                             handle              23
# 22                                             <init>              22
# 23                                            compare              22
# 24                                             handle              22
# 25                                  peekPrivateStream              21
# 26                                            execute              21
# 27                                             <init>              21
# 28                                     matchingFields              21
# 29                                            convert              21
#
#     linesInPackage
# 0              939
# 1             2213
# 2              504
# 3              937
# 4             1487
# 5              242
# 6              274
# 7              832
# 8              297
# 9              605
# 10             363
# 11             494
# 12             522
# 13             637
# 14             430
# 15             320
# 16             570
# 17             501
# 18             569
# 19             220
# 20             673
# 21             458
# 22             537
# 23             268
# 24             105
# 25             709
# 26             141
# 27             104
# 28             351
# 29             401

# %% [markdown]
# ## Cyclomatic Complexity

# %% [markdown]
# ### Table 2a - Cyclomatic method complexity distribution
#
# This table shows the distribution of the cyclomatic complexity of methods per artifact.
# For each artifact the number of methods with the cyclomatic complexity = 1,2,3,... is shown to get an overview of how cyclomatic complexity is distributed over methods.
#
# Only the 15 artifacts with the highest method count sum and their cyclomatic method complexity distribution (limited by 40) is shown here. The whole table can be found in the CSV report `Cyclomatic_Method_Complexity_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
cyclomatic_method_complexity_distribution_max_artifacts=15

cyclomatic_method_complexity_distribution=query_cypher_to_data_frame("../cypher/Overview/Cyclomatic_Method_Complexity_Distribution.cypher")
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.pivot(index='cyclomaticComplexity', columns='artifactName', values='methods')

# Fill missing values with zero
cyclomatic_method_complexity_distribution.fillna(0, inplace=True)

# Convert to integer
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
cyclomatic_method_complexity_distribution = cyclomatic_method_complexity_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:cyclomatic_method_complexity_distribution_max_artifacts]]

cyclomatic_method_complexity_distribution.head(40)
# Out:
# artifactName          axon-messaging-4.7.6.jar  axon-eventsourcing-4.7.6.jar  \
# cyclomaticComplexity
# 1                                         3860                           926
# 2                                          414                            92
# 3                                          266                            54
# 4                                          130                            24
# 5                                           65                             9
# 6                                           43                             3
# 7                                           19                             7
# 8                                           10                             7
# 9                                            7                             0
# 10                                           4                             0
# 11                                           7                             0
# 12                                           3                             0
# 13                                           2                             1
# 14                                           1                             0
# 15                                           1                             0
# 16                                           1                             0
# 21                                           2                             0
# 40                                           1                             0
#
# artifactName          axon-modelling-4.7.6.jar  axon-test-4.7.6.jar  \
# cyclomaticComplexity
# 1                                          837                  492
# 2                                           75                   60
# 3                                           37                   55
# 4                                           28                   21
# 5                                           22                   12
# 6                                           11                    8
# 7                                            2                    4
# 8                                            1                    3
# 9                                            2                    1
# 10                                           0                    1
# 11                                           0                    2
# 12                                           0                    1
# 13                                           0                    1
# 14                                           0                    0
# 15                                           0                    0
# 16                                           1                    0
# 21                                           0                    0
# 40                                           0                    0
#
# artifactName          axon-configuration-4.7.6.jar  axon-disruptor-4.7.6.jar
# cyclomaticComplexity
# 1                                              516                       146
# 2                                               35                        20
# 3                                               15                         5
# 4                                                5                         4
# 5                                                3                         3
# 6                                                0                         2
# 7                                                2                         2
# 8                                                0                         2
# 9                                                0                         0
# 10                                               0                         0
# 11                                               0                         0
# 12                                               0                         0
# 13                                               0                         0
# 14                                               0                         0
# 15                                               0                         0
# 16                                               0                         0
# 21                                               0                         0
# 40                                               0                         0

# %% [markdown]
# ### Table 2b - Cyclomatic method complexity distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
cyclomatic_method_complexity_distribution_normalized = cyclomatic_method_complexity_distribution.div(cyclomatic_method_complexity_distribution.sum(axis=0), axis=1).multiply(100)
cyclomatic_method_complexity_distribution_normalized.head(40)
# Out:
# artifactName          axon-messaging-4.7.6.jar  axon-eventsourcing-4.7.6.jar  \
# cyclomaticComplexity
# 1                                    79.818031                     82.457703
# 2                                     8.560794                      8.192342
# 3                                     5.500414                      4.808549
# 4                                     2.688172                      2.137133
# 5                                     1.344086                      0.801425
# 6                                     0.889165                      0.267142
# 7                                     0.392887                      0.623330
# 8                                     0.206782                      0.623330
# 9                                     0.144748                      0.000000
# 10                                    0.082713                      0.000000
# 11                                    0.144748                      0.000000
# 12                                    0.062035                      0.000000
# 13                                    0.041356                      0.089047
# 14                                    0.020678                      0.000000
# 15                                    0.020678                      0.000000
# 16                                    0.020678                      0.000000
# 21                                    0.041356                      0.000000
# 40                                    0.020678                      0.000000
#
# artifactName          axon-modelling-4.7.6.jar  axon-test-4.7.6.jar  \
# cyclomaticComplexity
# 1                                    82.381890            74.432678
# 2                                     7.381890             9.077156
# 3                                     3.641732             8.320726
# 4                                     2.755906             3.177005
# 5                                     2.165354             1.815431
# 6                                     1.082677             1.210287
# 7                                     0.196850             0.605144
# 8                                     0.098425             0.453858
# 9                                     0.196850             0.151286
# 10                                    0.000000             0.151286
# 11                                    0.000000             0.302572
# 12                                    0.000000             0.151286
# 13                                    0.000000             0.151286
# 14                                    0.000000             0.000000
# 15                                    0.000000             0.000000
# 16                                    0.098425             0.000000
# 21                                    0.000000             0.000000
# 40                                    0.000000             0.000000
#
# artifactName          axon-configuration-4.7.6.jar  axon-disruptor-4.7.6.jar
# cyclomaticComplexity
# 1                                        89.583333                 79.347826
# 2                                         6.076389                 10.869565
# 3                                         2.604167                  2.717391
# 4                                         0.868056                  2.173913
# 5                                         0.520833                  1.630435
# 6                                         0.000000                  1.086957
# 7                                         0.347222                  1.086957
# 8                                         0.000000                  1.086957
# 9                                         0.000000                  0.000000
# 10                                        0.000000                  0.000000
# 11                                        0.000000                  0.000000
# 12                                        0.000000                  0.000000
# 13                                        0.000000                  0.000000
# 14                                        0.000000                  0.000000
# 15                                        0.000000                  0.000000
# 16                                        0.000000                  0.000000
# 21                                        0.000000                  0.000000
# 40                                        0.000000                  0.000000

# %% [markdown]
# ### Table 2b Chart 1 - Cyclomatic method complexity distribution (normalized)

# %%
plot.figure();
method_line_count_x_ticks=range(1,11)
cyclomatic_complexity_y_ticks=[1, 2, 3, 4, 5, 7, 10, 20, 30, 40, 50, 100]
axes = cyclomatic_method_complexity_distribution_normalized.plot(
    kind='line', 
    logx=True,
    logy=True,
    grid=True,
    xlim=[1,11],
    ylim=[1,100],
    xticks=method_line_count_x_ticks,
    yticks=cyclomatic_complexity_y_ticks,
    title='Cyclomatic complexity distribution of methods', 
    xlabel='cyclomatic complexity',
    ylabel='percentage of methods',
    cmap=main_color_map,
)
axes.set_xticklabels(method_line_count_x_ticks)
axes.set_yticklabels(cyclomatic_complexity_y_ticks)
axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plot.show()

# %% [markdown]
# ### Table 2c - Top 30 packages with highest cyclomatic complexity
#
# The following table shows the top 30 packages with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'complexityInPackage', 'methodCount', 'maxComplexity','maxComplexityMethod']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_package=cyclomatic_complexity_per_package.sort_values(by='complexityInPackage', ascending=False)

# Print out the top 30 (head) rows
cyclomatic_complexity_per_package.head(30)
# Out:
#                 artifactName  \
# 0       axon-messaging-4.7.6
# 1   axon-configuration-4.7.6
# 3            axon-test-4.7.6
# 5       axon-modelling-4.7.6
# 4       axon-messaging-4.7.6
# 2       axon-messaging-4.7.6
# 6   axon-eventsourcing-4.7.6
# 7       axon-messaging-4.7.6
# 8       axon-modelling-4.7.6
# 10  axon-eventsourcing-4.7.6
# 16      axon-messaging-4.7.6
# 11  axon-eventsourcing-4.7.6
# 13      axon-messaging-4.7.6
# 9       axon-disruptor-4.7.6
# 12  axon-eventsourcing-4.7.6
# 19      axon-modelling-4.7.6
# 15      axon-messaging-4.7.6
# 18      axon-messaging-4.7.6
# 17           axon-test-4.7.6
# 14      axon-messaging-4.7.6
# 24      axon-messaging-4.7.6
# 22      axon-messaging-4.7.6
# 23           axon-test-4.7.6
# 25      axon-messaging-4.7.6
# 20      axon-messaging-4.7.6
# 27      axon-messaging-4.7.6
# 26  axon-eventsourcing-4.7.6
# 30      axon-messaging-4.7.6
# 36      axon-messaging-4.7.6
# 21      axon-messaging-4.7.6
#
#                                       fullPackageName  complexityInPackage  \
# 0                     org.axonframework.eventhandling                 1214
# 1                            org.axonframework.config                  680
# 3                    org.axonframework.test.aggregate                  434
# 5                 org.axonframework.modelling.command                  427
# 4                     org.axonframework.queryhandling                  419
# 2              org.axonframework.eventhandling.pooled                  415
# 6          org.axonframework.eventsourcing.eventstore                  395
# 7              org.axonframework.messaging.annotation                  386
# 8      org.axonframework.modelling.command.inspection                  340
# 10                    org.axonframework.eventsourcing                  305
# 16                           org.axonframework.common                  301
# 11  org.axonframework.eventsourcing.eventstore.leg...                  290
# 13                    org.axonframework.serialization                  285
# 9         org.axonframework.disruptor.commandhandling                  274
# 12    org.axonframework.eventsourcing.eventstore.jdbc                  273
# 19                   org.axonframework.modelling.saga                  264
# 15          org.axonframework.commandhandling.gateway                  257
# 18      org.axonframework.commandhandling.distributed                  240
# 17                        org.axonframework.test.saga                  234
# 14     org.axonframework.eventhandling.deadletter.jpa                  212
# 24                        org.axonframework.messaging                  209
# 22             org.axonframework.messaging.unitofwork                  206
# 23                    org.axonframework.test.matchers                  191
# 25                  org.axonframework.commandhandling                  180
# 20    org.axonframework.eventhandling.tokenstore.jdbc                  173
# 27             org.axonframework.messaging.deadletter                  169
# 26     org.axonframework.eventsourcing.eventstore.jpa                  155
# 30                          org.axonframework.tracing                  150
# 36          org.axonframework.messaging.responsetypes                  148
# 21  org.axonframework.eventhandling.deadletter.leg...                  147
#
#     methodCount  maxComplexity  \
# 0           793             21
# 1           576              7
# 3           249             13
# 5           315              9
# 4           333             11
# 2           308             21
# 6           262             13
# 7           239             14
# 8           218              9
# 10          236              8
# 16          144              9
# 11          185              8
# 13          181              7
# 9           184              8
# 12          236              7
# 19          181              6
# 15          180             12
# 18          172             12
# 17          167              9
# 14          132             15
# 24          156              4
# 22          129             11
# 23          108              8
# 25          151             10
# 20          130              9
# 27          112             10
# 26          101              8
# 30          120              7
# 36           76             10
# 21           97             11
#
#                                   maxComplexityMethod
# 0                                        processBatch
# 1                             invokeLifecycleHandlers
# 3                                   ensureValuesEqual
# 5                                       resolveTarget
# 4                                             doQuery
# 2                                                 run
# 6                                             hasNext
# 7                                              handle
# 8                                     prepareHandlers
# 10                                 doScheduleSnapshot
# 16  getExactDirectSuperTypesOfParameterizedTypeOrC...
# 11                              loadKeyViolationCodes
# 13                                     calculateRoute
# 9                                          doDispatch
# 12                                lambda$cleanGaps$37
# 19                                             handle
# 15                                      createGateway
# 18                                             equals
# 17                            assertDispatchedEqualTo
# 14                                             equals
# 24                                               from
# 22                                  executeWithResult
# 23                                        matchesList
# 25                                             <init>
# 20                                        updateToken
# 27                                             equals
# 26                                 fetchTrackedEvents
# 30                               determineMessageName
# 36                                            convert
# 21                                             equals

# %% [markdown]
# ### Table 2d - Top 30 methods with highest cyclomatic complexity
#
# The following table shows the top 30 packages containing the methods with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_method=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxComplexityType', 'maxComplexityMethod', 'maxComplexity']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.sort_values(by='maxComplexity', ascending=False)

# Reset the index to the new sort order
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.reset_index()

# Print out the top 30 (head) rows
cyclomatic_complexity_per_method.head(30)
# Out:
#     index              artifactName  \
# 0      47      axon-messaging-4.7.6
# 1       0      axon-messaging-4.7.6
# 2       2      axon-messaging-4.7.6
# 3      29      axon-modelling-4.7.6
# 4      14      axon-messaging-4.7.6
# 5       7      axon-messaging-4.7.6
# 6      46      axon-messaging-4.7.6
# 7      43      axon-messaging-4.7.6
# 8       6  axon-eventsourcing-4.7.6
# 9       3           axon-test-4.7.6
# 10     35      axon-messaging-4.7.6
# 11     15      axon-messaging-4.7.6
# 12     18      axon-messaging-4.7.6
# 13     55           axon-test-4.7.6
# 14     22      axon-messaging-4.7.6
# 15      4      axon-messaging-4.7.6
# 16     31      axon-messaging-4.7.6
# 17     21      axon-messaging-4.7.6
# 18     44      axon-messaging-4.7.6
# 19     36      axon-messaging-4.7.6
# 20     27      axon-messaging-4.7.6
# 21     25      axon-messaging-4.7.6
# 22     45      axon-messaging-4.7.6
# 23      5      axon-modelling-4.7.6
# 24     20      axon-messaging-4.7.6
# 25      8      axon-modelling-4.7.6
# 26     17           axon-test-4.7.6
# 27     16      axon-messaging-4.7.6
# 28     23           axon-test-4.7.6
# 29      9      axon-disruptor-4.7.6
#
#                                       fullPackageName  \
# 0   org.axonframework.eventhandling.scheduling.job...
# 1                     org.axonframework.eventhandling
# 2              org.axonframework.eventhandling.pooled
# 3         org.axonframework.modelling.saga.repository
# 4      org.axonframework.eventhandling.deadletter.jpa
# 5              org.axonframework.messaging.annotation
# 6   org.axonframework.commandhandling.distributed....
# 7                  org.axonframework.deadline.jobrunr
# 8          org.axonframework.eventsourcing.eventstore
# 9                    org.axonframework.test.aggregate
# 10                      org.axonframework.common.jdbc
# 11          org.axonframework.commandhandling.gateway
# 12      org.axonframework.commandhandling.distributed
# 13                      org.axonframework.test.server
# 14             org.axonframework.messaging.unitofwork
# 15                    org.axonframework.queryhandling
# 16                  org.axonframework.deadline.quartz
# 17  org.axonframework.eventhandling.deadletter.leg...
# 18                      org.axonframework.common.lock
# 19          org.axonframework.messaging.responsetypes
# 20             org.axonframework.messaging.deadletter
# 21                  org.axonframework.commandhandling
# 22               org.axonframework.serialization.json
# 23                org.axonframework.modelling.command
# 24    org.axonframework.eventhandling.tokenstore.jdbc
# 25     org.axonframework.modelling.command.inspection
# 26                        org.axonframework.test.saga
# 27                           org.axonframework.common
# 28                    org.axonframework.test.matchers
# 29        org.axonframework.disruptor.commandhandling
#
#                                     maxComplexityType  \
# 0                               JobRunrEventScheduler
# 1                              TrackingEventProcessor
# 2                        Coordinator$CoordinationTask
# 3      AssociationValueMap$AssociationValueComparator
# 4                                DeadLetterEventEntry
# 5                      AnnotatedMessageHandlingMember
# 6                                   CommandNameFilter
# 7                              JobRunrDeadlineManager
# 8                      ConcatenatingDomainEventStream
# 9                                AggregateTestFixture
# 10                           ConnectionWrapperFactory
# 11                              CommandGatewayFactory
# 12                                       ReplyMessage
# 13                              AxonServerEEContainer
# 14                                 BatchingUnitOfWork
# 15                                     SimpleQueryBus
# 16                                        DeadlineJob
# 17                                      JpaDeadLetter
# 18              PessimisticLockFactory$DisposableLock
# 19                      MultipleInstancesResponseType
# 20                                  GenericDeadLetter
# 21  MethodCommandHandlerDefinition$MethodCommandMe...
# 22                                  JacksonSerializer
# 23                    AnnotationCommandTargetResolver
# 24                                     JdbcTokenStore
# 25  AnnotatedAggregateMetaModelFactory$AnnotatedAg...
# 26                                   CommandValidator
# 27                                TypeReflectionUtils
# 28                                    SequenceMatcher
# 29                                DisruptorCommandBus
#
#                                   maxComplexityMethod  maxComplexity
# 0                                 $deserializeLambda$             40
# 1                                        processBatch             21
# 2                                                 run             21
# 3                                             compare             16
# 4                                              equals             15
# 5                                              handle             14
# 6                                 $deserializeLambda$             13
# 7                                 $deserializeLambda$             13
# 8                                             hasNext             13
# 9                                   ensureValuesEqual             13
# 10                                      lambda$wrap$0             12
# 11                                      createGateway             12
# 12                                             equals             12
# 13                                             equals             11
# 14                                  executeWithResult             11
# 15                                            doQuery             11
# 16                                            execute             11
# 17                                             equals             11
# 18                                               lock             10
# 19                                            convert             10
# 20                                             equals             10
# 21                                             <init>             10
# 22                                        deserialize              9
# 23                                      resolveTarget              9
# 24                                        updateToken              9
# 25                                    prepareHandlers              9
# 26                            assertDispatchedEqualTo              9
# 27  getExactDirectSuperTypesOfParameterizedTypeOrC...              9
# 28                                        matchesList              8
# 29                                         doDispatch              8
